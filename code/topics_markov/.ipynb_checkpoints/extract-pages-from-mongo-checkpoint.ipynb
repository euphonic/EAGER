# %% [markdown]
# # extract-pages-from-mongo
# SanjayKAroraPhD@gmail.com <br>
# November 2018
#
# ## Description
# This notebook extracts groups of pages from mongodb by firm_name to create firm-centric page output files that can later be topic modeled.  In doing so, it removes repetitive content (e.g., repeated menu items) and garbage content (e.g., improperly parsed HTML code).

# %%
# import data processing and other libraries
import csv
import sys
import requests
import os
import re
import pprint
import pymongo
import traceback
from time import sleep
import requests
import pandas as pd
from IPython.display import display
import time
import numpy as np
from bs4 import BeautifulSoup

# %%
MONGODB_DB = "FirmDB_20181116"
MONGODB_COLLECTION = "pages_COMBINED"
CONNECTION_STRING = "mongodb://localhost"

client = pymongo.MongoClient(CONNECTION_STRING)
db = client[MONGODB_DB]
col = db[MONGODB_COLLECTION]

DEPTH = 0

# %%
# gather unique firm_names from mongodb

def get_firm_aggregates ():
    query = [ { "$group": {"_id":"$firm_name" , "number":{"$sum":1}} } ]
    results = col.aggregate(query)

    mongo_dict = {}
    for result in results:
        key = (result['_id'])
        if key:
            mongo_dict[key[0]] = result['number']
        else:
            mongo_dict['NA'] = result['number']
    
    return mongo_dict

results_dict = get_firm_aggregates()
firm_names = results_dict.keys()
pp = pprint.PrettyPrinter()
pp.pprint(firm_names)
# Out:
# [u'Little Kids',
#  u'Daylight Solutions',
#  u'Biocon Limited',
#  u'Sony Corporation',
#  u'Magna International Inc.',
#  u'ENI Technology',
#  u'Honeywell International Inc.',
#  u'Aurrion',
#  u'The Jackson Laboratory',
#  u'Hewlett Packard Enterprise Development LP',
#  u'CUMMINS FILTRATION IP',
#  u'Custom Electronics Inc.',
#  u'H R D CORPORATION',
#  u'GENERAL MOTORS LLC',
#  u'FLIR Systems',
#  u'Sola U.S.A. Inc.',
#  u'Chromalox',
#  u'Empire Technology Development LLC',
#  u'Alcon Research',
#  u'Wyatt Technology Corporation',
#  u'Southwest Research Institute',
#  u'Tokyo Ohka Kogyo Co.',
#  u'Samsung Electronics',
#  u'Fairchild Semiconductor Corporation',
#  u'Supremex Inc.',
#  u'Calient Technologies',
#  u'Infineon Technologies Americas Corp.',
#  u'Ideal Power Inc.',
#  u'NuOrtho Surgical',
#  u'Easel Biotechnologies',
#  u'L-3 Communications Cincinnati Electronics Corporation',
#  u'SunEdison Semiconductor Limited',
#  u'IDEA TREE',
#  u'Solarmer Energy',
#  u'Braun Intertec Geothermal',
#  u'Fuji Electric Co.',
#  u'The Babcock & Wilcox Company',
#  u'Rima Enterprises',
#  u'Saint-Gobain Adfors Canada',
#  u'Agilent Technologies',
#  u'Toray Industries Inc. ',
#  u'Christie Digital Systems',
#  u'SYNTHOMER USA LLC',
#  u'Nissan North America',
#  u'Shin-Etsu Chemical Co.',
#  u'FUJIFILM Dimatix',
#  u'SUNSALUTER',
#  u'SII Semiconductor Corporation',
#  u'Prosoft International',
#  u'Energen',
#  u'KR Design House',
#  u'Akron Polymer Systems',
#  u'Revivicor',
#  u'Caribou Biosciences',
#  u'Syngenta Participations AG',
#  u'BERKEN ENERGY LLC',
#  u'ADASA INC.',
#  u'Abbott Molecular Inc.',
#  u'PLEX LLC',
#  u'Carver Scientific',
#  u'E. Tech Incorporation',
#  u'Canon',
#  u'Renewable Power Conversion',
#  u'Thermo Fisher Scientific Inc.',
#  u'Toray Plastics (America)',
#  u'Algenol Biotech LLC',
#  u'Cadence Design Systems',
#  u'ACACIA RESEARCH GROUP LLC',
#  u'Cabot Corporation',
#  u'Genesco Inc.',
#  u'CARBO Ceramics Inc.',
#  u'Metabolix',
#  u'TEKNOR APEX COMPANY',
#  u'One Earth Designs Inc.',
#  u'Commonwealth Scientific & Industrial Research Organization',
#  u'Siemens Industry',
#  u'Beryllium Discovery Corp.',
#  u'Tanaka Kikinzoku Kogyo K.K.',
#  u'Annam Biosciences',
#  u'Community Power Corporation',
#  u'Halliburton Energy Services',
#  u'Soraa Laser Diode',
#  u'Johnson & Johnson Vision Care',
#  u'DePuy Synthes Products',
#  u'STATS ChipPAC',
#  u'Crossbar',
#  u'Photon Dynamics',
#  u'Qiagen GmbH',
#  u'BAXALTA INCORPORATED',
#  u'Kodak Alaris Inc.',
#  u'J. E. WHITE',
#  u'AstenJohnson',
#  u'TRIDONIC GMBH & CO KG',
#  u'Heat Seal LLC',
#  u'Adlens Beacon',
#  u'VERLASE TECHNOLOGIES LLC',
#  u'UVIC INDUSTRY PARTNERSHIPS INC.',
#  u'LUCERA LABS',
#  u'Tau Therapeutics LLC',
#  u'Toshiba America Electronic Components',
#  u'PPG Industries Ohio',
#  u'BAE Systems Information and Electronic Systems Integration Inc.',
#  u'Alliance for Sustainable Energy',
#  u'Adobe Systems Incorporated',
#  u'GOAL ZERO LLC',
#  u'Handstand Innovations',
#  u'FRONT EDGE TECHNOLOGY INC.',
#  u'FUJIFILM Corporation',
#  u'Bruin Biometrics',
#  u'Lockheed Martin Corporation',
#  u'MonoSol',
#  u'nLIGHT',
#  u'Acorn Technologies',
#  u'Energysolutions',
#  u'Aerogen',
#  u'Zyvex Labs',
#  u'HGST NETHERLANDS B.V.',
#  u'BioNano Genomics',
#  u'Revera',
#  u'FEI Company',
#  u'Moxtek',
#  u'DNA Twopointo',
#  u'VMware',
#  u'Analog Devices',
#  u'SOL-ELECTRICA',
#  u'Toyota Motor Engineering & Manufacturing North America',
#  u'Deep Science',
#  u'Saint-Gobain Performance Plastics Corporation',
#  u'Macronix International Co.',
#  u'DIC Corporation',
#  u'CoolEarth Solar',
#  u'Express Imaging Systems',
#  u'Proterra Inc.',
#  u'Thorn Bioscience LLC',
#  u'Ortho-Clinical Diagnostics',
#  u'GIGA SOLAR FPC',
#  u'ALSTOM Technology Ltd',
#  u'Warsaw Orthopedic',
#  u'American Science and Technology Corporation',
#  u'E. I. du Pont de Nemours and Company',
#  u'Semiconductor Energy Laboratory Co.',
#  u'Pharmion Corporation',
#  u'Semics Inc.',
#  u'Hollywood Trucks',
#  u'Praxair Technology',
#  u'Sanuvox Technologies',
#  u'POSiFA MICROSYSTEMS',
#  u'ZENA TECHNOLOGIES',
#  u'MAXLINEAR',
#  u'NGK Spark Plug Co.',
#  u'MBC Ventures',
#  u'Headway Technologies',
#  u'Novellus Systems',
#  u'Englewood Lab',
#  u'SixPoint Materials',
#  u'Markel Corporation',
#  u'The Eastern Co.',
#  u'ABB Research Ltd.',
#  u'Shimadzu Corporation',
#  u'Fluidigm Corporation',
#  u'JOLED Inc.',
#  u'Pixar',
#  u'Bisco',
#  u'Synopsys',
#  u'Karsten Manufacturing Corporation',
#  u'Amkor Technology',
#  u'Lumenco',
#  u'Sustainable Technologies',
#  u'WCA Group LLC',
#  u'ASML Netherlands B.V.',
#  u'Hysitron Incorporated',
#  u'Eaton Corporation',
#  u'Medical Diagnostic Laboratories',
#  u'Bausch & Lomb Incorporated',
#  u'Wentworth Laboratories',
#  u'Gilead Sciences',
#  u'Heidelberger Druckmaschinen AG',
#  u'SD Technologies',
#  u'Abbott Point of Care Inc.',
#  u'Antaya Technologies Corporation',
#  u'Coleman Cable',
#  u'CMC ICOS BIOLOGICS',
#  u'Centre de Recherche Industrielle du Quebec',
#  u'Anelva Corporation',
#  u'Stablcor Technology',
#  u'Claret Medical',
#  u'Angstron Materials',
#  u'Veracyte',
#  u'Magnachip Semiconductor',
#  u'Reynolds Technologies',
#  u'Danisco US Inc.',
#  u'Bristol-Myers Squibb Company',
#  u'Polaris Products LLC',
#  u'Global Filtration Systems',
#  u'GE-Hitachi Nuclear Energy Americas LLC',
#  u'Butamax(TM) Advanced Biofuels LLC',
#  u'Fike Corporation',
#  u'Waters Technologies Corporation',
#  u'Samsung Electronics Co.',
#  u'Cavium',
#  u'ACell',
#  u'Immunolight',
#  u'Diamond Innovations',
#  u'Hollingsworth & Vose Company',
#  u'COOK MEDICAL TECHNOLOGIES LLC',
#  u'Tamura Corporation',
#  u'Crystal Solar Incorporated',
#  u'KOLO TECHNOLOGIES',
#  u'Weatherford Canada Partnership',
#  u'Casio Computer Co.',
#  u'Leap Frogg',
#  u'LGS Innovations LLC',
#  u'Kala Pharmaceuticals',
#  u'Zeno Semiconductor Inc',
#  u'Cornell Research Foundation',
#  u'National Education Corporation',
#  u'NEWFIELD THERAPEUTICS CORPORATION',
#  u'Northrop Grumman Systems Corporation',
#  u'NetApp',
#  u'Kronos International Inc',
#  u'Ion Power Group',
#  u'SEaB Energy Holdings Ltd.',
#  u'QUALCOMM Incorporated',
#  u'Gas Technology Institute',
#  u'St. Microelectronics Inc.',
#  u'Globus Medical',
#  u'Glucan Biorenewables LLC',
#  u'The Paymaster Corporation',
#  u'Tela Innovations',
#  u'VEECO PRECISION SURFACE PROCESSING LLC',
#  u'Unity Semiconductor Corporation',
#  u'Everspin Technologies',
#  u'Musco Corporation',
#  u'Nanotek Instruments',
#  u'NeuMoDx Molecular',
#  u'NanoLab',
#  u'MICROMIDAS',
#  u'Fujitsu Limited',
#  u'Nanoholdings',
#  u'Green Extraction Technologies',
#  u'Guardian Industries',
#  u'Integrated Device Technology',
#  u'Kashiv Pharma',
#  u'Allertein Therapeutics',
#  u'Baker Hughes Incorporated',
#  u'Solar Junction Corporation',
#  u'DHPC TECHNOLOGIES',
#  u'Yamaha Corporation',
#  u'Clearside Biomedical',
#  u'Met Tech Inc.',
#  u'GLOBALFOUNDRIES Inc.',
#  u'22nd Century Limited',
#  u'HTS',
#  u'Avon Products',
#  u'PDF Solutions',
#  u'TOMOWAVE LABORATORIES',
#  u'Sungevity Inc.',
#  u'Zephyr Energy Systems LLC',
#  u'Marathon Equipment Company',
#  u'Sumco Corporation',
#  u'Angaza Design',
#  u'Advanced Water Technology',
#  u'GE Healthcare Dharmacon',
#  u'Johnson Controls Technology Company',
#  u'Lux Bio Group',
#  u'Aushon Biosystems',
#  u'IMEC',
#  u'CERION LLC',
#  u'Qualsig Inc.',
#  u'Delavau LLC',
#  u'Kabushikikaisha Toshiba',
#  u'Veracode',
#  u'Oracle International Corporation',
#  u'Shell Oil Company',
#  u'Princeton Optronics',
#  u'TerraVia Holdings',
#  u'True-Safe Technologies',
#  u'Ansun Biopharma',
#  u'Solutia Inc.',
#  u'Crystalplex Corporation',
#  u'NovaSolix',
#  u'ExxonMobil Upstream Research Company',
#  u'Quantum Materials Corporation',
#  u'NOVA PANGAEA TECHNOLOGIES LIMITED',
#  u'Great American Duck Races',
#  u'Biocare Medical',
#  u'Swift Engineering',
#  u'Renesas Electronics Corporation',
#  u'Star Technology and Research',
#  u'TDK Corporation',
#  u'CAMBRIDGE ENTERPRISE LIMITED',
#  u'Magnolia Optical Technologies',
#  u'Mission Product Holdings',
#  u'WOVN',
#  u'Atrium Medical Corporation',
#  u'Hyundai Motor Company',
#  u'BASF Plant Science GmbH',
#  u'Kobe Steel',
#  u'Global Eagle Entertainment Inc.',
#  u'BROADCOM CORPORATION',
#  u'Yageo Corporation',
#  u'Em-Tech LLC',
#  u'McAlister Technologies',
#  u'Dow AgroSciences LLC',
#  u'Biotechnology Foundation',
#  u'Transilwrap Company',
#  u'Quantum Devices',
#  u'Vascular BioSciences',
#  u'Longhorn Vaccines and Diagnostics',
#  u'AGFA-GEVAERT N.V.',
#  u'Nordic Technologies',
#  u'Optodot Corporation',
#  u'Morpho',
#  u'MERCK SHARP & DOHME CORP.',
#  u'Ajinomoto Althea',
#  u'Combined Energies',
#  u'Michigan Biotechnology Institute',
#  u'ProNAi Therapeutics',
#  u'Cbrite Inc.',
#  u'PetraSolar',
#  u'WHATSAPP INC.',
#  u'Virent',
#  u'Ethicon Endo-Surgery',
#  u'Iogen Corporation',
#  u'McElroy Manufacturing',
#  u'NeoVision LLC',
#  u'Astech',
#  u'DEKA Products Limited Partnership',
#  u'Taiwan Semiconductor Manufacturing Company',
#  u'InView Technology Corporation',
#  u'Hunt Energy Enterprises LLC',
#  u'Rolls-Royce PLC',
#  u'BASF',
#  u'SRG Global',
#  u'Theraclone Sciences',
#  u'St. Jude Medical',
#  u'SEIKO NPC Corporation',
#  u'Areesys Technologies',
#  u'OLYMPUS CORPORATION',
#  u'Two Blades Foundation',
#  u'Senaya',
#  u'RES USA',
#  u'EXOS LLC',
#  u'BRIGHTLEAF TECHNOLOGIES INC.',
#  u'Ibis Biosciences',
#  u'Archer Daniels Midland Company',
#  u'Avertech',
#  u'Oculus VR',
#  u'Silicon Space Technology Corp.',
#  u'CP Kelco U.S.',
#  u'Cleanvantage LLC',
#  u'Novus Technology',
#  u'NCC Nano',
#  u'Simbol Inc.',
#  u'Agena Bioscience',
#  u'Stratasys',
#  u'U.S. NUTRACEUTICALS',
#  u'GED Intergrated Solution',
#  u'Linne Industries LLC',
#  u'Canon Kabushiki Kaisha',
#  u'Intermolecular',
#  u'Siemens Corporation',
#  u'Momentive Performance Materials Inc.',
#  u'Baxter International Inc.',
#  u'Materia',
#  u'Pfizer Inc.',
#  u'Maxout Renewables',
#  u'Ube Industries',
#  u'EPCOS AG',
#  u'Sick AG',
#  u'Siluria Technologies',
#  u'Adynxx',
#  u'Dialogic Corporation',
#  u'Marine Polymer Technologies',
#  u'NANOBIO CORPORATION',
#  u'Seiko Epson Corporation',
#  u'UTC FIRE & SECURITY CORPORATION',
#  u'NANO CELL SYSTEMS',
#  u'Illinois Tool Works',
#  u'SunRun',
#  u'ABB Technology Ltd.',
#  u'KUBIX INC.',
#  u'Gemex Systems',
#  u'King Electric Vehicles Inc.',
#  u'Global OLED Technology LLC',
#  u'Gracenote',
#  u'LG NANOH2O',
#  u'Battelle Memorial Institute',
#  u'American Piledriving Equipment',
#  u'Wizard Labs',
#  u'Genentech',
#  u'Sysmex Corporation',
#  u'GCP Applied Technologies Inc.',
#  u'KINO LLC',
#  u'TECNIUM',
#  u'Silicon Storage Technology',
#  u'Molecular Rebar Design',
#  u'Uniseal Solutions Inc.',
#  u'MicroLink Devices',
#  u'Bioneer Corporation',
#  u'D-Wave Systems Inc.',
#  u'Nantero',
#  u'Amberwave Inc.',
#  u'Thoratec Corporation',
#  u'Selecta Biosciences',
#  u'Child Laboratories Inc.',
#  u'AgroFresh Inc.',
#  u'Arpin Renewable Energy',
#  u'Xerox Corporation',
#  u'Dialight Corporation',
#  u'SPC International',
#  u"Nationwide Children's Hospital",
#  u'Perkinelmer Holdings',
#  u'American Air Liquide',
#  u'Brewer Science Inc.',
#  u'Solvay Specialty Polymers USA',
#  u'UWM Research Foundation',
#  u'Grandis Inc.',
#  u'BASF Coatings GmbH',
#  u'Pacific Biosciences of California',
#  u'Genisphere',
#  u'Achushnet Company',
#  u'Midrex Technologies',
#  u'TT Technologies',
#  u'Newdoll Enterprises LLC',
#  u'Carbon3D',
#  u'AG ENERGY SOLUTIONS',
#  u'Terra Caloric',
#  u'Applied Membrane Technologies',
#  u'Lintec Corporation',
#  u'Kansai Paint Co.',
#  u'Nanotech Biomachines',
#  u'Egenera',
#  u'3M Innovative Properties Company',
#  u'MATERIALS ANALYSIS TECHNOLOGY (US) CORP.',
#  u'SunCulture Solar Inc.',
#  u'KYOCERA DOCUMENT SOLUTIONS INC.',
#  u'Olympus NDT',
#  u'Omron Corporation',
#  u'Red Hat',
#  u'Takara Bio Inc.',
#  u'MirTech',
#  u'Momentive Performance Materials GmbH',
#  u'Pinnacle Technology',
#  u'Elwha LLC',
#  u'Inaeris Technologies',
#  u'Genomatica',
#  u'Henkel AG & Co. KGaA',
#  u'Dentsply International',
#  u'Owens-Brockway Glass Container Inc.',
#  u'SolarWorld Americas Inc.',
#  u'Applied Nanostructures',
#  u'GENERAL ELECTRIC COMPANY',
#  u'KT Corporation',
#  u'Cisco Technology',
#  u'Avantor Performance Materials',
#  u'Kaneka Corporation',
#  u'Dexerials Corporation',
#  u'Angiotech Pharmaceuticals (US)',
#  u'Dolby Laboratories Licensing Corporation',
#  u'Authenex',
#  u'Canon U.S. Life Sciences',
#  u'Garland Industries',
#  u'Andritz Inc.',
#  u'AGC Flat Glass North America',
#  u'Babcock Power Services',
#  u'Vizio Inc.',
#  u'Arkival Technology Corp.',
#  u'Newport Corporation',
#  u'iNanoBio LLC',
#  u'AltaRock Energy',
#  u'Unifrax I LLC',
#  u'Liquidia Technologies',
#  u'Lawrence Livermore National Security',
#  u'Applied Genetic Technologies Corporation',
#  u'Research Triangle Institute',
#  u'SolarLego Inc.',
#  u'HARMAN INTERNATIONAL INDUSTRIES',
#  u'Brookhaven Science Associates LLC ',
#  u'nanoComposix',
#  u'Nordson Corporation',
#  u'Federal Signal Corporation',
#  u'Imperial Innovations Limited',
#  u'Crestovo LLC',
#  u'OrbusNeich Medical',
#  u'Minebea Co.',
#  u'Adhesives Research',
#  u'KLA-Tencor Corporation',
#  u'Confluence Energy',
#  u'CP KELCO APS',
#  u'Roche Molecular Systems',
#  u'HAMAMATSU PHOTONICS K.K.',
#  u'Sanyo Electric Co.',
#  u'Hitachi High-Technologies Corporation',
#  u'Cedar Ridge Research',
#  u'Invensas Corporation',
#  u'Cambridge Electronics',
#  u'HRL Laboratories',
#  u'Verliant Energy',
#  u'Northwest Biotherapeutics',
#  u'KJ BIOSCIENCES LLC',
#  u'Johnson & Johnson Consumer Companies',
#  u'SNS NANO FIBER TECHNOLOGY',
#  u'CNH Industrial America LLC',
#  u'Osram Sylvania Inc.',
#  u'Envisionit LLC',
#  u'Sun Chemical Corporation',
#  u'Kajima Corporation',
#  u'Mitsubishi Metal Corporation',
#  u'TP Solar',
#  u'ATTOSTAT',
#  u'Wikipad',
#  u'Sunlight Photonics Inc.',
#  u'Pulse Therapeutics',
#  u'Sensor Electronic Technology',
#  u'Hon Hai Precision Industry Co.',
#  u'Extech/Exterior Technologies',
#  u'NanoTech Lubricants',
#  u'The Samuel Roberts Noble Foundation',
#  u'WiSys Technology Foundation',
#  u'ITN Energy Systems',
#  u'Reliance Controls Corporation',
#  u'Auterra',
#  u'Sumitomo Electric Device Innovations',
#  u'MicroContinuum',
#  u'Microchip Technology Incorporated',
#  u'DiscoveRx Corporation',
#  u'Genomic Health',
#  u'Carestream Health',
#  u'TRI ALPHA ENERGY',
#  u'Renmatix',
#  u'Zygo Corporation',
#  u'PACCAR Inc',
#  u'Evernote Corporation',
#  u'Entegris',
#  u'IDEX Health & Science LLC',
#  u'Echogen Power Systems',
#  u'Lion Copolymer Geismar',
#  u'Nanoridge Materials',
#  u'Rebellion Photonics',
#  u'Big Belly Solar',
#  u'Nokomis',
#  u'SUMITOMO WIRING SYSTEMS',
#  u'Zoetis Services LLC',
#  u'ExxonMobil Research and Engineering Company',
#  u'VINDICO NANOBIO TECHNOLOGY INC.',
#  u'HNO Greenfuels',
#  u'Esolar',
#  u'Bayer Cropscience AG',
#  u'EMD Technologies Inc.',
#  u'Newlans',
#  u'HIQ SOLAR',
#  u'Nederlandse Organisatie voor toegepast-natuurwetenschappelijk onderzoek TNO',
#  u'U S MICROPOWER INC',
#  u'Hewlett-Packard Development Company',
#  u'Arkema Inc.',
#  u'Floadia Corporation',
#  u'Entech Solar',
#  u'Global Solar Water Power Systems',
#  u'PortaFire',
#  u'Ormat Technologies Inc.',
#  u'Calysta',
#  u'MCI',
#  u'Singular Bio',
#  u'Xyleco',
#  u'Bigelow Aerospace',
#  u'Pacific Light Technologies',
#  u'Tesla Nanocoatings',
#  u'Integrated Solar Technology',
#  u'FULL CIRCLE BIOCHAR',
#  u'bioTheranostics',
#  u'UChicago Argonne',
#  u'Cetac Technologies Inc.',
#  u'fybr',
#  u'Da Yu Enterprises',
#  u'Adtran',
#  u'HOWARD INDUSTRIES',
#  u'Bitrode Corporation',
#  u'Sundrop Fuels',
#  u'AT&T Corporation',
#  u'Quallion LLC',
#  u'Ignis Innovation',
#  u'MONTEREY RESEARCH',
#  u'Stora Enso Oyj',
#  u'Proton Power',
#  u'Ambature',
#  u'Dermazone Solutions',
#  u'Industrial Technology Research Institute',
#  u'First Solar',
#  u'Inphenix',
#  u'RF Micro Devices',
#  u'Fujitsu Semiconductor Limited',
#  u'Meso Scale Technologies',
#  u'DSP Group LTD.',
#  u'Evri',
#  u'Abbott Cardiovascular Systems Inc.',
#  u'Solan',
#  u'LG Display Co.',
#  u'Bostik',
#  u'George Mason Research Foundation',
#  u'Soliton Lasers',
#  u'LIQUID X PRINTED METALS',
#  u'GOLBA LLC',
#  u'Innovation Hammer',
#  u'Conversant Intellectual Property Management Inc.',
#  u'Pacific Industrial Development Corporation',
#  u'Infinera Corporation',
#  u'Laserline Mfg.',
#  u'UT-Battelle',
#  u'BP Corporation North America Inc.',
#  u'Envision Solar International',
#  u'Avalanche Technology',
#  u'Bestway',
#  u'Suncore Photovoltaics',
#  u'Nikon Corporation',
#  u'Nippon Shokubai Co.',
#  u'Apple Inc.',
#  u'Janssen Biotech',
#  u'Mitsubishi Electric Corporation',
#  u'JSR Corporation',
#  u'Cross Match Technologies',
#  u'Tokyo Electron Limited',
#  u'CELLTRION',
#  u'Kamtec',
#  u'Faurecia Interior Systems',
#  u'RenovaCare Sciences Corp.',
#  u'Pansonic Corporation',
#  u'Codexis',
#  u'Applied Optoelectronics',
#  u'POET Research',
#  u'Sumitomo Rubber Industries',
#  u'MANUFACTURING RESOURCES INTERNATIONAL',
#  u'Greatbatch Ltd.',
#  u'IDEALAB',
#  u'Nthdegree Technologies Worldwide Inc.',
#  u'Fina Technology',
#  u'Corporation for National Research Initiatives',
#  u'Ablexis',
#  u'AbbVie Inc.',
#  u'FastCAP Systems Corporation',
#  u'Professional Compounding Centers of America',
#  u'Sensor-Kinesis Corporation',
#  u'Microsurge',
#  u'GLIKNIK INC.',
#  u'Luna Innovations Incorporated',
#  u'Eastman Kodak Company',
#  u'Mainstream Engineering Corp.',
#  u'Deployable Space Systems',
#  u'OSI Optoelectronics',
#  u'Thorlabs',
#  u'Microsemi SoC Corporation',
#  u'Transtron Solutions LLC',
#  u'NOK Corporation',
#  u'Bi-Modal Corporation',
#  u'Wenger Corporation',
#  u'Tufts Medical Center',
#  u'Chevron Oronitz Company LLC',
#  u'Hitachi Metals',
#  u'JNC Corporation',
#  u'Synaptic Research',
#  u'k-Space Associates',
#  u'Intuitive Surgical Operations',
#  u'FutureWei Technologies',
#  u'GLYCON LLC',
#  u'S. C. Johnson & Son',
#  u'Solar-Tectic LLC',
#  u'Cree',
#  u'Arcturus Therapeutics',
#  u'T.H.E.M.',
#  u'SolAero Technologies Corp.',
#  u'Banpil Photonics',
#  u'Selkermetrics',
#  u'Atleisure LLC',
#  u'Kiverdi',
#  u'STANDARD ALCOHOL COMPANY OF AMERICA',
#  u'Altex Technologies Corporation',
#  u'Adaptive Biotechnologies Corp.',
#  u'Brother International Corporation',
#  u'Amprius',
#  u'Vadient Optics',
#  u'Shoals Technologies Group',
#  u'Colgate-Palmolive Company',
#  u'Chevron U.S.A. Inc.',
#  u'Boehringer Ingelheim Vetmedica GmbH',
#  u'Boehringer Ingelheim International GmbH',
#  u'Inventus Holdings',
#  u'Surebeam Corporation',
#  u'Hoya Corporation',
#  u'Dynamic Solutions Worldwide',
#  u'Starlight Energy Holdings LLC',
#  u'Grain Processing Corporation',
#  u'Flextronics AP',
#  u'Fenwal',
#  u'CLEARSIGN COMBUSTION CORPORATION',
#  u'Incept LLC',
#  u'ZON',
#  u'Biological Dynamics',
#  u'R.J. Reynolds Tobacco Company',
#  u'SunLink Corporation',
#  u'Sangamo BioSciences',
#  u'ADVANCED CERAMIC FIBERS',
#  u'Tata Consultancy Services Limited',
#  u'KOLON INDUSTRIES',
#  u'Lam Research Corporation',
#  u'Heraeus Precious Metals North America Conshohocken LLC',
#  u'Medicis Pharmaceutical Corporation',
#  u'Robert Bosch GmbH',
#  u'Monolithe Semiconductor Inc.',
#  u'Senga Advisors',
#  u'MICROSOFT TECHNOLOGY LICENSING',
#  u'United Microelectronics Corp.',
#  u'Kureha Corporation',
#  u'Polysar Corporation',
#  u'Ethox Chemicals',
#  u'Mumetel',
#  u'Universal Display Corporation',
#  u'Biotta LLC',
#  u'SolaBlock LLC',
#  u'Redwood Systems',
#  u'Astex Pharmaceuticals',
#  u'Novus Energy LLC',
#  u'DECA Technologies Inc.',
#  u'Pioneer Energy',
#  u'Performance Plants',
#  u'Sinewatts',
#  u'ESCAPE THERAPEUTICS',
#  u'OmniVision Technologies',
#  u'X DEVELOPMENT LLC',
#  u'Monsanto Technology LLC',
#  u'Kinetech Power Company LLC',
#  u'Formula Plastics',
#  u'Green Solar Transportation',
#  u'eNow',
#  u'Atotech Deutschland GmbH',
#  u'Cool Planet Energy Systems',
#  u'NanoMech',
#  u'The Boeing Company',
#  u'Chemtreat',
#  u'Riverbed Technology',
#  u'Seiko Instruments Inc.',
#  u'OTSUKA PHARMACEUTICAL CO.',
#  u'ACUCELA INC.',
#  u'Smith & Nephew',
#  u'Eastman Chemical Company',
#  u'UNISANTIS ELECTRONICS SINGAPORE PTE. LTD.',
#  u'Neural Signals',
#  u'Vorbeck Materials Corporation',
#  u'Mattson Technology',
#  u'S&S X-Ray Products',
#  u'Nanoquantum Sciences',
#  u'Armageddon Energy Inc.',
#  u'PAX Scientific',
#  u'UCB Pharma S.A.',
#  u'INFINEUM INTERNATIONAL LIMITED',
#  u'ExxonMobil Chemical Patents Inc.',
#  u'Koch Biological Solutions',
#  u'INTEVAC',
#  u'Texas Research International',
#  u'Blue Sea Systems',
#  u'Electronic Warfare Associates',
#  u'Ricoh Company Limited',
#  u'SunPower Corporation',
#  u'Nanoco Technologies',
#  u'SAMSUNG DISPLAY CO.',
#  u'E Ink Corporation',
#  u'Nanocopocia',
#  u'GENCO SCIENCES LLC',
#  u'Amtech Systems',
#  u'mVerify Corporation',
#  u'Dana Corporation',
#  u'Sanofi',
#  u'Electrix',
#  u'Autonomic Materials',
#  u'Advanced Cell Technology',
#  u'CI4 Technologies',
#  u'Adeka Corporation',
#  u'THYSSENKRUPP INDUSTRIAL SOLUTIONS GMBH',
#  u'Universal Leaf Tobacco Co.',
#  u'Poly-Med',
#  u'Litron Laboratories Limited',
#  u'Harris Corporation',
#  u'Taiyo Ink Mfg. Co.',
#  u'Disney Enterprises',
#  u'INVISTA North America S.a.r.l.',
#  u'Symantec Corporation',
#  u'Transitions Optical',
#  u'Teledyne Scientific & Imaging',
#  u'aTyr Pharma',
#  u'NEC Corporation',
#  u'Incyte Holdings Corporation',
#  u'Raytheon Company',
#  u'Innolux Corporation',
#  u'DuPont Teijin Films U.S. Limited Partnership',
#  u'ServiceNow',
#  u'All Power Labs',
#  u'Ecovative Design',
#  u'HM3 Energy',
#  u'Lextar Electronics Corp.',
#  u'LG Electronics Inc.',
#  u'Roll-N-Lock Corporation',
#  u'SunEdison',
#  u'Synthetic Genomics',
#  u'TRANE INTERNATIONAL INC.',
#  u'Propagation Research Associates',
#  u'Industrial Science & Technology Network',
#  u'SOLENA FUELS CORPORATION',
#  u'II-VI Incorporated',
#  u'SELMAN AND ASSOCIATES',
#  u'ATC Technologies',
#  u'Allison Transmission',
#  u'Kerr Corporation',
#  u'Cura Vac',
#  u'Siemens Aktiengesellschaft ',
#  u"CSEM Centre Suisse d'Electronique et de Microtechnique SA-Recherche et Developpement",
#  u'Sinton Consulting',
#  u'Alnylam Pharmaceuticals',
#  u'PeterBrod Corp.',
#  u'Daikin Industries',
#  u'NeoPhotonics Corporation',
#  u'ECOSYNTHETIX LTD.',
#  u'ConocoPhillips Company',
#  u'AC International Inc.',
#  u'PolyOne Corporation',
#  u'Nanospectra Biosciences',
#  u'Skidmore',
#  u'SABIC GLOBAL TECHNOLOGIES B.V.',
#  u'GOJO Industries',
#  u'Tersus Environmental',
#  u'Genzyme Corporation',
#  u'ASTUTE MEDICAL',
#  u'UOP LLC',
#  u'Quantapore',
#  u'Alcotek',
#  u'Becton',
#  u'EMC Corporation',
#  u'Microchips Biotech',
#  u'Interface Performance Materials',
#  u'Paratek Pharmaceuticals',
#  u'NLT TECHNOLOGIES',
#  u'Sima Therapeutics',
#  u'Tyco Electronics Corporation',
#  u'MILLENIUM SYNTHFUELS CORPORATION',
#  u'Manta Instruments',
#  u'Plasma-Therm',
#  u'GEN-PROBE INCORPORATED',
#  u'Agrivida',
#  u'Elenion Technologies',
#  u'Alcatel Lucent',
#  u'Galectin Therapeutics',
#  u'APPLIED STEMCELL',
#  u'MIETAMARK GENETICS',
#  u'AIR PRODUCTS AND CHEMICALS',
#  u'Interez',
#  u'Uni-Charm Corporation',
#  u'Kemira OY',
#  u'Gestion Ultra International Inc.',
#  u'Nova Technologies',
#  u'Cook Biotech Incorporated',
#  u'Helios Focus LLC',
#  u'Acer Incorporated',
#  u'B.G. Negev Technologies and Applications Ltd.',
#  u'The Goodyear Tire & Rubber Company',
#  u'Basell Polyolefine GmbH',
#  u'VIASAT INC.',
#  u'Bell Helicopter Textron Inc.',
#  u'Starsource Scientific LLC',
#  u'AVOGY',
#  u'Schneider Electric USA',
#  u'WAFERTECH',
#  u'Hunter Douglas Inc.',
#  u'Dymax Corporation',
#  u'ASCENT SOLAR TECHNOLOGIES',
#  u'Conoco Inc.',
#  u'Cardiva Medical',
#  u'Columbia Insurance Company',
#  u'OPTERRA ENERGY SERVICES',
#  u'Altivera',
#  u'AROG PHARMACEUTICALS',
#  u'GTherm',
#  u'GE Healthcare Limited',
#  u'Buckman Laboratories International',
#  u'Abengoa Bioenergy New Technologies',
#  u'Ford Global Technologies',
#  u'Bio-Rad Laboratories',
#  u'Smart Planet Technologies',
#  u'Arrowhead Center',
#  u'Wostec',
#  u'Piksel',
#  u'Forest Concepts',
#  u'Delta Electronics',
#  u'Humanetics Corporation',
#  u'Fianium Ltd.',
#  u'Ivoclar Vivadent AG',
#  u'Parion Sciences',
#  u'Biosphere Medical',
#  u'GOSOLARLIFE',
#  u'Biosense Webster (Israel) Ltd.',
#  u'Stanley Electric Co.',
#  u'Sandia Corporation',
#  u'PQ CORPORATION',
#  u'Access Business Group International LLC',
#  u'Rohm and Haas Electronic Materials LLC',
#  u'SICPA Holding SA',
#  u'Kulite Semiconductor Products',
#  u'SolarCity Corporation',
#  u'Phillips 66 Company',
#  u'Rio Grande Valley Sugar Growers',
#  u'Roche Diabetes Care',
#  u'Selas Heat Technology Company LLC',
#  u'Oceanit Laboratories',
#  u'Instron Corporation ',
#  u'Triple Ring Technologies',
#  u'Nutech Ventures',
#  u'Accuri Cytometers',
#  u'Tapwave',
#  u'Saint-Gobain Ceramics & Plastics',
#  u'VIOLIN MEMORY',
#  u'Heliae Development',
#  u'Canon Nanotechnologies',
#  u'ALGETERNAL TECHNOLOGIES',
#  u'Ampio Pharmaceuticals',
#  u'Freescale Semiconductor',
#  u"Dr. Reddy's Laboratories Ltd.",
#  u'Cooper Technologies Company',
#  u'Gilead Connecticut',
#  u'VERILY LIFE SCIENCES LLC',
#  u'Bridgelux',
#  u'New England Biolabs',
#  u'Tarveda Therapeutics',
#  u'Integrated DNA Technologies',
#  u'Coactive Drive Corporation',
#  u'Regeneron Pharmaceuticals',
#  u'Pentair Thermal Management LLC',
#  u'Bend Research',
#  u'Hamilton Sundstrand Corporation',
#  u'Neutronic Perpetual Innovations',
#  u'Wireless Environment',
#  u'Gardner-Gibson',
#  u'Solaire Generation LLC',
#  u'Kinestral Technologies',
#  u'Power Integrations',
#  u'Masimo Semiconductor',
#  u'CellPrint IP Holding',
#  u'Kimberly-Clark Worldwide',
#  u'Ecolab Inc.',
#  u'Furukawa Electric Co.',
#  u'Silicor Materials Inc.',
#  u'Chevron Phillips Chemical Company LP',
#  u'Total Marketing Services',
#  u'Electrovaya Inc.',
#  u'Chipmos Technologies Inc.',
#  u'Graphene Technologies',
#  u'Carl Zeiss Meditec AG',
#  u'MEDport',
#  u'Avtaec Limited',
#  u'Roche Diagnostics GmbH',
#  u'Sweetwater Energy',
#  u'Hitachi',
#  u'Pendar Technologies',
#  u'Phoseon Technology',
#  u'Winbond Electronics Corp.',
#  u'Ensyn Renewables',
#  u'Element One',
#  u'Cyberonics',
#  u'Bird-B-Gone',
#  u'Oki Data Corporation',
#  u'Solight Solar',
#  u'Brightfield Transportation Solutions',
#  u'Dana-Farber Cancer Institute',
#  u'Google Inc.',
#  u'G.D.O. Inc',
#  u'The Carbon Cable Company',
#  u'GROW ENERGY',
#  u'Micron Technology',
#  u'R.A. Miller Industries',
#  u'LATITUDE PHARMACEUTICALS INC.',
#  u'PolyPlus Battery Company',
#  u'Green Box Batteries',
#  u'Agienic',
#  u'Peytant Solutions',
#  u'ElectraTherm',
#  u'Integrated Nano-Technologies',
#  u'Seagate Technology LLC',
#  u'GangaGen',
#  u'Mitsubishi Polyester Film',
#  u'PTC Therapeutics',
#  u'Novartis AG',
#  u'RADIANCE SOLAR',
#  u'Certain-teed Corporation',
#  u'SAINT-GOBAIN ABRASIFS',
#  u'Nvidia Corporation',
#  u'Lattice Semiconductor Corporation',
#  u'VINYLAST',
#  u'Intel Corporation',
#  u'PluroGen Therapeutics',
#  u'Roche Innovation Center Copenhagen A/S',
#  u'Pegatron Corporation',
#  u'W&Wsens Devices',
#  u'Lovelace Respiratory Research Institute',
#  u'Plant Sensory Systems',
#  u'Alencon Acquisition Co.',
#  u'AFMODEL',
#  u'Nanosys',
#  u'Delphi Technologies',
#  u'JX Nippon Mining & Metals Corporation',
#  u'The Henry M. Jackson Foundation for the Advancement of Military Medicine',
#  u'Wine.com',
#  u'SEEK THERMAL',
#  u'FLOW CONTROL LLC.',
#  u'Infineon Technologies AG',
#  u'Meyer Tool',
#  u'Magnolia Solar',
#  u'Micro Cooling Concepts',
#  u'Toda Kogyo Corporation',
#  u'Dell Software Inc.',
#  u'Atom Nanoelectronics',
#  u'Landauer',
#  u'International Business Machines Corporation',
#  u'Advanced Silicon Group',
#  u'Lake Lite',
#  u'CyboEnergy',
#  u'Marine Biotech Inc.',
#  u'ADVANCED INNOVATION CENTER LLC',
#  u'Maxim Integrated Products',
#  u'Midori USA',
#  u'Eisai Co.',
#  u'NICHIA CORPORATION',
#  u'Takeda Pharmaceutical Company Limited',
#  u'Siliconware Precision Industries Co.',
#  u'Nexcom Technology',
#  u'Denso Corporation',
#  u'Kraton Polymers U.S. LLC',
#  u'SPICE SOLAR',
#  u'Mediatek Inc.',
#  u'Continental Manufacturing',
#  u'TMC Corporation',
#  u'AMPT',
#  u'Narsys',
#  u'IMRA America',
#  u'Sun Drilling Products Corporation',
#  u'Previvo Genetics',
#  u'SB ENERGY',
#  u'Valicor',
#  u'Turf Group LLC',
#  u'International Technology Center',
#  u'HTC Corporation',
#  u'Sumitomo Electric Industries',
#  u'DISCOVERYBIOMED INC.',
#  u'PLYCEM USA',
#  u'Matrix Genetics',
#  u'Samsung SDI Co.',
#  u'Cellular Research',
#  u'EchoStar Technologies LLC',
#  u'Milliken & Company',
#  u'Honda Motor Co.',
#  u'Coloplast A/S',
#  u'Singulex',
#  u'Semprius',
#  u'Copernicus Therapeutics',
#  u'Unistrut International Corp.',
#  u'Siemens Medical Solutions USA',
#  u'Sion Power Corporation',
#  'NA',
#  u'Isis Pharmaceuticals',
#  u'Bemis Company',
#  u'Sun Synchrony',
#  u'IMDS Corporation',
#  u'SOLARTONIC',
#  u'Cristal USA Inc.',
#  u'Rapamycin Holdings',
#  u'Advanced Analogic Technologies',
#  u'Soraa',
#  u'Sierra Sciences',
#  u'Nissan Motor Co.',
#  u'CYBERCITY 3D',
#  u'Advanced Aqua Group',
#  u'Sequenom',
#  u'Hosiden Corporation',
#  u'Schlumberger Technology Corporation',
#  u'Pixelligent Technologies',
#  u'Tosoh Corporation',
#  u'Johnson Matthey PLC',
#  u'Ferro Corporation',
#  u'BTU International',
#  u'Ziptronix',
#  u'LifeNet Health',
#  u'New Technology Ventures',
#  u'Boston Scientific Scimed',
#  u'Greyrock Energy',
#  u'Courtagen Life Sciences',
#  u'ATOMERA INCORPORATED',
#  u'BASF Enzymes LLC',
#  u'Alpha and Omega Semiconductor Incorporated',
#  u'Quest Diagnostics Investments Incorporated',
#  u'Murata Manufacturing Co.',
#  u'O.B.I. Inc.',
#  u'Rhodia Operations',
#  u'Foret Plasma Labs',
#  u'Tigo Energy',
#  u'United Technologies Corporation',
#  u'Sila Nanotechnologies',
#  u'Lof Solar Corporation',
#  u'Neumedicines',
#  u'OAS Design Group',
#  u'Sagacious Investment Group L.L.C.',
#  u'System Biosciences',
#  u'Renewable Algal Energy',
#  u'SanDisk Technologies LLC',
#  u'Seetron Inc.',
#  u'Baxter Healthcare SA',
#  u'Complete Genomics',
#  u'Schneider Electric Solar Inverters USA',
#  u'Ceramatec',
#  u'Novon',
#  u'NOVA Chemicals (International) S.A.',
#  u'The Charles Stark Draper Laboratory',
#  u'Sharp Laboratories of America',
#  u'Fuji Xerox Co.',
#  u'Production Resource Group',
#  u'COVERIS FLEXIBLES US LLC',
#  u'Lehigh Technologies',
#  u'Pentron Clinical Technologies',
#  u'Domtar Paper Company',
#  u'Strategic Solar Energy',
#  u'GlaxoSmithKline Biologicals',
#  u'iBio',
#  u'Voxtel',
#  u'ENI S.p.A.',
#  u'Sigma-Aldrich Co. LLC',
#  u'Bridgestone Corporation',
#  u'Turtle Beach Corporation',
#  u'Palo Alto Research Center Incorporated',
#  u'Scientific Design Company',
#  u'SAE Magnetics (HK) Ltd.',
#  u'JFE STEEL CORPORATION',
#  u'Silicon Genesis Corporation',
#  u'JAC Products Inc.',
#  u'Vaxiion Therapeutics',
#  u'Johns Manville',
#  u'Watlow Electric Manufacturing Company',
#  u'Rockwell Collins',
#  u'Transposagen Biopharmaceuticals',
#  u'Conexant Systems',
#  u'Wave Energy Conversion Corporation of America',
#  u'Hadasit Medical Research Services & Development Company Ltd.',
#  u'Nippon Chemi-Con Corporation',
#  u'STMicroelectronics Limited',
#  u'Coriant Advanced Technology',
#  u'Dresser-Rand Company',
#  u'Bluestar Silicones France',
#  u'Finisar Corporation',
#  u'Bayer Materialscience LLC',
#  u'SolarReserve Technology',
#  u'Kia Motors Corporation ',
#  u'Nanomix',
#  u'InVisage Technologies',
#  u'Atonometrics',
#  u'ARBOR THERAPEUTICS',
#  u'Carl Zeiss Microscopy GmbH',
#  u'Applied Biosystems',
#  u'THE BOARD INSTITUTE',
#  u'Relypsa',
#  u'Ticona LLC',
#  u'Kao Corporation',
#  u'Xintec Inc.',
#  u'MAHLE International GmbH',
#  u'POLAR LIGHT TECHNOLOGIES AB',
#  u'Epizyme',
#  u'Sanken Electric Co.',
#  u'Alexion Pharmaceuticals',
#  u'Yissum',
#  u'WestPoint Home',
#  u'Georgia-Pacific Gypsum LLC',
#  u'Korea Kumho Petrochemical Co.',
#  u'Richtek Technology Corporation',
#  u'Avery Dennison Corporation',
#  u'Gtech Corporation',
#  u'AccuRay Corporation',
#  u'Gram Power',
#  u'Teradata US',
#  u'Rockwell Automation Technologies',
#  u'NanoOncology',
#  u'OFS Fitel',
#  u'ZIH Corp.',
#  u'DRS Network & Imaging Systems',
#  u'Travis Industries',
#  u'Lumentum Operations LLC']

# %%
# remove html content
def is_javascript (x):
    print ('\t' + x)
    # capture CDATA; function declarations; function calls; word sequences separated by a period (e.g., denoting paths)
    regex = re.findall('(CDATA|function|\w+\(.*?\);|\w{2,}[\\.|:]+\w{2,})', x) 
    # check to see if the regex finds some percentage of the words look like javascript patterns
    print ('\tregex is' + str(len(regex)))
    print ('\tx split is' + str(len(x.split()))
    if ((len(regex) / len(x.split())) > .10) and len(regex) > 3:
        print ("\tin if, looks like javascript")
        return True 
    else:
        return False

def clean_page_content (text_list):
    # remove whatever we think is html
    removed_html = filter(lambda x: not( bool(BeautifulSoup(x, "html.parser").find()) ), text_list)
    # remove content that looks like javascript 
    removed_js = filter(lambda x: not (is_javascript(x)), removed_html)
    
    print ("full text is " + str(len(text_list)))
    print ("cleaned html text is " + str(len(removed_html)))
    print ("cleaned js text is " + str(len(removed_js)))
    return removed_js
    

# iterate through each firm, get all pages associated with a firm, and produce data structure
# url --> depth
#     --> content (list)
# return data structure
def process_firm (firm_name): 
    regex = '^' + re.escape(firm_name) + '$'
    results = col.find( {"firm_name": re.compile(regex, re.IGNORECASE) } )

    firm_pages_dict = {}
    for result in results:
        key = (result['url'])
        if key:
            page_dict = {}
            page_dict['depth'] = result['domain'][0]
            page_dict['firm_name'] = firm_name
            page_dict['depth'] = result['depth'][0]
            page_dict['clnd_text'] = clean_page_content(result['full_text'])
            firm_pages_dict[key[0]] = page_dict
        else:
            continue
            
    return firm_pages_dict
# TODO: identify which pieces of content are common across all sites, and remove those
# def clean_content(firm_dict):
# Out:
#   File "<ipython-input-137-01a6568eb51f>", line 9
#     if ((len(regex) / len(x.split())) > .10) and len(regex) > 3:
#                                                                ^
# SyntaxError: invalid syntax

# %%
# regex test 
regex = re.findall('(CDATA|function|\w+\(.*?\);|\w{2,}[\\.|:]+\w{2,})', 'CDATA function contact-us javascript.function linker:autoLink www.littlekidsinc.com fxnCall(param.param); email@dextr.us') # last part is words sequences separated by punct
print (regex)
# Out:
# ['CDATA', 'function', 'javascript.function', 'linker:autoLink', 'www.littlekidsinc', 'fxnCall(param.param);', 'dextr.us']

# %%
# run
pp = pprint.PrettyPrinter()
for firm_name in firm_names: 
    print ("Working on " + firm_name)
    pp.pprint(process_firm (firm_name))
    break
# Out:
# Working on Little Kids
# full text is 117
# cleaned html text is 116
# cleaned js text is 116
# full text is 119
# cleaned html text is 118
# cleaned js text is 118
# full text is 106
# cleaned html text is 105
# cleaned js text is 105
# full text is 90
# cleaned html text is 89
# cleaned js text is 89
# full text is 96
# cleaned html text is 95
# cleaned js text is 95
# full text is 237
# cleaned html text is 236
# cleaned js text is 236
# full text is 202
# cleaned html text is 201
# cleaned js text is 201
# full text is 221
# cleaned html text is 220
# cleaned js text is 220
# full text is 107
# cleaned html text is 106
# cleaned js text is 106
# full text is 148
# cleaned html text is 147
# cleaned js text is 147
# full text is 158
# cleaned html text is 157
# cleaned js text is 157
# full text is 227
# cleaned html text is 226
# cleaned js text is 226
# full text is 248
# cleaned html text is 247
# cleaned js text is 247
# full text is 200
# cleaned html text is 199
# cleaned js text is 199
# full text is 208
# cleaned html text is 208
# cleaned js text is 208
# full text is 112
# cleaned html text is 111
# cleaned js text is 111
# full text is 195
# cleaned html text is 194
# cleaned js text is 194
# full text is 223
# cleaned html text is 222
# cleaned js text is 222
# full text is 185
# cleaned html text is 184
# cleaned js text is 184
# full text is 222
# cleaned html text is 221
# cleaned js text is 221
# full text is 275
# cleaned html text is 274
# cleaned js text is 274
# full text is 115
# cleaned html text is 114
# cleaned js text is 114
# full text is 115
# cleaned html text is 114
# cleaned js text is 114
# full text is 125
# cleaned html text is 124
# cleaned js text is 124
# full text is 89
# cleaned html text is 88
# cleaned js text is 88
# {u'http://www.littlekidsinc.com/': {'clnd_text': [u' Phone Number: 800-545-5437',
#                                                   u'Subscribe',
#                                                   u'Register',
#                                                   u'Contact Us',
#                                                   u'Home',
#                                                   u'Products',
#                                                   u'Slick Tricks \u2122',
#                                                   u'Fubbles Bubbles\xae',
#                                                   u'Fubbles\xae No-Spill\xae',
#                                                   u'CANDYLICIOUS\xae',
#                                                   u'Peeps\xae',
#                                                   u'Jelly Belly\xae',
#                                                   u'Sesame Street\xae',
#                                                   u'PJ Masks \u2122',
#                                                   u'Paw Patrol \u2122',
#                                                   u'Shimmer & Shine \u2122',
#                                                   u'Nickelodeon \u2122',
#                                                   u'Junk Ball\xae',
#                                                   u'Magic Kidchen \u2122',
#                                                   u'About Us',
#                                                   u'PICS',
#                                                   u'FAQs',
#                                                   u'How To',
#                                                   u'Stores',
#                                                   u'Contact',
#                                                   u'Contact Us',
#                                                   u'Cart',
#                                                   u'0',
#                                                   u"TAKE A PEEP AT WHAT'S HOT FOR\xa0",
#                                                   u'FOURTH OF JULY!',
#                                                   u'Learn More',
#                                                   u'Fubbles\xae Bubbles',
#                                                   u"Tip it upside down, knock it over, it won't spill! Fubbles No-Spill bubbles have won numerous toy innovation awards.",
#                                                   u'Learn More',
#                                                   u'Junk Ball\xae',
#                                                   u'Junk Ball is the ultimate backyard baseball game! Just twist the dial on the ball to control your pitch: throw curves, sliders, risers, even knuckleballs!',
#                                                   u'Learn More',
#                                                   u'Junk Ball\xae',
#                                                   u'Junk Ball is the ultimate backyard baseball game! Just twist the dial on the ball to control your pitch: throw curves, sliders, risers, even knuckleballs!',
#                                                   u'Learn More',
#                                                   u'PAW PATROL\u2122 ',
#                                                   u'Help the pups save the day with exciting Paw Patrol branded products.',
#                                                   u'Learn More',
#                                                   u'Countdown to the 4th',
#                                                   u'Get your favorite person a PEEP for the 4th.',
#                                                   u'Learn More >>',
#                                                   u'Sign Up For Our Newsletter!',
#                                                   u'Exclusive offers for new members!',
#                                                   u'Subscription Request Received',
#                                                   u'You should recieve an email asking you to verify your subscription and complete the subscription process.',
#                                                   u'\xd7',
#                                                   u' Subscribe to: Newsletter ',
#                                                   u'\n                        //<![CDATA[\n                        var submitcount22889 = 0;\n\n                        function checkWholeForm22889(theForm) {\n                                var why = "";\n                                if (theForm.FullName) why += isEmpty(theForm.FullName.value, "Name");\n                                if (theForm.EmailAddress) why += checkEmail(theForm.EmailAddress.value);\n                                if (why != "") {\n                                    alert(why);\n                                    return false;\n                                } else {\n                                    // Alert Container\n                                    var $errorMsg = $(theForm).find(".alert");\n                                    // Disable Button\n                                    $(theForm).find(\'button[type="submit"]\').attr("disabled", "disabled");\n                                    // Append Loading Animation (Optional)\n                                    $("body").append(\'<div class="spinner"></div\');\n                                    // Remove Previous Error Message\n                                    $errorMsg.removeClass("alert-danger").html("");\n                                    // Ajax Post\n                                    $.ajax({\n                                        type: \'POST\',\n                                        url: $(theForm).attr("action"),\n                                        data: $(theForm).serialize(),\n                                        success: function(response) {\n                                            if ($(response).find(".system-error-message").length > 0) {\n                                                $errorMsg.addClass("alert-danger").append(\'<p>\' + $(response).find(\n                                                    ".system-error-message").text() + \'</p>\');\n                                                $(theForm).find(\'button[type="submit"]\').removeAttr("disabled", "disabled").removeClass(\n                                                    "disabled"); // Remove Disabled Attribute on Button\n                                                $(".spinner").remove(); // Remove Loading Animation (optional)\n                                            }\n                                            // If Succesfull Response\n                                            else {\n                                                // If you want it to redirect to cusom page specified in the form action make sure to specify PageID=; Otherwise will show sucess message\n                                                var redirectUrl = $(theForm).attr("action").split("&PageID=")[1];\n\n                                                if (redirectUrl === undefined) {\n                                                    $(theForm).fadeOut(300, function() {\n                                                        $(".js-form-success").fadeIn(300);\n                                                    });\n                                                } else {\n                                                    document.location = redirectUrl;\n                                                }\n\n                                                $(".spinner").remove(); // Remove Loading Animation (optional)\n                                            }\n                                        },\n                                        error: function() {\n                                            alert("An error occured. Please try again or contact us for assistance");\n                                            $(theForm).find(\'button[type="submit"]\').removeAttr("disabled", "disabled").removeClass(\n                                                "disabled"); // Remove Disabled Attribute on Button\n                                            $(".spinner").remove( ...
#                                                   u'0',
#                                                   u'Item(s) added to your cart.',
#                                                   u'Little Kids Inc.',
#                                                   u'Little Kids develops, manufactures, and markets innovative and award-winning bubble, novelty, sports, crafts and food activity toys! ',
#                                                   u'A',
#                                                   u' 1015 Newman Avenue\n',
#                                                   u'\xa0 \xa0 \xa0 \xa0Seekonk, MA 02771',
#                                                   u'T',
#                                                   u'800-545-5437',
#                                                   u'M',
#                                                   u'info@littlekidsinc.com',
#                                                   u'Opening Hours',
#                                                   u'Mon - Fri: 8:30am - 5:00pm EST\n',
#                                                   u'Sat: Closed\n',
#                                                   u'Sun: Closed\n',
#                                                   u'Closed All Holidays',
#                                                   u'About',
#                                                   u'Products',
#                                                   u'About Us',
#                                                   u'FAQs',
#                                                   u'Contact Us',
#                                                   u'Account',
#                                                   u'Privacy',
#                                                   u'Terms',
#                                                   u'Return Policy',
#                                                   u'Portal',
#                                                   u'Follow Us',
#                                                   u' Facebook',
#                                                   u' Twitter',
#                                                   u' YouTube',
#                                                   u' Instagram',
#                                                   u'\xa9 2018 Little Kids Inc. - All Rights Reserved. Actual product colors and packaging may vary. \n\t\t',
#                                                   u'\xa9 2018 Jelly Belly Candy Company, Fairfield, CA 94533 USA. PEEPS\xae, The PEEPS\xaeChick Shape and the PEEPS\xae Bunny Shape are registered trademarks of Just Born, Inc., Bethlehem, PA \xa9 2018 . All Rights Reserved. PJ Masks \xa9 Frog Box / Entertainment One UK Limited /Walt Disney EMEA Productions Limited 2014. Les Pyjamasques by Romuald \xa9 (2007) Gallimard Jeunesse. All Rights Reserved. Sesame Street\xae and associated characters, trademarks and design elements are owned and licensed by Sesame Workshop. \xa9 2018 Sesame Workshop. All Rights Reserved. \xa9 2018 Viacom International Inc. All Rights Reserved. Nickelodeon, Teenage Mutant Ninja Turtles, Bubble Guppies, Shimmer and Shine and all related titles, logos and characters are trademarks of Viacom International Inc.\xa9 2018 Spin Master PAW Productions Inc. All Rights Reserved. PAW Patrol and all related titles, logos and characters are trademarks of Spin Master Ltd. ',
#                                                   u' Log into Your Account',
#                                                   u'Email Address ',
#                                                   u'*',
#                                                   u'Password ',
#                                                   u'*',
#                                                   u' New here? Create an Account',
#                                                   u'Log In',
#                                                   u'\n\t\t\t\tfunction checkWholeForm84228(theForm) {\n\t\t\t\t\t\tvar why = "";\n\t\t\t\t\t\tif (theForm.Username) why += isEmpty(theForm.Username.value, "Username");\n\t\t\t\t\t\tif (theForm.Password) why += isEmpty(theForm.Password.value, "Password");\n\t\t\t\t\t\tif (why != "") {\n\t\t\t\t\t\t\t\talert(why);\n\t\t\t\t\t\t\t\treturn false;\n\t\t\t\t\t\t}\n\t\t\t\t\t\t// Once Validation is complete run ajax_login function\n\t\t\t\t\t\tajax_login();\n\t\t\t\t\t\treturn false;\n\t\t\t\t}\n\t\t\t\t',
#                                                   u'\xd7',
#                                                   u' New here? Create an Account',
#                                                   u"Your account has been created.  Close this popup and you're ready to go!",
#                                                   u'First Name',
#                                                   u'Last Name',
#                                                   u'Email Address (also your username)',
#                                                   u'Username',
#                                                   u'Password',
#                                                   u'Confirm Password',
#                                                   u"Prove you're not a robot",
#                                                   u'function reCaptchaV2OnLoad() { reCaptchaV2Manager.onLoadHandler(); }',
#                                                   u"\n    reCaptchaV2Manager.registerInstance({\n        'id': 'a7f4f420789a486abe4e7efe4d2807d5',\n        'sitekey': '6LcGXxsUAAAAALhWpOesJevjsD2KnvmZbTZADnIJ',\n        'type': 'image',\n        'theme': 'white',\n        'size': 'normal'\n    });\n",
#                                                   u'Register',
#                                                   u'\n\t\t\t\t\t\t//<![CDATA[\n\n\t\t\t\t\t\t$(function() {\n\n\t\t\t\t\t\t\t\t$(\'#EmailAddressRegister\').on(\'change\', function(){\n\t\t\t\t\t\t\t\t\t\t$(\'#Username\').val($(\'#EmailAddressRegister\').val());\n\t\t\t\t\t\t\t\t});\n\t\t\t\t\t\t});\n\t\t\t\t\t\n\t\t\t\t\t\tvar submitcount89795 = 0;\n\n\t\t\t\t\t\tfunction checkWholeForm89795(theForm) {\n\t\t\t\t\t\t\t\tvar why = "";\n\t\t\t\t\t\t\t\tif (theForm.FirstName) why += isEmpty(theForm.FirstName.value, "First Name");\n\t\t\t\t\t\t\t\tif (theForm.LastName) why += isEmpty(theForm.LastName.value, "Last Name");\n\t\t\t\t\t\t\t\tif (theForm.EmailAddress) why += checkEmail(theForm.EmailAddress.value);\n\t\t\t\t\t\t\t\tif (theForm.Username) why += isEmpty(theForm.Username.value, "Username");\n\t\t\t\t\t\t\t\tif (theForm.Password && theForm.PasswordConfirm) {\n\t\t\t\t\t\t\t\t\t\twhy += isEmpty(theForm.Password.value, "Password");\n\t\t\t\t\t\t\t\t\t\twhy += isEmpty(theForm.PasswordConfirm.value, "Confirm Password");\n\t\t\t\t\t\t\t\t\t\tif (theForm.Password.value != theForm.PasswordConfirm.value) why += appendBreak("- Password and its confirmation do not match.");\n\t\t\t\t\t\t\t\t\t\tif (theForm.Password.value.length < 6) why += appendBreak("- Password must be 6 characters or longer.");\n\t\t\t\t\t\t\t\t}\n\t\t\t\t\t\t\t\tif (theForm[\'g-recaptcha-response\']) why += reCaptchaV2IsInvalid(theForm, "Please prove you\'re not a robot");\n\t\t\t\t\t\t\t\tif (why != "") {\n\t\t\t\t\t\t\t\t\t\talert(why);\n\t\t\t\t\t\t\t\t\t\treturn false;\n\t\t\t\t\t\t\t\t\t} else {\n\t\t\t\t\t\t\t\t\t// Alert Container\n\t\t\t\t\t\t\t\t\tvar $errorMsg = $(theForm).find(".alert");\n\t\t\t\t\t\t\t\t\t// Disable Button\n\t\t\t\t\t\t\t\t\t$(theForm).find(\'button[type="submit"]\').attr("disabled", "disabled");\n\t\t\t\t\t\t\t\t\t// Append Loading Animation (Optional)\n\t\t\t\t\t\t\t\t\t$("body").append(\'<div class="spinner"></div\');\n\t\t\t\t\t\t\t\t\t// Remove Previous Error Message\n\t\t\t\t\t\t\t\t\t$errorMsg.removeClass("alert-danger").html("");\n\t\t\t\t\t\t\t\t\t// Ajax Post\n\t\t\t\t\t\t\t\t\t$.ajax({\n\t\t\t\t\t\t\t\t\t\t\ttype: \'POST\',\n\t\t\t\t\t\t\t\t\t\t\turl: $(theForm).attr("action"),\n\t\t\t\t\t\t\t\t\t\t\tdata: $(theForm).serialize(),\n\t\t\t\t\t\t\t\t\t\t\tsuccess: function(response) {\n\t\t\t\t\t\t\t\t\t\t\t\t\tif ($(response).find(".system-error-message").length > 0) {\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t$errorMsg.addClass("alert-danger").append(\'<p>\' + $(response).find(".system-error-message").text() + \'</p>\');\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t$(theForm).find(\'button[type="submit"]\').removeAttr("disabled", "disabled").removeClass("disabled"); // Remove Disabled Attribute on Button\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t$(".spinner").remove(); // Remove Loading Animation (optional)\n\t\t\t\t\t\t\t\t\t\t\t\t\t}\n\t\t\t\t\t\t\t\t\t\t\t\t\t// If Succesfull Response\n\t\t\t\t\t\t\t\t\t\t\t\t\telse {\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t// If you want it to redirect to custom page specified in the form action make sure to specify PageID=; Otherwise will show sucess message\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tvar redirectUrl = $(theForm).attr("action").split("&PageID=")[1];\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tif (redirectUrl === undefined) {\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t$(theForm).fadeOut(300, function() {\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t$(".js-form-success").fadeIn(300);\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tlocation.reload();\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t});\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t} else {\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tdocument.location = redirectUrl;\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t}\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t$(".spinner").remove(); // Remove Loading Animation (optional)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t//$(\'#registerModal\').foundation(\'close\');\n\t\t\t\t\t\t\t\t\t\t\t\t\t}\n\t\t\t\t\t\t\t\t\t\t\t},\n\t\t\t\t\t\t\t\t\t\t\terror: function() {\n\t\t\t\t\t\t\t\t\t\t\t\t\talert("An er ...
#                                                   u'\xd7',
#                                                   u'Cart Summary',
#                                                   u"\n  (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){\n  (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),\n  m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\n  })(window,document,'script','//www.google-analytics.com/analytics.js','ga');\n    ga('create', 'UA-107877800-3', 'auto', {'allowLinker': true});\n    ga('require', 'linker');\n    ga('linker:autoLink', ['worldsecuresystems.com','www.littlekidsinc.com'],false,true);\n    ga('send', 'pageview');\n"],
#                                     'depth': 0,
#                                     'firm_name': u'Little Kids'},
#  u'http://www.littlekidsinc.com/about-us': {'clnd_text': [u' Phone Number: 800-545-5437',
#                                                           u'Subscribe',
#                                                           u'Register',
#                                                           u'Contact Us',
#                                                           u'Home',
#                                                           u'Products',
#                                                           u'Slick Tricks \u2122',
#                                                           u'Fubbles Bubbles\xae',
#                                                           u'Fubbles\xae No-Spill\xae',
#                                                           u'CANDYLICIOUS\xae',
#                                                           u'Peeps\xae',
#                                                           u'Jelly Belly\xae',
#                                                           u'Sesame Street\xae',
#                                                           u'PJ Masks \u2122',
#                                                           u'Paw Patrol \u2122',
#                                                           u'Shimmer & Shine \u2122',
#                                                           u'Nickelodeon \u2122',
#                                                           u'Junk Ball\xae',
#                                                           u'Magic Kidchen \u2122',
#                                                           u'About Us',
#                                                           u'PICS',
#                                                           u'FAQs',
#                                                           u'How To',
#                                                           u'Stores',
#                                                           u'Contact',
#                                                           u'Contact Us',
#                                                           u'Cart',
#                                                           u'0',
#                                                           u'We Are Little Kids Inc.',
#                                                           u'At LKI, we\u2019ve been creating toys that make kids smile, and work like magic for over 25 years! To us, childhood is all about making time\n                    to play \u2013 we aim to make products that help families savor their time together. Our mission is to make quality toys at affordable prices\n                    \u2013 so your family can enjoy them across generations.',
#                                                           u'Why choose LKI?',
#                                                           u'Play time is essential to children\u2019s growth in so many areas, such as physical, sensory, social, and intellectual development. Play gives\n                    kids the opportunity to experiment and try out all the things they are learning in their day to day lives, as well as develop new skills.\n                    Playing allows children to learn by doing and allows them to directly experience the real world around them. Our toys are designed\n                    to help kids learn through play!\n                    ',
#                                                           u'Bubble toys & water toys: ',
#                                                           u'Help kids engage in sensory play and improve dexterity!',
#                                                           u'They also get kids moving and outside to learn about nature! ',
#                                                           u'Role play toys:',
#                                                           u'Help kids improve social skills and gain leadership knowledge!',
#                                                           u'They also help kids engage in self directed play, and learn about others and the world around them! ',
#                                                           u'Playing with chalk in the driveway:',
#                                                           u'Helps kids express themselves creatively!',
#                                                           u'Gives them the confidence in themselves! ',
#                                                           u'Food activity toys:',
#                                                           u'Help kids learn about STEM curriculum!',
#                                                           u'Promote experimentation and creativity! ',
#                                                           u'Sports toys:',
#                                                           u'Help kids strengthen their bodies!',
#                                                           u'Get kids outside and active!',
#                                                           u'Improve social problem solving skills and team building!',
#                                                           u'0',
#                                                           u'Item(s) added to your cart.',
#                                                           u'Little Kids Inc.',
#                                                           u'Little Kids develops, manufactures, and markets innovative and award-winning bubble, novelty, sports, crafts and food activity toys! ',
#                                                           u'A',
#                                                           u' 1015 Newman Avenue\n',
#                                                           u'\xa0 \xa0 \xa0 \xa0Seekonk, MA 02771',
#                                                           u'T',
#                                                           u'800-545-5437',
#                                                           u'M',
#                                                           u'info@littlekidsinc.com',
#                                                           u'Opening Hours',
#                                                           u'Mon - Fri: 8:30am - 5:00pm EST\n',
#                                                           u'Sat: Closed\n',
#                                                           u'Sun: Closed\n',
#                                                           u'Closed All Holidays',
#                                                           u'About',
#                                                           u'Products',
#                                                           u'About Us',
#                                                           u'FAQs',
#                                                           u'Contact Us',
#                                                           u'Account',
#                                                           u'Privacy',
#                                                           u'Terms',
#                                                           u'Return Policy',
#                                                           u'Portal',
#                                                           u'Follow Us',
#                                                           u' Facebook',
#                                                           u' Twitter',
#                                                           u' YouTube',
#                                                           u' Instagram',
#                                                           u'\xa9 2018 Little Kids Inc. - All Rights Reserved. Actual product colors and packaging may vary. \n\t\t',
#                                                           u'\xa9 2018 Jelly Belly Candy Company, Fairfield, CA 94533 USA. PEEPS\xae, The PEEPS\xaeChick Shape and the PEEPS\xae Bunny Shape are registered trademarks of Just Born, Inc., Bethlehem, PA \xa9 2018 . All Rights Reserved. PJ Masks \xa9 Frog Box / Entertainment One UK Limited /Walt Disney EMEA Productions Limited 2014. Les Pyjamasques by Romuald \xa9 (2007) Gallimard Jeunesse. All Rights Reserved. Sesame Street\xae and associated characters, trademarks and design elements are owned and licensed by Sesame Workshop. \xa9 2018 Sesame Workshop. All Rights Reserved. \xa9 2018 Viacom International Inc. All Rights Reserved. Nickelodeon, Teenage Mutant Ninja Turtles, Bubble Guppies, Shimmer and Shine and all related titles, logos and characters are trademarks of Viacom International Inc.\xa9 2018 Spin Master PAW Productions Inc. All Rights Reserved. PAW Patrol and all related titles, logos and characters are trademarks of Spin Master Ltd. ',
#                                                           u' Log into Your Account',
#                                                           u'Email Address ',
#                                                           u'*',
#                                                           u'Password ',
#                                                           u'*',
#                                                           u' New here? Create an Account',
#                                                           u'Log In',
#                                                           u'\n\t\t\t\tfunction checkWholeForm84228(theForm) {\n\t\t\t\t\t\tvar why = "";\n\t\t\t\t\t\tif (theForm.Username) why += isEmpty(theForm.Username.value, "Username");\n\t\t\t\t\t\tif (theForm.Password) why += isEmpty(theForm.Password.value, "Password");\n\t\t\t\t\t\tif (why != "") {\n\t\t\t\t\t\t\t\talert(why);\n\t\t\t\t\t\t\t\treturn false;\n\t\t\t\t\t\t}\n\t\t\t\t\t\t// Once Validation is complete run ajax_login function\n\t\t\t\t\t\tajax_login();\n\t\t\t\t\t\treturn false;\n\t\t\t\t}\n\t\t\t\t',
#                                                           u'\xd7',
#                                                           u' New here? Create an Account',
#                                                           u"Your account has been created.  Close this popup and you're ready to go!",
#                                                           u'First Name',
#                                                           u'Last Name',
#                                                           u'Email Address (also your username)',
#                                                           u'Username',
#                                                           u'Password',
#                                                           u'Confirm Password',
#                                                           u"Prove you're not a robot",
#                                                           u'function reCaptchaV2OnLoad() { reCaptchaV2Manager.onLoadHandler(); }',
#                                                           u"\n    reCaptchaV2Manager.registerInstance({\n        'id': '94c3107d7fb24ab69bc7620b5aed8d9b',\n        'sitekey': '6LcGXxsUAAAAALhWpOesJevjsD2KnvmZbTZADnIJ',\n        'type': 'image',\n        'theme': 'white',\n        'size': 'normal'\n    });\n",
#                                                           u'Register',
#                                                           u'\n\t\t\t\t\t\t//<![CDATA[\n\n\t\t\t\t\t\t$(function() {\n\n\t\t\t\t\t\t\t\t$(\'#EmailAddressRegister\').on(\'change\', function(){\n\t\t\t\t\t\t\t\t\t\t$(\'#Username\').val($(\'#EmailAddressRegister\').val());\n\t\t\t\t\t\t\t\t});\n\t\t\t\t\t\t});\n\t\t\t\t\t\n\t\t\t\t\t\tvar submitcount89795 = 0;\n\n\t\t\t\t\t\tfunction checkWholeForm89795(theForm) {\n\t\t\t\t\t\t\t\tvar why = "";\n\t\t\t\t\t\t\t\tif (theForm.FirstName) why += isEmpty(theForm.FirstName.value, "First Name");\n\t\t\t\t\t\t\t\tif (theForm.LastName) why += isEmpty(theForm.LastName.value, "Last Name");\n\t\t\t\t\t\t\t\tif (theForm.EmailAddress) why += checkEmail(theForm.EmailAddress.value);\n\t\t\t\t\t\t\t\tif (theForm.Username) why += isEmpty(theForm.Username.value, "Username");\n\t\t\t\t\t\t\t\tif (theForm.Password && theForm.PasswordConfirm) {\n\t\t\t\t\t\t\t\t\t\twhy += isEmpty(theForm.Password.value, "Password");\n\t\t\t\t\t\t\t\t\t\twhy += isEmpty(theForm.PasswordConfirm.value, "Confirm Password");\n\t\t\t\t\t\t\t\t\t\tif (theForm.Password.value != theForm.PasswordConfirm.value) why += appendBreak("- Password and its confirmation do not match.");\n\t\t\t\t\t\t\t\t\t\tif (theForm.Password.value.length < 6) why += appendBreak("- Password must be 6 characters or longer.");\n\t\t\t\t\t\t\t\t}\n\t\t\t\t\t\t\t\tif (theForm[\'g-recaptcha-response\']) why += reCaptchaV2IsInvalid(theForm, "Please prove you\'re not a robot");\n\t\t\t\t\t\t\t\tif (why != "") {\n\t\t\t\t\t\t\t\t\t\talert(why);\n\t\t\t\t\t\t\t\t\t\treturn false;\n\t\t\t\t\t\t\t\t\t} else {\n\t\t\t\t\t\t\t\t\t// Alert Container\n\t\t\t\t\t\t\t\t\tvar $errorMsg = $(theForm).find(".alert");\n\t\t\t\t\t\t\t\t\t// Disable Button\n\t\t\t\t\t\t\t\t\t$(theForm).find(\'button[type="submit"]\').attr("disabled", "disabled");\n\t\t\t\t\t\t\t\t\t// Append Loading Animation (Optional)\n\t\t\t\t\t\t\t\t\t$("body").append(\'<div class="spinner"></div\');\n\t\t\t\t\t\t\t\t\t// Remove Previous Error Message\n\t\t\t\t\t\t\t\t\t$errorMsg.removeClass("alert-danger").html("");\n\t\t\t\t\t\t\t\t\t// Ajax Post\n\t\t\t\t\t\t\t\t\t$.ajax({\n\t\t\t\t\t\t\t\t\t\t\ttype: \'POST\',\n\t\t\t\t\t\t\t\t\t\t\turl: $(theForm).attr("action"),\n\t\t\t\t\t\t\t\t\t\t\tdata: $(theForm).serialize(),\n\t\t\t\t\t\t\t\t\t\t\tsuccess: function(response) {\n\t\t\t\t\t\t\t\t\t\t\t\t\tif ($(response).find(".system-error-message").length > 0) {\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t$errorMsg.addClass("alert-danger").append(\'<p>\' + $(response).find(".system-error-message").text() + \'</p>\');\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t$(theForm).find(\'button[type="submit"]\').removeAttr("disabled", "disabled").removeClass("disabled"); // Remove Disabled Attribute on Button\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t$(".spinner").remove(); // Remove Loading Animation (optional)\n\t\t\t\t\t\t\t\t\t\t\t\t\t}\n\t\t\t\t\t\t\t\t\t\t\t\t\t// If Succesfull Response\n\t\t\t\t\t\t\t\t\t\t\t\t\telse {\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t// If you want it to redirect to custom page specified in the form action make sure to specify PageID=; Otherwise will show sucess message\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tvar redirectUrl = $(theForm).attr("action").split("&PageID=")[1];\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tif (redirectUrl === undefined) {\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t$(theForm).fadeOut(300, function() {\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t$(".js-form-success").fadeIn(300);\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tlocation.reload();\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t});\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t} else {\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tdocument.location = redirectUrl;\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t}\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t$(".spinner").remove(); // Remove Loading Animation (optional)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t//$(\'#registerModal\').foundation(\'close\');\n\t\t\t\t\t\t\t\t\t\t\t\t\t}\n\t\t\t\t\t\t\t\t\t\t\t},\n\t\t\t\t\t\t\t\t\t\t\terror: function() {\n\t\t\t\t\t\t\t\t\t\t\t\t\taler ...
#                                                           u'\xd7',
#                                                           u'Cart Summary',
#                                                           u"\n  (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){\n  (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),\n  m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\n  })(window,document,'script','//www.google-analytics.com/analytics.js','ga');\n    ga('create', 'UA-107877800-3', 'auto', {'allowLinker': true});\n    ga('require', 'linker');\n    ga('linker:autoLink', ['worldsecuresystems.com','www.littlekidsinc.com'],false,true);\n    ga('send', 'pageview');\n"],
#                                             'depth': 1,
#                                             'firm_name': u'Little Kids'},
#  u'http://www.littlekidsinc.com/contact-us': {'clnd_text': [u'contact-us',
#                                                             u' Phone Number: 800-545-5437',
#                                                             u'Subscribe',
#                                                             u'Register',
#                                                             u'Contact Us',
#                                                             u'Home',
#                                                             u'Products',
#                                                             u'Slick Tricks \u2122',
#                                                             u'Fubbles Bubbles\xae',
#                                                             u'Fubbles\xae No-Spill\xae',
#                                                             u'CANDYLICIOUS\xae',
#                                                             u'Peeps\xae',
#                                                             u'Jelly Belly\xae',
#                                                             u'Sesame Street\xae',
#                                                             u'PJ Masks \u2122',
#                                                             u'Paw Patrol \u2122',
#                                                             u'Shimmer & Shine \u2122',
#                                                             u'Nickelodeon \u2122',
#                                                             u'Junk Ball\xae',
#                                                             u'Magic Kidchen \u2122',
#                                                             u'About Us',
#                                                             u'PICS',
#                                                             u'FAQs',
#                                                             u'How To',
#                                                             u'Stores',
#                                                             u'Contact',
#                                                             u'Contact Us',
#                                                             u'Cart',
#                                                             u'0',
#                                                             u'Our Location',
#                                                             u'1015 Newman Avenue\n',
#                                                             u'\xa0 \xa0 \xa0 \xa0Seekonk, MA 02771',
#                                                             u"Let's Have A Chat",
#                                                             u'T',
#                                                             u'800-545-5437',
#                                                             u'M',
#                                                             u'info@littlekidsinc.com',
#                                                             u'Working Hours',
#                                                             u'Mon - Fri: 8:30am - 5:00pm EST\n',
#                                                             u'Sat: Closed\n',
#                                                             u'Sun: Closed\n',
#                                                             u'Closed All Holidays',
#                                                             u'Contact Us',
#                                                             u'Leave A Message',
#                                                             u'*',
#                                                             u' Required\r\n    ',
#                                                             u'First Name ',
#                                                             u'*',
#                                                             u'Last Name ',
#                                                             u'*',
#                                                             u'Email Address ',
#                                                             u'*',
#                                                             u'Comments/Inquiries ',
#                                                             u'*',
#                                                             u"Prove you're not a robot ",
#                                                             u'*',
#                                                             u'function reCaptchaV2OnLoad() { reCaptchaV2Manager.onLoadHandler(); }',
#                                                             u"\n    reCaptchaV2Manager.registerInstance({\n        'id': '1d5287a1507e4430b5b55a5614df1e77',\n        'sitekey': '6LcGXxsUAAAAALhWpOesJevjsD2KnvmZbTZADnIJ',\n        'type': 'image',\n        'theme': 'white',\n        'size': 'normal'\n    });\n",
#                                                             u'\r\n        //<![CDATA[\r\n        var submitcount42557 = 0;\r\n\r\n        function checkWholeForm42557(theForm) {\r\n                var why = "";\r\n                if (theForm.FirstName) why += isEmpty(theForm.FirstName.value, "First Name");\r\n                if (theForm.LastName) why += isEmpty(theForm.LastName.value, "Last Name");\r\n                if (theForm.EmailAddress) why += checkEmail(theForm.EmailAddress.value);\r\n                if (theForm[\'g-recaptcha-response\']) why += reCaptchaV2IsInvalid(theForm, "Please prove you\'re not a robot");\r\n                if (theForm.CAT_Custom_869) why += isEmpty(theForm.CAT_Custom_869.value, "Comments/Enquiries");\r\n                if (why != "") {\r\n                    alert(why);\r\n                    return false;\r\n                }\r\n                if (submitcount42557 == 0) {\r\n                    submitcount42557++;\r\n                    theForm.submit();\r\n                    return false;\r\n                } else {\r\n                    alert("Form submission is in progress.");\r\n                    return false;\r\n                }\r\n            }\r\n            //]]>\r\n    ',
#                                                             u'0',
#                                                             u'Item(s) added to your cart.',
#                                                             u'Little Kids Inc.',
#                                                             u'Little Kids develops, manufactures, and markets innovative and award-winning bubble, novelty, sports, crafts and food activity toys! ',
#                                                             u'A',
#                                                             u' 1015 Newman Avenue\n',
#                                                             u'\xa0 \xa0 \xa0 \xa0Seekonk, MA 02771',
#                                                             u'T',
#                                                             u'800-545-5437',
#                                                             u'M',
#                                                             u'info@littlekidsinc.com',
#                                                             u'Opening Hours',
#                                                             u'Mon - Fri: 8:30am - 5:00pm EST\n',
#                                                             u'Sat: Closed\n',
#                                                             u'Sun: Closed\n',
#                                                             u'Closed All Holidays',
#                                                             u'About',
#                                                             u'Products',
#                                                             u'About Us',
#                                                             u'FAQs',
#                                                             u'Contact Us',
#                                                             u'Account',
#                                                             u'Privacy',
#                                                             u'Terms',
#                                                             u'Return Policy',
#                                                             u'Portal',
#                                                             u'Follow Us',
#                                                             u' Facebook',
#                                                             u' Twitter',
#                                                             u' YouTube',
#                                                             u' Instagram',
#                                                             u'\xa9 2018 Little Kids Inc. - All Rights Reserved. Actual product colors and packaging may vary. \n\t\t',
#                                                             u'\xa9 2018 Jelly Belly Candy Company, Fairfield, CA 94533 USA. PEEPS\xae, The PEEPS\xaeChick Shape and the PEEPS\xae Bunny Shape are registered trademarks of Just Born, Inc., Bethlehem, PA \xa9 2018 . All Rights Reserved. PJ Masks \xa9 Frog Box / Entertainment One UK Limited /Walt Disney EMEA Productions Limited 2014. Les Pyjamasques by Romuald \xa9 (2007) Gallimard Jeunesse. All Rights Reserved. Sesame Street\xae and associated characters, trademarks and design elements are owned and licensed by Sesame Workshop. \xa9 2018 Sesame Workshop. All Rights Reserved. \xa9 2018 Viacom International Inc. All Rights Reserved. Nickelodeon, Teenage Mutant Ninja Turtles, Bubble Guppies, Shimmer and Shine and all related titles, logos and characters are trademarks of Viacom International Inc.\xa9 2018 Spin Master PAW Productions Inc. All Rights Reserved. PAW Patrol and all related titles, logos and characters are trademarks of Spin Master Ltd. ',
#                                                             u' Log into Your Account',
#                                                             u'Email Address ',
#                                                             u'*',
#                                                             u'Password ',
#                                                             u'*',
#                                                             u' New here? Create an Account',
#                                                             u'Log In',
#                                                             u'\n\t\t\t\tfunction checkWholeForm84228(theForm) {\n\t\t\t\t\t\tvar why = "";\n\t\t\t\t\t\tif (theForm.Username) why += isEmpty(theForm.Username.value, "Username");\n\t\t\t\t\t\tif (theForm.Password) why += isEmpty(theForm.Password.value, "Password");\n\t\t\t\t\t\tif (why != "") {\n\t\t\t\t\t\t\t\talert(why);\n\t\t\t\t\t\t\t\treturn false;\n\t\t\t\t\t\t}\n\t\t\t\t\t\t// Once Validation is complete run ajax_login function\n\t\t\t\t\t\tajax_login();\n\t\t\t\t\t\treturn false;\n\t\t\t\t}\n\t\t\t\t',
#                                                             u'\xd7',
#                                                             u' New here? Create an Account',
#                                                             u"Your account has been created.  Close this popup and you're ready to go!",
#                                                             u'First Name',
#                                                             u'Last Name',
#                                                             u'Email Address (also your username)',
#                                                             u'Username',
#                                                             u'Password',
#                                                             u'Confirm Password',
#                                                             u"Prove you're not a robot",
# ...
#                                                        u'\xd7',
#                                                        u'Cart Summary',
#                                                        u"\n  (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){\n  (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),\n  m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\n  })(window,document,'script','//www.google-analytics.com/analytics.js','ga');\n    ga('create', 'UA-107877800-3', 'auto', {'allowLinker': true});\n    ga('require', 'linker');\n    ga('linker:autoLink', ['worldsecuresystems.com','www.littlekidsinc.com'],false,true);\n    ga('send', 'pageview');\n"],
#                                          'depth': 1,
#                                          'firm_name': u'Little Kids'},
#  u'http://www.littlekidsinc.com/user/my-account.htm': {'clnd_text': [u'littlekidsmain',
#                                                                      u' Phone Number: 800-545-5437',
#                                                                      u'Subscribe',
#                                                                      u'Register',
#                                                                      u'Contact Us',
#                                                                      u'Home',
#                                                                      u'Products',
#                                                                      u'Slick Tricks \u2122',
#                                                                      u'Fubbles Bubbles\xae',
#                                                                      u'Fubbles\xae No-Spill\xae',
#                                                                      u'CANDYLICIOUS\xae',
#                                                                      u'Peeps\xae',
#                                                                      u'Jelly Belly\xae',
#                                                                      u'Sesame Street\xae',
#                                                                      u'PJ Masks \u2122',
#                                                                      u'Paw Patrol \u2122',
#                                                                      u'Shimmer & Shine \u2122',
#                                                                      u'Nickelodeon \u2122',
#                                                                      u'Junk Ball\xae',
#                                                                      u'Magic Kidchen \u2122',
#                                                                      u'About Us',
#                                                                      u'PICS',
#                                                                      u'FAQs',
#                                                                      u'How To',
#                                                                      u'Stores',
#                                                                      u'Contact',
#                                                                      u'Contact Us',
#                                                                      u'Cart',
#                                                                      u'0',
#                                                                      u' Please log in to continue',
#                                                                      u' New here? Create an Account',
#                                                                      u'0',
#                                                                      u'Item(s) added to your cart.',
#                                                                      u'Little Kids Inc.',
#                                                                      u'Little Kids develops, manufactures, and markets innovative and award-winning bubble, novelty, sports, crafts and food activity toys! ',
#                                                                      u'A',
#                                                                      u' 1015 Newman Avenue\n',
#                                                                      u'\xa0 \xa0 \xa0 \xa0Seekonk, MA 02771',
#                                                                      u'T',
#                                                                      u'800-545-5437',
#                                                                      u'M',
#                                                                      u'info@littlekidsinc.com',
#                                                                      u'Opening Hours',
#                                                                      u'Mon - Fri: 8:30am - 5:00pm EST\n',
#                                                                      u'Sat: Closed\n',
#                                                                      u'Sun: Closed\n',
#                                                                      u'Closed All Holidays',
#                                                                      u'About',
#                                                                      u'Products',
#                                                                      u'About Us',
#                                                                      u'FAQs',
#                                                                      u'Contact Us',
#                                                                      u'Account',
#                                                                      u'Privacy',
#                                                                      u'Terms',
#                                                                      u'Return Policy',
#                                                                      u'Portal',
#                                                                      u'Follow Us',
#                                                                      u' Facebook',
#                                                                      u' Twitter',
#                                                                      u' YouTube',
#                                                                      u' Instagram',
#                                                                      u'\xa9 2018 Little Kids Inc. - All Rights Reserved. Actual product colors and packaging may vary. \n\t\t',
#                                                                      u'\xa9 2018 Jelly Belly Candy Company, Fairfield, CA 94533 USA. PEEPS\xae, The PEEPS\xaeChick Shape and the PEEPS\xae Bunny Shape are registered trademarks of Just Born, Inc., Bethlehem, PA \xa9 2018 . All Rights Reserved. PJ Masks \xa9 Frog Box / Entertainment One UK Limited /Walt Disney EMEA Productions Limited 2014. Les Pyjamasques by Romuald \xa9 (2007) Gallimard Jeunesse. All Rights Reserved. Sesame Street\xae and associated characters, trademarks and design elements are owned and licensed by Sesame Workshop. \xa9 2018 Sesame Workshop. All Rights Reserved. \xa9 2018 Viacom International Inc. All Rights Reserved. Nickelodeon, Teenage Mutant Ninja Turtles, Bubble Guppies, Shimmer and Shine and all related titles, logos and characters are trademarks of Viacom International Inc.\xa9 2018 Spin Master PAW Productions Inc. All Rights Reserved. PAW Patrol and all related titles, logos and characters are trademarks of Spin Master Ltd. ',
#                                                                      u' Log into Your Account',
#                                                                      u'Email Address ',
#                                                                      u'*',
#                                                                      u'Password ',
#                                                                      u'*',
#                                                                      u' New here? Create an Account',
#                                                                      u'Log In',
#                                                                      u'\n\t\t\t\tfunction checkWholeForm84228(theForm) {\n\t\t\t\t\t\tvar why = "";\n\t\t\t\t\t\tif (theForm.Username) why += isEmpty(theForm.Username.value, "Username");\n\t\t\t\t\t\tif (theForm.Password) why += isEmpty(theForm.Password.value, "Password");\n\t\t\t\t\t\tif (why != "") {\n\t\t\t\t\t\t\t\talert(why);\n\t\t\t\t\t\t\t\treturn false;\n\t\t\t\t\t\t}\n\t\t\t\t\t\t// Once Validation is complete run ajax_login function\n\t\t\t\t\t\tajax_login();\n\t\t\t\t\t\treturn false;\n\t\t\t\t}\n\t\t\t\t',
#                                                                      u'\xd7',
#                                                                      u' New here? Create an Account',
#                                                                      u"Your account has been created.  Close this popup and you're ready to go!",
#                                                                      u'First Name',
#                                                                      u'Last Name',
#                                                                      u'Email Address (also your username)',
#                                                                      u'Username',
#                                                                      u'Password',
#                                                                      u'Confirm Password',
#                                                                      u"Prove you're not a robot",
#                                                                      u'function reCaptchaV2OnLoad() { reCaptchaV2Manager.onLoadHandler(); }',
#                                                                      u"\n    reCaptchaV2Manager.registerInstance({\n        'id': '631b64ab2d8749c18ff4c1a395635a91',\n        'sitekey': '6LcGXxsUAAAAALhWpOesJevjsD2KnvmZbTZADnIJ',\n        'type': 'image',\n        'theme': 'white',\n        'size': 'normal'\n    });\n",
#                                                                      u'Register',
#                                                                      u'\n\t\t\t\t\t\t//<![CDATA[\n\n\t\t\t\t\t\t$(function() {\n\n\t\t\t\t\t\t\t\t$(\'#EmailAddressRegister\').on(\'change\', function(){\n\t\t\t\t\t\t\t\t\t\t$(\'#Username\').val($(\'#EmailAddressRegister\').val());\n\t\t\t\t\t\t\t\t});\n\t\t\t\t\t\t});\n\t\t\t\t\t\n\t\t\t\t\t\tvar submitcount89795 = 0;\n\n\t\t\t\t\t\tfunction checkWholeForm89795(theForm) {\n\t\t\t\t\t\t\t\tvar why = "";\n\t\t\t\t\t\t\t\tif (theForm.FirstName) why += isEmpty(theForm.FirstName.value, "First Name");\n\t\t\t\t\t\t\t\tif (theForm.LastName) why += isEmpty(theForm.LastName.value, "Last Name");\n\t\t\t\t\t\t\t\tif (theForm.EmailAddress) why += checkEmail(theForm.EmailAddress.value);\n\t\t\t\t\t\t\t\tif (theForm.Username) why += isEmpty(theForm.Username.value, "Username");\n\t\t\t\t\t\t\t\tif (theForm.Password && theForm.PasswordConfirm) {\n\t\t\t\t\t\t\t\t\t\twhy += isEmpty(theForm.Password.value, "Password");\n\t\t\t\t\t\t\t\t\t\twhy += isEmpty(theForm.PasswordConfirm.value, "Confirm Password");\n\t\t\t\t\t\t\t\t\t\tif (theForm.Password.value != theForm.PasswordConfirm.value) why += appendBreak("- Password and its confirmation do not match.");\n\t\t\t\t\t\t\t\t\t\tif (theForm.Password.value.length < 6) why += appendBreak("- Password must be 6 characters or longer.");\n\t\t\t\t\t\t\t\t}\n\t\t\t\t\t\t\t\tif (theForm[\'g-recaptcha-response\']) why += reCaptchaV2IsInvalid(theForm, "Please prove you\'re not a robot");\n\t\t\t\t\t\t\t\tif (why != "") {\n\t\t\t\t\t\t\t\t\t\talert(why);\n\t\t\t\t\t\t\t\t\t\treturn false;\n\t\t\t\t\t\t\t\t\t} else {\n\t\t\t\t\t\t\t\t\t// Alert Container\n\t\t\t\t\t\t\t\t\tvar $errorMsg = $(theForm).find(".alert");\n\t\t\t\t\t\t\t\t\t// Disable Button\n\t\t\t\t\t\t\t\t\t$(theForm).find(\'button[type="submit"]\').attr("disabled", "disabled");\n\t\t\t\t\t\t\t\t\t// Append Loading Animation (Optional)\n\t\t\t\t\t\t\t\t\t$("body").append(\'<div class="spinner"></div\');\n\t\t\t\t\t\t\t\t\t// Remove Previous Error Message\n\t\t\t\t\t\t\t\t\t$errorMsg.removeClass("alert-danger").html("");\n\t\t\t\t\t\t\t\t\t// Ajax Post\n\t\t\t\t\t\t\t\t\t$.ajax({\n\t\t\t\t\t\t\t\t\t\t\ttype: \'POST\',\n\t\t\t\t\t\t\t\t\t\t\turl: $(theForm).attr("action"),\n\t\t\t\t\t\t\t\t\t\t\tdata: $(theForm).serialize(),\n\t\t\t\t\t\t\t\t\t\t\tsuccess: function(response) {\n\t\t\t\t\t\t\t\t\t\t\t\t\tif ($(response).find(".system-error-message").length > 0) {\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t$errorMsg.addClass("alert-danger").append(\'<p>\' + $(response).find(".system-error-message").text() + \'</p>\');\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t$(theForm).find(\'button[type="submit"]\').removeAttr("disabled", "disabled").removeClass("disabled"); // Remove Disabled Attribute on Button\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t$(".spinner").remove(); // Remove Loading Animation (optional)\n\t\t\t\t\t\t\t\t\t\t\t\t\t}\n\t\t\t\t\t\t\t\t\t\t\t\t\t// If Succesfull Response\n\t\t\t\t\t\t\t\t\t\t\t\t\telse {\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t// If you want it to redirect to custom page specified in the form action make sure to specify PageID=; Otherwise will show sucess message\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tvar redirectUrl = $(theForm).attr("action").split("&PageID=")[1];\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tif (redirectUrl === undefined) {\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t$(theForm).fadeOut(300, function() {\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t$(".js-form-success").fadeIn(300);\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tlocation.reload();\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t});\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t} else {\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tdocument.location = redirectUrl;\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t}\n\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t$(".spinner").remove(); // Remove Loading Animation (optional)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t//$(\'#registerModal\').foundation(\'close\');\n\t\t\t\t\t\t\t\t\t\t\t\t\t}\n\t\t\t\t\t\t\t\t\t\t\t},\n\t\t\t\t\t\t\t\t\t\t\terror: function() {\n\t\t\t\t\t\t\t\t\t\ ...
#                                                                      u'\xd7',
#                                                                      u'Cart Summary',
#                                                                      u"\n  (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){\n  (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),\n  m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\n  })(window,document,'script','//www.google-analytics.com/analytics.js','ga');\n    ga('create', 'UA-107877800-3', 'auto', {'allowLinker': true});\n    ga('require', 'linker');\n    ga('linker:autoLink', ['worldsecuresystems.com','www.littlekidsinc.com'],false,true);\n    ga('send', 'pageview');\n"],
#                                                        'depth': 1,
#                                                        'firm_name': u'Little Kids'}}

# %%
# Out:
# ['CDATA', 'function', 'javascript.function', 'linker:autoLink', 'www.littlekidsinc', 'fxnCall(param.param);', 'dextr.us']

# %%
# %matplotlib inline
import pandas as pd
import os
import random
import re
import nltk
import gensim
import string
import urllib2
import math
import numpy as np
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
from gensim import corpora
from gensim.models import LdaMulticore
from collections import defaultdict
import copy as cp
from bs4 import BeautifulSoup
from functools import reduce 
import operator
import matplotlib.pyplot as plt
import pprint
import numpy as np
import pandas as pd

# %%
# find out what data this expects, e.g., with green_data (list of lists?) -- yes
# replace with file data

# %% [markdown]
# ## Webscraping with Beautiful Soup
# This is legagy code. Produce web scraped home page content in list of lists of website content

# %%
#read in the csv files with URLS
green = pd.read_csv("../../data/green_business_urls.csv")
synbio = pd.read_csv("../../data/synbio_business_urls.csv")
nano = pd.read_csv("../../data/nano_business_urls.csv")
#get lists of the urls
green_urls = list(green['lower_url'])
synbio_urls = list(synbio['lower_url'])
nano_urls = list(nano['lower_url'])

# %%
missed = []
def get_data(url):
    '''
    Function to extract the visible text data from a given URL
    '''
    try:
        if url.startswith("http"):
            html = urllib2.urlopen(url).read()
        else:
            html = urllib2.urlopen("http://" + url).read()
        soup = BeautifulSoup(html, 'lxml')
        [s.extract() for s in soup(['style', 'script', '[document]', 'head', 'title'])]
        visible_text = soup.getText()
        text =  [item.strip() for item in visible_text.split("\n") if not item.strip() == ""]
        return text
    except:
        missed.append(url)
#filter out the few null results
green_data = filter(lambda x : x and len(x) > 1, [get_data(item) for item in green_urls])
# synbio_data = filter(lambda x : x and len(x) > 1, [get_data(item) for item in synbio_urls])
# nano_data = filter(lambda x : x and len(x) > 1, [get_data(item) for item in nano_urls])

# %%
#check that we have the expected number of documents
print len(green_data)
# print len(synbio_data)
# print len(nano_data)

# pp = pprint.PrettyPrinter()
# pp.pprint(green_data)
# Out:
# 0

# %% [markdown]
# ## Load website data from file
# Look for text files prepared from MongoDB (the Scrapy scraper)

# %%
#import demo text files
in_path = '/Users/sarora/dev/EAGER/data/orgs/depth0_pages/' # where in files are stored
out_file = in_path + 'out_topics.csv' # where output files are stored
files = os.listdir(in_path)
files = [item for item in files if item.endswith('.txt')]

# %%
#generate pooled text and list of processed documents for topic model
combined_text = []
documents_dict = {}
for i in range(len(files)):
    with open(path + files[i], 'r') as my_file:
        text = my_file.readlines() # this is each separate paragraph including headers etc
        for k in ["\n", "\t", " "]: # remove the end of sentence tags
            text = [item.strip(k) for item in text]
        text = filter(lambda x : not x in [' ', '', '\t'],text) #remove the paragraphs that are just blank space
        #loop over text and add title elements to the paragraph they describe
        joined = []
        join = False
        for j in range(len(text)):
            if len(text[j]) < 100:
                join = True
            else:
                if join:
                    joined.append(text[j-1] + " " + text[j])
                else:
                    joined.append(text[j])
        combined_text +=joined # make a big list
        documents_dict[files[i]] = joined #make a list of lists

# %% [markdown]
# ## Data Prep

# %% [markdown]
# #### Prepare text for topic modelling

# %%
#tokenize text for topic modelling
def encode_item(text):
    '''
    Remove characters with encoding problems 
    '''
    clean = ""
    for item in text.split(" "):
        try:
            clean += str(item).encode('ascii','ignore') + " "
        except: 
            pass
    return clean.rstrip()

stopwords = nltk.corpus.stopwords.words('english') + list(set(string.punctuation))
stemmer = SnowballStemmer("english")

def stem_tokenizer(text):
    '''
    Tokenize and stem an input sentence"
    '''
    words_stemmed = filter(lambda x : not x in stopwords, [stemmer.stem(word) for word in nltk.word_tokenize(text)])
    return words_stemmed

def clean_text (text):
    clnd_text = filter(lambda x : not re.match("''|``|null|ul|^\.|^:|\\\\", word, flags=re.IGNORECASE)  for word in text]) 

def return_for_model(text):
    '''
    Deal with endcoding and return stemmed/tokenized text
    '''
    all_content = [encode_item(item) for item in text]
    all_content_stem_token = map(stem_tokenizer, all_content)
    all_content_clnd = map (clean_text, all_content_stem_token)
        
    return all_content_clnd
# Out:
#   File "<ipython-input-162-5c7b456becaa>", line 25
#     clnd_text = filter(lambda x : not re.match("''|``|null|ul|^\.|^:|\\\\", x, flags=re.IGNORECASE)  for word in text])
#                                                                                                                      ^
# SyntaxError: invalid syntax

# %%
def process_doc_list(dict_of_docs):
    '''
    input: lists of documents (which are individually lists of paragraphs)
    output: returns a test/train split of paragraphs and stemmed documents
    '''
    combined_text = []
    documents = []
    dict_of_processed_docs = {}
    print "Working on " + str(len(dict_of_docs.keys())) + " documents"
    c = 1
    for key in dict_of_docs:
        document = dict_of_docs[key]
        # print "Working on doc " + key

        text = filter(lambda x : not x in [' ', '', '\t'],document) #remove empty paragraphs
        #loop over text and add title elements to the paragraph they describe
        joined = []
        join = False
        for i in range(len(text)):
            if len(text[i]) < 40:
                join = True
            else:
                if join:
                    joined.append(text[i-1] + " " + text[i])
                else:
                    joined.append(text[i])
        combined_text +=joined # make a big list
        documents.append(joined) # make a list of lists
        dict_of_processed_docs[key] = return_for_model(document)
        
    combined = return_for_model(combined_text)
    random.shuffle(combined) #randomly shuffle in order to make test train split
    train_index = int(np.round(len(combined)*.8)) #about 80% in the training set
    train = combined[:train_index]
    test = combined[train_index:]
    return train, test, dict_of_processed_docs

# %% [markdown]
# #### Process Documents for Topic Modelling

# %%
# use the preceeding fuction to process the text data
all_train, all_test, all_docs_dict = process_doc_list(documents_dict)
# pp = pprint.PrettyPrinter()
# pp.pprint(all_docs)


# legacy code
# green_train, green_test, green_docs = process_doc_list(green_data)
# synbio_train, synbio_test, synbio_docs = process_doc_list(synbio_data)
# nano_train, nano_test, nano_docs = process_doc_list(nano_data)
# Out:
# Working on 857 documents

# %%
print len(all_train)
print len(all_test)
print len(all_docs_dict.keys())

print (all_train)
# Out:
# 5069
# 1267
# 857
# [[u'11.', u'novembra', u'2018', u'predstavili', u'koncept', u'vlaku', u'sveta', u't-flight', u'dosiahn', u'kilometrov', 'za', u'hodinu'], [u'global', u'manufactur', u'advanc', u'materi', u'filtrat', u'batteri', u'industri', u'applic', u'composit', u'materi', u'offer', u'superior', u'seal', u'passeng', u'car', u'heavy-duti', u'engin'], [u'februari', '22', u'2018', u'bioworld', u'medtech', u'articl', u'valley', u'startup', u'cardiva', u'rais', u'11m', u'back', u'expans', u'vascular', u'closur'], [u'read', u'connect', u'peopl', u'busi', u'compon', u'connect', u'power', u'technolog', u'optim', u'function', u'perform'], [u'pc-832', u'inform', u'westec', u'offer', u'chevron', u'author', u'initi', u'refresh', u'high-risk', u'vehicl', u'leas', u'driver', u'train', u'contact', u'peter', u'martinez', u'661', u'387-1055', u'schedul', u'price'], [u'continent', u'commerci', u'product', u'continent', u'commerci', u'product', u'lead', u'global', u'supplier', u'manufactur', u'plastic', u'textil', u'good', u'provid', u'solut', u'industri', u'healthcar', u'institut', u'commerci', u'educ', u'govern', u'market'], [u'taxi', u'artwork', u'nation', u'art', u'exhibit', u'mental', u'ill', u'inc.', u'naemi', u'organ', u'dedic', u'discov', u'preserv', u'art', u'peopl', u'mental', u'ill'], [u'kompensieren', u'sie', u'den', u'co2', u'footprint', u'ihrer', u'druckmaschinen', u'unser', u'co2-kompensations-zertifizierungsprogramm', u'das', u'wiederaufforstungsprojekt', u'der', u'nichtregierungsorganis', u'world', u'vision', u'nahe', u'dem', u'mount', u'damota', u'mit', u'dem', u'kauf', u'ein', u'heidelberg', u'co2', u'zertifikat', u'ihr', u'druckerei', u'helfen', u'sie', u'gemeinden', u'dieser', u'region', u'afrika', u'die', u'bodenfruchtbarkeit', u'wiederherzustellen', u'die', u'bodeneros', 'zu', u'verhindern', u'trinkwasserquellen', 'zu', u'sanieren', u'und', u'die', u'artenvielfalt', 'zu'], [u'welcom', u'res', u'mission', u'res', u'contractor', u'llc', u'continu', u'provid', u'value-ad', u'construct', u'servic', u'custom', u'creat', u'success', u'partnership', u'throughout', u'construct', u'process'], [u'aquaexcel2020', u'brokerag', u'event', u'research', u'innov', u'industri', u'applic', u'event', u'organis', u'eatip', u'aquatt', u'creat', u'forum', u'engag', u'exchang', u'research', u'potenti', u'industri', u'beneficiari', u'research', u'result', u'generat', u'aquaexcel2020', u'project', u'precursor', u'aquaexcel', u'...'], [u'data', u'servic', u'pssn', u'data', u'servic', u'petra', u'carrier', u'get', u'access', u'ubiquit', u'untap', u'network', u'increas', u'capac', u'coverag', u'improv', u'overal', u'network', u'qualiti', u'streetlight', u'owner', u'get', u'access', u'uncap', u'revenu', u'potenti', u'grow', u'proport', u'util', u'city-wid', u'communic', u'network', u'smart', u'citi', u'applic'], [u'display', u'light', u'technolog', u'next', u'decad', u'amol', u'active-matrix', u'organ', u'light-emit', u'diod', u'thin', u'display', u'organ', u'compound', u'act', u'electroluminesc', u'materi', u'faster', u'thinner', u'lighter', u'energi', u'effici', u'current', u'lcd', u'display'], [u'registersod', '``', u'core.j', "''", '``', u'\\u002f_layouts\\u002f1033\\u002fcore.j', u'rev=1vdxrr0ol3\\u00252fetgwnp2\\u00252bgbq\\u00253d\\u00253d', "''", u'registersod', '``', u'sp.runtime.j', "''", '``', u'\\u002f_layouts\\u002fsp.runtime.j', u'rev=9skdsc9n6p2birk3313m7q\\u00253d\\u00253d', "''", u'registersoddep', '``', u'sp.runtime.j', "''", '``', u'sp.core.j', "''", u'registersoddep', '``', u'sp.runtime.j', "''", '``', u'sp.res.resx', "''"], [u'product', u'petroblend', u'product', u'meet', u'exceed', u'specif', u'save', u'money', u'without', u'compromis', u'qualiti'], [u'respons', u'content', u'guarante', u'communiti', u'power', u'privaci', u'secur', u'polici', u'may', u'differ', u'communiti', u'power'], [u'metal', u'one', u'sale', u'network', u'140', u'offic', u'subsidiari', u'japan', u'oversea', u'provid', u'varieti', u'servic', 'mc', u'establish', u'subsidiari' ...

# %% [markdown]
# ## Run Topic Modelling

# %%
def topic_model(train, test, topics):
    '''
    input: preprocessed test and training data, optionally the number of topics
    output: a fitted LDA topic model and the bow representation of test data for model evaluation
    '''
    random.seed(1)
    #create topic model on full text
    #will need to run on server when we have more data
    full_dict = corpora.Dictionary(train)
    DT_matrix = [full_dict.doc2bow(doc) for doc in train]
    test_token = [full_dict.doc2bow(doc) for doc in test]
    lda = LdaMulticore(DT_matrix, id2word=full_dict, num_topics=topics) 
    return lda, test_token

# %%
k = [2, 5, 10, 15, 20, 25, 30, 40 , 50, 75, 100] #possible number of topics
def calculate_perplexities(train,test, k):
    '''
    inputs: preprocessed test and training data, a list of possible number of topics
    outputs: log perplexity and perplexity, scored on the test set
    '''
    log_perplexities = []
    perplexity = []
    for i in k:
        model, test_doc2bow = topic_model(train, test, i)
        log_p = model.log_perplexity(test_doc2bow)
        log_perplexities.append(log_p)
        perp = model.bound(test_doc2bow)
        perplexity.append(perp)
    return log_perplexities, perplexity


all_log_perplexities, all_perplexities = calculate_perplexities(all_train, all_test, k)

# green_log_perplexities, green_perplexities = calculate_perplexities(green_train, green_test, k)
# synbio_log_perplexities, synbio_perplexities = calculate_perplexities(synbio_train, synbio_test, k)
# nano_log_perplexities,nano_perplexities= calculate_perplexities(nano_train, nano_test, k)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-151-f015e40ee397> in <module>()
#      16
#      17
# ---> 18 all_log_perplexities, all_perplexities = calculate_perplexities(all_train, all_test, k)
#      19
#      20 # green_log_perplexities, green_perplexities = calculate_perplexities(green_train, green_test, k)
#
# <ipython-input-151-f015e40ee397> in calculate_perplexities(train, test, k)
#       8     perplexity = []
#       9     for i in k:
# ---> 10         model, test_doc2bow = topic_model(train, test, i)
#      11         log_p = model.log_perplexity(test_doc2bow)
#      12         log_perplexities.append(log_p)
#
# <ipython-input-150-2c7532ab261c> in topic_model(train, test, topics)
#       7     #create topic model on full text
#       8     #will need to run on server when we have more data
# ----> 9     full_dict = corpora.Dictionary(train)
#      10     DT_matrix = [full_dict.doc2bow(doc) for doc in train]
#      11     test_token = [full_dict.doc2bow(doc) for doc in test]
#
# /Users/sarora/anaconda2/lib/python2.7/site-packages/gensim/corpora/dictionary.pyc in __init__(self, documents, prune_at)
#      81
#      82         if documents is not None:
# ---> 83             self.add_documents(documents, prune_at=prune_at)
#      84
#      85     def __getitem__(self, tokenid):
#
# /Users/sarora/anaconda2/lib/python2.7/site-packages/gensim/corpora/dictionary.pyc in add_documents(self, documents, prune_at)
#     200
#     201             # update Dictionary with the document
# --> 202             self.doc2bow(document, allow_update=True)  # ignore the result, here we only care about updating token ids
#     203
#     204         logger.info(
#
# /Users/sarora/anaconda2/lib/python2.7/site-packages/gensim/corpora/dictionary.pyc in doc2bow(self, document, allow_update, return_missing)
#     238         """
#     239         if isinstance(document, string_types):
# --> 240             raise TypeError("doc2bow expects an array of unicode tokens on input, not a single string")
#     241
#     242         # Construct (word, frequency) mapping.
#
# TypeError: doc2bow expects an array of unicode tokens on input, not a single string

# %% [markdown]
# #### Perplexity Plots for each Website type

# %%
import matplotlib.pyplot as plt
plt.plot(k, all_perplexities)

# %%
plt.plot(k, green_perplexities)

# %%
plt.plot(k, synbio_perplexities)

# %%
plt.plot(k, nano_perplexities)

# %% [markdown]
# #### Predict topics by paragraph

# %%
# define data structs and train model
topic_by_firm_vector = {} # at the firm level
new_train = all_train + all_test # train model on all docs

full_dict = corpora.Dictionary(new_train)
DT_matrix = [full_dict.doc2bow(doc) for doc in new_train]
lda = LdaMulticore(DT_matrix, id2word=full_dict, num_topics=20)

# %%
x=lda.show_topics(num_topics=20, num_words=10,formatted=False)
topics_words = [(tp[0], [wd[0] for wd in tp[1]]) for tp in x]

#Below Code Prints Topics and Words
for topic,words in topics_words:
    print(str(topic)+ "::"+ str(words))
# Out:
# 0::[u'product', u'technolog', u'servic', u'use', u'provid', u'innov', u'includ', u'compani', u'ani', u'develop']
# 1::[u"''", u'product', u'develop', u'perform', u'servic', u'offer', u'solar', u'new', u'``', u'manufactur']
# 2::[u"''", u'product', u'``', u'de', u'bodi', u'global', u'technolog', u'use', u'solut', u'support']
# 3::[u'new', u'system', u'use', u"''", u'technolog', u'develop', u'materi', u'offer', u'product', u'project']
# 4::[u"''", u'technolog', u'develop', u'provid', u'ul', u'industri', u'system', u'hover', u'li', u'bodi']
# 5::[u"''", u'``', u'use', u'provid', u'new', u'registersod', u'technolog', u'product', u'solut', u'compani']
# 6::[u"''", u'technolog', u'develop', u'use', u'solut', u'product', u"'s", u'innov', u'offer', u'high']
# 7::[u"''", u'``', u'product', u'applic', u'technolog', u'use', u'servic', u'custom', u'data', u'cell']
# 8::[u'technolog', u'solut', u'provid', u'appli', u'innov', u'new', u'compani', u'develop', u'system', u'design']
# 9::[u'use', u'product', u'cooki', u'inform', u'websit', u"''", u'develop', u'provid', u'site', u'ani']
# 10::[u"''", u'``', u'center', u'year', u'use', u'technolog', u'null', u'ul', u'new', u'cap']
# 11::[u"''", u'technolog', u'product', u"'s", u'help', u'provid', u'servic', u'``', u'system', u'use']
# 12::[u'technolog', u'product', u'industri', u'new', u'help', u'use', u'design', u'dental', u'work', u'cast']
# 13::[u"''", u'``', u'system', u'process', u'industri', u'2018', u'applic', u'product', u'need', u'solut']
# 14::[u'water', u'2018', u'technolog', u'servic', u'provid', u'product', u'research', u'energi', u'new', u'work']
# 15::[u'use', u"''", u'may', u'technolog', u'new', u'research', u'appli', u'offer', u'plant', u'manufactur']
# 16::[u'product', u'solut', u'technolog', u'system', u'2018', u'use', u'develop', u'perform', u'design', u'offer']
# 17::[u"''", u'``', u'ani', u'center', u'product', u'includ', u'cancer', u'use', u'servic', u'new']
# 18::[u"''", u'``', u'null', u'true', u'center', u'product', u'cap', u'wheel', u'cast', u'option']
# 19::[u'develop', u'compani', u'process', u"''", u'product', u'solut', u'design', u'applic', u'work', u'need']

# %%
for firm_key in all_docs_dict:
    firm_paras = all_docs_dict[firm_key]
    main_topic = [] # at the firm level, where each para is an entry
    main_topic_probs = [] # same, but for probabilities
    para_order = []
    para_len = [] 
    order_num = 1
    for para in firm_paras:
        para_len.append(len(para))
        topic_by_prob = sorted([(i[1],i[0]) for i in lda.get_document_topics(full_dict.doc2bow(para))], reverse = True)
        main_topic.append(topic_by_prob[0][1])
        main_topic_probs.append(topic_by_prob[0][0])
        para_order.append(order_num)
        order_num = order_num + 1
    firm_df = pd.DataFrame(
        {'firm_key': firm_key, 
         'para_order': para_order,
         'num_words': para_len,
         'main_topic': main_topic,
         'prob': main_topic_probs
        })
    topic_by_firm_vector[firm_key] = firm_df # set at the firm level

# %%
print len(topic_by_firm_vector.keys())
print(topic_by_firm_vector['Big Belly Solar.txt'])
# Out:
# 856
#                firm_key  main_topic  num_words  para_order      prob
# 0   Big Belly Solar.txt           5         17           1  0.947222
# 1   Big Belly Solar.txt          13         33           2  0.511423
# 2   Big Belly Solar.txt           5         35           3  0.463315
# 3   Big Belly Solar.txt           8         34           4  0.972857
# 4   Big Belly Solar.txt           8         46           5  0.979787
# 5   Big Belly Solar.txt           8         26           6  0.459950
# 6   Big Belly Solar.txt          13         14           7  0.691091
# 7   Big Belly Solar.txt          11         13           8  0.932143
# 8   Big Belly Solar.txt           2         12           9  0.926923
# 9   Big Belly Solar.txt          19         51          10  0.907312
# 10  Big Belly Solar.txt           7         50          11  0.926871
# 11  Big Belly Solar.txt           5         41          12  0.718137
# 12  Big Belly Solar.txt           7         50          13  0.981373
# 13  Big Belly Solar.txt          19         54          14  0.749204
# 14  Big Belly Solar.txt          11         51          15  0.669899
# 15  Big Belly Solar.txt           5         49          16  0.593027
# 16  Big Belly Solar.txt          12         35          17  0.973611

# %%
# write to a single output topic file
headers = list(topic_by_firm_vector[topic_by_firm_vector.keys()[0]])
with open(out_file, 'a') as f:
    f.write(','.join(headers) + '\n')
    for firm_key in topic_by_firm_vector:
        df = topic_by_firm_vector[firm_key]
        df.to_csv(f, header=False, index=False)
    # append to file the data frame results -- check to see how to do this with pandas

# %% [markdown]
# ### Markov Model

# %%
from collections import defaultdict
import random

# %%
class markov_representation():
    def __init__(self):
        self.tokens = defaultdict(lambda: 0)
        self.transitions = defaultdict(lambda: defaultdict(lambda:0))
        self.for_matrix = defaultdict(lambda: 0)
    def add(self, list_of_tokens):
        for i in range(len(list_of_tokens) ):
            if i <= (len(list_of_tokens)-2):
                self.tokens[str(list_of_tokens[i])]+=1
                self.transitions[str(list_of_tokens[i])][str(list_of_tokens[i + 1])]+=1
                self.for_matrix[(str(list_of_tokens[i]),str(list_of_tokens[i + 1]))] +=1
            else: #separate block to add the last token to the list of tokens
                self.tokens[str(list_of_tokens[i])]+=1
                self.transitions[str(list_of_tokens[i])][None] +=1
    def test(self):
        #return self.transitions
        return self.for_matrix
    #to do: add transition matrix
    def make_transition_matrix(self):
        #tranform dictionary of tuples in self.for_matrix into matrix
        pass
    def generate_sequence(self):
        topic = 'start'
        document = ['start']
        while topic != 'end' and len(document)<20:
            options = self.transitions[topic]
            total = sum(options.values())
            temp = 0
            threshold = random.randint(0, total-1)
            for key, value in options.iteritems():
                temp += value
                if temp>threshold:
                    topic = key
                    break
            document.append(topic)
        if document[-1] != 'end':
            document.append('end')
        return document
        #I want to recursively call this to generate a sequence of the required length, but pass on this for now
#         if len(document) > min_length:
#             return document
#         else:
#             return self.generate_sequence(self, 5)

# %% [markdown]
# ### Apply Model

# %%
model = markov_representation()
for doc in topic_vector:
    model.add(doc)
model.generate_sequence()
# Out:
# ['start', '2', '1', '1', '0', 'end']

# %%
## add code to get transition matrix

# %%
model.test()
# Out:
# defaultdict(<function __main__.<lambda>>,
#             {('0', '0'): 7,
#              ('0', '1'): 4,
#              ('0', '2'): 4,
#              ('0', '3'): 5,
#              ('0', 'end'): 2,
#              ('1', '0'): 9,
#              ('1', '1'): 25,
#              ('1', '2'): 4,
#              ('1', '3'): 5,
#              ('1', 'end'): 4,
#              ('2', '0'): 1,
#              ('2', '1'): 8,
#              ('2', '2'): 17,
#              ('2', '3'): 4,
#              ('2', 'end'): 3,
#              ('3', '0'): 5,
#              ('3', '1'): 5,
#              ('3', '2'): 4,
#              ('3', '3'): 11,
#              ('3', 'end'): 1,
#              ('start', '1'): 5,
#              ('start', '2'): 4,
#              ('start', '3'): 1})

# %% [markdown]
# # extract-pages-from-mongo
# SanjayKAroraPhD@gmail.com <br>
# November 2018
#
# ## Description
# This notebook extracts groups of pages from mongodb by firm_name to create firm-centric page output files that can later be topic modeled.  In doing so, it removes repetitive content (e.g., repeated menu items) and garbage content (e.g., improperly parsed HTML code).

# %%
# import data processing and other libraries
import csv
import sys
import requests
import os
import re
import pprint
import pymongo
import traceback
from time import sleep
import requests
import pandas as pd
import io
from IPython.display import display
import time
import numpy as np
from bs4 import BeautifulSoup

# %%
MONGODB_DB = "FirmDB_20181116"
MONGODB_COLLECTION = "pages_COMBINED"
CONNECTION_STRING = "mongodb://localhost"

client = pymongo.MongoClient(CONNECTION_STRING)
db = client[MONGODB_DB]
col = db[MONGODB_COLLECTION]

DATA_DIR = '/Users/sarora/dev/EAGER/data/orgs/depth0_pages/'

# %%
# gather unique firm_names from mongodb

def get_firm_aggregates ():
    query = [ { "$group": {"_id":"$firm_name" , "number":{"$sum":1}} } ]
    results = col.aggregate(query)

    mongo_dict = {}
    for result in results:
        key = (result['_id'])
        if key:
            mongo_dict[key[0]] = result['number']
        else:
            mongo_dict['NA'] = result['number']
    
    return mongo_dict

results_dict = get_firm_aggregates()
firm_names = results_dict.keys()
pp = pprint.PrettyPrinter()
pp.pprint(firm_names)
# Out:
# [u'Little Kids',
#  u'Daylight Solutions',
#  u'Biocon Limited',
#  u'Sony Corporation',
#  u'Magna International Inc.',
#  u'ENI Technology',
#  u'Honeywell International Inc.',
#  u'Aurrion',
#  u'The Jackson Laboratory',
#  u'Hewlett Packard Enterprise Development LP',
#  u'CUMMINS FILTRATION IP',
#  u'Custom Electronics Inc.',
#  u'H R D CORPORATION',
#  u'GENERAL MOTORS LLC',
#  u'FLIR Systems',
#  u'Sola U.S.A. Inc.',
#  u'Chromalox',
#  u'Empire Technology Development LLC',
#  u'Alcon Research',
#  u'Wyatt Technology Corporation',
#  u'Southwest Research Institute',
#  u'Tokyo Ohka Kogyo Co.',
#  u'Samsung Electronics',
#  u'Fairchild Semiconductor Corporation',
#  u'Supremex Inc.',
#  u'Calient Technologies',
#  u'Infineon Technologies Americas Corp.',
#  u'Ideal Power Inc.',
#  u'NuOrtho Surgical',
#  u'Easel Biotechnologies',
#  u'L-3 Communications Cincinnati Electronics Corporation',
#  u'SunEdison Semiconductor Limited',
#  u'IDEA TREE',
#  u'Solarmer Energy',
#  u'Braun Intertec Geothermal',
#  u'Fuji Electric Co.',
#  u'The Babcock & Wilcox Company',
#  u'Rima Enterprises',
#  u'Saint-Gobain Adfors Canada',
#  u'Agilent Technologies',
#  u'Toray Industries Inc. ',
#  u'Christie Digital Systems',
#  u'SYNTHOMER USA LLC',
#  u'Nissan North America',
#  u'Shin-Etsu Chemical Co.',
#  u'FUJIFILM Dimatix',
#  u'SUNSALUTER',
#  u'SII Semiconductor Corporation',
#  u'Prosoft International',
#  u'Energen',
#  u'KR Design House',
#  u'Akron Polymer Systems',
#  u'Revivicor',
#  u'Caribou Biosciences',
#  u'Syngenta Participations AG',
#  u'BERKEN ENERGY LLC',
#  u'ADASA INC.',
#  u'Abbott Molecular Inc.',
#  u'PLEX LLC',
#  u'Carver Scientific',
#  u'E. Tech Incorporation',
#  u'Canon',
#  u'Renewable Power Conversion',
#  u'Thermo Fisher Scientific Inc.',
#  u'Toray Plastics (America)',
#  u'Algenol Biotech LLC',
#  u'Cadence Design Systems',
#  u'ACACIA RESEARCH GROUP LLC',
#  u'Cabot Corporation',
#  u'Genesco Inc.',
#  u'CARBO Ceramics Inc.',
#  u'Metabolix',
#  u'TEKNOR APEX COMPANY',
#  u'One Earth Designs Inc.',
#  u'Commonwealth Scientific & Industrial Research Organization',
#  u'Siemens Industry',
#  u'Beryllium Discovery Corp.',
#  u'Tanaka Kikinzoku Kogyo K.K.',
#  u'Annam Biosciences',
#  u'Community Power Corporation',
#  u'Halliburton Energy Services',
#  u'Soraa Laser Diode',
#  u'Johnson & Johnson Vision Care',
#  u'DePuy Synthes Products',
#  u'STATS ChipPAC',
#  u'Crossbar',
#  u'Photon Dynamics',
#  u'Qiagen GmbH',
#  u'BAXALTA INCORPORATED',
#  u'Kodak Alaris Inc.',
#  u'J. E. WHITE',
#  u'AstenJohnson',
#  u'TRIDONIC GMBH & CO KG',
#  u'Heat Seal LLC',
#  u'Adlens Beacon',
#  u'VERLASE TECHNOLOGIES LLC',
#  u'UVIC INDUSTRY PARTNERSHIPS INC.',
#  u'LUCERA LABS',
#  u'Tau Therapeutics LLC',
#  u'Toshiba America Electronic Components',
#  u'PPG Industries Ohio',
#  u'BAE Systems Information and Electronic Systems Integration Inc.',
#  u'Alliance for Sustainable Energy',
#  u'Adobe Systems Incorporated',
#  u'GOAL ZERO LLC',
#  u'Handstand Innovations',
#  u'FRONT EDGE TECHNOLOGY INC.',
#  u'FUJIFILM Corporation',
#  u'Bruin Biometrics',
#  u'Lockheed Martin Corporation',
#  u'MonoSol',
#  u'nLIGHT',
#  u'Acorn Technologies',
#  u'Energysolutions',
#  u'Aerogen',
#  u'Zyvex Labs',
#  u'HGST NETHERLANDS B.V.',
#  u'BioNano Genomics',
#  u'Revera',
#  u'FEI Company',
#  u'Moxtek',
#  u'DNA Twopointo',
#  u'VMware',
#  u'Analog Devices',
#  u'SOL-ELECTRICA',
#  u'Toyota Motor Engineering & Manufacturing North America',
#  u'Deep Science',
#  u'Saint-Gobain Performance Plastics Corporation',
#  u'Macronix International Co.',
#  u'DIC Corporation',
#  u'CoolEarth Solar',
#  u'Express Imaging Systems',
#  u'Proterra Inc.',
#  u'Thorn Bioscience LLC',
#  u'Ortho-Clinical Diagnostics',
#  u'GIGA SOLAR FPC',
#  u'ALSTOM Technology Ltd',
#  u'Warsaw Orthopedic',
#  u'American Science and Technology Corporation',
#  u'E. I. du Pont de Nemours and Company',
#  u'Semiconductor Energy Laboratory Co.',
#  u'Pharmion Corporation',
#  u'Semics Inc.',
#  u'Hollywood Trucks',
#  u'Praxair Technology',
#  u'Sanuvox Technologies',
#  u'POSiFA MICROSYSTEMS',
#  u'ZENA TECHNOLOGIES',
#  u'MAXLINEAR',
#  u'NGK Spark Plug Co.',
#  u'MBC Ventures',
#  u'Headway Technologies',
#  u'Novellus Systems',
#  u'Englewood Lab',
#  u'SixPoint Materials',
#  u'Markel Corporation',
#  u'The Eastern Co.',
#  u'ABB Research Ltd.',
#  u'Shimadzu Corporation',
#  u'Fluidigm Corporation',
#  u'JOLED Inc.',
#  u'Pixar',
#  u'Bisco',
#  u'Synopsys',
#  u'Karsten Manufacturing Corporation',
#  u'Amkor Technology',
#  u'Lumenco',
#  u'Sustainable Technologies',
#  u'WCA Group LLC',
#  u'ASML Netherlands B.V.',
#  u'Hysitron Incorporated',
#  u'Eaton Corporation',
#  u'Medical Diagnostic Laboratories',
#  u'Bausch & Lomb Incorporated',
#  u'Wentworth Laboratories',
#  u'Gilead Sciences',
#  u'Heidelberger Druckmaschinen AG',
#  u'SD Technologies',
#  u'Abbott Point of Care Inc.',
#  u'Antaya Technologies Corporation',
#  u'Coleman Cable',
#  u'CMC ICOS BIOLOGICS',
#  u'Centre de Recherche Industrielle du Quebec',
#  u'Anelva Corporation',
#  u'Stablcor Technology',
#  u'Claret Medical',
#  u'Angstron Materials',
#  u'Veracyte',
#  u'Magnachip Semiconductor',
#  u'Reynolds Technologies',
#  u'Danisco US Inc.',
#  u'Bristol-Myers Squibb Company',
#  u'Polaris Products LLC',
#  u'Global Filtration Systems',
#  u'GE-Hitachi Nuclear Energy Americas LLC',
#  u'Butamax(TM) Advanced Biofuels LLC',
#  u'Fike Corporation',
#  u'Waters Technologies Corporation',
#  u'Samsung Electronics Co.',
#  u'Cavium',
#  u'ACell',
#  u'Immunolight',
#  u'Diamond Innovations',
#  u'Hollingsworth & Vose Company',
#  u'COOK MEDICAL TECHNOLOGIES LLC',
#  u'Tamura Corporation',
#  u'Crystal Solar Incorporated',
#  u'KOLO TECHNOLOGIES',
#  u'Weatherford Canada Partnership',
#  u'Casio Computer Co.',
#  u'Leap Frogg',
#  u'LGS Innovations LLC',
#  u'Kala Pharmaceuticals',
#  u'Zeno Semiconductor Inc',
#  u'Cornell Research Foundation',
#  u'National Education Corporation',
#  u'NEWFIELD THERAPEUTICS CORPORATION',
#  u'Northrop Grumman Systems Corporation',
#  u'NetApp',
#  u'Kronos International Inc',
#  u'Ion Power Group',
#  u'SEaB Energy Holdings Ltd.',
#  u'QUALCOMM Incorporated',
#  u'Gas Technology Institute',
#  u'St. Microelectronics Inc.',
#  u'Globus Medical',
#  u'Glucan Biorenewables LLC',
#  u'The Paymaster Corporation',
#  u'Tela Innovations',
#  u'VEECO PRECISION SURFACE PROCESSING LLC',
#  u'Unity Semiconductor Corporation',
#  u'Everspin Technologies',
#  u'Musco Corporation',
#  u'Nanotek Instruments',
#  u'NeuMoDx Molecular',
#  u'NanoLab',
#  u'MICROMIDAS',
#  u'Fujitsu Limited',
#  u'Nanoholdings',
#  u'Green Extraction Technologies',
#  u'Guardian Industries',
#  u'Integrated Device Technology',
#  u'Kashiv Pharma',
#  u'Allertein Therapeutics',
#  u'Baker Hughes Incorporated',
#  u'Solar Junction Corporation',
#  u'DHPC TECHNOLOGIES',
#  u'Yamaha Corporation',
#  u'Clearside Biomedical',
#  u'Met Tech Inc.',
#  u'GLOBALFOUNDRIES Inc.',
#  u'22nd Century Limited',
#  u'HTS',
#  u'Avon Products',
#  u'PDF Solutions',
#  u'TOMOWAVE LABORATORIES',
#  u'Sungevity Inc.',
#  u'Zephyr Energy Systems LLC',
#  u'Marathon Equipment Company',
#  u'Sumco Corporation',
#  u'Angaza Design',
#  u'Advanced Water Technology',
#  u'GE Healthcare Dharmacon',
#  u'Johnson Controls Technology Company',
#  u'Lux Bio Group',
#  u'Aushon Biosystems',
#  u'IMEC',
#  u'CERION LLC',
#  u'Qualsig Inc.',
#  u'Delavau LLC',
#  u'Kabushikikaisha Toshiba',
#  u'Veracode',
#  u'Oracle International Corporation',
#  u'Shell Oil Company',
#  u'Princeton Optronics',
#  u'TerraVia Holdings',
#  u'True-Safe Technologies',
#  u'Ansun Biopharma',
#  u'Solutia Inc.',
#  u'Crystalplex Corporation',
#  u'NovaSolix',
#  u'ExxonMobil Upstream Research Company',
#  u'Quantum Materials Corporation',
#  u'NOVA PANGAEA TECHNOLOGIES LIMITED',
#  u'Great American Duck Races',
#  u'Biocare Medical',
#  u'Swift Engineering',
#  u'Renesas Electronics Corporation',
#  u'Star Technology and Research',
#  u'TDK Corporation',
#  u'CAMBRIDGE ENTERPRISE LIMITED',
#  u'Magnolia Optical Technologies',
#  u'Mission Product Holdings',
#  u'WOVN',
#  u'Atrium Medical Corporation',
#  u'Hyundai Motor Company',
#  u'BASF Plant Science GmbH',
#  u'Kobe Steel',
#  u'Global Eagle Entertainment Inc.',
#  u'BROADCOM CORPORATION',
#  u'Yageo Corporation',
#  u'Em-Tech LLC',
#  u'McAlister Technologies',
#  u'Dow AgroSciences LLC',
#  u'Biotechnology Foundation',
#  u'Transilwrap Company',
#  u'Quantum Devices',
#  u'Vascular BioSciences',
#  u'Longhorn Vaccines and Diagnostics',
#  u'AGFA-GEVAERT N.V.',
#  u'Nordic Technologies',
#  u'Optodot Corporation',
#  u'Morpho',
#  u'MERCK SHARP & DOHME CORP.',
#  u'Ajinomoto Althea',
#  u'Combined Energies',
#  u'Michigan Biotechnology Institute',
#  u'ProNAi Therapeutics',
#  u'Cbrite Inc.',
#  u'PetraSolar',
#  u'WHATSAPP INC.',
#  u'Virent',
#  u'Ethicon Endo-Surgery',
#  u'Iogen Corporation',
#  u'McElroy Manufacturing',
#  u'NeoVision LLC',
#  u'Astech',
#  u'DEKA Products Limited Partnership',
#  u'Taiwan Semiconductor Manufacturing Company',
#  u'InView Technology Corporation',
#  u'Hunt Energy Enterprises LLC',
#  u'Rolls-Royce PLC',
#  u'BASF',
#  u'SRG Global',
#  u'Theraclone Sciences',
#  u'St. Jude Medical',
#  u'SEIKO NPC Corporation',
#  u'Areesys Technologies',
#  u'OLYMPUS CORPORATION',
#  u'Two Blades Foundation',
#  u'Senaya',
#  u'RES USA',
#  u'EXOS LLC',
#  u'BRIGHTLEAF TECHNOLOGIES INC.',
#  u'Ibis Biosciences',
#  u'Archer Daniels Midland Company',
#  u'Avertech',
#  u'Oculus VR',
#  u'Silicon Space Technology Corp.',
#  u'CP Kelco U.S.',
#  u'Cleanvantage LLC',
#  u'Novus Technology',
#  u'NCC Nano',
#  u'Simbol Inc.',
#  u'Agena Bioscience',
#  u'Stratasys',
#  u'U.S. NUTRACEUTICALS',
#  u'GED Intergrated Solution',
#  u'Linne Industries LLC',
#  u'Canon Kabushiki Kaisha',
#  u'Intermolecular',
#  u'Siemens Corporation',
#  u'Momentive Performance Materials Inc.',
#  u'Baxter International Inc.',
#  u'Materia',
#  u'Pfizer Inc.',
#  u'Maxout Renewables',
#  u'Ube Industries',
#  u'EPCOS AG',
#  u'Sick AG',
#  u'Siluria Technologies',
#  u'Adynxx',
#  u'Dialogic Corporation',
#  u'Marine Polymer Technologies',
#  u'NANOBIO CORPORATION',
#  u'Seiko Epson Corporation',
#  u'UTC FIRE & SECURITY CORPORATION',
#  u'NANO CELL SYSTEMS',
#  u'Illinois Tool Works',
#  u'SunRun',
#  u'ABB Technology Ltd.',
#  u'KUBIX INC.',
#  u'Gemex Systems',
#  u'King Electric Vehicles Inc.',
#  u'Global OLED Technology LLC',
#  u'Gracenote',
#  u'LG NANOH2O',
#  u'Battelle Memorial Institute',
#  u'American Piledriving Equipment',
#  u'Wizard Labs',
#  u'Genentech',
#  u'Sysmex Corporation',
#  u'GCP Applied Technologies Inc.',
#  u'KINO LLC',
#  u'TECNIUM',
#  u'Silicon Storage Technology',
#  u'Molecular Rebar Design',
#  u'Uniseal Solutions Inc.',
#  u'MicroLink Devices',
#  u'Bioneer Corporation',
#  u'D-Wave Systems Inc.',
#  u'Nantero',
#  u'Amberwave Inc.',
#  u'Thoratec Corporation',
#  u'Selecta Biosciences',
#  u'Child Laboratories Inc.',
#  u'AgroFresh Inc.',
#  u'Arpin Renewable Energy',
#  u'Xerox Corporation',
#  u'Dialight Corporation',
#  u'SPC International',
#  u"Nationwide Children's Hospital",
#  u'Perkinelmer Holdings',
#  u'American Air Liquide',
#  u'Brewer Science Inc.',
#  u'Solvay Specialty Polymers USA',
#  u'UWM Research Foundation',
#  u'Grandis Inc.',
#  u'BASF Coatings GmbH',
#  u'Pacific Biosciences of California',
#  u'Genisphere',
#  u'Achushnet Company',
#  u'Midrex Technologies',
#  u'TT Technologies',
#  u'Newdoll Enterprises LLC',
#  u'Carbon3D',
#  u'AG ENERGY SOLUTIONS',
#  u'Terra Caloric',
#  u'Applied Membrane Technologies',
#  u'Lintec Corporation',
#  u'Kansai Paint Co.',
#  u'Nanotech Biomachines',
#  u'Egenera',
#  u'3M Innovative Properties Company',
#  u'MATERIALS ANALYSIS TECHNOLOGY (US) CORP.',
#  u'SunCulture Solar Inc.',
#  u'KYOCERA DOCUMENT SOLUTIONS INC.',
#  u'Olympus NDT',
#  u'Omron Corporation',
#  u'Red Hat',
#  u'Takara Bio Inc.',
#  u'MirTech',
#  u'Momentive Performance Materials GmbH',
#  u'Pinnacle Technology',
#  u'Elwha LLC',
#  u'Inaeris Technologies',
#  u'Genomatica',
#  u'Henkel AG & Co. KGaA',
#  u'Dentsply International',
#  u'Owens-Brockway Glass Container Inc.',
#  u'SolarWorld Americas Inc.',
#  u'Applied Nanostructures',
#  u'GENERAL ELECTRIC COMPANY',
#  u'KT Corporation',
#  u'Cisco Technology',
#  u'Avantor Performance Materials',
#  u'Kaneka Corporation',
#  u'Dexerials Corporation',
#  u'Angiotech Pharmaceuticals (US)',
#  u'Dolby Laboratories Licensing Corporation',
#  u'Authenex',
#  u'Canon U.S. Life Sciences',
#  u'Garland Industries',
#  u'Andritz Inc.',
#  u'AGC Flat Glass North America',
#  u'Babcock Power Services',
#  u'Vizio Inc.',
#  u'Arkival Technology Corp.',
#  u'Newport Corporation',
#  u'iNanoBio LLC',
#  u'AltaRock Energy',
#  u'Unifrax I LLC',
#  u'Liquidia Technologies',
#  u'Lawrence Livermore National Security',
#  u'Applied Genetic Technologies Corporation',
#  u'Research Triangle Institute',
#  u'SolarLego Inc.',
#  u'HARMAN INTERNATIONAL INDUSTRIES',
#  u'Brookhaven Science Associates LLC ',
#  u'nanoComposix',
#  u'Nordson Corporation',
#  u'Federal Signal Corporation',
#  u'Imperial Innovations Limited',
#  u'Crestovo LLC',
#  u'OrbusNeich Medical',
#  u'Minebea Co.',
#  u'Adhesives Research',
#  u'KLA-Tencor Corporation',
#  u'Confluence Energy',
#  u'CP KELCO APS',
#  u'Roche Molecular Systems',
#  u'HAMAMATSU PHOTONICS K.K.',
#  u'Sanyo Electric Co.',
#  u'Hitachi High-Technologies Corporation',
#  u'Cedar Ridge Research',
#  u'Invensas Corporation',
#  u'Cambridge Electronics',
#  u'HRL Laboratories',
#  u'Verliant Energy',
#  u'Northwest Biotherapeutics',
#  u'KJ BIOSCIENCES LLC',
#  u'Johnson & Johnson Consumer Companies',
#  u'SNS NANO FIBER TECHNOLOGY',
#  u'CNH Industrial America LLC',
#  u'Osram Sylvania Inc.',
#  u'Envisionit LLC',
#  u'Sun Chemical Corporation',
#  u'Kajima Corporation',
#  u'Mitsubishi Metal Corporation',
#  u'TP Solar',
#  u'ATTOSTAT',
#  u'Wikipad',
#  u'Sunlight Photonics Inc.',
#  u'Pulse Therapeutics',
#  u'Sensor Electronic Technology',
#  u'Hon Hai Precision Industry Co.',
#  u'Extech/Exterior Technologies',
#  u'NanoTech Lubricants',
#  u'The Samuel Roberts Noble Foundation',
#  u'WiSys Technology Foundation',
#  u'ITN Energy Systems',
#  u'Reliance Controls Corporation',
#  u'Auterra',
#  u'Sumitomo Electric Device Innovations',
#  u'MicroContinuum',
#  u'Microchip Technology Incorporated',
#  u'DiscoveRx Corporation',
#  u'Genomic Health',
#  u'Carestream Health',
#  u'TRI ALPHA ENERGY',
#  u'Renmatix',
#  u'Zygo Corporation',
#  u'PACCAR Inc',
#  u'Evernote Corporation',
#  u'Entegris',
#  u'IDEX Health & Science LLC',
#  u'Echogen Power Systems',
#  u'Lion Copolymer Geismar',
#  u'Nanoridge Materials',
#  u'Rebellion Photonics',
#  u'Big Belly Solar',
#  u'Nokomis',
#  u'SUMITOMO WIRING SYSTEMS',
#  u'Zoetis Services LLC',
#  u'ExxonMobil Research and Engineering Company',
#  u'VINDICO NANOBIO TECHNOLOGY INC.',
#  u'HNO Greenfuels',
#  u'Esolar',
#  u'Bayer Cropscience AG',
#  u'EMD Technologies Inc.',
#  u'Newlans',
#  u'HIQ SOLAR',
#  u'Nederlandse Organisatie voor toegepast-natuurwetenschappelijk onderzoek TNO',
#  u'U S MICROPOWER INC',
#  u'Hewlett-Packard Development Company',
#  u'Arkema Inc.',
#  u'Floadia Corporation',
#  u'Entech Solar',
#  u'Global Solar Water Power Systems',
#  u'PortaFire',
#  u'Ormat Technologies Inc.',
#  u'Calysta',
#  u'MCI',
#  u'Singular Bio',
#  u'Xyleco',
#  u'Bigelow Aerospace',
#  u'Pacific Light Technologies',
#  u'Tesla Nanocoatings',
#  u'Integrated Solar Technology',
#  u'FULL CIRCLE BIOCHAR',
#  u'bioTheranostics',
#  u'UChicago Argonne',
#  u'Cetac Technologies Inc.',
#  u'fybr',
#  u'Da Yu Enterprises',
#  u'Adtran',
#  u'HOWARD INDUSTRIES',
#  u'Bitrode Corporation',
#  u'Sundrop Fuels',
#  u'AT&T Corporation',
#  u'Quallion LLC',
#  u'Ignis Innovation',
#  u'MONTEREY RESEARCH',
#  u'Stora Enso Oyj',
#  u'Proton Power',
#  u'Ambature',
#  u'Dermazone Solutions',
#  u'Industrial Technology Research Institute',
#  u'First Solar',
#  u'Inphenix',
#  u'RF Micro Devices',
#  u'Fujitsu Semiconductor Limited',
#  u'Meso Scale Technologies',
#  u'DSP Group LTD.',
#  u'Evri',
#  u'Abbott Cardiovascular Systems Inc.',
#  u'Solan',
#  u'LG Display Co.',
#  u'Bostik',
#  u'George Mason Research Foundation',
#  u'Soliton Lasers',
#  u'LIQUID X PRINTED METALS',
#  u'GOLBA LLC',
#  u'Innovation Hammer',
#  u'Conversant Intellectual Property Management Inc.',
#  u'Pacific Industrial Development Corporation',
#  u'Infinera Corporation',
#  u'Laserline Mfg.',
#  u'UT-Battelle',
#  u'BP Corporation North America Inc.',
#  u'Envision Solar International',
#  u'Avalanche Technology',
#  u'Bestway',
#  u'Suncore Photovoltaics',
#  u'Nikon Corporation',
#  u'Nippon Shokubai Co.',
#  u'Apple Inc.',
#  u'Janssen Biotech',
#  u'Mitsubishi Electric Corporation',
#  u'JSR Corporation',
#  u'Cross Match Technologies',
#  u'Tokyo Electron Limited',
#  u'CELLTRION',
#  u'Kamtec',
#  u'Faurecia Interior Systems',
#  u'RenovaCare Sciences Corp.',
#  u'Pansonic Corporation',
#  u'Codexis',
#  u'Applied Optoelectronics',
#  u'POET Research',
#  u'Sumitomo Rubber Industries',
#  u'MANUFACTURING RESOURCES INTERNATIONAL',
#  u'Greatbatch Ltd.',
#  u'IDEALAB',
#  u'Nthdegree Technologies Worldwide Inc.',
#  u'Fina Technology',
#  u'Corporation for National Research Initiatives',
#  u'Ablexis',
#  u'AbbVie Inc.',
#  u'FastCAP Systems Corporation',
#  u'Professional Compounding Centers of America',
#  u'Sensor-Kinesis Corporation',
#  u'Microsurge',
#  u'GLIKNIK INC.',
#  u'Luna Innovations Incorporated',
#  u'Eastman Kodak Company',
#  u'Mainstream Engineering Corp.',
#  u'Deployable Space Systems',
#  u'OSI Optoelectronics',
#  u'Thorlabs',
#  u'Microsemi SoC Corporation',
#  u'Transtron Solutions LLC',
#  u'NOK Corporation',
#  u'Bi-Modal Corporation',
#  u'Wenger Corporation',
#  u'Tufts Medical Center',
#  u'Chevron Oronitz Company LLC',
#  u'Hitachi Metals',
#  u'JNC Corporation',
#  u'Synaptic Research',
#  u'k-Space Associates',
#  u'Intuitive Surgical Operations',
#  u'FutureWei Technologies',
#  u'GLYCON LLC',
#  u'S. C. Johnson & Son',
#  u'Solar-Tectic LLC',
#  u'Cree',
#  u'Arcturus Therapeutics',
#  u'T.H.E.M.',
#  u'SolAero Technologies Corp.',
#  u'Banpil Photonics',
#  u'Selkermetrics',
#  u'Atleisure LLC',
#  u'Kiverdi',
#  u'STANDARD ALCOHOL COMPANY OF AMERICA',
#  u'Altex Technologies Corporation',
#  u'Adaptive Biotechnologies Corp.',
#  u'Brother International Corporation',
#  u'Amprius',
#  u'Vadient Optics',
#  u'Shoals Technologies Group',
#  u'Colgate-Palmolive Company',
#  u'Chevron U.S.A. Inc.',
#  u'Boehringer Ingelheim Vetmedica GmbH',
#  u'Boehringer Ingelheim International GmbH',
#  u'Inventus Holdings',
#  u'Surebeam Corporation',
#  u'Hoya Corporation',
#  u'Dynamic Solutions Worldwide',
#  u'Starlight Energy Holdings LLC',
#  u'Grain Processing Corporation',
#  u'Flextronics AP',
#  u'Fenwal',
#  u'CLEARSIGN COMBUSTION CORPORATION',
#  u'Incept LLC',
#  u'ZON',
#  u'Biological Dynamics',
#  u'R.J. Reynolds Tobacco Company',
#  u'SunLink Corporation',
#  u'Sangamo BioSciences',
#  u'ADVANCED CERAMIC FIBERS',
#  u'Tata Consultancy Services Limited',
#  u'KOLON INDUSTRIES',
#  u'Lam Research Corporation',
#  u'Heraeus Precious Metals North America Conshohocken LLC',
#  u'Medicis Pharmaceutical Corporation',
#  u'Robert Bosch GmbH',
#  u'Monolithe Semiconductor Inc.',
#  u'Senga Advisors',
#  u'MICROSOFT TECHNOLOGY LICENSING',
#  u'United Microelectronics Corp.',
#  u'Kureha Corporation',
#  u'Polysar Corporation',
#  u'Ethox Chemicals',
#  u'Mumetel',
#  u'Universal Display Corporation',
#  u'Biotta LLC',
#  u'SolaBlock LLC',
#  u'Redwood Systems',
#  u'Astex Pharmaceuticals',
#  u'Novus Energy LLC',
#  u'DECA Technologies Inc.',
#  u'Pioneer Energy',
#  u'Performance Plants',
#  u'Sinewatts',
#  u'ESCAPE THERAPEUTICS',
#  u'OmniVision Technologies',
#  u'X DEVELOPMENT LLC',
#  u'Monsanto Technology LLC',
#  u'Kinetech Power Company LLC',
#  u'Formula Plastics',
#  u'Green Solar Transportation',
#  u'eNow',
#  u'Atotech Deutschland GmbH',
#  u'Cool Planet Energy Systems',
#  u'NanoMech',
#  u'The Boeing Company',
#  u'Chemtreat',
#  u'Riverbed Technology',
#  u'Seiko Instruments Inc.',
#  u'OTSUKA PHARMACEUTICAL CO.',
#  u'ACUCELA INC.',
#  u'Smith & Nephew',
#  u'Eastman Chemical Company',
#  u'UNISANTIS ELECTRONICS SINGAPORE PTE. LTD.',
#  u'Neural Signals',
#  u'Vorbeck Materials Corporation',
#  u'Mattson Technology',
#  u'S&S X-Ray Products',
#  u'Nanoquantum Sciences',
#  u'Armageddon Energy Inc.',
#  u'PAX Scientific',
#  u'UCB Pharma S.A.',
#  u'INFINEUM INTERNATIONAL LIMITED',
#  u'ExxonMobil Chemical Patents Inc.',
#  u'Koch Biological Solutions',
#  u'INTEVAC',
#  u'Texas Research International',
#  u'Blue Sea Systems',
#  u'Electronic Warfare Associates',
#  u'Ricoh Company Limited',
#  u'SunPower Corporation',
#  u'Nanoco Technologies',
#  u'SAMSUNG DISPLAY CO.',
#  u'E Ink Corporation',
#  u'Nanocopocia',
#  u'GENCO SCIENCES LLC',
#  u'Amtech Systems',
#  u'mVerify Corporation',
#  u'Dana Corporation',
#  u'Sanofi',
#  u'Electrix',
#  u'Autonomic Materials',
#  u'Advanced Cell Technology',
#  u'CI4 Technologies',
#  u'Adeka Corporation',
#  u'THYSSENKRUPP INDUSTRIAL SOLUTIONS GMBH',
#  u'Universal Leaf Tobacco Co.',
#  u'Poly-Med',
#  u'Litron Laboratories Limited',
#  u'Harris Corporation',
#  u'Taiyo Ink Mfg. Co.',
#  u'Disney Enterprises',
#  u'INVISTA North America S.a.r.l.',
#  u'Symantec Corporation',
#  u'Transitions Optical',
#  u'Teledyne Scientific & Imaging',
#  u'aTyr Pharma',
#  u'NEC Corporation',
#  u'Incyte Holdings Corporation',
#  u'Raytheon Company',
#  u'Innolux Corporation',
#  u'DuPont Teijin Films U.S. Limited Partnership',
#  u'ServiceNow',
#  u'All Power Labs',
#  u'Ecovative Design',
#  u'HM3 Energy',
#  u'Lextar Electronics Corp.',
#  u'LG Electronics Inc.',
#  u'Roll-N-Lock Corporation',
#  u'SunEdison',
#  u'Synthetic Genomics',
#  u'TRANE INTERNATIONAL INC.',
#  u'Propagation Research Associates',
#  u'Industrial Science & Technology Network',
#  u'SOLENA FUELS CORPORATION',
#  u'II-VI Incorporated',
#  u'SELMAN AND ASSOCIATES',
#  u'ATC Technologies',
#  u'Allison Transmission',
#  u'Kerr Corporation',
#  u'Cura Vac',
#  u'Siemens Aktiengesellschaft ',
#  u"CSEM Centre Suisse d'Electronique et de Microtechnique SA-Recherche et Developpement",
#  u'Sinton Consulting',
#  u'Alnylam Pharmaceuticals',
#  u'PeterBrod Corp.',
#  u'Daikin Industries',
#  u'NeoPhotonics Corporation',
#  u'ECOSYNTHETIX LTD.',
#  u'ConocoPhillips Company',
#  u'AC International Inc.',
#  u'PolyOne Corporation',
#  u'Nanospectra Biosciences',
#  u'Skidmore',
#  u'SABIC GLOBAL TECHNOLOGIES B.V.',
#  u'GOJO Industries',
#  u'Tersus Environmental',
#  u'Genzyme Corporation',
#  u'ASTUTE MEDICAL',
#  u'UOP LLC',
#  u'Quantapore',
#  u'Alcotek',
#  u'Becton',
#  u'EMC Corporation',
#  u'Microchips Biotech',
#  u'Interface Performance Materials',
#  u'Paratek Pharmaceuticals',
#  u'NLT TECHNOLOGIES',
#  u'Sima Therapeutics',
#  u'Tyco Electronics Corporation',
#  u'MILLENIUM SYNTHFUELS CORPORATION',
#  u'Manta Instruments',
#  u'Plasma-Therm',
#  u'GEN-PROBE INCORPORATED',
#  u'Agrivida',
#  u'Elenion Technologies',
#  u'Alcatel Lucent',
#  u'Galectin Therapeutics',
#  u'APPLIED STEMCELL',
#  u'MIETAMARK GENETICS',
#  u'AIR PRODUCTS AND CHEMICALS',
#  u'Interez',
#  u'Uni-Charm Corporation',
#  u'Kemira OY',
#  u'Gestion Ultra International Inc.',
#  u'Nova Technologies',
#  u'Cook Biotech Incorporated',
#  u'Helios Focus LLC',
#  u'Acer Incorporated',
#  u'B.G. Negev Technologies and Applications Ltd.',
#  u'The Goodyear Tire & Rubber Company',
#  u'Basell Polyolefine GmbH',
#  u'VIASAT INC.',
#  u'Bell Helicopter Textron Inc.',
#  u'Starsource Scientific LLC',
#  u'AVOGY',
#  u'Schneider Electric USA',
#  u'WAFERTECH',
#  u'Hunter Douglas Inc.',
#  u'Dymax Corporation',
#  u'ASCENT SOLAR TECHNOLOGIES',
#  u'Conoco Inc.',
#  u'Cardiva Medical',
#  u'Columbia Insurance Company',
#  u'OPTERRA ENERGY SERVICES',
#  u'Altivera',
#  u'AROG PHARMACEUTICALS',
#  u'GTherm',
#  u'GE Healthcare Limited',
#  u'Buckman Laboratories International',
#  u'Abengoa Bioenergy New Technologies',
#  u'Ford Global Technologies',
#  u'Bio-Rad Laboratories',
#  u'Smart Planet Technologies',
#  u'Arrowhead Center',
#  u'Wostec',
#  u'Piksel',
#  u'Forest Concepts',
#  u'Delta Electronics',
#  u'Humanetics Corporation',
#  u'Fianium Ltd.',
#  u'Ivoclar Vivadent AG',
#  u'Parion Sciences',
#  u'Biosphere Medical',
#  u'GOSOLARLIFE',
#  u'Biosense Webster (Israel) Ltd.',
#  u'Stanley Electric Co.',
#  u'Sandia Corporation',
#  u'PQ CORPORATION',
#  u'Access Business Group International LLC',
#  u'Rohm and Haas Electronic Materials LLC',
#  u'SICPA Holding SA',
#  u'Kulite Semiconductor Products',
#  u'SolarCity Corporation',
#  u'Phillips 66 Company',
#  u'Rio Grande Valley Sugar Growers',
#  u'Roche Diabetes Care',
#  u'Selas Heat Technology Company LLC',
#  u'Oceanit Laboratories',
#  u'Instron Corporation ',
#  u'Triple Ring Technologies',
#  u'Nutech Ventures',
#  u'Accuri Cytometers',
#  u'Tapwave',
#  u'Saint-Gobain Ceramics & Plastics',
#  u'VIOLIN MEMORY',
#  u'Heliae Development',
#  u'Canon Nanotechnologies',
#  u'ALGETERNAL TECHNOLOGIES',
#  u'Ampio Pharmaceuticals',
#  u'Freescale Semiconductor',
#  u"Dr. Reddy's Laboratories Ltd.",
#  u'Cooper Technologies Company',
#  u'Gilead Connecticut',
#  u'VERILY LIFE SCIENCES LLC',
#  u'Bridgelux',
#  u'New England Biolabs',
#  u'Tarveda Therapeutics',
#  u'Integrated DNA Technologies',
#  u'Coactive Drive Corporation',
#  u'Regeneron Pharmaceuticals',
#  u'Pentair Thermal Management LLC',
#  u'Bend Research',
#  u'Hamilton Sundstrand Corporation',
#  u'Neutronic Perpetual Innovations',
#  u'Wireless Environment',
#  u'Gardner-Gibson',
#  u'Solaire Generation LLC',
#  u'Kinestral Technologies',
#  u'Power Integrations',
#  u'Masimo Semiconductor',
#  u'CellPrint IP Holding',
#  u'Kimberly-Clark Worldwide',
#  u'Ecolab Inc.',
#  u'Furukawa Electric Co.',
#  u'Silicor Materials Inc.',
#  u'Chevron Phillips Chemical Company LP',
#  u'Total Marketing Services',
#  u'Electrovaya Inc.',
#  u'Chipmos Technologies Inc.',
#  u'Graphene Technologies',
#  u'Carl Zeiss Meditec AG',
#  u'MEDport',
#  u'Avtaec Limited',
#  u'Roche Diagnostics GmbH',
#  u'Sweetwater Energy',
#  u'Hitachi',
#  u'Pendar Technologies',
#  u'Phoseon Technology',
#  u'Winbond Electronics Corp.',
#  u'Ensyn Renewables',
#  u'Element One',
#  u'Cyberonics',
#  u'Bird-B-Gone',
#  u'Oki Data Corporation',
#  u'Solight Solar',
#  u'Brightfield Transportation Solutions',
#  u'Dana-Farber Cancer Institute',
#  u'Google Inc.',
#  u'G.D.O. Inc',
#  u'The Carbon Cable Company',
#  u'GROW ENERGY',
#  u'Micron Technology',
#  u'R.A. Miller Industries',
#  u'LATITUDE PHARMACEUTICALS INC.',
#  u'PolyPlus Battery Company',
#  u'Green Box Batteries',
#  u'Agienic',
#  u'Peytant Solutions',
#  u'ElectraTherm',
#  u'Integrated Nano-Technologies',
#  u'Seagate Technology LLC',
#  u'GangaGen',
#  u'Mitsubishi Polyester Film',
#  u'PTC Therapeutics',
#  u'Novartis AG',
#  u'RADIANCE SOLAR',
#  u'Certain-teed Corporation',
#  u'SAINT-GOBAIN ABRASIFS',
#  u'Nvidia Corporation',
#  u'Lattice Semiconductor Corporation',
#  u'VINYLAST',
#  u'Intel Corporation',
#  u'PluroGen Therapeutics',
#  u'Roche Innovation Center Copenhagen A/S',
#  u'Pegatron Corporation',
#  u'W&Wsens Devices',
#  u'Lovelace Respiratory Research Institute',
#  u'Plant Sensory Systems',
#  u'Alencon Acquisition Co.',
#  u'AFMODEL',
#  u'Nanosys',
#  u'Delphi Technologies',
#  u'JX Nippon Mining & Metals Corporation',
#  u'The Henry M. Jackson Foundation for the Advancement of Military Medicine',
#  u'Wine.com',
#  u'SEEK THERMAL',
#  u'FLOW CONTROL LLC.',
#  u'Infineon Technologies AG',
#  u'Meyer Tool',
#  u'Magnolia Solar',
#  u'Micro Cooling Concepts',
#  u'Toda Kogyo Corporation',
#  u'Dell Software Inc.',
#  u'Atom Nanoelectronics',
#  u'Landauer',
#  u'International Business Machines Corporation',
#  u'Advanced Silicon Group',
#  u'Lake Lite',
#  u'CyboEnergy',
#  u'Marine Biotech Inc.',
#  u'ADVANCED INNOVATION CENTER LLC',
#  u'Maxim Integrated Products',
#  u'Midori USA',
#  u'Eisai Co.',
#  u'NICHIA CORPORATION',
#  u'Takeda Pharmaceutical Company Limited',
#  u'Siliconware Precision Industries Co.',
#  u'Nexcom Technology',
#  u'Denso Corporation',
#  u'Kraton Polymers U.S. LLC',
#  u'SPICE SOLAR',
#  u'Mediatek Inc.',
#  u'Continental Manufacturing',
#  u'TMC Corporation',
#  u'AMPT',
#  u'Narsys',
#  u'IMRA America',
#  u'Sun Drilling Products Corporation',
#  u'Previvo Genetics',
#  u'SB ENERGY',
#  u'Valicor',
#  u'Turf Group LLC',
#  u'International Technology Center',
#  u'HTC Corporation',
#  u'Sumitomo Electric Industries',
#  u'DISCOVERYBIOMED INC.',
#  u'PLYCEM USA',
#  u'Matrix Genetics',
#  u'Samsung SDI Co.',
#  u'Cellular Research',
#  u'EchoStar Technologies LLC',
#  u'Milliken & Company',
#  u'Honda Motor Co.',
#  u'Coloplast A/S',
#  u'Singulex',
#  u'Semprius',
#  u'Copernicus Therapeutics',
#  u'Unistrut International Corp.',
#  u'Siemens Medical Solutions USA',
#  u'Sion Power Corporation',
#  'NA',
#  u'Isis Pharmaceuticals',
#  u'Bemis Company',
#  u'Sun Synchrony',
#  u'IMDS Corporation',
#  u'SOLARTONIC',
#  u'Cristal USA Inc.',
#  u'Rapamycin Holdings',
#  u'Advanced Analogic Technologies',
#  u'Soraa',
#  u'Sierra Sciences',
#  u'Nissan Motor Co.',
#  u'CYBERCITY 3D',
#  u'Advanced Aqua Group',
#  u'Sequenom',
#  u'Hosiden Corporation',
#  u'Schlumberger Technology Corporation',
#  u'Pixelligent Technologies',
#  u'Tosoh Corporation',
#  u'Johnson Matthey PLC',
#  u'Ferro Corporation',
#  u'BTU International',
#  u'Ziptronix',
#  u'LifeNet Health',
#  u'New Technology Ventures',
#  u'Boston Scientific Scimed',
#  u'Greyrock Energy',
#  u'Courtagen Life Sciences',
#  u'ATOMERA INCORPORATED',
#  u'BASF Enzymes LLC',
#  u'Alpha and Omega Semiconductor Incorporated',
#  u'Quest Diagnostics Investments Incorporated',
#  u'Murata Manufacturing Co.',
#  u'O.B.I. Inc.',
#  u'Rhodia Operations',
#  u'Foret Plasma Labs',
#  u'Tigo Energy',
#  u'United Technologies Corporation',
#  u'Sila Nanotechnologies',
#  u'Lof Solar Corporation',
#  u'Neumedicines',
#  u'OAS Design Group',
#  u'Sagacious Investment Group L.L.C.',
#  u'System Biosciences',
#  u'Renewable Algal Energy',
#  u'SanDisk Technologies LLC',
#  u'Seetron Inc.',
#  u'Baxter Healthcare SA',
#  u'Complete Genomics',
#  u'Schneider Electric Solar Inverters USA',
#  u'Ceramatec',
#  u'Novon',
#  u'NOVA Chemicals (International) S.A.',
#  u'The Charles Stark Draper Laboratory',
#  u'Sharp Laboratories of America',
#  u'Fuji Xerox Co.',
#  u'Production Resource Group',
#  u'COVERIS FLEXIBLES US LLC',
#  u'Lehigh Technologies',
#  u'Pentron Clinical Technologies',
#  u'Domtar Paper Company',
#  u'Strategic Solar Energy',
#  u'GlaxoSmithKline Biologicals',
#  u'iBio',
#  u'Voxtel',
#  u'ENI S.p.A.',
#  u'Sigma-Aldrich Co. LLC',
#  u'Bridgestone Corporation',
#  u'Turtle Beach Corporation',
#  u'Palo Alto Research Center Incorporated',
#  u'Scientific Design Company',
#  u'SAE Magnetics (HK) Ltd.',
#  u'JFE STEEL CORPORATION',
#  u'Silicon Genesis Corporation',
#  u'JAC Products Inc.',
#  u'Vaxiion Therapeutics',
#  u'Johns Manville',
#  u'Watlow Electric Manufacturing Company',
#  u'Rockwell Collins',
#  u'Transposagen Biopharmaceuticals',
#  u'Conexant Systems',
#  u'Wave Energy Conversion Corporation of America',
#  u'Hadasit Medical Research Services & Development Company Ltd.',
#  u'Nippon Chemi-Con Corporation',
#  u'STMicroelectronics Limited',
#  u'Coriant Advanced Technology',
#  u'Dresser-Rand Company',
#  u'Bluestar Silicones France',
#  u'Finisar Corporation',
#  u'Bayer Materialscience LLC',
#  u'SolarReserve Technology',
#  u'Kia Motors Corporation ',
#  u'Nanomix',
#  u'InVisage Technologies',
#  u'Atonometrics',
#  u'ARBOR THERAPEUTICS',
#  u'Carl Zeiss Microscopy GmbH',
#  u'Applied Biosystems',
#  u'THE BOARD INSTITUTE',
#  u'Relypsa',
#  u'Ticona LLC',
#  u'Kao Corporation',
#  u'Xintec Inc.',
#  u'MAHLE International GmbH',
#  u'POLAR LIGHT TECHNOLOGIES AB',
#  u'Epizyme',
#  u'Sanken Electric Co.',
#  u'Alexion Pharmaceuticals',
#  u'Yissum',
#  u'WestPoint Home',
#  u'Georgia-Pacific Gypsum LLC',
#  u'Korea Kumho Petrochemical Co.',
#  u'Richtek Technology Corporation',
#  u'Avery Dennison Corporation',
#  u'Gtech Corporation',
#  u'AccuRay Corporation',
#  u'Gram Power',
#  u'Teradata US',
#  u'Rockwell Automation Technologies',
#  u'NanoOncology',
#  u'OFS Fitel',
#  u'ZIH Corp.',
#  u'DRS Network & Imaging Systems',
#  u'Travis Industries',
#  u'Lumentum Operations LLC']

# %%
# remove html content
def is_javascript (x):
    match_string = "(CDATA|return\s+true|return\s+false|function|\w+\(.*?\);|\w{2,}[\\.|:]+\w{2,}|'\w+':\s+'\w+')"
    # capture CDATA; function declarations; function calls; word sequences separated by a period (e.g., denoting paths)
    regex = re.findall(match_string, x) 
    # check to see if the regex finds some percentage of the words look like javascript patterns
    if (len(regex) / float(len(x.split())) > .10) and len(regex) > 3:
        return True 
    else:
        return False

def clean_page_content (text_list):
    # remove whatever we think is html
    removed_html = filter(lambda x: not( bool(BeautifulSoup(x, "html.parser").find()) ), text_list)
    # remove content that looks like javascript 
    removed_js = filter(lambda x: not (is_javascript(x)), removed_html)
    # add other checks here as needed

    return removed_js
    

# iterate through each firm, get all pages associated with a firm, and produce data structure
# url --> depth
#     --> content (list)
# return data structure
def process_firm (firm_name): 
    regex = '^' + re.escape(firm_name) + '$'
    results = col.find( {"$and":[ {"firm_name": re.compile(regex, re.IGNORECASE) }, {"depth":1}]} )
    
    firm_pages_dict = {}
    depth0_page_text = [] # home page
    for result in results:
        key = (result['url'])
        if key:
            page_dict = {}
            depth = result['depth'][0]
            page_dict['depth'] = depth
            page_dict['domain'] = result['domain'][0]
            page_dict['firm_name'] = firm_name
            clnd_text = clean_page_content(result['full_text'])
            page_dict['clnd_text'] = clnd_text
            firm_pages_dict[key[0]] = page_dict
            
            if depth == 0:
                depth0_page_text = clnd_text
        else:
            continue
            
    return firm_pages_dict, depth0_page_text
# TODO: identify which pieces of content are common across all sites, and remove those
# def clean_content(firm_dict):

# %%
# regex test 
regex = re.findall("(CDATA|return\s+true|return\s+false|function|\w+\(.*?\);|\w{2,}[\\.|:]+\w{2,}|'\w+':\s+'\w+')", 
                   "CDATA function contact-us javascript.function linker:autoLink www.littlekidsinc.com fxnCall(param.param); email@dextr.us 'type': 'image' return true return false") # last part is words sequences separated by punct
print (regex)
# Out:
# ['CDATA', 'function', 'javascript.function', 'linker:autoLink', 'www.littlekidsinc', 'fxnCall(param.param);', 'dextr.us', "'type': 'image'", 'return true', 'return false']

# %%
# run
pp = pprint.PrettyPrinter()
for firm_name in firm_names: 
    print ("Working on " + firm_name)
    firm_pages_dict, depth0_page_text = process_firm (firm_name)
    # pp.pprint(depth0_page_text)
    if depth0_page_text: 
        with io.open(DATA_DIR + firm_name.replace(" ", "_") + '.txt','w',encoding='utf8') as f:
            f.write ('\n'.join (depth0_page_text))
# Out:
# Working on Little Kids
# Working on Daylight Solutions
# Working on Biocon Limited
# Working on Sony Corporation
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.allaboutdnt.com" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# Working on Magna International Inc.
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.globenewswire.com/NewsRoom/AttachmentNg/99f51b5e-31df-44d8-aca5-43b70d33e853" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.globenewswire.com/NewsRoom/AttachmentNg/6dd59a22-822f-444c-b864-78e2f6a7068f" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# Working on ENI Technology
# Working on Honeywell International Inc.
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://honeywellhub.secure.force.com/PrivacyInformationRequestForm?lang=en" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://honeywellprod.sharepoint.com/teams/TS-Spin-Off-Info-Hub/SitePages/HR-online.aspx" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://resideoinc.sharepoint.com/sites/FrontDoor/Functions/hr/HR-Online/Pages/HROnline.aspx" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://thermalsolutions.honeywell.com/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# Working on Aurrion
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.asurion.com/privacy-policy/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# Working on The Jackson Laboratory
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://ckbhome.jax.org" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://doi.org/10.1080/15384047.2018.1507666" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.informatics.jax.org" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://ohlabjax.weebly.com" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# Working on Hewlett Packard Enterprise Development LP
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:219: UserWarning: "//" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://partner.hpe.com" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.aboutads.info/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://youradchoices.com/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.google.com/policies/privacy/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://tools.google.com/dlpage/gaoptout" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# Working on CUMMINS FILTRATION IP
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/cumminsfiltration" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/fleetguard" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.instagram.com/cummins_filtration/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.youtube.com/user/FleetguardFiltration" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/nanoforce" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/directflow" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/optiair" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/magnumrs" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/cabinair" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/air" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/ourcoolantsolutions" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/crankcaseventilation" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/fuel" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/lube" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/hydraulics" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/fluidanalysis" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/transmission" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/sites/default/files/LT36510_0.pdf" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/NOAT" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/sites/default/files/LT36590.pdf" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/spinonfilterlube" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/centrifuge" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/sensors" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/closedcvfilters" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/opencvfilters" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/spinonfilters" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/fuelprocessors" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.fleetschool.com/#/signup" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/fleetguardcoolantsolutions" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.youtube.com/watch?v=n-ZAPJiFLzg" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/literature/additives" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/literature/air" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/literature/applications" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/literature/cooling" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/literature/crankcase-ventilation" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/literature/fluid-analysis" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/literature/fuel" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/literature/hydraulic" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/literature/lube" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/literature/transmission-filtration" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/literature/def-urea" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/literature/marketing-general" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/literature/oil-and-gas" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.cumminsfiltration.com/literature/corporate-literature" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# Working on Custom Electronics Inc.
# Working on H R D CORPORATION
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://haywardrec.org/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://haywardrec.org/directory.aspx?DID=" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# Working on GENERAL MOTORS LLC
# Working on FLIR Systems
# Working on Sola U.S.A. Inc.
# Working on Chromalox
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.asme.org" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.ul.com" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.fmglobal.com" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.csagroup.org/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://ec.europa.eu/growth/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.cemarking.net" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.nato.int/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.sgs.co.uk/en-gb/solutions/complying-with-requirements-for-hazardous-atmospheres" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.cstb.fr/actualites/english-webzine.html" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.ptb.de/en/wegweiser/oeffentlichkeit/verbraucherschutz/zulassung.html" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.ia.omron.com/support/models/demko" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.evpu.sk" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.intertek.com/government/regulatoryupdates/customs-union-eac-machinery/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.ul-asia.com/news_nl/2006-Issue17/page7.htm" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.dosh.gov.my/index.php" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.iso.org/iso/home.htm" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.iecex.com/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://ec.europa.eu/environment/chemicals/reach/reach_intro.htm" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.bis.gov.uk/nmo/enforcement/rohs-home" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://english.kosha.or.kr/english/main.do" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# Working on Empire Technology Development LLC
# Working on Alcon Research
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.businessinsider.com/why-you-have-dark-circles-under-your-eyes-2014-6" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.mayoclinic.org/symptoms/dark-circles-under-eyes/basics/causes/sym-20050624" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.allaboutvision.com/cosmetic/puffy-eyes.htm" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.novartis.com" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://twitter.com/novartis" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.alcon.com/privacy-policy" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.alcon.com/about-us/corporate-responsibility/eye-care-everyone" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.allaboutcookies.org/manage-cookies/index.html" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.networkadvertising.org/managing/opt_out.asp" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.aboutads.info/appchoices" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# Working on Wyatt Technology Corporation
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://polyanalytik.bio.br/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.wyatt.com/files/WTE/Administration/AGB_eng-2018.pdf" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# Working on Southwest Research Institute
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://tacticalnetworks.swri.org" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# Working on Tokyo Ohka Kogyo Co.
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.tok.co.jp/eng/products/package" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# Working on Samsung Electronics
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.samsung.com/us/tv-upgrade/terms-and-conditions/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.hp.com/go/samsung" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.t-mobile.com/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.samsung.com/galaxywatch/device-compatibility" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.att.com/plans/next.html" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.samsung.com/us/account/privacy-policy/samsungads" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.samsung.com" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://account.samsung.com/membership/pp" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://help.content.samsung.com" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.smartthings.com" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.hp.com/go/privacy" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://youtu.be/Fx8lA9Qj6ZA" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.samsung.com/us/support/premium-care/terms-and-conditions/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# Working on Fairchild Semiconductor Corporation
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.jamsadr.com/file-an-eu-us-privacy-shield-claim" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.onsemi.com" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# Working on Supremex Inc.
# Working on Calient Technologies
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.calient.net" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.calient.net" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://sc18.supercomputing.org" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# Working on Infineon Technologies Americas Corp.
# Working on Ideal Power Inc.
# Working on NuOrtho Surgical
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.bitlifesciences.com/wcmb2011/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://posters.webges.com/get/pdf/icrs2010/3754/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.atmc.umassd.edu/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# Working on Easel Biotechnologies
# Working on L-3 Communications Cincinnati Electronics Corporation
# Working on SunEdison Semiconductor Limited
# Working on IDEA TREE
# Working on Solarmer Energy
# Working on Braun Intertec Geothermal
# Working on Fuji Electric Co.
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.sg.fujielectric.com/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.fujielectric.com/fcs/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.ffec.co.jp/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.fujielectric.co.jp/technica/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.hoei-elec.co.jp/english/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.hfd.co.jp" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# ...
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://t.co/Cgc2sZNHWz" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://t.co/73LeYI7MNm" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://t.co/y6iw6WwaOM" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://t.co/TUBLf4GCwi" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://t.co/KKgcnLoQzx" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://t.co/d11nx0Yrgp" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://t.co/EBm3JDToo1" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://t.co/sJKSSrk6e7" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://t.co/0hO19ocuho" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://t.co/1vxU8c08MD" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://t.co/PrL85m4Dor" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# Working on National Education Corporation
# Working on NEWFIELD THERAPEUTICS CORPORATION
# Working on Northrop Grumman Systems Corporation
# Working on NetApp
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.netapp.com/us/index.aspx" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.netapp.com/us/media/infographic-5reasons-aiq.pdf" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.netapp.com/us/media/nva-1125-design.pdf" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.netapp.com/us/media/ar-idc-pmem-new-storage-tier.pdf" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.netapp.com/us/media/tr-4036.pdf" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.netapp.com/us/media/na-323.pdf" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.netapp.com/us/media/wp-7283.pdf" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.netapp.com/us/media/wp-7285.pdf" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.netapp.com/us/media/nva-1124-design.pdf" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.netapp.com/us/media/sb-3957.pdf" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.netapp.com/us/media/ds-3881.pdf" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.netapp.com/us/media/tr-4626.pdf" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.netapp.com/us/media/nva-1127-design.pdf" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.netapp.com/us/media/sb-3933.pdf" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.netapp.com/us/media/tr-4722.pdf" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.netapp.com/us/media/tr-4721.pdf" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.netapp.com/us/media/sb-3904.pdf" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.netapp.com/us/media/nva-1126-design.pdf" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.netapp.com/us/media/tr-4718.pdf" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.netapp.com/us/media/tr-4719.pdf" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://www.netapp.com/us/media/cs-multimedia.pdf" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# Working on Kronos International Inc
# /Users/sarora/anaconda2/lib/python2.7/site-packages/bs4/__init__.py:282: UserWarning: "https://community.kronos.com" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-86-92e8ba292d06> in <module>()
#       3 for firm_name in firm_names:
#       4     print ("Working on " + firm_name)
# ----> 5     firm_pages_dict, depth0_page_text = process_firm (firm_name)
#       6     # pp.pprint(depth0_page_text)
#       7     if depth0_page_text:
#
# <ipython-input-73-12343f896f76> in process_firm(firm_name)
#      30     firm_pages_dict = {}
#      31     depth0_page_text = [] # home page
# ---> 32     for result in results:
#      33         key = (result['url'])
#      34         if key:
#
# /Users/sarora/anaconda2/lib/python2.7/site-packages/pymongo/cursor.pyc in next(self)
#    1167         if self.__empty:
#    1168             raise StopIteration
# -> 1169         if len(self.__data) or self._refresh():
#    1170             if self.__manipulate:
#    1171                 _db = self.__collection.database
#
# /Users/sarora/anaconda2/lib/python2.7/site-packages/pymongo/cursor.pyc in _refresh(self)
#    1104                                         self.__collection.database.client,
#    1105                                         self.__max_await_time_ms)
# -> 1106                 self.__send_message(g)
#    1107
#    1108         return len(self.__data)
#
# /Users/sarora/anaconda2/lib/python2.7/site-packages/pymongo/cursor.pyc in __send_message(self, operation)
#     922             try:
#     923                 response = client._send_message_with_response(operation,
# --> 924                                                               **kwargs)
#     925                 self.__address = response.address
#     926                 if self.__exhaust:
#
# /Users/sarora/anaconda2/lib/python2.7/site-packages/pymongo/mongo_client.pyc in _send_message_with_response(self, operation, read_preference, exhaust, address)
#    1027             self.__all_credentials,
#    1028             self._event_listeners,
# -> 1029             exhaust)
#    1030
#    1031     def _reset_on_error(self, server, func, *args, **kwargs):
#
# /Users/sarora/anaconda2/lib/python2.7/site-packages/pymongo/mongo_client.pyc in _reset_on_error(self, server, func, *args, **kwargs)
#    1038         """
#    1039         try:
# -> 1040             return func(*args, **kwargs)
#    1041         except NetworkTimeout:
#    1042             # The socket has been closed. Don't reset the server.
#
# /Users/sarora/anaconda2/lib/python2.7/site-packages/pymongo/server.pyc in send_message_with_response(self, operation, set_slave_okay, all_credentials, listeners, exhaust)
#     104             try:
#     105                 sock_info.send_message(data, max_doc_size)
# --> 106                 reply = sock_info.receive_message(request_id)
#     107             except Exception as exc:
#     108                 if publish:
#
# /Users/sarora/anaconda2/lib/python2.7/site-packages/pymongo/pool.pyc in receive_message(self, request_id)
#     548                                    self.max_message_size)
#     549         except BaseException as error:
# --> 550             self._raise_connection_failure(error)
#     551
#     552     def legacy_write(self, request_id, msg, max_doc_size, with_last_error):
#
# /Users/sarora/anaconda2/lib/python2.7/site-packages/pymongo/pool.pyc in _raise_connection_failure(self, error)
#     675             _raise_connection_failure(self.address, error)
#     676         else:
# --> 677             raise error
#     678
#     679     def __eq__(self, other):
#
# KeyboardInterrupt:

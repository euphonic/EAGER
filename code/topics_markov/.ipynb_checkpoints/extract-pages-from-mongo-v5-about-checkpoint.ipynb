# %% [markdown]
# # extract-pages-from-mongo-v5
# SanjayKAroraPhD@gmail.com <br>
# December 2018
#
# ## Description
# This version of the notebook extracts groups of pages from mongodb by firm_name to create firm-centric <b>about</b> page output files that can later be topic modeled.  In doing so, it removes repetitive content (e.g., repeated menu items) and garbage content (e.g., improperly parsed HTML code).
#
# ## Change log
# v4 focuses on about pages
#
# ## TODO:
# * Whole process: get data, topic model and see if it looks sufficiently interesting/different
# * Enhance data collection, per the following:
#     * Select a region or country — WAIT
#         * http://www.ivoclarvivadent.com: Please select your region
#         * https://www.enersys.com/: PLEASE SELECT A REGION
#         * https://www.m-petfilm.com/: ENGLISH
#     * Crawl from focal about page only following links that look like part of the about story, maintaining ordering.  Check to see if the other links identified above are also there?
#         * http://xtalsolar.com/investors_partners.html
# * Order known about us pages in the same way the links are found on a home page or about us landing page

# %%
# import data processing and other libraries
import csv
import sys
import requests
import os
import re
import pprint
import pymongo
import traceback
from time import sleep
import requests
import pandas as pd
import io
from IPython.display import display
import time
import numpy as np
from bs4 import BeautifulSoup
import string
import random
from urllib.parse import urlparse, urljoin
from collections import defaultdict

# %%
from boilerpipe.extract import Extractor

# %%
# import sklearn
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_moons, make_circles, make_classification
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.model_selection import GroupKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix

# %%
# first figure out what is an about page. need to label training data
# identify features -- for right now, unigrams if just one word in the header, otherwise bi- or trigrams 
# predict about pages

# %%
MONGODB_DB = "FirmDB_20181226"
MONGODB_COLLECTION = "pages_ABOUT"
CONNECTION_STRING = "mongodb://localhost"

client = pymongo.MongoClient(CONNECTION_STRING)
db = client[MONGODB_DB]
col = db[MONGODB_COLLECTION]

ABOUT_DIR = '/Users/sarora/dev/EAGER/data/orgs/about/'
DATA_DIR = '/Users/sarora/dev/EAGER/data/orgs/depth0_boilerpipe/'
TRAINING_PERCENT = .10
pp = pprint.PrettyPrinter()

# %%
def get_domain (url):
    o = urlparse(url.lower())
    domain = o.netloc.strip('www.')
    return domain

# output urls for labeling of training data
results = col.find({},{"url": 1, "firm_name": 1})
df = pd.DataFrame(columns = ('firm_name', 'url', 'label'))
domain_count = defaultdict(lambda:0,{})
for i in range(results.count()):
    result = results.next()
    url = result['url'][0]
    domain_count[get_domain(url)] += 1
    firm_name = result['firm_name'][0] if 'firm_name' in result else ''
    df.loc[i] = [firm_name, url, '']
    
df['gid'] = df.groupby(['firm_name']).ngroup()

# %%
df.gid.nunique()
label_ids = random.sample(range(1, df.gid.nunique()), 200)
df_label = df[df['gid'].isin(label_ids)]
with open(ABOUT_DIR + 'about_pages_to_label.csv', mode='w') as to_label:
    df_label.to_csv(to_label, index=False)

# %%
# read back labeled data (note that about, management/team and partners, are dichotomous)
df_about_labeled = pd.read_csv(ABOUT_DIR + 'about_pages_labeled.csv')
df_about_labeled = df_about_labeled.fillna(0)

# count pages per domain
for index, row in df_about_labeled.iterrows():
    pages_in_domain = domain_count[get_domain(row['url'])]
    df_about_labeled.loc[index,'pages_in_domain'] = pages_in_domain
    is_sole_page = 0 if pages_in_domain > 1 else 1
    df_about_labeled.loc[index,'is_sole_page'] = is_sole_page
    
labeled_urls = list(df_about_labeled['url']) # for training models on labeled urls below
df_about_labeled = df_about_labeled.set_index(['firm_name', 'url'])
print (df_about_labeled.columns.tolist())

# final test set is the rows of the original data frame without the urls in df_about_labeled
# Out:
# ['about', 'mgmt', 'partners', 'gid', 'pages_in_domain', 'is_sole_page']

# %% [markdown]
# ## Create features to predict about pages
# Create features:
# 1. title and url path fragment unigrams (also tried n-grams, as well as content from headers, with worse results)
# 2. is home page and doesn't have any other pages
# 3. other ideas here: https://towardsdatascience.com/understanding-feature-engineering-part-3-traditional-methods-for-text-data-f6f7d70acd41

# %%
# load page data and create features

# remove simple article words and punctuation (need to keep 'about')
stop_words = ['the','a'] + list(string.punctuation) 
# remove known company names for model training and evaluation in the labeled data 
remove_regex = re.compile(r'^(3m|united|states|menu|en_us|algeternal|s\d+|sarepta|skygen|nexgen|abbott|adlens|errorpage|\d{1,3}|\d{5,}|\w+\d+|\d+\w+|asten|johnson|baker|hughes|ge|bhge|biocon|egfr|gcsf|biocon|pegfilgrastim|bostik|canon|chevron|phillips|coloplast|cyberonics|microsoft|evoqua|ford|hitachi|glucanbio|hunter|douglas|kimberly|clark|lextar|fisher|lockheed|martin |lux|nec|nanocopoeia|cisco|schlumberger|weccamerica|inanobio|nanocomposix|zoetis|zygo)$', re.IGNORECASE)
# used to filter top-level header content
header_in = re.compile('(about|company|corporate|who.we.are|(^|/)vision|profile|corporate|management|team|history|values|strategy|our |technology|research|commercialization)', flags=re.IGNORECASE)
header_regex = re.compile(r'h[1-9]+')

def clean_string(in_string):
    if not in_string:
        return in_string
    split_words = in_string.lower().split()
    result_words  = [word for word in split_words if word not in stop_words]
    result_words  = [word for word in result_words if not remove_regex.search(word)]
    result = ' '.join(result_words)
    return ' ' + result

def get_page_path_text (url):
    o = urlparse(url.lower())
    path = o.path
    path_parts = path.split ('/')
    path_parts = [part.split('.')[0] for part in path_parts] # remove page names
    path_parts = [split for part in path_parts for split in part.split('-') ] # split on underscores, hyphens, et al
    path_parts = [split for part in path_parts for split in part.split('_') ] # split on underscores, hyphens, et al
    clnd_string = clean_string(' '.join(path_parts))
    return clnd_string

# recurse through the header text to add into feature grams
def get_header_text (headers, names, index):
    texts = [clean_string(header.text) for header in headers if header.name == names[index]]
    texts = list(filter(header_in.search, texts))
    if texts and len(texts[0].split()) > 4:
        if(len(names) > (index + 1)):
            return get_header_text (headers, names, index + 1)
        else:
            return ''
    else: 
        return ' '.join (texts)
    
def process_firms (urls): 
    firm_page_features = {}
    for url in urls: 
        result = col.find_one({"url": url})
        domain = get_domain(url)
        html = result['html'][0]
        
        # print (url)

        soup = BeautifulSoup(html, 'lxml')
        running_text = ''
        path_text = get_page_path_text(url)
        
        if path_text:
            # print (path_text)
            running_text += path_text
            
        if soup.title and soup.title.string:
            # print (soup.title.string)
            running_text += clean_string(soup.title.string)
            
        headers = soup.find_all(header_regex, text=True)
        names = sorted(set ([header.name for header in headers]))
        running_text += get_header_text (headers, names, 0)

        firm_page_features[url] = running_text
        
    return firm_page_features

# %%
# for testing regex
print (get_page_path_text('http://www.google.com/path-en/path_to/page.html'))
print (re.split("\W+|_", "Testing this_thing"))
print (clean_string('3m 01	08	100	10m ford 235 1990 s129 188209 0913lk the ? about us'))
pp.pprint (list(filter(header_in.search, ['about us', 'not found', 'company'])))
# Out:
#  path en path to page
# ['Testing', 'this', 'thing']
#  about us
# ['about us', 'company']

# %%
# get firm website data for n-gram processing 
labeled_firm_page_features = process_firms (labeled_urls)

urls = labeled_firm_page_features.keys()
print (len(urls))
corpus = []
for url in urls:
    corpus.append (labeled_firm_page_features[url])
    
# unigram
ubv = TfidfVectorizer(min_df=0., max_df=1.)
# you can set the n-gram range to 1,2 to get unigrams as well as bigrams (performs worse than just unigrams)
# ubv = TfidfVectorizer(ngram_range=(3,3)) 

ubv_matrix = ubv.fit_transform(corpus)

ubv_matrix = ubv_matrix.toarray()
vocab = ubv.get_feature_names()
ubv_df = pd.DataFrame(ubv_matrix, columns=vocab)
ubv_df.index = urls
ubv_df.index.name='url'
# Out:
# 1031

# %%
# merge two datasets (features and labeled data)
print(ubv_df.shape)
print(df_about_labeled.shape)

print (ubv_df.index.name)
print (df_about_labeled.index.name)

all_merged = ubv_df.join(df_about_labeled, how='inner', rsuffix='_lbl')
print(all_merged.shape)
# Out:
# (1031, 1472)
# (1031, 6)
# url
# None
# (1031, 1478)

# %%
# split labeled and predict datasets 
labeled = all_merged[all_merged['gid'].notnull()]
print(labeled.shape)
print (df_about_labeled.columns.tolist())
# Out:
# (1031, 1478)
# ['about', 'mgmt', 'partners', 'gid', 'pages_in_domain', 'is_sole_page']

# %%
# labeled train/test split
X = labeled.iloc[:,1:len(ubv_df.columns)]
X['pages_in_domain'] = labeled['pages_in_domain']
X['is_sole_page'] = labeled['is_sole_page']
X.to_csv(ABOUT_DIR + 'X.csv', index = True) # for manual inspection

y = labeled.loc[:,'about_lbl']

# %% [markdown]
# ## Train and evaluate the model
# On just the labeled data

# %%
# specify a few models

names = ["Nearest Neighbors", "Linear SVM", "RBF SVM", 
         "Decision Tree", "Random Forest", "Neural Net", "AdaBoost",
         "Naive Bayes", "SVC", "QDA"]

classifiers = [
    KNeighborsClassifier(3),
    SVC(kernel="linear", C=0.025),
    SVC(gamma=2, C=1),
    DecisionTreeClassifier(max_depth=5),
    RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1),
    MLPClassifier(alpha=1),
    AdaBoostClassifier(),
    GaussianNB(),
    SVC(gamma=0.001, C=100.), 
    QuadraticDiscriminantAnalysis()]

# %%
# build dataframe for output metrics 
eval_df = pd.DataFrame (names,index=(range(len(names))), columns=["Name"])
eval_df['Accuracy'] = np.float64(0)
display (eval_df)
# Out:
#                 Name  Accuracy
# 0  Nearest Neighbors       0.0
# 1         Linear SVM       0.0
# 2            RBF SVM       0.0
# 3      Decision Tree       0.0
# 4      Random Forest       0.0
# 5         Neural Net       0.0
# 6           AdaBoost       0.0
# 7        Naive Bayes       0.0
# 8                SVC       0.0
# 9                QDA       0.0

# %%
# build evaluation outputs (currently limited to accuracy)
i = np.int64(0)
for name, clf in zip(names, classifiers):
    display (name)
    scores = cross_val_score(clf, X, y)
    avg_score = np.mean(scores)
    eval_df.set_value(i, 'Accuracy', avg_score)
    i = i + 1
    
display(eval_df)
eval_df.to_clipboard()
# Out:
# 'Nearest Neighbors'
# /usr/local/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   import sys
# 'Linear SVM'
# /usr/local/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   import sys
# 'RBF SVM'
# /usr/local/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   import sys
# 'Decision Tree'
# /usr/local/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   import sys
# 'Random Forest'
# /usr/local/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   import sys
# 'Neural Net'
# /usr/local/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /usr/local/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:562: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   import sys
# 'AdaBoost'
# /usr/local/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   import sys
# 'Naive Bayes'
# /usr/local/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   import sys
# 'SVC'
# /usr/local/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   import sys
# 'QDA'
# /usr/local/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /usr/local/lib/python3.6/site-packages/sklearn/discriminant_analysis.py:692: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /usr/local/lib/python3.6/site-packages/sklearn/discriminant_analysis.py:692: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /usr/local/lib/python3.6/site-packages/sklearn/discriminant_analysis.py:692: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   import sys
#                 Name  Accuracy
# 0  Nearest Neighbors  0.681875
# 1         Linear SVM  0.647918
# 2            RBF SVM  0.700328
# 3      Decision Tree  0.758491
# 4      Random Forest  0.646946
# 5         Neural Net  0.839966
# 6           AdaBoost  0.816721
# 7        Naive Bayes  0.659557
# 8                SVC  0.798251
# 9                QDA  0.489900

# %% [markdown]
# ## Grid search using MLPClassifier to tune hyperparameter

# %%
hls = []
hls.append([100,])
hls.append([70,70,70])
hls.append([40,40,40])
hls.append([10,10,10])
pp.pprint(hls)
# Out:
# [[100], [70, 70, 70], [40, 40, 40], [10, 10, 10]]

# %%
parameters = {'solver': ['lbfgs'], 'max_iter': [300,500,700], 'alpha': 10.0 ** -np.arange(5, 10), 'hidden_layer_sizes': hls, 'random_state':[5,10,15]}
clf_grid = GridSearchCV(MLPClassifier(), parameters, n_jobs=-1)
clf_grid.fit(X,y)

print("Best score: %0.4f" % clf_grid.best_score_)
print("Using the following parameters:")
print(clf_grid.best_params_)
# Out:
# /usr/local/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# Best score: 0.8555
# Using the following parameters:
# {'alpha': 1e-09, 'hidden_layer_sizes': [70, 70, 70], 'max_iter': 300, 'random_state': 5, 'solver': 'lbfgs'}

# %%
# train neural net model with best hyperparameter configuration
clf = MLPClassifier(alpha=0.0000001, hidden_layer_sizes=(70,70,70), max_iter=300, random_state=5, solver='lbfgs')
clf.fit(X, y)

y_hat = clf.predict(X)

# %%
# print all instances where predictions don't match labels (for inspection)
confusion_matrix(y, y_hat)

for key, y_i, y_hat_i in zip(list(X.index), y, y_hat):
    if y_i != y_hat_i:
        print(key[1], 'has been classified as ', y_hat_i, 'but should be ', y_i)
# Out:
# http://acaciaresearch.com/history/ has been classified as  1.0 but should be  0.0
# https://www.asml.com/company/company-calendar/en/s32775 has been classified as  1.0 but should be  0.0
# https://allisontransmission.com/company/history-heritage has been classified as  1.0 but should be  0.0
# https://www.shire.com/who-we-are/areas-of-focus has been classified as  0.0 but should be  1.0
# https://www.shire.com/who-we-are/responsibility has been classified as  0.0 but should be  1.0
# http://www.brightleafpower.com/innovation/ has been classified as  0.0 but should be  1.0
# http://www.agcbio.com/about/environmental_policy has been classified as  0.0 but should be  1.0
# https://www.cadence.com/content/cadence-www/global/en_US/home/company/customers.html has been classified as  1.0 but should be  0.0
# https://global.canon/en/corporate/ has been classified as  0.0 but should be  1.0
# https://www.christiedigital.com/en-us/about-christie has been classified as  0.0 but should be  1.0
# https://www.coloplast.us/about-us/ has been classified as  0.0 but should be  1.0
# https://www.coriant.com/company has been classified as  0.0 but should be  1.0
# https://livanova.cyberonics.com/about/corporate-compliance has been classified as  1.0 but should be  0.0
# https://livanova.cyberonics.com/about/corporate-governance has been classified as  1.0 but should be  0.0
# https://www.leonardodrs.com/about-us/thought-leadership/ has been classified as  0.0 but should be  1.0
# http://www.deltaww.com/about/brand.aspx?secID=5&pid=2&tid=0&hl=en-US has been classified as  1.0 but should be  0.0
# https://www.dialogic.com/about-us has been classified as  0.0 but should be  1.0
# https://www.eni.com/en_IT/investors/risk-management.page has been classified as  0.0 but should be  1.0
# http://ecovativedesign.com/ has been classified as  0.0 but should be  1.0
# https://www.westerndigital.com/company/innovations has been classified as  1.0 but should be  0.0
# http://hiqsolar.com/contact-us.html has been classified as  0.0 but should be  1.0
# https://utcaerospacesystems.com/join-the-utc-team/ has been classified as  0.0 but should be  1.0
# http://imds-ohio.com/AboutUs/Corp_Gov/ has been classified as  1.0 but should be  0.0
# https://www.infineum.com/en/about-us/safety/ has been classified as  0.0 but should be  1.0
# https://www.infineum.com/en/careers/our-teams/ has been classified as  0.0 but should be  1.0
# http://www.nmm.jx-group.co.jp/english/company/group/group_01.html has been classified as  1.0 but should be  0.0
# http://www.kaneka.co.jp/en/corporate/policy/ has been classified as  1.0 but should be  0.0
# http://www.kaneka.co.jp/en/corporate/ has been classified as  0.0 but should be  1.0
# http://www.kaneka.co.jp/en/corporate/director/ has been classified as  0.0 but should be  1.0
# http://www.kaneka.co.jp/en/corporate/chronicle/ has been classified as  1.0 but should be  0.0
# https://www.kashivpharma.com/about/people-management/ has been classified as  0.0 but should be  1.0
# https://www.kimberly-clark.com/en-us/company/employees has been classified as  0.0 but should be  1.0
# http://www.kureha.co.jp/en/about/challenge/philosophy.html has been classified as  1.0 but should be  0.0
# http://lextar.com/?sn=93&lang=en-US has been classified as  0.0 but should be  1.0
# https://lockheedmartin.com/en-us/who-we-are/international.html has been classified as  0.0 but should be  1.0
# https://www.nano-lab.com/aboutdefault.html has been classified as  0.0 but should be  1.0
# https://nanocopoeia.com/ has been classified as  1.0 but should be  0.0
# http://nano.com/ has been classified as  1.0 but should be  0.0
# http://www.nanosysinc.com/ has been classified as  1.0 but should be  0.0
# https://www.neb.com/about-neb/environmental-commitment has been classified as  1.0 but should be  0.0
# https://www.neb.com/about-neb/quality-at-neb has been classified as  1.0 but should be  0.0
# https://www.neb.com/about-neb/passion-in-science-awards has been classified as  1.0 but should be  0.0
# http://www.northropgrumman.com/AboutUs/OurHeritage/Pages/default.aspx has been classified as  0.0 but should be  1.0
# https://www.oki.com/en/profile/info/manage.html has been classified as  1.0 but should be  0.0
# https://www.paccar.com/about-us/philanthropy/ has been classified as  1.0 but should be  0.0
# https://www.phoseon.com/about-industrial-curing has been classified as  1.0 but should be  0.0
# http://www.reynoldstechnology.biz/company-butted-steel-tubing/our-people/ has been classified as  1.0 but should be  0.0
# http://www.reynoldstechnology.biz/company-butted-steel-tubing/register-for-updates/ has been classified as  1.0 but should be  0.0
# https://displaysolutions.samsung.com/industries/corporate has been classified as  0.0 but should be  1.0
# http://www.spil.com.tw/about/?u=1*2 has been classified as  1.0 but should be  0.0
# https://www.sjm.com/en/about?clset=af584191-45c9-4201-8740-5409f4cf8bdd%3ab20716c1-c2a6-4e4c-844b-d0dd6899eb3a has been classified as  0.0 but should be  1.0
# http://taiyo-hd.co.jp/en/group/thou/ has been classified as  0.0 but should be  1.0
# https://www.takeda.com/who-we-are/corporate-governance/ has been classified as  0.0 but should be  1.0
# https://www.takeda.com/who-we-are/how-we-work/ has been classified as  1.0 but should be  0.0
# https://www.tel.com/about/cg/ has been classified as  0.0 but should be  1.0
# https://www.tel.com/about/message/ has been classified as  1.0 but should be  0.0
# https://www.tel.com/about/locations/ has been classified as  1.0 but should be  0.0
# https://www.tel.com/about/ptc/ has been classified as  0.0 but should be  1.0
# https://www.tuftsmedicalcenter.org/About-Us/Quality-and-Safety has been classified as  1.0 but should be  0.0
# https://www.zenosemi.com has been classified as  0.0 but should be  1.0

# %% [markdown]
# ## Predict about pages for unlabeled data

# %%
# prepare domain level features 
df_predict = df[~df['url'].isin(labeled_urls)] # careful: index is firm_name and url now
# count pages per domain
for index, row in df_predict.iterrows():
    pages_in_domain = domain_count[get_domain(row['url'])]
    df_predict.loc[index,'pages_in_domain'] = pages_in_domain
    is_sole_page = 0 if pages_in_domain > 1 else 1
    df_predict.loc[index,'is_sole_page'] = is_sole_page
    
# set index 
df_predict = df_predict.set_index(['firm_name', 'url'])
print (df_predict.columns.tolist())
# Out:
# ['label', 'gid', 'pages_in_domain', 'is_sole_page']

# %%
# check to see whether there are duplicate urls
# note: there should be because different assignees may map to the same domain (see error above)
import collections
counter=collections.Counter(df_predict.index)
most_common = counter.most_common(10)
pp.pprint (most_common)
# Out:
# [(('Mitsubishi Metal Corporation',
#    'https://www.mitsubishicorp.com/jp/en/about/plan/'),
#   1),
#  (('22nd Century Limited', 'http://www.xxiicentury.com/history/'), 1),
#  (('Mitsubishi Metal Corporation',
#    'https://www.mitsubishicorp.com/jp/en/about/global/'),
#   1),
#  (('Mitsubishi Metal Corporation',
#    'https://www.mitsubishicorp.com/jp/en/about/message/'),
#   1),
#  (('Forest Concepts', 'http://forestconcepts.com/index.php?page=01002'), 1),
#  (('ZENA TECHNOLOGIES', 'http://xena-technologies.com/program-management/'), 1),
#  (('Kansai Paint Co.', 'https://www.kansai.com/about-us/corporate_data.html'),
#   1),
#  (('W&Wsens Devices', 'https://www.wwsensdevices.com/'), 1),
#  (('Kansai Paint Co.', 'https://www.kansai.com/about-us/brand.html'), 1),
#  (('Kansai Paint Co.', 'https://www.kansai.com/about-us/'), 1)]

# %%
# prepare n-gram features
unlabeled_firm_page_features = process_firms (set(df_predict.index.get_level_values('url')))

prediction_urls = unlabeled_firm_page_features.keys()

pred_corpus = []
for url in prediction_urls:
    pred_corpus.append (unlabeled_firm_page_features[url])

ubv_prediction_matrix = ubv.transform(pred_corpus)

ubv_prediction_matrix = ubv_prediction_matrix.toarray()
vocab = ubv.get_feature_names()
ubv_prediction_df = pd.DataFrame(ubv_prediction_matrix, columns=vocab)
ubv_prediction_df.index = prediction_urls
ubv_prediction_df.index.name='url'

# %%
print(ubv_prediction_df.shape)
print(df_predict.shape)

predict_merged = ubv_prediction_df.join(df_predict, how='right', rsuffix='_lbl')
print(predict_merged.shape)

# merge
X_test = predict_merged.iloc[:,1:len(ubv_prediction_df.columns)]
X_test['pages_in_domain'] = predict_merged['pages_in_domain']
X_test['is_sole_page'] = predict_merged['is_sole_page']
print (X.shape)
print (X_test.shape) # should be the same number of cols

X_test
# Out:
# (4147, 1472)
# (4516, 4)
# (4516, 1476)
# (1031, 1473)
# (4516, 1473)
#                                                                                                  10m  \
# firm_name                                    url
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/plan/    0.0
# 22nd Century Limited                         http://www.xxiicentury.com/history/                 0.0
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/global/  0.0
#                                              https://www.mitsubishicorp.com/jp/en/about/mess...  0.0
# Forest Concepts                              http://forestconcepts.com/index.php?page=01002      0.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/program-management/    0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/corporate_data....  0.0
# W&Wsens Devices                              https://www.wwsensdevices.com/                      0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/brand.html          0.0
#                                              https://www.kansai.com/about-us/                    0.0
# Xintec Inc.                                  http://www.xintec.com.tw/eng/CSR_Corporate_Gove...  0.0
# k-Space Associates                           https://www.k-space.com/company/distributors/       0.0
# Amkor Technology                             https://amkor.com/company-history/                  0.0
#                                              https://amkor.com/technology/system-in-package/     0.0
# Wine.com                                     https://www.wine.com/content/landing/corporate-...  0.0
# Industrial Technology Research Institute     https://www.itri.org.tw/eng/Content/Management/...  0.0
# Vizio Inc.                                   https://www.vizio.com/about                         0.0
# Midrex Technologies                          https://midrex.com/company-info/history             0.0
# VMware                                       https://www.vmware.com/company/leadership.html      0.0
#                                              https://www.vmware.com/company/innovation.html      0.0
# VEECO PRECISION SURFACE PROCESSING LLC       http://www.veeco.com/company                        0.0
# ABB AB                                       https://new.abb.com/network-management              0.0
# VMware                                       https://www.vmware.com/company/foundation.html      0.0
# ABB AB                                       https://new.abb.com/about                           0.0
#                                              https://new.abb.com/cpm                             0.0
# DuPont Teijin Films U.S. Limited Partnership https://usa.dupontteijinfilms.com/about/            0.0
# Vaxiion Therapeutics                         http://www.vaxiion.com/executive-management.html    0.0
#                                              http://www.vaxiion.com/the-company.html             0.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/                       0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/history.html        0.0
# ...                                                                                              ...
# Ormat Technologies Inc.                      https://www.ormat.com/en/company/general/view/?...  0.0
# Gram Power                                   https://grampower.com/about-us/our-team.html        0.0
# SAINT-GOBAIN ABRASIFS                        https://www.saint-gobain-abrasives.com/en-us/pr...  0.0
# Ormat Technologies Inc.                      https://www.ormat.com/en/company/general/view/?...  0.0
# Lintec Corporation                           http://www.lintec-global.com/about/message/         0.0
#                                              http://www.lintec-global.com/about/history/         0.0
# Angaza Design                                https://www.angaza.com/about/                       0.0
# Lintec Corporation                           http://www.lintec-global.com/ir/management/         0.0
#                                              http://www.lintec-global.com/about/brochure/book/   0.0
# Kulite Semiconductor Products                https://www.kulite.com/company/news/                0.0
# Lintec Corporation                           http://www.lintec-global.com/about/country/amer...  0.0
#                                              http://www.lintec-global.com/about/network/         0.0
# Kulite Semiconductor Products                https://www.kulite.com/company/contact-info/        0.0
#                                              https://www.kulite.com/company/customer-resources/  0.0
#                                              https://www.kulite.com/company/corporate-respon...  0.0
#                                              https://www.kulite.com/company/supplier-code-of...  0.0
# Bend Research                                https://www.capsugel.com/about-capsugel             0.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news                    0.0
#                                              http://pidc.com/our-company/locations               0.0
# Valicor                                      http://trucent.com/                                 0.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news/pacific-indust...  0.0
# SOLAZYME                                     http://solazyme.com/                                0.0
# Starlight Energy Holdings LLC                http://www.starlightenergy.us/                      0.0
# Solight Solar                                http://www.solight.com/                             0.0
# ZON                                          https://www.zon.si/                                 0.0
# Ostendo Technologies                         https://www.ostendo.com/                            0.0
# Quantapore                                   https://quantapore.com/                             0.0
# Synaptic Research                            https://research.synaptic.co.uk/SynapticResearc...  0.0
# Sun Drilling Products Corporation            https://www.sunspecialtyproducts.com/               0.0
# MEDport                                      https://medport.com/                                0.0
#
#                                                                                                  13485  \
# firm_name                                    url
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/plan/      0.0
# 22nd Century Limited                         http://www.xxiicentury.com/history/                   0.0
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/global/    0.0
#                                              https://www.mitsubishicorp.com/jp/en/about/mess...    0.0
# Forest Concepts                              http://forestconcepts.com/index.php?page=01002        0.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/program-management/      0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/corporate_data....    0.0
# W&Wsens Devices                              https://www.wwsensdevices.com/                        0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/brand.html            0.0
#                                              https://www.kansai.com/about-us/                      0.0
# Xintec Inc.                                  http://www.xintec.com.tw/eng/CSR_Corporate_Gove...    0.0
# k-Space Associates                           https://www.k-space.com/company/distributors/         0.0
# Amkor Technology                             https://amkor.com/company-history/                    0.0
#                                              https://amkor.com/technology/system-in-package/       0.0
# Wine.com                                     https://www.wine.com/content/landing/corporate-...    0.0
# Industrial Technology Research Institute     https://www.itri.org.tw/eng/Content/Management/...    0.0
# Vizio Inc.                                   https://www.vizio.com/about                           0.0
# Midrex Technologies                          https://midrex.com/company-info/history               0.0
# VMware                                       https://www.vmware.com/company/leadership.html        0.0
#                                              https://www.vmware.com/company/innovation.html        0.0
# VEECO PRECISION SURFACE PROCESSING LLC       http://www.veeco.com/company                          0.0
# ABB AB                                       https://new.abb.com/network-management                0.0
# VMware                                       https://www.vmware.com/company/foundation.html        0.0
# ABB AB                                       https://new.abb.com/about                             0.0
#                                              https://new.abb.com/cpm                               0.0
# DuPont Teijin Films U.S. Limited Partnership https://usa.dupontteijinfilms.com/about/              0.0
# Vaxiion Therapeutics                         http://www.vaxiion.com/executive-management.html      0.0
#                                              http://www.vaxiion.com/the-company.html               0.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/                         0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/history.html          0.0
# ...                                                                                                ...
# Ormat Technologies Inc.                      https://www.ormat.com/en/company/general/view/?...    0.0
# Gram Power                                   https://grampower.com/about-us/our-team.html          0.0
# SAINT-GOBAIN ABRASIFS                        https://www.saint-gobain-abrasives.com/en-us/pr...    0.0
# Ormat Technologies Inc.                      https://www.ormat.com/en/company/general/view/?...    0.0
# Lintec Corporation                           http://www.lintec-global.com/about/message/           0.0
#                                              http://www.lintec-global.com/about/history/           0.0
# Angaza Design                                https://www.angaza.com/about/                         0.0
# Lintec Corporation                           http://www.lintec-global.com/ir/management/           0.0
#                                              http://www.lintec-global.com/about/brochure/book/     0.0
# Kulite Semiconductor Products                https://www.kulite.com/company/news/                  0.0
# Lintec Corporation                           http://www.lintec-global.com/about/country/amer...    0.0
#                                              http://www.lintec-global.com/about/network/           0.0
# Kulite Semiconductor Products                https://www.kulite.com/company/contact-info/          0.0
#                                              https://www.kulite.com/company/customer-resources/    0.0
#                                              https://www.kulite.com/company/corporate-respon...    0.0
#                                              https://www.kulite.com/company/supplier-code-of...    0.0
# Bend Research                                https://www.capsugel.com/about-capsugel               0.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news                      0.0
#                                              http://pidc.com/our-company/locations                 0.0
# Valicor                                      http://trucent.com/                                   0.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news/pacific-indust...    0.0
# SOLAZYME                                     http://solazyme.com/                                  0.0
# Starlight Energy Holdings LLC                http://www.starlightenergy.us/                        0.0
# Solight Solar                                http://www.solight.com/                               0.0
# ZON                                          https://www.zon.si/                                   0.0
# Ostendo Technologies                         https://www.ostendo.com/                              0.0
# Quantapore                                   https://quantapore.com/                               0.0
# Synaptic Research                            https://research.synaptic.co.uk/SynapticResearc...    0.0
# Sun Drilling Products Corporation            https://www.sunspecialtyproducts.com/                 0.0
# MEDport                                      https://medport.com/                                  0.0
#
#                                                                                                  14001  \
# firm_name                                    url
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/plan/      0.0
# 22nd Century Limited                         http://www.xxiicentury.com/history/                   0.0
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/global/    0.0
#                                              https://www.mitsubishicorp.com/jp/en/about/mess...    0.0
# Forest Concepts                              http://forestconcepts.com/index.php?page=01002        0.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/program-management/      0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/corporate_data....    0.0
# W&Wsens Devices                              https://www.wwsensdevices.com/                        0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/brand.html            0.0
#                                              https://www.kansai.com/about-us/                      0.0
# Xintec Inc.                                  http://www.xintec.com.tw/eng/CSR_Corporate_Gove...    0.0
# k-Space Associates                           https://www.k-space.com/company/distributors/         0.0
# Amkor Technology                             https://amkor.com/company-history/                    0.0
#                                              https://amkor.com/technology/system-in-package/       0.0
# Wine.com                                     https://www.wine.com/content/landing/corporate-...    0.0
# Industrial Technology Research Institute     https://www.itri.org.tw/eng/Content/Management/...    0.0
# Vizio Inc.                                   https://www.vizio.com/about                           0.0
# Midrex Technologies                          https://midrex.com/company-info/history               0.0
# VMware                                       https://www.vmware.com/company/leadership.html        0.0
#                                              https://www.vmware.com/company/innovation.html        0.0
# VEECO PRECISION SURFACE PROCESSING LLC       http://www.veeco.com/company                          0.0
# ABB AB                                       https://new.abb.com/network-management                0.0
# VMware                                       https://www.vmware.com/company/foundation.html        0.0
# ABB AB                                       https://new.abb.com/about                             0.0
#                                              https://new.abb.com/cpm                               0.0
# DuPont Teijin Films U.S. Limited Partnership https://usa.dupontteijinfilms.com/about/              0.0
# Vaxiion Therapeutics                         http://www.vaxiion.com/executive-management.html      0.0
#                                              http://www.vaxiion.com/the-company.html               0.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/                         0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/history.html          0.0
# ...                                                                                                ...
# Ormat Technologies Inc.                      https://www.ormat.com/en/company/general/view/?...    0.0
# Gram Power                                   https://grampower.com/about-us/our-team.html          0.0
# SAINT-GOBAIN ABRASIFS                        https://www.saint-gobain-abrasives.com/en-us/pr...    0.0
# Ormat Technologies Inc.                      https://www.ormat.com/en/company/general/view/?...    0.0
# Lintec Corporation                           http://www.lintec-global.com/about/message/           0.0
#                                              http://www.lintec-global.com/about/history/           0.0
# Angaza Design                                https://www.angaza.com/about/                         0.0
# Lintec Corporation                           http://www.lintec-global.com/ir/management/           0.0
#                                              http://www.lintec-global.com/about/brochure/book/     0.0
# Kulite Semiconductor Products                https://www.kulite.com/company/news/                  0.0
# Lintec Corporation                           http://www.lintec-global.com/about/country/amer...    0.0
#                                              http://www.lintec-global.com/about/network/           0.0
# Kulite Semiconductor Products                https://www.kulite.com/company/contact-info/          0.0
#                                              https://www.kulite.com/company/customer-resources/    0.0
#                                              https://www.kulite.com/company/corporate-respon...    0.0
#                                              https://www.kulite.com/company/supplier-code-of...    0.0
# Bend Research                                https://www.capsugel.com/about-capsugel               0.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news                      0.0
#                                              http://pidc.com/our-company/locations                 0.0
# Valicor                                      http://trucent.com/                                   0.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news/pacific-indust...    0.0
# SOLAZYME                                     http://solazyme.com/                                  0.0
# Starlight Energy Holdings LLC                http://www.starlightenergy.us/                        0.0
# Solight Solar                                http://www.solight.com/                               0.0
# ZON                                          https://www.zon.si/                                   0.0
# Ostendo Technologies                         https://www.ostendo.com/                              0.0
# Quantapore                                   https://quantapore.com/                               0.0
# Synaptic Research                            https://research.synaptic.co.uk/SynapticResearc...    0.0
# Sun Drilling Products Corporation            https://www.sunspecialtyproducts.com/                 0.0
# MEDport                                      https://medport.com/                                  0.0
#
#                                                                                                  1870s  \
# firm_name                                    url
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/plan/      0.0
# 22nd Century Limited                         http://www.xxiicentury.com/history/                   0.0
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/global/    0.0
#                                              https://www.mitsubishicorp.com/jp/en/about/mess...    0.0
# Forest Concepts                              http://forestconcepts.com/index.php?page=01002        0.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/program-management/      0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/corporate_data....    0.0
# W&Wsens Devices                              https://www.wwsensdevices.com/                        0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/brand.html            0.0
#                                              https://www.kansai.com/about-us/                      0.0
# Xintec Inc.                                  http://www.xintec.com.tw/eng/CSR_Corporate_Gove...    0.0
# k-Space Associates                           https://www.k-space.com/company/distributors/         0.0
# Amkor Technology                             https://amkor.com/company-history/                    0.0
#                                              https://amkor.com/technology/system-in-package/       0.0
# Wine.com                                     https://www.wine.com/content/landing/corporate-...    0.0
# Industrial Technology Research Institute     https://www.itri.org.tw/eng/Content/Management/...    0.0
# Vizio Inc.                                   https://www.vizio.com/about                           0.0
# Midrex Technologies                          https://midrex.com/company-info/history               0.0
# VMware                                       https://www.vmware.com/company/leadership.html        0.0
#                                              https://www.vmware.com/company/innovation.html        0.0
# VEECO PRECISION SURFACE PROCESSING LLC       http://www.veeco.com/company                          0.0
# ABB AB                                       https://new.abb.com/network-management                0.0
# VMware                                       https://www.vmware.com/company/foundation.html        0.0
# ABB AB                                       https://new.abb.com/about                             0.0
#                                              https://new.abb.com/cpm                               0.0
# DuPont Teijin Films U.S. Limited Partnership https://usa.dupontteijinfilms.com/about/              0.0
# Vaxiion Therapeutics                         http://www.vaxiion.com/executive-management.html      0.0
#                                              http://www.vaxiion.com/the-company.html               0.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/                         0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/history.html          0.0
# ...                                                                                                ...
# Ormat Technologies Inc.                      https://www.ormat.com/en/company/general/view/?...    0.0
# Gram Power                                   https://grampower.com/about-us/our-team.html          0.0
# SAINT-GOBAIN ABRASIFS                        https://www.saint-gobain-abrasives.com/en-us/pr...    0.0
# Ormat Technologies Inc.                      https://www.ormat.com/en/company/general/view/?...    0.0
# Lintec Corporation                           http://www.lintec-global.com/about/message/           0.0
#                                              http://www.lintec-global.com/about/history/           0.0
# Angaza Design                                https://www.angaza.com/about/                         0.0
# Lintec Corporation                           http://www.lintec-global.com/ir/management/           0.0
#                                              http://www.lintec-global.com/about/brochure/book/     0.0
# Kulite Semiconductor Products                https://www.kulite.com/company/news/                  0.0
# Lintec Corporation                           http://www.lintec-global.com/about/country/amer...    0.0
#                                              http://www.lintec-global.com/about/network/           0.0
# Kulite Semiconductor Products                https://www.kulite.com/company/contact-info/          0.0
#                                              https://www.kulite.com/company/customer-resources/    0.0
#                                              https://www.kulite.com/company/corporate-respon...    0.0
#                                              https://www.kulite.com/company/supplier-code-of...    0.0
# Bend Research                                https://www.capsugel.com/about-capsugel               0.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news                      0.0
#                                              http://pidc.com/our-company/locations                 0.0
# Valicor                                      http://trucent.com/                                   0.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news/pacific-indust...    0.0
# SOLAZYME                                     http://solazyme.com/                                  0.0
# Starlight Energy Holdings LLC                http://www.starlightenergy.us/                        0.0
# Solight Solar                                http://www.solight.com/                               0.0
# ZON                                          https://www.zon.si/                                   0.0
# Ostendo Technologies                         https://www.ostendo.com/                              0.0
# Quantapore                                   https://quantapore.com/                               0.0
# Synaptic Research                            https://research.synaptic.co.uk/SynapticResearc...    0.0
# Sun Drilling Products Corporation            https://www.sunspecialtyproducts.com/                 0.0
# MEDport                                      https://medport.com/                                  0.0
#
#                                                                                                  1910s  \
# firm_name                                    url
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/plan/      0.0
# 22nd Century Limited                         http://www.xxiicentury.com/history/                   0.0
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/global/    0.0
#                                              https://www.mitsubishicorp.com/jp/en/about/mess...    0.0
# Forest Concepts                              http://forestconcepts.com/index.php?page=01002        0.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/program-management/      0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/corporate_data....    0.0
# W&Wsens Devices                              https://www.wwsensdevices.com/                        0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/brand.html            0.0
#                                              https://www.kansai.com/about-us/                      0.0
# Xintec Inc.                                  http://www.xintec.com.tw/eng/CSR_Corporate_Gove...    0.0
# k-Space Associates                           https://www.k-space.com/company/distributors/         0.0
# Amkor Technology                             https://amkor.com/company-history/                    0.0
#                                              https://amkor.com/technology/system-in-package/       0.0
# Wine.com                                     https://www.wine.com/content/landing/corporate-...    0.0
# Industrial Technology Research Institute     https://www.itri.org.tw/eng/Content/Management/...    0.0
# Vizio Inc.                                   https://www.vizio.com/about                           0.0
# Midrex Technologies                          https://midrex.com/company-info/history               0.0
# VMware                                       https://www.vmware.com/company/leadership.html        0.0
#                                              https://www.vmware.com/company/innovation.html        0.0
# VEECO PRECISION SURFACE PROCESSING LLC       http://www.veeco.com/company                          0.0
# ABB AB                                       https://new.abb.com/network-management                0.0
# VMware                                       https://www.vmware.com/company/foundation.html        0.0
# ABB AB                                       https://new.abb.com/about                             0.0
#                                              https://new.abb.com/cpm                               0.0
# DuPont Teijin Films U.S. Limited Partnership https://usa.dupontteijinfilms.com/about/              0.0
# Vaxiion Therapeutics                         http://www.vaxiion.com/executive-management.html      0.0
#                                              http://www.vaxiion.com/the-company.html               0.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/                         0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/history.html          0.0
# ...                                                                                                ...
# Ormat Technologies Inc.                      https://www.ormat.com/en/company/general/view/?...    0.0
# Gram Power                                   https://grampower.com/about-us/our-team.html          0.0
# SAINT-GOBAIN ABRASIFS                        https://www.saint-gobain-abrasives.com/en-us/pr...    0.0
# Ormat Technologies Inc.                      https://www.ormat.com/en/company/general/view/?...    0.0
# Lintec Corporation                           http://www.lintec-global.com/about/message/           0.0
#                                              http://www.lintec-global.com/about/history/           0.0
# Angaza Design                                https://www.angaza.com/about/                         0.0
# Lintec Corporation                           http://www.lintec-global.com/ir/management/           0.0
#                                              http://www.lintec-global.com/about/brochure/book/     0.0
# Kulite Semiconductor Products                https://www.kulite.com/company/news/                  0.0
# Lintec Corporation                           http://www.lintec-global.com/about/country/amer...    0.0
#                                              http://www.lintec-global.com/about/network/           0.0
# Kulite Semiconductor Products                https://www.kulite.com/company/contact-info/          0.0
#                                              https://www.kulite.com/company/customer-resources/    0.0
#                                              https://www.kulite.com/company/corporate-respon...    0.0
#                                              https://www.kulite.com/company/supplier-code-of...    0.0
# Bend Research                                https://www.capsugel.com/about-capsugel               0.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news                      0.0
#                                              http://pidc.com/our-company/locations                 0.0
# Valicor                                      http://trucent.com/                                   0.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news/pacific-indust...    0.0
# SOLAZYME                                     http://solazyme.com/                                  0.0
# Starlight Energy Holdings LLC                http://www.starlightenergy.us/                        0.0
# Solight Solar                                http://www.solight.com/                               0.0
# ZON                                          https://www.zon.si/                                   0.0
# Ostendo Technologies                         https://www.ostendo.com/                              0.0
# Quantapore                                   https://quantapore.com/                               0.0
# Synaptic Research                            https://research.synaptic.co.uk/SynapticResearc...    0.0
# Sun Drilling Products Corporation            https://www.sunspecialtyproducts.com/                 0.0
# MEDport                                      https://medport.com/                                  0.0
#
#                                                                                                  1920s  \
# firm_name                                    url
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/plan/      0.0
# 22nd Century Limited                         http://www.xxiicentury.com/history/                   0.0
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/global/    0.0
#                                              https://www.mitsubishicorp.com/jp/en/about/mess...    0.0
# Forest Concepts                              http://forestconcepts.com/index.php?page=01002        0.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/program-management/      0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/corporate_data....    0.0
# W&Wsens Devices                              https://www.wwsensdevices.com/                        0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/brand.html            0.0
#                                              https://www.kansai.com/about-us/                      0.0
# Xintec Inc.                                  http://www.xintec.com.tw/eng/CSR_Corporate_Gove...    0.0
# k-Space Associates                           https://www.k-space.com/company/distributors/         0.0
# Amkor Technology                             https://amkor.com/company-history/                    0.0
#                                              https://amkor.com/technology/system-in-package/       0.0
# Wine.com                                     https://www.wine.com/content/landing/corporate-...    0.0
# Industrial Technology Research Institute     https://www.itri.org.tw/eng/Content/Management/...    0.0
# Vizio Inc.                                   https://www.vizio.com/about                           0.0
# Midrex Technologies                          https://midrex.com/company-info/history               0.0
# VMware                                       https://www.vmware.com/company/leadership.html        0.0
#                                              https://www.vmware.com/company/innovation.html        0.0
# VEECO PRECISION SURFACE PROCESSING LLC       http://www.veeco.com/company                          0.0
# ABB AB                                       https://new.abb.com/network-management                0.0
# VMware                                       https://www.vmware.com/company/foundation.html        0.0
# ABB AB                                       https://new.abb.com/about                             0.0
#                                              https://new.abb.com/cpm                               0.0
# DuPont Teijin Films U.S. Limited Partnership https://usa.dupontteijinfilms.com/about/              0.0
# Vaxiion Therapeutics                         http://www.vaxiion.com/executive-management.html      0.0
#                                              http://www.vaxiion.com/the-company.html               0.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/                         0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/history.html          0.0
# ...                                                                                                ...
# Ormat Technologies Inc.                      https://www.ormat.com/en/company/general/view/?...    0.0
# Gram Power                                   https://grampower.com/about-us/our-team.html          0.0
# SAINT-GOBAIN ABRASIFS                        https://www.saint-gobain-abrasives.com/en-us/pr...    0.0
# Ormat Technologies Inc.                      https://www.ormat.com/en/company/general/view/?...    0.0
# Lintec Corporation                           http://www.lintec-global.com/about/message/           0.0
#                                              http://www.lintec-global.com/about/history/           0.0
# Angaza Design                                https://www.angaza.com/about/                         0.0
# Lintec Corporation                           http://www.lintec-global.com/ir/management/           0.0
#                                              http://www.lintec-global.com/about/brochure/book/     0.0
# Kulite Semiconductor Products                https://www.kulite.com/company/news/                  0.0
# Lintec Corporation                           http://www.lintec-global.com/about/country/amer...    0.0
#                                              http://www.lintec-global.com/about/network/           0.0
# Kulite Semiconductor Products                https://www.kulite.com/company/contact-info/          0.0
#                                              https://www.kulite.com/company/customer-resources/    0.0
#                                              https://www.kulite.com/company/corporate-respon...    0.0
#                                              https://www.kulite.com/company/supplier-code-of...    0.0
# Bend Research                                https://www.capsugel.com/about-capsugel               0.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news                      0.0
#                                              http://pidc.com/our-company/locations                 0.0
# Valicor                                      http://trucent.com/                                   0.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news/pacific-indust...    0.0
# SOLAZYME                                     http://solazyme.com/                                  0.0
# Starlight Energy Holdings LLC                http://www.starlightenergy.us/                        0.0
# Solight Solar                                http://www.solight.com/                               0.0
# ZON                                          https://www.zon.si/                                   0.0
# Ostendo Technologies                         https://www.ostendo.com/                              0.0
# Quantapore                                   https://quantapore.com/                               0.0
# Synaptic Research                            https://research.synaptic.co.uk/SynapticResearc...    0.0
# Sun Drilling Products Corporation            https://www.sunspecialtyproducts.com/                 0.0
# MEDport                                      https://medport.com/                                  0.0
#
#                                                                                                  2016  \
# firm_name                                    url
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/plan/     0.0
# 22nd Century Limited                         http://www.xxiicentury.com/history/                  0.0
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/global/   0.0
#                                              https://www.mitsubishicorp.com/jp/en/about/mess...   0.0
# Forest Concepts                              http://forestconcepts.com/index.php?page=01002       0.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/program-management/     0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/corporate_data....   0.0
# W&Wsens Devices                              https://www.wwsensdevices.com/                       0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/brand.html           0.0
#                                              https://www.kansai.com/about-us/                     0.0
# Xintec Inc.                                  http://www.xintec.com.tw/eng/CSR_Corporate_Gove...   0.0
# k-Space Associates                           https://www.k-space.com/company/distributors/        0.0
# Amkor Technology                             https://amkor.com/company-history/                   0.0
#                                              https://amkor.com/technology/system-in-package/      0.0
# Wine.com                                     https://www.wine.com/content/landing/corporate-...   0.0
# Industrial Technology Research Institute     https://www.itri.org.tw/eng/Content/Management/...   0.0
# Vizio Inc.                                   https://www.vizio.com/about                          0.0
# Midrex Technologies                          https://midrex.com/company-info/history              0.0
# VMware                                       https://www.vmware.com/company/leadership.html       0.0
#                                              https://www.vmware.com/company/innovation.html       0.0
# VEECO PRECISION SURFACE PROCESSING LLC       http://www.veeco.com/company                         0.0
# ABB AB                                       https://new.abb.com/network-management               0.0
# VMware                                       https://www.vmware.com/company/foundation.html       0.0
# ABB AB                                       https://new.abb.com/about                            0.0
#                                              https://new.abb.com/cpm                              0.0
# DuPont Teijin Films U.S. Limited Partnership https://usa.dupontteijinfilms.com/about/             0.0
# Vaxiion Therapeutics                         http://www.vaxiion.com/executive-management.html     0.0
#                                              http://www.vaxiion.com/the-company.html              0.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/                        0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/history.html         0.0
# ...                                                                                               ...
# Ormat Technologies Inc.                      https://www.ormat.com/en/company/general/view/?...   0.0
# Gram Power                                   https://grampower.com/about-us/our-team.html         0.0
# SAINT-GOBAIN ABRASIFS                        https://www.saint-gobain-abrasives.com/en-us/pr...   0.0
# Ormat Technologies Inc.                      https://www.ormat.com/en/company/general/view/?...   0.0
# Lintec Corporation                           http://www.lintec-global.com/about/message/          0.0
#                                              http://www.lintec-global.com/about/history/          0.0
# Angaza Design                                https://www.angaza.com/about/                        0.0
# Lintec Corporation                           http://www.lintec-global.com/ir/management/          0.0
#                                              http://www.lintec-global.com/about/brochure/book/    0.0
# Kulite Semiconductor Products                https://www.kulite.com/company/news/                 0.0
# Lintec Corporation                           http://www.lintec-global.com/about/country/amer...   0.0
#                                              http://www.lintec-global.com/about/network/          0.0
# Kulite Semiconductor Products                https://www.kulite.com/company/contact-info/         0.0
#                                              https://www.kulite.com/company/customer-resources/   0.0
#                                              https://www.kulite.com/company/corporate-respon...   0.0
#                                              https://www.kulite.com/company/supplier-code-of...   0.0
# Bend Research                                https://www.capsugel.com/about-capsugel              0.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news                     0.0
#                                              http://pidc.com/our-company/locations                0.0
# Valicor                                      http://trucent.com/                                  0.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news/pacific-indust...   0.0
# SOLAZYME                                     http://solazyme.com/                                 0.0
# Starlight Energy Holdings LLC                http://www.starlightenergy.us/                       0.0
# Solight Solar                                http://www.solight.com/                              0.0
# ZON                                          https://www.zon.si/                                  0.0
# Ostendo Technologies                         https://www.ostendo.com/                             0.0
# Quantapore                                   https://quantapore.com/                              0.0
# Synaptic Research                            https://research.synaptic.co.uk/SynapticResearc...   0.0
# Sun Drilling Products Corporation            https://www.sunspecialtyproducts.com/                0.0
# MEDport                                      https://medport.com/                                 0.0
#
#                                                                                                  2020  \
# firm_name                                    url
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/plan/     0.0
# 22nd Century Limited                         http://www.xxiicentury.com/history/                  0.0
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/global/   0.0
#                                              https://www.mitsubishicorp.com/jp/en/about/mess...   0.0
# Forest Concepts                              http://forestconcepts.com/index.php?page=01002       0.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/program-management/     0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/corporate_data....   0.0
# W&Wsens Devices                              https://www.wwsensdevices.com/                       0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/brand.html           0.0
#                                              https://www.kansai.com/about-us/                     0.0
# Xintec Inc.                                  http://www.xintec.com.tw/eng/CSR_Corporate_Gove...   0.0
# ...
#                                              https://www.kulite.com/company/supplier-code-of...   0.0
# Bend Research                                https://www.capsugel.com/about-capsugel              0.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news                     0.0
#                                              http://pidc.com/our-company/locations                0.0
# Valicor                                      http://trucent.com/                                  0.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news/pacific-indust...   0.0
# SOLAZYME                                     http://solazyme.com/                                 0.0
# Starlight Energy Holdings LLC                http://www.starlightenergy.us/                       0.0
# Solight Solar                                http://www.solight.com/                              0.0
# ZON                                          https://www.zon.si/                                  0.0
# Ostendo Technologies                         https://www.ostendo.com/                             0.0
# Quantapore                                   https://quantapore.com/                              0.0
# Synaptic Research                            https://research.synaptic.co.uk/SynapticResearc...   0.0
# Sun Drilling Products Corporation            https://www.sunspecialtyproducts.com/                0.0
# MEDport                                      https://medport.com/                                 0.0
#
#                                                                                                  pages_in_domain  \
# firm_name                                    url
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/plan/               11.0
# 22nd Century Limited                         http://www.xxiicentury.com/history/                             4.0
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/global/             11.0
#                                              https://www.mitsubishicorp.com/jp/en/about/mess...             11.0
# Forest Concepts                              http://forestconcepts.com/index.php?page=01002                  4.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/program-management/                3.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/corporate_data....              6.0
# W&Wsens Devices                              https://www.wwsensdevices.com/                                  1.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/brand.html                      6.0
#                                              https://www.kansai.com/about-us/                                6.0
# Xintec Inc.                                  http://www.xintec.com.tw/eng/CSR_Corporate_Gove...              6.0
# k-Space Associates                           https://www.k-space.com/company/distributors/                   9.0
# Amkor Technology                             https://amkor.com/company-history/                              4.0
#                                              https://amkor.com/technology/system-in-package/                 4.0
# Wine.com                                     https://www.wine.com/content/landing/corporate-...              3.0
# Industrial Technology Research Institute     https://www.itri.org.tw/eng/Content/Management/...              2.0
# Vizio Inc.                                   https://www.vizio.com/about                                     1.0
# Midrex Technologies                          https://midrex.com/company-info/history                         8.0
# VMware                                       https://www.vmware.com/company/leadership.html                 11.0
#                                              https://www.vmware.com/company/innovation.html                 11.0
# VEECO PRECISION SURFACE PROCESSING LLC       http://www.veeco.com/company                                    7.0
# ABB AB                                       https://new.abb.com/network-management                         11.0
# VMware                                       https://www.vmware.com/company/foundation.html                 11.0
# ABB AB                                       https://new.abb.com/about                                      11.0
#                                              https://new.abb.com/cpm                                        11.0
# DuPont Teijin Films U.S. Limited Partnership https://usa.dupontteijinfilms.com/about/                        5.0
# Vaxiion Therapeutics                         http://www.vaxiion.com/executive-management.html                2.0
#                                              http://www.vaxiion.com/the-company.html                         2.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/                                   3.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/history.html                    6.0
# ...                                                                                                          ...
# Ormat Technologies Inc.                      https://www.ormat.com/en/company/general/view/?...             22.0
# Gram Power                                   https://grampower.com/about-us/our-team.html                    6.0
# SAINT-GOBAIN ABRASIFS                        https://www.saint-gobain-abrasives.com/en-us/pr...             12.0
# Ormat Technologies Inc.                      https://www.ormat.com/en/company/general/view/?...             22.0
# Lintec Corporation                           http://www.lintec-global.com/about/message/                    22.0
#                                              http://www.lintec-global.com/about/history/                    22.0
# Angaza Design                                https://www.angaza.com/about/                                   2.0
# Lintec Corporation                           http://www.lintec-global.com/ir/management/                    22.0
#                                              http://www.lintec-global.com/about/brochure/book/              22.0
# Kulite Semiconductor Products                https://www.kulite.com/company/news/                           20.0
# Lintec Corporation                           http://www.lintec-global.com/about/country/amer...             22.0
#                                              http://www.lintec-global.com/about/network/                    22.0
# Kulite Semiconductor Products                https://www.kulite.com/company/contact-info/                   20.0
#                                              https://www.kulite.com/company/customer-resources/             20.0
#                                              https://www.kulite.com/company/corporate-respon...             20.0
#                                              https://www.kulite.com/company/supplier-code-of...             20.0
# Bend Research                                https://www.capsugel.com/about-capsugel                         4.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news                               16.0
#                                              http://pidc.com/our-company/locations                          16.0
# Valicor                                      http://trucent.com/                                             2.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news/pacific-indust...             16.0
# SOLAZYME                                     http://solazyme.com/                                            2.0
# Starlight Energy Holdings LLC                http://www.starlightenergy.us/                                  2.0
# Solight Solar                                http://www.solight.com/                                         2.0
# ZON                                          https://www.zon.si/                                             2.0
# Ostendo Technologies                         https://www.ostendo.com/                                        2.0
# Quantapore                                   https://quantapore.com/                                         1.0
# Synaptic Research                            https://research.synaptic.co.uk/SynapticResearc...              2.0
# Sun Drilling Products Corporation            https://www.sunspecialtyproducts.com/                           2.0
# MEDport                                      https://medport.com/                                            2.0
#
#                                                                                                  is_sole_page
# firm_name                                    url
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/plan/             0.0
# 22nd Century Limited                         http://www.xxiicentury.com/history/                          0.0
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/global/           0.0
#                                              https://www.mitsubishicorp.com/jp/en/about/mess...           0.0
# Forest Concepts                              http://forestconcepts.com/index.php?page=01002               0.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/program-management/             0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/corporate_data....           0.0
# W&Wsens Devices                              https://www.wwsensdevices.com/                               1.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/brand.html                   0.0
#                                              https://www.kansai.com/about-us/                             0.0
# Xintec Inc.                                  http://www.xintec.com.tw/eng/CSR_Corporate_Gove...           0.0
# k-Space Associates                           https://www.k-space.com/company/distributors/                0.0
# Amkor Technology                             https://amkor.com/company-history/                           0.0
#                                              https://amkor.com/technology/system-in-package/              0.0
# Wine.com                                     https://www.wine.com/content/landing/corporate-...           0.0
# Industrial Technology Research Institute     https://www.itri.org.tw/eng/Content/Management/...           0.0
# Vizio Inc.                                   https://www.vizio.com/about                                  1.0
# Midrex Technologies                          https://midrex.com/company-info/history                      0.0
# VMware                                       https://www.vmware.com/company/leadership.html               0.0
#                                              https://www.vmware.com/company/innovation.html               0.0
# VEECO PRECISION SURFACE PROCESSING LLC       http://www.veeco.com/company                                 0.0
# ABB AB                                       https://new.abb.com/network-management                       0.0
# VMware                                       https://www.vmware.com/company/foundation.html               0.0
# ABB AB                                       https://new.abb.com/about                                    0.0
#                                              https://new.abb.com/cpm                                      0.0
# DuPont Teijin Films U.S. Limited Partnership https://usa.dupontteijinfilms.com/about/                     0.0
# Vaxiion Therapeutics                         http://www.vaxiion.com/executive-management.html             0.0
#                                              http://www.vaxiion.com/the-company.html                      0.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/                                0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/history.html                 0.0
# ...                                                                                                       ...
# Ormat Technologies Inc.                      https://www.ormat.com/en/company/general/view/?...           0.0
# Gram Power                                   https://grampower.com/about-us/our-team.html                 0.0
# SAINT-GOBAIN ABRASIFS                        https://www.saint-gobain-abrasives.com/en-us/pr...           0.0
# Ormat Technologies Inc.                      https://www.ormat.com/en/company/general/view/?...           0.0
# Lintec Corporation                           http://www.lintec-global.com/about/message/                  0.0
#                                              http://www.lintec-global.com/about/history/                  0.0
# Angaza Design                                https://www.angaza.com/about/                                0.0
# Lintec Corporation                           http://www.lintec-global.com/ir/management/                  0.0
#                                              http://www.lintec-global.com/about/brochure/book/            0.0
# Kulite Semiconductor Products                https://www.kulite.com/company/news/                         0.0
# Lintec Corporation                           http://www.lintec-global.com/about/country/amer...           0.0
#                                              http://www.lintec-global.com/about/network/                  0.0
# Kulite Semiconductor Products                https://www.kulite.com/company/contact-info/                 0.0
#                                              https://www.kulite.com/company/customer-resources/           0.0
#                                              https://www.kulite.com/company/corporate-respon...           0.0
#                                              https://www.kulite.com/company/supplier-code-of...           0.0
# Bend Research                                https://www.capsugel.com/about-capsugel                      0.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news                             0.0
#                                              http://pidc.com/our-company/locations                        0.0
# Valicor                                      http://trucent.com/                                          0.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news/pacific-indust...           0.0
# SOLAZYME                                     http://solazyme.com/                                         0.0
# Starlight Energy Holdings LLC                http://www.starlightenergy.us/                               0.0
# Solight Solar                                http://www.solight.com/                                      0.0
# ZON                                          https://www.zon.si/                                          0.0
# Ostendo Technologies                         https://www.ostendo.com/                                     0.0
# Quantapore                                   https://quantapore.com/                                      1.0
# Synaptic Research                            https://research.synaptic.co.uk/SynapticResearc...           0.0
# Sun Drilling Products Corporation            https://www.sunspecialtyproducts.com/                        0.0
# MEDport                                      https://medport.com/                                         0.0
#
# [4516 rows x 1473 columns]

# %%
# predict with newly constructed X
y_predicted = clf.predict(X_test)

# %%
# write to file
with open(ABOUT_DIR + 'about_predicted_and_labels.csv', mode='w') as about_file:
    about_writer = csv.writer(about_file, delimiter=',', quotechar='"')
    about_writer.writerow(['firm_name', 'url', 'is_about'])
    # output predicted values to file
    for fn, u, predicted_value in zip(X_test.index.get_level_values('firm_name'), X_test.index.get_level_values('url'), y_predicted):
        # print (fn + ' with url ' + u + ' has predicted value ' + str(predicted_value))
        about_writer.writerow([fn, u, predicted_value])
    # and the labeled ones too...
    for fn, u, labeled_value in zip(X.index.get_level_values('firm_name'), X.index.get_level_values('url'), y):
        # print (fn + ' with url ' + u + ' has predicted value ' + str(labeled_value))
        about_writer.writerow([fn, u, labeled_value])

# %% [markdown]
# ## Extract data from mongodb
# * Now that we know which pages are about pages, extract from mongodb and output for topic modeling
# * For now, construct paragraphs from different pages by ordering urls by their length.  In the future, might want to contruct paragraphs in their 'natural' sequential order as they would appear on a home page or landing page

# %%
# combine both labeled and predicted frames
print (X_test.shape)
print(X.shape)

combined = X_test.append(X)
print (combined.shape)
print (len(y_predicted))
print (len(y))
abouts = pd.DataFrame(index=combined.index)

abouts['is_about'] = list(y_predicted) + list(y)
abouts = abouts.reset_index()
abouts
# Out:
# (4516, 1474)
# (1031, 1474)
# (5547, 1474)
# 4516
# 1031
#                                           firm_name  \
# 0                      Mitsubishi Metal Corporation
# 1                              22nd Century Limited
# 2                      Mitsubishi Metal Corporation
# 3                      Mitsubishi Metal Corporation
# 4                                   Forest Concepts
# 5                                 ZENA TECHNOLOGIES
# 6                                  Kansai Paint Co.
# 7                                   W&Wsens Devices
# 8                                  Kansai Paint Co.
# 9                                  Kansai Paint Co.
# 10                                      Xintec Inc.
# 11                               k-Space Associates
# 12                                 Amkor Technology
# 13                                 Amkor Technology
# 14                                         Wine.com
# 15         Industrial Technology Research Institute
# 16                                       Vizio Inc.
# 17                              Midrex Technologies
# 18                                           VMware
# 19                                           VMware
# 20           VEECO PRECISION SURFACE PROCESSING LLC
# 21                                           ABB AB
# 22                                           VMware
# 23                                           ABB AB
# 24                                           ABB AB
# 25     DuPont Teijin Films U.S. Limited Partnership
# 26                             Vaxiion Therapeutics
# 27                             Vaxiion Therapeutics
# 28                                ZENA TECHNOLOGIES
# 29                                 Kansai Paint Co.
# ...                                             ...
# 5517                                  Unifrax I LLC
# 5518                                  Unifrax I LLC
# 5519                                  Unifrax I LLC
# 5520                VINDICO NANOBIO TECHNOLOGY INC.
# 5521                VINDICO NANOBIO TECHNOLOGY INC.
# 5522                                Verliant Energy
# 5523  Wave Energy Conversion Corporation of America
# 5524                         Zeno Semiconductor Inc
# 5525                            Zoetis Services LLC
# 5526                            Zoetis Services LLC
# 5527                            Zoetis Services LLC
# 5528                            Zoetis Services LLC
# 5529                            Zoetis Services LLC
# 5530                            Zoetis Services LLC
# 5531                            Zoetis Services LLC
# 5532                            Zoetis Services LLC
# 5533                            Zoetis Services LLC
# 5534                            Zoetis Services LLC
# 5535                            Zoetis Services LLC
# 5536                               Zygo Corporation
# 5537                               Zygo Corporation
# 5538                               Zygo Corporation
# 5539                               Zygo Corporation
# 5540                               Zygo Corporation
# 5541                               Zygo Corporation
# 5542                                           fybr
# 5543                                   iNanoBio LLC
# 5544                                   iNanoBio LLC
# 5545                                   nanoComposix
# 5546                                   nanoComposix
#
#                                                     url  is_about
# 0      https://www.mitsubishicorp.com/jp/en/about/plan/       1.0
# 1                   http://www.xxiicentury.com/history/       1.0
# 2     https://www.mitsubishicorp.com/jp/en/about/glo...       1.0
# 3     https://www.mitsubishicorp.com/jp/en/about/mes...       0.0
# 4        http://forestconcepts.com/index.php?page=01002       0.0
# 5      http://xena-technologies.com/program-management/       0.0
# 6     https://www.kansai.com/about-us/corporate_data...       1.0
# 7                        https://www.wwsensdevices.com/       0.0
# 8            https://www.kansai.com/about-us/brand.html       1.0
# 9                      https://www.kansai.com/about-us/       1.0
# 10    http://www.xintec.com.tw/eng/CSR_Corporate_Gov...       0.0
# 11        https://www.k-space.com/company/distributors/       0.0
# 12                   https://amkor.com/company-history/       1.0
# 13      https://amkor.com/technology/system-in-package/       0.0
# 14    https://www.wine.com/content/landing/corporate...       0.0
# 15    https://www.itri.org.tw/eng/Content/Management...       0.0
# 16                          https://www.vizio.com/about       1.0
# 17              https://midrex.com/company-info/history       1.0
# 18       https://www.vmware.com/company/leadership.html       0.0
# 19       https://www.vmware.com/company/innovation.html       1.0
# 20                         http://www.veeco.com/company       1.0
# 21               https://new.abb.com/network-management       0.0
# 22       https://www.vmware.com/company/foundation.html       0.0
# 23                            https://new.abb.com/about       1.0
# 24                              https://new.abb.com/cpm       0.0
# 25             https://usa.dupontteijinfilms.com/about/       1.0
# 26     http://www.vaxiion.com/executive-management.html       0.0
# 27              http://www.vaxiion.com/the-company.html       1.0
# 28                        http://xena-technologies.com/       0.0
# 29         https://www.kansai.com/about-us/history.html       1.0
# ...                                                 ...       ...
# 5517  http://www.unifrax.com/about-us/luyang-partner...       0.0
# 5518                   http://www.unifrax.com/about-us/       1.0
# 5519  http://www.unifrax.com/about-us/career-opportu...       0.0
# 5520  http://vindicoat.com/joomla1/index.php/meet-th...       0.0
# 5521  http://vindicoat.com/joomla1/index.php/meet-th...       0.0
# 5522                     http://www.verliantenergy.com/       1.0
# 5523                     https://weccamerica.com/about/       1.0
# 5524                           https://www.zenosemi.com       1.0
# 5525         https://www.zoetis.com/about-us/index.aspx       1.0
# 5526  https://www.zoetis.com/about-us/vision-mission...       1.0
# 5527       https://www.zoetis.com/about-us/history.aspx       1.0
# 5528  https://www.zoetis.com/about-us/executive-team...       0.0
# 5529  https://www.zoetis.com/about-us/zoetis-at-a-gl...       1.0
# 5530       https://www.zoetis.com/?eventName=LOGGED_OUT       0.0
# 5531  https://www.zoetis.com/about-us/core-beliefs.aspx       1.0
# 5532     https://www.zoetis.com/about-us/our-story.aspx       1.0
# 5533  https://www.zoetis.com/about-us/awards/index.aspx       1.0
# 5534  https://www.zoetis.com/about-us/company-locati...       0.0
# 5535  https://www.zoetis.com/about-us/corporate-gove...       0.0
# 5536              https://www.zygo.com/?/aboutus/shows/       0.0
# 5537  https://www.zygo.com/?/met/profilers/zegagepro...       0.0
# 5538  https://www.zygo.com/?/blog/facts-and-statisti...       0.0
# 5539  https://www.zygo.com/?/aboutus/privacy-cookie-...       0.0
# 5540              https://www.zygo.com/?/met/profilers/       0.0
# 5541   https://www.zygo.com/?/aboutus/news/20181017.htm       0.0
# 5542                         https://fybr.com/about-us/       1.0
# 5543                       http://inanobio.com/team.php       0.0
# 5544                    http://inanobio.com/aboutus.php       1.0
# 5545            https://nanocomposix.com/pages/about-us       1.0
# 5546                https://nanocomposix.com/pages/team       0.0
#
# [5547 rows x 3 columns]

# %%
# gather unique firm_names from mongodb
firm_names = set(abouts['firm_name'])
print (len(firm_names))
pp = pprint.PrettyPrinter()
pp.pprint(firm_names)
# Out:
# 1050
# {'22nd Century Limited',
#  '3M Innovative Properties Company',
#  'ABB AB',
#  'AC International Inc.',
#  'ACACIA RESEARCH GROUP LLC',
#  'ACUCELA INC.',
#  'ACell',
#  'ADASA INC.',
#  'ADVANCED INNOVATION CENTER LLC',
#  'AFMODEL',
#  'AGC Flat Glass North America',
#  'AGFA-GEVAERT N.V.',
#  'ALGETERNAL TECHNOLOGIES',
#  'ALSTOM Technology Ltd',
#  'AMPT',
#  'APPLIED STEMCELL',
#  'ARBOR THERAPEUTICS',
#  'ASCENT SOLAR TECHNOLOGIES',
#  'ASM America',
#  'ASML Netherlands B.V.',
#  'ASTUTE MEDICAL',
#  'AT&T Corporation',
#  'ATC Technologies',
#  'ATOMERA INCORPORATED',
#  'ATTOSTAT',
#  'AVI BioPharma',
#  'AVOGY',
#  'AbbVie Inc.',
#  'Abbott Molecular Inc.',
#  'Abbott Point of Care Inc.',
#  'Abengoa Bioenergy New Technologies',
#  'Ablexis',
#  'Access Business Group International LLC',
#  'AccuRay Corporation',
#  'Acorn Technologies',
#  'Adaptive Biotechnologies Corp.',
#  'Adeka Corporation',
#  'Adhesives Research',
#  'Adlens Beacon',
#  'Adobe Systems Incorporated',
#  'Adtran',
#  'Advanced Analogic Technologies',
#  'Advanced Aqua Group',
#  'Advanced Silicon Group',
#  'Adynxx',
#  'Aerogen',
#  'Agena Bioscience',
#  'Agienic',
#  'Agilent Technologies',
#  'Agrivida',
#  'AgroFresh Inc.',
#  'Ajinomoto Althea',
#  'Alcatel Lucent',
#  'Alcon Research',
#  'Alcotek',
#  'Alexion Pharmaceuticals',
#  'Algenol Biotech LLC',
#  'All Power Labs',
#  'Allertein Therapeutics',
#  'Alliance for Sustainable Energy',
#  'Allison Transmission',
#  'Alnylam Pharmaceuticals',
#  'Alpha and Omega Semiconductor Incorporated',
#  'AltaRock Energy',
#  'Altex Technologies Corporation',
#  'Altivera',
#  'Ambature',
#  'Amberwave Inc.',
#  'American Air Liquide',
#  'American Piledriving Equipment',
#  'Amgen Fremont Inc.',
#  'Amicus Therapeutics',
#  'Amkor Technology',
#  'Ampio Pharmaceuticals',
#  'Amtech Systems',
#  'Analog Devices',
#  'Andritz Inc.',
#  'Anelva Corporation',
#  'Angaza Design',
#  'Angiotech Pharmaceuticals (US)',
#  'Angstron Materials',
#  'Ansun Biopharma',
#  'Antaya Technologies Corporation',
#  'Apple Inc.',
#  'Applied Genetic Technologies Corporation',
#  'Applied Materials',
#  'Applied Membrane Technologies',
#  'Applied Nanostructures',
#  'Applied Optoelectronics',
#  'Archer Daniels Midland Company',
#  'Arcturus Therapeutics',
#  'Areesys Technologies',
#  'Arkema Inc.',
#  'Armageddon Energy Inc.',
#  'Arpin Renewable Energy',
#  'Arrowhead Center',
#  'Astech',
#  'AstenJohnson',
#  'Atleisure LLC',
#  'Atom Nanoelectronics',
#  'Atonometrics',
#  'Atrium Medical Corporation',
#  'Aurrion',
#  'Aushon Biosystems',
#  'Auterra',
#  'Authenex',
#  'Autonomic Materials',
#  'Avalanche Technology',
#  'Avantor Performance Materials',
#  'Avery Dennison Corporation',
#  'Avon Products',
#  'Avtaec Limited',
#  'B.G. Negev Technologies and Applications Ltd.',
#  'BAE Systems Information and Electronic Systems Integration Inc.',
#  'BASF',
#  'BASF Coatings GmbH',
#  'BAXALTA INCORPORATED',
#  'BP Corporation North America Inc.',
#  'BRIGHTLEAF TECHNOLOGIES INC.',
#  'BROADCOM CORPORATION',
#  'BTU International',
#  'Babcock Power Services',
#  'Baker Hughes Incorporated',
#  'Banpil Photonics',
#  'Basell Polyolefine GmbH',
#  'Battelle Memorial Institute',
#  'Bausch & Lomb Incorporated',
#  'Baxter Healthcare SA',
#  'Bayer Cropscience AG',
#  'Bayer Materialscience LLC',
#  'Bell Helicopter Textron Inc.',
#  'Bemis Company',
#  'Bend Research',
#  'Bestway',
#  'Bi-Modal Corporation',
#  'Big Belly Solar',
#  'Bigelow Aerospace',
#  'Bio-Rad Laboratories',
#  'BioNano Genomics',
#  'Biocare Medical',
#  'Biocon Limited',
#  'Biological Dynamics',
#  'Bioneer Corporation',
#  'Biosense Webster (Israel) Ltd.',
#  'Biosphere Medical',
#  'Biotechnology Foundation',
#  'Biotta LLC',
#  'Bird-B-Gone',
#  'Bisco',
#  'Bitrode Corporation',
#  'BlackBerry Limited',
#  'Blue Sea Systems',
#  'Bluestar Silicones France',
#  'Boehringer Ingelheim International GmbH',
#  'Boehringer Ingelheim Vetmedica GmbH',
#  'Bostik',
#  'Boston Scientific Scimed',
#  'Braun Intertec Geothermal',
#  'Brewer Science Inc.',
#  'Bridgelux',
#  'Bridgestone Corporation',
#  'Brightfield Transportation Solutions',
#  'Bristol-Myers Squibb Company',
#  'Brookhaven Science Associates LLC ',
#  'Bruin Biometrics',
#  'Buckman Laboratories International',
#  'Butamax(TM) Advanced Biofuels LLC',
#  'CAMBRIDGE ENTERPRISE LIMITED',
#  'CARBO Ceramics Inc.',
#  'CELLTRION',
#  'CERION LLC',
#  'CI4 Technologies',
#  'CLEARSIGN COMBUSTION CORPORATION',
#  'CMC ICOS BIOLOGICS',
#  'CNH Industrial America LLC',
#  'COOK MEDICAL TECHNOLOGIES LLC',
#  'COVERIS FLEXIBLES US LLC',
#  'CP KELCO APS',
#  "CSEM Centre Suisse d'Electronique et de Microtechnique SA-Recherche et "
#  'Developpement',
#  'CUMMINS FILTRATION IP',
#  'Cabot Corporation',
#  'Cadence Design Systems',
#  'Calient Technologies',
#  'Calysta',
#  'Canon',
#  'Canon Kabushiki Kaisha',
#  'Canon Nanotechnologies',
#  'Canon U.S. Life Sciences',
#  'Carbon3D',
#  'Cardiva Medical',
#  'Carestream Health',
#  'Caribou Biosciences',
#  'Carl Zeiss Meditec AG',
#  'Carver Scientific',
#  'Casio Computer Co.',
#  'Cbrite Inc.',
#  'Cedar Ridge Research',
#  'Celanese Corporation',
#  'CellPrint IP Holding',
#  'Cellular Research',
#  'Ceramatec',
#  'Cetac Technologies Inc.',
#  'Chemtreat',
#  'Chevron Oronitz Company LLC',
#  'Chevron Phillips Chemical Company LP',
#  'Chevron U.S.A. Inc.',
#  'Chipmos Technologies Inc.',
#  'Christie Digital Systems',
#  'Chromalox',
#  'Cisco Technology',
#  'Claret Medical',
#  'Cleanvantage LLC',
#  'Clearside Biomedical',
#  'Coactive Drive Corporation',
#  'Codexis',
#  'Coleman Cable',
#  'Colgate-Palmolive Company',
#  'Coloplast A/S',
#  'Columbia Insurance Company',
#  'Combined Energies',
#  'Commonwealth Scientific & Industrial Research Organization',
#  'Community Power Corporation',
#  'Complete Genomics',
#  'Conexant Systems',
#  'Confluence Energy',
#  'Conoco Inc.',
#  'ConocoPhillips Company',
#  'Conversant Intellectual Property Management Inc.',
#  'Cook Biotech Incorporated',
#  'Cool Planet Energy Systems',
#  'CoolEarth Solar',
#  'Coriant Advanced Technology',
#  'Cornell Research Foundation',
#  'Corporation for National Research Initiatives',
#  'Cree',
#  'Cristal USA Inc.',
#  'Cross Match Technologies',
#  'Crossbar',
#  'Crystal Solar Inc.',
#  'Cura Vac',
#  'Custom Electronics Inc.',
#  'Cyberonics',
#  'CyboEnergy',
#  'DECA Technologies Inc.',
#  'DEKA Products Limited Partnership',
#  'DHPC TECHNOLOGIES',
#  'DIC Corporation',
#  'DISCOVERYBIOMED INC.',
#  'DNA Twopointo',
#  'DRS Network & Imaging Systems',
#  'DSP Group LTD.',
#  'Da Yu Enterprises',
#  'Daikin Industries',
#  'Dana Corporation',
#  'Dana-Farber Cancer Institute',
#  'Danisco US Inc.',
#  'Daylight Solutions',
#  'DePuy Synthes Products',
#  'Delavau LLC',
#  'Dell Software Inc.',
#  'Delphi Technologies',
#  'Delta Electronics',
#  'Denso Corporation',
#  'Deployable Space Systems',
#  'Dermazone Solutions',
#  'Dexerials Corporation',
#  'Dialight Corporation',
#  'Dialogic Corporation',
#  'Diamond Innovations',
#  'DiscoveRx Corporation',
#  'Disney Enterprises',
#  'Dolby Laboratories Licensing Corporation',
#  'Domtar Paper Company',
#  "Dr. Reddy's Laboratories Ltd.",
#  'Dresser-Rand Company',
#  'DuPont Teijin Films U.S. Limited Partnership',
#  'E Ink Corporation',
#  'E. Tech Incorporation',
#  'ECOSYNTHETIX LTD.',
#  'EMC Corporation',
#  'EMD Technologies Inc.',
#  'ENI S.p.A.',
#  'ESCAPE THERAPEUTICS',
#  'EXOS LLC',
#  'Easel Biotechnologies',
#  'Eastman Chemical Company',
#  'Eastman Kodak Company',
#  'Eaton Corporation',
#  'EchoStar Technologies LLC',
#  'Echogen Power Systems',
#  'Ecolab Inc.',
#  'Ecovative Design',
#  'Egenera',
#  'Eisai Co.',
#  'ElectraTherm',
#  'Electrix',
#  'Electrovaya Inc.',
#  'Element One',
#  'Elenion Technologies',
#  'Elwha LLC',
#  'Em-Tech LLC',
#  'Energysolutions',
#  'Englewood Lab',
#  'Ensyn Renewables',
#  'Entech Solar',
#  'Entegris',
#  'Envision Solar International',
#  'Envisionit LLC',
#  'Epizyme',
#  'Esolar',
#  'Ethicon Endo-Surgery',
#  'Evernote Corporation',
#  'Everspin Technologies',
#  'Evoqua Water Technologies LLC',
#  'Evri',
#  'ExxonMobil Chemical Patents Inc.',
#  'ExxonMobil Upstream Research Company',
#  'FEI Company',
#  'FLIR Systems',
#  'FLOW CONTROL LLC.',
#  'FPInnovations',
#  'FRONT EDGE TECHNOLOGY INC.',
#  'FUJIFILM Corporation',
#  'FUJIFILM Dimatix',
#  'FULL CIRCLE BIOCHAR',
#  'Fairchild Semiconductor Corporation',
#  'FastCAP Systems Corporation',
#  'Faurecia Interior Systems',
#  'Federal Signal Corporation',
#  'Ferro Corporation',
#  'Fianium Ltd.',
#  'Finisar Corporation',
#  'First Solar',
#  'Flextronics AP',
#  'Floadia Corporation',
#  'Fluidigm Corporation',
#  'Ford Global Technologies',
#  'Forest Concepts',
#  'Foret Plasma Labs',
#  'Formula Plastics',
#  'Freescale Semiconductor',
#  'Fuji Electric Co.',
#  'Fuji Xerox Co.',
#  'Fujitsu Limited',
#  'Furukawa Electric Co.',
#  'FutureWei Technologies',
#  'GCP Applied Technologies Inc.',
#  'GE Healthcare Dharmacon',
#  'GE-Hitachi Nuclear Energy Americas LLC',
#  'GED Intergrated Solution',
#  'GEN-PROBE INCORPORATED',
#  'GENCO SCIENCES LLC',
#  'GENERAL MOTORS LLC',
#  'GLIKNIK INC.',
#  'GLYCON LLC',
#  'GOAL ZERO LLC',
#  'GOJO Industries',
#  'GOLBA LLC',
#  'GOSOLARLIFE',
#  'GROW ENERGY',
#  'Galectin Therapeutics',
#  'GangaGen',
#  'Gardner-Gibson',
#  'Gas Technology Institute',
#  'Gemex Systems',
#  'Genentech',
#  'Genisphere',
#  'Genomatica',
#  'Genomic Health',
#  'Genzyme Corporation',
#  'Gestion Ultra International Inc.',
#  'Gilead Connecticut',
#  'Gilead Sciences',
#  'GlassPoint Solar',
#  'GlaxoSmithKline Biologicals',
#  'Global Eagle Entertainment Inc.',
#  'Global OLED Technology LLC',
#  'Global Solar Water Power Systems',
#  'Globus Medical',
#  'Glucan Biorenewables LLC',
#  'Gracenote',
#  'Grain Processing Corporation',
#  'Gram Power',
#  'Grandis Inc.',
#  'Graphene Technologies',
#  'Greatbatch Ltd.',
#  'Green Box Batteries',
#  'Green Extraction Technologies',
#  'Green Solar Transportation',
#  'Greyrock Energy',
#  'Gtech Corporation',
#  'Guardian Industries',
#  'H R D CORPORATION',
#  'HAMAMATSU PHOTONICS K.K.',
#  'HARMAN INTERNATIONAL INDUSTRIES',
#  'HGST NETHERLANDS B.V.',
#  'HIQ SOLAR',
#  'HM3 Energy',
#  'HNO Greenfuels',
#  'HOWARD INDUSTRIES',
#  'HRL Laboratories',
#  'HTC Corporation',
#  'HTS',
#  'Halliburton Energy Services',
#  'Hamilton Sundstrand Corporation',
#  'Handstand Innovations',
#  'Harris Corporation',
#  'Headway Technologies',
#  'Heat Seal LLC',
#  'Heidelberger Druckmaschinen AG',
#  'Heliae Development',
#  'Heraeus Precious Metals North America Conshohocken LLC',
#  'Hewlett Packard Enterprise Development LP',
#  'Hitachi',
#  'Hitachi High-Technologies Corporation',
#  'Hitachi Metals',
#  'Hollingsworth & Vose Company',
#  'Hollywood Trucks',
#  'Hon Hai Precision Industry Co.',
#  'Honda Motor Co.',
#  'Honeywell International Inc.',
#  'Hosiden Corporation',
#  'Hoya Corporation',
#  'Humanetics Corporation',
#  'Hunt Energy Enterprises LLC',
#  'Hunter Douglas Inc.',
#  'Hynix Semiconductor Inc.',
#  'Hysitron Incorporated',
#  'Hyundai Motor Company',
#  'IDEALAB',
#  'IDEX Health & Science LLC',
#  'II-VI Incorporated',
#  'IMDS Corporation',
#  'IMEC',
#  'IMRA America',
#  'INFINEUM INTERNATIONAL LIMITED',
#  'INTEVAC',
#  'INVISTA North America S.a.r.l.',
#  'ITN Energy Systems',
#  'Ideal Power Inc.',
#  'Ignis Innovation',
#  'Illinois Tool Works',
#  'Immunolight',
#  'Imperial Innovations Limited',
#  'InView Technology Corporation',
#  'Inaeris Technologies',
#  'Incept LLC',
#  'Incyte Holdings Corporation',
#  'Industrial Science & Technology Network',
#  'Industrial Technology Research Institute',
#  'Infineon Technologies AG',
#  'Infinera Corporation',
#  'Innolux Corporation',
#  'Innovation Hammer',
#  'Inphenix',
#  'Instron Corporation ',
#  'Integrated DNA Technologies',
#  'Integrated Device Technology',
#  'Integrated Nano-Technologies',
#  'Integrated Solar Technology',
#  'Intellectual Keystone Technology LLC',
#  'Interface Performance Materials',
#  'Intermolecular',
#  'International Business Machines Corporation',
#  'Intuitive Surgical Operations',
#  'Invensas Corporation',
#  'Iogen Corporation',
#  'Ion Power Group',
#  'Ivoclar Vivadent AG',
#  'J. E. WHITE',
#  'JFE STEEL CORPORATION',
#  'JNC Corporation',
#  'JSR Corporation',
#  'JX Nippon Mining & Metals Corporation',
#  'Janssen Biotech',
#  'Johns Manville',
#  'Johnson & Johnson Consumer Companies',
#  'Johnson & Johnson Vision Care',
#  'Johnson Controls Technology Company',
#  'Johnson Matthey PLC',
#  'KINO LLC',
#  'KJ BIOSCIENCES LLC',
#  'KLA-Tencor Corporation',
#  'KOLO TECHNOLOGIES',
#  'KOLON INDUSTRIES',
#  'KT Corporation',
#  'KYOCERA DOCUMENT SOLUTIONS INC.',
#  'Kabushikikaisha Toshiba',
#  'Kajima Corporation',
#  'Kala Pharmaceuticals',
#  'Kaneka Corporation',
#  'Kansai Paint Co.',
#  'Kao Corporation',
#  'Karsten Manufacturing Corporation',
#  'Kashiv Pharma',
#  'Kemira OY',
#  'Kerr Corporation',
#  'Kia Motors Corporation ',
#  'Kimberly-Clark Worldwide',
#  'Kinestral Technologies',
#  'King Electric Vehicles Inc.',
#  'Kobe Steel',
#  'Kodak Alaris Inc.',
#  'Korea Kumho Petrochemical Co.',
#  'Kraton Polymers U.S. LLC',
#  'Kronos International Inc',
#  'Kulite Semiconductor Products',
#  'Kureha Corporation',
#  'L-3 Communications Cincinnati Electronics Corporation',
#  'LG Display Co.',
#  'LG Electronics Inc.',
#  'LG NANOH2O',
#  'LGS Innovations LLC',
#  'LIQUID X PRINTED METALS',
#  'LUCERA LABS',
#  'Lake Lite',
#  'Landauer',
#  'Lattice Semiconductor Corporation',
#  'Lawrence Livermore National Security',
#  'Leap Frogg',
#  'Lextar Electronics Corp.',
#  'Life Technologies Corporation',
#  'LifeNet Health',
#  'Linne Industries LLC',
#  'Lintec Corporation',
#  'Liquidia Technologies',
#  'Litron Laboratories Limited',
#  'Little Kids',
#  'Livetv',
#  'Lockheed Martin Corporation',
#  'Locus Energy',
#  'Lof Solar Corporation',
#  'Longhorn Vaccines and Diagnostics',
#  'Lovelace Respiratory Research Institute',
#  'Lumenco',
#  'Lumentum Operations LLC',
#  'Luna Innovations Incorporated',
#  'Lux Bio Group',
#  'MAHLE International GmbH',
#  'MANUFACTURING RESOURCES INTERNATIONAL',
#  'MATERIALS ANALYSIS TECHNOLOGY (US) CORP.',
#  'MAXLINEAR',
#  'MBC Ventures',
#  'MCI',
#  'MEDport',
#  'MERCK SHARP & DOHME CORP.',
#  'MICROMIDAS',
#  'MICROSOFT TECHNOLOGY LICENSING',
#  'MIETAMARK GENETICS',
#  'MILLENIUM SYNTHFUELS CORPORATION',
#  'Macronix International Co.',
#  'Magna International Inc.',
#  'Magnachip Semiconductor',
#  'Magnolia Optical Technologies',
#  'Magnolia Solar',
#  'Mainstream Engineering Corp.',
#  'Marathon Equipment Company',
#  'Marine Polymer Technologies',
#  'Markel Corporation',
#  'Materia',
#  'Mattson Technology',
#  'Maxout Renewables',
#  'McAlister Technologies',
#  'McElroy Manufacturing',
#  'Mediatek Inc.',
#  'Medical Diagnostic Laboratories',
#  'Medicis Pharmaceutical Corporation',
#  'Meso Scale Technologies',
#  'Met Tech Inc.',
#  'Metabolix',
#  'Meyer Tool',
#  'Michigan Biotechnology Institute',
#  'Micro Cooling Concepts',
#  'MicroContinuum',
#  'MicroLink Devices',
#  'Microchip Technology Incorporated',
#  'Microchips Biotech',
#  'Micron Technology',
#  'Microsemi SoC Corporation',
#  'Midori USA',
#  'Midrex Technologies',
#  'Milliken & Company',
#  'Minebea Co.',
#  'MirTech',
#  'Mission Product Holdings',
#  'Mitsubishi Electric Corporation',
#  'Mitsubishi Metal Corporation',
#  'Molecular Rebar Design',
#  'Momentive Performance Materials GmbH',
#  'MonoSol',
#  'Monsanto Technology LLC',
#  'Moxtek',
#  'Murata Manufacturing Co.',
#  'Musco Corporation',
#  'NANO CELL SYSTEMS',
#  'NANOBIO CORPORATION',
#  'NCC Nano',
#  'NEC Corporation',
#  'NGK Spark Plug Co.',
#  'NLT TECHNOLOGIES',
#  'NOK Corporation',
#  'NOVA Chemicals (International) S.A.',
#  'NanoGram Corporation',
#  'NanoLab',
#  'NanoMech',
#  'NanoOncology',
#  'NanoTech Lubricants',
#  'Nanoco Technologies',
#  'Nanocopocia',
#  'Nanoholdings',
#  'Nanomix',
#  'Nanoquantum Sciences',
#  'Nanoridge Materials',
#  'Nanospectra Biosciences',
#  'Nanosys',
#  'Nanotech Biomachines',
#  'Nanotek Instruments',
#  'Nantero',
#  "Nationwide Children's Hospital",
#  'Nederlandse Organisatie voor toegepast-natuurwetenschappelijk onderzoek TNO',
#  'NeoPhotonics Corporation',
#  'NeoVision LLC',
#  'NetApp',
#  'NeuMoDx Molecular',
#  'Neural Signals',
#  'Neutronic Perpetual Innovations',
#  'New England Biolabs',
#  'New Technology Ventures',
#  'Newdoll Enterprises LLC',
#  'Newlans',
#  'Newport Corporation',
#  'Nexcom Technology',
#  'Nikon Corporation',
#  'Nippon Chemi-Con Corporation',
#  'Nippon Shokubai Co.',
#  'Nissan North America',
#  'Nokia Corporation',
#  'Nokomis',
#  'Nordic Technologies',
#  'Nordson Corporation',
#  'Northrop Grumman Systems Corporation',
#  'Northwest Biotherapeutics',
#  'Nova Technologies',
#  'Novartis AG',
#  'Novon',
#  'Novozymes A/S',
#  'Novus Technology',
#  'Nthdegree Technologies Worldwide Inc.',
#  'NuOrtho Surgical',
#  'Nutech Ventures',
#  'Nvidia Corporation',
#  'O.B.I. Inc.',
#  'OAS Design Group',
#  'OFS Fitel',
#  'OLYMPUS CORPORATION',
#  'OPTERRA ENERGY SERVICES',
#  'OSI Optoelectronics',
#  'Oceanit Laboratories',
#  'Oculus VR',
#  'Oki Data Corporation',
#  'Olympus NDT',
#  'OmniVision Technologies',
#  'Omron Corporation',
#  'One Earth Designs Inc.',
#  'Opel Solar',
#  'Optodot Corporation',
#  'Oracle International Corporation',
#  'OrbusNeich Medical',
#  'Ormat Technologies Inc.',
#  'Ortho-Clinical Diagnostics',
#  'Osram Sylvania Inc.',
#  'Ostendo Technologies',
#  'Owens-Brockway Glass Container Inc.',
#  'PACCAR Inc',
#  'PAX Scientific',
#  'PDF Solutions',
#  'PELLION TECHNOLOGIES',
#  'PLEX LLC',
#  'PLYCEM USA',
#  'PNM',
#  'POET Research',
#  'POSiFA MICROSYSTEMS',
#  'PPG Industries Ohio',
#  'PQ CORPORATION',
#  'Pacific Biosciences of California',
#  'Pacific Industrial Development Corporation',
#  'Pacific Light Technologies',
#  'Palo Alto Research Center Incorporated',
#  'Pansonic Corporation',
#  'Paratek Pharmaceuticals',
#  'Pardev',
#  'Parion Sciences',
#  'Pegatron Corporation',
#  'Pendar Technologies',
#  'Pentair Thermal Management LLC',
#  'Pentron Clinical Technologies',
#  'Performance Plants',
#  'Perkinelmer Holdings',
#  'PeterBrod Corp.',
#  'PetraSolar',
#  'Peytant Solutions',
#  'Pfizer Inc.',
#  'Pharmatrophix',
#  'Pharmion Corporation',
#  'Phillips 66 Company',
#  'Phoseon Technology',
#  'Photon Dynamics',
#  'Piksel',
#  'Pinnacle Technology',
#  'Pioneer Energy',
#  'Pixar',
#  'Pixelligent Technologies',
#  'Plant Sensory Systems',
#  'Plasma-Therm',
#  'PluroGen Therapeutics',
#  'Polaris Products LLC',
#  'Poly-Med',
#  'PolyOne Corporation',
#  'PolyPlus Battery Company',
#  'Polysar Corporation',
#  'PortaFire',
#  'Power Integrations',
#  'Praxair S.T. Technology',
#  'Previvo Genetics',
#  'Princeton Optronics',
#  'ProNAi Therapeutics',
#  'Production Resource Group',
#  'Professional Compounding Centers of America',
#  'Propagation Research Associates',
#  'Proterra Inc.',
#  'Proton Power',
#  'Pulse Therapeutics',
#  'QUALCOMM Incorporated',
#  'Qiagen GmbH',
#  'Quantapore',
#  'Quantum Devices',
#  'Quantum Materials Corporation',
#  'R.A. Miller Industries',
#  'RADIANCE SOLAR',
#  'RES USA',
#  'RF Micro Devices',
#  'Rapamycin Holdings',
#  'Raytheon Company',
#  'Rebellion Photonics',
#  'Red Hat',
#  'Regeneron Pharmaceuticals',
#  'Reliance Controls Corporation',
#  'Relypsa',
#  'Renesas Electronics Corporation',
#  'Renewable Power Conversion',
#  'RenovaCare Sciences Corp.',
#  'Research Triangle Institute',
#  'Revera',
#  'Revivicor',
#  'Reynolds Technologies',
#  'Richtek Technology Corporation',
#  'Ricoh Company Limited',
#  'Rima Enterprises',
#  'Rio Grande Valley Sugar Growers',
#  'Riverbed Technology',
#  'Robert Bosch GmbH',
#  'Roche Diagnostics GmbH',
#  'Roche Molecular Systems',
#  'Rockwell Automation Technologies',
#  'Rockwell Collins',
#  'Rohm and Haas Electronic Materials LLC',
#  'Roll-N-Lock Corporation',
#  'Rolls-Royce PLC',
#  'S&S X-Ray Products',
#  'S. C. Johnson & Son',
#  'SABIC GLOBAL TECHNOLOGIES B.V.',
#  'SAE Magnetics (HK) Ltd.',
#  'SAINT-GOBAIN ABRASIFS',
#  'SAMSUNG DISPLAY CO.',
#  'SB ENERGY',
#  'SD Technologies',
#  'SEEK THERMAL',
#  'SEIKO NPC Corporation',
#  'SELMAN AND ASSOCIATES',
#  'SEaB Energy Holdings Ltd.',
#  'SICPA Holding SA',
#  'SII Semiconductor Corporation',
#  'SOL-ELECTRICA',
#  'SOLAZYME',
#  'SPC International',
#  'SPICE SOLAR',
#  'SRG Global',
#  'STANDARD ALCOHOL COMPANY OF AMERICA',
#  'STATS ChipPAC',
#  'SUMITOMO WIRING SYSTEMS',
#  'SUNSALUTER',
#  'SYNTHOMER USA LLC',
#  'Sagacious Investment Group L.L.C.',
#  'Saint-Gobain Adfors Canada',
#  'Saint-Gobain Ceramics & Plastics',
#  'Saint-Gobain Performance Plastics Corporation',
#  'Samsung Electronics',
#  'Samsung SDI Co.',
#  'SanDisk Technologies LLC',
#  'Sandia Corporation',
#  'Sangamo BioSciences',
#  'Sanken Electric Co.',
#  'Sanofi',
#  'Sanuvox Technologies',
#  'Sanyo Electric Co.',
#  'Schlumberger Technology Corporation',
#  'Schneider Electric Solar Inverters USA',
#  'Schneider Electric USA',
#  'Scientific Design Company',
#  'Seagate Technology LLC',
#  'Seetron Inc.',
#  'Seiko Epson Corporation',
#  'Seiko Instruments Inc.',
#  'Selas Heat Technology Company LLC',
#  'Selecta Biosciences',
#  'Selkermetrics',
#  'Semiconductor Energy Laboratory Co.',
#  'Semics Inc.',
#  'Semprius',
#  'Senaya',
#  'Senga Advisors',
#  'Sensor Electronic Technology',
#  'Sensor-Kinesis Corporation',
#  'Sequenom',
#  'ServiceNow',
#  'Sharp Laboratories of America',
#  'Shell Oil Company',
#  'Shin-Etsu Chemical Co.',
#  'Shoals Technologies Group',
#  'Sick AG',
#  'Siemens Aktiengesellschaft ',
#  'Siemens Medical Solutions USA',
#  'Sienna Biopharmaceuticals',
#  'Sigma-Aldrich Co. LLC',
#  'Silicon Genesis Corporation',
#  'Silicon Space Technology Corp.',
#  'Silicon Storage Technology',
#  'Siliconware Precision Industries Co.',
#  'Silicor Materials Inc.',
#  'Siluria Technologies',
#  'Sima Therapeutics',
#  'Simbol Inc.',
#  'Sinewatts',
#  'Singular Bio',
#  'Singulex',
#  'Sinton Consulting',
#  'Sion Power Corporation',
#  'SixPoint Materials',
#  'Skidmore',
#  'Smart Planet Technologies',
#  'Smith & Nephew',
#  'SolAero Technologies Corp.',
#  'Sola U.S.A. Inc.',
#  'SolaBlock LLC',
#  'Solaire Generation LLC',
#  'Solan',
#  'Solar Junction Corporation',
#  'Solar-Tectic LLC',
#  'SolarCity Corporation',
#  'SolarLego Inc.',
#  'SolarReserve Technology',
#  'SolarWorld Americas Inc.',
#  'Solarmer Energy',
#  'Solight Solar',
#  'Soliton Lasers',
#  'Solvay Specialty Polymers USA',
#  'Sony Corporation',
#  'Sony Interactive Entertainment America LLC',
#  'Soraa',
#  'Soraa Laser Diode',
#  'Southwest Research Institute',
#  'St. Jude Medical',
#  'St. Microelectronics Inc.',
#  'Stablcor Technology',
#  'Stanley Electric Co.',
#  'Star Technology and Research',
#  'Starlight Energy Holdings LLC',
#  'Starsource Scientific LLC',
#  'Stora Enso Oyj',
#  'Stratasys',
#  'Suganit Systems',
#  'Sumco Corporation',
#  'Sumitomo Electric Device Innovations',
#  'Sumitomo Electric Industries',
#  'Sumitomo Rubber Industries',
#  'Sun Chemical Corporation',
#  'Sun Drilling Products Corporation',
#  'Sun Synchrony',
#  'SunCulture Solar Inc.',
#  'SunEdison',
#  'SunEdison Semiconductor Limited',
#  'SunLink Corporation',
#  'SunPower Corporation',
#  'SunRun',
#  'Suncore Photovoltaics',
#  'Sundrop Fuels',
#  'Sungevity Inc.',
#  'Sunlight Photonics Inc.',
#  'Supremex Inc.',
#  'Surebeam Corporation',
#  'Sustainable Technologies',
#  'Swagelok Company',
#  'Sweetwater Energy',
#  'Swift Engineering',
#  'Symantec Corporation',
#  'Synaptic Research',
#  'Syngenta Participations AG',
#  'Synopsys',
#  'Synthetic Genomics',
#  'System Biosciences',
#  'T.H.E.M.',
#  'TDK Corporation',
#  'TECNIUM',
#  'TEKNOR APEX COMPANY',
#  'THE BOARD INSTITUTE',
#  'THYSSENKRUPP INDUSTRIAL SOLUTIONS GMBH',
#  'TMC Corporation',
#  'TOMOWAVE LABORATORIES',
#  'TP Solar',
#  'TRANE INTERNATIONAL INC.',
#  'TRI ALPHA ENERGY',
#  'TRIDONIC GMBH & CO KG',
#  'TT Technologies',
#  'Taiwan Semiconductor Manufacturing Company',
#  'Taiyo Ink Mfg. Co.',
#  'Takara Bio Inc.',
#  'Takeda Pharmaceutical Company Limited',
#  'Tamura Corporation',
#  'Tapwave',
#  'Tarveda Therapeutics',
#  'Tata Consultancy Services Limited',
#  'Tau Therapeutics LLC',
#  'Tela Innovations',
#  'Teledyne Scientific & Imaging',
#  'Teradata US',
#  'Terra Caloric',
#  'Tersus Environmental',
#  'Tessera',
#  'Texas Research International',
#  'The Babcock & Wilcox Company',
#  'The Boeing Company',
#  'The Carbon Cable Company',
#  'The Charles Stark Draper Laboratory',
#  'The Eastern Co.',
#  'The Goodyear Tire & Rubber Company',
#  'The Henry M. Jackson Foundation for the Advancement of Military Medicine',
#  'The Jackson Laboratory',
#  'The Paymaster Corporation',
#  'The Samuel Roberts Noble Foundation',
#  'Theraclone Sciences',
#  'Thorlabs',
#  'Thorn Bioscience LLC',
#  'Tigo Energy',
#  'Toda Kogyo Corporation',
#  'Tokyo Electron Limited',
#  'Tokyo Ohka Kogyo Co.',
#  'Toray Industries Inc. ',
#  'Toray Plastics (America)',
#  'Toshiba America Electronic Components',
#  'Tosoh Corporation',
#  'Total Marketing Services',
#  'Toyota Motor Engineering & Manufacturing North America',
#  'Transilwrap Company',
#  'Transitions Optical',
#  'Transposagen Biopharmaceuticals',
#  'Transtron Solutions LLC',
#  'Travis Industries',
#  'Triple Ring Technologies',
#  'True-Safe Technologies',
#  'Tufts Medical Center',
#  'Turtle Beach Corporation',
#  'Two Blades Foundation',
#  'Tyco Electronics Corporation',
#  'U S MICROPOWER INC',
#  'U.S. NUTRACEUTICALS',
#  'UCB Pharma S.A.',
#  'UChicago Argonne',
#  'UOP LLC',
#  'UT-Battelle',
#  'UWM Research Foundation',
#  'Ube Industries',
#  'Uni-Charm Corporation',
#  'Unifrax I LLC',
#  'Uniseal Solutions Inc.',
#  'Unistrut International Corp.',
#  'United Microelectronics Corp.',
#  'United Technologies Corporation',
#  'Unity Semiconductor Corporation',
#  'Universal Display Corporation',
#  'Universal Leaf Tobacco Co.',
#  'VEECO PRECISION SURFACE PROCESSING LLC',
#  'VIASAT INC.',
#  'VINDICO NANOBIO TECHNOLOGY INC.',
#  'VINYLAST',
#  'VIOLIN MEMORY',
#  'VMware',
#  'Vadient Optics',
#  'Valicor',
#  'Vascular BioSciences',
#  'Vaxiion Therapeutics',
#  'Veracode',
#  'Veracyte',
#  'Verliant Energy',
#  'Virent',
#  'Vizio Inc.',
#  'Vorbeck Materials Corporation',
#  'Voxtel',
#  'W&Wsens Devices',
#  'WAFERTECH',
#  'WCA Group LLC',
#  'WHATSAPP INC.',
#  'WOVN',
#  'Waters Technologies Corporation',
#  'Watlow Electric Manufacturing Company',
#  'Wave Energy Conversion Corporation of America',
#  'Weatherford Canada Partnership',
#  'Wenger Corporation',
#  'WestPoint Home',
#  'WiSys Technology Foundation',
#  'Wikipad',
#  'Winbond Electronics Corp.',
#  'Wine.com',
#  'Wireless Environment',
#  'Wizard Labs',
#  'Wostec',
#  'Wyatt Technology Corporation',
#  'Xerox Corporation',
#  'Xintec Inc.',
#  'Xyleco',
#  'Yageo Corporation',
#  'Yamaha Corporation',
#  'Yeda Research and Development Co.',
#  'Yissum',
#  'ZENA TECHNOLOGIES',
#  'ZIH Corp.',
#  'ZON',
#  'Zeno Semiconductor Inc',
#  'Zephyr Energy Systems LLC',
#  'Zoetis Services LLC',
#  'Zygo Corporation',
#  'aTyr Pharma',
#  'bioTheranostics',
#  'eNow',
#  'fybr',
#  'iBio',
#  'iNanoBio LLC',
#  'k-Space Associates',
#  'mVerify Corporation',
#  'nLIGHT',
#  'nanoComposix'}

# %%
def get_ordered_about_urls (firm_name):
    urls = list (abouts.loc[(abouts['firm_name'] == firm_name) & (abouts['is_about'] == 1), 'url'])
    urls.sort(key = len)
    # print ('Original urls')
    # pp.pprint(urls)

    index = {}
    for url in urls:
        path_fragments = len(url.split('/'))
        added = False
        for i in range(1, path_fragments):
            key_phrase = url.rsplit('/', maxsplit=i)[0]
            if key_phrase in urls or (key_phrase + '/') in urls: 
                od = index.setdefault(key_phrase, OrderedDict())
                od[url] = 1
                added = True
                continue
        if not added:
            od = index.setdefault(url, OrderedDict())
            od[url] = 1
 
    
    # pp.pprint (index)
    return_urls = [] # OrderedDict((item, 1)for sublist in list(index.values()) for item in sublist)
    seen = set ()
    for key in index.keys():
        tree_urls = index[key]
        for fu in tree_urls:
            if fu not in seen:
                return_urls.append(fu)
                seen.add(fu)
    
    return return_urls

test_urls = get_ordered_about_urls ('Apple Inc.')
print ('Ordered urls')
pp.pprint (test_urls)
# Out:
# Ordered urls
# []

# %%
# remove html content
def is_javascript (x):
    match_string = r"(CDATA|return\s+true|return\s+false|getelementbyid|function|\w+\(.*?\);|\w{2,}[\\.|:]+\w{2,}|'\w+':\s+'\w+|\\|{|}|\r|\n|\/\/')"
    # capture CDATA; function declarations; function calls; word sequences separated by a period (e.g., denoting paths)
    regex = re.findall(match_string, x) 
    # check to see if the regex finds some percentage of the words look like javascript patterns
    if (len(regex) / float(len(x.split())) > .10):
        return True 
    else:
        return False

def clean_page_content (text_list):
    # remove whatever we think is html
    removed_html = filter(lambda x: not( bool(BeautifulSoup(x, "html.parser").find()) ), text_list)
    # remove content that looks like javascript 
    removed_js = filter(lambda x: not (is_javascript(x)), removed_html)
    # add other checks here as needed

    return removed_js
    

# iterate through firm urls and return concatenated string
def get_url_content (urls): 
    running_text = ''
    for url in urls:
        print ('\tWorking on ' + url)
        result = col.find_one( {"url": url} )
        if result:
            clnd_text = clean_page_content(result['full_text'])
            clnd_text = '\n'.join(clnd_text)
            boilerpipe = None
            
            if 'body' in result:
                extractor = Extractor(extractor='DefaultExtractor', html = result['body'][0])
                lines = extractor.getText().replace(u'\xa0', u' ').split('\n')
                filtered = filter(lambda x: not re.match(r'^\s*$', x), lines)
                boilerpipe = '\n'.join(filtered)

            # TODO fix to split().  Counting characters currently 
            if boilerpipe and (len(boilerpipe) > .5 * len(clnd_text)):
                print ('\t\tUsing boilerplate')
                running_text += boilerpipe
            else:
                print ('\t\tUsing clnd_text')
                running_text += clnd_text
        else:
            print ('Cannot find url: ' + url)

    return running_text

# %%
# regex test 
regex = re.findall(r"(CDATA|return\s+true|return\s+false|getelementbyid|function|\w+\(.*?\);|\w{2,}[\\.|:]+\w{2,}|'\w+':\s+'\w+|\\|{|}|\r|\n|\/\/')", 
                   "CDATA function contact-us getelementbyid javascript.function linker:autoLink www.littlekidsinc.com fxnCall(param.param); email@dextr.us 'type': 'image' return true return false rev7bynlh\\u00252bvcgrjg\\ {height}") # last part is words sequences separated by punct
print (regex)
# Out:
# ['CDATA', 'function', 'getelementbyid', 'javascript.function', 'linker:autoLink', 'www.littlekidsinc', 'fxnCall(param.param);', 'dextr.us', "'type': 'image", 'return true', 'return false', 'rev7bynlh\\u00252bvcgrjg', '\\', '{', '}']

# %%
test_site_text = get_url_content (test_urls)
print (test_site_text)
# Out:
# 	Working on https://www.terratechcorp.com/about
# 		Using boilerplate
# 	Working on https://www.terratechcorp.com/about/mission-vision-and-values
# 		Using boilerplate
# A Greener World
# Committed to cultivating and providing the highest quality cannabis and other agricultural products
# Medical Cannabis
# & Urban Agriculture
# Terra Tech Corp is a vertically integrated cannabis-focused agriculture company. We’re pioneering the future by integrating the best of the natural world with technology to create sustainable solutions for medical cannabis production, extraction and distribution, plant science research and development, food production and Closed Environment Agriculture (CEA). Through this development, we have created relevant brands in both the cannabis and agriculture industries.
# Committed to Cultivating and Providing
# The Highest Quality Medical Cannabis
# Through multiple subsidiaries in this space, we are committed to cultivating and providing the highest quality medical cannabis consistently delivered to qualified, registered medical marijuana establishments in the safest and most secure manner.
# Our commitment to advancing research within the medical cannabis industry will lead our approach in cultivating and cross-breeding strains of medical cannabis that treat a variety of ailments. We are uniquely positioned to operate safe and successful medical cannabis cultivation facilities throughout the United States.
# "U.S. Legal Pot Sales Expected to Hit $8 Billion Per Year By 2018"
# -Huffington Post
# Our Dispensary Model
# Our dispensary model is simple: providing consistency in every patient experience. We are setting a higher standard for patients who utilize our dispensaries – they can expect the same look, feel, experience and strong sense of security at every location.
# Regardless of the state or specific dispensary, patients will know they are obtaining the best product available on the market today.
# Benefits of Cultivating Cannabis
# With Our Superior Agriculture
# We’ve harnessed the power of our superior agricultural experience to cultivate cannabis in state-of-the-art, environmentally controlled greenhouses. This positions us as the future sole leader in the booming cannabis market.
# Our proven greenhouse growing systems perform reliably, sustainably and profitably:
# Energy efficiency
# offers operational
# Up to
# 30% More
# Sustainable Farming Is Our Passion
# Our produce subsidiary, Edible Garden®, was founded to meet a growing demand from both retailers and consumers to have year-round access to culinary greens unaffected by unstable market forces.
# The company is now a fast-growing family of co-op local growers across the United States, specializing in fresh, hydroponic, non-GMO produce, herbs and leafy greens. Their local farmers deliver the safest, most nutrient-rich products to the same convenient supermarkets where customers do their regular shopping. While other brands – including those certified organic – are often imported from outside the United States. Edible Garden®’s local farmers exclusively grow, pack and ship their own products. This business model allows for unsurpassed monitoring and quality assurance, from planting to delivery.
# Our Products and Facilities are Certified Fresh from:
# A Look Back As We Leap Forward
# We have reached major milestones in the growth potential for Terra Tech, in
# addition to groundbreaking changes in the medical cannabis industry.
# Feb. 2012
# June 2013
# 2013
# More than doubled supermarket presence from 300 to 800 stores
# June 2014
# Oct. 2014
# Nov. 2014
# Dec. 2014
# Dec. 2014
# Dec. 2014
# Launched IVXX™, one of the nations first brands of cannabis products
# 2014
# 2014 totals
# Received over 200 media impressions in print, broadcast and internet
# Giving Back
# Our brands have a social mandate to give back. What does that mean? Well to us it doesn’t just mean writing a check, it means getting involved whether it be an environmental concern or social reform. Our people and our partners get involved with our efforts to change the lives of others. Below are a few of our favorite organizations. Take some time to get involved too!
# Leadership
# Our extensive experience and knowledge in agriculture positions us to create,
# grow and sell the highest premium cannabis brand on the market.Our Mission
# Our mission is to bring to market innovative agricultural products, to create a quality work environment for our employees, to offer our customers products they feel good about buying and to invest in our future.
# Our Vision
# Our vision is to help transform, through both innovation and brand development, the way we utilize plants to enhance both the well-being of our bodies and the sustainability of our planet.
# Why We Wake Up In The Morning
# To develop the best products we can and to use our company to push for environmental and social change.
# Environmental Change
# Our environmental resources are depleting at a rapid pace. We know there is a better way for industry and environment to coexist, and we are committed to work to that end.
# Social Change
# Thousands of people are in prison for the production and distribution of cannabis in our country. Families are torn apart and lives have been ruined for growing a plant. Cannabis has changed the lives of sick patients, created jobs for the unemployed and injected our national, state and local economies with tax revenue. We are committed to help right the wrongs of the past and to develop a transparent and accountable cannabis community.

# %%
# standard firm cleaning regex
def clean_firm_name (firm):
    firm_clnd = re.sub('(\.|,| corporation| incorporated| llc| inc| international| gmbh| ltd)', '', firm, flags=re.IGNORECASE).rstrip()
    return firm_clnd

# %%
# run process_firm and write to file
pp = pprint.PrettyPrinter()
for firm_name in firm_names: 
    print ("Working on " + firm_name)
    about_urls = get_ordered_about_urls(firm_name)
    about_text = get_url_content (about_urls)
    
    if about_text: 
        firm_clnd = clean_firm_name(firm_name) # standard cleaning code throughout project
        file = re.sub('\/', '|', firm_clnd) + '.txt'
        with io.open(DATA_DIR + file,'w',encoding='utf8') as f:
            f.write (about_text)
    else:
        print ("Couldn't find any text for firm!")
# Out:
# Working on E. Tech Incorporation
# 	Working on https://www.terratechcorp.com/about
# 		Using boilerplate
# 	Working on https://www.terratechcorp.com/about/mission-vision-and-values
# 		Using boilerplate
# Working on COVERIS FLEXIBLES US LLC
# 	Working on http://www.coveris.com/company/
# 		Using boilerplate
# 	Working on http://www.coveris.com/company/about-us/
# 		Using boilerplate
# Working on Little Kids
# 	Working on http://www.littlekidsinc.com/about-us
# 		Using boilerplate
# Working on Neutronic Perpetual Innovations
# 	Working on http://npimobile.com/about-us/
# 		Using boilerplate
# Working on Englewood Lab
# 	Working on http://englewoodlab.com/about-us/
# 		Using boilerplate
# 	Working on http://englewoodlab.com/about-us/history/
# 		Using boilerplate
# Working on Optodot Corporation
# 	Working on http://optodot.com/about-us
# 		Using boilerplate
# Working on Nippon Chemi-Con Corporation
# 	Working on http://www.chemi-con.co.jp/e/company/index.html
# 		Using boilerplate
# Working on Cedar Ridge Research
# 	Working on http://cr-res.com/who-we-are
# 		Using boilerplate
# 	Working on http://cr-res.com/who-we-are/
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:219: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# 		Using boilerplate
# 	Working on http://cr-res.com/crr-history/
# 		Using clnd_text
# Working on BROADCOM CORPORATION
# 	Working on https://www.broadcom.com/
# 		Using clnd_text
# 	Working on https://www.broadcom.com/company/about-us/
# 		Using clnd_text
# Working on Boston Scientific Scimed
# 	Working on http://www.bostonscientific.com/en-US/about-us.html
# 		Using clnd_text
# 	Working on http://www.bostonscientific.com/en-US/about-us/awards.html
# 		Using boilerplate
# 	Working on http://www.bostonscientific.com/en-US/about-us/history.html
# 		Using clnd_text
# 	Working on http://www.bostonscientific.com/en-US/about-us/who-we-are.html
# 		Using clnd_text
# Working on MonoSol
# 	Working on https://www.monosol.com/about/
# 		Using boilerplate
# 	Working on https://www.monosol.com/about/awards/
# 		Using boilerplate
# 	Working on https://www.monosol.com/about/monosol-af-ltd-tax-strategy/
# 		Using clnd_text
# Working on ACell
# 	Working on https://acell.com/about-us/
# 		Using boilerplate
# Working on Carver Scientific
# ''
# Working on SunCulture Solar Inc.
# 	Working on http://solpad.com/about-us/
# 		Using boilerplate
# Working on ESCAPE THERAPEUTICS
# 	Working on http://escapetherapeutics.com/mission.html
# 		Using boilerplate
# 	Working on http://escapetherapeutics.com/overview.html
# 		Using boilerplate
# Working on Gas Technology Institute
# 	Working on https://www.gti.energy/about/
# 		Using clnd_text
# 	Working on https://www.gti.energy/about/subsidiaries/
# 		Using boilerplate
# 	Working on https://www.gti.energy/about/corporate-citizenship/
# 		Using boilerplate
# 	Working on https://www.gti.energy/about/mission-values-history/
# 		Using boilerplate
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://news.pg.com/press-release/pg-corporate-announcements/pg-recognizes-top-performing-global-partners-0" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# Working on Marine Polymer Technologies
# ''
# Working on Proterra Inc.
# ''
# Working on Alcotek
# 	Working on https://alcotek.com/about-us/
# 		Using boilerplate
# Working on ASML Netherlands B.V.
# 	Working on https://www.asml.com/company/who-we-are/en/s277?rid=51980
# 		Using clnd_text
# 	Working on https://www.asml.com/company/what-we-do/en/s277?rid=51981
# 		Using clnd_text
# 	Working on https://www.asml.com/company/our-history/en/s277?rid=51985
# 		Using clnd_text
# 	Working on https://www.asml.com/company/organization/en/s277?rid=51984
# 		Using clnd_text
# 	Working on https://www.asml.com/company/why-we-exist/en/s277?rid=51983
# 		Using clnd_text
# 	Working on https://www.asml.com/company/how-we-do-it/en/s277?rid=51979
# 		Using clnd_text
# 	Working on https://www.asml.com/company/in-a-nutshell/en/s277?rid=51978
# 		Using clnd_text
# Working on mVerify Corporation
# 	Working on https://numverify.com/about
# 		Using boilerplate
# Working on ACUCELA INC.
# 	Working on https://www.acucela.com/company/index.html
# 		Using clnd_text
# 	Working on https://www.acucela.com/company/information/index.html
# 		Using clnd_text
# Working on Universal Display Corporation
# 	Working on https://oled.com/about/
# 		Using clnd_text
# 	Working on https://oled.com/about/awards/
# 		Using boilerplate
# 	Working on https://oled.com/about/history/
# 		Using clnd_text
# Working on Apple Inc.
# ''
# Working on Arcturus Therapeutics
# 	Working on https://arcturusrx.com/about-arcturus/
# 		Using boilerplate
# Working on Innolux Corporation
# 	Working on http://www.innolux.com/Pages/EN/AboutUs_EN.html
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://www.innolux.com/Pages%2fcn%2fAboutUs_cn.html" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://www.innolux.com/Pages%2ftw%2fAboutUs_tw.html" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://www.innolux.com/Pages%2fen%2fAboutUs_en.html" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://www.innolux.com/Pages%2fcn%2fAboutUs%2fMilestones_cn.html" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://www.innolux.com/Pages%2ftw%2fAboutUs%2fMilestones_tw.html" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://www.innolux.com/Pages%2fen%2fAboutUs%2fMilestones_en.html" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://www.innolux.com/Pages%2fcn%2fAboutUs%2fCompany_Overview_cn.html" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://www.innolux.com/Pages%2ftw%2fAboutUs%2fCompany_Overview_tw.html" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://www.innolux.com/Pages%2fen%2fAboutUs%2fCompany_Overview_en.html" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://www.innolux.com/Pages%2fcn%2fAboutUs%2fHonors_and_Awards_cn.html" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://www.innolux.com/Pages%2ftw%2fAboutUs%2fHonors_and_Awards_tw.html" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://www.innolux.com/Pages%2fen%2fAboutUs%2fHonors_and_Awards_en.html" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# 		Using boilerplate
# 	Working on http://www.innolux.com/Pages/EN/AboutUs/Milestones_EN.html
# 		Using clnd_text
# 	Working on http://www.innolux.com/Pages/EN/AboutUs/Company_Overview_EN.html
# 		Using clnd_text
# 	Working on http://www.innolux.com/Pages/EN/AboutUs/Honors_and_Awards_EN.html
# 		Using boilerplate
# Working on Immunolight
# 	Working on http://www.immunolight.com/company/
# 		Using clnd_text
# 	Working on http://www.immunolight.com/company/blog/
# 		Using boilerplate
# Working on Dana Corporation
# 	Working on http://www.dana.com/corporate-pages/history
# 		Using boilerplate
# Working on GlaxoSmithKline Biologicals
# 	Working on https://www.gsk.com/en-gb/about-us/
# 		Using clnd_text
# 	Working on https://www.gsk.com/en-gb/about-us/vaccines/
# 		Using clnd_text
# 	Working on https://www.gsk.com/en-gb/about-us/our-history/
# 		Using clnd_text
# 	Working on https://www.gsk.com/en-gb/about-us/pharmaceuticals/
# 		Using clnd_text
# 	Working on https://www.gsk.com/en-gb/investors/about-gsk/
# 		Using clnd_text
# 	Working on https://www.gsk.com/en-gb/careers/culture-and-values/
# 		Using clnd_text
# Working on Baker Hughes Incorporated
# 	Working on https://www.bhge.com/our-company
# 		Using boilerplate
# Working on TMC Corporation
# 	Working on http://www.tcm.com/my-profile/index.html
# 		Using boilerplate
# Working on The Carbon Cable Company
# 	Working on https://www.thecableco.com/about-us
# 		Using clnd_text
# 	Working on https://www.thecableco.com/chord_company.html
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:219: UserWarning: "b'/'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# 		Using clnd_text
# 	Working on https://www.thecableco.com/vibrapod_company.html
# 		Using clnd_text
# 	Working on https://www.thecableco.com/the_cable_company.html
# 		Using clnd_text
# Working on Carestream Health
# 	Working on https://www.carestream.com/en/us/corporate
# 		Using clnd_text
# 	Working on https://www.carestream.com/en/us/corporate/company-history
# 		Using clnd_text
# Working on Humanetics Corporation
# 	Working on http://www.humaneticsatd.com/about-us
# 		Using clnd_text
# Working on Seiko Epson Corporation
# 	Working on https://global.epson.com/company/
# 		Using clnd_text
# 	Working on https://global.epson.com/company/glance/
# 		Using clnd_text
# 	Working on https://global.epson.com/innovation/vision/
# 		Using boilerplate
# Working on Analog Devices
# 	Working on https://www.analog.com/en/about-adi.html
# 		Using boilerplate
# 	Working on https://www.analog.com:443/en/myhistory.html
# 		Using boilerplate
# Working on Samsung SDI Co.
# 	Working on http://samsungsdi.com/about-sdi.html
# 		Using boilerplate
# 	Working on http://samsungsdi.com/about-sdi/history.html
# 		Using boilerplate
# 	Working on http://samsungsdi.com/about-sdi/research-development.html
# 		Using boilerplate
# Working on VINYLAST
# 	Working on http://palisaderail.com/about-vinylast/
# 		Using boilerplate
# Working on Faurecia Interior Systems
# 	Working on http://www.faurecia.com/en/group/history
# 		Using clnd_text
# 	Working on http://www.faurecia.com/en/group/vision-and-strategy
# 		Using boilerplate
# 	Working on http://www.faurecia.com/en/group/convictions-and-values
# 		Using boilerplate
# 	Working on http://www.faurecia.com/en/newsroom/efmd-awards-faurecia-clip-accreditation-its-corporate-university
# 		Using boilerplate
# Working on ATTOSTAT
# 	Working on http://www.attostat.com/about-us
# 		Using clnd_text
# 	Working on http://www.attostat.com/about-us/
# 		Using clnd_text
# Working on Ablexis
# 	Working on http://www.ablexis.com/about/
# 		Using boilerplate
# Working on Shin-Etsu Chemical Co.
# 	Working on http://www.shinetsu.co.jp/en/company/
# 		Using clnd_text
# 	Working on http://www.shinetsu.co.jp/en/company/r_d.html
# 		Using clnd_text
# 	Working on http://www.shinetsu.co.jp/en/company/movie.html
# 		Using boilerplate
# 	Working on http://www.shinetsu.co.jp/en/company/history.html
# 		Using clnd_text
# 	Working on http://www.shinetsu.co.jp/en/company/profile.html
# 		Using clnd_text
# 	Working on http://www.shinetsu.co.jp/en/company/quality.html
# 		Using clnd_text
# Working on Yamaha Corporation
# 	Working on http://yamaha-motor.com/corporate/home.aspx
# 		Using clnd_text
# Working on Elenion Technologies
# 	Working on https://elenion.com/summary/
# 		Using boilerplate
# Working on Senaya
# 	Working on http://www.senaya.com/about-us/
# 		Using boilerplate
# Working on Solarmer Energy
# 	Working on http://solarmer.com/aboutus/
# 		Using boilerplate
# Working on CellPrint IP Holding
# 	Working on https://cellprintbiotechnology.com/about/company/
# 		Using boilerplate
# Working on LG Electronics Inc.
# ''
# Working on Braun Intertec Geothermal
# 	Working on https://braunintertec.com/about-us/
# 		Using boilerplate
# 	Working on https://braunintertec.com/about-us/awards/
# 		Using boilerplate
# 	Working on https://braunintertec.com/about-us/history/
# 		Using boilerplate
# Working on DRS Network & Imaging Systems
# 	Working on https://www.leonardodrs.com/about-us/
# 		Using boilerplate
# 	Working on https://www.leonardodrs.com/about-us/ethics/
# 		Using boilerplate
# 	Working on https://www.leonardodrs.com/about-us/our-structure/
# 		Using clnd_text
# 	Working on https://www.leonardodrs.com/about-us/thought-leadership/
# 		Using clnd_text
# Working on Ferro Corporation
# 	Working on https://www.ferro.com/about/vision-values-and-mission
# 		Using boilerplate
# Working on Columbia Insurance Company
# 	Working on http://colinsgrp.com/site/history
# 		Using boilerplate
# 	Working on http://colinsgrp.com/site/about-us
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://mc.insurance.illinois.gov/messagecenter.nsf" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# 		Using boilerplate
# 	Working on http://colinsgrp.com/site/our-purpose
# 		Using boilerplate
# Working on Total Marketing Services
# 	Working on https://www.total.com/en/info/company-websites
# 		Using clnd_text
# 	Working on https://www.total.com/en/group/identity/history
# 		Using clnd_text
# 	Working on https://www.total.com/en/group/identity/five-strong-values-embedded-our-dna
# 		Using clnd_text
# Working on Bostik
# 	Working on https://www.bostik.com/our-company/
# 		Using boilerplate
# 	Working on https://www.bostik.com/our-company/about-arkema/
# 		Using clnd_text
# Working on WOVN
# 	Working on http://www.wovns.com/about
# 		Using boilerplate
# Working on Roche Diagnostics GmbH
# 	Working on https://www.accu-chek.com/about-us
# 		Using clnd_text
# Working on U S MICROPOWER INC
# 	Working on https://micropower-group.com/about/about/
# 		Using boilerplate
# Working on Cisco Technology
# 	Working on https://www.cisco.com/c/en/us/about.html
# 		Using clnd_text
# Working on MAXLINEAR
# 	Working on http://www.maxlinear.com/company/about-maxlinear/
# 		Using boilerplate
# Working on Heidelberger Druckmaschinen AG
# 	Working on https://www.heidelberg.com/global/de/company/company_overview.jsp
# 		Using clnd_text
# Working on Quantum Devices
# 	Working on https://www.quantumdev.com/about/
# 		Using boilerplate
# Working on Bristol-Myers Squibb Company
# 	Working on https://www.bms.com/about-us.html
# 		Using boilerplate
# 	Working on https://www.bms.com/about-us/our-company/achievements.html
# 		Using boilerplate
# Working on Teledyne Scientific & Imaging
# 	Working on http://www.teledyne-si.com/company-information
# 		Using clnd_text
# 	Working on http://www.teledyne-si.com/company-information/about-us
# 		Using clnd_text
# 	Working on http://www.teledyne-si.com/company-information/ethics-statement
# 		Using boilerplate
# Working on NanoLab
# 	Working on https://www.nano-lab.com/aboutdefault.html
# 		Using clnd_text
# Working on Gemex Systems
# 	Working on https://gemex.com/about/
# 		Using boilerplate
# Working on IDEX Health & Science LLC
# 	Working on https://www.idex-hs.com/about/
# 		Using clnd_text
# 	Working on https://www.idex-hs.com/about-us/company-history/
# 		Using boilerplate
# Working on Community Power Corporation
# ''
# Working on Bioneer Corporation
# 	Working on https://us.bioneer.com/about/mission.aspx
# 		Using clnd_text
# 	Working on https://us.bioneer.com/about/history.aspx
# 		Using clnd_text
# 	Working on https://us.bioneer.com/about/partners.aspx
# 		Using clnd_text
# Working on OSI Optoelectronics
# ''
# Working on FEI Company
# 	Working on https://www.fei.com/life-sciences/history-of-cryo-em/
# 		Using boilerplate
# Working on Pacific Light Technologies
# 	Working on http://www.pacificlighttech.com/about-us/overview/
# 		Using boilerplate
# Working on The Henry M. Jackson Foundation for the Advancement of Military Medicine
# 	Working on http://www.hjf.org/about/
# 		Using clnd_text
# 	Working on http://www.hjf.org/about/ethics/
# 		Using clnd_text
# 	Working on http://www.hjf.org/about/history/
# 		Using clnd_text
# 	Working on http://www.hjf.org/about/research-sponsors/
# 		Using clnd_text
# 	Working on http://www.hjf.org/about/research-sponsors/funding/
# 		Using boilerplate
# Working on BioNano Genomics
# 	Working on https://bionanogenomics.com/company/
# 		Using clnd_text
# Working on Da Yu Enterprises
# 	Working on http://dayuenterprises.com/About_Us.html
# 		Using boilerplate
# Working on Murata Manufacturing Co.
# 	Working on https://www.murata.com/en-us/about?intcid5=com_xxx_xxx_cmn_nv_xxx
# 		Using boilerplate
# 	Working on https://www.murata.com/en-us/about?intcid5=com_xxx_xxx_cmn_ft_xxx
# 		Using boilerplate
# 	Working on https://www.murata.com/en-us/about/rd?intcid5=com_xxx_xxx_cmn_nv_xxx
# 		Using boilerplate
# 	Working on https://www.murata.com/en-us/about/rd?intcid5=com_xxx_xxx_cmn_ft_xxx
# 		Using boilerplate
# 	Working on https://www.murata.com/en-us/about/company?intcid5=com_xxx_xxx_cmn_nv_xxx
# 		Using boilerplate
# 	Working on https://www.murata.com/en-us/about/company?intcid5=com_xxx_xxx_cmn_ft_xxx
# 		Using boilerplate
# 	Working on https://www.murata.com/en-us/about/americas?intcid5=com_xxx_xxx_cmn_nv_xxx
# 		Using boilerplate
# Working on Quantapore
# 	Working on https://quantapore.com/
# 		Using clnd_text
# Working on Sun Drilling Products Corporation
# ''
# Working on Grandis Inc.
# ''
# Working on Triple Ring Technologies
# ''
# Working on UWM Research Foundation
# 	Working on https://uwmrf.org/about/
# 		Using clnd_text
# Working on Symantec Corporation
# 	Working on https://www.symantec.com/about
# 		Using clnd_text
# 	Working on https://www.symantec.com/about/analyst
# 		Using clnd_text
# 	Working on https://www.symantec.com/about/webcasts
# 		Using boilerplate
# Working on FRONT EDGE TECHNOLOGY INC.
# 	Working on http://frontedgetechnology.com/about.htm
# 		Using boilerplate
# Working on Solan
# 	Working on https://www.salon.com/about
# 		Using boilerplate
# 	Working on https://www.salon.com/about/
# 		Using boilerplate
# 	Working on https://www.salon.com/about/ir/
# 		Using clnd_text
# 	Working on https://www.salon.com/about/tos/
# 		Using boilerplate
# 	Working on https://www.salon.com/about/advertise/
# 		Using boilerplate
# 	Working on https://www.salon.com/about/corrections/
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://www.salon.com/about/ir/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# 		Using clnd_text
# 	Working on https://www.salon.com/2018/12/02/cnn-keeps-letting-guests-and-paid-commentators-lie-about-climate-scientists_partner/
# 		Using boilerplate
# Working on Janssen Biotech
# 	Working on https://www.janssen.com/about
# 		Using boilerplate
# 	Working on https://www.janssen.com/company
# 		Using clnd_text
# Working on Amtech Systems
# 	Working on http://amtechsystems.com/profile.htm
# 		Using boilerplate
# Working on SolarLego Inc.
# 	Working on https://education.lego.com/en-us/about-us
# 		Using boilerplate
# Working on Dresser-Rand Company
# 	Working on http://dresser-rand.com/company/
# 		Using clnd_text
# 	Working on http://dresser-rand.com/company/about-us/
# 		Using clnd_text
# 	Working on http://dresser-rand.com/company/ethics-hotline/
# 		Using clnd_text
# Working on Johns Manville
# 	Working on https://www.jm.com/en/our-company/
# 		Using clnd_text
# 	Working on https://www.jm.com/en/our-company/CoreValues/
# 		Using clnd_text
# 	Working on https://www.jm.com/en/our-company/HistoryandHeritage/
# 		Using clnd_text
# Working on Parion Sciences
# 	Working on http://parion.com/about/
# 		Using clnd_text
# Working on Uniseal Solutions Inc.
# 	Working on https://www.unisealsolutions.com/company/
# 		Using boilerplate
# Working on Pardev
# 	Working on http://pardev.com/company/about-us.html
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.siemens.com/global/en/home/company/sustainability/compliance/reporting-channels.html" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# 		Using boilerplate
# 	Working on http://pardev.com/company/our-philosophy.html
# 		Using boilerplate
# 	Working on http://pardev.com/company/industries-served.html
# 		Using boilerplate
# Working on Voxtel
# 	Working on http://voxtel-inc.com/about-voxtel/
# 		Using boilerplate
# Working on Semprius
# 	Working on https://www.semprius.com/about-us/
# 		Using clnd_text
# Working on Toda Kogyo Corporation
# 	Working on http://www.todakogyo.co.jp/english/about/csr.html
# 		Using clnd_text
# 	Working on http://www.todakogyo.co.jp/english/about/index.html
# 		Using boilerplate
# 	Working on http://www.todakogyo.co.jp/english/about/history.html
# 		Using boilerplate
# Working on System Biosciences
# 	Working on https://www.systembio.com/company/about/
# 		Using clnd_text
# 	Working on https://www.systembio.com/company/mission/
# 		Using clnd_text
# Working on GENCO SCIENCES LLC
# 	Working on https://www.gpen.com/pages/about
# 		Using clnd_text
# Working on BASF
# 	Working on https://www.basf.com/us/en/who-we-are.html
# 		Using boilerplate
# 	Working on https://www.basf.com/us/en/who-we-are/innovation.html
# 		Using boilerplate
# Working on U.S. NUTRACEUTICALS
# 	Working on https://www.nutraceutical.com/company/
# 		Using clnd_text
# 	Working on https://www.nutraceutical.com/company/ethics/
# 		Using boilerplate
# 	Working on https://www.nutraceutical.com/company/vision/
# 		Using clnd_text
# 	Working on https://www.nutraceutical.com/company/history/
# 		Using clnd_text
# 	Working on https://www.nutraceutical.com/company/employees/
# 		Using clnd_text
# Working on Amgen Fremont Inc.
# 	Working on https://www.amgen.com/about/
# 		Using clnd_text
# 	Working on https://www.amgen.com/about/quick-facts/
# 		Using clnd_text
# 	Working on https://www.amgen.com/about/how-we-operate/
# 		Using clnd_text
# 	Working on https://www.amgen.com/about/mission-and-values/
# 		Using clnd_text
# 	Working on https://www.amgen.com/about/awards-and-accolades/
# 		Using boilerplate
# 	Working on https://www.amgen.com/about/how-we-operate/corporate-governance/
# 		Using clnd_text
# 	Working on https://www.amgen.com/about/how-we-operate/business-ethics-and-compliance/
# 		Using clnd_text
# 	Working on https://www.amgen.com/about/how-we-operate/policies-practices-and-disclosures/
# 		Using clnd_text
# Working on Metabolix
# 	Working on https://www.yield10bio.com/Corporate-Overview
# 		Using boilerplate
# Working on Sinewatts
# 	Working on https://www.sinewatts.com/
# 		Using clnd_text
# Working on Zygo Corporation
# ''
# Working on Hollingsworth & Vose Company
# 	Working on https://www.hollingsworth-vose.com/en/Company/
# 		Using clnd_text
# 	Working on https://www.hollingsworth-vose.com/en/Company/Company-History/
# 		Using clnd_text
# Working on Confluence Energy
# 	Working on http://www.confluenceenergy.com/about
# 		Using boilerplate
# 	Working on http://www.confluenceenergy.com/about/our-story
# 		Using boilerplate
# Working on Bell Helicopter Textron Inc.
# 	Working on http://bellflight.com/company
# 		Using clnd_text
# 	Working on http://bellflight.com/company/certificates
# 		Using clnd_text
# 	Working on http://bellflight.com/company/innovation/APT
# 		Using clnd_text
# Working on IMRA America
# 	Working on https://www.imra.com/history-mission/
# 		Using boilerplate
# Working on The Goodyear Tire & Rubber Company
# 	Working on https://www.goodyear.com/en-US/company
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.goodyear.com/en-US/company/cavs-partnership/gwp-entry-form" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.goodyear.com/en-US/company/cavs-partnership" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://www.goodyear.com/en-US/terms-conditions-privacy-policy" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://www.nba.com/news/privacy_policy.html" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# 		Using boilerplate
# Working on Advanced Silicon Group
# ''
# Working on ABB AB
# 	Working on https://new.abb.com/about
# 		Using clnd_text
# 	Working on https://new.abb.com/about/integrity
# 		Using clnd_text
# 	Working on https://new.abb.com/about/supplying
# 		Using clnd_text
# 	Working on https://new.abb.com/about/abb-in-brief
# 		Using clnd_text
# Working on Cetac Technologies Inc.
# 	Working on http://www.teledynecetac.com/about-us/about-us
# 		Using boilerplate
# 	Working on http://www.teledynecetac.com/about-us/workshops
# 		Using clnd_text
# Working on THYSSENKRUPP INDUSTRIAL SOLUTIONS GMBH
# 	Working on https://www.thyssenkrupp.com/en/company/
# 		Using boilerplate
# 	Working on https://www.thyssenkrupp.com/en/company/history/
# 		Using boilerplate
# 	Working on https://www.thyssenkrupp.com/en/company/innovation/
# 		Using clnd_text
# 	Working on https://www.thyssenkrupp.com/en/company/history/index/
# 		Using boilerplate
# 	Working on https://www.thyssenkrupp.com/en/company/history/the-logos/
# 		Using boilerplate
# 	Working on https://www.thyssenkrupp.com/en/company/corporate-culture/
# 		Using boilerplate
# Working on International Business Machines Corporation
# 	Working on https://www.ibm.com/ibm/us/en/?lnk=fab
# 		Using boilerplate
# Working on Adaptive Biotechnologies Corp.
# 	Working on https://www.adaptivebiotech.com/about
# 		Using clnd_text
# 	Working on https://www.adaptivebiotech.com/about/advisors
# 		Using boilerplate
# 	Working on https://www.adaptivebiotech.com/about-us/pipeline
# 		Using boilerplate
# Working on B.G. Negev Technologies and Applications Ltd.
# 	Working on http://in.bgu.ac.il/en/bgn/Pages/about.aspx
# 		Using boilerplate
# 	Working on http://in.bgu.ac.il/en/bgn/Pages/about-bgu.aspx
# 		Using boilerplate
# Working on Biosphere Medical
# 	Working on https://www.merit.com/about/
# 		Using clnd_text
# 	Working on https://www.merit.com/about/vision-values/
# 		Using clnd_text
# Working on Global Solar Water Power Systems
# 	Working on http://gswps.com/AboutUs.aspx
# 		Using boilerplate
# Working on CUMMINS FILTRATION IP
# 	Working on https://cumminsfiltration.com/history
# 		Using clnd_text
# 	Working on https://www.cumminsfiltration.com/visionmission
# 		Using clnd_text
# Working on Cellular Research
# 	Working on https://cellularresearchinstitute.com/about.html
# 		Using boilerplate
# Working on Carbon3D
# 	Working on https://www.carbon3d.com/about/
# 		Using boilerplate
# Working on Propagation Research Associates
# 	Working on http://pra-corp.com/about.php
# 		Using boilerplate
# Working on Danisco US Inc.
# 	Working on https://www.dupontnutritionandhealth.com/about-us.html
# 		Using clnd_text
# 	Working on https://www.dupontnutritionandhealth.com/about-us/what-we-do.html
# 		Using clnd_text
# 	Working on https://www.dupontnutritionandhealth.com/about-us/who-we-are.html
# 		Using boilerplate
# 	Working on https://www.dupontnutritionandhealth.com/about-us/where-we-are-located.html
# 		Using clnd_text
# Working on Christie Digital Systems
# 	Working on https://www.christiedigital.com/en-us/about-christie
# 		Using boilerplate
# Working on IMDS Corporation
# 	Working on http://imds-ohio.com/AboutUs/
# 		Using clnd_text
# 	Working on http://imds-ohio.com/AboutUs/Corp_Profile/
# 		Using boilerplate
# Working on Hitachi Metals
# 	Working on https://www.hitachimetals.com/corporate-information/profile.php
# 		Using boilerplate
# Working on Revera
# 	Working on https://www.reveraliving.com/about-revera/about-us
# 		Using clnd_text
# 	Working on https://www.reveraliving.com/about-revera/about-revera
# 		Using clnd_text
# 	Working on https://www.reveraliving.com/about-revera/innovation-at-revera
# 		Using clnd_text
# Working on Vizio Inc.
# 	Working on https://www.vizio.com/about
# 		Using clnd_text
# Working on Samsung Electronics
# 	Working on https://www.samsung.com/us/aboutsamsung/home/
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://www.hitachi-metals.co.jp/e/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://www.hitachi.com" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://www.hp.com/go/samsung" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/SICK.Deutschland" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/sick_de" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.youtube.com/user/SICKSensors" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://plus.google.com/105985015069795775228/posts" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.xing.com/companies/sickag" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.linkedin.com/company/sick-ag" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# 		Using boilerplate
# Working on HM3 Energy
# 	Working on http://hm3energy.com/about/
# 		Using clnd_text
# 	Working on http://hm3energy.com/about/hm3-energy-achievements/
# 		Using boilerplate
# Working on Integrated DNA Technologies
# 	Working on https://www.idtdna.com/pages/about/core-values
# 		Using boilerplate
# Working on Sick AG
# 	Working on https://www.sick.com/de/en/sick-ags-company-profile/w/about/
# 		Using clnd_text
# 	Working on https://www.sick.com/de/en/about-sick/our-philosophy/w/our-philosophy/
# 		Using clnd_text
# 	Working on https://www.sick.com/de/en/about-sick/sicks-company-history/w/the-history-of-sick/
# 		Using clnd_text
# 	Working on https://www.sick.com/de/en/about-sick/research-and-development/w/research-and-development/
# 		Using clnd_text
# Working on Performance Plants
# 	Working on http://performanceplants.com/corporate
# 		Using boilerplate
# Working on Bruin Biometrics
# 	Working on http://bruinbiometrics.com/us/about-us
# 		Using clnd_text
# 	Working on http://bruinbiometrics.com/us/about-us/about-us-2
# 		Using clnd_text
# 	Working on http://bruinbiometrics.com/us/about-us/mission-values
# 		Using boilerplate
# 	Working on http://bruinbiometrics.com/us/sem/pressure-ulcers-dtis
# 		Using boilerplate
# Working on NanoGram Corporation
# 	Working on http://www.nanogram.com/home/
# 		Using boilerplate
# Working on Siemens Aktiengesellschaft
# ''
# Working on WestPoint Home
# 	Working on https://www.westpointhome.com/about-us.html
# 		Using boilerplate
# 	Working on https://www.westpointhome.com/home-decor/decorative-pillows/ncaa-pillows-by-the-northwest-company.html
# 		Using clnd_text
# Working on LifeNet Health
# 	Working on https://www.lifenethealth.org/about/divisions
# 		Using clnd_text
# 	Working on https://www.lifenethealth.org/about/our-mission
# 		Using clnd_text
# 	Working on https://www.lifenethealth.org/about-lifenet-health
# 		Using clnd_text
# Working on SOL-ELECTRICA
# 	Working on http://sol-electrica.com/about_sere_sol_electrica.htm
# 		Using boilerplate
# Working on Chevron Oronitz Company LLC
# 	Working on https://www.oronite.com/about/vision.aspx
# 		Using clnd_text
# 	Working on https://www.oronite.com/about/history.aspx
# 		Using boilerplate
# 	Working on https://www.oronite.com/about/default.aspx
# 		Using clnd_text
# 	Working on https://www.oronite.com/about/china-overview.aspx
# 		Using boilerplate
# Working on Fujitsu Limited
# 	Working on http://www.fujitsu.com/jp/about/
# 		Using clnd_text
# 	Working on http://www.fujitsu.com/jp/about/resources/
# 		Using clnd_text
# 	Working on http://www.fujitsu.com/jp/about/index.html
# 		Using clnd_text
# 	Working on http://www.fujitsu.com/jp/about/corporate/
# 		Using clnd_text
# 	Working on http://www.fujitsu.com/jp/about/philosophy/
# 		Using clnd_text
# 	Working on http://www.fujitsu.com/jp/about/activities/
# 		Using clnd_text
# 	Working on http://www.fujitsu.com/jp/about/environment/
# 		Using clnd_text
# 	Working on http://www.fujitsu.com/jp/vision/
# 		Using clnd_text
# Working on Virent
# 	Working on http://www.virent.com/company/
# 		Using boilerplate
# Working on CARBO Ceramics Inc.
# 	Working on https://carboceramics.com/about/our-values
# 		Using clnd_text
# 	Working on https://carboceramics.com/about/about-carbo
# 		Using clnd_text
# 	Working on https://carboceramics.com/about/about-carbo/ASSETGUARD
# 		Using clnd_text
# 	Working on https://carboceramics.com/investors/company-profile
# 		Using clnd_text
# 	Working on https://carboceramics.com/about/about-carbo?lang=en-US
# 		Using clnd_text
# 	Working on https://carboceramics.com/about/about-carbo?lang=ru-RU
# 		Using clnd_text
# Working on Liquidia Technologies
# 	Working on http://liquidia.com/about-liquidia/
# 		Using boilerplate
# 	Working on http://liquidia.com/about-liquidia/collaborations/
# 		Using boilerplate
# Working on Opel Solar
# ''
# Working on Graphene Technologies
# 	Working on http://graphenetechnologies.com/
# 		Using boilerplate
# Working on Hamilton Sundstrand Corporation
# 	Working on https://utcaerospacesystems.com/join-the-utc-team/
# 		Using clnd_text
# 	Working on https://utcaerospacesystems.com/corporate-citizenship/
# 		Using boilerplate
# Working on Boehringer Ingelheim Vetmedica GmbH
# 	Working on https://www.bi-vetmedica.com/company/company.html
# 		Using clnd_text
# 	Working on https://www.bi-vetmedica.com/species/swine/about.html
# 		Using clnd_text
# 	Working on https://www.bi-vetmedica.com/company/company/about_us.html
# 		Using clnd_text
# 	Working on https://www.bi-vetmedica.com/company/company/about_us/history.html
# 		Using boilerplate
# Working on Toray Plastics (America)
# 	Working on http://toraytpa.com/about-us
# 		Using boilerplate
# Working on Meso Scale Technologies
# 	Working on https://www.mesoscale.com/en/our_company
# 		Using clnd_text
# Working on Proton Power
# 	Working on http://www.protonpower.com/about
# 		Using clnd_text
# 	Working on http://www.protonpower.com/about/
# 		Using clnd_text
# 	Working on http://www.protonpower.com/history
# 		Using boilerplate
# 	Working on http://www.protonpower.com/history/
# 		Using boilerplate
# 	Working on http://www.protonpower.com/about-graphene/
# 		Using clnd_text
# Working on MBC Ventures
# 	Working on https://www.mbc.net/en/corporate/about-us.html
# 		Using boilerplate
# Working on Butamax(TM) Advanced Biofuels LLC
# 	Working on http://www.butamax.com/biofuel-company.aspx
# 		Using boilerplate
# Working on Unifrax I LLC
# 	Working on http://www.unifrax.com/about-us/
# 		Using boilerplate
# Working on Dana-Farber Cancer Institute
# 	Working on https://www.dana-farber.org/about-us/
# 		Using clnd_text
# 	Working on https://www.dana-farber.org/about-us/history-and-milestones/
# 		Using clnd_text
# Working on SII Semiconductor Corporation
# 	Working on https://www.ablic.com/en/semicon/corp/
# 		Using clnd_text
# 	Working on https://www.ablic.com/en/semicon/corp/vision/
# 		Using clnd_text
# 	Working on https://www.ablic.com/en/semicon/corp/history/
# 		Using clnd_text
# 	Working on https://www.ablic.com/en/semicon/corp/vision/?rf=subbnr
# 		Using clnd_text
# Working on GangaGen
# 	Working on http://www.gangagen.com/about-us.html
# 		Using boilerplate
# Working on LIQUID X PRINTED METALS
# 	Working on http://www.liquid-x.com/about/
# 		Using boilerplate
# Working on Dell Software Inc.
# 	Working on https://www.quest.com/company/
# 		Using boilerplate
# Working on Arrowhead Center
# ''
# Working on Dexerials Corporation
# 	Working on http://www.dexerials.jp/en/profile/vision.html
# 		Using clnd_text
# 	Working on http://www.dexerials.jp/en/csr/envi/prize.html
# 		Using clnd_text
# 	Working on http://www.dexerials.jp/en/profile/profile.html
# 		Using clnd_text
# 	Working on http://www.dexerials.jp/en/profile/history.html
# 		Using boilerplate
# 	Working on http://www.dexerials.jp/en/csr/envi/vision.html
# 		Using boilerplate
# Working on Custom Electronics Inc.
# 	Working on https://www.customelec.com/company
# 		Using clnd_text
# 	Working on https://www.customelec.com/copy-of-company
# 		Using clnd_text
# Working on Vadient Optics
# 	Working on http://vadient.com/creating-a-new-class-of-optical-design/about-us
# 		Using boilerplate
# 	Working on http://vadient.com/creating-a-new-class-of-optical-design/about-us/changing-the-unchanging-field-of-optics
# 		Using boilerplate
# Working on Ortho-Clinical Diagnostics
# 	Working on https://www.orthoclinicaldiagnostics.com/en-us/home/about-us
# 		Using boilerplate
# 	Working on https://www.orthoclinicaldiagnostics.com/en-us/home/who-we-are
# 		Using boilerplate
# 	Working on https://www.orthoclinicaldiagnostics.com/en-us/home/our-history
# 		Using clnd_text
# Working on Litron Laboratories Limited
# 	Working on https://litronlabs.com/About-Us
# 		Using boilerplate
# Working on Halliburton Energy Services
# 	Working on https://www.halliburton.com/en-US/about-us/default.html?node-id=hgbr8q6o
# 		Using clnd_text
# 	Working on https://www.halliburton.com/en-US/about-us/default.html?node-id=hgbr8q6o&SRC=Footer
# 		Using clnd_text
# 	Working on https://www.halliburton.com/en-US/about-us/corporate-profile/default.html?node-id=hgeyxt5p
# 		Using clnd_text
# Working on Nanotek Instruments
# 	Working on http://nanotekinstruments.com/about-us/
# 		Using boilerplate
# Working on Momentive Performance Materials GmbH
# 	Working on https://www.momentive.com/en-us/about/
# 		Using clnd_text
# 	Working on https://www.momentive.com/en-us/vision-and-values/
# 		Using clnd_text
# 	Working on https://www.momentive.com/en-us/careers/who-we-are/
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://pubs.acs.org/doi/abs/10.1021/nl102661q" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://pubs.acs.org/doi/abs/10.1021/nl2018492" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://pubs.rsc.org/en/content/articlelanding/2012/ee/c2ee02911a" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# 		Using clnd_text
# Working on J. E. WHITE
# ''
# Working on iBio
# 	Working on https://ibioinc.com/index.php/company-background/disclaimer
# 		Using boilerplate
# 	Working on https://ibioinc.com/index.php/company-background/company-background-2
# 		Using clnd_text
# Working on Canon Nanotechnologies
# 	Working on http://cnt.canon.com/overview/
# 		Using boilerplate
# Working on Agilent Technologies
# 	Working on https://www.agilent.com/about/workingwa/index.html
# 		Using clnd_text
# 	Working on https://www.agilent.com/about/companyinfo/index.html
# 		Using boilerplate
# 	Working on https://www.agilent.com/about/features/raman-spectroscopy.html
# 		Using boilerplate
# Working on PluroGen Therapeutics
# 	Working on http://plurogen.com/about-us/
# 		Using boilerplate
# 	Working on http://plurogen.com/about-us/about-dr-rodeheaver/
# 		Using boilerplate
# Working on Bisco
# ''
# Working on Antaya Technologies Corporation
# 	Working on https://www.antaya.com/company/
# 		Using boilerplate
# Working on Life Technologies Corporation
# ''
# Working on SPC International
# ''
# Working on Takeda Pharmaceutical Company Limited
# 	Working on https://www.takeda.com/who-we-are/
# 		Using clnd_text
# 	Working on https://www.takeda.com/who-we-are/company-information/
# 		Using boilerplate
# 	Working on https://www.takeda.com/who-we-are/corporate-governance/
# 		Using boilerplate
# 	Working on https://www.takeda.com/who-we-are/corporate-philosophy/
# 		Using boilerplate
# Working on Bridgelux
# 	Working on https://bridgelux.com/company
# 		Using clnd_text
# Working on Intellectual Keystone Technology LLC
# 	Working on http://ikt.us.com/about-us.html
# 		Using boilerplate
# Working on Nissan North America
# 	Working on https://www.nissanusa.com/about.html
# 		Using clnd_text
# 	Working on https://www.nissanusa.com/about/heritage.html
# 		Using clnd_text
# 	Working on https://www.nissanusa.com/about/corporate-information.html
# 		Using clnd_text
# Working on AT&T Corporation
# ''
# Working on Brightfield Transportation Solutions
# 	Working on http://brightfieldts.com/mission-and-values/
# 		Using clnd_text
# 	Working on http://brightfieldts.com/the-brightfield-leadership-team/
# 		Using clnd_text
# 	Working on http://brightfieldts.com/brightfield-transportation-solutions-story/
# 		Using boilerplate
# Working on Magnolia Solar
# 	Working on http://magnoliasolar.com/about/jobs.html
# 		Using clnd_text
# 	Working on http://magnoliasolar.com/about/quest.html
# 		Using boilerplate
# 	Working on http://magnoliasolar.com/about/index.html
# 		Using boilerplate
# 	Working on http://magnoliasolar.com/about/values.html
# 		Using boilerplate
# 	Working on http://magnoliasolar.com/about/vision.html
# 		Using boilerplate
# 	Working on http://magnoliasolar.com/about/history.html
# 		Using boilerplate
# 	Working on http://magnoliasolar.com/about/strategy.html
# 		Using boilerplate
# Working on NGK Spark Plug Co.
# 	Working on http://ngksparkplugs.com/about-ngk
# 		Using clnd_text
# Working on Cleanvantage LLC
# 	Working on http://biovantage.dk/
# 		Using boilerplate
# Working on Fuji Xerox Co.
# 	Working on https://www.fujixerox.com/eng/company
# 		Using clnd_text
# Working on Pharmatrophix
# ''
# Working on Energysolutions
# 	Working on https://www.energysolutions.com/about/
# 		Using boilerplate
# Working on Siluria Technologies
# 	Working on http://siluria.com/About
# 		Using boilerplate
# 	Working on http://siluria.com/About/Company_Overview
# 		Using clnd_text
# 	Working on http://siluria.com/About/Vision_and_Culture
# 		Using clnd_text
# Working on Archer Daniels Midland Company
# 	Working on https://www.adm.com/our-company
# 		Using clnd_text
# 	Working on https://www.adm.com/our-company/history
# 		Using clnd_text
# 	Working on https://www.adm.com/our-company/adm-facts
# 		Using clnd_text
# 	Working on https://www.adm.com/our-company/procurement
# 		Using boilerplate
# 	Working on https://www.adm.com/careers/values-vision
# 		Using clnd_text
# Working on Microsemi SoC Corporation
# 	Working on https://www.microsemi.com/company/awards
# 		Using clnd_text
# 	Working on https://www.microsemi.com/company/quality
# 		Using clnd_text
# 	Working on https://www.microsemi.com/company/about-us
# 		Using clnd_text
# 	Working on https://www.microsemi.com/company/technology
# 		Using boilerplate
# Working on OFS Fitel
# 	Working on https://www.ofsoptics.com/about/
# 		Using clnd_text
# 	Working on https://www.ofsoptics.com/our-values/
# 		Using clnd_text
# Working on Solar Junction Corporation
# 	Working on http://sj-solar.com/about_us/
# 		Using boilerplate
# 	Working on http://sj-solar.com/about_us/careers.php
# 		Using clnd_text
# Working on Kulite Semiconductor Products
# 	Working on https://www.kulite.com/company/
# 		Using clnd_text
# 	Working on https://www.kulite.com/company/history/
# 		Using boilerplate
# 	Working on https://www.kulite.com/company/mission-statement/
# 		Using clnd_text
# Working on Tata Consultancy Services Limited
# ''
# Working on Foret Plasma Labs
# ...
# 		Using clnd_text
# 	Working on https://www.synopsys.com/community/snug/about-snug.html
# 		Using clnd_text
# Working on UT-Battelle
# 	Working on https://ut-battelle.org/director.shtml
# 		Using boilerplate
# Working on Fluidigm Corporation
# 	Working on https://www.fluidigm.com/about/aboutfluidigm
# 		Using boilerplate
# Working on Johnson Controls Technology Company
# 	Working on https://www.johnsoncontrols.com/about-us/history
# 		Using boilerplate
# 	Working on https://www.johnsoncontrols.com/about-us/our-company
# 		Using clnd_text
# 	Working on https://www.johnsoncontrols.com/about-us/ethics-and-compliance
# 		Using clnd_text
# Working on ADVANCED INNOVATION CENTER LLC
# 	Working on http://aicchile.com/en/
# 		Using clnd_text
# 	Working on http://aicchile.com/en/nosotros/
# 		Using clnd_text
# Working on Bestway
# 	Working on http://www.bestwaycorp.us/AboutUs/Page
# 		Using boilerplate
# Working on SUNSALUTER
# 	Working on https://www.sunsaluter.org/about
# 		Using clnd_text
# Working on Pixar
# ''
# Working on Saint-Gobain Performance Plastics Corporation
# 	Working on https://www.plastics.saint-gobain.com/about-us
# 		Using clnd_text
# Working on PAX Scientific
# 	Working on http://paxscientific.com/history/
# 		Using boilerplate
# 	Working on http://paxscientific.com/innovative-technology/
# 		Using boilerplate
# Working on GCP Applied Technologies Inc.
# ''
# Working on eNow
# 	Working on https://enowenergy.com/
# 		Using clnd_text
# 	Working on https://enowenergy.com/learn-about-solar/
# 		Using boilerplate
# Working on Alpha and Omega Semiconductor Incorporated
# 	Working on http://aosmd.com/about
# 		Using boilerplate
# 	Working on http://aosmd.com/about/newsroom
# 		Using clnd_text
# Working on Formula Plastics
# 	Working on http://formulaplastics.com/about.html
# 		Using boilerplate
# Working on Magna International Inc.
# 	Working on https://www.magna.com/company
# 		Using clnd_text
# Working on Omron Corporation
# 	Working on https://www.omron.com/about/
# 		Using clnd_text
# 	Working on https://www.omron.com/about/social/
# 		Using clnd_text
# 	Working on https://www.omron.com/about/annual/
# 		Using clnd_text
# 	Working on https://www.omron.com/about/history/
# 		Using clnd_text
# 	Working on https://www.omron.com/about/outline/
# 		Using clnd_text
# 	Working on https://www.omron.com/about/strategy/
# 		Using clnd_text
# Working on Esolar
# 	Working on http://esolar.solar/about
# 		Using boilerplate
# Working on True-Safe Technologies
# 	Working on http://fiatest.com/about-us/
# 		Using boilerplate
# 	Working on https://fiatest.com/about-us/
# 		Using boilerplate
# Working on Ube Industries
# 	Working on https://ube-ind.co.jp/ube/en/rss/about_rss.html
# 		Using clnd_text
# Working on Gtech Corporation
# 	Working on https://www.gtech.co.uk/about-gtech
# 		Using clnd_text
# Working on JNC Corporation
# 	Working on https://jncwheels.com/pages/about-us
# 		Using clnd_text
# Working on Guardian Industries
# 	Working on https://www.guardian.com/en/about_us/a.html
# 		Using boilerplate
# 	Working on https://www.guardian.com/en/about_us/one_world.html
# 		Using boilerplate
# 	Working on https://www.guardian.com/en/about_us/introduction.html
# 		Using boilerplate
# Working on Biotechnology Foundation
# 	Working on https://cabiotech.org/about/
# 		Using boilerplate
# 	Working on https://cabiotech.org/about/our-value/
# 		Using boilerplate
# Working on RenovaCare Sciences Corp.
# 	Working on https://www.renovacareinc.com/about/
# 		Using boilerplate
# Working on VIASAT INC.
# 	Working on https://www.viasat.com/about
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.guardian.com" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.guardianglass.com" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://www.srgglobal.com" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# 		Using boilerplate
# Working on Autonomic Materials
# 	Working on https://www.autonomicmaterials.com/Our-Company
# 		Using clnd_text
# Working on Daikin Industries
# 	Working on https://www.daikin.com/corporate/index.html
# 		Using clnd_text
# 	Working on https://www.daikin.com/csr/environment/vision.html
# 		Using clnd_text
# 	Working on https://www.daikin.com/corporate/overview/index.html
# 		Using clnd_text
# 	Working on https://www.daikin.com/about/corporate/tic/index.html
# 		Using clnd_text
# Working on Red Hat
# 	Working on https://www.redhat.com/en/about
# 		Using clnd_text
# 	Working on https://www.redhat.com/en/about/company
# 		Using boilerplate
# 	Working on https://www.redhat.com/en/about/feedback
# 		Using clnd_text
# 	Working on https://www.redhat.com/en/about/newsroom
# 		Using clnd_text
# 	Working on https://www.redhat.com/en/about/privacy-policy
# 		Using boilerplate
# Working on Rebellion Photonics
# 	Working on https://rebellionphotonics.com/about-us.html
# 		Using clnd_text
# Working on RADIANCE SOLAR
# 	Working on https://radiancesolar.com/about-us/
# 		Using boilerplate
# Working on MicroLink Devices
# 	Working on http://mldevices.com/index.php/company
# 		Using boilerplate
# 	Working on http://mldevices.com/index.php/company/about-us
# 		Using boilerplate
# Working on Wave Energy Conversion Corporation of America
# 	Working on https://weccamerica.com/about/
# 		Using boilerplate
# Working on L-3 Communications Cincinnati Electronics Corporation
# 	Working on https://cinele.com/about/index.htm
# 		Using boilerplate
# Working on Angiotech Pharmaceuticals (US)
# 	Working on http://angiotech.com/about
# 		Using boilerplate
# 	Working on http://angiotech.com/about/itemlist/category/5-corporate-profile
# 		Using boilerplate
# Working on Adhesives Research
# 	Working on http://www.adhesivesresearch.com/about/
# 		Using clnd_text
# Working on Delphi Technologies
# 	Working on https://www.delphi.com/company
# 		Using boilerplate
# 	Working on https://www.delphi.com/company/vision-and-values
# 		Using boilerplate
# Working on Transitions Optical
# 	Working on https://www.transitions.com/en-us/our-company/
# 		Using clnd_text
# 	Working on https://www.transitions.com/en-us/our-company/history/
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/delphitech" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/delphitech" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.linkedin.com/company/delphitechnologies" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.youtube.com/DelphiTechnologies" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# 		Using clnd_text
# Working on Solvay Specialty Polymers USA
# 	Working on https://www.solvay.com/en/our-company
# 		Using clnd_text
# 	Working on https://www.solvay.com/en/company-information/history
# 		Using clnd_text
# 	Working on https://www.solvay.com/en/company-information/procurement
# 		Using clnd_text
# 	Working on https://www.solvay.com/en/company-information/our-strategy
# 		Using clnd_text
# 	Working on https://www.solvay.com/en/company-information/our-businesses
# 		Using clnd_text
# Working on Soraa Laser Diode
# 	Working on https://www.sldlaser.com/about
# 		Using clnd_text
# Working on Olympus NDT
# 	Working on https://www.olympus-ims.com/en/about-us/
# 		Using boilerplate
# 	Working on https://www.olympus-ims.com/en/training-academy/about/
# 		Using boilerplate
# 	Working on https://www.olympus-ims.com/en/support/ethics-corporate-compliance/
# 		Using boilerplate
# Working on St. Jude Medical
# 	Working on https://www.sjm.com/en/about?clset=af584191-45c9-4201-8740-5409f4cf8bdd%3ab20716c1-c2a6-4e4c-844b-d0dd6899eb3a
# 		Using boilerplate
# 	Working on https://www.sjm.com/en/about/company-facts?clset=af584191-45c9-4201-8740-5409f4cf8bdd%3ab20716c1-c2a6-4e4c-844b-d0dd6899eb3a
# 		Using clnd_text
# Working on Industrial Technology Research Institute
# 	Working on https://www.itri.org.tw/eng/Content/Messagess/contents.aspx?SiteID=1&MmmID=617731521661672477
# 		Using clnd_text
# Working on Research Triangle Institute
# 	Working on https://www.rti.org/about-us
# 		Using boilerplate
# 	Working on https://www.rti.org/impact/evaluating-quality-improvement-center-research-based-infant-toddler-court-teams
# 		Using boilerplate
# Working on Agienic
# 	Working on http://agienic.com/about/company
# 		Using boilerplate
# Working on MATERIALS ANALYSIS TECHNOLOGY (US) CORP.
# 	Working on http://www.ma-tek.com/about_us.php?act=rd
# 		Using boilerplate
# 	Working on http://www.ma-tek.com/about_us.php?act=partne
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://olympusamerica.ethicspoint.com" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://www.qicct.org/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://goo.gl/oPVQ9o" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://www.tw.sgs.com/zh_tw" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://www.intertek-twn.com/big5/news/index_news.asp?page_id=7&project_code=0" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://www.balazs.com/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://www.tsing-hua.com.tw/htmls/Welcome.htm" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://www.etc.org.tw/cubekm/front/bin/home.phtml" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://www.ipfirm.com/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# 		Using clnd_text
# 	Working on http://www.ma-tek.com/about_us.php?act=history
# 		Using clnd_text
# 	Working on http://www.ma-tek.com/about_us.php?act=quality
# 		Using clnd_text
# 	Working on http://www.ma-tek.com/about_us.php?act=customer
# 		Using clnd_text
# 	Working on http://www.ma-tek.com/about_us.php?act=business
# 		Using clnd_text
# 	Working on http://www.ma-tek.com/about_us.php?act=glorious
# 		Using clnd_text
# Working on Tarveda Therapeutics
# 	Working on http://www.tarvedatx.com/about.html
# 		Using boilerplate
# Working on Sumco Corporation
# 	Working on http://sumco.com/CompanyPolicy.aspx
# 		Using boilerplate
# Working on TRIDONIC GMBH & CO KG
# 	Working on https://www.tridonic.com/com/en/about-us.asp
# 		Using boilerplate
# Working on Star Technology and Research
# 	Working on http://star-tech-inc.com/id4.html
# 		Using clnd_text
# Working on Auterra
# 	Working on http://auterrainc.com/about.php
# 		Using boilerplate
# Working on BASF Coatings GmbH
# 	Working on http://basf-coatings.com/global/ecweb/en/content/about_us/index
# 		Using boilerplate
# 	Working on http://basf-coatings.com/global/ecweb/en/content/about_us/history/index
# 		Using boilerplate
# 	Working on http://basf-coatings.com/global/ecweb/en/content/about_us/general-information/disclaimer
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://www.tridonic.us" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# 		Using boilerplate
# Working on Owens-Brockway Glass Container Inc.
# 	Working on http://www.o-i.com/About-O-I/
# 		Using clnd_text
# Working on SolAero Technologies Corp.
# 	Working on https://solaerotech.com/about-us/
# 		Using boilerplate
# Working on Adobe Systems Incorporated
# 	Working on https://www.adobe.com/about-adobe.html?promoid=2NVQCDBQ&mv=other
# 		Using clnd_text
# Working on SunEdison Semiconductor Limited
# ''
# Working on Zoetis Services LLC
# 	Working on https://www.zoetis.com/about-us/index.aspx
# 		Using clnd_text
# 	Working on https://www.zoetis.com/about-us/history.aspx
# 		Using boilerplate
# 	Working on https://www.zoetis.com/about-us/our-story.aspx
# 		Using clnd_text
# 	Working on https://www.zoetis.com/about-us/core-beliefs.aspx
# 		Using clnd_text
# 	Working on https://www.zoetis.com/about-us/awards/index.aspx
# 		Using clnd_text
# 	Working on https://www.zoetis.com/about-us/vision-mission.aspx
# 		Using clnd_text
# 	Working on https://www.zoetis.com/about-us/zoetis-at-a-glance.aspx
# 		Using clnd_text
# Working on Palo Alto Research Center Incorporated
# 	Working on https://www.parc.com/about-parc/
# 		Using boilerplate
# 	Working on https://www.parc.com/about-parc/parc-history/
# 		Using boilerplate
# 	Working on https://www.parc.com/about-parc/parc-cleanroom/
# 		Using boilerplate
# Working on Invensas Corporation
# 	Working on https://www.invensas.com/company/
# 		Using boilerplate

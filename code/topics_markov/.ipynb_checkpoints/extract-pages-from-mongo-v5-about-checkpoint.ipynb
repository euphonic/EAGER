# %% [markdown]
# # extract-pages-from-mongo-v5
# SanjayKAroraPhD@gmail.com <br>
# December 2018
#
# ## Description
# This version of the notebook extracts groups of pages from mongodb by firm_name to create firm-centric <b>about</b> page output files that can later be topic modeled.  In doing so, it removes repetitive content (e.g., repeated menu items) and garbage content (e.g., improperly parsed HTML code).
#
# ## Change log
# v4 focuses on about pages
#
# ## TODO:
# * Whole process: get data, topic model and see if it looks sufficiently interesting/different
# * Enhance data collection, per the following:
#     * Select a region or country — WAIT
#         * http://www.ivoclarvivadent.com: Please select your region
#         * https://www.enersys.com/: PLEASE SELECT A REGION
#         * https://www.m-petfilm.com/: ENGLISH
#     * Crawl from focal about page only following links that look like part of the about story, maintaining ordering.  Check to see if the other links identified above are also there?
#         * http://xtalsolar.com/investors_partners.html
# * Order known about us pages in the same way the links are found on a home page or about us landing page

# %%
# import data processing and other libraries
import csv
import sys
import requests
import os
import re
import pprint
import pymongo
import traceback
from time import sleep
import requests
import pandas as pd
import io
from IPython.display import display
import time
import numpy as np
from bs4 import BeautifulSoup
import string
import random
from urllib.parse import urlparse, urljoin
from collections import defaultdict
from collections import OrderedDict
import collections

# %%
from boilerpipe.extract import Extractor

# %%
# import sklearn
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_moons, make_circles, make_classification
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.model_selection import GroupKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix

# %%
MONGODB_DB = "FirmDB_20181226"
MONGODB_COLLECTION = "pages_ABOUT"
CONNECTION_STRING = "mongodb://localhost"

client = pymongo.MongoClient(CONNECTION_STRING)
db = client[MONGODB_DB]
col = db[MONGODB_COLLECTION]

ABOUT_DIR = '/Users/sarora/dev/EAGER/data/orgs/about/'
DATA_DIR = '/Users/sarora/dev/EAGER/data/orgs/parsed_page_output/'
TRAINING_PERCENT = .10
pp = pprint.PrettyPrinter()

# %%
def get_domain (url):
    o = urlparse(url.lower())
    domain = o.netloc.strip('www.')
    return domain

# output urls for labeling of training data
results = col.find({},{"url": 1, "firm_name": 1})
df = pd.DataFrame(columns = ('firm_name', 'url', 'label'))
domain_count = defaultdict(lambda:0,{})
for i in range(results.count()):
    result = results.next()
    url = result['url'][0]
    domain_count[get_domain(url)] += 1
    firm_name = result['firm_name'][0] if 'firm_name' in result else ''
    df.loc[i] = [firm_name, url, '']
    
df['gid'] = df.groupby(['firm_name']).ngroup()

# %%
df.gid.nunique()
label_ids = random.sample(range(1, df.gid.nunique()), 200)
df_label = df[df['gid'].isin(label_ids)]
with open(ABOUT_DIR + 'about_pages_to_label.csv', mode='w') as to_label:
    df_label.to_csv(to_label, index=False)

# %%
# read back labeled data (note that about, management/team and partners, are dichotomous)
df_about_labeled = pd.read_csv(ABOUT_DIR + 'about_pages_labeled.csv')
df_about_labeled = df_about_labeled.fillna(0)

# count pages per domain
for index, row in df_about_labeled.iterrows():
    pages_in_domain = domain_count[get_domain(row['url'])]
    df_about_labeled.loc[index,'pages_in_domain'] = pages_in_domain
    is_sole_page = 0 if pages_in_domain > 1 else 1
    df_about_labeled.loc[index,'is_sole_page'] = is_sole_page
    
labeled_urls = list(df_about_labeled['url']) # for training models on labeled urls below
df_about_labeled = df_about_labeled.set_index(['firm_name', 'url'])
print (df_about_labeled.columns.tolist())

# final test set is the rows of the original data frame without the urls in df_about_labeled
# Out:
# ['about_lbl', 'mgmt_lbl', 'partners_lbl', 'ip_lbl', 'about_agg_lbl', 'gid', 'pages_in_domain', 'is_sole_page']

# %% [markdown]
# ## Create features to predict about pages
# Create features:
# 1. title and url path fragment unigrams (also tried n-grams, as well as content from headers, with worse results)
# 2. is home page and doesn't have any other pages
# 3. other ideas here: https://towardsdatascience.com/understanding-feature-engineering-part-3-traditional-methods-for-text-data-f6f7d70acd41

# %%
# load page data and create features

# remove simple article words and punctuation (need to keep 'about')
stop_words = ['the','a'] + list(string.punctuation) 
# remove known company names for model training and evaluation in the labeled data 
remove_regex = re.compile(r'^(3m|united|states|menu|en_us|algeternal|s\d+|sarepta|skygen|nexgen|abbott|adlens|errorpage|\d{1,3}|\d{5,}|\w+\d+|\d+\w+|asten|johnson|baker|hughes|ge|bhge|biocon|egfr|gcsf|biocon|pegfilgrastim|bostik|canon|chevron|phillips|coloplast|cyberonics|microsoft|evoqua|ford|hitachi|glucanbio|hunter|douglas|kimberly|clark|lextar|fisher|lockheed|martin |lux|nec|nanocopoeia|cisco|schlumberger|weccamerica|inanobio|nanocomposix|zoetis|zygo)$', re.IGNORECASE)
# used to filter top-level header content
header_in = re.compile('(about|company|corporate|who.we.are|(^|/)vision|awards|profile|corporate|management|team|history|values|strategy|our |technology|research|commercialization)', flags=re.IGNORECASE)
header_regex = re.compile(r'h[1-9]+')

def clean_string(in_string):
    if not in_string:
        return in_string
    split_words = in_string.lower().split()
    result_words  = [word for word in split_words if word not in stop_words]
    result_words  = [word for word in result_words if not remove_regex.search(word)]
    result = ' '.join(result_words)
    return ' ' + result

def get_page_path_text (url):
    o = urlparse(url.lower())
    path = o.path
    path_parts = path.split ('/')
    path_parts = [part.split('.')[0] for part in path_parts] # remove page names
    path_parts = [split for part in path_parts for split in part.split('-') ] # split on underscores, hyphens, et al
    path_parts = [split for part in path_parts for split in part.split('_') ] # split on underscores, hyphens, et al
    clnd_string = clean_string(' '.join(path_parts))
    return clnd_string

# recurse through the header text to add into feature grams
def get_header_text (headers, names, index):
    texts = [clean_string(header.text) for header in headers if header.name == names[index]]
    texts = list(filter(header_in.search, texts))
    if texts and len(texts[0].split()) > 4:
        if(len(names) > (index + 1)):
            return get_header_text (headers, names, index + 1)
        else:
            return ''
    else: 
        return ' '.join (texts)
    
def process_firms (urls): 
    firm_page_features = {}
    for url in urls: 
        result = col.find_one({"url": url})
        domain = get_domain(url)
        html = result['html'][0]
        
        # print (url)

        soup = BeautifulSoup(html, 'lxml')
        running_text = ''
        path_text = get_page_path_text(url)
        
        if path_text:
            # print (path_text)
            running_text += path_text
            
        if soup.title and soup.title.string:
            # print (soup.title.string)
            running_text += clean_string(soup.title.string)
            
        headers = soup.find_all(header_regex, text=True)
        names = sorted(set ([header.name for header in headers]))
        running_text += get_header_text (headers, names, 0)

        firm_page_features[url] = running_text
        
    return firm_page_features

# %%
# for testing regex
print (get_page_path_text('http://www.google.com/path-en/path_to/page.html'))
print (re.split("\W+|_", "Testing this_thing"))
print (clean_string('3m 01	08	100	10m ford 235 1990 s129 188209 0913lk the ? about us'))
pp.pprint (list(filter(header_in.search, ['about us', 'not found', 'company'])))
# Out:
#  path en path to page
# ['Testing', 'this', 'thing']
#  about us
# ['about us', 'company']

# %%
# get firm website data for n-gram processing 
labeled_firm_page_features = process_firms (labeled_urls)

urls = labeled_firm_page_features.keys()
print (len(urls))
corpus = []
for url in urls:
    corpus.append (labeled_firm_page_features[url])
    
# unigram
ubv = TfidfVectorizer(min_df=0., max_df=1.)
# you can set the n-gram range to 1,2 to get unigrams as well as bigrams (performs worse than just unigrams)
# ubv = TfidfVectorizer(ngram_range=(1,2)) 

ubv_matrix = ubv.fit_transform(corpus)

ubv_matrix = ubv_matrix.toarray()
vocab = ubv.get_feature_names()
ubv_df = pd.DataFrame(ubv_matrix, columns=vocab)
ubv_df.index = urls
ubv_df.index.name='url'
# Out:
# 1031

# %%
# merge two datasets (features and labeled data)
print(ubv_df.shape)
print(df_about_labeled.shape)

all_merged = ubv_df.join(df_about_labeled, how='inner')
print(all_merged.shape)
# Out:
# (1031, 1472)
# (1031, 8)
# (1031, 1480)

# %%
# split labeled and predict datasets 
labeled = all_merged[all_merged['gid'].notnull()]
print (df_about_labeled.columns.tolist())
# Out:
# ['about_lbl', 'mgmt_lbl', 'partners_lbl', 'ip_lbl', 'about_agg_lbl', 'gid', 'pages_in_domain', 'is_sole_page']

# %%
# labeled train/test split
X = labeled.iloc[:,1:len(ubv_df.columns)]
X['pages_in_domain'] = labeled['pages_in_domain']
X['is_sole_page'] = labeled['is_sole_page']
X.to_csv(ABOUT_DIR + 'X.csv', index = True) # for manual inspection

y = labeled.loc[:,'about_lbl']

# %% [markdown]
# ## Train and evaluate the model
# On just the labeled data

# %%
# specify a few models

names = ["Nearest Neighbors", "Linear SVM", "RBF SVM", 
         "Decision Tree", "Random Forest", "Neural Net", "AdaBoost",
         "Naive Bayes", "SVC", "QDA"]

classifiers = [
    KNeighborsClassifier(3),
    SVC(kernel="linear", C=0.025),
    SVC(gamma=2, C=1),
    DecisionTreeClassifier(max_depth=5),
    RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1),
    MLPClassifier(alpha=1),
    AdaBoostClassifier(),
    GaussianNB(),
    SVC(gamma=0.001, C=100.), 
    QuadraticDiscriminantAnalysis()]

# %%
# build dataframe for output metrics 
eval_df = pd.DataFrame (names,index=(range(len(names))), columns=["Name"])
eval_df['Accuracy'] = np.float64(0)
display (eval_df)
# Out:
#                 Name  Accuracy
# 0  Nearest Neighbors       0.0
# 1         Linear SVM       0.0
# 2            RBF SVM       0.0
# 3      Decision Tree       0.0
# 4      Random Forest       0.0
# 5         Neural Net       0.0
# 6           AdaBoost       0.0
# 7        Naive Bayes       0.0
# 8                SVC       0.0
# 9                QDA       0.0

# %%
# build evaluation outputs (currently limited to accuracy)
i = np.int64(0)
for name, clf in zip(names, classifiers):
    display (name)
    scores = cross_val_score(clf, X, y)
    avg_score = np.mean(scores)
    eval_df.set_value(i, 'Accuracy', avg_score)
    i = i + 1
    
display(eval_df)
eval_df.to_clipboard()
# Out:
# 'Nearest Neighbors'
# 'Linear SVM'
# 'RBF SVM'
# 'Decision Tree'
# 'Random Forest'
# 'Neural Net'
# 'AdaBoost'
# 'Naive Bayes'
# 'SVC'
# 'QDA'
#                 Name  Accuracy
# 0  Nearest Neighbors  0.683819
# 1         Linear SVM  0.646946
# 2            RBF SVM  0.702277
# 3      Decision Tree  0.750716
# 4      Random Forest  0.646946
# 5         Neural Net  0.847723
# 6           AdaBoost  0.816710
# 7        Naive Bayes  0.660529
# 8                SVC  0.800189
# 9                QDA  0.475250

# %% [markdown]
# ## Grid search using MLPClassifier to tune hyperparameters

# %%
hls = []
hls.append([100,])
hls.append([70,70,70])
hls.append([40,40,40])
hls.append([10,10,10])
pp.pprint(hls)
# Out:
# [[100], [70, 70, 70], [40, 40, 40], [10, 10, 10]]

# %%
parameters = {'solver': ['lbfgs'], 'max_iter': [300,500,700], 'alpha': 10.0 ** -np.arange(1, 10), 'hidden_layer_sizes': hls, 'random_state':[5,10,15]}
clf_grid = GridSearchCV(MLPClassifier(), parameters, n_jobs=-1)
clf_grid.fit(X,y)

print("Best score: %0.4f" % clf_grid.best_score_)
print("Using the following parameters:")
print(clf_grid.best_params_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-b3629d7b189f> in <module>
# ----> 1 parameters = {'solver': ['lbfgs'], 'max_iter': [300,500,700], 'alpha': 10.0 ** -np.arange(1, 10), 'hidden_layer_sizes': hls, 'random_state':[5,10,15]}
#       2 clf_grid = GridSearchCV(MLPClassifier(), parameters, n_jobs=-1)
#       3 clf_grid.fit(X,y)
#       4
#       5 print("Best score: %0.4f" % clf_grid.best_score_)
#
# NameError: name 'hls' is not defined

# %%
# train neural net model with best hyperparameter configuration
clf = MLPClassifier(alpha=0.01, hidden_layer_sizes=(70,70,70), max_iter=300, random_state=10, solver='lbfgs')
clf.fit(X, y)

y_hat = clf.predict(X)

# %%
# print all instances where predictions don't match labels (for inspection)
confusion_matrix(y, y_hat)

for key, y_i, y_hat_i in zip(list(X.index), y, y_hat):
    if y_i != y_hat_i:
        print(key[1], 'has been classified as ', y_hat_i, 'but should be ', y_i)
# Out:
# http://acaciaresearch.com/history/ has been classified as  1.0 but should be  0.0
# https://www.asml.com/company/faq/en/s32894 has been classified as  1.0 but should be  0.0
# https://www.asml.com/company/company-calendar/en/s32775 has been classified as  1.0 but should be  0.0
# https://allisontransmission.com/company/centennial has been classified as  0.0 but should be  1.0
# https://allisontransmission.com/company/history-heritage has been classified as  1.0 but should be  0.0
# https://www.amgen.com/about/how-we-operate/policies-practices-and-disclosures/ has been classified as  0.0 but should be  1.0
# https://www.amgen.com/about/quick-facts/ has been classified as  0.0 but should be  1.0
# https://www.andritz.com/group-en/about-us/gr-company-boards has been classified as  1.0 but should be  0.0
# http://angiotech.com/about/itemlist/category/59-come-see-us has been classified as  1.0 but should be  0.0
# https://www.adm.com/our-company/procurement has been classified as  0.0 but should be  1.0
# https://www.adm.com/our-company/adm-facts has been classified as  0.0 but should be  1.0
# https://www.arkema.com/en/social-responsibility/vision-and-strategy/ has been classified as  0.0 but should be  1.0
# https://www.arkema.com/en/arkema-group/profile/ has been classified as  0.0 but should be  1.0
# https://www.arkema.com/en/social-responsibility/vision-and-strategy/materiality-analysis/ has been classified as  0.0 but should be  1.0
# https://www.shire.com/who-we-are/areas-of-focus has been classified as  0.0 but should be  1.0
# https://www.shire.com/who-we-are/responsibility has been classified as  0.0 but should be  1.0
# https://www.shire.com/who-we-are/our-story/our-footprint has been classified as  1.0 but should be  0.0
# http://www.brightleafpower.com/innovation/ has been classified as  0.0 but should be  1.0
# https://www.baxter.com/our-story/corporate-responsibility has been classified as  1.0 but should be  0.0
# http://biocon.com/biocon_aboutus_factsheet.asp has been classified as  0.0 but should be  1.0
# http://biocon.com/biocon_aboutus.asp has been classified as  0.0 but should be  1.0
# http://biocon.com/biocon_aboutus_businesses.asp has been classified as  0.0 but should be  1.0
# https://braunintertec.com/about-us/safety-quality-certifications/ has been classified as  1.0 but should be  0.0
# http://bsa-hq.org/ has been classified as  1.0 but should be  0.0
# http://www.agcbio.com/about/environmental_policy has been classified as  0.0 but should be  1.0
# https://global.canon/en/corporate/ has been classified as  0.0 but should be  1.0
# https://www.christiedigital.com/en-us/about-christie has been classified as  0.0 but should be  1.0
# https://www.coloplast.us/about-us/ has been classified as  0.0 but should be  1.0
# https://www.coriant.com/company has been classified as  0.0 but should be  1.0
# http://www.cristal.com/chinese/Pages/about.aspx has been classified as  0.0 but should be  1.0
# https://livanova.cyberonics.com/about/corporate-compliance has been classified as  1.0 but should be  0.0
# https://livanova.cyberonics.com/about/corporate-governance has been classified as  1.0 but should be  0.0
# https://www.leonardodrs.com/about-us/ has been classified as  0.0 but should be  1.0
# https://www.leonardodrs.com/about-us/thought-leadership/ has been classified as  0.0 but should be  1.0
# http://www.deltaww.com/about/brand.aspx?secID=5&pid=2&tid=0&hl=en-US has been classified as  1.0 but should be  0.0
# https://www.dialogic.com/about-us has been classified as  0.0 but should be  1.0
# https://www.eni.com/en_IT/investors/risk-management.page has been classified as  0.0 but should be  1.0
# http://ecovativedesign.com/ has been classified as  0.0 but should be  1.0
# https://www.envisionit.com/about-us/our-people has been classified as  1.0 but should be  0.0
# https://www.envisionit.com/about-us/our-partners has been classified as  1.0 but should be  0.0
# https://www.envisionit.com/about-us/our-microsoft-partnership has been classified as  1.0 but should be  0.0
# https://www.genomichealth.com/en-US/who_we_are/our_founders has been classified as  1.0 but should be  0.0
# https://www.westerndigital.com/company/innovations has been classified as  1.0 but should be  0.0
# http://hiqsolar.com/contact-us.html has been classified as  0.0 but should be  1.0
# http://hm3energy.com/about/hm3-energy-achievements/ has been classified as  0.0 but should be  1.0
# http://www.hrl.com/about/directions has been classified as  1.0 but should be  0.0
# https://utcaerospacesystems.com/join-the-utc-team/ has been classified as  0.0 but should be  1.0
# https://utcaerospacesystems.com/corporate-citizenship/ has been classified as  0.0 but should be  1.0
# https://www.heidelberg.com/global/de/company/company_overview.jsp has been classified as  0.0 but should be  1.0
# https://www.hunterdouglas.com/corporate-responsibility has been classified as  1.0 but should be  0.0
# http://imds-ohio.com/AboutUs/ has been classified as  0.0 but should be  1.0
# https://www.infineum.com/en/careers/our-teams/ has been classified as  0.0 but should be  1.0
# https://www.incyte.com/who-we-are/our-community has been classified as  1.0 but should be  0.0
# https://www.infinera.com/company/customers/ has been classified as  0.0 but should be  1.0
# http://www.nmm.jx-group.co.jp/english/company/data.html has been classified as  0.0 but should be  1.0
# http://www.kaneka.co.jp/en/corporate/ has been classified as  0.0 but should be  1.0
# http://www.kaneka.co.jp/en/corporate/director/ has been classified as  0.0 but should be  1.0
# http://www.kaneka.co.jp/en/corporate/chronicle/ has been classified as  1.0 but should be  0.0
# https://www.kashivpharma.com/about/people-management/ has been classified as  0.0 but should be  1.0
# https://www.kimberly-clark.com/en-us/company/employees has been classified as  0.0 but should be  1.0
# https://www.kronos.com/about-us has been classified as  0.0 but should be  1.0
# http://www.kureha.co.jp/en/about/group.html has been classified as  1.0 but should be  0.0
# http://lextar.com/?sn=93&lang=en-US has been classified as  0.0 but should be  1.0
# https://lockheedmartin.com/en-us/who-we-are/international.html has been classified as  0.0 but should be  1.0
# https://lockheedmartin.com/en-us/who-we-are/business-areas.html has been classified as  1.0 but should be  0.0
# https://www.microsemi.com/company/quality has been classified as  0.0 but should be  1.0
# https://www.microsemi.com/company/technology has been classified as  0.0 but should be  1.0
# http://www.molecularrebar.com/our-team-molecular-rebar/ has been classified as  1.0 but should be  0.0
# http://nanotechlubricantsinc.com/Home.html has been classified as  0.0 but should be  1.0
# https://nanocopoeia.com/ has been classified as  1.0 but should be  0.0
# http://nano.com/nanomix.html has been classified as  0.0 but should be  1.0
# https://www.neb.com/research has been classified as  0.0 but should be  1.0
# https://www.neb.com/about-neb has been classified as  0.0 but should be  1.0
# http://www.northropgrumman.com/AboutUs/InnovationNetwork/Pages/default.aspx has been classified as  0.0 but should be  1.0
# https://www.oki.com/en/profile/info/manage.html has been classified as  1.0 but should be  0.0
# https://www.oracle.com/corporate/ has been classified as  0.0 but should be  1.0
# https://www.paccar.com/about-us/contact/ has been classified as  1.0 but should be  0.0
# https://www.paccar.com/about-us/philanthropy/ has been classified as  1.0 but should be  0.0
# https://www.plex.tv/about/charity/ has been classified as  1.0 but should be  0.0
# http://www.reynoldstechnology.biz/company-butted-steel-tubing/our-people/ has been classified as  1.0 but should be  0.0
# https://displaysolutions.samsung.com/about-us/notice has been classified as  1.0 but should be  0.0
# https://displaysolutions.samsung.com/industries/corporate has been classified as  0.0 but should be  1.0
# https://selmanlog.com/Default.aspx has been classified as  0.0 but should be  1.0
# https://www.sandisk.com/about has been classified as  0.0 but should be  1.0
# https://www.slb.com/about/rd/research.aspx has been classified as  0.0 but should be  1.0
# https://www.slb.com/about/history/1920s.aspx has been classified as  1.0 but should be  0.0
# https://www.sjm.com/en/about/our-commitments?clset=af584191-45c9-4201-8740-5409f4cf8bdd%3ab20716c1-c2a6-4e4c-844b-d0dd6899eb3a has been classified as  1.0 but should be  0.0
# https://www.sjm.com/en/about?clset=af584191-45c9-4201-8740-5409f4cf8bdd%3ab20716c1-c2a6-4e4c-844b-d0dd6899eb3a has been classified as  0.0 but should be  1.0
# https://www.sunchemical.com/about/our-sustainability/our-approach/ has been classified as  1.0 but should be  0.0
# https://www.sunchemical.com/about/ has been classified as  0.0 but should be  1.0
# https://www.sunchemical.com/200-years/ has been classified as  0.0 but should be  1.0
# http://taiyo-hd.co.jp/en/group/thou/ has been classified as  0.0 but should be  1.0
# http://taiyo-hd.co.jp/en/about/philosophy/ has been classified as  0.0 but should be  1.0
# https://www.takeda.com/who-we-are/corporate-governance/ has been classified as  0.0 but should be  1.0
# https://www.takeda.com/who-we-are/our-people/ has been classified as  1.0 but should be  0.0
# https://www.takeda.com/who-we-are/how-we-work/ has been classified as  1.0 but should be  0.0
# http://easterncompany.com/company-governance.php has been classified as  1.0 but should be  0.0
# https://www.tel.com/about/cg/ has been classified as  0.0 but should be  1.0
# https://www.tel.com/about/message/ has been classified as  1.0 but should be  0.0
# https://www.tel.com/about/locations/ has been classified as  1.0 but should be  0.0
# https://www.tel.com/about/ptc/ has been classified as  0.0 but should be  1.0
# https://www.toray.com/aboutus/philosophy.html has been classified as  0.0 but should be  1.0
# https://www.toray.com/aboutus/visual/index.html has been classified as  1.0 but should be  0.0
# http://www.transposagenbio.com/about-us/our-people has been classified as  1.0 but should be  0.0
# http://www.verliantenergy.com/ has been classified as  0.0 but should be  1.0
# https://www.zoetis.com/about-us/zoetis-at-a-glance.aspx has been classified as  0.0 but should be  1.0
# https://www.zoetis.com/about-us/core-beliefs.aspx has been classified as  0.0 but should be  1.0

# %% [markdown]
# ## Predict about pages for unlabeled data

# %%
# prepare domain level features 
df_predict = df[~df['url'].isin(labeled_urls)] # careful: index is firm_name and url now
# count pages per domain
for index, row in df_predict.iterrows():
    pages_in_domain = domain_count[get_domain(row['url'])]
    df_predict.loc[index,'pages_in_domain'] = pages_in_domain
    is_sole_page = 0 if pages_in_domain > 1 else 1
    df_predict.loc[index,'is_sole_page'] = is_sole_page
    
# set index 
df_predict = df_predict.set_index(['firm_name', 'url'])
print (df_predict.columns.tolist())
# Out:
# ['label', 'gid', 'pages_in_domain', 'is_sole_page']

# %%
# check to see whether there are duplicate urls
# note: there should be because different assignees may map to the same domain (see error above)
counter=collections.Counter(df_predict.index)
most_common = counter.most_common(10)
pp.pprint (most_common)
# Out:
# [(('Mitsubishi Metal Corporation',
#    'https://www.mitsubishicorp.com/jp/en/about/plan/'),
#   1),
#  (('22nd Century Limited', 'http://www.xxiicentury.com/history/'), 1),
#  (('Mitsubishi Metal Corporation',
#    'https://www.mitsubishicorp.com/jp/en/about/global/'),
#   1),
#  (('Mitsubishi Metal Corporation',
#    'https://www.mitsubishicorp.com/jp/en/about/message/'),
#   1),
#  (('Forest Concepts', 'http://forestconcepts.com/index.php?page=01002'), 1),
#  (('ZENA TECHNOLOGIES', 'http://xena-technologies.com/program-management/'), 1),
#  (('Kansai Paint Co.', 'https://www.kansai.com/about-us/corporate_data.html'),
#   1),
#  (('W&Wsens Devices', 'https://www.wwsensdevices.com/'), 1),
#  (('Kansai Paint Co.', 'https://www.kansai.com/about-us/brand.html'), 1),
#  (('Kansai Paint Co.', 'https://www.kansai.com/about-us/'), 1)]

# %%
# prepare n-gram features
unlabeled_firm_page_features = process_firms (set(df_predict.index.get_level_values('url')))

prediction_urls = unlabeled_firm_page_features.keys()

pred_corpus = []
for url in prediction_urls:
    pred_corpus.append (unlabeled_firm_page_features[url])

ubv_prediction_matrix = ubv.transform(pred_corpus)

ubv_prediction_matrix = ubv_prediction_matrix.toarray()
vocab = ubv.get_feature_names()
ubv_prediction_df = pd.DataFrame(ubv_prediction_matrix, columns=vocab)
ubv_prediction_df.index = prediction_urls
ubv_prediction_df.index.name='url'

# %%
print(ubv_prediction_df.shape)
print(df_predict.shape)

predict_merged = ubv_prediction_df.join(df_predict, how='right', rsuffix='_lbl')
print(predict_merged.shape)

# merge
X_test = predict_merged.iloc[:,1:len(ubv_prediction_df.columns)]
X_test['pages_in_domain'] = predict_merged['pages_in_domain']
X_test['is_sole_page'] = predict_merged['is_sole_page']
print (X.shape)
print (X_test.shape) # should be the same number of cols

X_test
# Out:
# (4147, 1472)
# (4516, 4)
# (4516, 1476)
# (1031, 1473)
# (4516, 1473)
#                                                                                                  10m  \
# firm_name                                    url
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/plan/    0.0
# 22nd Century Limited                         http://www.xxiicentury.com/history/                 0.0
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/global/  0.0
#                                              https://www.mitsubishicorp.com/jp/en/about/mess...  0.0
# Forest Concepts                              http://forestconcepts.com/index.php?page=01002      0.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/program-management/    0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/corporate_data....  0.0
# W&Wsens Devices                              https://www.wwsensdevices.com/                      0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/brand.html          0.0
#                                              https://www.kansai.com/about-us/                    0.0
# Xintec Inc.                                  http://www.xintec.com.tw/eng/CSR_Corporate_Gove...  0.0
# k-Space Associates                           https://www.k-space.com/company/distributors/       0.0
# Amkor Technology                             https://amkor.com/company-history/                  0.0
#                                              https://amkor.com/technology/system-in-package/     0.0
# Wine.com                                     https://www.wine.com/content/landing/corporate-...  0.0
# Industrial Technology Research Institute     https://www.itri.org.tw/eng/Content/Management/...  0.0
# Vizio Inc.                                   https://www.vizio.com/about                         0.0
# Midrex Technologies                          https://midrex.com/company-info/history             0.0
# VMware                                       https://www.vmware.com/company/leadership.html      0.0
#                                              https://www.vmware.com/company/innovation.html      0.0
# VEECO PRECISION SURFACE PROCESSING LLC       http://www.veeco.com/company                        0.0
# ABB AB                                       https://new.abb.com/network-management              0.0
# VMware                                       https://www.vmware.com/company/foundation.html      0.0
# ABB AB                                       https://new.abb.com/about                           0.0
#                                              https://new.abb.com/cpm                             0.0
# DuPont Teijin Films U.S. Limited Partnership https://usa.dupontteijinfilms.com/about/            0.0
# Vaxiion Therapeutics                         http://www.vaxiion.com/executive-management.html    0.0
#                                              http://www.vaxiion.com/the-company.html             0.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/                       0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/history.html        0.0
# ...                                                                                              ...
# Ormat Technologies Inc.                      https://www.ormat.com/en/company/general/view/?...  0.0
# Gram Power                                   https://grampower.com/about-us/our-team.html        0.0
# SAINT-GOBAIN ABRASIFS                        https://www.saint-gobain-abrasives.com/en-us/pr...  0.0
# Ormat Technologies Inc.                      https://www.ormat.com/en/company/general/view/?...  0.0
# Lintec Corporation                           http://www.lintec-global.com/about/message/         0.0
#                                              http://www.lintec-global.com/about/history/         0.0
# Angaza Design                                https://www.angaza.com/about/                       0.0
# Lintec Corporation                           http://www.lintec-global.com/ir/management/         0.0
#                                              http://www.lintec-global.com/about/brochure/book/   0.0
# Kulite Semiconductor Products                https://www.kulite.com/company/news/                0.0
# Lintec Corporation                           http://www.lintec-global.com/about/country/amer...  0.0
#                                              http://www.lintec-global.com/about/network/         0.0
# Kulite Semiconductor Products                https://www.kulite.com/company/contact-info/        0.0
#                                              https://www.kulite.com/company/customer-resources/  0.0
#                                              https://www.kulite.com/company/corporate-respon...  0.0
#                                              https://www.kulite.com/company/supplier-code-of...  0.0
# Bend Research                                https://www.capsugel.com/about-capsugel             0.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news                    0.0
#                                              http://pidc.com/our-company/locations               0.0
# Valicor                                      http://trucent.com/                                 0.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news/pacific-indust...  0.0
# SOLAZYME                                     http://solazyme.com/                                0.0
# Starlight Energy Holdings LLC                http://www.starlightenergy.us/                      0.0
# Solight Solar                                http://www.solight.com/                             0.0
# ZON                                          https://www.zon.si/                                 0.0
# Ostendo Technologies                         https://www.ostendo.com/                            0.0
# Quantapore                                   https://quantapore.com/                             0.0
# Synaptic Research                            https://research.synaptic.co.uk/SynapticResearc...  0.0
# Sun Drilling Products Corporation            https://www.sunspecialtyproducts.com/               0.0
# MEDport                                      https://medport.com/                                0.0
#
#                                                                                                  13485  \
# firm_name                                    url
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/plan/      0.0
# 22nd Century Limited                         http://www.xxiicentury.com/history/                   0.0
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/global/    0.0
#                                              https://www.mitsubishicorp.com/jp/en/about/mess...    0.0
# Forest Concepts                              http://forestconcepts.com/index.php?page=01002        0.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/program-management/      0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/corporate_data....    0.0
# W&Wsens Devices                              https://www.wwsensdevices.com/                        0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/brand.html            0.0
#                                              https://www.kansai.com/about-us/                      0.0
# Xintec Inc.                                  http://www.xintec.com.tw/eng/CSR_Corporate_Gove...    0.0
# k-Space Associates                           https://www.k-space.com/company/distributors/         0.0
# Amkor Technology                             https://amkor.com/company-history/                    0.0
#                                              https://amkor.com/technology/system-in-package/       0.0
# Wine.com                                     https://www.wine.com/content/landing/corporate-...    0.0
# Industrial Technology Research Institute     https://www.itri.org.tw/eng/Content/Management/...    0.0
# Vizio Inc.                                   https://www.vizio.com/about                           0.0
# Midrex Technologies                          https://midrex.com/company-info/history               0.0
# VMware                                       https://www.vmware.com/company/leadership.html        0.0
#                                              https://www.vmware.com/company/innovation.html        0.0
# VEECO PRECISION SURFACE PROCESSING LLC       http://www.veeco.com/company                          0.0
# ABB AB                                       https://new.abb.com/network-management                0.0
# VMware                                       https://www.vmware.com/company/foundation.html        0.0
# ABB AB                                       https://new.abb.com/about                             0.0
#                                              https://new.abb.com/cpm                               0.0
# DuPont Teijin Films U.S. Limited Partnership https://usa.dupontteijinfilms.com/about/              0.0
# Vaxiion Therapeutics                         http://www.vaxiion.com/executive-management.html      0.0
#                                              http://www.vaxiion.com/the-company.html               0.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/                         0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/history.html          0.0
# ...                                                                                                ...
# Ormat Technologies Inc.                      https://www.ormat.com/en/company/general/view/?...    0.0
# Gram Power                                   https://grampower.com/about-us/our-team.html          0.0
# SAINT-GOBAIN ABRASIFS                        https://www.saint-gobain-abrasives.com/en-us/pr...    0.0
# Ormat Technologies Inc.                      https://www.ormat.com/en/company/general/view/?...    0.0
# Lintec Corporation                           http://www.lintec-global.com/about/message/           0.0
#                                              http://www.lintec-global.com/about/history/           0.0
# Angaza Design                                https://www.angaza.com/about/                         0.0
# Lintec Corporation                           http://www.lintec-global.com/ir/management/           0.0
#                                              http://www.lintec-global.com/about/brochure/book/     0.0
# Kulite Semiconductor Products                https://www.kulite.com/company/news/                  0.0
# Lintec Corporation                           http://www.lintec-global.com/about/country/amer...    0.0
#                                              http://www.lintec-global.com/about/network/           0.0
# Kulite Semiconductor Products                https://www.kulite.com/company/contact-info/          0.0
#                                              https://www.kulite.com/company/customer-resources/    0.0
#                                              https://www.kulite.com/company/corporate-respon...    0.0
#                                              https://www.kulite.com/company/supplier-code-of...    0.0
# Bend Research                                https://www.capsugel.com/about-capsugel               0.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news                      0.0
#                                              http://pidc.com/our-company/locations                 0.0
# Valicor                                      http://trucent.com/                                   0.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news/pacific-indust...    0.0
# SOLAZYME                                     http://solazyme.com/                                  0.0
# Starlight Energy Holdings LLC                http://www.starlightenergy.us/                        0.0
# Solight Solar                                http://www.solight.com/                               0.0
# ZON                                          https://www.zon.si/                                   0.0
# Ostendo Technologies                         https://www.ostendo.com/                              0.0
# Quantapore                                   https://quantapore.com/                               0.0
# Synaptic Research                            https://research.synaptic.co.uk/SynapticResearc...    0.0
# Sun Drilling Products Corporation            https://www.sunspecialtyproducts.com/                 0.0
# MEDport                                      https://medport.com/                                  0.0
#
#                                                                                                  14001  \
# firm_name                                    url
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/plan/      0.0
# 22nd Century Limited                         http://www.xxiicentury.com/history/                   0.0
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/global/    0.0
#                                              https://www.mitsubishicorp.com/jp/en/about/mess...    0.0
# Forest Concepts                              http://forestconcepts.com/index.php?page=01002        0.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/program-management/      0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/corporate_data....    0.0
# W&Wsens Devices                              https://www.wwsensdevices.com/                        0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/brand.html            0.0
#                                              https://www.kansai.com/about-us/                      0.0
# Xintec Inc.                                  http://www.xintec.com.tw/eng/CSR_Corporate_Gove...    0.0
# k-Space Associates                           https://www.k-space.com/company/distributors/         0.0
# Amkor Technology                             https://amkor.com/company-history/                    0.0
#                                              https://amkor.com/technology/system-in-package/       0.0
# Wine.com                                     https://www.wine.com/content/landing/corporate-...    0.0
# Industrial Technology Research Institute     https://www.itri.org.tw/eng/Content/Management/...    0.0
# Vizio Inc.                                   https://www.vizio.com/about                           0.0
# Midrex Technologies                          https://midrex.com/company-info/history               0.0
# VMware                                       https://www.vmware.com/company/leadership.html        0.0
#                                              https://www.vmware.com/company/innovation.html        0.0
# VEECO PRECISION SURFACE PROCESSING LLC       http://www.veeco.com/company                          0.0
# ABB AB                                       https://new.abb.com/network-management                0.0
# VMware                                       https://www.vmware.com/company/foundation.html        0.0
# ABB AB                                       https://new.abb.com/about                             0.0
#                                              https://new.abb.com/cpm                               0.0
# DuPont Teijin Films U.S. Limited Partnership https://usa.dupontteijinfilms.com/about/              0.0
# Vaxiion Therapeutics                         http://www.vaxiion.com/executive-management.html      0.0
#                                              http://www.vaxiion.com/the-company.html               0.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/                         0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/history.html          0.0
# ...                                                                                                ...
# Ormat Technologies Inc.                      https://www.ormat.com/en/company/general/view/?...    0.0
# Gram Power                                   https://grampower.com/about-us/our-team.html          0.0
# SAINT-GOBAIN ABRASIFS                        https://www.saint-gobain-abrasives.com/en-us/pr...    0.0
# Ormat Technologies Inc.                      https://www.ormat.com/en/company/general/view/?...    0.0
# Lintec Corporation                           http://www.lintec-global.com/about/message/           0.0
#                                              http://www.lintec-global.com/about/history/           0.0
# Angaza Design                                https://www.angaza.com/about/                         0.0
# Lintec Corporation                           http://www.lintec-global.com/ir/management/           0.0
#                                              http://www.lintec-global.com/about/brochure/book/     0.0
# Kulite Semiconductor Products                https://www.kulite.com/company/news/                  0.0
# Lintec Corporation                           http://www.lintec-global.com/about/country/amer...    0.0
#                                              http://www.lintec-global.com/about/network/           0.0
# Kulite Semiconductor Products                https://www.kulite.com/company/contact-info/          0.0
#                                              https://www.kulite.com/company/customer-resources/    0.0
#                                              https://www.kulite.com/company/corporate-respon...    0.0
#                                              https://www.kulite.com/company/supplier-code-of...    0.0
# Bend Research                                https://www.capsugel.com/about-capsugel               0.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news                      0.0
#                                              http://pidc.com/our-company/locations                 0.0
# Valicor                                      http://trucent.com/                                   0.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news/pacific-indust...    0.0
# SOLAZYME                                     http://solazyme.com/                                  0.0
# Starlight Energy Holdings LLC                http://www.starlightenergy.us/                        0.0
# Solight Solar                                http://www.solight.com/                               0.0
# ZON                                          https://www.zon.si/                                   0.0
# Ostendo Technologies                         https://www.ostendo.com/                              0.0
# Quantapore                                   https://quantapore.com/                               0.0
# Synaptic Research                            https://research.synaptic.co.uk/SynapticResearc...    0.0
# Sun Drilling Products Corporation            https://www.sunspecialtyproducts.com/                 0.0
# MEDport                                      https://medport.com/                                  0.0
#
#                                                                                                  1870s  \
# firm_name                                    url
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/plan/      0.0
# 22nd Century Limited                         http://www.xxiicentury.com/history/                   0.0
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/global/    0.0
#                                              https://www.mitsubishicorp.com/jp/en/about/mess...    0.0
# Forest Concepts                              http://forestconcepts.com/index.php?page=01002        0.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/program-management/      0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/corporate_data....    0.0
# W&Wsens Devices                              https://www.wwsensdevices.com/                        0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/brand.html            0.0
#                                              https://www.kansai.com/about-us/                      0.0
# Xintec Inc.                                  http://www.xintec.com.tw/eng/CSR_Corporate_Gove...    0.0
# k-Space Associates                           https://www.k-space.com/company/distributors/         0.0
# Amkor Technology                             https://amkor.com/company-history/                    0.0
#                                              https://amkor.com/technology/system-in-package/       0.0
# Wine.com                                     https://www.wine.com/content/landing/corporate-...    0.0
# Industrial Technology Research Institute     https://www.itri.org.tw/eng/Content/Management/...    0.0
# Vizio Inc.                                   https://www.vizio.com/about                           0.0
# Midrex Technologies                          https://midrex.com/company-info/history               0.0
# VMware                                       https://www.vmware.com/company/leadership.html        0.0
#                                              https://www.vmware.com/company/innovation.html        0.0
# VEECO PRECISION SURFACE PROCESSING LLC       http://www.veeco.com/company                          0.0
# ABB AB                                       https://new.abb.com/network-management                0.0
# VMware                                       https://www.vmware.com/company/foundation.html        0.0
# ABB AB                                       https://new.abb.com/about                             0.0
#                                              https://new.abb.com/cpm                               0.0
# DuPont Teijin Films U.S. Limited Partnership https://usa.dupontteijinfilms.com/about/              0.0
# Vaxiion Therapeutics                         http://www.vaxiion.com/executive-management.html      0.0
#                                              http://www.vaxiion.com/the-company.html               0.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/                         0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/history.html          0.0
# ...                                                                                                ...
# Ormat Technologies Inc.                      https://www.ormat.com/en/company/general/view/?...    0.0
# Gram Power                                   https://grampower.com/about-us/our-team.html          0.0
# SAINT-GOBAIN ABRASIFS                        https://www.saint-gobain-abrasives.com/en-us/pr...    0.0
# Ormat Technologies Inc.                      https://www.ormat.com/en/company/general/view/?...    0.0
# Lintec Corporation                           http://www.lintec-global.com/about/message/           0.0
#                                              http://www.lintec-global.com/about/history/           0.0
# Angaza Design                                https://www.angaza.com/about/                         0.0
# Lintec Corporation                           http://www.lintec-global.com/ir/management/           0.0
#                                              http://www.lintec-global.com/about/brochure/book/     0.0
# Kulite Semiconductor Products                https://www.kulite.com/company/news/                  0.0
# Lintec Corporation                           http://www.lintec-global.com/about/country/amer...    0.0
#                                              http://www.lintec-global.com/about/network/           0.0
# Kulite Semiconductor Products                https://www.kulite.com/company/contact-info/          0.0
#                                              https://www.kulite.com/company/customer-resources/    0.0
#                                              https://www.kulite.com/company/corporate-respon...    0.0
#                                              https://www.kulite.com/company/supplier-code-of...    0.0
# Bend Research                                https://www.capsugel.com/about-capsugel               0.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news                      0.0
#                                              http://pidc.com/our-company/locations                 0.0
# Valicor                                      http://trucent.com/                                   0.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news/pacific-indust...    0.0
# SOLAZYME                                     http://solazyme.com/                                  0.0
# Starlight Energy Holdings LLC                http://www.starlightenergy.us/                        0.0
# Solight Solar                                http://www.solight.com/                               0.0
# ZON                                          https://www.zon.si/                                   0.0
# Ostendo Technologies                         https://www.ostendo.com/                              0.0
# Quantapore                                   https://quantapore.com/                               0.0
# Synaptic Research                            https://research.synaptic.co.uk/SynapticResearc...    0.0
# Sun Drilling Products Corporation            https://www.sunspecialtyproducts.com/                 0.0
# MEDport                                      https://medport.com/                                  0.0
#
#                                                                                                  1910s  \
# firm_name                                    url
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/plan/      0.0
# 22nd Century Limited                         http://www.xxiicentury.com/history/                   0.0
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/global/    0.0
#                                              https://www.mitsubishicorp.com/jp/en/about/mess...    0.0
# Forest Concepts                              http://forestconcepts.com/index.php?page=01002        0.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/program-management/      0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/corporate_data....    0.0
# W&Wsens Devices                              https://www.wwsensdevices.com/                        0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/brand.html            0.0
#                                              https://www.kansai.com/about-us/                      0.0
# Xintec Inc.                                  http://www.xintec.com.tw/eng/CSR_Corporate_Gove...    0.0
# k-Space Associates                           https://www.k-space.com/company/distributors/         0.0
# Amkor Technology                             https://amkor.com/company-history/                    0.0
#                                              https://amkor.com/technology/system-in-package/       0.0
# Wine.com                                     https://www.wine.com/content/landing/corporate-...    0.0
# Industrial Technology Research Institute     https://www.itri.org.tw/eng/Content/Management/...    0.0
# Vizio Inc.                                   https://www.vizio.com/about                           0.0
# Midrex Technologies                          https://midrex.com/company-info/history               0.0
# VMware                                       https://www.vmware.com/company/leadership.html        0.0
#                                              https://www.vmware.com/company/innovation.html        0.0
# VEECO PRECISION SURFACE PROCESSING LLC       http://www.veeco.com/company                          0.0
# ABB AB                                       https://new.abb.com/network-management                0.0
# VMware                                       https://www.vmware.com/company/foundation.html        0.0
# ABB AB                                       https://new.abb.com/about                             0.0
#                                              https://new.abb.com/cpm                               0.0
# DuPont Teijin Films U.S. Limited Partnership https://usa.dupontteijinfilms.com/about/              0.0
# Vaxiion Therapeutics                         http://www.vaxiion.com/executive-management.html      0.0
#                                              http://www.vaxiion.com/the-company.html               0.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/                         0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/history.html          0.0
# ...                                                                                                ...
# Ormat Technologies Inc.                      https://www.ormat.com/en/company/general/view/?...    0.0
# Gram Power                                   https://grampower.com/about-us/our-team.html          0.0
# SAINT-GOBAIN ABRASIFS                        https://www.saint-gobain-abrasives.com/en-us/pr...    0.0
# Ormat Technologies Inc.                      https://www.ormat.com/en/company/general/view/?...    0.0
# Lintec Corporation                           http://www.lintec-global.com/about/message/           0.0
#                                              http://www.lintec-global.com/about/history/           0.0
# Angaza Design                                https://www.angaza.com/about/                         0.0
# Lintec Corporation                           http://www.lintec-global.com/ir/management/           0.0
#                                              http://www.lintec-global.com/about/brochure/book/     0.0
# Kulite Semiconductor Products                https://www.kulite.com/company/news/                  0.0
# Lintec Corporation                           http://www.lintec-global.com/about/country/amer...    0.0
#                                              http://www.lintec-global.com/about/network/           0.0
# Kulite Semiconductor Products                https://www.kulite.com/company/contact-info/          0.0
#                                              https://www.kulite.com/company/customer-resources/    0.0
#                                              https://www.kulite.com/company/corporate-respon...    0.0
#                                              https://www.kulite.com/company/supplier-code-of...    0.0
# Bend Research                                https://www.capsugel.com/about-capsugel               0.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news                      0.0
#                                              http://pidc.com/our-company/locations                 0.0
# Valicor                                      http://trucent.com/                                   0.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news/pacific-indust...    0.0
# SOLAZYME                                     http://solazyme.com/                                  0.0
# Starlight Energy Holdings LLC                http://www.starlightenergy.us/                        0.0
# Solight Solar                                http://www.solight.com/                               0.0
# ZON                                          https://www.zon.si/                                   0.0
# Ostendo Technologies                         https://www.ostendo.com/                              0.0
# Quantapore                                   https://quantapore.com/                               0.0
# Synaptic Research                            https://research.synaptic.co.uk/SynapticResearc...    0.0
# Sun Drilling Products Corporation            https://www.sunspecialtyproducts.com/                 0.0
# MEDport                                      https://medport.com/                                  0.0
#
#                                                                                                  1920s  \
# firm_name                                    url
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/plan/      0.0
# 22nd Century Limited                         http://www.xxiicentury.com/history/                   0.0
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/global/    0.0
#                                              https://www.mitsubishicorp.com/jp/en/about/mess...    0.0
# Forest Concepts                              http://forestconcepts.com/index.php?page=01002        0.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/program-management/      0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/corporate_data....    0.0
# W&Wsens Devices                              https://www.wwsensdevices.com/                        0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/brand.html            0.0
#                                              https://www.kansai.com/about-us/                      0.0
# Xintec Inc.                                  http://www.xintec.com.tw/eng/CSR_Corporate_Gove...    0.0
# k-Space Associates                           https://www.k-space.com/company/distributors/         0.0
# Amkor Technology                             https://amkor.com/company-history/                    0.0
#                                              https://amkor.com/technology/system-in-package/       0.0
# Wine.com                                     https://www.wine.com/content/landing/corporate-...    0.0
# Industrial Technology Research Institute     https://www.itri.org.tw/eng/Content/Management/...    0.0
# Vizio Inc.                                   https://www.vizio.com/about                           0.0
# Midrex Technologies                          https://midrex.com/company-info/history               0.0
# VMware                                       https://www.vmware.com/company/leadership.html        0.0
#                                              https://www.vmware.com/company/innovation.html        0.0
# VEECO PRECISION SURFACE PROCESSING LLC       http://www.veeco.com/company                          0.0
# ABB AB                                       https://new.abb.com/network-management                0.0
# VMware                                       https://www.vmware.com/company/foundation.html        0.0
# ABB AB                                       https://new.abb.com/about                             0.0
#                                              https://new.abb.com/cpm                               0.0
# DuPont Teijin Films U.S. Limited Partnership https://usa.dupontteijinfilms.com/about/              0.0
# Vaxiion Therapeutics                         http://www.vaxiion.com/executive-management.html      0.0
#                                              http://www.vaxiion.com/the-company.html               0.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/                         0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/history.html          0.0
# ...                                                                                                ...
# Ormat Technologies Inc.                      https://www.ormat.com/en/company/general/view/?...    0.0
# Gram Power                                   https://grampower.com/about-us/our-team.html          0.0
# SAINT-GOBAIN ABRASIFS                        https://www.saint-gobain-abrasives.com/en-us/pr...    0.0
# Ormat Technologies Inc.                      https://www.ormat.com/en/company/general/view/?...    0.0
# Lintec Corporation                           http://www.lintec-global.com/about/message/           0.0
#                                              http://www.lintec-global.com/about/history/           0.0
# Angaza Design                                https://www.angaza.com/about/                         0.0
# Lintec Corporation                           http://www.lintec-global.com/ir/management/           0.0
#                                              http://www.lintec-global.com/about/brochure/book/     0.0
# Kulite Semiconductor Products                https://www.kulite.com/company/news/                  0.0
# Lintec Corporation                           http://www.lintec-global.com/about/country/amer...    0.0
#                                              http://www.lintec-global.com/about/network/           0.0
# Kulite Semiconductor Products                https://www.kulite.com/company/contact-info/          0.0
#                                              https://www.kulite.com/company/customer-resources/    0.0
#                                              https://www.kulite.com/company/corporate-respon...    0.0
#                                              https://www.kulite.com/company/supplier-code-of...    0.0
# Bend Research                                https://www.capsugel.com/about-capsugel               0.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news                      0.0
#                                              http://pidc.com/our-company/locations                 0.0
# Valicor                                      http://trucent.com/                                   0.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news/pacific-indust...    0.0
# SOLAZYME                                     http://solazyme.com/                                  0.0
# Starlight Energy Holdings LLC                http://www.starlightenergy.us/                        0.0
# Solight Solar                                http://www.solight.com/                               0.0
# ZON                                          https://www.zon.si/                                   0.0
# Ostendo Technologies                         https://www.ostendo.com/                              0.0
# Quantapore                                   https://quantapore.com/                               0.0
# Synaptic Research                            https://research.synaptic.co.uk/SynapticResearc...    0.0
# Sun Drilling Products Corporation            https://www.sunspecialtyproducts.com/                 0.0
# MEDport                                      https://medport.com/                                  0.0
#
#                                                                                                  2016  \
# firm_name                                    url
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/plan/     0.0
# 22nd Century Limited                         http://www.xxiicentury.com/history/                  0.0
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/global/   0.0
#                                              https://www.mitsubishicorp.com/jp/en/about/mess...   0.0
# Forest Concepts                              http://forestconcepts.com/index.php?page=01002       0.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/program-management/     0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/corporate_data....   0.0
# W&Wsens Devices                              https://www.wwsensdevices.com/                       0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/brand.html           0.0
#                                              https://www.kansai.com/about-us/                     0.0
# Xintec Inc.                                  http://www.xintec.com.tw/eng/CSR_Corporate_Gove...   0.0
# k-Space Associates                           https://www.k-space.com/company/distributors/        0.0
# Amkor Technology                             https://amkor.com/company-history/                   0.0
#                                              https://amkor.com/technology/system-in-package/      0.0
# Wine.com                                     https://www.wine.com/content/landing/corporate-...   0.0
# Industrial Technology Research Institute     https://www.itri.org.tw/eng/Content/Management/...   0.0
# Vizio Inc.                                   https://www.vizio.com/about                          0.0
# Midrex Technologies                          https://midrex.com/company-info/history              0.0
# VMware                                       https://www.vmware.com/company/leadership.html       0.0
#                                              https://www.vmware.com/company/innovation.html       0.0
# VEECO PRECISION SURFACE PROCESSING LLC       http://www.veeco.com/company                         0.0
# ABB AB                                       https://new.abb.com/network-management               0.0
# VMware                                       https://www.vmware.com/company/foundation.html       0.0
# ABB AB                                       https://new.abb.com/about                            0.0
#                                              https://new.abb.com/cpm                              0.0
# DuPont Teijin Films U.S. Limited Partnership https://usa.dupontteijinfilms.com/about/             0.0
# Vaxiion Therapeutics                         http://www.vaxiion.com/executive-management.html     0.0
#                                              http://www.vaxiion.com/the-company.html              0.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/                        0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/history.html         0.0
# ...                                                                                               ...
# Ormat Technologies Inc.                      https://www.ormat.com/en/company/general/view/?...   0.0
# Gram Power                                   https://grampower.com/about-us/our-team.html         0.0
# SAINT-GOBAIN ABRASIFS                        https://www.saint-gobain-abrasives.com/en-us/pr...   0.0
# Ormat Technologies Inc.                      https://www.ormat.com/en/company/general/view/?...   0.0
# Lintec Corporation                           http://www.lintec-global.com/about/message/          0.0
#                                              http://www.lintec-global.com/about/history/          0.0
# Angaza Design                                https://www.angaza.com/about/                        0.0
# Lintec Corporation                           http://www.lintec-global.com/ir/management/          0.0
#                                              http://www.lintec-global.com/about/brochure/book/    0.0
# Kulite Semiconductor Products                https://www.kulite.com/company/news/                 0.0
# Lintec Corporation                           http://www.lintec-global.com/about/country/amer...   0.0
#                                              http://www.lintec-global.com/about/network/          0.0
# Kulite Semiconductor Products                https://www.kulite.com/company/contact-info/         0.0
#                                              https://www.kulite.com/company/customer-resources/   0.0
#                                              https://www.kulite.com/company/corporate-respon...   0.0
#                                              https://www.kulite.com/company/supplier-code-of...   0.0
# Bend Research                                https://www.capsugel.com/about-capsugel              0.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news                     0.0
#                                              http://pidc.com/our-company/locations                0.0
# Valicor                                      http://trucent.com/                                  0.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news/pacific-indust...   0.0
# SOLAZYME                                     http://solazyme.com/                                 0.0
# Starlight Energy Holdings LLC                http://www.starlightenergy.us/                       0.0
# Solight Solar                                http://www.solight.com/                              0.0
# ZON                                          https://www.zon.si/                                  0.0
# Ostendo Technologies                         https://www.ostendo.com/                             0.0
# Quantapore                                   https://quantapore.com/                              0.0
# Synaptic Research                            https://research.synaptic.co.uk/SynapticResearc...   0.0
# Sun Drilling Products Corporation            https://www.sunspecialtyproducts.com/                0.0
# MEDport                                      https://medport.com/                                 0.0
#
#                                                                                                  2020  \
# firm_name                                    url
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/plan/     0.0
# 22nd Century Limited                         http://www.xxiicentury.com/history/                  0.0
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/global/   0.0
#                                              https://www.mitsubishicorp.com/jp/en/about/mess...   0.0
# Forest Concepts                              http://forestconcepts.com/index.php?page=01002       0.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/program-management/     0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/corporate_data....   0.0
# W&Wsens Devices                              https://www.wwsensdevices.com/                       0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/brand.html           0.0
#                                              https://www.kansai.com/about-us/                     0.0
# Xintec Inc.                                  http://www.xintec.com.tw/eng/CSR_Corporate_Gove...   0.0
# ...
#                                              https://www.kulite.com/company/supplier-code-of...   0.0
# Bend Research                                https://www.capsugel.com/about-capsugel              0.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news                     0.0
#                                              http://pidc.com/our-company/locations                0.0
# Valicor                                      http://trucent.com/                                  0.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news/pacific-indust...   0.0
# SOLAZYME                                     http://solazyme.com/                                 0.0
# Starlight Energy Holdings LLC                http://www.starlightenergy.us/                       0.0
# Solight Solar                                http://www.solight.com/                              0.0
# ZON                                          https://www.zon.si/                                  0.0
# Ostendo Technologies                         https://www.ostendo.com/                             0.0
# Quantapore                                   https://quantapore.com/                              0.0
# Synaptic Research                            https://research.synaptic.co.uk/SynapticResearc...   0.0
# Sun Drilling Products Corporation            https://www.sunspecialtyproducts.com/                0.0
# MEDport                                      https://medport.com/                                 0.0
#
#                                                                                                  pages_in_domain  \
# firm_name                                    url
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/plan/               11.0
# 22nd Century Limited                         http://www.xxiicentury.com/history/                             4.0
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/global/             11.0
#                                              https://www.mitsubishicorp.com/jp/en/about/mess...             11.0
# Forest Concepts                              http://forestconcepts.com/index.php?page=01002                  4.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/program-management/                3.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/corporate_data....              6.0
# W&Wsens Devices                              https://www.wwsensdevices.com/                                  1.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/brand.html                      6.0
#                                              https://www.kansai.com/about-us/                                6.0
# Xintec Inc.                                  http://www.xintec.com.tw/eng/CSR_Corporate_Gove...              6.0
# k-Space Associates                           https://www.k-space.com/company/distributors/                   9.0
# Amkor Technology                             https://amkor.com/company-history/                              4.0
#                                              https://amkor.com/technology/system-in-package/                 4.0
# Wine.com                                     https://www.wine.com/content/landing/corporate-...              3.0
# Industrial Technology Research Institute     https://www.itri.org.tw/eng/Content/Management/...              2.0
# Vizio Inc.                                   https://www.vizio.com/about                                     1.0
# Midrex Technologies                          https://midrex.com/company-info/history                         8.0
# VMware                                       https://www.vmware.com/company/leadership.html                 11.0
#                                              https://www.vmware.com/company/innovation.html                 11.0
# VEECO PRECISION SURFACE PROCESSING LLC       http://www.veeco.com/company                                    7.0
# ABB AB                                       https://new.abb.com/network-management                         11.0
# VMware                                       https://www.vmware.com/company/foundation.html                 11.0
# ABB AB                                       https://new.abb.com/about                                      11.0
#                                              https://new.abb.com/cpm                                        11.0
# DuPont Teijin Films U.S. Limited Partnership https://usa.dupontteijinfilms.com/about/                        5.0
# Vaxiion Therapeutics                         http://www.vaxiion.com/executive-management.html                2.0
#                                              http://www.vaxiion.com/the-company.html                         2.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/                                   3.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/history.html                    6.0
# ...                                                                                                          ...
# Ormat Technologies Inc.                      https://www.ormat.com/en/company/general/view/?...             22.0
# Gram Power                                   https://grampower.com/about-us/our-team.html                    6.0
# SAINT-GOBAIN ABRASIFS                        https://www.saint-gobain-abrasives.com/en-us/pr...             12.0
# Ormat Technologies Inc.                      https://www.ormat.com/en/company/general/view/?...             22.0
# Lintec Corporation                           http://www.lintec-global.com/about/message/                    22.0
#                                              http://www.lintec-global.com/about/history/                    22.0
# Angaza Design                                https://www.angaza.com/about/                                   2.0
# Lintec Corporation                           http://www.lintec-global.com/ir/management/                    22.0
#                                              http://www.lintec-global.com/about/brochure/book/              22.0
# Kulite Semiconductor Products                https://www.kulite.com/company/news/                           20.0
# Lintec Corporation                           http://www.lintec-global.com/about/country/amer...             22.0
#                                              http://www.lintec-global.com/about/network/                    22.0
# Kulite Semiconductor Products                https://www.kulite.com/company/contact-info/                   20.0
#                                              https://www.kulite.com/company/customer-resources/             20.0
#                                              https://www.kulite.com/company/corporate-respon...             20.0
#                                              https://www.kulite.com/company/supplier-code-of...             20.0
# Bend Research                                https://www.capsugel.com/about-capsugel                         4.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news                               16.0
#                                              http://pidc.com/our-company/locations                          16.0
# Valicor                                      http://trucent.com/                                             2.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news/pacific-indust...             16.0
# SOLAZYME                                     http://solazyme.com/                                            2.0
# Starlight Energy Holdings LLC                http://www.starlightenergy.us/                                  2.0
# Solight Solar                                http://www.solight.com/                                         2.0
# ZON                                          https://www.zon.si/                                             2.0
# Ostendo Technologies                         https://www.ostendo.com/                                        2.0
# Quantapore                                   https://quantapore.com/                                         1.0
# Synaptic Research                            https://research.synaptic.co.uk/SynapticResearc...              2.0
# Sun Drilling Products Corporation            https://www.sunspecialtyproducts.com/                           2.0
# MEDport                                      https://medport.com/                                            2.0
#
#                                                                                                  is_sole_page
# firm_name                                    url
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/plan/             0.0
# 22nd Century Limited                         http://www.xxiicentury.com/history/                          0.0
# Mitsubishi Metal Corporation                 https://www.mitsubishicorp.com/jp/en/about/global/           0.0
#                                              https://www.mitsubishicorp.com/jp/en/about/mess...           0.0
# Forest Concepts                              http://forestconcepts.com/index.php?page=01002               0.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/program-management/             0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/corporate_data....           0.0
# W&Wsens Devices                              https://www.wwsensdevices.com/                               1.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/brand.html                   0.0
#                                              https://www.kansai.com/about-us/                             0.0
# Xintec Inc.                                  http://www.xintec.com.tw/eng/CSR_Corporate_Gove...           0.0
# k-Space Associates                           https://www.k-space.com/company/distributors/                0.0
# Amkor Technology                             https://amkor.com/company-history/                           0.0
#                                              https://amkor.com/technology/system-in-package/              0.0
# Wine.com                                     https://www.wine.com/content/landing/corporate-...           0.0
# Industrial Technology Research Institute     https://www.itri.org.tw/eng/Content/Management/...           0.0
# Vizio Inc.                                   https://www.vizio.com/about                                  1.0
# Midrex Technologies                          https://midrex.com/company-info/history                      0.0
# VMware                                       https://www.vmware.com/company/leadership.html               0.0
#                                              https://www.vmware.com/company/innovation.html               0.0
# VEECO PRECISION SURFACE PROCESSING LLC       http://www.veeco.com/company                                 0.0
# ABB AB                                       https://new.abb.com/network-management                       0.0
# VMware                                       https://www.vmware.com/company/foundation.html               0.0
# ABB AB                                       https://new.abb.com/about                                    0.0
#                                              https://new.abb.com/cpm                                      0.0
# DuPont Teijin Films U.S. Limited Partnership https://usa.dupontteijinfilms.com/about/                     0.0
# Vaxiion Therapeutics                         http://www.vaxiion.com/executive-management.html             0.0
#                                              http://www.vaxiion.com/the-company.html                      0.0
# ZENA TECHNOLOGIES                            http://xena-technologies.com/                                0.0
# Kansai Paint Co.                             https://www.kansai.com/about-us/history.html                 0.0
# ...                                                                                                       ...
# Ormat Technologies Inc.                      https://www.ormat.com/en/company/general/view/?...           0.0
# Gram Power                                   https://grampower.com/about-us/our-team.html                 0.0
# SAINT-GOBAIN ABRASIFS                        https://www.saint-gobain-abrasives.com/en-us/pr...           0.0
# Ormat Technologies Inc.                      https://www.ormat.com/en/company/general/view/?...           0.0
# Lintec Corporation                           http://www.lintec-global.com/about/message/                  0.0
#                                              http://www.lintec-global.com/about/history/                  0.0
# Angaza Design                                https://www.angaza.com/about/                                0.0
# Lintec Corporation                           http://www.lintec-global.com/ir/management/                  0.0
#                                              http://www.lintec-global.com/about/brochure/book/            0.0
# Kulite Semiconductor Products                https://www.kulite.com/company/news/                         0.0
# Lintec Corporation                           http://www.lintec-global.com/about/country/amer...           0.0
#                                              http://www.lintec-global.com/about/network/                  0.0
# Kulite Semiconductor Products                https://www.kulite.com/company/contact-info/                 0.0
#                                              https://www.kulite.com/company/customer-resources/           0.0
#                                              https://www.kulite.com/company/corporate-respon...           0.0
#                                              https://www.kulite.com/company/supplier-code-of...           0.0
# Bend Research                                https://www.capsugel.com/about-capsugel                      0.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news                             0.0
#                                              http://pidc.com/our-company/locations                        0.0
# Valicor                                      http://trucent.com/                                          0.0
# Pacific Industrial Development Corporation   http://pidc.com/our-company/news/pacific-indust...           0.0
# SOLAZYME                                     http://solazyme.com/                                         0.0
# Starlight Energy Holdings LLC                http://www.starlightenergy.us/                               0.0
# Solight Solar                                http://www.solight.com/                                      0.0
# ZON                                          https://www.zon.si/                                          0.0
# Ostendo Technologies                         https://www.ostendo.com/                                     0.0
# Quantapore                                   https://quantapore.com/                                      1.0
# Synaptic Research                            https://research.synaptic.co.uk/SynapticResearc...           0.0
# Sun Drilling Products Corporation            https://www.sunspecialtyproducts.com/                        0.0
# MEDport                                      https://medport.com/                                         0.0
#
# [4516 rows x 1473 columns]

# %%
# predict with newly constructed X
y_predicted = clf.predict(X_test)

# %%
# standard firm cleaning regex
def clean_firm_name (firm):
    firm_clnd = re.sub('(\.|,| corporation| incorporated| llc| inc| international| gmbh| ltd)', '', firm, flags=re.IGNORECASE).rstrip()
    return firm_clnd

# write to file
with open(ABOUT_DIR + 'about_predicted_and_labels.csv', mode='w') as about_file:
    about_writer = csv.writer(about_file, delimiter=',', quotechar='"')
    about_writer.writerow(['firm_name', 'url', 'is_about'])
    # output predicted values to file
    for fn, u, predicted_value in zip(X_test.index.get_level_values('firm_name'), X_test.index.get_level_values('url'), y_predicted):
        # print (fn + ' with url ' + u + ' has predicted value ' + str(predicted_value))
        about_writer.writerow([clean_firm_name(fn), u, predicted_value])
    # and the labeled ones too...
    for fn, u, labeled_value in zip(X.index.get_level_values('firm_name'), X.index.get_level_values('url'), y):
        # print (fn + ' with url ' + u + ' has predicted value ' + str(labeled_value))
        about_writer.writerow([clean_firm_name(fn), u, labeled_value])

# %% [markdown]
# ## Extract data from mongodb
# * Now that we know which pages are about pages, extract from mongodb and output for topic modeling
# * For now, construct paragraphs from different pages by ordering urls by their length.  In the future, might want to contruct paragraphs in their 'natural' sequential order as they would appear on a home page or landing page

# %%
# combine both labeled and predicted frames
print (X_test.shape)
print(X.shape)

combined = X_test.append(X)
print (combined.shape)
print (len(y_predicted))
print (len(y))
abouts = pd.DataFrame(index=combined.index)

abouts['is_about'] = list(y_predicted) + list(y)
abouts = abouts.reset_index()
abouts
# Out:
# (4516, 1473)
# (1031, 1473)
# (5547, 1473)
# 4516
# 1031
#                                           firm_name  \
# 0                      Mitsubishi Metal Corporation
# 1                              22nd Century Limited
# 2                      Mitsubishi Metal Corporation
# 3                      Mitsubishi Metal Corporation
# 4                                   Forest Concepts
# 5                                 ZENA TECHNOLOGIES
# 6                                  Kansai Paint Co.
# 7                                   W&Wsens Devices
# 8                                  Kansai Paint Co.
# 9                                  Kansai Paint Co.
# 10                                      Xintec Inc.
# 11                               k-Space Associates
# 12                                 Amkor Technology
# 13                                 Amkor Technology
# 14                                         Wine.com
# 15         Industrial Technology Research Institute
# 16                                       Vizio Inc.
# 17                              Midrex Technologies
# 18                                           VMware
# 19                                           VMware
# 20           VEECO PRECISION SURFACE PROCESSING LLC
# 21                                           ABB AB
# 22                                           VMware
# 23                                           ABB AB
# 24                                           ABB AB
# 25     DuPont Teijin Films U.S. Limited Partnership
# 26                             Vaxiion Therapeutics
# 27                             Vaxiion Therapeutics
# 28                                ZENA TECHNOLOGIES
# 29                                 Kansai Paint Co.
# ...                                             ...
# 5517                                  Unifrax I LLC
# 5518                                  Unifrax I LLC
# 5519                                  Unifrax I LLC
# 5520                VINDICO NANOBIO TECHNOLOGY INC.
# 5521                VINDICO NANOBIO TECHNOLOGY INC.
# 5522                                Verliant Energy
# 5523  Wave Energy Conversion Corporation of America
# 5524                         Zeno Semiconductor Inc
# 5525                            Zoetis Services LLC
# 5526                            Zoetis Services LLC
# 5527                            Zoetis Services LLC
# 5528                            Zoetis Services LLC
# 5529                            Zoetis Services LLC
# 5530                            Zoetis Services LLC
# 5531                            Zoetis Services LLC
# 5532                            Zoetis Services LLC
# 5533                            Zoetis Services LLC
# 5534                            Zoetis Services LLC
# 5535                            Zoetis Services LLC
# 5536                               Zygo Corporation
# 5537                               Zygo Corporation
# 5538                               Zygo Corporation
# 5539                               Zygo Corporation
# 5540                               Zygo Corporation
# 5541                               Zygo Corporation
# 5542                                           fybr
# 5543                                   iNanoBio LLC
# 5544                                   iNanoBio LLC
# 5545                                   nanoComposix
# 5546                                   nanoComposix
#
#                                                     url  is_about
# 0      https://www.mitsubishicorp.com/jp/en/about/plan/       0.0
# 1                   http://www.xxiicentury.com/history/       1.0
# 2     https://www.mitsubishicorp.com/jp/en/about/glo...       1.0
# 3     https://www.mitsubishicorp.com/jp/en/about/mes...       0.0
# 4        http://forestconcepts.com/index.php?page=01002       0.0
# 5      http://xena-technologies.com/program-management/       0.0
# 6     https://www.kansai.com/about-us/corporate_data...       1.0
# 7                        https://www.wwsensdevices.com/       1.0
# 8            https://www.kansai.com/about-us/brand.html       1.0
# 9                      https://www.kansai.com/about-us/       1.0
# 10    http://www.xintec.com.tw/eng/CSR_Corporate_Gov...       0.0
# 11        https://www.k-space.com/company/distributors/       0.0
# 12                   https://amkor.com/company-history/       1.0
# 13      https://amkor.com/technology/system-in-package/       0.0
# 14    https://www.wine.com/content/landing/corporate...       0.0
# 15    https://www.itri.org.tw/eng/Content/Management...       0.0
# 16                          https://www.vizio.com/about       1.0
# 17              https://midrex.com/company-info/history       1.0
# 18       https://www.vmware.com/company/leadership.html       0.0
# 19       https://www.vmware.com/company/innovation.html       0.0
# 20                         http://www.veeco.com/company       1.0
# 21               https://new.abb.com/network-management       0.0
# 22       https://www.vmware.com/company/foundation.html       0.0
# 23                            https://new.abb.com/about       1.0
# 24                              https://new.abb.com/cpm       0.0
# 25             https://usa.dupontteijinfilms.com/about/       1.0
# 26     http://www.vaxiion.com/executive-management.html       0.0
# 27              http://www.vaxiion.com/the-company.html       1.0
# 28                        http://xena-technologies.com/       0.0
# 29         https://www.kansai.com/about-us/history.html       1.0
# ...                                                 ...       ...
# 5517  http://www.unifrax.com/about-us/luyang-partner...       0.0
# 5518                   http://www.unifrax.com/about-us/       1.0
# 5519  http://www.unifrax.com/about-us/career-opportu...       0.0
# 5520  http://vindicoat.com/joomla1/index.php/meet-th...       0.0
# 5521  http://vindicoat.com/joomla1/index.php/meet-th...       0.0
# 5522                     http://www.verliantenergy.com/       1.0
# 5523                     https://weccamerica.com/about/       1.0
# 5524                           https://www.zenosemi.com       1.0
# 5525         https://www.zoetis.com/about-us/index.aspx       1.0
# 5526  https://www.zoetis.com/about-us/vision-mission...       1.0
# 5527       https://www.zoetis.com/about-us/history.aspx       1.0
# 5528  https://www.zoetis.com/about-us/executive-team...       0.0
# 5529  https://www.zoetis.com/about-us/zoetis-at-a-gl...       1.0
# 5530       https://www.zoetis.com/?eventName=LOGGED_OUT       0.0
# 5531  https://www.zoetis.com/about-us/core-beliefs.aspx       1.0
# 5532     https://www.zoetis.com/about-us/our-story.aspx       1.0
# 5533  https://www.zoetis.com/about-us/awards/index.aspx       1.0
# 5534  https://www.zoetis.com/about-us/company-locati...       0.0
# 5535  https://www.zoetis.com/about-us/corporate-gove...       0.0
# 5536              https://www.zygo.com/?/aboutus/shows/       0.0
# 5537  https://www.zygo.com/?/met/profilers/zegagepro...       0.0
# 5538  https://www.zygo.com/?/blog/facts-and-statisti...       0.0
# 5539  https://www.zygo.com/?/aboutus/privacy-cookie-...       0.0
# 5540              https://www.zygo.com/?/met/profilers/       0.0
# 5541   https://www.zygo.com/?/aboutus/news/20181017.htm       0.0
# 5542                         https://fybr.com/about-us/       1.0
# 5543                       http://inanobio.com/team.php       0.0
# 5544                    http://inanobio.com/aboutus.php       1.0
# 5545            https://nanocomposix.com/pages/about-us       1.0
# 5546                https://nanocomposix.com/pages/team       0.0
#
# [5547 rows x 3 columns]

# %%
# gather unique firm_names from mongodb
firm_names = set(abouts['firm_name'])
print (len(firm_names))
pp = pprint.PrettyPrinter()
pp.pprint(firm_names)
# Out:
# 1050
# {'22nd Century Limited',
#  '3M Innovative Properties Company',
#  'ABB AB',
#  'AC International Inc.',
#  'ACACIA RESEARCH GROUP LLC',
#  'ACUCELA INC.',
#  'ACell',
#  'ADASA INC.',
#  'ADVANCED INNOVATION CENTER LLC',
#  'AFMODEL',
#  'AGC Flat Glass North America',
#  'AGFA-GEVAERT N.V.',
#  'ALGETERNAL TECHNOLOGIES',
#  'ALSTOM Technology Ltd',
#  'AMPT',
#  'APPLIED STEMCELL',
#  'ARBOR THERAPEUTICS',
#  'ASCENT SOLAR TECHNOLOGIES',
#  'ASM America',
#  'ASML Netherlands B.V.',
#  'ASTUTE MEDICAL',
#  'AT&T Corporation',
#  'ATC Technologies',
#  'ATOMERA INCORPORATED',
#  'ATTOSTAT',
#  'AVI BioPharma',
#  'AVOGY',
#  'AbbVie Inc.',
#  'Abbott Molecular Inc.',
#  'Abbott Point of Care Inc.',
#  'Abengoa Bioenergy New Technologies',
#  'Ablexis',
#  'Access Business Group International LLC',
#  'AccuRay Corporation',
#  'Acorn Technologies',
#  'Adaptive Biotechnologies Corp.',
#  'Adeka Corporation',
#  'Adhesives Research',
#  'Adlens Beacon',
#  'Adobe Systems Incorporated',
#  'Adtran',
#  'Advanced Analogic Technologies',
#  'Advanced Aqua Group',
#  'Advanced Silicon Group',
#  'Adynxx',
#  'Aerogen',
#  'Agena Bioscience',
#  'Agienic',
#  'Agilent Technologies',
#  'Agrivida',
#  'AgroFresh Inc.',
#  'Ajinomoto Althea',
#  'Alcatel Lucent',
#  'Alcon Research',
#  'Alcotek',
#  'Alexion Pharmaceuticals',
#  'Algenol Biotech LLC',
#  'All Power Labs',
#  'Allertein Therapeutics',
#  'Alliance for Sustainable Energy',
#  'Allison Transmission',
#  'Alnylam Pharmaceuticals',
#  'Alpha and Omega Semiconductor Incorporated',
#  'AltaRock Energy',
#  'Altex Technologies Corporation',
#  'Altivera',
#  'Ambature',
#  'Amberwave Inc.',
#  'American Air Liquide',
#  'American Piledriving Equipment',
#  'Amgen Fremont Inc.',
#  'Amicus Therapeutics',
#  'Amkor Technology',
#  'Ampio Pharmaceuticals',
#  'Amtech Systems',
#  'Analog Devices',
#  'Andritz Inc.',
#  'Anelva Corporation',
#  'Angaza Design',
#  'Angiotech Pharmaceuticals (US)',
#  'Angstron Materials',
#  'Ansun Biopharma',
#  'Antaya Technologies Corporation',
#  'Apple Inc.',
#  'Applied Genetic Technologies Corporation',
#  'Applied Materials',
#  'Applied Membrane Technologies',
#  'Applied Nanostructures',
#  'Applied Optoelectronics',
#  'Archer Daniels Midland Company',
#  'Arcturus Therapeutics',
#  'Areesys Technologies',
#  'Arkema Inc.',
#  'Armageddon Energy Inc.',
#  'Arpin Renewable Energy',
#  'Arrowhead Center',
#  'Astech',
#  'AstenJohnson',
#  'Atleisure LLC',
#  'Atom Nanoelectronics',
#  'Atonometrics',
#  'Atrium Medical Corporation',
#  'Aurrion',
#  'Aushon Biosystems',
#  'Auterra',
#  'Authenex',
#  'Autonomic Materials',
#  'Avalanche Technology',
#  'Avantor Performance Materials',
#  'Avery Dennison Corporation',
#  'Avon Products',
#  'Avtaec Limited',
#  'B.G. Negev Technologies and Applications Ltd.',
#  'BAE Systems Information and Electronic Systems Integration Inc.',
#  'BASF',
#  'BASF Coatings GmbH',
#  'BAXALTA INCORPORATED',
#  'BP Corporation North America Inc.',
#  'BRIGHTLEAF TECHNOLOGIES INC.',
#  'BROADCOM CORPORATION',
#  'BTU International',
#  'Babcock Power Services',
#  'Baker Hughes Incorporated',
#  'Banpil Photonics',
#  'Basell Polyolefine GmbH',
#  'Battelle Memorial Institute',
#  'Bausch & Lomb Incorporated',
#  'Baxter Healthcare SA',
#  'Bayer Cropscience AG',
#  'Bayer Materialscience LLC',
#  'Bell Helicopter Textron Inc.',
#  'Bemis Company',
#  'Bend Research',
#  'Bestway',
#  'Bi-Modal Corporation',
#  'Big Belly Solar',
#  'Bigelow Aerospace',
#  'Bio-Rad Laboratories',
#  'BioNano Genomics',
#  'Biocare Medical',
#  'Biocon Limited',
#  'Biological Dynamics',
#  'Bioneer Corporation',
#  'Biosense Webster (Israel) Ltd.',
#  'Biosphere Medical',
#  'Biotechnology Foundation',
#  'Biotta LLC',
#  'Bird-B-Gone',
#  'Bisco',
#  'Bitrode Corporation',
#  'BlackBerry Limited',
#  'Blue Sea Systems',
#  'Bluestar Silicones France',
#  'Boehringer Ingelheim International GmbH',
#  'Boehringer Ingelheim Vetmedica GmbH',
#  'Bostik',
#  'Boston Scientific Scimed',
#  'Braun Intertec Geothermal',
#  'Brewer Science Inc.',
#  'Bridgelux',
#  'Bridgestone Corporation',
#  'Brightfield Transportation Solutions',
#  'Bristol-Myers Squibb Company',
#  'Brookhaven Science Associates LLC ',
#  'Bruin Biometrics',
#  'Buckman Laboratories International',
#  'Butamax(TM) Advanced Biofuels LLC',
#  'CAMBRIDGE ENTERPRISE LIMITED',
#  'CARBO Ceramics Inc.',
#  'CELLTRION',
#  'CERION LLC',
#  'CI4 Technologies',
#  'CLEARSIGN COMBUSTION CORPORATION',
#  'CMC ICOS BIOLOGICS',
#  'CNH Industrial America LLC',
#  'COOK MEDICAL TECHNOLOGIES LLC',
#  'COVERIS FLEXIBLES US LLC',
#  'CP KELCO APS',
#  "CSEM Centre Suisse d'Electronique et de Microtechnique SA-Recherche et "
#  'Developpement',
#  'CUMMINS FILTRATION IP',
#  'Cabot Corporation',
#  'Cadence Design Systems',
#  'Calient Technologies',
#  'Calysta',
#  'Canon',
#  'Canon Kabushiki Kaisha',
#  'Canon Nanotechnologies',
#  'Canon U.S. Life Sciences',
#  'Carbon3D',
#  'Cardiva Medical',
#  'Carestream Health',
#  'Caribou Biosciences',
#  'Carl Zeiss Meditec AG',
#  'Carver Scientific',
#  'Casio Computer Co.',
#  'Cbrite Inc.',
#  'Cedar Ridge Research',
#  'Celanese Corporation',
#  'CellPrint IP Holding',
#  'Cellular Research',
#  'Ceramatec',
#  'Cetac Technologies Inc.',
#  'Chemtreat',
#  'Chevron Oronitz Company LLC',
#  'Chevron Phillips Chemical Company LP',
#  'Chevron U.S.A. Inc.',
#  'Chipmos Technologies Inc.',
#  'Christie Digital Systems',
#  'Chromalox',
#  'Cisco Technology',
#  'Claret Medical',
#  'Cleanvantage LLC',
#  'Clearside Biomedical',
#  'Coactive Drive Corporation',
#  'Codexis',
#  'Coleman Cable',
#  'Colgate-Palmolive Company',
#  'Coloplast A/S',
#  'Columbia Insurance Company',
#  'Combined Energies',
#  'Commonwealth Scientific & Industrial Research Organization',
#  'Community Power Corporation',
#  'Complete Genomics',
#  'Conexant Systems',
#  'Confluence Energy',
#  'Conoco Inc.',
#  'ConocoPhillips Company',
#  'Conversant Intellectual Property Management Inc.',
#  'Cook Biotech Incorporated',
#  'Cool Planet Energy Systems',
#  'CoolEarth Solar',
#  'Coriant Advanced Technology',
#  'Cornell Research Foundation',
#  'Corporation for National Research Initiatives',
#  'Cree',
#  'Cristal USA Inc.',
#  'Cross Match Technologies',
#  'Crossbar',
#  'Crystal Solar Inc.',
#  'Cura Vac',
#  'Custom Electronics Inc.',
#  'Cyberonics',
#  'CyboEnergy',
#  'DECA Technologies Inc.',
#  'DEKA Products Limited Partnership',
#  'DHPC TECHNOLOGIES',
#  'DIC Corporation',
#  'DISCOVERYBIOMED INC.',
#  'DNA Twopointo',
#  'DRS Network & Imaging Systems',
#  'DSP Group LTD.',
#  'Da Yu Enterprises',
#  'Daikin Industries',
#  'Dana Corporation',
#  'Dana-Farber Cancer Institute',
#  'Danisco US Inc.',
#  'Daylight Solutions',
#  'DePuy Synthes Products',
#  'Delavau LLC',
#  'Dell Software Inc.',
#  'Delphi Technologies',
#  'Delta Electronics',
#  'Denso Corporation',
#  'Deployable Space Systems',
#  'Dermazone Solutions',
#  'Dexerials Corporation',
#  'Dialight Corporation',
#  'Dialogic Corporation',
#  'Diamond Innovations',
#  'DiscoveRx Corporation',
#  'Disney Enterprises',
#  'Dolby Laboratories Licensing Corporation',
#  'Domtar Paper Company',
#  "Dr. Reddy's Laboratories Ltd.",
#  'Dresser-Rand Company',
#  'DuPont Teijin Films U.S. Limited Partnership',
#  'E Ink Corporation',
#  'E. Tech Incorporation',
#  'ECOSYNTHETIX LTD.',
#  'EMC Corporation',
#  'EMD Technologies Inc.',
#  'ENI S.p.A.',
#  'ESCAPE THERAPEUTICS',
#  'EXOS LLC',
#  'Easel Biotechnologies',
#  'Eastman Chemical Company',
#  'Eastman Kodak Company',
#  'Eaton Corporation',
#  'EchoStar Technologies LLC',
#  'Echogen Power Systems',
#  'Ecolab Inc.',
#  'Ecovative Design',
#  'Egenera',
#  'Eisai Co.',
#  'ElectraTherm',
#  'Electrix',
#  'Electrovaya Inc.',
#  'Element One',
#  'Elenion Technologies',
#  'Elwha LLC',
#  'Em-Tech LLC',
#  'Energysolutions',
#  'Englewood Lab',
#  'Ensyn Renewables',
#  'Entech Solar',
#  'Entegris',
#  'Envision Solar International',
#  'Envisionit LLC',
#  'Epizyme',
#  'Esolar',
#  'Ethicon Endo-Surgery',
#  'Evernote Corporation',
#  'Everspin Technologies',
#  'Evoqua Water Technologies LLC',
#  'Evri',
#  'ExxonMobil Chemical Patents Inc.',
#  'ExxonMobil Upstream Research Company',
#  'FEI Company',
#  'FLIR Systems',
#  'FLOW CONTROL LLC.',
#  'FPInnovations',
#  'FRONT EDGE TECHNOLOGY INC.',
#  'FUJIFILM Corporation',
#  'FUJIFILM Dimatix',
#  'FULL CIRCLE BIOCHAR',
#  'Fairchild Semiconductor Corporation',
#  'FastCAP Systems Corporation',
#  'Faurecia Interior Systems',
#  'Federal Signal Corporation',
#  'Ferro Corporation',
#  'Fianium Ltd.',
#  'Finisar Corporation',
#  'First Solar',
#  'Flextronics AP',
#  'Floadia Corporation',
#  'Fluidigm Corporation',
#  'Ford Global Technologies',
#  'Forest Concepts',
#  'Foret Plasma Labs',
#  'Formula Plastics',
#  'Freescale Semiconductor',
#  'Fuji Electric Co.',
#  'Fuji Xerox Co.',
#  'Fujitsu Limited',
#  'Furukawa Electric Co.',
#  'FutureWei Technologies',
#  'GCP Applied Technologies Inc.',
#  'GE Healthcare Dharmacon',
#  'GE-Hitachi Nuclear Energy Americas LLC',
#  'GED Intergrated Solution',
#  'GEN-PROBE INCORPORATED',
#  'GENCO SCIENCES LLC',
#  'GENERAL MOTORS LLC',
#  'GLIKNIK INC.',
#  'GLYCON LLC',
#  'GOAL ZERO LLC',
#  'GOJO Industries',
#  'GOLBA LLC',
#  'GOSOLARLIFE',
#  'GROW ENERGY',
#  'Galectin Therapeutics',
#  'GangaGen',
#  'Gardner-Gibson',
#  'Gas Technology Institute',
#  'Gemex Systems',
#  'Genentech',
#  'Genisphere',
#  'Genomatica',
#  'Genomic Health',
#  'Genzyme Corporation',
#  'Gestion Ultra International Inc.',
#  'Gilead Connecticut',
#  'Gilead Sciences',
#  'GlassPoint Solar',
#  'GlaxoSmithKline Biologicals',
#  'Global Eagle Entertainment Inc.',
#  'Global OLED Technology LLC',
#  'Global Solar Water Power Systems',
#  'Globus Medical',
#  'Glucan Biorenewables LLC',
#  'Gracenote',
#  'Grain Processing Corporation',
#  'Gram Power',
#  'Grandis Inc.',
#  'Graphene Technologies',
#  'Greatbatch Ltd.',
#  'Green Box Batteries',
#  'Green Extraction Technologies',
#  'Green Solar Transportation',
#  'Greyrock Energy',
#  'Gtech Corporation',
#  'Guardian Industries',
#  'H R D CORPORATION',
#  'HAMAMATSU PHOTONICS K.K.',
#  'HARMAN INTERNATIONAL INDUSTRIES',
#  'HGST NETHERLANDS B.V.',
#  'HIQ SOLAR',
#  'HM3 Energy',
#  'HNO Greenfuels',
#  'HOWARD INDUSTRIES',
#  'HRL Laboratories',
#  'HTC Corporation',
#  'HTS',
#  'Halliburton Energy Services',
#  'Hamilton Sundstrand Corporation',
#  'Handstand Innovations',
#  'Harris Corporation',
#  'Headway Technologies',
#  'Heat Seal LLC',
#  'Heidelberger Druckmaschinen AG',
#  'Heliae Development',
#  'Heraeus Precious Metals North America Conshohocken LLC',
#  'Hewlett Packard Enterprise Development LP',
#  'Hitachi',
#  'Hitachi High-Technologies Corporation',
#  'Hitachi Metals',
#  'Hollingsworth & Vose Company',
#  'Hollywood Trucks',
#  'Hon Hai Precision Industry Co.',
#  'Honda Motor Co.',
#  'Honeywell International Inc.',
#  'Hosiden Corporation',
#  'Hoya Corporation',
#  'Humanetics Corporation',
#  'Hunt Energy Enterprises LLC',
#  'Hunter Douglas Inc.',
#  'Hynix Semiconductor Inc.',
#  'Hysitron Incorporated',
#  'Hyundai Motor Company',
#  'IDEALAB',
#  'IDEX Health & Science LLC',
#  'II-VI Incorporated',
#  'IMDS Corporation',
#  'IMEC',
#  'IMRA America',
#  'INFINEUM INTERNATIONAL LIMITED',
#  'INTEVAC',
#  'INVISTA North America S.a.r.l.',
#  'ITN Energy Systems',
#  'Ideal Power Inc.',
#  'Ignis Innovation',
#  'Illinois Tool Works',
#  'Immunolight',
#  'Imperial Innovations Limited',
#  'InView Technology Corporation',
#  'Inaeris Technologies',
#  'Incept LLC',
#  'Incyte Holdings Corporation',
#  'Industrial Science & Technology Network',
#  'Industrial Technology Research Institute',
#  'Infineon Technologies AG',
#  'Infinera Corporation',
#  'Innolux Corporation',
#  'Innovation Hammer',
#  'Inphenix',
#  'Instron Corporation ',
#  'Integrated DNA Technologies',
#  'Integrated Device Technology',
#  'Integrated Nano-Technologies',
#  'Integrated Solar Technology',
#  'Intellectual Keystone Technology LLC',
#  'Interface Performance Materials',
#  'Intermolecular',
#  'International Business Machines Corporation',
#  'Intuitive Surgical Operations',
#  'Invensas Corporation',
#  'Iogen Corporation',
#  'Ion Power Group',
#  'Ivoclar Vivadent AG',
#  'J. E. WHITE',
#  'JFE STEEL CORPORATION',
#  'JNC Corporation',
#  'JSR Corporation',
#  'JX Nippon Mining & Metals Corporation',
#  'Janssen Biotech',
#  'Johns Manville',
#  'Johnson & Johnson Consumer Companies',
#  'Johnson & Johnson Vision Care',
#  'Johnson Controls Technology Company',
#  'Johnson Matthey PLC',
#  'KINO LLC',
#  'KJ BIOSCIENCES LLC',
#  'KLA-Tencor Corporation',
#  'KOLO TECHNOLOGIES',
#  'KOLON INDUSTRIES',
#  'KT Corporation',
#  'KYOCERA DOCUMENT SOLUTIONS INC.',
#  'Kabushikikaisha Toshiba',
#  'Kajima Corporation',
#  'Kala Pharmaceuticals',
#  'Kaneka Corporation',
#  'Kansai Paint Co.',
#  'Kao Corporation',
#  'Karsten Manufacturing Corporation',
#  'Kashiv Pharma',
#  'Kemira OY',
#  'Kerr Corporation',
#  'Kia Motors Corporation ',
#  'Kimberly-Clark Worldwide',
#  'Kinestral Technologies',
#  'King Electric Vehicles Inc.',
#  'Kobe Steel',
#  'Kodak Alaris Inc.',
#  'Korea Kumho Petrochemical Co.',
#  'Kraton Polymers U.S. LLC',
#  'Kronos International Inc',
#  'Kulite Semiconductor Products',
#  'Kureha Corporation',
#  'L-3 Communications Cincinnati Electronics Corporation',
#  'LG Display Co.',
#  'LG Electronics Inc.',
#  'LG NANOH2O',
#  'LGS Innovations LLC',
#  'LIQUID X PRINTED METALS',
#  'LUCERA LABS',
#  'Lake Lite',
#  'Landauer',
#  'Lattice Semiconductor Corporation',
#  'Lawrence Livermore National Security',
#  'Leap Frogg',
#  'Lextar Electronics Corp.',
#  'Life Technologies Corporation',
#  'LifeNet Health',
#  'Linne Industries LLC',
#  'Lintec Corporation',
#  'Liquidia Technologies',
#  'Litron Laboratories Limited',
#  'Little Kids',
#  'Livetv',
#  'Lockheed Martin Corporation',
#  'Locus Energy',
#  'Lof Solar Corporation',
#  'Longhorn Vaccines and Diagnostics',
#  'Lovelace Respiratory Research Institute',
#  'Lumenco',
#  'Lumentum Operations LLC',
#  'Luna Innovations Incorporated',
#  'Lux Bio Group',
#  'MAHLE International GmbH',
#  'MANUFACTURING RESOURCES INTERNATIONAL',
#  'MATERIALS ANALYSIS TECHNOLOGY (US) CORP.',
#  'MAXLINEAR',
#  'MBC Ventures',
#  'MCI',
#  'MEDport',
#  'MERCK SHARP & DOHME CORP.',
#  'MICROMIDAS',
#  'MICROSOFT TECHNOLOGY LICENSING',
#  'MIETAMARK GENETICS',
#  'MILLENIUM SYNTHFUELS CORPORATION',
#  'Macronix International Co.',
#  'Magna International Inc.',
#  'Magnachip Semiconductor',
#  'Magnolia Optical Technologies',
#  'Magnolia Solar',
#  'Mainstream Engineering Corp.',
#  'Marathon Equipment Company',
#  'Marine Polymer Technologies',
#  'Markel Corporation',
#  'Materia',
#  'Mattson Technology',
#  'Maxout Renewables',
#  'McAlister Technologies',
#  'McElroy Manufacturing',
#  'Mediatek Inc.',
#  'Medical Diagnostic Laboratories',
#  'Medicis Pharmaceutical Corporation',
#  'Meso Scale Technologies',
#  'Met Tech Inc.',
#  'Metabolix',
#  'Meyer Tool',
#  'Michigan Biotechnology Institute',
#  'Micro Cooling Concepts',
#  'MicroContinuum',
#  'MicroLink Devices',
#  'Microchip Technology Incorporated',
#  'Microchips Biotech',
#  'Micron Technology',
#  'Microsemi SoC Corporation',
#  'Midori USA',
#  'Midrex Technologies',
#  'Milliken & Company',
#  'Minebea Co.',
#  'MirTech',
#  'Mission Product Holdings',
#  'Mitsubishi Electric Corporation',
#  'Mitsubishi Metal Corporation',
#  'Molecular Rebar Design',
#  'Momentive Performance Materials GmbH',
#  'MonoSol',
#  'Monsanto Technology LLC',
#  'Moxtek',
#  'Murata Manufacturing Co.',
#  'Musco Corporation',
#  'NANO CELL SYSTEMS',
#  'NANOBIO CORPORATION',
#  'NCC Nano',
#  'NEC Corporation',
#  'NGK Spark Plug Co.',
#  'NLT TECHNOLOGIES',
#  'NOK Corporation',
#  'NOVA Chemicals (International) S.A.',
#  'NanoGram Corporation',
#  'NanoLab',
#  'NanoMech',
#  'NanoOncology',
#  'NanoTech Lubricants',
#  'Nanoco Technologies',
#  'Nanocopocia',
#  'Nanoholdings',
#  'Nanomix',
#  'Nanoquantum Sciences',
#  'Nanoridge Materials',
#  'Nanospectra Biosciences',
#  'Nanosys',
#  'Nanotech Biomachines',
#  'Nanotek Instruments',
#  'Nantero',
#  "Nationwide Children's Hospital",
#  'Nederlandse Organisatie voor toegepast-natuurwetenschappelijk onderzoek TNO',
#  'NeoPhotonics Corporation',
#  'NeoVision LLC',
#  'NetApp',
#  'NeuMoDx Molecular',
#  'Neural Signals',
#  'Neutronic Perpetual Innovations',
#  'New England Biolabs',
#  'New Technology Ventures',
#  'Newdoll Enterprises LLC',
#  'Newlans',
#  'Newport Corporation',
#  'Nexcom Technology',
#  'Nikon Corporation',
#  'Nippon Chemi-Con Corporation',
#  'Nippon Shokubai Co.',
#  'Nissan North America',
#  'Nokia Corporation',
#  'Nokomis',
#  'Nordic Technologies',
#  'Nordson Corporation',
#  'Northrop Grumman Systems Corporation',
#  'Northwest Biotherapeutics',
#  'Nova Technologies',
#  'Novartis AG',
#  'Novon',
#  'Novozymes A/S',
#  'Novus Technology',
#  'Nthdegree Technologies Worldwide Inc.',
#  'NuOrtho Surgical',
#  'Nutech Ventures',
#  'Nvidia Corporation',
#  'O.B.I. Inc.',
#  'OAS Design Group',
#  'OFS Fitel',
#  'OLYMPUS CORPORATION',
#  'OPTERRA ENERGY SERVICES',
#  'OSI Optoelectronics',
#  'Oceanit Laboratories',
#  'Oculus VR',
#  'Oki Data Corporation',
#  'Olympus NDT',
#  'OmniVision Technologies',
#  'Omron Corporation',
#  'One Earth Designs Inc.',
#  'Opel Solar',
#  'Optodot Corporation',
#  'Oracle International Corporation',
#  'OrbusNeich Medical',
#  'Ormat Technologies Inc.',
#  'Ortho-Clinical Diagnostics',
#  'Osram Sylvania Inc.',
#  'Ostendo Technologies',
#  'Owens-Brockway Glass Container Inc.',
#  'PACCAR Inc',
#  'PAX Scientific',
#  'PDF Solutions',
#  'PELLION TECHNOLOGIES',
#  'PLEX LLC',
#  'PLYCEM USA',
#  'PNM',
#  'POET Research',
#  'POSiFA MICROSYSTEMS',
#  'PPG Industries Ohio',
#  'PQ CORPORATION',
#  'Pacific Biosciences of California',
#  'Pacific Industrial Development Corporation',
#  'Pacific Light Technologies',
#  'Palo Alto Research Center Incorporated',
#  'Pansonic Corporation',
#  'Paratek Pharmaceuticals',
#  'Pardev',
#  'Parion Sciences',
#  'Pegatron Corporation',
#  'Pendar Technologies',
#  'Pentair Thermal Management LLC',
#  'Pentron Clinical Technologies',
#  'Performance Plants',
#  'Perkinelmer Holdings',
#  'PeterBrod Corp.',
#  'PetraSolar',
#  'Peytant Solutions',
#  'Pfizer Inc.',
#  'Pharmatrophix',
#  'Pharmion Corporation',
#  'Phillips 66 Company',
#  'Phoseon Technology',
#  'Photon Dynamics',
#  'Piksel',
#  'Pinnacle Technology',
#  'Pioneer Energy',
#  'Pixar',
#  'Pixelligent Technologies',
#  'Plant Sensory Systems',
#  'Plasma-Therm',
#  'PluroGen Therapeutics',
#  'Polaris Products LLC',
#  'Poly-Med',
#  'PolyOne Corporation',
#  'PolyPlus Battery Company',
#  'Polysar Corporation',
#  'PortaFire',
#  'Power Integrations',
#  'Praxair S.T. Technology',
#  'Previvo Genetics',
#  'Princeton Optronics',
#  'ProNAi Therapeutics',
#  'Production Resource Group',
#  'Professional Compounding Centers of America',
#  'Propagation Research Associates',
#  'Proterra Inc.',
#  'Proton Power',
#  'Pulse Therapeutics',
#  'QUALCOMM Incorporated',
#  'Qiagen GmbH',
#  'Quantapore',
#  'Quantum Devices',
#  'Quantum Materials Corporation',
#  'R.A. Miller Industries',
#  'RADIANCE SOLAR',
#  'RES USA',
#  'RF Micro Devices',
#  'Rapamycin Holdings',
#  'Raytheon Company',
#  'Rebellion Photonics',
#  'Red Hat',
#  'Regeneron Pharmaceuticals',
#  'Reliance Controls Corporation',
#  'Relypsa',
#  'Renesas Electronics Corporation',
#  'Renewable Power Conversion',
#  'RenovaCare Sciences Corp.',
#  'Research Triangle Institute',
#  'Revera',
#  'Revivicor',
#  'Reynolds Technologies',
#  'Richtek Technology Corporation',
#  'Ricoh Company Limited',
#  'Rima Enterprises',
#  'Rio Grande Valley Sugar Growers',
#  'Riverbed Technology',
#  'Robert Bosch GmbH',
#  'Roche Diagnostics GmbH',
#  'Roche Molecular Systems',
#  'Rockwell Automation Technologies',
#  'Rockwell Collins',
#  'Rohm and Haas Electronic Materials LLC',
#  'Roll-N-Lock Corporation',
#  'Rolls-Royce PLC',
#  'S&S X-Ray Products',
#  'S. C. Johnson & Son',
#  'SABIC GLOBAL TECHNOLOGIES B.V.',
#  'SAE Magnetics (HK) Ltd.',
#  'SAINT-GOBAIN ABRASIFS',
#  'SAMSUNG DISPLAY CO.',
#  'SB ENERGY',
#  'SD Technologies',
#  'SEEK THERMAL',
#  'SEIKO NPC Corporation',
#  'SELMAN AND ASSOCIATES',
#  'SEaB Energy Holdings Ltd.',
#  'SICPA Holding SA',
#  'SII Semiconductor Corporation',
#  'SOL-ELECTRICA',
#  'SOLAZYME',
#  'SPC International',
#  'SPICE SOLAR',
#  'SRG Global',
#  'STANDARD ALCOHOL COMPANY OF AMERICA',
#  'STATS ChipPAC',
#  'SUMITOMO WIRING SYSTEMS',
#  'SUNSALUTER',
#  'SYNTHOMER USA LLC',
#  'Sagacious Investment Group L.L.C.',
#  'Saint-Gobain Adfors Canada',
#  'Saint-Gobain Ceramics & Plastics',
#  'Saint-Gobain Performance Plastics Corporation',
#  'Samsung Electronics',
#  'Samsung SDI Co.',
#  'SanDisk Technologies LLC',
#  'Sandia Corporation',
#  'Sangamo BioSciences',
#  'Sanken Electric Co.',
#  'Sanofi',
#  'Sanuvox Technologies',
#  'Sanyo Electric Co.',
#  'Schlumberger Technology Corporation',
#  'Schneider Electric Solar Inverters USA',
#  'Schneider Electric USA',
#  'Scientific Design Company',
#  'Seagate Technology LLC',
#  'Seetron Inc.',
#  'Seiko Epson Corporation',
#  'Seiko Instruments Inc.',
#  'Selas Heat Technology Company LLC',
#  'Selecta Biosciences',
#  'Selkermetrics',
#  'Semiconductor Energy Laboratory Co.',
#  'Semics Inc.',
#  'Semprius',
#  'Senaya',
#  'Senga Advisors',
#  'Sensor Electronic Technology',
#  'Sensor-Kinesis Corporation',
#  'Sequenom',
#  'ServiceNow',
#  'Sharp Laboratories of America',
#  'Shell Oil Company',
#  'Shin-Etsu Chemical Co.',
#  'Shoals Technologies Group',
#  'Sick AG',
#  'Siemens Aktiengesellschaft ',
#  'Siemens Medical Solutions USA',
#  'Sienna Biopharmaceuticals',
#  'Sigma-Aldrich Co. LLC',
#  'Silicon Genesis Corporation',
#  'Silicon Space Technology Corp.',
#  'Silicon Storage Technology',
#  'Siliconware Precision Industries Co.',
#  'Silicor Materials Inc.',
#  'Siluria Technologies',
#  'Sima Therapeutics',
#  'Simbol Inc.',
#  'Sinewatts',
#  'Singular Bio',
#  'Singulex',
#  'Sinton Consulting',
#  'Sion Power Corporation',
#  'SixPoint Materials',
#  'Skidmore',
#  'Smart Planet Technologies',
#  'Smith & Nephew',
#  'SolAero Technologies Corp.',
#  'Sola U.S.A. Inc.',
#  'SolaBlock LLC',
#  'Solaire Generation LLC',
#  'Solan',
#  'Solar Junction Corporation',
#  'Solar-Tectic LLC',
#  'SolarCity Corporation',
#  'SolarLego Inc.',
#  'SolarReserve Technology',
#  'SolarWorld Americas Inc.',
#  'Solarmer Energy',
#  'Solight Solar',
#  'Soliton Lasers',
#  'Solvay Specialty Polymers USA',
#  'Sony Corporation',
#  'Sony Interactive Entertainment America LLC',
#  'Soraa',
#  'Soraa Laser Diode',
#  'Southwest Research Institute',
#  'St. Jude Medical',
#  'St. Microelectronics Inc.',
#  'Stablcor Technology',
#  'Stanley Electric Co.',
#  'Star Technology and Research',
#  'Starlight Energy Holdings LLC',
#  'Starsource Scientific LLC',
#  'Stora Enso Oyj',
#  'Stratasys',
#  'Suganit Systems',
#  'Sumco Corporation',
#  'Sumitomo Electric Device Innovations',
#  'Sumitomo Electric Industries',
#  'Sumitomo Rubber Industries',
#  'Sun Chemical Corporation',
#  'Sun Drilling Products Corporation',
#  'Sun Synchrony',
#  'SunCulture Solar Inc.',
#  'SunEdison',
#  'SunEdison Semiconductor Limited',
#  'SunLink Corporation',
#  'SunPower Corporation',
#  'SunRun',
#  'Suncore Photovoltaics',
#  'Sundrop Fuels',
#  'Sungevity Inc.',
#  'Sunlight Photonics Inc.',
#  'Supremex Inc.',
#  'Surebeam Corporation',
#  'Sustainable Technologies',
#  'Swagelok Company',
#  'Sweetwater Energy',
#  'Swift Engineering',
#  'Symantec Corporation',
#  'Synaptic Research',
#  'Syngenta Participations AG',
#  'Synopsys',
#  'Synthetic Genomics',
#  'System Biosciences',
#  'T.H.E.M.',
#  'TDK Corporation',
#  'TECNIUM',
#  'TEKNOR APEX COMPANY',
#  'THE BOARD INSTITUTE',
#  'THYSSENKRUPP INDUSTRIAL SOLUTIONS GMBH',
#  'TMC Corporation',
#  'TOMOWAVE LABORATORIES',
#  'TP Solar',
#  'TRANE INTERNATIONAL INC.',
#  'TRI ALPHA ENERGY',
#  'TRIDONIC GMBH & CO KG',
#  'TT Technologies',
#  'Taiwan Semiconductor Manufacturing Company',
#  'Taiyo Ink Mfg. Co.',
#  'Takara Bio Inc.',
#  'Takeda Pharmaceutical Company Limited',
#  'Tamura Corporation',
#  'Tapwave',
#  'Tarveda Therapeutics',
#  'Tata Consultancy Services Limited',
#  'Tau Therapeutics LLC',
#  'Tela Innovations',
#  'Teledyne Scientific & Imaging',
#  'Teradata US',
#  'Terra Caloric',
#  'Tersus Environmental',
#  'Tessera',
#  'Texas Research International',
#  'The Babcock & Wilcox Company',
#  'The Boeing Company',
#  'The Carbon Cable Company',
#  'The Charles Stark Draper Laboratory',
#  'The Eastern Co.',
#  'The Goodyear Tire & Rubber Company',
#  'The Henry M. Jackson Foundation for the Advancement of Military Medicine',
#  'The Jackson Laboratory',
#  'The Paymaster Corporation',
#  'The Samuel Roberts Noble Foundation',
#  'Theraclone Sciences',
#  'Thorlabs',
#  'Thorn Bioscience LLC',
#  'Tigo Energy',
#  'Toda Kogyo Corporation',
#  'Tokyo Electron Limited',
#  'Tokyo Ohka Kogyo Co.',
#  'Toray Industries Inc. ',
#  'Toray Plastics (America)',
#  'Toshiba America Electronic Components',
#  'Tosoh Corporation',
#  'Total Marketing Services',
#  'Toyota Motor Engineering & Manufacturing North America',
#  'Transilwrap Company',
#  'Transitions Optical',
#  'Transposagen Biopharmaceuticals',
#  'Transtron Solutions LLC',
#  'Travis Industries',
#  'Triple Ring Technologies',
#  'True-Safe Technologies',
#  'Tufts Medical Center',
#  'Turtle Beach Corporation',
#  'Two Blades Foundation',
#  'Tyco Electronics Corporation',
#  'U S MICROPOWER INC',
#  'U.S. NUTRACEUTICALS',
#  'UCB Pharma S.A.',
#  'UChicago Argonne',
#  'UOP LLC',
#  'UT-Battelle',
#  'UWM Research Foundation',
#  'Ube Industries',
#  'Uni-Charm Corporation',
#  'Unifrax I LLC',
#  'Uniseal Solutions Inc.',
#  'Unistrut International Corp.',
#  'United Microelectronics Corp.',
#  'United Technologies Corporation',
#  'Unity Semiconductor Corporation',
#  'Universal Display Corporation',
#  'Universal Leaf Tobacco Co.',
#  'VEECO PRECISION SURFACE PROCESSING LLC',
#  'VIASAT INC.',
#  'VINDICO NANOBIO TECHNOLOGY INC.',
#  'VINYLAST',
#  'VIOLIN MEMORY',
#  'VMware',
#  'Vadient Optics',
#  'Valicor',
#  'Vascular BioSciences',
#  'Vaxiion Therapeutics',
#  'Veracode',
#  'Veracyte',
#  'Verliant Energy',
#  'Virent',
#  'Vizio Inc.',
#  'Vorbeck Materials Corporation',
#  'Voxtel',
#  'W&Wsens Devices',
#  'WAFERTECH',
#  'WCA Group LLC',
#  'WHATSAPP INC.',
#  'WOVN',
#  'Waters Technologies Corporation',
#  'Watlow Electric Manufacturing Company',
#  'Wave Energy Conversion Corporation of America',
#  'Weatherford Canada Partnership',
#  'Wenger Corporation',
#  'WestPoint Home',
#  'WiSys Technology Foundation',
#  'Wikipad',
#  'Winbond Electronics Corp.',
#  'Wine.com',
#  'Wireless Environment',
#  'Wizard Labs',
#  'Wostec',
#  'Wyatt Technology Corporation',
#  'Xerox Corporation',
#  'Xintec Inc.',
#  'Xyleco',
#  'Yageo Corporation',
#  'Yamaha Corporation',
#  'Yeda Research and Development Co.',
#  'Yissum',
#  'ZENA TECHNOLOGIES',
#  'ZIH Corp.',
#  'ZON',
#  'Zeno Semiconductor Inc',
#  'Zephyr Energy Systems LLC',
#  'Zoetis Services LLC',
#  'Zygo Corporation',
#  'aTyr Pharma',
#  'bioTheranostics',
#  'eNow',
#  'fybr',
#  'iBio',
#  'iNanoBio LLC',
#  'k-Space Associates',
#  'mVerify Corporation',
#  'nLIGHT',
#  'nanoComposix'}

# %%
def get_ordered_about_urls (firm_name):
    urls = list (abouts.loc[(abouts['firm_name'] == firm_name) & (abouts['is_about'] == 1), 'url'])
    urls.sort(key = len)
    # print ('Original urls')
    # pp.pprint(urls)

    index = {}
    for url in urls:
        path_fragments = len(url.split('/'))
        added = False
        for i in range(1, path_fragments):
            key_phrase = url.rsplit('/', maxsplit=i)[0]
            if key_phrase in urls or (key_phrase + '/') in urls: 
                od = index.setdefault(key_phrase, OrderedDict())
                od[url] = 1
                added = True
                continue
        if not added:
            od = index.setdefault(url, OrderedDict())
            od[url] = 1
 
    # pp.pprint (index)
    
    return_urls = [] 
    seen = set ()
    for key in index.keys():
        tree_urls = index[key]
        for fu in tree_urls:
            if fu not in seen:
                return_urls.appju8j nend(fu)
                seen.add(fu)
    
    # finally remove home page if it exists and if there are other pages to draw on
    if not return_urls: 
        return None
    else: 
        first_page = return_urls[0]
        first_page_path = get_page_path_text (first_page)
        if first_page_path == ' ' or first_page_path == '':
            print (first_page_path + 'empty')
            return_urls.pop(0)
        return return_urls

test_urls = get_ordered_about_urls ('Previvo Genetics')
print ('Ordered urls')
pp.pprint (test_urls)
# Out:
# Ordered urls
# None

# %%
# remove html content
def is_javascript (x):
    match_string = r"(CDATA|return\s+true|return\s+false|getelementbyid|function|\w+\(.*?\);|\w{2,}[\\.|:]+\w{2,}|header|hover|'\w+':\s+'\w+|\\|{|}|\r|\n|\/\/')"
    # capture CDATA; function declarations; function calls; word sequences separated by a period (e.g., denoting paths)
    regex = re.findall(match_string, x) 
    # check to see if the regex finds some percentage of the words look like javascript patterns
    if (len(regex) / float(len(x.split())) > .10):
        return True 
    else:
        return False

def clean_page_content (text_list):
    # remove whatever we think is html
    removed_html = filter(lambda x: not( bool(BeautifulSoup(x, "html.parser").find()) ), text_list)
    # remove content that looks like javascript 
    removed_js = filter(lambda x: not (is_javascript(x)), removed_html)
    # add other checks here as needed

    return removed_js
    

# iterate through firm urls and return concatenated string
def get_content (urls): 
    running_text = ''
    for url in urls:
        print ('\tWorking on ' + url)
        result = col.find_one( {"url": url} )
        if result:
            clnd_text = clean_page_content(result['full_text'])
            clnd_text = '\n'.join(clnd_text)
            boilerpipe = None
            
            if 'body' in result:
                extractor = Extractor(extractor='DefaultExtractor', html = result['body'][0])
                lines = extractor.getText().replace(u'\xa0', u' ').split('\n')
                filtered = filter(lambda x: not re.match(r'^\s*$', x), lines)
                boilerpipe = '\n'.join(filtered)

            # TODO fix to split().  Counting characters currently 
            if boilerpipe and (len(boilerpipe) > .5 * len(clnd_text)):
                print ('\t\tUsing boilerplate')
                running_text += boilerpipe
            else:
                print ('\t\tUsing clnd_text')
                running_text += clnd_text
        else:
            print ('Cannot find url: ' + url)

    return running_text

def clean_text (firm_name, text):
    strip_regex = re.compile(r"(" + "\s|".join(firm_name.split()) + "\s)", re.IGNORECASE)
    clnd_text = strip_regex.sub ('', text)
    
    more_regex = re.compile(r"([A-Z]\.?){1,} ")
    clnd_text = more_regex.sub ('', clnd_text)
    
    return ' '.join(clnd_text.split(' '))

# %%
# regex test 
regex = re.findall(r"(CDATA|return\s+true|return\s+false|getelementbyid|function|\w+\(.*?\);|\w{2,}[\\.|:]+\w{2,}|'\w+':\s+'\w+|\\|{|}|\r|\n|\/\/')", 
                   "CDATA function contact-us getelementbyid javascript.function linker:autoLink www.littlekidsinc.com fxnCall(param.param); email@dextr.us 'type': 'image' return true return false rev7bynlh\\u00252bvcgrjg\\ {height}") # last part is words sequences separated by punct
print (regex)

print (clean_firm_name('Ford Motor Co. Corporation'))
print (clean_text (clean_firm_name('Ford Motor Co.'), 'Ford is a motor company.  It has been building vehicles for over a century. H.W.F_ Ford was a nice guy.'))
# Out:
# ['CDATA', 'function', 'getelementbyid', 'javascript.function', 'linker:autoLink', 'www.littlekidsinc', 'fxnCall(param.param);', 'dextr.us', "'type': 'image", 'return true', 'return false', 'rev7bynlh\\u00252bvcgrjg', '\\', '{', '}']
# Ford Motor Co
# is a company.  It has been building vehicles for over a century. H.W.F_ was a nice guy.

# %%
test_site_text = get_content (test_urls)
print (test_site_text)
# Out:
# 	Working on http://www.xxiicentury.com/history/
# 		Using boilerplate
# 	Working on http://www.xxiicentury.com/profile/
# 		Using boilerplate
# Company History
# THE IDEA
# In 1998, Joseph Pandolfino founded 22nd Century Limited, LLC (22nd Century) to provide funding to North Carolina State University (NCSU) for a research and development collaboration on nicotine biosynthesis in the tobacco plant. Mr. Pandolfino asked the question: “Since coffee without caffeine and beer without alcohol are commercially available, why aren’t tobacco cigarettes without nicotine a choice for consumers?” Further, he hypothesized: “If it were possible to produce tobacco cigarettes without nicotine, couldn’t smokers use these extraordinary cigarettes to successfully quit smoking?”
# A paradox to be sure. Nonetheless, Mr. Pandolfino’s hypothesis stemmed from his careful observation of real smokers. As an importer of tobacco-free herbal cigarettes, Mr. Pandolfino learned that many consumers were using nicotine-free herbal cigarettes to successfully quit smoking. Anecdotal evidence suggested that this approach was particularly effective. The biggest problem with the novel “therapy” was the fact that herbal cigarettes have distinct taste and aroma characteristics which greatly limit their consumer appeal and acceptance.
# Indeed, although various processes were developed to improve these nicotine-free herbal cigarettes, it became clear that their peculiar taste and aroma characteristics would never appeal to mainstream smokers. If, on the other hand, a tobacco cigarette without nicotine could be developed, Mr. Pandolfino believed a new cigarette category could prove an attractive product choice to all smokers. With this in mind, Mr. Pandolfino set out to investigate the feasibility of efficiently producing nicotine-free tobacco cigarettes.
# Already Philip Morris USA had developed a process to extract nicotine from tobacco; however this process, similar to that of producing decaffeinated coffee, proved very costly. What’s more, these “denicotinized” or “denic” cigarettes (test-marketed from 1989 to 1991) simply did not taste good. Philip Morris concluded that within the denicotinization process, various other tobacco leaf compounds important to tobacco’s taste characteristics were extracted along with the nicotine. Denicotinization tobacco processes are not selective for nicotine and, according to Philip Morris, “resulted in a dramatic change in the taste of the original tobacco” ( Philip Morris 1994 ).
# Therefore, Mr. Pandolfino concluded, the key to producing a cigarette with virtually no nicotine – that smokers would find acceptable – is the ability to grow tobacco plants whose intrinsic nicotine content is a tiny fraction of that found in conventional tobacco plants. This conclusion led Mr. Pandolfino on a journey to acquire and develop the know-how and technology, including intellectual property rights, to block nicotine biosynthesis in the tobacco plant through genetic engineering.
# THE TECHNOLOGY
# To this end, in 1997 Mr. Pandolfino met Dr. Mark Conkling, Director of the Biotechnology Programs at North Carolina State University. Dr. Conkling had recently cloned a key gene in the tobacco plant responsible for nicotine production. Dr. Conkling believed expression of this gene could be blocked to produce tobacco plants with virtually no nicotine. Mr. Pandolfino concurred and the result of their meeting was a successful 5-year research collaboration between 22nd Century and NCSU that resulted in a patented very low nicotine tobacco variety (Xie et al. 2004). This became the first genetically modified (GM) tobacco variety deregulated by the Animal Plant & Health Inspection Service (APHIS) of the United States Department of Agriculture (USDA).
# In 1999, 22nd Century exclusively sublicensed this proprietary technology and tobacco to Liggett Group, the fifth largest cigarette company in the United States, and shortly thereafter to other subsidiaries of Vector Group Ltd. ( Wall Street Journal 2001 ). In 2003, Vector Tobacco Inc., an affiliate of Liggett Group, marketed in eight U.S. states Quest®, a novel cigarette brand containing 22nd Century’s proprietary tobacco, to gather data for the U.S. Food and Drug Administration (FDA) approval process of Quest® as a smoking cessation aid. Quest® also utilized Mr. Pandolfino’s product concept comprised of a series of cigarettes with the same “tar” yield but progressively reduced nicotine content for use in smoking cessation.
# Also in 2003, the USDA, and in 2005, the Plant Breeders’ Rights Office of Canada granted NCSU plant variety protection (PVP) certificates for a very low nicotine tobacco variety developed at NCSU from funding by 22nd Century. 22nd Century has exclusive rights to this tobacco variety. Both the U.S. and Canadian PVP certificates expire in 2023. A PVP certificate is a useful piece of intellectual property since it legally prevents others from growing the protected tobacco variety, and in the case of tobacco, from importing or exporting the subject tobacco leaf.
# THE RESEARCH
# In 2006, Vector Tobacco sponsored a multi-center Phase II smoking-cessation clinical trial to evaluate the effectiveness of Quest® alone or in combination with nicotine replacement therapy ( Becker et al. 2008 ). This trial was performed under Vector’s Investigational New Drug Application (IND) filed with the FDA in 2004. After conveying that it intended to proceed with Phase III clinical trials, Vector Group Ltd.  announced  that Vector Tobacco was no longer pursuing FDA approval of its smoking cessation aid in development. Accordingly, 22nd Century’s licenses to all affiliates of Vector Group Ltd. were terminated. Subsequently (in 2008) through binding arbitration, 22nd Century obtained rights to use and reference at the FDA all data in Vector’s IND, including all results from the Phase II clinical trial, relating to cigarettes containing 22nd Century’s proprietary tobacco. 22nd Century no longer has any type of relationship with Liggett Group or Vector Tobacco.
# From 2005 to 2009, 22nd Century partnered again with NCSU and with other public institutions for further R&D that included the cloning of additional nicotine biosynthesis genes: the Nara Institute of Science and Technology, Nara Japan (NAIST) and the National Research Council of Canada, Plant Biotechnology Institute, Saskatoon Canada (NRC). These contracted R&D partners, NCSU, NAIST and NRC, were first to (i) clone the key nicotine biosynthesis genes and several transcription factor genes that regulate expression of all nicotine biosynthesis genes and (ii) demonstrate biochemical evidence of the function of these genes. The technology and exclusive related patent rights 22nd Century obtained from NAIST and NRC are keystones of 22nd Century’s intellectual property, representing the company’s second-generation technology that has significant advantages over the earlier technology licensed to Liggett Group and Vector Tobacco. Furthermore, 22nd Century’s technology can be employed so that the resulting tobacco plants are not genetically modified (GM).
# 22nd Century’s model of outsourcing R&D to world-renowned plant biotechnology centers has enabled 22nd Century to maintain strict control of its R&D costs, while providing the company broad access to large public institutions’ infrastructure and transdisciplinary expertise. As a result, 22nd Century has obtained exclusive rights to all key nicotine biosynthesis genes that can be regulated to produce viable commercial products with modified content of nicotine and tobacco-specific nitrosamines (TSNAs).
# NAIST assigned various patent families to 22nd Century in 2010, including the NBB technology. Also in 2010, a University of Minnesota clinical trial, led by Dr. Dorothy Hatsukami who is a member of FDA’s Tobacco Products Scientific Advisory Committee known as  TPSAC , demonstrated that Very Low Nicotine (VLNC) cigarettes (made exclusively with 22nd Century’s proprietary tobacco) used over a 6-week treatment period are effective for smoking cessation ( Hatsukami et al. 2010 ). 22nd Century also completed development of an improved VLNC cigarette to continue clinical trials with the company’s proprietary VLNC cigarettes for use in smoking cessation.
# A PUBLICLY TRADED COMPANY
# 2011 was quite an eventful year for the company. In January, 22nd Century became a publicly traded company in conjunction with $5.4 million of private investment. Shares of 22nd Century Group, Inc. are traded under the stock symbol XXII (NYSE American: XXII). 22nd Century received FDA clearance for its Investigational New Drug (IND) Application in July and sponsored a Phase II-B clinical trial for its  X-22 smoking cessation aid in development , a prescription-based smoking cessation aid consisting of a kit of Very Low Nicotine (VLNC) cigarettes. 22nd Century licensed Heracles Pharmaceuticals LLC, its pharmaceutical subsidiary, exclusive worldwide rights to X-22.
# Other notable company events that occurred in 2011: 22nd Century entered into a 3-year R&D agreement with University of Virginia, and Goodrich Tobacco Company, LLC, 22nd Century’s tobacco product subsidiary, introduced two super-premium cigarette brands into the U.S. market and delivered more than 9 million SPECTRUM® research cigarettes . SPECTRUM® was developed by 22nd Century for NIDA, a department of the National Institutes of Health (NIH), and is strictly for independent research purposes.
# THE PRESENT AND… FUTURE!
# © 22nd Century Group Inc. All Rights Reserved.Company Profile
# 22nd Century is a plant biotechnology company with an important mission: To Reduce the Harm Caused by Smoking.
# Our long-term focus is the research, development, licensing, manufacturing, and worldwide sales and distribution of our important products. 22nd Century Group’s proprietary genetic engineering technology and plant breeding expertise allow us to regulate the level of nicotine (and other nicotinic alkaloids) in the tobacco plant. As a result of our unique technology, we are able to grow tobacco with up to 97% less nicotine than conventional tobacco – as well as plants with relatively high nicotine levels. The applications for this technology are extraordinary; in independent clinical studies, our Very Low Nicotine Content (VLNC) tobacco has demonstrated remarkable efficacy as a smoking cessation aid. On the other hand, for smokers who do not wish to quit, our high nicotine tobacco enables us to produce a cigarette with what we believe is the world’s lowest tar-to-nicotine ratio.
# We believe that the tobacco industry is at the beginning of a paradigm shift toward the development and commercialization of reduced-risk tobacco products which represent a significant step toward achieving the public health objective of harm reduction. Our 18 years of research and development on the tobacco plant, mainly on the nicotine biosynthetic pathway, uniquely positions us to become a major benefactor of this paradigm shift developing in the tobacco industry. Our technology has created, and will continue to develop, a pipeline of products. We are primarily involved in the following activities:
# The international licensing of 22nd Century Ltd’s technology, proprietary tobaccos, and trademarks
# The research and development of potentially reduced-risk or modified risk tobacco products
# The development of X-22, a prescription-based smoking cessation aid consisting of very low nicotine cigarettes
# The manufacture, marketing and international distribution of RED SUN and MAGIC proprietary cigarettes
# The production of SPECTRUM research cigarettes for the National Institute of Drug Abuse (NIDA)
# The contract manufacturing of other companies’ branded tobacco products
# 22nd Century Group is organized around the following wholly-owned operating subsidiaries:
# Goodrich Tobacco is focused on commercial tobacco products and potentially less harmful cigarettes.
# Botanical Genetics  is focused on natural, safe and effective cannabis/hemp-based products for human health, well-being and nutrition, in addition to industrial products refined from cannabis/hemp.
# Heracles Pharmaceuticals  is focused on X-22, a prescription smoking cessation aid in development.
# NASCO Products  is our manufacturing facility located in Mocksville, NC.
# © 22nd Century Group Inc. All Rights Reserved.

# %%
# run process_firm and write to file
pp = pprint.PrettyPrinter()
for firm_name in firm_names: 
    print ("Working on " + firm_name)
    about_urls = get_ordered_about_urls(firm_name)
    if not about_urls:
        print ("\tCouldn't find any urls for firm!")
        continue
        
    about_text = get_content (about_urls)
    
    if about_text: 
        firm_clnd = clean_firm_name(firm_name) # standard cleaning code throughout project
        about_clnd = clean_text (firm_name, about_text)
        file = re.sub('\/', '|', firm_clnd) + '.txt'
        with io.open(DATA_DIR + file,'w',encoding='utf8') as f:
            f.write (about_clnd)
    else:
        print ("\tCouldn't find any text for firm!")
# Out:
# Working on DEKA Products Limited Partnership
# 	Working on http://www.dekaresearch.com/about-deka/
# 		Using boilerplate
# Working on Elenion Technologies
# 	Working on https://elenion.com/summary/
# 		Using boilerplate
# Working on INFINEUM INTERNATIONAL LIMITED
# 	Working on https://www.infineum.com/en/about-us/
# 		Using clnd_text
# 	Working on https://www.infineum.com/en/about-us/safety/
# 		Using clnd_text
# 	Working on https://www.infineum.com/en/about-us/history/
# 		Using boilerplate
# 	Working on https://www.infineum.com/en/about-us/overview/
# 		Using boilerplate
# 	Working on https://www.infineum.com/en/about-us/our-brand/
# 		Using clnd_text
# 	Working on https://www.infineum.com/en/careers/our-teams/
# 		Using boilerplate
# Working on OmniVision Technologies
# 	Working on https://www.ovt.com/company
# 		Using clnd_text
# 	Working on https://www.ovt.com/company/company-profile
# 		Using clnd_text
# Working on Kimberly-Clark Worldwide
# 	Working on https://www.kimberly-clark.com/en-us/company/awards
# 		Using clnd_text
# 	Working on https://www.kimberly-clark.com/en-us/company/about-us
# 		Using boilerplate
# 	Working on https://www.kimberly-clark.com/en-us/company/employees
# 		Using clnd_text
# 	Working on https://www.kimberly-clark.com/en-us/company/our-vision
# 		Using clnd_text
# Working on Rebellion Photonics
# 	Working on https://rebellionphotonics.com/about-us.html
# 		Using clnd_text
# Working on Tapwave
# 	Working on https://tapwave.net/action/warfare-incorporated
# 		Using boilerplate
# Working on JSR Corporation
# 	Working on http://jsr.vccs.edu/who_we_are/about/mission.aspx
# 		Using clnd_text
# Working on Pentron Clinical Technologies
# 	Working on https://www.pentron.com/en-us/our-company
# 		Using boilerplate
# Working on Universal Display Corporation
# 	Working on https://oled.com/about/
# 		Using clnd_text
# 	Working on https://oled.com/about/awards/
# 		Using boilerplate
# 	Working on https://oled.com/about/history/
# 		Using clnd_text
# Working on Total Marketing Services
# 	Working on https://www.total.com/en/info/company-websites
# 		Using clnd_text
# 	Working on https://www.total.com/en/group/identity/history
# 		Using clnd_text
# 	Working on https://www.total.com/en/group/identity/five-strong-values-embedded-our-dna
# 		Using clnd_text
# Working on Previvo Genetics
# 	Couldn't find any urls for firm!
# Working on Tata Consultancy Services Limited
# 	Working on https://www.tcs.com/about-us
# 		Using boilerplate
# Working on CP KELCO APS
# 	Working on https://www.cpkelco.com/about-cp-kelco/our-history/
# 		Using boilerplate
# 	Working on https://www.cpkelco.com/about-cp-kelco/our-company/
# 		Using boilerplate
# 	Working on https://www.cpkelco.com/about-cp-kelco/our-principles/
# 		Using boilerplate
# Working on Codexis
# 	Working on https://www.codexis.com/company/about-us/
# 		Using boilerplate
# 	Working on https://www.codexis.com/company/awards-and-recognition/
# 		Using boilerplate
# Working on Molecular Rebar Design
# 	Couldn't find any urls for firm!
# Working on SunEdison Semiconductor Limited
# 	Working on https://www.gw-semi.com/overview-locations/
# 		Using boilerplate
# Working on Yissum
# 	Working on http://yissum.co.il/overview
# 		Using clnd_text
# Working on Agienic
# 	Working on http://agienic.com/about/company
# 		Using boilerplate
# Working on MirTech
# 	Working on http://www.mirtechusa.com/our-company/
# 		Using clnd_text
# Working on Foret Plasma Labs
# 	Working on http://plasmawhirl.com/about.php
# 		Using clnd_text
# Working on FULL CIRCLE BIOCHAR
# 	Working on http://fullcirclebiochar.com/company/
# 		Using boilerplate
# Working on Kao Corporation
# 	Couldn't find any urls for firm!
# Working on Applied Materials
# 	Working on http://www.appliedmaterials.com/company/about
# 		Using clnd_text
# 	Working on http://www.appliedmaterials.com/company/about/our-story
# 		Using boilerplate
# Working on COOK MEDICAL TECHNOLOGIES LLC
# 	Working on https://www.cookmedical.com/about/
# 		Using clnd_text
# 	Working on https://www.cookmedical.com/about/history/
# 		Using boilerplate
# 	Working on https://www.cookmedical.com/about/ethics-compliance/
# 		Using boilerplate
# 	Working on https://www.cookmedical.com/about/mission-and-values/
# 		Using clnd_text
# Working on Kashiv Pharma
# 	Working on https://www.kashivpharma.com/about/
# 		Using clnd_text
# 	Working on https://www.kashivpharma.com/about/business-model/
# 		Using clnd_text
# 	Working on https://www.kashivpharma.com/about/mission-vision/
# 		Using clnd_text
# 	Working on https://www.kashivpharma.com/about/people-management/
# 		Using clnd_text
# Working on McAlister Technologies
# 	Working on https://mcallister.com/about-us/
# 		Using boilerplate
# Working on Egenera
#  empty
# 	Working on https://www.egenera.com/about-us-enterprise-cloud-service-providers/
# 		Using boilerplate
# Working on Chevron Phillips Chemical Company LP
# 	Working on http://www.cpchem.com/en-us/company/pages/default.aspx
# 		Using boilerplate
# Working on Ceramatec
# 	Working on https://www.ceramtec.com/about-us/
# 		Using boilerplate
# Working on Cross Match Technologies
# 	Working on https://www.crossmatch.com/company/about/
# 		Using clnd_text
# Working on Incyte Holdings Corporation
# 	Working on https://www.incyte.com/who-we-are/biopharmaceutical-research
# 		Using boilerplate
# Working on Piksel
# 	Working on https://piksel.com/about/
# 		Using boilerplate
# Working on Disney Enterprises
# 	Working on https://www.thewaltdisneycompany.com/about/
# 		Using boilerplate
# Working on Daikin Industries
# 	Working on https://www.daikin.com/corporate/index.html
# 		Using clnd_text
# 	Working on https://www.daikin.com/csr/environment/vision.html
# 		Using clnd_text
# 	Working on https://www.daikin.com/corporate/overview/index.html
# 		Using clnd_text
# 	Working on https://www.daikin.com/about/corporate/tic/index.html
# 		Using clnd_text
# Working on Fuji Electric Co.
# 	Working on https://www.fujielectric.com/company/profile.html
# 		Using clnd_text
# Working on Marathon Equipment Company
# 	Working on https://www.marathonequipment.com/about
# 		Using boilerplate
# Working on Sony Interactive Entertainment America LLC
# 	Working on https://www.sie.com/en/corporate.html
# 		Using clnd_text
# 	Working on https://www.sie.com/en/corporate/history.html
# 		Using clnd_text
# Working on Sustainable Technologies
# 	Working on http://sustech.cc/wordpress/?page_id=2
# 		Using boilerplate
# Working on NanoOncology
# 	Working on https://www.iinano.org/about
# 		Using clnd_text
# Working on McElroy Manufacturing
# 	Working on https://www.mcelroy.com/en/aboutus.htm
# 		Using boilerplate
# 	Working on https://www.mcelroy.com/aboutus_corp.htm
# 		Using boilerplate
# 	Working on https://www.mcelroy.com/en/aboutus_corp.htm
# 		Using boilerplate
# Working on Aurrion
# 	Working on https://www.asurion.com/about/
# 		Using clnd_text
# 	Working on https://www.asurion.com/about/awards/
# 		Using clnd_text
# Working on Angaza Design
# 	Working on https://www.angaza.com/about/
# 		Using boilerplate
# Working on SD Technologies
# 	Working on http://www.sd-techs.com/about-us.html
# 		Using clnd_text
# Working on ZIH Corp.
# 	Working on https://www.zebra.com/us/en/about-zebra.html
# 		Using clnd_text
# Working on Mission Product Holdings
# 	Working on https://www.mission.com/pages/our-mission
# 		Using clnd_text
# Working on PACCAR Inc
# 	Working on https://www.paccar.com/about-us/awards/
# 		Using clnd_text
# 	Working on https://www.paccar.com/about-us/history/
# 		Using boilerplate
# 	Working on https://www.paccar.com/about-us/get-to-know-paccar/
# 		Using boilerplate
# Working on Regeneron Pharmaceuticals
# 	Working on https://www.regeneron.com/about
# 		Using clnd_text
# 	Working on https://www.regeneron.com/history
# 		Using boilerplate
# Working on PLEX LLC
# 	Working on https://www.plex.tv/about/
# 		Using boilerplate
# Working on ALGETERNAL TECHNOLOGIES
#  empty
# 	Couldn't find any urls for firm!
# Working on AFMODEL
# 	Working on https://afmodels.com/about-us/
# 		Using boilerplate
# Working on Greatbatch Ltd.
# 	Working on https://integer.net/about-us/
# 		Using clnd_text
# Working on Starlight Energy Holdings LLC
#  empty
# 	Couldn't find any urls for firm!
# Working on Lumentum Operations LLC
# 	Working on https://www.lumentum.com/en/company
# 		Using clnd_text
# Working on Nanomix
# 	Working on http://nano.com/nanomix.html
# 		Using boilerplate
# Working on Green Box Batteries
# 	Working on https://biggreenbox.com/pages/how-it-works
# 		Using boilerplate
# Working on Johnson & Johnson Vision Care
#  empty
# 	Couldn't find any urls for firm!
# Working on Schneider Electric Solar Inverters USA
# 	Working on https://solar.schneider-electric.com/company/about-us/
# 		Using clnd_text
# Working on Cbrite Inc.
#  empty
# 	Couldn't find any urls for firm!
# Working on Instron Corporation
# 	Working on http://www.instron.us/en-us/our-company?region=North%20America
# 		Using clnd_text
# Working on Diamond Innovations
# 	Working on https://www.hyperionmt.com/en/About-Us/
# 		Using boilerplate
# Working on Livetv
# 	Couldn't find any urls for firm!
# Working on Poly-Med
# 	Working on http://poly-med.com/about/
# 		Using boilerplate
# Working on SELMAN AND ASSOCIATES
# 	Working on https://selmanlog.com/Default.aspx
# 		Using boilerplate
# Working on INVISTA North America S.a.r.l.
# 	Working on https://www.invista.com/about/who-we-are
# 		Using boilerplate
# 	Working on https://www.invista.com/About/Who-We-Are
# 		Using boilerplate
# Working on WCA Group LLC
# 	Working on https://www.wca-group.com/about-us/
# 		Using clnd_text
# Working on Nanotek Instruments
# 	Working on http://nanotekinstruments.com/about-us/
# 		Using boilerplate
# Working on First Solar
# 	Working on http://www.firstsolar.com/en/About-Us/Overview
# 		Using clnd_text
# Working on Altex Technologies Corporation
# 	Working on http://altextech.com/about.html
# 		Using boilerplate
# Working on Dermazone Solutions
# 	Couldn't find any urls for firm!
# Working on Innovation Hammer
# 	Working on http://ihammerllc.com/aboutus
# 		Using boilerplate
# 	Working on http://ihammerllc.com/AboutUs/tabid/88/Default.aspx
# 		Using boilerplate
# Working on MBC Ventures
# 	Working on https://www.mbc.net/en/corporate/about-us.html
# 		Using boilerplate
# Working on Yamaha Corporation
# 	Couldn't find any urls for firm!
# Working on Veracode
# 	Working on https://www.veracode.com/about
# 		Using clnd_text
# Working on Watlow Electric Manufacturing Company
# 	Working on https://www.watlow.com/en/about-watlow
# 		Using clnd_text
# 	Working on https://www.watlow.com/en/about-watlow/news/watconnect-c1-release
# 		Using boilerplate
# Working on Electrovaya Inc.
# 	Couldn't find any urls for firm!
# Working on Soliton Lasers
# 	Working on https://www.soliton.com/about/
# 		Using boilerplate
# Working on Raytheon Company
# 	Working on https://www.raytheon.com/ourcompany
# 		Using clnd_text
# 	Working on https://www.raytheon.com/ourcompany/history
# 		Using boilerplate
# 	Working on https://www.raytheon.com/ourcompany/ourculture/vv
# 		Using clnd_text
# Working on Nanoridge Materials
# 	Working on http://nanoridge.com/about/
# 		Using boilerplate
# Working on Ecolab Inc.
# 	Working on https://www.ecolab.com/about
# 		Using clnd_text
# 	Working on https://www.ecolab.com/about/our-history
# 		Using clnd_text
# 	Working on https://www.ecolab.com/about/our-businesses
# 		Using clnd_text
# 	Working on https://www.ecolab.com/about/industries-we-serve
# 		Using clnd_text
# 	Working on https://www.ecolab.com/about/industries-we-serve/retail
# 		Using clnd_text
# 	Working on https://www.ecolab.com/about/industries-we-serve/foodservice
# 		Using clnd_text
# 	Working on https://www.ecolab.com/about/industries-we-serve/hospitality
# 		Using clnd_text
# Working on ECOSYNTHETIX LTD.
# 	Working on http://ecosynthetix.com/about-us
# 		Using clnd_text
# Working on Ube Industries
# 	Working on https://ube-ind.co.jp/ube/en/rss/about_rss.html
# 		Using clnd_text
# 	Working on https://ube-ind.co.jp/ube/en/corporate/index.html
# 		Using clnd_text
# Working on Johnson Controls Technology Company
# 	Working on https://www.johnsoncontrols.com/about-us/history
# 		Using boilerplate
# 	Working on https://www.johnsoncontrols.com/about-us/our-company
# 		Using clnd_text
# 	Working on https://www.johnsoncontrols.com/about-us/ethics-and-compliance
# 		Using clnd_text
# Working on Evernote Corporation
# 	Working on https://evernote.com/about
# 		Using boilerplate
# Working on FPInnovations
# 	Working on https://fpinnovations.ca/about-us/pages/organization
# 		Using clnd_text
# 	Working on https://fpinnovations.ca/about-us/Pages/our-work.aspx
# 		Using clnd_text
# 	Working on https://fpinnovations.ca/about-us/Pages/our-network.aspx
# 		Using clnd_text
# 	Working on https://fpinnovations.ca/about-us/pages/our-network.aspx
# 		Using clnd_text
# 	Working on https://fpinnovations.ca/about-us/Pages/organization.aspx
# 		Using clnd_text
# Working on Xintec Inc.
# 	Working on http://www.xintec.com.tw/eng/AX_Introduction.aspx
# 		Using boilerplate
# 	Working on http://www.xintec.com.tw/eng/IR_Company_Profile.aspx
# 		Using clnd_text
# 	Working on http://www.xintec.com.tw/eng/AX_Core-Value_Vision.aspx
# 		Using clnd_text
# Working on Green Solar Transportation
# 	Working on http://greensolartransport.com/com_our-vision.php
# 		Using boilerplate
# Working on GCP Applied Technologies Inc.
# 	Couldn't find any urls for firm!
# Working on Access Business Group International LLC
# 	Working on https://www.accessbusinessgroup.com/about-abg/
# 		Using boilerplate
# Working on PortaFire
# 	Couldn't find any urls for firm!
# Working on E Ink Corporation
# 	Working on https://eink.com/about-us.html
# 		Using boilerplate
# 	Working on https://eink.com/about-our-logo.html
# 		Using boilerplate
# Working on Cardiva Medical
# 	Working on https://www.cardivamedical.com/about-us/ethics/
# 		Using clnd_text
# Working on aTyr Pharma
# 	Couldn't find any urls for firm!
# Working on Materia
# 	Working on http://www.materia-inc.com/corporate/about
# 		Using boilerplate
# 	Working on http://www.materia-inc.com/corporate/about/values
# 		Using boilerplate
# 	Working on http://www.materia-inc.com/corporate/about/history
# 		Using boilerplate
# 	Working on http://www.materia-inc.com/corporate/about/facilities
# 		Using boilerplate
# Working on Soraa
# 	Working on https://www.soraa.com/about
# 		Using boilerplate
# 	Working on https://www.soraa.com/about/news
# 		Using clnd_text
# 	Working on https://www.soraa.com/learn/technology/lighting-revives-2-million-years-history
# 		Using clnd_text
# Working on BlackBerry Limited
# 	Working on https://www.blackberry.com/us/en/company
# 		Using clnd_text
# Working on Commonwealth Scientific & Industrial Research Organization
# 	Working on https://www.csiro.au/en/About
# 		Using clnd_text
# 	Working on https://www.csiro.au/en/About/We-are-CSIRO
# 		Using boilerplate
# Working on HRL Laboratories
# 	Working on http://www.hrl.com/about
# 		Using boilerplate
# 	Working on http://www.hrl.com/about/history
# 		Using boilerplate
# 	Working on http://www.hrl.com/about/quality
# 		Using clnd_text
# 	Working on http://www.hrl.com/about/mission
# 		Using boilerplate
# Working on VIOLIN MEMORY
# 	Working on https://www.violinsystems.com/company/
# 		Using clnd_text
# 	Working on https://www.violinsystems.com/company/awards/
# 		Using boilerplate
# Working on SixPoint Materials
# 	Working on http://spmaterials.com/history.htm
# 		Using boilerplate
# Working on Genisphere
# 	Working on https://genisphere.com/about-us
# 		Using boilerplate
# Working on Little Kids
# 	Working on http://www.littlekidsinc.com/about-us
# 		Using boilerplate
# Working on Perkinelmer Holdings
# 	Working on http://www.perkinelmer.com/company/index.html
# 		Using clnd_text
# Working on Halliburton Energy Services
# 	Working on https://www.halliburton.com/en-US/about-us/default.html?node-id=hgbr8q6o
# 		Using clnd_text
# 	Working on https://www.halliburton.com/en-US/about-us/legal/wage-garnishment.html?SRC=Footer
# 		Using clnd_text
# 	Working on https://www.halliburton.com/en-US/about-us/default.html?node-id=hgbr8q6o&SRC=Footer
# 		Using clnd_text
# 	Working on https://www.halliburton.com/en-US/about-us/corporate-profile/default.html?node-id=hgeyxt5p
# 		Using clnd_text
# Working on Imperial Innovations Limited
# 	Working on https://www.imperialinnovations.co.uk/about/
# 		Using clnd_text
# 	Working on https://www.imperialinnovations.co.uk/about/what-we-do/
# 		Using clnd_text
# 	Working on https://www.imperialinnovations.co.uk/staff/tell-us-about-your-invention/
# 		Using boilerplate
# Working on Nanocopocia
# 	Couldn't find any urls for firm!
# Working on Peytant Solutions
#  empty
# 	Couldn't find any urls for firm!
# Working on OPTERRA ENERGY SERVICES
# 	Working on https://engieservices.us/about-us/
# 		Using boilerplate
# Working on Archer Daniels Midland Company
# 	Working on https://www.adm.com/our-company
# 		Using clnd_text
# 	Working on https://www.adm.com/our-company/history
# 		Using clnd_text
# 	Working on https://www.adm.com/our-company/adm-facts
# 		Using clnd_text
# 	Working on https://www.adm.com/our-company/procurement
# 		Using boilerplate
# 	Working on https://www.adm.com/careers/values-vision
# 		Using clnd_text
# Working on International Business Machines Corporation
# 	Working on https://www.ibm.com/ibm/us/en/?lnk=fab
# 		Using boilerplate
# Working on SRG Global
# 	Working on http://www.srgglobal.com/our-company
# 		Using clnd_text
# 	Working on http://www.srgglobal.com/our-company/history
# 		Using clnd_text
# 	Working on http://www.srgglobal.com/our-company/philosophy
# 		Using clnd_text
# Working on The Goodyear Tire & Rubber Company
# 	Working on https://www.goodyear.com/en-US/company
# 		Using boilerplate
# 	Working on https://www.goodyear.com/en-US/company/college-football
# 		Using boilerplate
# Working on Eastman Kodak Company
# 	Working on https://kodak.com/corp/company/default.htm
# 		Using clnd_text
# 	Working on https://kodak.com/motion/About/default.htm
# 		Using clnd_text
# 	Working on https://kodak.com/US/en/services-business/who-we-are/default.htm
# 		Using clnd_text
# Working on POSiFA MICROSYSTEMS
# 	Working on http://posifamicrosystems.com/about_us.php
# 		Using boilerplate
# Working on LGS Innovations LLC
# 	Working on https://www.lgsinnovations.com/about/
# 		Using boilerplate
# 	Working on https://www.lgsinnovations.com/history/
# 		Using boilerplate
# 	Working on https://www.lgsinnovations.com/about-alliant/
# 		Using clnd_text
# 	Working on https://www.lgsinnovations.com/mission-values/
# 		Using clnd_text
# 	Working on https://www.lgsinnovations.com/company-culture
# 		Using boilerplate
# Working on Community Power Corporation
# 	Couldn't find any urls for firm!
# Working on Oculus VR
# 	Couldn't find any urls for firm!
# Working on Global Eagle Entertainment Inc.
# 	Working on http://www.globaleagle.com/about/albatross
# 		Using boilerplate
# Working on DuPont Teijin Films U.S. Limited Partnership
# 	Working on https://usa.dupontteijinfilms.com/about/
# 		Using boilerplate
# 	Working on https://usa.dupontteijinfilms.com/about/values/
# 		Using clnd_text
# 	Working on https://usa.dupontteijinfilms.com/about/history/
# 		Using boilerplate
# Working on Sensor-Kinesis Corporation
# 	Working on http://sensor-kinesis.com/who-we-are/
# 		Using boilerplate
# Working on Cetac Technologies Inc.
# 	Working on http://www.teledynecetac.com/about-us/about-us
# 		Using boilerplate
# 	Working on http://www.teledynecetac.com/about-us/workshops
# 		Using clnd_text
# 	Working on http://www.teledynecetac.com/about-us/terms-and-conditions
# 		Using clnd_text
# Working on Newdoll Enterprises LLC
# 	Working on http://newholdllc.com/key-values/
# 		Using boilerplate
# 	Working on http://newholdllc.com/who-we-are/
# 		Using clnd_text
# Working on Canon Nanotechnologies
# 	Working on http://cnt.canon.com/overview/
# 		Using boilerplate
# Working on Parion Sciences
# 	Working on http://parion.com/about/
# 		Using clnd_text
# Working on Hoya Corporation
# 	Working on https://www.hoyavision.com/what-i-need/learn-about-hoya/history/
# 		Using clnd_text
# 	Working on https://www.hoyavision.com/what-i-need/learn-about-hoya/company/
# 		Using clnd_text
# 	Working on https://www.hoyavision.com/what-i-need/learn-about-hoya/core-values/
# 		Using clnd_text
# Working on Brookhaven Science Associates LLC
# 	Working on http://bsa-hq.org/about/about.php
# 		Using boilerplate
# Working on Macronix International Co.
# 	Working on http://www.macronix.com/en-us/about/Pages/company-overview.aspx
# 		Using clnd_text
# 	Working on http://www.macronix.com/zh-tw/about/Pages/company-overview.aspx
# 		Using clnd_text
# Working on Cyberonics
# 	Working on https://livanova.cyberonics.com/about
# 		Using clnd_text
# Working on Power Integrations
# 	Working on https://www.power.com/company/
# 		Using boilerplate
# Working on NanoMech
# 	Working on http://www.nanomech.com/company-profile/
# 		Using boilerplate
# 	Working on http://www.nanomech.com/company-profile/safety/
# 		Using boilerplate
# 	Working on http://www.nanomech.com/company-profile/history/
# 		Using boilerplate
# Working on Algenol Biotech LLC
# 	Working on http://algenol.com/about-us/
# 		Using boilerplate
# Working on SPICE SOLAR
# 	Working on http://www.spicesolar.com/about-spice-solar/
# 		Using boilerplate
# Working on Biocare Medical
# 	Working on https://biocare.net/about-us/
# 		Using clnd_text
# 	Working on https://biocare.net/about-us/awards/
# 		Using clnd_text
# 	Working on https://biocare.net/about-us/company-history/
# 		Using clnd_text
# Working on Swagelok Company
# 	Working on https://www.swagelok.com:443/en/About
# 		Using clnd_text
# 	Working on https://www.swagelok.com:443/en/About/Our-Values
# 		Using clnd_text
# Working on Mitsubishi Electric Corporation
# 	Working on https://www.mitsubishielectric.com/en/about/index.html
# 		Using clnd_text
# 	Working on https://www.mitsubishielectric.com/en/about/rd/index.html
# 		Using clnd_text
# 	Working on https://www.mitsubishielectric.com/en/about/rd/ip/index.html
# 		Using clnd_text
# 	Working on https://www.mitsubishielectric.com/en/about/history/index.html
# 		Using clnd_text
# 	Working on https://www.mitsubishielectric.com/en/about/mission/index.html
# 		Using clnd_text
# 	Working on https://www.mitsubishielectric.com/en/about/strategy/index.html
# 		Using boilerplate
# 	Working on https://www.mitsubishielectric.com/en/about/businesses/index.html
# 		Using clnd_text
# 	Working on https://www.mitsubishielectric.com/en/about/rd/advance/index.html
# 		Using clnd_text
# Working on Wireless Environment
# 	Working on http://wirelessenv.com/about-us/
# 		Using boilerplate
# Working on The Carbon Cable Company
# 	Working on https://www.thecableco.com/about-us
# 		Using clnd_text
# 	Working on https://www.thecableco.com/chord_company.html
# 		Using clnd_text
# 	Working on https://www.thecableco.com/vibrapod_company.html
# 		Using clnd_text
# 	Working on https://www.thecableco.com/the_cable_company.html
# 		Using clnd_text
# Working on BAE Systems Information and Electronic Systems Integration Inc.
# 	Working on https://www.baesystems.com/en-us/our-company/bae-systems-inc/about-us
# 		Using clnd_text
# 	Working on https://www.baesystems.com/en-us/our-company/inc-businesses/electronic-systems/about-us
# 		Using clnd_text
# Working on Lintec Corporation
# 	Working on http://www.lintec-global.com/about/
# 		Using boilerplate
# 	Working on http://www.lintec-global.com/about/motto/
# 		Using boilerplate
# 	Working on http://www.lintec-global.com/about/history/
# 		Using boilerplate
# 	Working on http://www.lintec-global.com/about/overview/
# 		Using boilerplate
# Working on Solarmer Energy
# 	Working on http://solarmer.com/aboutus/
# 		Using boilerplate
# Working on KOLON INDUSTRIES
# 	Working on http://www.kolonindustries.com/Eng//Company/company04_01.asp
# 		Using boilerplate
# Working on Advanced Analogic Technologies
# 	Working on http://analogictech.com/About.aspx
# 		Using clnd_text
# Working on Galectin Therapeutics
# 	Working on http://galectintherapeutics.com/who-we-are/about-us/
# 		Using boilerplate
# 	Working on http://galectintherapeutics.com/who-we-are/leadership/
# 		Using boilerplate
# Working on Ecovative Design
#  empty
# 	Couldn't find any urls for firm!
# Working on Nokomis
# 	Working on http://nokomisinc.com/history.html
# 		Using clnd_text
# 	Working on http://nokomisinc.com/about-us.html
# 		Using clnd_text
# Working on Bayer Materialscience LLC
# 	Working on https://www.bayer.com/en/history.aspx
# 		Using clnd_text
# 	Working on https://www.bayer.com/en/profile-and-organization.aspx
# 		Using clnd_text
# Working on System Biosciences
# 	Working on https://www.systembio.com/company/about/
# 		Using clnd_text
# 	Working on https://www.systembio.com/company/mission/
# 		Using clnd_text
# Working on Relypsa
# 	Working on https://www.relypsa.com/who-we-are/about-us/
# 		Using boilerplate
# 	Working on https://www.relypsa.com/who-we-are/our-history/
# 		Using boilerplate
# 	Working on https://www.relypsa.com/who-we-are/mission-values/
# 		Using boilerplate
# Working on Suncore Photovoltaics
# 	Working on http://suncoreus.com/about-us/
# 		Using boilerplate
# Working on Hosiden Corporation
# 	Working on https://www.hosiden.com/company/
# 		Using clnd_text
# Working on ENI S.p.A.
# 	Working on https://www.eni.com/en_IT/company.page
# 		Using clnd_text
# 	Working on https://www.eni.com/en_IT/company/eni-history.page
# 		Using clnd_text
# 	Working on https://www.eni.com/en_IT/company/company-profile.page
# 		Using clnd_text
# 	Working on https://www.eni.com/en_IT/investors/risk-management.page
# 		Using clnd_text
# Working on PeterBrod Corp.
# 	Working on http://petroblend.com/about-us/
# 		Using boilerplate
# Working on Professional Compounding Centers of America
# 	Couldn't find any urls for firm!
# Working on Richtek Technology Corporation
# 	Working on https://www.richtek.com/About%20Richtek?sc_lang=en
# 		Using clnd_text
# 	Working on https://www.richtek.com/About%20Richtek/Newsletters?sc_lang=en
# 		Using clnd_text
# Working on Agena Bioscience
# 	Couldn't find any urls for firm!
# Working on SII Semiconductor Corporation
# 	Working on https://www.ablic.com/en/semicon/corp/vision/
# 		Using clnd_text
# 	Working on https://www.ablic.com/en/semicon/corp/vision/?rf=subbnr
# 		Using clnd_text
# 	Working on https://www.ablic.com/en/semicon/corp/history/
# 		Using clnd_text
# Working on Magnolia Optical Technologies
# 	Couldn't find any urls for firm!
# Working on ADASA INC.
# 	Working on https://adasa.com/pages/about-us
# 		Using boilerplate
# Working on Universal Leaf Tobacco Co.
# 	Working on http://www.universalcorp.com/AboutUs
# 		Using clnd_text
# 	Working on http://www.universalcorp.com/AboutUs/History
# 		Using boilerplate
# 	Working on http://www.universalcorp.com/AboutUs/NextHundred
# 		Using boilerplate
# 	Working on http://www.universalcorp.com/AboutUs/CoreBeliefs
# 		Using boilerplate
# 	Working on http://www.universalcorp.com/OurCompany
# 		Using boilerplate
# 	Working on http://www.universalcorp.com/OurCompany/UniversalIngredients
# 		Using boilerplate
# Working on Envision Solar International
# 	Working on http://www.envisionsolar.com/about-envision-solar/
# 		Using boilerplate
# Working on Sumitomo Electric Industries
# 	Working on https://global-sei.com/company/120th/
# 		Using boilerplate
# 	Working on https://global-sei.com/company/vision.html
# 		Using boilerplate
# Working on Saint-Gobain Adfors Canada
# 	Working on http://www.adfors.com/us/about-adfors
# 		Using clnd_text
# Working on Heat Seal LLC
# 	Working on https://heatsealco.com/about-ampak
# 		Using clnd_text
# 	Working on https://heatsealco.com/about-heatseal
# 		Using boilerplate
# Working on Yageo Corporation
# 	Working on http://www.yageo.com/portal/about_yageo/about.jsp?SWITCH_CATEGORY=/about_yageo/Corporate%20overview&menuid=0&title1=c1
# 		Using clnd_text
# 	Working on http://www.yageo.com/portal/about_yageo/about.jsp?SWITCH_CATEGORY=/about_yageo/Social%20Responsibility&menuid=1&title1=c2
# 		Using clnd_text
# 	Working on http://www.yageo.com/portal/about_yageo/about.jsp?SWITCH_CATEGORY=/about_yageo/Environment%20and%20Safety&menuid=2&title1=c3
# 		Using clnd_text
# 	Working on http://www.yageo.com/portal/about_yageo/about.jsp?SWITCH_CATEGORY=/about_yageo/Certificates%20and%20Awards&menuid=4&title1=c5
# 		Using clnd_text
# Working on RES USA
# 	Working on https://www.res-usa.com/about-res-contractors/
# 		Using boilerplate
# Working on Silicon Space Technology Corp.
# 	Working on https://www.voragotech.com/company-overview
# 		Using boilerplate
# Working on PELLION TECHNOLOGIES
# 	Couldn't find any urls for firm!
# Working on Meyer Tool
# 	Working on https://www.meyertool.com/about-us/
# 		Using boilerplate
# Working on HAMAMATSU PHOTONICS K.K.
# 	Working on https://www.hamamatsu.com/jp/en/our-company/index.html
# 		Using clnd_text
# 	Working on https://www.hamamatsu.com/jp/en/our-company/history/index.html
# 		Using boilerplate
# 	Working on https://www.hamamatsu.com/jp/en/our-company/about-crl/index.html
# 		Using clnd_text
# 	Working on https://www.hamamatsu.com/jp/en/our-company/at-a-glance/index.html
# 		Using boilerplate
# 	Working on https://www.hamamatsu.com/jp/en/our-company/our-philosophy/index.html
# 		Using boilerplate
# Working on Roll-N-Lock Corporation
# 	Working on https://rollnlock.com/about-us
# 		Using boilerplate
# Working on Sun Drilling Products Corporation
# 	Couldn't find any urls for firm!
# Working on Revera
# 	Working on https://www.reveraliving.com/about-revera/about-us
# 		Using clnd_text
# 	Working on https://www.reveraliving.com/about-revera/about-revera
# 		Using clnd_text
# Working on Applied Membrane Technologies
# 	Couldn't find any urls for firm!
# Working on Hyundai Motor Company
# 	Working on https://www.hyundaiusa.com/about-hyundai/news/index.aspx?intcmp=footer%20nav;bottom;text;news
# 		Using boilerplate
# 	Working on https://www.hyundaiusa.com/about-hyundai/doing-business.aspx?intcmp=footer%20nav;bottom;text;doing%20business
# 		Using boilerplate
# 	Working on https://www.hyundaiusa.com/about-hyundai/our-company/index.aspx?intcmp=footer%20nav;bottom;text;our%20company
# 		Using boilerplate
# Working on Tau Therapeutics LLC
# 	Working on http://taurx.com/about-us/
# 		Using boilerplate
# Working on T.H.E.M.
# 	Working on http://www.them.net/about-us/
# 		Using boilerplate
# 	Working on http://www.them.net/about-us/markets/
# 		Using clnd_text
# 	Working on http://www.them.net/about-us/history/
# 		Using clnd_text
# 	Working on http://www.them.net/about-us/partners/
# 		Using boilerplate
# 	Working on http://www.them.net/about-us/them-advantage/
# 		Using boilerplate
# Working on TOMOWAVE LABORATORIES
# 	Working on http://www.tomowave.com/about-us/
# 		Using boilerplate
# 	Working on http://www.tomowave.com/about-us/collaborators/
# 		Using clnd_text
# Working on Proton Power
# 	Working on http://www.protonpower.com/about
# 		Using clnd_text
# 	Working on http://www.protonpower.com/about/
# 		Using clnd_text
# 	Working on http://www.protonpower.com/history
# 		Using boilerplate
# 	Working on http://www.protonpower.com/history/
# 		Using boilerplate
# 	Working on http://www.protonpower.com/about-graphene/
# 		Using clnd_text
# Working on Nationwide Children's Hospital
# 	Working on https://www.nationwidechildrens.org/about-us
# 		Using boilerplate
# 	Working on https://www.nationwidechildrens.org/about-us/our-story
# 		Using clnd_text
# Working on Hollingsworth & Vose Company
# 	Working on https://www.hollingsworth-vose.com/en/Company/
# 		Using clnd_text
# 	Working on https://www.hollingsworth-vose.com/en/Company/Company-History/
# 		Using clnd_text
# Working on Integrated DNA Technologies
# 	Working on https://www.idtdna.com/pages/about/core-values
# 		Using boilerplate
# Working on Seiko Instruments Inc.
# 	Working on http://seikoinstruments.com/company.htm
# 		Using boilerplate
# Working on Sumitomo Electric Device Innovations
# 	Working on http://www.sedi.co.jp/about/index.html?version=en
# 		Using boilerplate
# Working on UChicago Argonne
# 	Working on http://uchicagoargonnellc.org/about/
# 		Using boilerplate
# Working on Theraclone Sciences
# 	Working on http://theraclone-sciences.com/about.php
# 		Using boilerplate
# Working on SolAero Technologies Corp.
# 	Working on https://solaerotech.com/about-us/
# 		Using boilerplate
# 	Working on https://solaerotech.com/about-us/our-facilities/
# 		Using clnd_text
# Working on EMD Technologies Inc.
# 	Working on https://emd-technologies.com/about-emd/
# 		Using boilerplate
# Working on Cool Planet Energy Systems
# 	Working on https://www.coolplanet.com/about/corporate/
# 		Using clnd_text
# Working on Amicus Therapeutics
# 	Working on https://www.amicusrx.com/about-us/
# 		Using clnd_text
# 	Working on https://www.amicusrx.com/about-us/belief-statement/
# 		Using clnd_text
# Working on Renewable Power Conversion
# 	Working on http://rpcincorporated.com/about-rpc.html
# 		Using boilerplate
# Working on Teledyne Scientific & Imaging
# 	Working on http://www.teledyne-si.com/company-information
# 		Using clnd_text
# 	Working on http://www.teledyne-si.com/company-information/about-us
# 		Using clnd_text
# Working on Gilead Connecticut
# 	Working on http://gileadcs.org/who-we-are/
# 		Using clnd_text
# 	Working on http://gileadcs.org/who-we-are/mission-vision-values/
# 		Using clnd_text
# Working on SunEdison
# 	Working on http://sunedison.com/index.html
# 		Using boilerplate
# Working on Alcon Research
# 	Working on https://www.alcon.com/about-us
# 		Using clnd_text
# 	Working on https://www.alcon.com/about-us/who-we-are
# 		Using clnd_text
# 	Working on https://www.alcon.com/about-us/who-we-are/mission-and-values
# 		Using clnd_text
# 	Working on https://www.alcon.com/careers/culture-values
# 		Using boilerplate
# Working on DNA Twopointo
# 	Working on https://www.atum.bio/company
# 		Using boilerplate
# 	Working on https://www.atum.bio/company?mi=82
# 		Using boilerplate
# 	Working on https://www.atum.bio/company?mi=6454
# 		Using boilerplate
# Working on GLYCON LLC
# 	Working on http://www.glycon.com/history
# 		Using boilerplate
# Working on Lattice Semiconductor Corporation
# 	Working on http://www.latticesemi.com/About
# 		Using clnd_text
# 	Working on http://www.latticesemi.com/About/Sitemap
# 		Using clnd_text
# 	Working on https://www.latticesemi.com/About
# 		Using clnd_text
# Working on Microchips Biotech
# 	Working on http://microchipsbiotech.com/about.php
# 		Using boilerplate
# Working on Northwest Biotherapeutics
# 	Working on https://nwbio.com/about-us/
# 		Using boilerplate
# Working on Dresser-Rand Company
# 	Working on http://dresser-rand.com/company/
# 		Using clnd_text
# 	Working on http://dresser-rand.com/company/about-us/
# 		Using clnd_text
# Working on Delphi Technologies
# 	Working on https://www.delphi.com/company
# 		Using boilerplate
# 	Working on https://www.delphi.com/company/vision-and-values
# 		Using boilerplate
# Working on New England Biolabs
# 	Working on https://www.neb.com/research
# 		Using clnd_text
# 	Working on https://www.neb.com/about-neb
# 		Using clnd_text
# 	Working on https://www.neb.com/about-neb/neb-overview
# 		Using boilerplate
# Working on nanoComposix
# 	Working on https://nanocomposix.com/pages/about-us
# 		Using boilerplate
# Working on Sienna Biopharmaceuticals
# 	Working on https://siennabio.com/company/overview/
# 		Using clnd_text
# 	Working on https://siennabio.com/company/corporate-advisors/
# 		Using clnd_text
# 	Working on https://investors.siennabio.com/corporate-governance
# 		Using clnd_text
# Working on Agilent Technologies
# 	Working on https://www.agilent.com/about/workingwa/index.html
# 		Using clnd_text
# 	Working on https://www.agilent.com/about/companyinfo/index.html
# 		Using boilerplate
# 	Working on https://www.agilent.com/about/features/raman-spectroscopy.html
# 		Using boilerplate
# Working on S&S X-Ray Products
#  empty
# 	Couldn't find any urls for firm!
# Working on Apple Inc.
# 	Couldn't find any urls for firm!
# Working on WestPoint Home
# 	Working on https://www.westpointhome.com/about-us.html
# 		Using boilerplate
# Working on FLOW CONTROL LLC.
# 	Working on https://www.flowcontrol.com/about.html
# 		Using boilerplate
# Working on Schneider Electric USA
# 	Working on https://www.schneider-electric.us/en/about-us/
# 		Using clnd_text
# 	Working on https://www.schneider-electric.us/en/about-us/company-profile/
# 		Using clnd_text
# Working on Takeda Pharmaceutical Company Limited
# 	Working on https://www.takeda.com/who-we-are/
# 		Using clnd_text
# 	Working on https://www.takeda.com/who-we-are/company-information/
# 		Using boilerplate
# 	Working on https://www.takeda.com/who-we-are/corporate-governance/
# 		Using boilerplate
# 	Working on https://www.takeda.com/who-we-are/corporate-philosophy/
# 		Using boilerplate
# Working on Clearside Biomedical
# 	Working on http://www.clearsidebio.com/aboutus.htm
# 		Using clnd_text
# Working on Abengoa Bioenergy New Technologies
# 	Working on http://www.abengoa.com/web/en/compania/index.html
# 		Using clnd_text
# Working on Microsemi SoC Corporation
# 	Working on https://www.microsemi.com/company/awards
# 		Using clnd_text
# 	Working on https://www.microsemi.com/company/quality
# 		Using clnd_text
# 	Working on https://www.microsemi.com/company/about-us
# 		Using clnd_text
# 	Working on https://www.microsemi.com/company/technology
# 		Using boilerplate
# Working on ADVANCED INNOVATION CENTER LLC
# 	Working on http://aicchile.com/en/nosotros/
# 		Using clnd_text
# Working on Sinton Consulting
# 	Working on https://www.sintoninstruments.com/about-sinton-instruments/
# 		Using boilerplate
# Working on OSI Optoelectronics
# 	Couldn't find any urls for firm!
# Working on RenovaCare Sciences Corp.
# 	Working on https://www.renovacareinc.com/about/
# 		Using boilerplate
# Working on Unistrut International Corp.
# 	Working on https://unistrut.us/about
# 		Using clnd_text
# Working on Midori USA
# 	Couldn't find any urls for firm!
# Working on Pioneer Energy
# 	Working on http://mypioneerenergy.com/about-us.aspx
# 		Using boilerplate
# Working on Pansonic Corporation
#  empty
# 	Couldn't find any urls for firm!
# Working on Bird-B-Gone
# 	Working on https://www.birdbgone.com/about/
# 		Using boilerplate
# Working on Amtech Systems
# 	Working on http://amtechsystems.com/profile.htm
# 		Using boilerplate
# Working on Ansun Biopharma
# 	Working on http://www.ansunbiopharma.com/about-ansun-biopharma/
# 		Using boilerplate
# Working on Bayer Cropscience AG
# 	Couldn't find any urls for firm!
# Working on Teradata US
# 	Working on https://www.teradata.com.au/About-Us
# 		Using boilerplate
# 	Working on https://www.teradata.com.au/About-Us/Awards
# 		Using boilerplate
# 	Working on https://www.teradata.com.au/About-Us/Our-History
# 		Using boilerplate
# 	Working on https://www.teradata.com.au/About-Us/Corporate-Governance
# 		Using clnd_text
# 	Working on https://www.teradata.com.au/About-Us/Corporate-Social-Responsibility
# 		Using boilerplate
# Working on DRS Network & Imaging Systems
# 	Working on https://www.leonardodrs.com/about-us/
# 		Using boilerplate
# 	Working on https://www.leonardodrs.com/about-us/ethics/
# 		Using boilerplate
# 	Working on https://www.leonardodrs.com/about-us/our-structure/
# 		Using clnd_text
# 	Working on https://www.leonardodrs.com/about-us/thought-leadership/
# 		Using clnd_text
# Working on Tela Innovations
# 	Working on http://www.tela-inc.com/company-overview/
# 		Using boilerplate
# Working on Elwha LLC
# 	Working on https://www.elwha.org/culture-history/stories/
# 		Using clnd_text
# 	Working on https://www.elwha.org/culture-history/lifestyle/
# 		Using clnd_text
# 	Working on https://www.elwha.org/culture-history/tse-whit-zen/
# 		Using boilerplate
# 	Working on https://www.elwha.org/culture-history/boston-charlie/
# 		Using clnd_text
# 	Working on https://www.elwha.org/culture-history/current-status/
# 		Using clnd_text
# 	Working on https://www.elwha.org/culture-history/klallam-language/
# 		Using boilerplate
# 	Working on https://www.elwha.org/culture-history/traditional-values/
# 		Using boilerplate
# 	Working on https://www.elwha.org/culture-history/culture-and-beliefs/
# 		Using boilerplate
# 	Working on https://www.elwha.org/culture-history/longhouse-structures/
# 		Using boilerplate
# Working on SEEK THERMAL
# 	Working on https://www.thermal.com/about.html
# 		Using boilerplate
# Working on Nederlandse Organisatie voor toegepast-natuurwetenschappelijk onderzoek TNO
# 	Working on https://www.tno.nl/en/about-tno/
# 		Using clnd_text
# 	Working on https://www.tno.nl/en/about-tno/organisation/
# 		Using clnd_text
# 	Working on https://www.tno.nl/en/about-tno/more-about-our-work/
# 		Using clnd_text
# 	Working on https://www.tno.nl/en/about-tno/mission-and-strategy/
# 		Using clnd_text
# Working on GOSOLARLIFE
# 	Working on http://www.gosolarlife.com/about-us.aspx
# 		Using clnd_text
# Working on Christie Digital Systems
# 	Working on https://www.christiedigital.com/en-us/about-christie
# 		Using boilerplate
# Working on J. E. WHITE
# 	Couldn't find any urls for firm!
# Working on Yeda Research and Development Co.
# 	Working on http://yedarnd.com/Overview
# 		Using clnd_text
# Working on KOLO TECHNOLOGIES
# 	Working on http://kolomedical.com/about.html
# 		Using boilerplate
# Working on Ricoh Company Limited
# 	Working on https://www.ricoh.com/about/
# 		Using clnd_text
# 	Working on https://www.ricoh.com/about/company/data/
# 		Using clnd_text
# 	Working on https://www.ricoh.com/about/company/global/
# 		Using clnd_text
# 	Working on https://www.ricoh.com/about/company/history/
# 		Using boilerplate
# 	Working on https://www.ricoh.com/about/company/business/
# 		Using clnd_text
# 	Working on https://www.ricoh.com/about/company/ataglance/
# 		Using clnd_text
# Working on Shell Oil Company
# 	Working on https://www.shell.us/about-us.html
# 		Using clnd_text
# 	Working on https://www.shell.us/motorist/shell-fuels/ask-shell-about-fuels.html
# 		Using clnd_text
# Working on GENERAL MOTORS LLC
# 	Working on https://www.gm.com/our-company/about-gm.html
# 		Using boilerplate
# Working on SOL-ELECTRICA
# 	Working on http://sol-electrica.com/about_sere_sol_electrica.htm
# 		Using boilerplate
# Working on Semiconductor Energy Laboratory Co.
# 	Working on http://www.sel.co.jp/en/corporate/index.html
# 		Using boilerplate
# 	Working on http://www.sel.co.jp/en/corporate/access.html
# 		Using boilerplate
# Working on Markel Corporation
# 	Working on https://www.markelcorp.com/about-markel
# 		Using clnd_text
# 	Working on https://www.markelcorp.com/about-markel/markel-style
# 		Using clnd_text
# Working on Andritz Inc.
# 	Working on https://www.andritz.com/group-en/about-us
# 		Using clnd_text
# 	Working on https://www.andritz.com/group-en/about-us/gr-quality
# 		Using boilerplate
# 	Working on https://www.andritz.com/group-en/about-us/gr-history
# 		Using boilerplate
# 	Working on https://www.andritz.com/group-en/about-us/gr-manufacturing
# 		Using boilerplate
# Working on Kureha Corporation
# 	Working on http://www.kureha.co.jp/en/about/index.html
# 		Using clnd_text
# Working on SABIC GLOBAL TECHNOLOGIES B.V.
# 	Working on https://www.sabic.com/en/about
# 		Using boilerplate
# 	Working on https://www.sabic.com/en/about/ehss
# 		Using clnd_text
# 	Working on https://www.sabic.com/en/about/our-brand
# 		Using clnd_text
# 	Working on https://www.sabic.com/en/about/our-vision
# 		Using clnd_text
# Working on NeoVision LLC
# 	Working on https://www.neovisiongroup.com/about.html
# 		Using clnd_text
# 	Working on https://www.neovisiongroup.com/about/contact-us.html
# 		Using clnd_text
# 	Working on https://www.neovisiongroup.com/about/why-buy-from-us.html
# 		Using boilerplate
# 	Working on https://www.neovisiongroup.com/about/meet-our-doctors.html
# 		Using boilerplate
# 	Working on https://www.neovisiongroup.com/eye-health/vision-conditions.html
# 		Using boilerplate
# Working on Coriant Advanced Technology
# 	Working on https://www.coriant.com/company
# 		Using boilerplate
# Working on TRI ALPHA ENERGY
# 	Working on https://tae.com/company/
# 		Using boilerplate
# 	Working on https://tae.com/company/collaborators/
# 		Using clnd_text
# Working on Pulse Therapeutics
# 	Working on https://www.pulsetherapeutics.com/about/
# 		Using clnd_text
# Working on Longhorn Vaccines and Diagnostics
# 	Working on https://www.lhnvd.com/about
# 		Using boilerplate
# Working on O.B.I. Inc.
# 	Working on https://obi.org/about-us/
# 		Using boilerplate
# 	Working on https://obi.org/about-us/newsroom/
# 		Using boilerplate
# 	Working on https://obi.org/about-us/share-your-story/
# 		Using clnd_text
# 	Working on https://obi.org/about-us/events-promotions/
# 		Using boilerplate
# 	Working on https://obi.org/about-us/life-saving-stories/
# 		Using boilerplate
# 	Working on https://obi.org/about-us/newsroom/ou-wins-bedlam-blood-battle/2125/
# 		Using boilerplate
# 	Working on https://obi.org/about-us/events-promotions/feel-good-give-globally/603
# 		Using clnd_text
# Working on The Babcock & Wilcox Company
# 	Working on https://www.babcock.com/en/about
# 		Using clnd_text
# Working on Bell Helicopter Textron Inc.
# 	Working on http://bellflight.com/company
# 		Using clnd_text
# 	Working on http://bellflight.com/company/certificates
# 		Using clnd_text
# 	Working on http://bellflight.com/company/innovation/APT
# 		Using clnd_text
# Working on L-3 Communications Cincinnati Electronics Corporation
# 	Working on https://cinele.com/about/index.htm
# 		Using boilerplate
# Working on Pixelligent Technologies
# 	Working on https://pixelligent.com/our-company/
# 		Using boilerplate
# 	Working on https://www.pixelligent.com/our-company/
# 		Using boilerplate
# Working on Advanced Silicon Group
# 	Couldn't find any urls for firm!
# Working on Kaneka Corporation
# 	Working on http://www.kaneka.co.jp/en/corporate/
# 		Using clnd_text
# 	Working on http://www.kaneka.co.jp/en/corporate/director/
# 		Using clnd_text
# Working on Nutech Ventures
# 	Working on http://www.nutechventures.org/about-us/
# 		Using clnd_text
# Working on Sun Chemical Corporation
# 	Working on https://www.sunchemical.com/about/
# 		Using boilerplate
# 	Working on https://www.sunchemical.com/about/research-and-development/
# 		Using clnd_text
# 	Working on https://www.sunchemical.com/200-years/
# 		Using boilerplate
# Working on CoolEarth Solar
#  empty
# 	Couldn't find any urls for firm!
# Working on Industrial Technology Research Institute
# 	Working on https://www.itri.org.tw/eng/Content/Messagess/contents.aspx?SiteID=1&MmmID=617731521661672477
# 		Using clnd_text
# Working on Arrowhead Center
# 	Working on http://arrowheadcenter.nmsu.edu/our-team/
# 		Using boilerplate
# Working on SanDisk Technologies LLC
# 	Working on https://www.sandisk.com/about
# 		Using clnd_text
# Working on Sanuvox Technologies
# 	Working on https://sanuvox.com/about-us/
# 		Using clnd_text
# Working on DECA Technologies Inc.
# 	Working on http://www.decatechnologies.com/about-us/
# 		Using boilerplate
# 	Working on http://www.decatechnologies.com/deca-technologies-transforming-electronic-interconnect/decas-wlcsp-its-about-time/
# 		Using boilerplate
# Working on Schlumberger Technology Corporation
# 	Working on https://www.slb.com/about.aspx
# 		Using clnd_text
# 	Working on https://www.slb.com/about/rd.aspx
# 		Using clnd_text
# 	Working on https://www.slb.com/about/who.aspx
# 		Using clnd_text
# 	Working on https://www.slb.com/about/history.aspx
# 		Using clnd_text
# 	Working on https://www.slb.com/about/rd/research.aspx
# 		Using clnd_text
# Working on Xyleco
#  empty
# 	Couldn't find any urls for firm!
# Working on Cornell Research Foundation
# 	Working on http://www.cornell.edu/about/
# 		Using boilerplate
# 	Working on http://www.cornell.edu/about/maps/
# 		Using clnd_text
# 	Working on http://www.cornell.edu/about/facts.cfm
# 		Using boilerplate
# 	Working on http://www.cornell.edu/about/mission.cfm
# 		Using clnd_text
# 	Working on http://www.cornell.edu/about/traditions.cfm
# 		Using clnd_text
# 	Working on http://www.cornell.edu/about/locations/ithaca/
# 		Using clnd_text
# Working on Landauer
# 	Working on https://www.landauer.com/about
# 		Using boilerplate
# 	Working on https://www.landauer.com/history
# 		Using boilerplate
# Working on Hysitron Incorporated
# 	Working on https://www.hysitron.com/about-us
# 		Using boilerplate
# 	Working on https://www.hysitron.com/about-us/awards
# 		Using clnd_text
# Working on AVOGY
# 	Working on https://nexgenpowersystems.com/about/
# 		Using boilerplate
# Working on Allison Transmission
# 	Working on https://allisontransmission.com/company
# 		Using clnd_text
# 	Working on https://allisontransmission.com/company/about
# 		Using clnd_text
# 	Working on https://allisontransmission.com/company/centennial
# 		Using boilerplate
# 	Working on https://allisontransmission.com/careers/our-values
# 		Using clnd_text
# Working on Ambature
# 	Couldn't find any urls for firm!
# Working on Sandia Corporation
# 	Working on https://www.sandia.gov/about/60-ways/
# 		Using boilerplate
# 	Working on https://www.sandia.gov/about/index.html
# 		Using clnd_text
# 	Working on https://www.sandia.gov/about/history/index.html
# 		Using boilerplate
# 	Working on https://www.sandia.gov/about/mission/index.html
# 		Using clnd_text
# 	Working on https://www.sandia.gov/about/diversity/index.html
# 		Using boilerplate
# 	Working on https://www.sandia.gov/about/community/index.html
# 		Using clnd_text
# 	Working on https://www.sandia.gov/about/environment/index.html
# 		Using clnd_text
# 	Working on https://www.sandia.gov/about/facts_figures/index.html
# 		Using clnd_text
# Working on HIQ SOLAR
# 	Working on http://hiqsolar.com/contact-us.html
# 		Using clnd_text
# Working on Atrium Medical Corporation
# 	Working on http://www.atriummed.com/EN/About/default.asp
# 		Using boilerplate
# Working on Newlans
# 	Working on http://newlans.com/about.html
# 		Using boilerplate
# Working on NeoPhotonics Corporation
# 	Working on https://www.neophotonics.com/company/
# 		Using boilerplate
# 	Working on https://www.neophotonics.com/company-history/
# 		Using boilerplate
# Working on Grain Processing Corporation
# ...
# 		Using clnd_text
# 	Working on http://starsource.com/about/?33.html
# 		Using clnd_text
# Working on SAINT-GOBAIN ABRASIFS
# 	Working on https://www.saint-gobain-abrasives.com/en-us/about-us
# 		Using clnd_text
# 	Working on https://www.saint-gobain-abrasives.com/en-us/proud-our-history
# 		Using clnd_text
# Working on NGK Spark Plug Co.
# 	Working on http://ngksparkplugs.com/about-ngk
# 		Using clnd_text
# Working on Nova Technologies
# 	Working on https://novatechnologies.com/company.html
# 		Using clnd_text
# Working on Nikon Corporation
# 	Working on https://www.nikon.com/about/
# 		Using clnd_text
# 	Working on https://www.nikon.com/about/corporate/
# 		Using clnd_text
# 	Working on https://www.nikon.com/about/sp/universcale/
# 		Using clnd_text
# Working on MicroLink Devices
# 	Working on http://mldevices.com/index.php/company
# 		Using boilerplate
# 	Working on http://mldevices.com/index.php/company/about-us
# 		Using boilerplate
# Working on One Earth Designs Inc.
# 	Working on https://www.oneearthdesigns.com/about-us/
# 		Using boilerplate
# Working on Genomic Health
# 	Working on https://www.genomichealth.com/en-US/who_we_are
# 		Using clnd_text
# 	Working on https://www.genomichealth.com/en-US/who_we_are/our_mission
# 		Using boilerplate
# 	Working on https://www.genomichealth.com/en-US/who_we_are/company_timeline_milestones
# 		Using boilerplate
# Working on Synthetic Genomics
# 	Working on https://www.syntheticgenomics.com/company/
# 		Using boilerplate
# Working on IMDS Corporation
# 	Working on http://imds-ohio.com/AboutUs/
# 		Using clnd_text
# 	Working on http://imds-ohio.com/AboutUs/Corp_Profile/
# 		Using boilerplate
# Working on New Technology Ventures
# 	Working on https://www.newtechvc.com/about.html
# 		Using boilerplate
# Working on JFE STEEL CORPORATION
# 	Working on http://www.jfe-steel.co.jp/en/movie/
# 		Using clnd_text
# 	Working on http://www.jfe-steel.co.jp/en/company/about.html
# 		Using clnd_text
# 	Working on http://www.jfe-steel.co.jp/en/company/index.html
# 		Using clnd_text
# 	Working on http://www.jfe-steel.co.jp/en/company/philosophy.html
# 		Using boilerplate
# Working on Tamura Corporation
# 	Working on http://tamuracorp.com/about/
# 		Using boilerplate
# 	Working on http://tamuracorp.com/about/tamura-america/
# 		Using clnd_text
# Working on Iogen Corporation
# 	Working on http://iogen.ca/about-iogen/index.html
# 		Using boilerplate
# Working on Baxter Healthcare SA
# 	Working on https://www.baxter.com/our-story
# 		Using clnd_text
# 	Working on https://www.baxter.com/our-story/our-history
# 		Using boilerplate
# Working on Sagacious Investment Group L.L.C.
# 	Working on http://www.sagaciousinvestmentservices.com/about-us22.html
# 		Using clnd_text
# Working on ARBOR THERAPEUTICS
# 	Couldn't find any urls for firm!
# Working on Wostec
# 	Working on https://www.westec.org/about.html
# 		Using clnd_text
# Working on The Charles Stark Draper Laboratory
# 	Working on https://www.draper.com/about
# 		Using boilerplate
# Working on Hon Hai Precision Industry Co.
# 	Couldn't find any urls for firm!
# Working on LG Display Co.
# 	Working on http://lgdisplay.com/eng/company/vision
# 		Using clnd_text
# 	Working on http://lgdisplay.com/eng/company/history
# 		Using boilerplate
# 	Working on http://lgdisplay.com/eng/company/overview
# 		Using clnd_text
# Working on ATC Technologies
# 	Working on http://atctechnologiesinc.com/AboutUs.html
# 		Using boilerplate
# Working on Canon U.S. Life Sciences
# 	Couldn't find any urls for firm!
# Working on HM3 Energy
# 	Working on http://hm3energy.com/about/
# 		Using clnd_text
# 	Working on http://hm3energy.com/about/hm3-energy-achievements/
# 		Using boilerplate
# Working on GlassPoint Solar
# 	Working on https://www.glasspoint.com/about-us/
# 		Using boilerplate
# Working on Renesas Electronics Corporation
# 	Working on https://www.renesas.com/us/en/about/company.html
# 		Using clnd_text
# 	Working on https://www.renesas.com/us/en/about/ir/financial.html
# 		Using clnd_text
# 	Working on https://www.renesas.com/us/en/about/company/profile.html
# 		Using clnd_text
# Working on Dell Software Inc.
# 	Working on https://www.quest.com/company/
# 		Using boilerplate
# Working on Taiwan Semiconductor Manufacturing Company
# 	Working on https://tsmc.com/english/aboutTSMC/company_profile.htm
# 		Using clnd_text
# Working on U.S. NUTRACEUTICALS
# 	Working on https://www.nutraceutical.com/company/
# 		Using clnd_text
# 	Working on https://www.nutraceutical.com/company/ethics/
# 		Using boilerplate
# 	Working on https://www.nutraceutical.com/company/vision/
# 		Using clnd_text
# 	Working on https://www.nutraceutical.com/company/history/
# 		Using clnd_text
# 	Working on https://www.nutraceutical.com/company/employees/
# 		Using clnd_text
# Working on PAX Scientific
# 	Working on http://paxscientific.com/history/
# 		Using boilerplate
# Working on Sanken Electric Co.
# 	Working on https://www.sanken-ele.co.jp/en/corp/index.htm
# 		Using clnd_text
# 	Working on https://www.sanken-ele.co.jp/en/corp/corp08.htm
# 		Using boilerplate
# Working on ACACIA RESEARCH GROUP LLC
# 	Working on http://acaciaresearch.com/corporate-profile/
# 		Using clnd_text
# Working on NCC Nano
# 	Working on https://www.novacentrix.com/about_us
# 		Using boilerplate
# Working on mVerify Corporation
# 	Working on https://numverify.com/about
# 		Using boilerplate
# Working on Wine.com
# 	Working on https://www.wine.com/content/about-us/home
# 		Using clnd_text
# Working on Delta Electronics
# 	Working on http://www.deltaww.com/about/company.aspx?secID=5&pid=0&tid=0&hl=en-US
# 		Using boilerplate
# 	Working on http://www.deltaww.com/about/milestone.aspx?secID=5&pid=5&tid=0&hl=en-US
# 		Using clnd_text
# 	Working on http://www.deltaww.com/about/innovation2.aspx?secID=5&pid=4&tid=0&hl=en-US
# 		Using boilerplate
# Working on Vizio Inc.
# 	Working on https://www.vizio.com/about
# 		Using clnd_text
# Working on GENCO SCIENCES LLC
# 	Working on https://www.gpen.com/pages/about
# 		Using clnd_text
# Working on Rima Enterprises
#  empty
# 	Couldn't find any urls for firm!
# Working on Plasma-Therm
# 	Couldn't find any urls for firm!
# Working on AstenJohnson
# 	Working on https://www.astenjohnson.com/about/
# 		Using boilerplate
# 	Working on https://www.astenjohnson.com/about/history/
# 		Using clnd_text
# 	Working on https://www.astenjohnson.com/about/our-companies/
# 		Using clnd_text
# Working on Braun Intertec Geothermal
# 	Working on https://braunintertec.com/about-us/
# 		Using boilerplate
# 	Working on https://braunintertec.com/about-us/awards/
# 		Using boilerplate
# 	Working on https://braunintertec.com/about-us/history/
# 		Using boilerplate
# Working on Nanosys
# 	Working on http://www.nanosysinc.com/who-we-are
# 		Using boilerplate
# 	Working on http://www.nanosysinc.com/who-we-are/
# 		Using boilerplate
# Working on TMC Corporation
# 	Working on http://www.tcm.com/my-profile/index.html
# 		Using boilerplate
# Working on Banpil Photonics
# 	Working on http://banpil.com/vmv.htm
# 		Using clnd_text
# Working on Forest Concepts
# 	Working on http://forestconcepts.com/index.php?page=5000
# 		Using clnd_text
# 	Working on http://forestconcepts.com/index.php?page=05004
# 		Using boilerplate
# 	Working on http://forestconcepts.com/index.php?page=01000
# 		Using clnd_text
# Working on iBio
# 	Working on https://ibioinc.com/index.php/company-background/disclaimer
# 		Using boilerplate
# 	Working on https://ibioinc.com/index.php/company-background/company-background-2
# 		Using clnd_text
# Working on GE Healthcare Dharmacon
# 	Working on https://dharmacon.horizondiscovery.com/about-us/
# 		Using clnd_text
# 	Working on https://dharmacon.horizondiscovery.com/about-us/about-open-biosystems/
# 		Using clnd_text
# 	Working on https://dharmacon.horizondiscovery.com/about-us/genomics-discovery-initiative/
# 		Using boilerplate
# Working on CNH Industrial America LLC
# 	Working on http://cnhindustrial.com/en-us/know_us/who_we_are/Pages/default.aspx
# 		Using clnd_text
# 	Working on http://www.cnhindustrial.com/en-us/know_us/who_we_are/Pages/our_history.aspx
# 		Using boilerplate
# Working on HARMAN INTERNATIONAL INDUSTRIES
# 	Working on https://www.harman.com/company
# 		Using boilerplate
# Working on PNM
# 	Working on https://WWW.PNM.COM/web/pnm.com/about-pnm
# 		Using boilerplate
# Working on STANDARD ALCOHOL COMPANY OF AMERICA
# 	Couldn't find any urls for firm!
# Working on Guardian Industries
# 	Working on https://www.guardian.com/en/about_us/a.html
# 		Using boilerplate
# 	Working on https://www.guardian.com/en/about_us/introduction.html
# 		Using boilerplate
# Working on Pacific Industrial Development Corporation
# 	Working on http://pidc.com/our-company/corporate-overview
# 		Using clnd_text
# Working on NLT TECHNOLOGIES
# 	Working on https://www.tianma.co.jp/en/profile/index.html
# 		Using clnd_text
# 	Working on https://www.tianma.co.jp/en/profile/quality_management.html
# 		Using clnd_text
# 	Working on https://www.tianma.co.jp/en/profile/environment_management.html
# 		Using clnd_text
# Working on Intellectual Keystone Technology LLC
# 	Working on http://ikt.us.com/about-us.html
# 		Using boilerplate
# Working on GOJO Industries
# 	Working on http://gojo.com/en/About-GOJO?sc_lang=en
# 		Using clnd_text
# 	Working on http://gojo.com/en/About-GOJO/History?sc_lang=en
# 		Using boilerplate
# Working on Solan
# 	Working on https://www.salon.com/about
# 		Using boilerplate
# 	Working on https://www.salon.com/about/
# 		Using boilerplate
# 	Working on https://www.salon.com/2018/12/02/cnn-keeps-letting-guests-and-paid-commentators-lie-about-climate-scientists_partner/
# 		Using boilerplate
# Working on Areesys Technologies
# 	Working on http://areesys.com/index.php/2013-04-17-17-15-27/2013-04-17-17-23-07
# 		Using clnd_text
# Working on Global Solar Water Power Systems
# 	Working on http://gswps.com/AboutUs.aspx
# 		Using boilerplate
# Working on Vascular BioSciences
# 	Working on http://vascularbiosciences.com/about-vbs/
# 		Using clnd_text
# Working on Nanoholdings
# 	Working on https://www.nh2.com/about
# 		Using boilerplate
# Working on Kulite Semiconductor Products
# 	Working on https://www.kulite.com/company/history/
# 		Using boilerplate
# Working on Bend Research
# 	Working on https://www.capsugel.com/about-capsugel
# 		Using clnd_text
# 	Working on https://www.capsugel.com/now-a-lonza-company
# 		Using clnd_text
# Working on Easel Biotechnologies
# 	Working on http://www.easelbio.com/about/
# 		Using boilerplate
# Working on Silicon Genesis Corporation
# 	Working on http://sigen.net/about_sigen_overview.html
# 		Using clnd_text
# 	Working on http://sigen.net/about_sigen_positions.html
# 		Using clnd_text
# Working on Evoqua Water Technologies LLC
# 	Working on http://evoqua.com/en/about
# 		Using clnd_text
# 	Couldn't find any text for firm!
# Working on Revivicor
# 	Working on http://revivicor.com/about.html
# 		Using boilerplate
# Working on Abbott Molecular Inc.
# 	Working on https://www.molecular.abbott/us/en/about-us/who-we-are
# 		Using boilerplate
# Working on Crystal Solar Inc.
# 	Working on http://xtalsolar.com/company.html
# 		Using boilerplate
# Working on Stablcor Technology
# 	Couldn't find any urls for firm!
# Working on NanoTech Lubricants
# 	Working on http://nanotechlubricantsinc.com/Home.html
# 		Using boilerplate
# Working on Zygo Corporation
# 	Couldn't find any urls for firm!
# Working on 3M Innovative Properties Company
# 	Working on https://www.3m.com/3M/en_US/company-us/about-3m/
# 		Using boilerplate
# Working on MATERIALS ANALYSIS TECHNOLOGY (US) CORP.
# 	Working on http://www.ma-tek.com/about_us.php?act=rd
# 		Using boilerplate
# 	Working on http://www.ma-tek.com/about_us.php?act=partne
# 		Using clnd_text
# 	Working on http://www.ma-tek.com/about_us.php?act=history
# 		Using clnd_text
# 	Working on http://www.ma-tek.com/about_us.php?act=quality
# 		Using clnd_text
# 	Working on http://www.ma-tek.com/about_us.php?act=customer
# 		Using clnd_text
# 	Working on http://www.ma-tek.com/about_us.php?act=business
# 		Using clnd_text
# 	Working on http://www.ma-tek.com/about_us.php?act=glorious
# 		Using clnd_text
# Working on KYOCERA DOCUMENT SOLUTIONS INC.
# 	Working on https://www.kyoceradocumentsolutions.com/company/
# 		Using clnd_text
# 	Working on https://www.kyoceradocumentsolutions.com/company/profile.html
# 		Using clnd_text
# Working on Biotechnology Foundation
# 	Working on https://cabiotech.org/about/
# 		Using boilerplate
# 	Working on https://cabiotech.org/about/our-value/
# 		Using boilerplate
# Working on Boston Scientific Scimed
# 	Working on http://www.bostonscientific.com/en-US/about-us.html
# 		Using clnd_text
# 	Working on http://www.bostonscientific.com/en-US/about-us/awards.html
# 		Using boilerplate
# 	Working on http://www.bostonscientific.com/en-US/about-us/history.html
# 		Using clnd_text
# 	Working on http://www.bostonscientific.com/en-US/about-us/who-we-are.html
# 		Using clnd_text
# Working on Quantapore
#  empty
# 	Couldn't find any urls for firm!
# Working on GOAL ZERO LLC
# 	Working on https://www.goalzero.com/story/
# 		Using boilerplate
# Working on Atonometrics
# 	Working on http://www.atonometrics.com/about/
# 		Using clnd_text
# Working on Ampio Pharmaceuticals
# 	Working on https://ampiopharma.com/about-us/
# 		Using boilerplate
# 	Working on http://ampiopharma.com/pipeline/optina/
# 		Using boilerplate
# 	Working on http://ampiopharma.com/pipeline/ampion/
# 		Using clnd_text
# 	Working on https://ampiopharma.com/pipeline/about-osteoarthritis/
# 		Using boilerplate
# 	Working on https://ampiopharma.com/pipeline/about-diabetic-macular-edema/
# 		Using boilerplate
# Working on GED Intergrated Solution
# 	Working on http://www.gedusa.com/company/
# 		Using clnd_text
# 	Working on http://www.gedusa.com/company/history/
# 		Using boilerplate
# 	Working on http://www.gedusa.com/company/key-messaging/
# 		Using boilerplate
# Working on Sharp Laboratories of America
# 	Working on http://www.sharplabs.com/index.php/about-sla/history
# 		Using boilerplate
# 	Working on http://www.sharplabs.com/index.php/about-sla/overview
# 		Using boilerplate
# Working on AgroFresh Inc.
# 	Working on https://www.agrofresh.com/about-us/
# 		Using boilerplate
# 	Working on https://www.agrofresh.com/about-us/history/
# 		Using boilerplate
# 	Working on https://www.agrofresh.com/about-us/at-a-glance/
# 		Using clnd_text
# 	Working on https://www.agrofresh.com/about-us/r-and-d-centers/
# 		Using boilerplate
# 	Working on https://www.agrofresh.com/about-us/smarter-freshness/
# 		Using boilerplate
# Working on Samsung Electronics
# 	Working on https://www.samsung.com/us/aboutsamsung/home/
# 		Using boilerplate
# 	Working on https://www.samsung.com/us/aboutsamsung/rss/rssFeedList.do
# 		Using clnd_text
# Working on Research Triangle Institute
# 	Working on https://www.rti.org/about-us
# 		Using boilerplate
# Working on Biological Dynamics
# 	Couldn't find any urls for firm!
# Working on Kemira OY
# 	Working on https://www.kemira.com/company/
# 		Using boilerplate
# Working on Saint-Gobain Ceramics & Plastics
# 	Working on https://www.ceramicmaterials.saint-gobain.com/history
# 		Using boilerplate
# Working on Seagate Technology LLC
# 	Working on https://www.seagate.com/our-story/
# 		Using boilerplate
# Working on MILLENIUM SYNTHFUELS CORPORATION
# 	Working on http://milleniumsynthfuels.com/about/
# 		Using boilerplate
# Working on Inphenix
# 	Working on https://www.inphenix.com/en/about-us/
# 		Using boilerplate
# Working on Gram Power
# 	Working on https://grampower.com/about-us/join-us.html
# 		Using boilerplate
# 	Working on https://grampower.com/about-us/about-us.html
# 		Using boilerplate
# 	Working on https://grampower.com/about-us/our-team.html
# 		Using boilerplate
# Working on Bluestar Silicones France
# 	Working on https://silicones.elkem.com/EN/about-us
# 		Using boilerplate
# 	Working on https://silicones.elkem.com:443/EN/company/About_Us/Pages/home.aspx
# 		Using boilerplate
# 	Working on https://silicones.elkem.com/EN/company/About_Us/Pages/Our-values.aspx
# 		Using clnd_text
# 	Working on https://silicones.elkem.com/EN/company/Lists/Event_company/Dispform.aspx?ID=149
# 		Using boilerplate
# 	Working on https://silicones.elkem.com/EN/company/Lists/Event_company/Dispform.aspx?ID=152
# 		Using boilerplate
# 	Working on https://silicones.elkem.com/EN/company/Lists/Event_company/Dispform.aspx?ID=151
# 		Using boilerplate
# Working on Entech Solar
#  empty
# 	Couldn't find any urls for firm!
# Working on Valicor
# 	Couldn't find any urls for firm!
# Working on Novon
# 	Working on http://novon.com/about.htm
# 		Using boilerplate
# Working on FRONT EDGE TECHNOLOGY INC.
# 	Working on http://frontedgetechnology.com/about.htm
# 		Using boilerplate

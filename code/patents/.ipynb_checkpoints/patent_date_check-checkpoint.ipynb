# %%
! pip install cdindex
# Out:
# Requirement already satisfied: cdindex in /Users/Sanjay.K.Arora/opt/anaconda3/envs/36/lib/python3.6/site-packages (1.0.19)
# Requirement already satisfied: future in /Users/Sanjay.K.Arora/opt/anaconda3/envs/36/lib/python3.6/site-packages (from cdindex) (0.18.2)

# %%
import urllib.request
import cdindex
import zipfile
import requests, zipfile, io
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# %% [markdown]
# ## CDIndex on Latest PatentView Data

# %% [markdown]
# ### Test

# %%
# dummy vertices for python module tests
pyvertices= [{"name": "0Z", "time": datetime(1992, 1, 1)},
				{"name": "1Z", "time": datetime(1992, 1, 1)},
				{"name": "2Z", "time": datetime(1993, 1, 1)},
				{"name": "3Z", "time": datetime(1993, 1, 1)},
				{"name": "4Z", "time": datetime(1995, 1, 1)},
				{"name": "5Z", "time": datetime(1997, 1, 1)},
				{"name": "6Z", "time": datetime(1998, 1, 1)},
				{"name": "7Z", "time": datetime(1999, 1, 1)},
				{"name": "8Z", "time": datetime(1999, 1, 1)},
				{"name": "9Z", "time": datetime(1998, 1, 1)},
				{"name": "10Z", "time": datetime(1997, 1, 1)}]

# dummy edges for python module tests
pyedges = [{"source": "4Z", "target": "2Z"},
				{"source": "4Z", "target": "0Z"},
				{"source": "4Z", "target": "1Z"},
				{"source": "4Z", "target": "3Z"},
				{"source": "5Z", "target": "2Z"},
				{"source": "6Z", "target": "2Z"},
				{"source": "6Z", "target": "4Z"},
				{"source": "7Z", "target": "4Z"},
				{"source": "8Z", "target": "4Z"},
				{"source": "9Z", "target": "4Z"},
				{"source": "9Z", "target": "1Z"},
				{"source": "9Z", "target": "3Z"},
				{"source": "10Z", "target": "4Z"}]


# create graph
graph = cdindex.Graph()

# add vertices
for vertex in pyvertices:
	graph.add_vertex(vertex["name"], cdindex.timestamp_from_datetime(vertex["time"]))

# add edges
for edge in pyedges:
	graph.add_edge(edge["source"], edge["target"])

# %%
print (graph.cdindex("4Z", int(timedelta(days=1825).total_seconds())))
print (graph.mcdindex("4Z", int(timedelta(days=1825).total_seconds())))
# Out:
# 0.16666666666666666
# 0.8333333333333333

# %% [markdown]
# ### Download Datasets

# %%
PATENT_ZIP_FILE = 'https://s3.amazonaws.com/data.patentsview.org/download/patent.tsv.zip'
CITATIONS_ZIP_FILE = 'https://s3.amazonaws.com/data.patentsview.org/download/uspatentcitation.tsv.zip'

def downloadAndExtract(url):
  r = requests.get(url)
  z = zipfile.ZipFile(io.BytesIO(r.content))
  z.extractall("HOME_DIR")

# %%
downloadAndExtract (PATENT_ZIP_FILE)

# %%
downloadAndExtract (CITATIONS_ZIP_FILE)

# %%
HOME_DIR = '//Users/Sanjay.K.Arora/data/web_of_innovation/'
PAT_FILE = HOME_DIR + 'patent.tsv'
CIT_FILE = HOME_DIR + 'uspatentcitation.tsv'

pat_df = pd.read_csv(PAT_FILE, sep='\t', dtype=str)
# cit_df = pd.read_csv(CIT_FILE, sep='\t', dtype=str)

# %%
# print dataframe contents
pat_df.head()
# Out:
#          id     type    number country        date  \
# 0  10000000  utility  10000000      US  2018-06-19
# 1  10000001  utility  10000001      US  2018-06-19
# 2  10000002  utility  10000002      US  2018-06-19
# 3  10000003  utility  10000003      US  2018-06-19
# 4  10000004  utility  10000004      US  2018-06-19
#
#                                             abstract  \
# 0  A frequency modulated (coherent) laser detecti...
# 1  The injection molding machine includes a fixed...
# 2  The present invention relates to: a method for...
# 3  The invention relates to a method for producin...
# 4  The present invention relates to provides a do...
#
#                                                title kind num_claims  \
# 0  Coherent LADAR using intra-pixel quadrature de...   B2         20
# 1  Injection molding machine and mold thickness c...   B2         12
# 2  Method for manufacturing polymer film and co-e...   B2          9
# 3  Method for producing a container from a thermo...   B2         18
# 4  Process of obtaining a double-oriented film, c...   B2          6
#
#         filename withdrawn
# 0  ipg180619.xml         0
# 1  ipg180619.xml         0
# 2  ipg180619.xml         0
# 3  ipg180619.xml         0
# 4  ipg180619.xml         0

# %%
# describe date
res = [datetime.strptime(dt, "%Y-%m-%d").strftime("%d-%m-%Y") for dt in pat_df.date]

# %%
pd.Series(res).max()
# Out:
# '31-12-2019'

# %%
cit_df.tail()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[61]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>uuid</th>
#       <th>patent_id</th>
#       <th>citation_id</th>
#       <th>date</th>
#       <th>name</th>
#       <th>kind</th>
#       <th>country</th>
#       <th>category</th>
#       <th>sequence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>117189467</th>
#       <td>zzzzwloy340w4xrnpngahtr6p</td>
#       <td>6289398</td>
#       <td>5412661</td>
#       <td>1995-05-01</td>
#       <td>Hao et al.</td>
#       <td>NaN</td>
#       <td>US</td>
#       <td>NaN</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>117189468</th>
#       <td>zzzzws5a59zyn06u1aotvayxj</td>
#       <td>9694946</td>
#       <td>3465908</td>
#       <td>1969-09-01</td>
#       <td>Acton</td>
#       <td>A</td>
#       <td>US</td>
#       <td>cited by applicant</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>117189469</th>
#       <td>zzzzycnb8175jpa3poze4fi4t</td>
#       <td>10835247</td>
#       <td>10064621</td>
#       <td>2018-09-01</td>
#       <td>Kerr et al.</td>
#       <td>B2</td>
#       <td>US</td>
#       <td>cited by applicant</td>
#       <td>4415</td>
#     </tr>
#     <tr>
#       <th>117189470</th>
#       <td>zzzzywzbtsvlits7lwa41ii63</td>
#       <td>8997525</td>
#       <td>3627504</td>
#       <td>1971-12-01</td>
#       <td>Johnson et al.</td>
#       <td>A</td>
#       <td>US</td>
#       <td>cited by applicant</td>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>117189471</th>
#       <td>zzzzzm8wuh09bvu6b069vlv8x</td>
#       <td>8789741</td>
#       <td>7336184</td>
#       <td>2008-02-01</td>
#       <td>Smith et al.</td>
#       <td>B2</td>
#       <td>US</td>
#       <td>cited by applicant</td>
#       <td>1173</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# print patent ids max length
print (pat_df.id.str.len().max())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">8
# </div>

# %%
# print patent ids max length
print(cit_df.patent_id.str.len().max())
print(cit_df.citation_id.str.len().max())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">8
# 15.0
# </div>

# %%
# length of citation id looks long. let's take a look
lengths = cit_df.citation_id.str.len()
argmax = np.where(lengths == lengths.max())[0]
cit_df.iloc[argmax]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[64]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>uuid</th>
#       <th>patent_id</th>
#       <th>citation_id</th>
#       <th>date</th>
#       <th>name</th>
#       <th>kind</th>
#       <th>country</th>
#       <th>category</th>
#       <th>sequence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>20014958</th>
#       <td>658pl0odzsfgfm4mche26h43l</td>
#       <td>4015716</td>
#       <td>341047419681100</td>
#       <td>NaN</td>
#       <td>217 53</td>
#       <td>NaN</td>
#       <td>US</td>
#       <td>NaN</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>61766402</th>
#       <td>iz0o18syv90w8jnti139cqoqh</td>
#       <td>6674859</td>
#       <td>PCT/US 96/16348</td>
#       <td>1996-11-01</td>
#       <td>NaN</td>
#       <td>B1</td>
#       <td>US</td>
#       <td>cited by other</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>75419156</th>
#       <td>n5zjqrtlu9p4jjfp2sdxasqly</td>
#       <td>6674859</td>
#       <td>PCT/US 93/08069</td>
#       <td>1991-06-01</td>
#       <td>NaN</td>
#       <td>B1</td>
#       <td>US</td>
#       <td>cited by other</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>75861054</th>
#       <td>navmooilzku8ceoqp3p94w6ce</td>
#       <td>6826645</td>
#       <td>PCT/US 01/43638</td>
#       <td>2001-11-01</td>
#       <td>NaN</td>
#       <td>A2</td>
#       <td>US</td>
#       <td>cited by other</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>106334846</th>
#       <td>wnydaf4cocs96nxhht0snw7s2</td>
#       <td>6572230</td>
#       <td>US-2001 0016695</td>
#       <td>2001-08-01</td>
#       <td>NaN</td>
#       <td>B1</td>
#       <td>US</td>
#       <td>cited by other</td>
#       <td>36</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### Filter
# Only retain those patents that are in the focal web of innovation panel or those that cite or were cited by the paeel

# %% [markdown]
# ### Load Graph

# %%
# create graph
graph = cdindex.Graph()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# create vertices
pat_vertices =[{"name": x, "time": datetime.fromisoformat(y)} for x, y in zip(pat_df['id'], pat_df['date'])]

# test out
pat_vertices[0:5]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[82]: [{&#39;name&#39;: &#39;10000000&#39;, &#39;time&#39;: datetime.datetime(2018, 6, 19, 0, 0)},
#  {&#39;name&#39;: &#39;10000001&#39;, &#39;time&#39;: datetime.datetime(2018, 6, 19, 0, 0)},
#  {&#39;name&#39;: &#39;10000002&#39;, &#39;time&#39;: datetime.datetime(2018, 6, 19, 0, 0)},
#  {&#39;name&#39;: &#39;10000003&#39;, &#39;time&#39;: datetime.datetime(2018, 6, 19, 0, 0)},
#  {&#39;name&#39;: &#39;10000004&#39;, &#39;time&#39;: datetime.datetime(2018, 6, 19, 0, 0)}]</div>

# %%
# add vertices to graph
for vertex in pat_vertices:
	graph.add_vertex(vertex["name"], cdindex.timestamp_from_datetime(vertex["time"]))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# create edges
cit_edges = [{"source": x, "target": y} for x, y in zip(cit_df['patent_id'], cit_df['citation_id'])]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
list(filter(lambda pat_vertices: pat_vertices['name'] == 'D809697', pat_vertices))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[88]: [{&#39;name&#39;: &#39;D809697&#39;, &#39;time&#39;: datetime.datetime(2018, 2, 6, 0, 0)}]</div>

# %%
'D809697' in list(graph.vertices())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[96]: True</div>

# %%
graph_vertices = list(graph.vertices())
# add edges
for edge in tqdm(cit_edges):
  if (edge["source"] not in graph_vertices):
    print ('source not in vertex list')
    print (edge, flush=True)
    continue 
  if (edge["target"] not in graph_vertices):
    print ('target not in vertex list')
    print (edge, flush=True)
    continue 
  graph.add_edge(edge["source"], edge["target"])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">target not in vertex list
# {&#39;source&#39;: &#39;D809697&#39;, &#39;target&#39;: &#39;1963218&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;10456544&#39;, &#39;target&#39;: &#39;2317608&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;D490798&#39;, &#39;target&#39;: &#39;D190749&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;4494772&#39;, &#39;target&#39;: &#39;3743315&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;7467440&#39;, &#39;target&#39;: &#39;3264678&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;4715135&#39;, &#39;target&#39;: &#39;3912084&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;4144596&#39;, &#39;target&#39;: &#39;3594826&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;10801415&#39;, &#39;target&#39;: &#39;3824030&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;3971635&#39;, &#39;target&#39;: &#39;3607157&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;9834239&#39;, &#39;target&#39;: &#39;3829113&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;4022120&#39;, &#39;target&#39;: &#39;3064556&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;D342613&#39;, &#39;target&#39;: &#39;3081012&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;7820922&#39;, &#39;target&#39;: &#39;2393581&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;7699392&#39;, &#39;target&#39;: &#39;532444&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;6681857&#39;, &#39;target&#39;: &#39;3336982&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;RE36681&#39;, &#39;target&#39;: &#39;3004638&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;5226570&#39;, &#39;target&#39;: &#39;3877624&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;4948011&#39;, &#39;target&#39;: &#39;3526075&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;4690835&#39;, &#39;target&#39;: &#39;3263891&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;4616393&#39;, &#39;target&#39;: &#39;2837817&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;7040670&#39;, &#39;target&#39;: &#39;3100655&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;5924448&#39;, &#39;target&#39;: &#39;3790310&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;6932883&#39;, &#39;target&#39;: &#39;3458978&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;D568544&#39;, &#39;target&#39;: &#39;1385371&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;4338015&#39;, &#39;target&#39;: &#39;3602451&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;4594065&#39;, &#39;target&#39;: &#39;3647309&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;4039729&#39;, &#39;target&#39;: &#39;3410726&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;4904145&#39;, &#39;target&#39;: &#39;715270&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;7836691&#39;, &#39;target&#39;: &#39;2664698&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;4062420&#39;, &#39;target&#39;: &#39;3847492&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;D796237&#39;, &#39;target&#39;: &#39;D120018&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;9884262&#39;, &#39;target&#39;: &#39;2974438&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;4448475&#39;, &#39;target&#39;: &#39;3901771&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;D280077&#39;, &#39;target&#39;: &#39;D226303&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;D262570&#39;, &#39;target&#39;: &#39;D82179&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;4165278&#39;, &#39;target&#39;: &#39;1913876&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;7766301&#39;, &#39;target&#39;: &#39;3539081&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;4412866&#39;, &#39;target&#39;: &#39;3231492&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;7458114&#39;, &#39;target&#39;: &#39;3095583&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;D541020&#39;, &#39;target&#39;: &#39;3407518&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;4685942&#39;, &#39;target&#39;: &#39;3616616&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;9321965&#39;, &#39;target&#39;: &#39;3746626&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;D718486&#39;, &#39;target&#39;: &#39;1355298&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;9638357&#39;, &#39;target&#39;: &#39;2788994&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;5038973&#39;, &#39;target&#39;: &#39;3319828&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;4918255&#39;, &#39;target&#39;: &#39;3131120&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;4012118&#39;, &#39;target&#39;: &#39;3697150&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;4124086&#39;, &#39;target&#39;: &#39;3866703&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;7487850&#39;, &#39;target&#39;: &#39;3030459&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;9918460&#39;, &#39;target&#39;: &#39;2093132&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;8256721&#39;, &#39;target&#39;: &#39;3858875&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;4022117&#39;, &#39;target&#39;: &#39;3521546&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;4572754&#39;, &#39;target&#39;: &#39;3518756&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;D292434&#39;, &#39;target&#39;: &#39;D220385&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;4796835&#39;, &#39;target&#39;: &#39;3724782&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;4898863&#39;, &#39;target&#39;: &#39;3415841&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;10357731&#39;, &#39;target&#39;: &#39;3679057&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;4720074&#39;, &#39;target&#39;: &#39;2169965&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;4630805&#39;, &#39;target&#39;: &#39;3841496&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;8272554&#39;, &#39;target&#39;: &#39;3795034&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;8814854&#39;, &#39;target&#39;: &#39;3539034&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;4249652&#39;, &#39;target&#39;: &#39;1794331&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;4115634&#39;, &#39;target&#39;: &#39;3222303&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;8963471&#39;, &#39;target&#39;: &#39;3836790&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;8279417&#39;, &#39;target&#39;: &#39;2075883&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;6293272&#39;, &#39;target&#39;: &#39;732470&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;10010487&#39;, &#39;target&#39;: &#39;3335890&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;4311825&#39;, &#39;target&#39;: &#39;3436375&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;4081266&#39;, &#39;target&#39;: &#39;3226184&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;3978136&#39;, &#39;target&#39;: &#39;3459807&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;4480343&#39;, &#39;target&#39;: &#39;312999&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;6336412&#39;, &#39;target&#39;: &#39;2721777&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;4062912&#39;, &#39;target&#39;: &#39;2353195&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;8154376&#39;, &#39;target&#39;: &#39;3878423&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;4482534&#39;, &#39;target&#39;: &#39;3608070&#39;}
# target not in vertex list
# {&#39;source&#39;: &#39;4509639&#39;, &#39;target&#39;: &#39;2760677&#39

# %%
# confirm that some patent ids are not in the main list of patents for some reason 
pat_df[pat_df.id=='1963218']

# %% [markdown]
# ### Compute scores

# %%
cd_index_5 = {}
for patent_id in graph_vertices:
  cd_index_5[patent_id] = graph.cdindex(patent_id, int(datetime.timedelta(days=1825)))

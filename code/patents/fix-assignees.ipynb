# %% [markdown]
# # load-csv-into-rdb
# SanjayKAroraPhD@gmail.com <br>
# February 2019
#
# ## Description
# Load a csv into a pandas dataframe and persist to a mysql db

# %%
import pandas as pd
import csv 
from pandas.io import sql
from sqlalchemy import types, text, create_engine
import math
import pprint

# %%
CORRECT_FILE = '/Users/sanjay/dev/EAGER/code/patents/assignees_needing_correcting.csv'
ENGINE = create_engine('mysql://root:innovate@localhost/patents_20181127?charset=utf8', encoding='utf-8')
CON = ENGINE.connect()

pp = pprint.PrettyPrinter()

# %%
table_df = pd.read_csv(CORRECT_FILE, sep=',', encoding='utf-8', warn_bad_lines=True, error_bad_lines=False)
table_df.head()
# Out:
#                        lookup_firm  touched
# 0                           ABB AB      1.0
# 1                   ABB Technology      1.0
# 2    Adaptive Biotechnologies Corp      1.0
# 3  Advanced Cardiovascular Systems      1.0
# 4                  AGFA-GEVAERT NV      1.0

# %%
lookup_firm = table_df['lookup_firm']
out_rows = []

for lf in lookup_firm: 
    print (lf)
    firm_short = lf.replace('-','').split()
    firm_short = (' ').join (firm_short [0: 1])
    print (firm_short)
    
    query = text ("SELECT ac.organization_clnd, count(pa.patent_id) cpid "
                "FROM assignee_clnd ac, patent_assignee pa "
                 "WHERE organization_clnd LIKE :fs "
             "AND ac.id = pa.assignee_id "
             "GROUP BY organization_clnd " 
             "ORDER BY cpid desc "
             "LIMIT 10;")

    print (query)
    rs = CON.execute(query, fs=firm_short + '%').fetchall()
    # build list with lf, firm_short, and top n results

    out_row = [lf, firm_short]
    for (organization_clnd, cpid) in rs:
        out_row.append (organization_clnd + ': ' + str(cpid))
    
    out_rows.append (out_row)
# Out:
# ABB AB
# ABB
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# ABB Technology
# ABB
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Adaptive Biotechnologies Corp
# Adaptive
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Advanced Cardiovascular Systems
# Advanced
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# AGFA-GEVAERT NV
# AGFAGEVAERT
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Alcatel Lucent
# Alcatel
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Allison Transmission
# Allison
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Andritz
# Andritz
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Asahi Kasei Kabushiki Kaisha
# Asahi
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# ATI Technologies ULC
# ATI
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Atotech Deutschland
# Atotech
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Avery Dennison
# Avery
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# BAE Systems Information and Electronic Systems Integration
# BAE
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# BASF Plant Science
# BASF
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Battelle Energy Alliance
# Battelle
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Bausch & Lomb
# Bausch
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Baxter
# Baxter
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Baxter Healthcare SA
# Baxter
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Bayer Materialscience
# Bayer
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Biocon Limited
# Biocon
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Boehringer Ingelheim
# Boehringer
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Boehringer Ingelheim Vetmedica
# Boehringer
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Buckman Laboratories
# Buckman
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Cadence Design Systems
# Cadence
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# CAMBRIDGE ENTERPRISE LIMITED
# CAMBRIDGE
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Canon
# Canon
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Cardiac Pacemakers
# Cardiac
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Carl Zeiss Meditec AG
# Carl
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Casio Computer Co
# Casio
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Ceramatec
# Ceramatec
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Certain-teed
# Certainteed
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Chevron Oronitz Company
# Chevron
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Chipmos Technologies
# Chipmos
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Cleanvantage
# Cleanvantage
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# CNH Industrial America
# CNH
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Commonwealth Scientific & Industrial Research Organization
# Commonwealth
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Conexant Systems
# Conexant
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Cornell Research Foundation
# Cornell
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# CSEM Centre Suisse d'Electronique et de Microtechnique SA-Recherche et Developpement
# CSEM
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Da Yu Enterprises
# Da
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Daikin Industries
# Daikin
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Dana-Farber Cancer Institute
# DanaFarber
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# DEKA Products Limited Partnership
# DEKA
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Delta Electronics
# Delta
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# DIC
# DIC
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# DiscoveRx
# DiscoveRx
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Dow AgroSciences
# Dow
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Dow Corning
# Dow
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Dresser-Rand Company
# DresserRand
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Eastman Chemical Company
# Eastman
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Eastman Kodak Company
# Eastman
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Ecolab
# Ecolab
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Eisai Co
# Eisai
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# EPCOS AG
# EPCOS
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# ExxonMobil Research and Engineering Company
# ExxonMobil
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# ExxonMobil Upstream Research Company
# ExxonMobil
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Faurecia Interior Systems
# Faurecia
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# FEI Company
# FEI
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Furukawa Electric Co
# Furukawa
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# GE-Hitachi Nuclear Energy Americas
# GEHitachi
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Genzyme
# Genzyme
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# GlaxoSmithKline Biologicals
# GlaxoSmithKline
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Guardian Industries
# Guardian
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Hadasit Medical Research Services & Development Company
# Hadasit
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Haier US Appliance Solutions
# Haier
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# HAMAMATSU PHOTONICS KK
# HAMAMATSU
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Harris
# Harris
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Headway Technologies
# Headway
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Heidelberger Druckmaschinen AG
# Heidelberger
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Hewlett Packard Enterprise Development LP
# Hewlett
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Hewlett-Packard Development Company
# HewlettPackard
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Hon Hai Precision Industry Co
# Hon
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# HTC
# HTC
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Hunter Douglas
# Hunter
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# III HOLDINGS 1
# III
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Infinera
# Infinera
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Isis Pharmaceuticals
# Isis
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Ivoclar Vivadent AG
# Ivoclar
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Johns Manville
# Johns
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Kabushikikaisha Toshiba
# Kabushikikaisha
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Kao
# Kao
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Karsten Manufacturing
# Karsten
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Kemira OY
# Kemira
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Kerr
# Kerr
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Kobe Steel
# Kobe
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Korea Kumho Petrochemical Co
# Korea
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Kraton Polymers US
# Kraton
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Laserline Mfg
# Laserline
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Lattice Semiconductor
# Lattice
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Lion Copolymer Geismar
# Lion
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Litron Laboratories Limited
# Litron
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Marathon Equipment Company
# Marathon
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Mattson Technology
# Mattson
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Maxim Integrated Products
# Maxim
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Medical Diagnostic Laboratories
# Medical
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# MERCK SHARP & DOHME CORP
# MERCK
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Meso Scale Technologies
# Meso
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Minebea Co
# Minebea
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Mitsubishi Polyester Film
# Mitsubishi
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Nestec S A
# Nestec
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Newport
# Newport
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# NGK Spark Plug Co
# NGK
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Nikon
# Nikon
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Nippon Shokubai Co
# Nippon
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Nissan Motor Co
# Nissan
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Nokia Technologies Oy
# Nokia
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Nordson
# Nordson
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Northrop Grumman Systems
# Northrop
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# NOVA Chemicals (International) SA
# NOVA
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Nova Technologies
# Nova
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Novellus Systems
# Novellus
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Novozymes
# Novozymes
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# OmniVision Technologies
# OmniVision
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Pacific Biosciences of California
# Pacific
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Pacific Light Technologies
# Pacific
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Panasonic Intellectual Property of America
# Panasonic
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Parker-Hannifin
# ParkerHannifin
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Performance Plants
# Performance
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Phillips 66 Company
# Phillips
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# PolyPlus Battery Company
# PolyPlus
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# QUALCOMM MEMS Technologies
# QUALCOMM
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Raytheon BBN Technologies Corp
# Raytheon
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Raytheon Company
# Raytheon
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# RJ Reynolds Tobacco Company
# RJ
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Rockwell Automation Technologies
# Rockwell
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Rolls-Royce North American Technologies
# RollsRoyce
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Rolls-Royce PLC
# RollsRoyce
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Rosemount Aerospace
# Rosemount
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# SABIC GLOBAL TECHNOLOGIES BV
# SABIC
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# SAE Magnetics (HK)
# SAE
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# SAINT-GOBAIN ABRASIFS
# SAINTGOBAIN
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Saint-Gobain Ceramics & Plastics
# SaintGobain
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Samsung Electronics
# Samsung
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Sanofi
# Sanofi
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# SC Johnson & Son
# SC
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# SD Technologies
# SD
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Sharp Laboratories of America
# Sharp
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Shimadzu
# Shimadzu
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Siemens
# Siemens
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Siemens Medical Solutions USA
# Siemens
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Sigma-Aldrich Co
# SigmaAldrich
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Siliconware Precision Industries Co
# Siliconware
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Skidmore
# Skidmore
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Sony Interactive Entertainment America
# Sony
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# STATS ChipPAC
# STATS
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# STMicroelectronics SA
# STMicroelectronics
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Stora Enso Oyj
# Stora
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Sun Chemical
# Sun
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Sun Drilling Products
# Sun
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Symantec
# Symantec
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Syngenta Participations AG
# Syngenta
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Tanaka Kikinzoku Kogyo KK
# Tanaka
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Tata Consultancy Services Limited
# Tata
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# TDK
# TDK
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Teradata US
# Teradata
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# The Eastern Co
# The
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# The Gates
# The
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# The Henry M Jackson Foundation for the Advancement of Military Medicine
# The
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# The Jackson Laboratory
# The
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# The Samuel Roberts Noble Foundation
# The
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Thermo Finnigan
# Thermo
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Thermo Fisher Scientific
# Thermo
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Toyota Motor Engineering & Manufacturing North America
# Toyota
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Ube Industries
# Ube
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# UCB Pharma SA
# UCB
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# US Smokeless Tobacco Company
# US
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Winbond Electronics Corp
# Winbond
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;
# Yeda Research and Development Co
# Yeda
# SELECT ac.organization_clnd, count(pa.patent_id) cpid FROM assignee_clnd ac, patent_assignee pa WHERE organization_clnd LIKE :fs AND ac.id = pa.assignee_id GROUP BY organization_clnd ORDER BY cpid desc LIMIT 10;

# %%
pp.pprint (out_rows)
# Out:
# [['ABB AB',
#   'ABB',
#   'Abbott Laboratoies: 3922',
#   'ABB: 1215',
#   'ABB Technologies AG: 1047',
#   'Abbott Cardiobascular Systems: 1012',
#   'ABB Research: 983',
#   'Abbott DiabetesCare: 873',
#   'ABB Schweiz AB: 667',
#   'AbbVie: 644',
#   'Abbott Medical Optics: 298',
#   'ABB Patent: 221'],
#  ['ABB Technology',
#   'ABB',
#   'Abbott Laboratoies: 3922',
#   'ABB: 1215',
#   'ABB Technologies AG: 1047',
#   'Abbott Cardiobascular Systems: 1012',
#   'ABB Research: 983',
#   'Abbott DiabetesCare: 873',
#   'ABB Schweiz AB: 667',
#   'AbbVie: 644',
#   'Abbott Medical Optics: 298',
#   'ABB Patent: 221'],
#  ['Adaptive Biotechnologies Corp',
#   'Adaptive',
#   'Adaptive Computing Enterprises: 65',
#   'Adaptive Spectrum and Signal Alignment: 61',
#   'Adaptive Optics Associates: 20',
#   'ADAPTIVE BIOTECHNOLOGIES: 18',
#   'Adaptive Materials: 17',
#   'Adaptive Technologies: 17',
#   'Adaptive Methods: 15',
#   'Adaptive Networks: 13',
#   'Adaptive Micro Systems: 12',
#   'Adaptivenergy: 11'],
#  ['Advanced Cardiovascular Systems',
#   'Advanced',
#   'Advanced Micro Devices: 10885',
#   'Advanced Cardiovascular Sytems: 1528',
#   'Advanced Semiconductor Engineering: 916',
#   'Advanced Technology Materials: 621',
#   'Advanced Optoelectronic Technology: 313',
#   'Advanced Neuromodualation Systems: 309',
#   'Advanced Energy Industries: 204',
#   'ADVANCED-CONNECTEK: 193',
#   'Advanced Analogic Technologies: 175',
#   'Advanced Connectek: 170'],
#  ['AGFA-GEVAERT NV', 'AGFAGEVAERT'],
#  ['Alcatel Lucent',
#   'Alcatel',
#   'Alcatel-Lucent: 4701',
#   'Alcatel: 3352',
#   'Alcatel-Lucent USA Zinc: 1305',
#   'Alcatel USA Sourcing L P: 259',
#   'Alcatel Canada: 217',
#   'Alcatel Network Systems: 162',
#   "Alcatel Alsthom Companie Generale d'Electricite: 127",
#   'Alcatel Espace: 79',
#   'Alcatel Business Systems: 55',
#   'Alcatel-Lucent Canada: 55'],
#  ['Allison Transmission',
#   'Allison',
#   'AllisonTransmission: 249',
#   'Allison Advanced Development Company: 46',
#   'Allison Engine Co: 40',
#   'Allison: 20',
#   'Allison Acoustics: 2',
#   'Allison Mfg: 2',
#   'Allison Payment Systems: 2',
#   'Allison Enterprises: 1',
#   'Allison Transmisssion: 1',
#   'Allison tech Sales: 1'],
#  ['Andritz',
#   'Andritz',
#   'Andritz Oy: 327',
#   'Andritz Patentverwaltungsgellschaft mbH: 75',
#   'Andritz Sprout-Bauer: 32',
#   'Andritz-Ahlstrom: 28',
#   'Andritz Technology and Asset Management: 19',
#   'Andritz-Ahlstrom Oy: 17',
#   'Andritz-Patentverwaltungs-GmbH: 7',
#   'Andritz Kusters: 5',
#   'Andritz Hydro: 4',
#   'ANDRITZ PERFOJET SAS: 3'],
#  ['Asahi Kasei Kabushiki Kaisha',
#   'Asahi',
#   'Asahi Kogakukogyo Kabushiki Kaisha: 3340',
#   'Asahi Glass Comapny Limited: 2607',
#   'Asahi Kasei Chemicals: 498',
#   'Asahi Denka Kogyo Kabushiki Kaisha: 207',
#   'Asahi Seiko Kabushiki Kaisha: 200',
#   'Asahi Kasei Microdevices: 108',
#   'Asahi-Dow: 100',
#   'Asahi Intecc Co: 92',
#   'Asahi Kasei E-Materials: 76',
#   'Asahi Kasei Pharma: 67'],
#  ['ATI Technologies ULC',
#   'ATI',
#   'ATI Technology ULC: 511',
#   'ATI Technologies: 366',
#   'ATI: 333',
#   'ATI Properties: 195',
#   'ATIEVA: 143',
#   'ATICO USA: 63',
#   'ATI Industrial Automation: 34',
#   'Atitania: 8',
#   'Atigeo: 7',
#   'ATIR Holding SA: 7'],
#  ['Atotech Deutschland',
#   'Atotech',
#   'Atotech Deutschland GmH: 212',
#   'Atotech USA: 16',
#   'Atotech US A: 1',
#   'Atotech Deutschland LLP: 1'],
#  ['Avery Dennison',
#   'Avery',
#   'Avery-Dennison: 1304',
#   'AVERY DENNISON RETAIL INFORMATION SERVICES: 104',
#   'Avery Corp: 103',
#   'Avery Outdoors: 14',
#   'Avery Products: 9',
#   'Avery Dennison Zweckform Office Products Europe: 5',
#   'AVERY AEROSPACE: 4',
#   'Avery: 3',
#   'Avery Dennison Materials Pty: 3',
#   'Avery Design Systems: 3'],
#  ['BAE Systems Information and Electronic Systems Integration',
#   'BAE',
#   'BAE Systems Information and Electronics Systems Integration: 1214',
#   'BAE Systems: 599',
#   'BAE Systems Controls: 58',
#   'BAE Systems Land & Armaments LP: 54',
#   'BAE Systems Bofors AB: 52',
#   'BAE Industries: 52',
#   'BAE SYSTEMS HÃ\x83Â\x83Ã\x82Â\x84GGLUNDS AKTIENBOLAG: 46',
#   'BAE Systems Electronics Limited: 20',
#   'BAE Systems Imaging Solutions: 18',
#   'BAE Systems Tensy Lon HPM: 16'],
#  ['BASF Plant Science',
#   'BASF',
#   'BASF Aktiengeschaft: 11305',
#   'BASF SF: 3644',
#   'BASF Wyandotte: 455',
#   'BASF Coatings: 421',
#   'BASF Plant Sciences: 266',
#   'BASF Lacke+Farben AG: 113',
#   'BASF Lacke & Farben Aktiengesellschaft: 84',
#   'BASF Farben & Faser AG: 80',
#   'BASF Catalysts: 77',
#   'BASF Magnetics: 75'],
#  ['Battelle Energy Alliance',
#   'Battelle',
#   'Battelle Memorial Institute: 1647',
#   'Battelle Energy Alliance LC: 414',
#   'Battelle Development: 172',
#   'Battelle Institute eV: 81',
#   'Battelle Memorial Institute K1-53: 21',
#   'Battelle Pulmonary Therapeutics: 9',
#   'Battelle Memorial Insitute: 4',
#   'BattellePharma: 3',
#   'Battelle Ingenieurtechnik: 2',
#   'Battelle Memorial Institute Pacific Northwest Laboratory: 1'],
#  ['Bausch & Lomb',
#   'Bausch',
#   'Bausch-Lomb: 1061',
#   'Bausch & Lomb Surgical: 48',
#   'Bausch & Lomb Pharma Holdings Corp: 3',
#   'Bausch & Lomb Professional Dental Products: 2',
#   'Bausch & Lomb Hearing Systems Division: 1',
#   'Bausch Ã\x83Â¢Ã\x82Â\x80Ã\x82Â¢ Lomb: 1',
#   'Bausch Ã\x83Â\x83Ã\x82Â· Lomb: 1',
#   'Bausch & Strobel Maschinenfabrik: 1',
#   'Bausch & Strobel Maschinenfabrik & Co: 1'],
#  ['Baxter',
#   'Baxter',
#   'Baxter Internatiional: 2093',
#   'Baxter Travenol Labs: 807',
#   'Baxter Healthcare: 793',
#   'Baxter SA: 70',
#   'Baxter Laboratories: 49',
#   'Baxter Diagnostics: 30',
#   'Baxter Englewood: 21',
#   'Baxter Biotech Technology Sarl: 15',
#   'Baxter Innovations: 12',
#   'Baxter Research Medical: 4'],
#  ['Baxter Healthcare SA',
#   'Baxter',
#   'Baxter Internatiional: 2093',
#   'Baxter Travenol Labs: 807',
#   'Baxter Healthcare: 793',
#   'Baxter SA: 70',
#   'Baxter Laboratories: 49',
#   'Baxter Diagnostics: 30',
#   'Baxter Englewood: 21',
#   'Baxter Biotech Technology Sarl: 15',
#   'Baxter Innovations: 12',
#   'Baxter Research Medical: 4'],
#  ['Bayer Materialscience',
#   'Bayer',
#   'Bayer AG: 12493',
#   'Bayer CropScience AG: 1196',
#   'Bayer MeterialScience AG: 709',
#   'BAYER INTELLECTUALPROPERTY: 693',
#   'Bayer Healhcare AG: 639',
#   'Bayer Schering Pharma Aktiengesellschaft: 196',
#   'Bayer Pharma: 184',
#   'Bayer Pharmaceuticals: 71',
#   'Bayer Bioscience NV: 67',
#   'Bayer Technology Services: 62'],
#  ['Biocon Limited',
#   'Biocon',
#   'Biocon: 90',
#   'BioControl Systems: 33',
#   'Biocontrol Medical: 13',
#   'Bioconnect Systems: 9',
#   'Biocontrol Limited: 7',
#   'Biocontrol: 7',
#   'Biocontrol Technology: 6',
#   'Biocon India Limited: 5',
#   'BioControl System: 1',
#   'Bioconversion Srl: 1'],
#  ['Boehringer Ingelheim',
#   'Boehringer',
#   'Boehringer Ingelheim Pharma KG & Co: 2531',
#   'Boehringer Mannehim: 1152',
#   'Boehringer Ingelheim (Canada): 63',
#   'Boehringer Ingelheim Microparts: 46',
#   'Boehringer Laboratories: 30',
#   'Boehringer Mannheim Italia SpA: 24',
#   'Boehringer Technologies LP: 21',
#   'Boehringer Biochemia Robin SpA: 21',
#   'Boehringer Werkzeugmaschinen: 16',
#   'BOEHRINGER INGELHEIM RCV & CO KG: 12'],
#  ['Boehringer Ingelheim Vetmedica',
#   'Boehringer',
#   'Boehringer Ingelheim Pharma KG & Co: 2531',
#   'Boehringer Mannehim: 1152',
#   'Boehringer Ingelheim (Canada): 63',
#   'Boehringer Ingelheim Microparts: 46',
#   'Boehringer Laboratories: 30',
#   'Boehringer Mannheim Italia SpA: 24',
#   'Boehringer Technologies LP: 21',
#   'Boehringer Biochemia Robin SpA: 21',
#   'Boehringer Werkzeugmaschinen: 16',
#   'BOEHRINGER INGELHEIM RCV & CO KG: 12'],
#  ['Buckman Laboratories',
#   'Buckman',
#   "Buckman Laboratories Int'l: 191",
#   'Buckman Jet Drilling: 6',
#   'Buckman Laboratories of Canada: 1',
#   'Buckman Imports: 1',
#   'Buckman Laboratores: 1'],
#  ['Cadence Design Systems',
#   'Cadence',
#   'Cadence Design Sysyems: 1803',
#   'Cadence Environmental Energy: 18',
#   'Cadence Chemical Resources: 10',
#   'Cadence Innovation: 8',
#   'Cadence AMS Design India Private Limited: 6',
#   'Cadence Design (Israel) II: 5',
#   'Cadence Biomedical: 2',
#   'Cadence Enviromental Energy: 2',
#   'Cadence Design Systems of San Jose: 1',
#   'Cadence Technologies: 1'],
#  ['CAMBRIDGE ENTERPRISE LIMITED',
#   'CAMBRIDGE',
#   'Cambridge Display Technology Limited: 291',
#   'Cambridge Silicon Radio Limited: 225',
#   'Cambridge Enterprise: 188',
#   'Cambridge University Technical Services: 77',
#   'Cambridge Research and Instrumentation: 61',
#   'Cambridge Semiconductor Limited: 49',
#   'Cambridge Consultants Limited: 46',
#   'Cambridge: 45',
#   'Cambridge NeuroScience: 44',
#   'Cambridge Polymer Group: 36'],
#  ['Canon',
#   'Canon',
#   'Canon Kabushiki Kaiaha: 69889',
#   'Canon Denshi Kabushiki Kaisha: 280',
#   'Canon Anelva: 279',
#   'Canon Finetech: 202',
#   'Canon US Life Sciences: 101',
#   'Canon Information Systems: 77',
#   'CANON FINETECH NISCA: 67',
#   'CANON COMPONENTS: 58',
#   'Canon Information Systems & Research Australia: 57',
#   'Canon USA: 55'],
#  ['Cardiac Pacemakers',
#   'Cardiac',
#   'Cardiac Pacemarkers: 3492',
#   'CardiacScience: 64',
#   'Cardiac Pathways: 61',
#   'Cardiac Intelligence: 47',
#   'Cardiac Dimensions: 46',
#   'Cardiac Mariners: 21',
#   'Cardiac Assist: 18',
#   'Cardiac Dimensions Pty: 12',
#   'Cardiac Control Systems: 8',
#   'Cardiac Assist Technologies: 8'],
#  ['Carl Zeiss Meditec AG',
#   'Carl',
#   'Carl Zeiss SMT GbmH: 1605',
#   'Carl-Zeiss Stiftung: 661',
#   'Carl Zeiss Meditec: 519',
#   'Carl Zeiss Microscopy: 342',
#   'Carl Freudenberg AG: 319',
#   'Carl Zeiss Jana: 244',
#   'Carl Zeiss Micro Imaging: 154',
#   'Carl Zeiss Vision: 111',
#   'Carl Zeiss Industrielle Messtechnik: 91',
#   'Carl Hurth Maschinen und Zahnradfabrik: 85'],
#  ['Casio Computer Co',
#   'Casio',
#   'CASIO COMPUTERS CO: 4181',
#   'Casio Keisanki Kabushiki Kaisha: 364',
#   'Casio Hitachi Mobile Communications Co: 94',
#   'Casio Electronics Manufacturing: 88',
#   'Casio PhoneMate: 18',
#   'Casio Denshikougyou Kabushiki Kaisha: 5',
#   'Casio Micronics Co: 4',
#   'Casio Communications: 3',
#   'Casio Hitachi Mobile Communication Co: 2',
#   'Casion Technology Co: 1'],
#  ['Ceramatec', 'Ceramatec', 'Ceramatech: 1'],
#  ['Certain-teed',
#   'Certainteed',
#   'CertainTeed Corportation: 743',
#   'CertainTeed Gypsum: 25',
#   'CertainTeed Canada: 6',
#   'CERTAINTEED GYPSUM AND CEILING MANUFACTURING: 5',
#   'Certainteed Ceiling: 4',
#   'Certainteed Ceilings: 2',
#   'Certainteed Insulation Canada: 1',
#   'CertainTeed Shade Systems LLC: 1'],
#  ['Chevron Oronitz Company',
#   'Chevron',
#   'Chevron Research Company: 2141',
#   'Chevron USA: 1813',
#   'Chevron Chemical: 223',
#   'Chevron: 24',
#   'Chevron Philips Chemical Company LP: 22',
#   'Chevron (HK) Limited: 20',
#   'Chevron Oronite Technology BV: 16',
#   'Chevron Research and Technology Company a Division of Chevron USA: 13',
#   'Chevron Japan: 10',
#   'Chevron Chemical SA: 5'],
#  ['Chipmos Technologies',
#   'Chipmos',
#   'Chipmos Technology: 186',
#   'ChipMos Technologies (Bermeda): 90',
#   'ChipMOS Technologies (Shanghai): 2'],
#  ['Cleanvantage', 'Cleanvantage'],
#  ['CNH Industrial America',
#   'CNH',
#   'CNH Industrial Americal: 1020',
#   'CNH America: 970',
#   'CNH Industrial Canada: 215',
#   'CNH Canada: 178',
#   'CNH Baumaschinen: 9',
#   'CNH France SA: 5',
#   'CNH FOODSERVICE: 3',
#   'CNH Industrial Belgium nv: 2',
#   'CNH UK: 2',
#   'CNH Industrial France SAS: 1'],
#  ['Commonwealth Scientific & Industrial Research Organization',
#   'Commonwealth',
#   'Commonwealth Scientific and Industries Research Organization: 911',
#   'Commonwealth Edison Co: 33',
#   'Commonwealth of Puerto Rico: 29',
#   'Commonwealth of Australia: 27',
#   'Commonwealth Scientific and Industrial Research: 11',
#   'Commonwealth Industries: 8',
#   'Commonwealth Scientific: 8',
#   'Commonwealth Scientific and Industrial Research Organization (CSIRO): 6',
#   'Commonwealth Aluminum: 4',
#   'Commonwealth Serum Laboratories Commission: 4'],
#  ['Conexant Systems',
#   'Conexant',
#   'Conexant Sytems: 764',
#   'Conexant: 47',
#   'Conexant Systems Worldwide: 1',
#   'Conexant Systems UK Limited: 1'],
#  ['Cornell Research Foundation',
#   'Cornell',
#   'Cornell Universiy: 601',
#   'Cornell-Dubilier Electric: 8',
#   'CORNELL UNIVERSITY CORNELL CENTER FOR TECHNOLOGY ENTERPRISE & '
#   'COMMERCIALIZATION '
#   '(Ã\x83Â¢Ã\x82Â\x80Ã\x82Â\x9cCCTECÃ\x83Â¢Ã\x82Â\x80Ã\x82Â\x9d): 7',
#   'Cornell Dubilier Electronics: 6',
#   'Cornell Iron Works: 6',
#   'Cornell Development: 5',
#   'Cornell Dubilier Marketing: 4',
#   'CORNELL IRONWORKS ENTERPRISES: 4',
#   'Cornell Center for Technology Enterprise & Commercialization: 4',
#   'Cornell Pump Company: 3'],
#  ["CSEM Centre Suisse d'Electronique et de Microtechnique SA-Recherche et "
#   'Developpement',
#   'CSEM',
#   "CSEM-Centre Suisse d'Electronique et de Microtechnique SA - Recherche et "
#   'Development: 138',
#   "CSEM Centre Suisse d'Electronique et de Microtechniques SA "
#   'Ã\x83Â¢Ã\x82Â\x80Ã\x82Â\x94 Recherche et DÃ\x83Â\x83Ã\x82Â©veloppement: 13',
#   "CSEM Centre Suisse d' Electronique et de Microtechnique "
#   'SAÃ\x83Â¢Ã\x82Â\x80Ã\x82Â\x94Recherche et Developpement: 4',
#   'CSEM Centre Suisse dÃ\x83Â¢Ã\x82Â\x80Ã\x82Â²Electronique et de '
#   'Microtechnique SA: 3',
#   "CSEM Centre Suisse d'Electronique et de Microtechnique "
#   'SAÃ\x83Â¢Ã\x82Â\x80Ã\x82Â\x94Recherche et DÃ\x83Â\x83Ã\x82Â©veloppement: 3',
#   "CSEM CENTRE SUISSE D'ELECTRONIQUE ET DE MICROTECHNIQUE "
#   'SAÃ\x83Â¢Ã\x82Â\x80Ã\x82Â\x94RECHERCHE ET DEVÃ\x83Â\x83Ã\x82Â\x89LOPPEMENT: '
#   '1',
#   "CSEMÃ\x83Â¢Ã\x82Â\x80Ã\x82Â\x94Centre Suisse d'Electronique et de "
#   'Microtechnique SAÃ\x83Â¢Ã\x82Â\x80Ã\x82Â\x94Recherche et Developpement: 1',
#   "CSEM Centre Suisse d'Electronique et de Microtechniques SA - Recherche et "
#   'DÃ\x83Â\x83Ã\x82Â©veloppement of Neuchatel Switzerland: 1',
#   "CSEM Centre Suisse D'Electronique Et De: 1",
#   "CSEM CENTRE SUISSE D'ELECTRONIQUE ET DE MICROTECHNIQUE SA-RECHERCHE AT "
#   'DÃ\x83Â\x83Ã\x82Â\x89VELOPPEMENT: 1'],
#  ['Da Yu Enterprises',
#   'Da',
#   'DaimlerChrysler AG: 3579',
#   'Daiki Industries: 2650',
#   'Daimler-Benz Aktieqesellschaft: 2611',
#   'Dai Nippon Printing: 2157',
#   'Dana Corproation: 1555',
#   'Dart Industries: 1544',
#   'Daewoo Electronics CoLtd: 1169',
#   'Daicel Chemical Industries: 1150',
#   'Dainippon Screen Manufacturing Co: 998',
#   'Danfoss: 760'],
#  ['Daikin Industries',
#   'Daikin',
#   'Daikin Clutch: 14',
#   'DAIKIN APPLIED AMERICAS: 11',
#   'Daikin Europe NV: 11',
#   'Daikin America: 7',
#   'Daikin Kogyo Kabushiki Kaisha: 6',
#   'Daikin Institute of Advanced Chemistry and Technology: 2',
#   'Daikin Institute of Advanced Chemistry and Technology (Dai-Act): 2',
#   'DAIKIN APPLIED SYSTEMS CO: 2',
#   'Daikin Plant Co: 1',
#   'Daikin US: 1'],
#  ['Dana-Farber Cancer Institute', 'DanaFarber'],
#  ['DEKA Products Limited Partnership',
#   'DEKA',
#   'Deka Products Limited Partners: 741',
#   'Dekalb Genetics: 198',
#   'Dekati Oy: 11',
#   'Dekalb Plant Genetics: 6',
#   'DeKalb-Pfizer Genetics: 4',
#   'Deka Medical: 3',
#   'DeKalb AgResearch: 2',
#   'DEKALB BLOWER: 1',
#   'Dekalb Swine Breeders: 1',
#   'DeKalb Genetics Corp: 1'],
#  ['Delta Electronics',
#   'Delta',
#   'Delta Electronic: 2104',
#   'DELTA FAUCET COMPANY: 345',
#   'DELTA ELECTRONICS (SHANGHAI) CO: 181',
#   'Delta Tooling Co: 112',
#   'Delta Machinery Corp: 93',
#   'Delta Kogyo Co: 87',
#   'Delta T: 76',
#   'Delta Systems: 74',
#   'Delta Design: 57',
#   'Delta Enterprise Corp: 42'],
#  ['DIC',
#   'DIC',
#   'DIC Corportion: 409',
#   'Dictaphone: 158',
#   'Dickey-john: 80',
#   'Dicon Fiberoptics: 59',
#   'Dicerna Pharmaceuticals: 30',
#   'Dicke Tool Company: 29',
#   'Dichtungstechnik G Bruss & Co: 21',
#   'Dickson Industries: 13',
#   'Dico Company: 13',
#   'Dicon Systems Limited: 13'],
#  ['DiscoveRx', 'DiscoveRx', 'Discoverx Corp: 25'],
#  ['Dow AgroSciences',
#   'Dow',
#   'Dow Chemical Co: 7697',
#   'Dow Global Technoloigies: 2760',
#   'Dow AroSciecnes: 1060',
#   'Dow Corning Toray Silicone Co: 535',
#   'DOW CORNING TORAY CO: 245',
#   'Dowa Mining Co: 221',
#   'Dowa Electronics Materials Co: 196',
#   'Dow Global Technologies: 145',
#   'DowElanco: 135',
#   'Dowell Schlumberger: 126'],
#  ['Dow Corning',
#   'Dow',
#   'Dow Chemical Co: 7697',
#   'Dow Global Technoloigies: 2760',
#   'Dow AroSciecnes: 1060',
#   'Dow Corning Toray Silicone Co: 535',
#   'DOW CORNING TORAY CO: 245',
#   'Dowa Mining Co: 221',
#   'Dowa Electronics Materials Co: 196',
#   'Dow Global Technologies: 145',
#   'DowElanco: 135',
#   'Dowell Schlumberger: 126'],
#  ['Dresser-Rand Company', 'DresserRand'],
#  ['Eastman Chemical Company',
#   'Eastman',
#   'Eastman Kodak Co: 21484',
#   'Eastman Chemical: 1732',
#   'Eastman Christensen Company: 37',
#   'Eastman Machine Company: 26',
#   'Eastman Technology: 23',
#   'Eastman Outdoors: 17',
#   'Eastman Holding Company: 16',
#   'Eastman Chemical Resins: 9',
#   'Eastman Whipstock: 6',
#   'Eastman Specialties Holdings: 6'],
#  ['Eastman Kodak Company',
#   'Eastman',
#   'Eastman Kodak Co: 21484',
#   'Eastman Chemical: 1732',
#   'Eastman Christensen Company: 37',
#   'Eastman Machine Company: 26',
#   'Eastman Technology: 23',
#   'Eastman Outdoors: 17',
#   'Eastman Holding Company: 16',
#   'Eastman Chemical Resins: 9',
#   'Eastman Whipstock: 6',
#   'Eastman Specialties Holdings: 6'],
#  ['Ecolab',
#   'Ecolab',
#   'Ecolab USA: 910',
#   'Ecolab & Co oGH: 825',
#   'ECOLAB USE: 1'],
#  ['Eisai Co',
#   'Eisai',
#   'Eisai Company: 670',
#   'Eisai R & D Management Co: 378',
#   'Eisai Chemical Co: 17',
#   'Eisai of North America: 4',
#   'Eisai Research Institute: 2',
#   'Eisai Chemical: 1',
#   'Eisai Ci: 1',
#   'Eisai & Managment Co: 1',
#   'Eisai R&D Co: 1',
#   'Eisai R & D Development Co: 1'],
#  ['EPCOS AG',
#   'EPCOS',
#   'EPCOS: 659',
#   'Epcos Pte: 9',
#   'EPCOSAG: 1',
#   'EPCOS (Zhuhai FTZ) Co: 1',
#   'EPCOS do BrazilA: 1'],
#  ['ExxonMobil Research and Engineering Company',
#   'ExxonMobil',
#   'ExxonMobilChemical Patents: 2570',
#   'ExxonMobil Research and Engineered Company: 1482',
#   'ExxonMobil Upstream Resarch Co: 980',
#   'ExxonMobil Oil: 144',
#   'ExxonMobile Chemical Patents: 18',
#   'ExxonMobile Upstream Research Company: 13',
#   'ExxonMobil: 3',
#   'ExxonMobil Upstream Reseach Company: 2',
#   'ExxonMobil Oil Corp: 2',
#   'ExxonMobil Chemical Patents: 2'],
#  ['ExxonMobil Upstream Research Company',
#   'ExxonMobil',
#   'ExxonMobilChemical Patents: 2570',
#   'ExxonMobil Research and Engineered Company: 1482',
#   'ExxonMobil Upstream Resarch Co: 980',
#   'ExxonMobil Oil: 144',
#   'ExxonMobile Chemical Patents: 18',
#   'ExxonMobile Upstream Research Company: 13',
#   'ExxonMobil: 3',
#   'ExxonMobil Upstream Reseach Company: 2',
#   'ExxonMobil Oil Corp: 2',
#   'ExxonMobil Chemical Patents: 2'],
#  ['Faurecia Interior Systems',
#   'Faurecia',
#   'Faurecia Interior Industrie: 130',
#   'Faurecia Innenraum Systeme: 121',
#   "Faurecia Siege d'Automobile SA: 102",
#   'Faurecia Autositze & Co: 88',
#   'Faurecia Interior Systems USA: 66',
#   'Faurecia Emissions Control Technologies: 63',
#   'Faurecia Automotive Seating: 49',
#   "Faurecia Systemes d'Echappement: 38",
#   "Faurecia SiÃ\x83Â\x83Ã\x82Â¨ges d'Automobile: 32",
#   'Faurecia Bloc Avant: 30'],
#  ['FEI Company',
#   'FEI',
#   'FEI Compay: 503',
#   'Feitian Technologies Co: 120',
#   'Feit Electric Company: 29',
#   'Feintool Holding AG: 25',
#   'Feinmetall: 20',
#   'Feintool Intellectual Property AG: 17',
#   'FEI EFA: 11',
#   'Feinstein Patents: 10',
#   'Feiloli Electronic Co: 9',
#   'Feig Electronic: 8'],
#  ['Furukawa Electric Co',
#   'Furukawa',
#   'FURUKAWA AUTOMOTIVE SYSTEMS: 131',
#   'Furukawa Co: 49',
#   'Furukawa Denchi Kabushiki Kaisha: 38',
#   'Furukawa Aluminum Co: 35',
#   'Furukawa-Sky Aluminum: 30',
#   'Furukawa Circuit Foil Co: 16',
#   'FURUKAWA MAGNET WIRE CO: 16',
#   'Furukawa Denki Kogyo Kabushiki Kaisha: 10',
#   'Furukawa Metals Company: 7',
#   'Furukawa Industrial Machinery Systems Co: 5'],
#  ['GE-Hitachi Nuclear Energy Americas', 'GEHitachi'],
#  ['Genzyme',
#   'Genzyme',
#   'Genzyme Corpforation: 560',
#   'Genzyme Transgenics Corporatiion: 13',
#   'Genzyme Glycobiology Research Institute: 10',
#   'Genzyme Limited: 6',
#   'Genzyme Therapeutic Products Limited Partnership: 2',
#   'Genzyme Transgenic: 1',
#   'Genzyme A Sanofi Company: 1',
#   'Genzyme Diagnostics: 1'],
#  ['GlaxoSmithKline Biologicals',
#   'GlaxoSmithKline',
#   'GlaxoSmithKline: 336',
#   'GlaxoSmithKline Biologicals SR: 273',
#   'GlaxoSmithKline Intellectual Property (No2) Limited: 113',
#   'GlaxoSmithKline Consumer Healthcare: 67',
#   'GlaxoSmithKline Istrazivacki Centar Zagreb DOO: 8',
#   'GlaxoSmithKline Australia Pty: 4',
#   'GlaxoSmithKline istrazivacki Centar Zagreb do: 4',
#   'GlaxoSmithKline Consumer Healthcare Holdings (US): 2',
#   'GlaxoSmithKline istrazivacki center Zagreb doo: 2',
#   'GlaxoSmithKline Consumer Healthcare (UK) IP Limited: 2'],
#  ['Guardian Industries',
#   'Guardian',
#   'Guardian Industries Corp: 727',
#   'Guardian Glass: 63',
#   'Guardian Technologies: 35',
#   'Guardian Fiberglass: 26',
#   'Guardian Products: 26',
#   'Guardian Data Storage: 15',
#   'Guardian IG: 13',
#   'Guardian Electric Manufacturing Company: 12',
#   'Guardian Building Products: 7',
#   'Guardian Automotive Trim: 6'],
#  ['Hadasit Medical Research Services & Development Company',
#   'Hadasit',
#   'HADASIT MEDICAL RESEARCH SERVICE AND DEVELOPMENT: 151',
#   'Hadasit: 1'],
#  ['Haier US Appliance Solutions',
#   'Haier',
#   'Haier US Appliance Solution: 389',
#   'Haier Group Company: 79',
#   'Haier Asia Co: 6',
#   'Haier US Applicance Solutions: 5',
#   'Haier America Refrigerators Company: 5',
#   'HAIER GROUP CO: 4',
#   'HAIER GROUP TECHNIQUE R&D CENTER: 4',
#   'HAIER GROUP TECHNIQUE R & D CENTER: 2',
#   'Haier America: 1',
#   'Haier Merloni (Qingdao) Washing Machine Co: 1'],
#  ['HAMAMATSU PHOTONICS KK',
#   'HAMAMATSU',
#   'Hamamatsu Phonics KK: 1899',
#   'Hamamatsu Terebi Kabushiki Kaisha: 12',
#   'Hamamatsu TV Co: 8',
#   'Hamamatsu: 5',
#   'Hamamatsu Foundation for Science and Technology Promotion: 5',
#   'Hamamatsu Systems: 5',
#   'Hamamatsu Industry Co: 4',
#   'HAMAMATSU UNIVERSITY SCHOOL OF MEDICINE: 4',
#   'Hamamatsu Phontonics KK: 2',
#   'Hamamatsu-shi Photonics KK: 1'],
#  ['Harris',
#   'Harris',
#   'Harris Corporatiion: 3445',
#   'Harris Technology: 91',
#   'Harris Graphics: 81',
#   'Harris Moran Seed Company: 40',
#   'Harris Stratex Networks: 29',
#   'Harris Stratex Networks Operating: 24',
#   'Harris Semiconductor Patents: 21',
#   'Harris Research: 21',
#   'Harris Broadband Wireless Access: 16',
#   'Harris Waste Management Group: 14'],
#  ['Headway Technologies',
#   'Headway',
#   'Headway Technoloies: 1053',
#   'Headway Research: 4',
#   'Headway: 3',
#   'Headway Techologies: 1',
#   'Headway Technolog: 1',
#   'Headway Advanced Materials Co: 1',
#   'Headway Research Limited: 1'],
#  ['Heidelberger Druckmaschinen AG',
#   'Heidelberger',
#   'Heidelberger Drunkmaschinen AG: 2453',
#   'Heidelberger Zement AG: 10',
#   'Heidelberger Zement Aktiengesellschaft: 4',
#   'Heidelberger Harris: 3',
#   'Heidelberger Bauchemie: 3',
#   'Heidelberger Baustofftechnik: 1',
#   'Heidelberger Ionenstrahltherapie (HIT) Betriebs-Gesellschaft AM '
#   'Universitatsklinikum Heidelberg mbH: 1',
#   'HeidelbergerDruckmaschinen AG: 1',
#   'Heidelberger Druckmaschinen Heidelberg: 1',
#   'Heidelberger DruckmaschinenAG: 1'],
#  ['Hewlett Packard Enterprise Development LP',
#   'Hewlett',
#   'Hewlett-Packasrd Development Comany LP: 33016',
#   'Hewlett-Packard Indigo BV: 150',
#   'Hewlett-Packard Industrial Printing: 57',
#   'Hewlett-Packard development Company LP: 8',
#   'Hewlett-Packard Gesellschaft mbH: 4',
#   'Hewlett-Parkard Indigo BV: 2',
#   'HewlettÃ\x83Â¢Ã\x82Â\x80Ã\x82Â\x94Packard Development Company LP: 2',
#   'Hewlett-Packard Company Intellectual Property Administration: 2',
#   'Hewlett-Packard Co Legal Dept: 1',
#   'Hewlett-Packard Caribe BV: 1'],
#  ['Hewlett-Packard Development Company', 'HewlettPackard'],
#  ['Hon Hai Precision Industry Co',
#   'Hon',
#   'Hon Hai Precisiopn Ind Co: 18541',
#   'Honeywell-International: 15026',
#   'Honda Motors: 13353',
#   'Honda Giken Kogyo Kabashiki Kaisha: 10466',
#   'Hon Fu Jin Precision Industry (Shen Zhen) Co: 4072',
#   'Honeywell Information Systems: 686',
#   'Hong Kong Applied Science and Technology Research Institute Co: 380',
#   'Hong Kong University of Science & Technology: 369',
#   'HONG FU JIN PRECISON INDUSTRY (WuHan) CO: 222',
#   'HON Technology: 176'],
#  ['HTC',
#   'HTC',
#   'HTC Sweden AB: 27',
#   'HTC Products: 11',
#   'HTCERAMIX SA: 5',
#   'HTC MARKETING CORP: 2',
#   'HTC Beteiligungs: 2',
#   'HTC Co: 1',
#   'HTC Sweden A3: 1',
#   'HTC Management Services: 1',
#   'HTC Purenergy: 1'],
#  ['Hunter Douglas',
#   'Hunter',
#   'Hunter-Douglas: 587',
#   'Hunter Fan Company: 541',
#   'Hunter Engineering Company: 250',
#   'Hunter Industries: 195',
#   'Hunter Douglas Industries BV: 106',
#   'Hunter Douglas Internation NV: 96',
#   "Hunter's Manufacturing Co: 55",
#   "Hunter's Specialties: 38",
#   'Hunter Automated Machinery: 33',
#   'Hunter-Melnor: 15'],
#  ['III HOLDINGS 1',
#   'III',
#   'III HOLDINGS 3: 258',
#   'III-N Technology: 3',
#   'III Holdings 7: 3',
#   'III-Solutions: 1',
#   'III Sigma Company: 1',
#   'III GI: 1',
#   'Iiidustrial Technology Research Institute: 1'],
#  ['Infinera', 'Infinera', 'Infinera Corp: 451'],
#  ['Isis Pharmaceuticals',
#   'Isis',
#   'Isis Phamaceuticals: 1048',
#   'ISIS INNOVATION: 320',
#   'ISIS Technology Limited: 7',
#   'ISIS PHARMA: 5',
#   'Isis Innovations: 4',
#   'ISIS: 4',
#   'Isis Pharmceuticals: 2',
#   'Isis Sentronics: 2',
#   'Isis Medical Instruments: 1',
#   'ISIS GEOMATICS: 1'],
#  ['Ivoclar Vivadent AG',
#   'Ivoclar',
#   'Ivoclar AG: 50',
#   'IvoclarVivadent AG: 1',
#   'Ivoclar NA: 1'],
#  ['Johns Manville',
#   'Johns',
#   'Johnson Controls Technology Company: 1157',
#   'Johnson & Johson Vision Care: 848',
#   'Johns Manvill: 557',
#   'Johnson Matthey Public Limted Company: 504',
#   'Johnson & Johnson: 470',
#   'Johnson Electric SA: 467',
#   'Johnson Matthey PLC: 361',
#   'Johnson & Johnson Consumer Companies: 266',
#   'Johnson Controls: 248',
#   'Johns-Manville: 210'],
#  ['Kabushikikaisha Toshiba',
#   'Kabushikikaisha',
#   'Kabushikikaisha Yakult Honsha: 176',
#   'Kabushikikaisha Ueno Seiyaku Oyo Kenkyujo: 120',
#   'Kabushikikaisha Equos Research Co: 90',
#   'Kabushikikaisha Shofu: 62',
#   'Kabushikikaisha Barudan: 28',
#   'Kabushikikaisha Kojundokagaku Kenkyusho: 16',
#   'Kabushikikaisha Igaki Iryo Sekkei: 15',
#   'Kabushikikaisha Wacom: 13',
#   'Kabushikikaisha Tokyo Keiki: 11',
#   'Kabushikikaisha Kashiwaraseitai: 9'],
#  ['Kao',
#   'Kao',
#   'Kao Coproration: 3011',
#   'Kao Soap Co: 323',
#   'KAOHSIUNG MEDICAL UNIVERISTY: 102',
#   'KAO Germany: 80',
#   'Kao Soap Company: 17',
#   'Kaonetics Technologies: 13',
#   'Kao USA: 11',
#   'Kao Kabushiki Kaisha: 6',
#   'Kaon Interactive: 4',
#   'Kaonmedia Co: 4'],
#  ['Karsten Manufacturing',
#   'Karsten',
#   'Karsten Manufactuing: 2',
#   'Karsten Baumann: 1',
#   'Karsten Solheim: 1',
#   'Karsten Metaal BV: 1',
#   'Karsten Gierss: 1',
#   'Karsten Maufacturing: 1'],
#  ['Kemira OY',
#   'Kemira',
#   'Kemira: 176',
#   'Kemira Chemicals Oy: 45',
#   'Kemira Kemi AB: 15',
#   'Kemira Agro Oy: 8',
#   'Kemira Kemi Aktiebolag: 5',
#   'Kemira Metalkat Oy: 5',
#   'Kemira Growhow Oyj: 5',
#   'Kemira Growhow Oy: 3',
#   'Kemira Water Solutions: 3',
#   'Kemira Pigments Oy: 3'],
#  ['Kerr',
#   'Kerr',
#   'Kerr-McGee Chemical: 137',
#   'Kerr-McGee: 85',
#   "Kerry's Bromeliad Nursery: 29",
#   'Kerr Group: 27',
#   'Kerr Glass Manufacturing: 19',
#   'KerrHawe SA: 14',
#   'Kerr-McGee Refining: 14',
#   'Kerr Manufacturing Company: 13',
#   'Kerry: 13',
#   'Kerr-McGee Coal: 13'],
#  ['Kobe Steel',
#   'Kobe',
#   'Kobe Steel Limited: 1359',
#   'Kobelco Construction Machinery Co: 362',
#   'Kobe: 61',
#   'Kobelco Cranes Co: 44',
#   'Kobe Steel USA: 37',
#   'Kobelco Research Institute: 36',
#   'Kobenhavns Universitet: 16',
#   'Kobelco Eco-Solutions Co: 10',
#   'Kober AG: 10',
#   'Kobe Precision: 8'],
#  ['Korea Kumho Petrochemical Co',
#   'Korea',
#   'Korea Advanced Institute of Scientififc and Technology: 1427',
#   'Korea Institute of Science and Techonology: 1358',
#   'Korea Research Institue of Chemical Technology: 620',
#   'Korea University Research and Business Machines: 351',
#   'Korea Atomic Energy Research: 309',
#   'Korea Institute of Energy Research: 282',
#   'Korea Telecommunication: 278',
#   'Korea Institute of Machinery and Materials: 230',
#   'Korea Electronics Technology Institute: 230',
#   'Korea Kumbo Petrochemical Co: 220'],
#  ['Kraton Polymers US',
#   'Kraton',
#   'Kraton Chemical: 6',
#   'Kraton Polymers: 5',
#   'Kraton Polymer US: 2'],
#  ['Laserline Mfg',
#   'Laserline',
#   'Laserline Manufacturing: 13',
#   'Laserline Company: 8',
#   'LASERLINE GESELLSCHAFT FUR ENTWICKLUNG UND VERTRIEB VON DIODENLASERN MBH: 3',
#   'Laserline Gesellschaft fur Entwicklung und Vertrieb: 1',
#   'Laserline Gesellschaft fur Entwicklung und Vertrieb Von Diddenlasern: 1'],
#  ['Lattice Semiconductor',
#   'Lattice',
#   'Lattice Semiconductor Corp: 695',
#   'Lattice Power (Jiangxi): 24',
#   'Lattice Intellectual Property: 16',
#   'Lattice Intellectual Property Limited: 16',
#   'Lattice Energy: 3',
#   'Lattice: 3',
#   'Lattice Technology: 3',
#   'Lattice Engines: 3',
#   'Lattice Technology Co: 3',
#   'Lattice Semicondutor: 2'],
#  ['Lion Copolymer Geismar',
#   'Lion',
#   'Lion: 261',
#   'Lion Apparel: 53',
#   'Lionel LLC: 51',
#   'Lion Fat and Oil Co: 35',
#   "Lion's Wheel Industrial Corp: 23",
#   'Lion Copolyer Geismar: 21',
#   'Lion Bioscience AG: 16',
#   'Liontech Trains: 12',
#   'Lionbridge Technologies: 9',
#   'Lion Laboratories Limited: 8'],
#  ['Litron Laboratories Limited',
#   'Litron',
#   'Litron Laboratories: 22',
#   'Litronic: 9',
#   'Litronix: 4',
#   'LITRONIK Entwicklungs: 3',
#   'Litronik Batterietechnologie & Co: 3',
#   'LITRONIK Batterietechnologie: 1'],
#  ['Marathon Equipment Company',
#   'Marathon',
#   'Marathon Oil Compamy: 398',
#   'Marathon Ashland Pertoleum: 54',
#   'Marathon Electric Manufacturing Corportion: 33',
#   'Marathon Equipment: 25',
#   'Marathon Petroleum Company: 24',
#   'Marathon Manufacturing Company: 16',
#   'Marathon Technologies: 15',
#   'Marathon Oil Canada: 15',
#   'Marathon GTF Technology: 13',
#   'Marathon: 12'],
#  ['Mattson Technology',
#   'Mattson',
#   'Mattson Technologies: 152',
#   'Mattson Thermal Products: 12',
#   'Mattson Technology Canada: 6',
#   'Mattson Spray Equipment: 4',
#   'Mattson Instruments: 2',
#   'Mattson Inter Tool: 1',
#   'Mattson Technology IP: 1',
#   'Mattson Spray Equipment Company: 1',
#   'Mattson Wet Products: 1'],
#  ['Maxim Integrated Products',
#   'Maxim',
#   'Maxim Integrated: 1028',
#   'Maxim Pharmaceuticals: 26',
#   'Maxim Lighting: 11',
#   'Maxim Intergrated Products: 11',
#   'Maxim: 10',
#   'Maxima Technologies & Systems: 6',
#   'Maxim Silencers: 5',
#   'Maximus: 4',
#   'Maxim Trucks: 4',
#   'Maxim Marketing: 3'],
#  ['Medical Diagnostic Laboratories',
#   'Medical',
#   'Medical Instill Technologies: 189',
#   'Medical Components: 177',
#   'Medical College of Wisconsin Research Foundation: 87',
#   'Medical Engineering: 80',
#   'Medical Diagnostic Lab: 65',
#   'Medical College of Georgia Research Institute: 47',
#   'Medical College of Ohio: 40',
#   'Medical & Biological Laboratories Co: 34',
#   'Medical Specialties: 32',
#   'Medical University of South Carolina Foundation Research Development: 31'],
#  ['MERCK SHARP & DOHME CORP',
#   'MERCK',
#   'Merck Company: 4838',
#   'Merck Patent Gesellaschaft mit Beschrankter Haftung: 3308',
#   'Merck Sharp and Dohme: 1889',
#   'Merck Frosst Canada Ind: 298',
#   'Merck Serono S A: 141',
#   'Merck Canada: 40',
#   'Merckle: 24',
#   'Merck HDAC Research: 12',
#   'Merck Eprova AG: 6',
#   'Merck Sante: 5'],
#  ['Meso Scale Technologies',
#   'Meso',
#   'Meso Scale Technology: 85',
#   'MesoSystems Technology: 27',
#   'MESOBLAST: 19',
#   'Mesoblast Sarl: 9',
#   'Mesophotonics Limited: 8',
#   'MESOCOAT: 4',
#   'Mesoscribe Technologies: 3',
#   'MesoScale Technologies: 3',
#   'MESOBLAST SÃ\x83Â\x83Ã\x82Â\x81RL: 3',
#   'Mesotes Co: 2'],
#  ['Minebea Co',
#   'Minebea',
#   'Minebea Company: 1140',
#   'Minebea Kabushiki-Kaisha: 52',
#   'MINEBEA MITSUMI: 28',
#   'Minebea Motor Manufacturing: 28',
#   'Minebea Kabushiki-Kaisha (Minebea Co): 6',
#   'Minebea Motor Manufacturing Corportion: 1',
#   'Minebea C: 1',
#   'Minebea Col: 1',
#   'Minebea Co (Minebea): 1',
#   'Minebea-Matsushita Motor: 1'],
#  ['Mitsubishi Polyester Film',
#   'Mitsubishi',
#   'Mitsubishi Electric: 8030',
#   'Mitsubishi Heavey Industries: 3353',
#   'Mitsubishi Gas Chemical Co: 1723',
#   'Mitsubishi Chemical: 1622',
#   'Mitsubishi Jidosha Kogyo Kabushiki Kaishi: 1523',
#   'Mitsubishi Jukogyo: 1214',
#   'Mitsubishi Materials: 1142',
#   'Mitsubishi Electric Research Laboratories: 1126',
#   'Mitsubishi Paper Mills Limited: 570',
#   'MITSUBISHI PENCIL COMPANY LIMITED: 469'],
#  ['Nestec S A',
#   'Nestec',
#   'Nestech Machine Systems: 5',
#   'Nestec Machine Systems: 1',
#   'NestecSA: 1'],
#  ['Newport',
#   'Newport',
#   'Newport Fab: 182',
#   'Newport Corp: 128',
#   'Newport Media: 118',
#   'Newport News Shipbuilding and Dry Dock Company: 56',
#   'Newport Pharmaceuticals: 9',
#   'Newport Electronics: 6',
#   'Newport Opticom: 6',
#   'Newport News Shipbuilding: 5',
#   'Newport Medical Instruments: 4',
#   'Newport Laboratories: 3'],
#  ['NGK Spark Plug Co',
#   'NGK',
#   'NGK Insulator: 2846',
#   'NGK Spark Plug: 2216',
#   'NGK Optoceramics Co: 12',
#   'NGK Adrec Co: 11',
#   'NGK Ceramic Device Co: 6',
#   'NGK Metals: 4',
#   'NGKS Corp: 3',
#   'NGK Optoceramics: 3',
#   'NGK Spark Co: 2',
#   'NGK Printer Ceramics Co: 2'],
#  ['Nikon',
#   'Nikon',
#   'Nikon Corportation: 7622',
#   'Nikon Vision Co: 67',
#   'Nikon Precision: 41',
#   'NIKON METROLOGY NV: 20',
#   'Nikon Engineering Co: 17',
#   'Nikon Technologies: 14',
#   'Nikon-Essilor Co: 11',
#   'Nikon Research of America: 11',
#   'Nikon Systems: 6',
#   'Nikon-Trimble Co: 3'],
#  ['Nippon Shokubai Co',
#   'Nippon',
#   'Nippondenso Co: 3145',
#   'Nippon Steel: 2169',
#   'Nippon Telegraph and Telephone: 1987',
#   'Nippon Soken: 1675',
#   'Nippon Shokubi Co: 1379',
#   'Nippon Oil: 1035',
#   'Nippon Sheet Glass Co Limited: 968',
#   'NIPPON STEEL & SUMITOMO METAL: 949',
#   'Nippon Kogaku KK: 836',
#   'Nippon Electric Co: 805'],
#  ['Nissan Motor Co',
#   'Nissan',
#   'Nissan Motor Company Limted: 10643',
#   'Nissan Chemical Industry Co: 1119',
#   'Nissan North America: 540',
#   'Nissan Technical Center North America: 207',
#   'Nissan Diesel Motor Co: 95',
#   'Nissan Jidosha Kabushiki Kaisha: 77',
#   'Nissan Shatai Co: 39',
#   'Nissan Design America: 23',
#   'Nissan Design: 11',
#   'Nissan Research & Development: 8'],
#  ['Nokia Technologies Oy',
#   'Nokia',
#   'Nokia Technologie Oy: 2206',
#   'Nokia Mobile Phones: 1912',
#   'Nokia Solutions and Networks 0y: 853',
#   'Nokia Siemens Networks & Co: 754',
#   'Nokia Telecommunictions OY: 689',
#   'Nokia Networks Oy: 324',
#   'Nokian Tyres PLC: 49',
#   'Nokia of America: 32',
#   'Nokia: 22',
#   'Nokia Graetz: 17'],
#  ['Nordson',
#   'Nordson',
#   'Nordson Coporation: 1496',
#   'Nordson Holdings SARL & Co KG: 5',
#   'NORDSON BKG: 1',
#   'Nordson Extrusion Dies Industries: 1',
#   'Nordson Sangsan: 1'],
#  ['Northrop Grumman Systems',
#   'Northrop',
#   'Northrop: 316',
#   'Northrop Grumman Guidance & Electronics Company: 72',
#   'Northrop Grumman Space & Mission Systems Corp: 28',
#   'Northrop Grumman LITEF: 25',
#   'Northrop Grumman Space & Missions Systems Corp: 7',
#   'Northrop Grumman Ship Systems: 4',
#   'Northrop Gumman: 3',
#   'Northrop Grumann Systems: 2',
#   'Northrop Gumman Systems: 2',
#   'Northrop Gurmman: 2'],
#  ['NOVA Chemicals (International) SA',
#   'NOVA',
#   'Novartis AG: 3289',
#   'Novatek Microelectronics Corp: 846',
#   'Novartis Vaccines & Diagnostics: 292',
#   'NOVA Chemicals (International): 223',
#   'Nova Measuring Instuments: 131',
#   'Novartis Finance: 118',
#   'Novamont SpA: 88',
#   'NovAtel: 78',
#   'Novatel Wireless: 74',
#   'Nova Chemical: 68'],
#  ['Nova Technologies',
#   'Nova',
#   'Novartis AG: 3289',
#   'Novatek Microelectronics Corp: 846',
#   'Novartis Vaccines & Diagnostics: 292',
#   'NOVA Chemicals (International): 223',
#   'Nova Measuring Instuments: 131',
#   'Novartis Finance: 118',
#   'Novamont SpA: 88',
#   'NovAtel: 78',
#   'Novatel Wireless: 74',
#   'Nova Chemical: 68'],
#  ['Novellus Systems',
#   'Novellus',
#   'Novellus Development Company: 1',
#   'Novellus System: 1',
#   'NOVELLUSDX: 1'],
#  ['Novozymes',
#   'Novozymes',
#   'Novozymes Als: 1266',
#   'Novozymes North America: 54',
#   'Novozymes Biotech: 45',
#   'Novozymes Biologicals Holding A/S: 25',
#   'Novozymes Biopharma DK A/S: 16',
#   'Novozymes Adenium Biotech A/S: 8',
#   'Novozymes A/S Patents: 6',
#   'Novozymes Biopharma UK Limited: 4',
#   'Novozymes Biopolymer A/S: 3',
#   'Novozymes Bioindustry: 2'],
#  ['OmniVision Technologies',
#   'OmniVision',
#   'OmniVision Technologie: 840',
#   'Omnivision Technologies (Shanghai) Co: 14',
#   'OmniVision Holding: 11',
#   'OmniVision CDM Optics: 10',
#   'OMNIVISION OPTOELECTRONICS TECHNOLOGIES (SHANGHAI) CO: 2',
#   'Omnivision: 1',
#   'OmniVision Technololgies: 1',
#   'OmniVision Tehnologies: 1'],
#  ['Pacific Biosciences of California',
#   'Pacific',
#   'Pacific Market: 294',
#   'Pacific Biosciences: 258',
#   'Pacific Industrial Company: 117',
#   'Pacific Scientific Company: 100',
#   'Pacific Handy Cutter: 84',
#   'Pacific Marketing (HK) Limited: 76',
#   'Pacific Communication Sciences: 51',
#   'Pacific: 46',
#   'Pacific Bell: 44',
#   'Pacific Scientific Energetic Materials Company: 42'],
#  ['Pacific Light Technologies',
#   'Pacific',
#   'Pacific Market: 294',
#   'Pacific Biosciences: 258',
#   'Pacific Industrial Company: 117',
#   'Pacific Scientific Company: 100',
#   'Pacific Handy Cutter: 84',
#   'Pacific Marketing (HK) Limited: 76',
#   'Pacific Communication Sciences: 51',
#   'Pacific: 46',
#   'Pacific Bell: 44',
#   'Pacific Scientific Energetic Materials Company: 42'],
#  ['Panasonic Intellectual Property of America',
#   'Panasonic',
#   'Panasonic Corportion: 16105',
#   'PANASONIC INTELLECTUAL PROPERTY MANAGEMANT COLTD: 6978',
#   'Panasonic Liquid Crystal Display Co: 962',
#   'Panasonic Electric Works: 401',
#   'PANASONIC HEALTHCARE HOLDINGS CO: 166',
#   'Panasonic Communications CoLtd: 157',
#   'Panasonic EV Energy Co: 107',
#   'Panasonic of North America: 101',
#   'Panasonic Automotive Systems Company of America Division of Panasonic of '
#   'North America: 98',
#   'Panasonic Technologies: 92'],
#  ['Parker-Hannifin', 'ParkerHannifin'],
#  ['Performance Plants',
#   'Performance',
#   'Performance Designed Products: 64',
#   'Performance Contracting: 40',
#   'Performance Indicatior: 38',
#   'Performance Machine: 35',
#   'Performance Industries: 29',
#   'Performance Friction: 24',
#   'Performance Design: 23',
#   'Performance Controls Company: 19',
#   'PERFORMANCE TIRE: 14',
#   'Performance Fibers: 14'],
#  ['Phillips 66 Company',
#   'Phillips',
#   'Phillips Petroleum Company: 4969',
#   'Phillips Petroleum Co: 93',
#   'Phillips Plastics: 55',
#   'Phillips & Temro Industries: 35',
#   'Phillips Screw Company: 33',
#   'Phillips Fibers: 13',
#   'Phillips & Brooks/Gladwin: 9',
#   'Phillips Cables Limited: 9',
#   'Phillips Medical: 8',
#   'Phillips Plastics Corp: 8'],
#  ['PolyPlus Battery Company',
#   'PolyPlus',
#   'PolyPlus Battery Co: 89',
#   'POLYPLUS TRANSFECTION: 2',
#   'POLYPLUS-TRANSFECTION SA: 2',
#   'Polyplus: 2',
#   'PolyPlus Batter Company: 1',
#   'Polyplus Transfection SA: 1',
#   'Polyplus-Transfection: 1',
#   'Polyplus Co: 1'],
#  ['QUALCOMM MEMS Technologies',
#   'QUALCOMM',
#   'Qualcomm Center: 20993',
#   'Qualcomm Mems Technologies Co: 589',
#   'QUALCOMM TECHNOLOGIES: 194',
#   'Qualcomm Atheros: 107',
#   'Qualcomm Innovation Center: 88',
#   'Qualcomm: 27',
#   'Qualcomm Connected Experiences: 17',
#   'QUALCOMM SWITCH CORP: 5',
#   'Qualcomm Iskoot: 3',
#   'QUALCOMM Atheros Technology: 2'],
#  ['Raytheon BBN Technologies Corp',
#   'Raytheon',
#   'Raytheon: 6300',
#   'Raytheon BBN Technology Corp: 196',
#   'Raytheon Canada Limited: 53',
#   'Raytheon TI Systems: 33',
#   'Raytheon Applied Signal Technology: 19',
#   'RAYTHEON CYBER PRODUCTS: 10',
#   'Raytheon Sarcos: 10',
#   'Raytheon Engineers & Constructors: 8',
#   'Raytheon UTD: 7',
#   'Raytheon E-Systems: 7'],
#  ['Raytheon Company',
#   'Raytheon',
#   'Raytheon: 6300',
#   'Raytheon BBN Technology Corp: 196',
#   'Raytheon Canada Limited: 53',
#   'Raytheon TI Systems: 33',
#   'Raytheon Applied Signal Technology: 19',
#   'RAYTHEON CYBER PRODUCTS: 10',
#   'Raytheon Sarcos: 10',
#   'Raytheon Engineers & Constructors: 8',
#   'Raytheon UTD: 7',
#   'Raytheon E-Systems: 7'],
#  ['RJ Reynolds Tobacco Company',
#   'RJ',
#   'RJ Mears: 25',
#   'RJS: 17',
#   'RJ Lee Group: 13',
#   'RJF: 12',
#   'RJ Watches SA: 10',
#   'RJS Technology: 9',
#   'RJR Polymers: 8',
#   'RJR Archer: 7',
#   'RJS Industries: 6',
#   'RJM: 5'],
#  ['Rockwell Automation Technologies',
#   'Rockwell',
#   'Rockwell Cororation: 3436',
#   'Rockwell Automatino Technologies: 2006',
#   'Rockwell Collins: 1818',
#   'Rockwell Technologies: 92',
#   'Rockwell Science Center: 86',
#   'Rockwell Electronic Commerce Technologies: 77',
#   'Rockwell-Rimoldi SpA: 59',
#   'Rockwell Scientific Licensing: 44',
#   'Rockwell Automation Asia Pacific Business Center Pte: 36',
#   'Rockwell Semiconductor Systems: 34'],
#  ['Rolls-Royce North American Technologies', 'RollsRoyce'],
#  ['Rolls-Royce PLC', 'RollsRoyce'],
#  ['Rosemount Aerospace',
#   'Rosemount',
#   'Rosemount Analytical: 78',
#   'Rosemount Office Systems: 15',
#   'Rosemount Engineering Company Limited: 6',
#   'Rosemount Measurement Limited: 3',
#   'Rosemount Estates Pty: 1',
#   'Rosemount Areospace: 1',
#   'Rosemount Aserospace: 1',
#   'Rosemount In: 1'],
#  ['SABIC GLOBAL TECHNOLOGIES BV',
#   'SABIC',
#   'SABIC Innovative Plastics IP B V: 605',
#   'SABIC GLOBAL TECHNOLOGIES: 488',
#   'SABIC SK NEXLENE COMPANY PTE: 3',
#   'SABIC Innovative Platics IP BV: 3',
#   'Sabic Basic Industries: 2',
#   'Sabic Innnovative Plastics IP BV: 1',
#   'SABIC Innovative Plastics IP BV: 1',
#   'Sabic Global Technolgies BV: 1',
#   'SABIC GLOBAL TECHNOLOGIES IP BV: 1',
#   'Sabic Innovative Plastics South America: 1'],
#  ['SAE Magnetics (HK)',
#   'SAE',
#   'Sae Magntics (HK): 723',
#   'Saes Getters SpA: 245',
#   'SAES Pure Gas: 25',
#   'Saebo: 12',
#   'Saeco IPR Limited: 12',
#   'Saehan Industries: 12',
#   'SAE Magnetics (Hong Kong) Limited: 6',
#   'SAES Getter SpA: 6',
#   'Saeilo Enterprises: 4',
#   'SAETA & CO KG: 4'],
#  ['SAINT-GOBAIN ABRASIFS', 'SAINTGOBAIN'],
#  ['Saint-Gobain Ceramics & Plastics', 'SaintGobain'],
#  ['Samsung Electronics',
#   'Samsung',
#   'Samsung Electronics Co Lgd: 81221',
#   'Samsung-Display Co: 11106',
#   'Samsung SDI Co: 5735',
#   'Samsung-Electro Mechanics: 4370',
#   'Samsung Mobile Display Co: 1221',
#   'Samsung Techwin Co: 401',
#   'Samsung Display Devices Co: 389',
#   'Samsung Gwangju Electronics Co: 287',
#   'SAMSUNG MEDISON CO: 220',
#   'Samsung LED Co: 202'],
#  ['Sanofi',
#   'Sanofi',
#   'Sanofi Aventis Deutschland: 1095',
#   'Sanofi SA: 963',
#   'Sanofi-Aventis SA: 385',
#   'Sanofi Pasteur Limited: 157',
#   'Sanofi-Synthlabo: 156',
#   'Sanofi Pasteur Vaxdesign Corp: 21',
#   'Sanofi Pastuer Biologies: 20',
#   'Sanofi Winthrop: 16',
#   'Sanofi-Aventis US: 8',
#   'Sanofi Pasteur Limited/Sanofi Pasteur LimitÃ\x83Â\x83Ã\x82Â©e: 7'],
#  ['SC Johnson & Son',
#   'SC',
#   'Schlumberger Technology Corporatin: 7589',
#   'Schering Akitiengesellschaft: 3147',
#   'Scimed Line Systems: 1833',
#   'Schaeffler Technologies & Co KG: 1820',
#   'Schott Glaswerke: 1135',
#   'SC Johnson: 1075',
#   'SCA Hygiene Products Aktiebolag: 843',
#   'Scientific-Atlanta: 637',
#   'Schneider Electric Industries SAS: 615',
#   'SCM: 479'],
#  ['SD Technologies',
#   'SD',
#   'SDGI HoldingsInc: 337',
#   'SDI Technology: 171',
#   'SDL: 159',
#   'SD3: 112',
#   'SDCmaterials: 68',
#   'SDI: 47',
#   'SDS Biotech K K: 38',
#   'SDB IP Holdings: 32',
#   'SDG: 27',
#   'SD Lizenzverwertungsgesellschaft mbH & Co KG Lenbachplatz 6: 23'],
#  ['Sharp Laboratories of America',
#   'Sharp',
#   'Sharp Corporatoin: 21450',
#   'Sharp Laboratories of Amrica: 2021',
#   'Sharper Image: 214',
#   'Sharp Microelectronics Technology: 64',
#   'Sharps Associates: 17',
#   'Sharper Image Acquisition: 15',
#   'Sharp Manufacturing Company of America: 8',
#   'SHARP FLUIDICS: 8',
#   'Sharper Shape Oy: 8',
#   'Sharpoint: 7'],
#  ['Shimadzu',
#   'Shimadzu',
#   'Shimadzu Research Laboratory (Europe): 24',
#   'Shimadzu Seisakusho: 20',
#   'Shimadzu Research Laboratory (Shanghai) Co: 10',
#   'Shimadzu Mectem: 4',
#   'Shimadzu Research Laboratory: 1',
#   'Shimadzu Sanjo Factory: 1',
#   'Shimadzu Seisakushi: 1',
#   'Shimadzu Mekutemu Kabushiki Kaisya: 1'],
#  ['Siemens',
#   'Siemens',
#   'Siemens Aktiengellschaft: 27906',
#   'Siemens Medical System: 1979',
#   'Siemens Energy: 1161',
#   'Siemens Industry: 732',
#   'Siemens VDO Automotive: 637',
#   'Siemens Automotive L P: 602',
#   'Siemens Energy & Automation: 568',
#   'Siemens Westinghouse Power Corproation: 414',
#   'Siemens Healthcare Diagnostics: 398',
#   'Siemens Corporate Research Corp: 377'],
#  ['Siemens Medical Solutions USA',
#   'Siemens',
#   'Siemens Aktiengellschaft: 27906',
#   'Siemens Medical System: 1979',
#   'Siemens Energy: 1161',
#   'Siemens Industry: 732',
#   'Siemens VDO Automotive: 637',
#   'Siemens Automotive L P: 602',
#   'Siemens Energy & Automation: 568',
#   'Siemens Westinghouse Power Corproation: 414',
#   'Siemens Healthcare Diagnostics: 398',
#   'Siemens Corporate Research Corp: 377'],
#  ['Sigma-Aldrich Co', 'SigmaAldrich'],
#  ['Siliconware Precision Industries Co',
#   'Siliconware',
#   'Siliconware Precision Industries: 585',
#   'Siliconware Precison Industries Co: 2',
#   'Siliconware Precision Industries Co Letd: 2',
#   'Siliconware Precicion Industries Co: 1',
#   'Siliconware Precision Industires Co: 1',
#   'Siliconware Precisionindustries Co: 1'],
#  ['Skidmore',
#   'Skidmore',
#   'Skidmore Owings & Merrill LLP: 18',
#   'Skidmore Owings & Merrill: 3',
#   'Skidmore Engineering Div Buckeye Gear Company: 1',
#   'Skidmore-Wilhelm Manufacturing Co: 1',
#   'Skidmore-Wilhelm Mfg Co: 1'],
#  ['Sony Interactive Entertainment America',
#   'Sony',
#   'Sony Corp: 49610',
#   'Sony Electronics Jointy: 2975',
#   'Sony Computer Entainment America: 2160',
#   'Sony Ericsson Mobile Communicatios AB: 1094',
#   'Sony Mobile Communicatins Japan: 1059',
#   'Sony Interactive Enertainment: 660',
#   'Sony United Kingdom Limited: 437',
#   'Sony Deutschalnd: 361',
#   'Sony Semiconductor Solution: 235',
#   'Sony Chemical: 193'],
#  ['STATS ChipPAC',
#   'STATS',
#   'STATS Chip PAC: 1619',
#   'StatSignal Systems: 17',
#   'Stats (UK) Limited: 14',
#   'StatSignal IPC: 8',
#   'Statspin: 2',
#   'Stats: 2',
#   'Statspin Technologies: 2',
#   'STATS ChipPAC Ptc: 1'],
#  ['STMicroelectronics SA',
#   'STMicroelectronics',
#   'STMicroelectronics (Crolle 2) SAS: 406',
#   'STMicroelectronics Asia Pacific PTE-Singapore: 344',
#   'STMicroelectronics (Grenoble 2) SAS: 287',
#   'STMicroelectronics (Research & Development) Limited: 237',
#   'STMicroelectronics Pvt: 206',
#   'STMicroelectronics (Tours) SAS: 126',
#   'STMicroelectronics (Shenzhen) R&D Co: 100',
#   'STMicroelectronics Design and Application SRO: 44',
#   'STMicroelectronics (Beijing) R&D Company: 29',
#   'STMicroelectronics (R&D): 26'],
#  ['Stora Enso Oyj',
#   'Stora',
#   'Storage Technology Partners 11: 1011',
#   'Stora Enso Oyi: 122',
#   'STORAGECRAFT TECHNOLOGY: 61',
#   'Stora Kopparbergs Bergslags Aktiebolag: 43',
#   'Storart Technology Co: 25',
#   'Stora Enso North America: 14',
#   'Storage Appliance: 12',
#   'Stora Feldmuhle AG: 7',
#   'Storage Computer: 5',
#   'Stora Feldmuhle Aktiengesellschaft: 3'],
#  ['Sun Chemical',
#   'Sun',
#   'Sun Microsystems: 7605',
#   'Sundstrand: 1377',
#   'Sunpower: 589',
#   'Sunbeam Products: 565',
#   'SUN PATENT TRUST: 509',
#   'Sun Chemicals BV: 436',
#   'Suntory Limited: 421',
#   'Suntory Flowers: 411',
#   'Sunonwealth Electric Machines Industry Co: 374',
#   'Sunplus Technology CoLtd: 354'],
#  ['Sun Drilling Products',
#   'Sun',
#   'Sun Microsystems: 7605',
#   'Sundstrand: 1377',
#   'Sunpower: 589',
#   'Sunbeam Products: 565',
#   'SUN PATENT TRUST: 509',
#   'Sun Chemicals BV: 436',
#   'Suntory Limited: 421',
#   'Suntory Flowers: 411',
#   'Sunonwealth Electric Machines Industry Co: 374',
#   'Sunplus Technology CoLtd: 354'],
#  ['Symantec',
#   'Symantec',
#   'Symantec Coporation: 2837',
#   'Symantec Operating: 557',
#   'Symantec Operation: 4',
#   'Symantec Operating System: 1',
#   'Symantec Software: 1'],
#  ['Syngenta Participations AG',
#   'Syngenta',
#   'Syngenta Participation: 1304',
#   'Syngenta Crop Protection: 676',
#   'Syngenta Seeds BV: 225',
#   'Syngenta: 200',
#   'Syngenta Investment: 29',
#   'Syngenta (AT) Limited: 16',
#   'Syngenta Mogen BV: 11',
#   'Syngenta Seed BV: 3',
#   'Syngenta Foundation for Sustainable Agriculture: 1',
#   'Syngenta Crop Science Protection AG: 1'],
#  ['Tanaka Kikinzoku Kogyo KK',
#   'Tanaka',
#   'Tanaka Manufacturing Co: 34',
#   'Tanaka Seimitsu Kogyo Co: 12',
#   'Tanaka Denshi Kogyo Kabushiki Kaisha: 12',
#   'Tanaka Denshi Kogyo KK: 11',
#   'Tanaka Seiki Co: 11',
#   'Tanaka Chemical: 9',
#   'Tanaka Kogyo Co: 9',
#   'Tanaka Limited: 5',
#   'Tanaka Giken Co: 3',
#   'Tanaka Iron Works Co: 3'],
#  ['Tata Consultancy Services Limited',
#   'Tata',
#   'TATA CONSULTANCY SERVICES: 435',
#   'Tata Communications (America): 22',
#   'TATA STEEL IJMUIDEN BV: 21',
#   'Tata Steel Limited: 19',
#   'Tatabanyai Szenbanyak: 16',
#   'TATA STEEL NEDERLAND TECHNOLOGY BV: 11',
#   'Tata Motors Limited: 8',
#   'Tata Institute of Fundamental Research: 6',
#   'Tatara Systems: 6',
#   'Tata Technologies Pte Limited: 5'],
#  ['TDK',
#   'TDK',
#   'TDK Co: 5651',
#   'TDK Electronic Company: 336',
#   'TDK TAIWAN CORP: 55',
#   'TDK-Micronas: 31',
#   'TDK-Lameda: 23',
#   'TDK Taiwan: 19',
#   'TDK RF Solutions: 8',
#   'TDK-Lambda UK Limited: 6',
#   'TDK Systems: 4',
#   'TDK Korea: 3'],
#  ['Teradata US',
#   'Teradata',
#   'Teradata U S: 445',
#   'Teradata Corp: 12',
#   'Teradata: 1',
#   'Teradata Technologies Limited: 1'],
#  ['The Eastern Co',
#   'The',
#   'The Boeing Comapany: 14704',
#   'The Procgter & Gamble Company: 13927',
#   'The United States of America as represented by the Secretary of the Navy: '
#   '13772',
#   'The Regents of the University of Calforinia: 11222',
#   'The United States of America as represented by the Secretary of the Army: '
#   '7862',
#   'The United States of America as represented by the Secretary of the Air '
#   'Force: 4295',
#   'The United States of America as represented by the United States of '
#   'Department of Energy: 4163',
#   'The Black & Decker Company: 4152',
#   'The United States of America as represented by the Administrator of the '
#   'National Aeronautics & Space Administration: 4041',
#   'The Dow Corning: 3070'],
#  ['The Gates',
#   'The',
#   'The Boeing Comapany: 14704',
#   'The Procgter & Gamble Company: 13927',
#   'The United States of America as represented by the Secretary of the Navy: '
#   '13772',
#   'The Regents of the University of Calforinia: 11222',
#   'The United States of America as represented by the Secretary of the Army: '
#   '7862',
#   'The United States of America as represented by the Secretary of the Air '
#   'Force: 4295',
#   'The United States of America as represented by the United States of '
#   'Department of Energy: 4163',
#   'The Black & Decker Company: 4152',
#   'The United States of America as represented by the Administrator of the '
#   'National Aeronautics & Space Administration: 4041',
#   'The Dow Corning: 3070'],
#  ['The Henry M Jackson Foundation for the Advancement of Military Medicine',
#   'The',
#   'The Boeing Comapany: 14704',
#   'The Procgter & Gamble Company: 13927',
#   'The United States of America as represented by the Secretary of the Navy: '
#   '13772',
#   'The Regents of the University of Calforinia: 11222',
#   'The United States of America as represented by the Secretary of the Army: '
#   '7862',
#   'The United States of America as represented by the Secretary of the Air '
#   'Force: 4295',
#   'The United States of America as represented by the United States of '
#   'Department of Energy: 4163',
#   'The Black & Decker Company: 4152',
#   'The United States of America as represented by the Administrator of the '
#   'National Aeronautics & Space Administration: 4041',
#   'The Dow Corning: 3070'],
#  ['The Jackson Laboratory',
#   'The',
#   'The Boeing Comapany: 14704',
#   'The Procgter & Gamble Company: 13927',
#   'The United States of America as represented by the Secretary of the Navy: '
#   '13772',
#   'The Regents of the University of Calforinia: 11222',
#   'The United States of America as represented by the Secretary of the Army: '
#   '7862',
#   'The United States of America as represented by the Secretary of the Air '
#   'Force: 4295',
#   'The United States of America as represented by the United States of '
#   'Department of Energy: 4163',
#   'The Black & Decker Company: 4152',
#   'The United States of America as represented by the Administrator of the '
#   'National Aeronautics & Space Administration: 4041',
#   'The Dow Corning: 3070'],
#  ['The Samuel Roberts Noble Foundation',
#   'The',
#   'The Boeing Comapany: 14704',
#   'The Procgter & Gamble Company: 13927',
#   'The United States of America as represented by the Secretary of the Navy: '
#   '13772',
#   'The Regents of the University of Calforinia: 11222',
#   'The United States of America as represented by the Secretary of the Army: '
#   '7862',
#   'The United States of America as represented by the Secretary of the Air '
#   'Force: 4295',
#   'The United States of America as represented by the United States of '
#   'Department of Energy: 4163',
#   'The Black & Decker Company: 4152',
#   'The United States of America as represented by the Administrator of the '
#   'National Aeronautics & Space Administration: 4041',
#   'The Dow Corning: 3070'],
#  ['Thermo Finnigan',
#   'Thermo',
#   'Thermo King Corp: 428',
#   'Thermo Finnigan LLP: 310',
#   'Thermos LLC: 238',
#   'Thermo Fisher Scientific (Bremen): 148',
#   'Thermo Fisher Scientific SpA: 145',
#   'Thermo Electron: 102',
#   'ThermoTek: 61',
#   'Thermo Electron Scientific Instruments: 57',
#   'Thermo Scientific Portable Analytical Instruments: 43',
#   'Thermos KK: 37'],
#  ['Thermo Fisher Scientific',
#   'Thermo',
#   'Thermo King Corp: 428',
#   'Thermo Finnigan LLP: 310',
#   'Thermos LLC: 238',
#   'Thermo Fisher Scientific (Bremen): 148',
#   'Thermo Fisher Scientific SpA: 145',
#   'Thermo Electron: 102',
#   'ThermoTek: 61',
#   'Thermo Electron Scientific Instruments: 57',
#   'Thermo Scientific Portable Analytical Instruments: 43',
#   'Thermos KK: 37'],
#  ['Toyota Motor Engineering & Manufacturing North America',
#   'Toyota',
#   'Toyota Jidohsa Kabushiki Kaisha: 24345',
#   'Toyota Motor Engineering & Manufacturing North American: 1839',
#   'Toyota Boshoku Kaisha: 697',
#   'Toyota Shatai Kabushiki Kaisya: 138',
#   'Toyota Motor Corp: 111',
#   'Toyota Motor Sales USA: 46',
#   'Toyota Technical Center USA: 44',
#   'Toyota Jidoshi Kabushiki Kaisha: 26',
#   'Toyota Infotechnology Center USA: 23',
#   'Toyota Tsusho: 21'],
#  ['Ube Industries',
#   'Ube',
#   'Ube Industries Limited: 1322',
#   'Uber Technologies: 208',
#   'Ube Machinery Corp: 42',
#   'uBeam: 37',
#   'Ubeeairwalk: 35',
#   'Ube-Nitto Kasei Co: 28',
#   'Ube Material Industries: 27',
#   'Ube Nitto Kasei Co: 10',
#   'Ube Electronics: 8',
#   'Ube Cycon: 8'],
#  ['UCB Pharma SA',
#   'UCB',
#   'UCB Pharma: 230',
#   'UCB SA/NV: 94',
#   'UCB BIOPHARA SPRL: 86',
#   'UCB Societe Anonyme: 18',
#   'UCB Farchim SA: 8',
#   'UCB Manufacturing: 5',
#   'UCB Films PLC Star House: 3',
#   'UCB Chip: 3',
#   'UCBL UNIVERSITE CLAUDE BERNARD DE LYON 1: 2',
#   'UCB: 2'],
#  ['US Smokeless Tobacco Company',
#   'US',
#   'US Philips Cororation: 14016',
#   'Ushio Denki Kabushikikaisha: 664',
#   'USM: 532',
#   'US Synthetic: 370',
#   'Usui Kokusai Sangyo Kabushiki Kaiska: 253',
#   'USG Interiors: 249',
#   'US Department of Energy: 192',
#   'US Environmental Protection Agency: 133',
#   'USV Pharmaceutical: 128',
#   'Usinor-Sacilor Societe Anonyme: 117'],
#  ['Winbond Electronics Corp',
#   'Winbond',
#   'Winbond Electonics: 1101',
#   'Winbond Electronics America: 6',
#   'Winbond Electronics North America: 5',
#   'Winbond Memory Laboratory: 3',
#   'Winbond Electronics NA: 2',
#   'Winbond Electronics (HK): 1',
#   'Winbond Electronics CorpI: 1',
#   'Winbond Electrnics Corp: 1'],
#  ['Yeda Research and Development Co',
#   'Yeda',
#   'Yeda Reearch and Development Co: 960',
#   'Yeda Research and Development Co Weizmann Institute of Science: 40',
#   'Yeda Reseach and Development Co: 2',
#   'Yeda: 2',
#   'Yeda Research & Development Co of Weizmann Institute of Science: 1',
#   'Yeda Research and Development Co Israeli Company of The Weizmann Institute '
#   'of Science: 1',
#   'Yeda Research and Development Company Israeli Company of the Weizmann '
#   'Institute of Science: 1',
#   'Yeda Research and Development Company Limited: 1']]

# %%
out_table = pd.DataFrame (out_rows)
out_table.to_csv ('/Users/sanjay/dev/EAGER/code/patents/corrected_assignees_options.csv', index = True)

# %%
CON.close()

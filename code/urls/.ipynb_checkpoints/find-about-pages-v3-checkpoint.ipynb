# %% [markdown]
# # find-about-pages-v3
# SanjayKAroraPhD@gmail.com <br>
# December 2018
#
# ## Description
# Most of the interesting company information is not on home pages but on about us pages.  This script finds those links from the home pages for further crawling.
#
# ## Change log
# v3 treats this is an exercise for identifying inputs to crawling.
#
# ## TODO:
# * Need to make better use of all pages in the site, e.g., to improve data quality and use additional paragraph data found on non-homepages
# * Standardize firm name cleaning code utility into a universally accessible module
# * Port this to real-time crawler?

# %%
# import data processing and other libraries
import csv
import sys
import requests
import os
import re
import pprint
import pymongo
import traceback
from time import sleep
import requests
import pandas as pd
import io
from IPython.display import display
import time
import numpy as np
from bs4 import BeautifulSoup
import string
from urllib.parse import urlparse, urljoin
import requests

# %%
from boilerpipe.extract import Extractor

# %%
MONGODB_DB = "FirmDB_20181203"
MONGODB_COLLECTION = "pages_depth0"
CONNECTION_STRING = "mongodb://localhost"
username = "scrapy"
password = "eager"
authSource = "FirmDB"
authMechanism='SCRAM-SHA-1'

client = pymongo.MongoClient(CONNECTION_STRING, username=username, password=password, authSource=authSource, authMechanism=authMechanism)
db = client[MONGODB_DB]
col = db[MONGODB_COLLECTION]

OUT_DIR = '/Users/sarora/dev/EAGER/data/orgs/about/'
OUTF = OUT_DIR + 'about_links3.csv'

# %%
# gather unique firm_names from mongodb

def get_firm_aggregates ():
    query = [ { "$group": {"_id":"$firm_name" , "number":{"$sum":1}} } ]
    # test for a specific firm
    # query = [ {"$match":{"firm_name": 'MAHLE International GmbH'}}, { "$group": {"_id":"$firm_name" , "number":{"$sum":1}} } ]
    results = col.aggregate(query)

    mongo_dict = {}
    for result in results:
        key = (result['_id'])
        if key:
            mongo_dict[key[0]] = result['number']
    
    return mongo_dict

results_dict = get_firm_aggregates()
firm_names = results_dict.keys()
print (len(firm_names))
pp = pprint.PrettyPrinter()
pp.pprint(firm_names)
# Out:
# 1152
# dict_keys(['Xintec Inc.', 'W&Wsens Devices', '22nd Century Limited', 'Yamaha Corporation', 'ZENA TECHNOLOGIES', 'Wikipad', 'Wine.com', 'Vizio Inc.', 'WHATSAPP INC.', 'VMware', 'VEECO PRECISION SURFACE PROCESSING LLC', 'WestPoint Home', 'VIASAT INC.', 'DuPont Teijin Films U.S. Limited Partnership', 'Vaxiion Therapeutics', 'Silicon Space Technology Corp.', 'Universal Leaf Tobacco Co.', 'TRIDONIC GMBH & CO KG', 'Valicor', 'ZON', 'Transitions Optical', 'Kabushikikaisha Toshiba', 'Waters Technologies Corporation', 'Virent', 'Nederlandse Organisatie voor toegepast-natuurwetenschappelijk onderzoek TNO', 'Thorn Bioscience LLC', 'Xerox Corporation', 'Metabolix', 'Vascular BioSciences', 'Wizard Labs', 'Casio Computer Co.', 'Crystal Solar Inc.', 'WOVN', 'Wireless Environment', 'Hamilton Sundstrand Corporation', 'Ube Industries', 'UChicago Argonne', 'Weatherford Canada Partnership', 'Vorbeck Materials Corporation', 'Wenger Corporation', 'TECNIUM', 'Wave Energy Conversion Corporation of America', 'Verliant Energy', 'Veracode', 'Tata Consultancy Services Limited', 'Tufts Medical Center', 'Tokyo Ohka Kogyo Co.', 'Transtron Solutions LLC', 'TRANE INTERNATIONAL INC.', 'United Technologies Corporation', 'Unistrut International Corp.', 'Watlow Electric Manufacturing Company', 'NLT TECHNOLOGIES', 'Disney Enterprises', 'Xyleco', 'TT Technologies', 'Total Marketing Services', 'Transposagen Biopharmaceuticals', 'VINDICO NANOBIO TECHNOLOGY INC.', 'Tosoh Corporation', 'Toda Kogyo Corporation', 'Toray Plastics (America)', 'SEEK THERMAL', 'Tersus Environmental', 'Angstron Materials', 'Theraclone Sciences', 'Carl Zeiss Meditec AG', 'The Carbon Cable Company', 'Tokyo Electron Limited', 'Zephyr Energy Systems LLC', 'Yageo Corporation', 'Yeda Research and Development Co.', 'Tela Innovations', 'E. Tech Incorporation', 'Takeda Pharmaceutical Company Limited', 'Tamura Corporation', 'Synopsys', 'Sustainable Technologies', 'Transilwrap Company', 'THYSSENKRUPP INDUSTRIAL SOLUTIONS GMBH', 'Toshiba America Electronic Components', 'Tessera', 'T.H.E.M.', 'SYNTHOMER USA LLC', 'Tyco Electronics Corporation', 'TEKNOR APEX COMPANY', 'EXOS LLC', 'Tapwave', 'TMC Corporation', 'Thorlabs', 'Tarveda Therapeutics', 'Syngenta Participations AG', 'Conexant Systems', 'Southwest Research Institute', 'Integrated Solar Technology', 'Sun Chemical Corporation', 'Sun Synchrony', 'Supremex Inc.', 'SUNSALUTER', 'Terra Caloric', 'SunRun', 'Sumitomo Rubber Industries', 'Stratasys', 'SunEdison', 'STATS ChipPAC', 'Suganit Systems', 'STANDARD ALCOHOL COMPANY OF AMERICA', 'Simbol Inc.', 'Starlight Energy Holdings LLC', 'Star Technology and Research', 'Stablcor Technology', 'SPC International', 'Toray Industries Inc. ', 'Siliconware Precision Industries Co.', 'Silicon Storage Technology', 'SPICE SOLAR', 'SRG Global', 'Solight Solar', 'Solvay Specialty Polymers USA', 'SunCulture Solar Inc.', 'SB ENERGY', 'SOLAZYME', 'Kao Corporation', 'Sola U.S.A. Inc.', 'SolAero Technologies Corp.', 'St. Jude Medical', 'Skidmore', 'Solar-Tectic LLC', 'SOL-ELECTRICA', 'Sanofi', 'Schlumberger Technology Corporation', 'Smith & Nephew', 'Hynix Semiconductor Inc.', 'Singular Bio', 'Pansonic Corporation', 'Nippon Shokubai Co.', 'Semprius', 'SELMAN AND ASSOCIATES', 'Seetron Inc.', 'S. C. Johnson & Son', 'Seagate Technology LLC', 'Sandia Corporation', 'Bluestar Silicones France', 'Schneider Electric USA', 'Sick AG', 'Silicor Materials Inc.', 'Sigma-Aldrich Co. LLC', 'ProNAi Therapeutics', 'Sumco Corporation', 'Silicon Genesis Corporation', 'SICPA Holding SA', 'Sienna Biopharmaceuticals', 'SAE Magnetics (HK) Ltd.', 'Renewable Power Conversion', 'Sweetwater Energy', 'Research Triangle Institute', 'Rockwell Collins', 'Shell Oil Company', 'BAXALTA INCORPORATED', 'Sharp Laboratories of America', 'Quantum Materials Corporation', 'Sensor-Kinesis Corporation', 'Semiconductor Energy Laboratory Co.', 'Zoetis Services LLC', 'SEaB Energy Holdings Ltd.', 'POSiFA MICROSYSTEMS', 'PolyPlus Battery Company', 'Sysmex Corporation', 'Pixe ...

# %%
# find all links that have about, company, and corporate mentions 
# 1. pull down home page
# 2. get a list of all links in Beautiful Soup
# 3. keep only those that match a regex

firm_about_dict = {}
firm_home_dict = {}

# regex to filter in about pages and filter out non-about looking pages
regex_in = re.compile('(about|company|corporate|who.we.are|(^|/)vision|profile|corporate|management|team|history|values|partner)', flags=re.IGNORECASE)
regex_out = re.compile('(order|sale|api|product|company.?home|pdf$)', flags=re.IGNORECASE)
    
def fix_url(url, home_url, domain):
    joined_url = urljoin (home_url, url, allow_fragments=False)
    # needed for company names with embedded urls, e.g., KT Corporation
    found_url = re.findall('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\), ]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', joined_url) 
    if not found_url:
        return ''
    matches = re.split("','", found_url[0]) 
    return matches[0]

def get_domain (url):
    o = urlparse(url)
    domain = o.netloc
    return domain

def get_link_path (url):
    o = urlparse(url)
    path = o.path + o.params + o.query + o.fragment
    return path

def get_about_links_from_home_pages (): 
    for firm_name in firm_names: 
            
        regex = '^' + re.escape(firm_name) + '$'
        results = col.find( {"firm_name": re.compile(regex, re.IGNORECASE)}).sort("depth",pymongo.ASCENDING) 

        result = results[0]
        html = result['html'][0]
        home_url = result['url'][0]
 
        domain = get_domain(home_url).strip('\/')
        
        # print ("Working on " + firm_name + ' at ' + home_url)
        soup = BeautifulSoup(html, 'lxml')
        abouts = {a.get('href'): ' '.join(str(a.string).split()) for a in soup.find_all('a', href=True) 
                  if regex_in.search(get_link_path(a.get('href'))) or regex_in.search(str(a.string))}
        
        abouts_fixed = {fix_url(link, home_url, domain): text for link, text in abouts.items()} 
 
        abouts_clnd = {link: text for link, text in abouts_fixed.items() if re.search(domain, link)}
        abouts_clnd = {link: text for link, text in abouts_clnd.items() 
                       if not regex_out.search(link) and not regex_out.search(text)}
        
        if abouts_clnd:
            firm_about_dict[firm_name] = abouts_clnd

        firm_home_dict[firm_name] = home_url
            
#     pp.pprint (firm_about_dict)
#     pp.pprint (firm_home_dict)

get_about_links_from_home_pages()
# Out:
# {'22nd Century Limited': {'http://www.xxiicentury.com/': 'About Us',
#                           'http://www.xxiicentury.com/history/': 'Company '
#                                                                  'History',
#                           'http://www.xxiicentury.com/our-management/': 'Our '
#                                                                         'Management',
#                           'http://www.xxiicentury.com/profile/': 'Company '
#                                                                  'Profile / '
#                                                                  'Mission'},
#  '3M Innovative Properties Company': {'https://www.3m.com/': 'None',
#                                       'https://www.3m.com/3M/en_US/company-us/': 'None',
#                                       'https://www.3m.com/3M/en_US/company-us/3m-science-applied-to-life/': 'None',
#                                       'https://www.3m.com/3M/en_US/company-us/SDS-search/': 'SDS '
#                                                                                             'Search',
#                                       'https://www.3m.com/3M/en_US/company-us/about-3m/': 'None',
#                                       'https://www.3m.com/3M/en_US/company-us/about-3m/compliance-business-conduct/': 'None',
#                                       'https://www.3m.com/3M/en_US/company-us/about-3m/state-of-science-index-survey/': 'Does '
#                                                                                                                         'science '
#                                                                                                                         'matter?',
#                                       'https://www.3m.com/3M/en_US/company-us/about-3m/technologies/': 'None',
#                                       'https://www.3m.com/3M/en_US/company-us/dmca-copyright-policy/': 'DMCA',
#                                       'https://www.3m.com/3M/en_US/company-us/help-center/': 'Help',
#                                       'https://www.3m.com/3M/en_US/company-us/legal-information/': 'Legal',
#                                       'https://www.3m.com/3M/en_US/company-us/partners-suppliers/': 'Partners '
#                                                                                                     '& '
#                                                                                                     'Suppliers',
#                                       'https://www.3m.com/3M/en_US/company-us/patent/': 'None',
#                                       'https://www.3m.com/3M/en_US/company-us/privacy-policy/': 'Privacy',
#                                       'https://www.3m.com/3M/en_US/company-us/regulatory-information/': 'More '
#                                                                                                         'Regulatory '
#                                                                                                         '& '
#                                                                                                         'Compliance '
#                                                                                                         'Information',
#                                       'https://www.3m.com/3M/en_US/company-us/site-map/': 'Site '
#                                                                                           'Map',
#                                       'https://www.3m.com/3M/en_US/company-us/transport-information-search/': 'Transport '
#                                                                                                               'Information '
#                                                                                                               'Search',
#                                       'https://www.3m.com/3M/en_US/home-improvement-us/': 'Learn '
#                                                                                           'more '
#                                                                                           'about '
#                                                                                           'Home '
#                                                                                           'Improvement'},
#  'ABB AB': {'https://new.abb.com/about': 'About',
#             'https://new.abb.com/about/abb-in-brief': 'ABB in brief',
#             'https://new.abb.com/about/abb-in-brief/group-structure/board-of-directors': 'Board '
#                                                                                          'of '
#                                                                                          'Directors',
#             'https://new.abb.com/about/abb-in-brief/group-structure/executive-committee': 'Executive '
#                                                                                           'Committee',
#             'https://new.abb.com/about/corporate-governance': 'Corporate '
#                                                               'governance',
#             'https://new.abb.com/about/integrity': 'Integrity',
#             'https://new.abb.com/about/supplying': 'Supplying',
#             'https://new.abb.com/about/technology': 'Technology',
#             'https://new.abb.com/channel-partners': 'Channel Partners',
#             'https://new.abb.com/cpm': 'Operations Management Software',
#             'https://new.abb.com/investorrelations': 'About ABB',
#             'https://new.abb.com/investorrelations/corporate-governance/board-and-executive-committee-shareholdings-and-dealings': 'Directors '
#                                                                                                                                    'dealings',
#             'https://new.abb.com/network-management': 'Network Management',
#             'https://new.abb.com/network-management/service': 'Network '
#                                                               'Management',
#             'https://new.abb.com/news/detail/10330/abb-expands-partnerships-at-china-international-import-expo': 'None',
#             'https://new.abb.com/service/lifecycle-management': 'Lifecycle '
#                                                                 'management'},
#  'AC International Inc.': {'http://acinter.com/aboutus.htm': 'None'},
#  'ACACIA RESEARCH GROUP LLC': {'http://acaciaresearch.com/corporate-governance/': 'Corporate '
#                                                                                   'Governance',
#                                'http://acaciaresearch.com/corporate-profile/': 'Corporate '
#                                                                                'Profile',
#                                'http://acaciaresearch.com/history/': 'History'},
#  'ACUCELA INC.': {'https://www.acucela.com/company/index.html': 'COMPANY',
#                   'https://www.acucela.com/company/information/index.html': 'Contact '
#                                                                             'Us'},
#  'ACell': {'https://acell.com/about-us/': 'Who We Are',
#            'https://acell.com/leadership-team/': 'Senior Leadership'},
#  'ADASA INC.': {'https://adasa.com/pages/about-us': 'About'},
#  'ADVANCED INNOVATION CENTER LLC': {'http://aicchile.com/en/': 'About Us',
#                                     'http://aicchile.com/en/nosotros/': 'Team'},
#  'AFMODEL': {'https://afmodels.com/about-become-a-model/': 'None',
#              'https://afmodels.com/about-us/': 'ABOUT US'},
#  'AG ENERGY SOLUTIONS': {'https://ag.energy/about-2/': 'About',
#                          'https://ag.energy/about/': 'Carbon Logic'},
#  'AGC Flat Glass North America': {'https://www.agcglass.com/': 'About AGC',
#                                   'https://www.agcglass.com/contact': 'Contact '
#                                                                       'our '
#                                                                       'world-class '
#                                                                       'customer '
#                                                                       'service '
#                                                                       'team '
#                                                                       'today',
#                                   'https://www.agcglass.com/corporate-information': 'Corporate '
#                                                                                     'Information',
#                                   'https://www.agcglass.com/service-without-limits': 'Learn '
#                                                                                      'more '
#                                                                                      'about '
#                                                                                      "AGC's "
#                                                                                      '"Service '
#                                                                                      'Without '
#                                                                                      'Limits"'},
#  'AGFA-GEVAERT N.V.': {'http://agfa.com/corporate/about-us/agfa-in-the-world/': 'Agfa '
#                                                                                 'in '
#                                                                                 'the '
#                                                                                 'World',
#                        'http://agfa.com/corporate/about-us/history/': 'History',
#                        'http://agfa.com/corporate/about-us/our-company/': 'Our '
#                                                                           'Company',
#                        'http://agfa.com/corporate/about-us/our-company/company-film-meet-the-world-of-agfa/': 'None',
#                        'http://agfa.com/corporate/about-us/technology/': 'Technology',
#                        'http://agfa.com/corporate/contact/': 'webmaster',
#                        'http://agfa.com/corporate/investor-relations/faq-investors-contact/': 'Investor '
#                                                                                               'Relations',
#                        'http://agfa.com/corporate/press/': 'None',
#                        'http://agfa.com/corporate/privacy-and-legal-notice/': 'Privacy '
#                                                                               'and '
#                                                                               'Legal '
#                                                                               'information.',
#                        'http://agfa.com/corporate/privacy-cookie-settings/': 'Read '
#                                                                              'more '
#                                                                              'about '
#                                                                              'how '
#                                                                              'agfa '
#                                                                              'uses '
#                                                                              'cookies.',
#                        'https://www.agfa.com/corporate/': 'None',
#                        'https://www.agfa.com/corporate/about-us/': 'None',
#                        'https://www.agfa.com/corporate/about-us/agfa-in-the-world/': 'Agfa '
#                                                                                      'in '
#                                                                                      'the '
#                                                                                      'World',
#                        'https://www.agfa.com/corporate/about-us/history/': 'History',
#                        'https://www.agfa.com/corporate/about-us/our-company/': 'Our '
#                                                                                'Company',
#                        'https://www.agfa.com/corporate/about-us/our-company/business-groups/': 'Business '
#                                                                                                'Groups',
#                        'https://www.agfa.com/corporate/about-us/our-company/company-film-meet-the-world-of-agfa/': 'Company '
#                                                                                                                    'Film',
#                        'https://www.agfa.com/corporate/about-us/our-company/company-structure/': 'Company '
#                                                                                                  'Structure',
#                        'https://www.agfa.com/corporate/about-us/our-company/manufacturing/': 'Manufacturing',
#                        'https://www.agfa.com/corporate/about-us/our-company/mission/': 'Mission',
#                        'https://www.agfa.com/corporate/about-us/our-company/purchasing/': 'Purchasing',
#                        'https://www.agfa.com/corporate/about-us/our-company/safety-health-and-environment-she/': 'Safety, '
#                                                                                                                  'Health '
#                                                                                                                  'and '
#                                                                                                                  'Environment',
#                        'https://www.agfa.com/corporate/about-us/our-company/safety-health-and-environment-she/cmr/': 'CMR',
#                        'https://www.agfa.com/corporate/about-us/our-company/safety-health-and-environment-she/environmental-policy/': 'Policy',
#                        'https://www.agfa.com/corporate/about-us/our-company/safety-health-and-environment-she/green-marketing/': 'Green '
#                                                                                                                                  'Marketing',
#                        'https://www.agfa.com/corporate/about-us/our-company/safety-health-and-environment-she/roles-responsibilities/': 'Roles '
#                                                                                                                                         '& '
#                                                                                                                                         'Responsibilities',
#                        'https://www.agfa.com/corporate/about-us/our-company/safety-health-and-environment-she/sustainability-reports/': 'Sustainability '
#                                                                                                                                         'Reports',
#                        'https://www.agfa.com/corporate/about-us/technology/': 'Technology',
#                        'https://www.agfa.com/corporate/about-us/technology/ideas-and-proposals/': 'Ideas '
#                                                                                                   'and '
#                                                                                                   'Proposals',
#                        'https://www.agfa.com/corporate/author/eyoqh/': 'Jurgen '
#                                                                        'Wauters',
#                        'https://www.agfa.com/corporate/contact/': 'None',
#                        'https://www.agfa.com/corporate/faq/': 'FAQ',
#                        'https://www.agfa.com/corporate/investor-relations/': 'None',
#                        'https://www.agfa.com/corporate/investor-relations/agfa-share/': 'Click '
#                                                                                         'here '
#                                                                                         'to '
#                                                                                         'see '
#                                                                                         'more '
#                                                                                         'share '
#                                                                                         'data',
#                        'https://www.agfa.com/corporate/investor-relations/analyst-consensus/': 'Analyst '
#                                                                                                'Consensus',
#                        'https://www.agfa.com/corporate/investor-relations/analyst-coverage/': 'Analyst '
#                                                                                               'Coverage',
#                        'https://www.agfa.com/corporate/investor-relations/bonds-exchange-offer/': 'Bonds '
#                                                                                                   'Exchange '
#                                                                                                   'Offer',
#                        'https://www.agfa.com/corporate/investor-relations/corporate-governance/': 'Corporate '
#                                                                                                   'Governance',
#                        'https://www.agfa.com/corporate/investor-relations/corporate-governance/audit-committee/': 'Audit '
#                                                                                                                   'Committee',
#                        'https://www.agfa.com/corporate/investor-relations/corporate-governance/board-of-directors/': 'Board '
#                                                                                                                      'of '
#                                                                                                                      'Directors',
#                        'https://www.agfa.com/corporate/investor-relations/corporate-governance/bylaws/': 'Bylaws',
#                        'https://www.agfa.com/corporate/investor-relations/corporate-governance/corporate-governance-charter/': 'Corporate '
#                                                                                                                                'Governance '
#                                                                                                                                'Charter',
#                        'https://www.agfa.com/corporate/investor-relations/corporate-governance/executive-management/': 'Executive '
#                                                                                                                        'Management',
#                        'https://www.agfa.com/corporate/investor-relations/corporate-governance/nomination-and-remuneration-committee/': 'Nomination '
#                                                                                                                                         'and '
#                                                                                                                                         'Remuneration '
#                                                                                                                                         'Committee',
#                        'https://www.agfa.com/corporate/investor-relations/faq-investors-contact/': 'FAQ '
#                                                                                                    '– '
#                                                                                                    'Investors '
#                                                                                                    'Contact',
#                        'https://www.agfa.com/corporate/investor-relations/financial-calendar/': 'Financial '
#                                                                                                 'Calendar',
#                        'https://www.agfa.com/corporate/investor-relations/investor-events/': 'Investor '
#                                                                                              'Events',
#                        'https://www.agfa.com/corporate/investor-relations/key-figures/': 'Key '
#                                                                                          'Figures',
#                        'https://www.agfa.com/corporate/investor-relations/mailing-lists-e-mail-alerts/': 'Mailing '
#                                                                                                          'lists '
#                                                                                                          '& '
#                                                                                                          'e-mail '
#                                                                                                          'alerts',
#                        'https://www.agfa.com/corporate/investor-relations/reports-and-presentations/': 'Reports '
#                                                                                                        'and '
#                                                                                                        'Presentations',
#                        'https://www.agfa.com/corporate/investor-relations/reports-and-presentations/annual-reports/': 'Annual '
#                                                                                                                       'Reports',
#                        'https://www.agfa.com/corporate/investor-relations/reports-and-presentations/presentations-for-analysts-and-press/': 'Presentations '
#                                                                                                                                             'for '
#                                                                                                                                             'analysts '
#                                                                                                                                             'and '
#                                                                                                                                             'press',
#                        'https://www.agfa.com/corporate/investor-relations/reports-and-presentations/quarterly-results/': 'Quarterly '
#                                                                                                                          'Results',
#                        'https://www.agfa.com/corporate/investor-relations/reports-and-presentations/statutory-accounts/': 'Statutory '
#                                                                                                                           'Accounts',
#                        'https://www.agfa.com/corporate/investor-relations/reports-and-presentations/sustainability-reports/': 'Sustainability '
#                                                                                                                               'Reports',
#                        'https://www.agfa.com/corporate/investor-relations/shareholder-structure/': 'Shareholder '
#                                                                                                    'Structure',
#                        'https://www.agfa.com/corporate/investor-relations/shareholders-meeting/annual-general-meeting/': 'Annual '
#                                                                                                                          'General '
#                                                                                                                          'Meeting',
#                        'https://www.agfa.com/corporate/investor-relations/shareholders-meeting/extraordinary-general-meeting/': 'Extraordinary '
#                                                                                                                                 'General '
#                                                                                                                                 'Meeting',
#                        'https://www.agfa.com/corporate/news-item/agfa-declines-indication-of-interest-by-kanteron-systems/': 'None',
#                        'https://www.agfa.com/corporate/news-item/agfa-gevaert-publiceert-resultaten-voor-het-derde-kwartaal-van-2018-gereglementeerde-informatie/': 'None',
#                        'https://www.agfa.com/corporate/news-item/agfa-gevaert-publishes-its-third-quarter-2018-results-regulated-information/': 'None',
#                        'https://www.agfa.com/corporate/news-item/agfa-graphics-intends-to-close-offset-printing-plate-factory-in-branchburg-new-jersey-usa/': 'None',
#                        'https://www.agfa.com/corporate/news-item/agfa-graphics-plant-sluiting-van-fabriek-voor-offsetdrukplaten-in-branchburg-new-jersey-usa/': 'None',
#                        'https://www.agfa.com/corporate/news-item/agfa-wijst-toenaderingspoging-kanteron-systems-af/': 'None',
#                        'https://www.agfa.com/corporate/news-item/agfas-board-of-directors-co-opts-klaus-rohrig-aoc-as-non-executive-director/': 'None',
#                        'https://www.agfa.com/corporate/news-item/agfas-raad-van-bestuur-coopteert-klaus-rohrig-aoc-tot-niet-uitvoerend-bestuurder/': 'None',
#                        'https://www.agfa.com/corporate/news-item/openbaarmaking-over-een-transparantie-kennisgeving-norges-bank-gereglementeerde-informatie-3/': 'None',
#                        'https://www.agfa.com/corporate/news-item/publication-of-a-transparency-notification-norges-bank-regulated-information-3/': 'None',
#                        'https://www.agfa.com/corporate/press/': 'Press '
#                                                                 'Releases',
#                        'https://www.agfa.com/corporate/support/msds/': 'Safety '
#                                                                        'Data '
#                                                                        'Sheets'},
#  'ALGETERNAL TECHNOLOGIES': {'https://algeternal.com/': 'About Us'},
#  'ALSTOM Technology Ltd': {'https://www.alstom.com/about-cookies': 'Cookie '
#                                                                    'Policy',
#                            'https://www.alstom.com/company/corporate-governance': 'Corporate '
#                                                                                   'governance',
#                            'https://www.alstom.com/company/innovation-drives-our-growth': 'Innovation',
#                            'https://www.alstom.com/company/preferred-partner-mobility-solutions': 'Strategy',
#                            'https://www.alstom.com/finance/financial-share-information-about-alstom': 'Financial '
#                                                                                                       '& '
#                                                                                                       'Share '
#                                                                                                       'information',
#                            'https://www.alstom.com/fulfilling-our-customers-expectations-best-and-most-committed-partners': 'Suppliers',
#                            'https://www.alstom.com/train-manufacturer-sustainable-mobility-maker': 'Company'},
#  'AMPT': {'http://www.ampt.com/': 'Partners',
#           'http://www.ampt.com/company/': 'Company',
#           'http://www.ampt.com/partners/': 'Partners',
#           'http://www.ampt.com/partners/hdpv-alliance/': 'HDPV Alliance',
#           'http://www.ampt.com/partners/inverter-partners/': 'Inverter '
#                                                              'Partners',
#           'http://www.ampt.com/partners/partner-solutions/': 'Partner '
#                                                              'Solutions'},
#  'APPLIED STEMCELL': {'https://www.appliedstemcell.com/about-us': 'About Us',
#                       'https://www.appliedstemcell.com/about-us/careers': 'Careers',
#                       'https://www.appliedstemcell.com/about-us/executive-team': 'Our '
#                                                                                  'Board',
#                       'https://www.appliedstemcell.com/about-us/facility': 'Facility',
#                       'https://www.appliedstemcell.com/about-us/partners': 'Partners'},
#  'ARBOR THERAPEUTICS': {'http://arborpharma.com/about-us/': 'None',
#                         'http://arborpharma.com/team/': 'Executive Team'},
#  'ASCENT SOLAR TECHNOLOGIES': {'http://ascentsolar.com/about.html': 'None',
#                                'http://ascentsolar.com/ir-asti-news-page.html': 'Company '
#                                                                                 'Press '
#                                                                                 'Releases',
#                                'http://ascentsolar.com/ir-company-overview.html': 'Company '
#                                                                                   'Overview',
#                                'http://ascentsolar.com/ir-corporate-governance.html': 'Corporate '
#                                                                                       'Governance'},
#  'ASM America': {'http://www.asm.com/about': 'Go to our About section',
#                  'http://www.asm.com/about/company-profile': 'Company profile',
#                  'http://www.asm.com/about/contact-us': 'Contact us',
#                  'http://www.asm.com/about/corporate-calendar': 'Corporate '
#                                                                 'calendar',
#                  'http://www.asm.com/about/corporate-responsibility': 'Corporate '
#                                                                       'responsibility',
#                  'http://www.asm.com/about/corporate-responsibility/environmental': 'Environmental',
#                  'http://www.asm.com/about/corporate-responsibility/ethics': 'Ethics',
#                  'http://www.asm.com/about/corporate-responsibility/executive-commitment-statement': 'Executive '
#                                                                                                      'Commitment '
#                                                                                                      'Statement',
#                  'http://www.asm.com/about/corporate-responsibility/health-and-safety': 'Health '
#                                                                                         '＆ '
#                                                                                         'safety',
#                  'http://www.asm.com/about/corporate-responsibility/labor': 'Labor',
#                  'http://www.asm.com/about/corporate-responsibility/supply-chain': 'Supply '
#                                                                                    'chain',
#                  'http://www.asm.com/about/history': 'History',
#                  'http://www.asm.com/about/layering-the-future': 'Layering the '
#                                                                  'future',
#                  'http://www.asm.com/about/locations': 'None',
#                  'http://www.asm.com/about/organization': 'Organization',
#                  'http://www.asm.com/about/organization/management-board': 'Management '
#                                                                            'Board',
#                  'http://www.asm.com/about/organization/supervisory-board': 'Supervisory '
#                                                                             'Board',
#                  'http://www.asm.com/about/our-founder': 'Our founder',
#                  'http://www.asm.com/about/our-story': 'Our story',
#                  'http://www.asm.com/about/research-and-our-partners': 'Research '
#                                                                        'and '
#                                                                        'our '
#                                                                        'partners',
#                  'http://www.asm.com/about/strategy-and-focus-areas': 'Strategy '
#                                                                       '＆ focus '
#                                                                       'areas',
#                  'http://www.asm.com/about/strategy-and-focus-areas/breakthrough-technology': 'None',
#                  'http://www.asm.com/about/strategy-and-focus-areas/focus-areas': 'Focus '
#                                                                                   'areas',
#                  'http://www.asm.com/about/strategy-and-focus-areas/mission-and-strategy': 'Mission '
#                                                                                            '＆ '
#                                                                                            'strategy',
#                  'http://www.asm.com/about/supplier-management': 'Supplier '
#                                                                  'management',
#                  'http://www.asm.com/investors/corporate-governance': 'Corporate '
#                                                                       'governance',
#                  'http://www.asm.com/investors/corporate-governance/agm': 'AGM '
#                                                                           '2018',
#                  'http://www.asm.com/investors/corporate-governance/articles-of-association': 'Articles '
#                                                                                               'of '
#                                                                                               'Association',
#                  'http://www.asm.com/investors/corporate-governance/management-board': 'Management '
#                                                                                        'Board',
#                  'http://www.asm.com/investors/corporate-governance/policies': 'Policies',
#                  'http://www.asm.com/investors/corporate-governance/supervisory-board': 'Supervisory '
#                                                                                         'Board',
#                  'http://www.asm.com/investors/corporate-reports': 'Corporate '
#                                                                    'reports',
#                  'http://www.asm.com/investors/corporate-reports/annual-reports-(us-gaap)-forms-20-f': 'US '
#                                                                                                        'GAAP '
#                                                                                                        'Annual '
#                                                                                                        'reports '
#                                                                                                        '/ '
#                                                                                                        'Forms '
#                                                                                                        '20-F',
#                  'http://www.asm.com/investors/corporate-reports/corporate-responsibility-reports': 'Corporate '
#                                                                                                     'Responsibility '
#                                                                                                     'Reports',
#                  'http://www.asm.com/investors/corporate-reports/quarterly-reports': 'Quarterly '
#                                                                                      'reports',
#                  'http://www.asm.com/investors/corporate-reports/statutory-annual-reports-interim-reports-(ifrs)': 'Annual '
#                                                                                                                    '/ '
#                                                                                                                    'Interim '
#                                                                                                                    'Reports '
#                                                                                                                    '(IFRS)',
#                  'http://www.asm.com/technology/key-technologies/all-about-ald': 'All '
#                                                                                  'about '
#                                                                                  'ALD'},
#  'ASML Netherlands B.V.': {'https://www.asml.com/company/all-our-stories/en/s223?rid=57263': 'All '
#                                                                                              'our '
#                                                                                              'stories',
#                            'https://www.asml.com/company/company-calendar/en/s32775': 'Excurion '
#                                                                                       'Day '
#                                                                                       'Belgian '
#                                                                                       'Students '
#                                                                                       'Electronics '
#                                                                                       '& '
#                                                                                       'ICT',
#                            'https://www.asml.com/company/faq/en/s32894': 'FAQ',
#                            'https://www.asml.com/company/how-we-do-it/en/s277?rid=51979': 'How '
#                                                                                           'we '
#                                                                                           'do '
#                                                                                           'it',
#                            'https://www.asml.com/company/in-a-nutshell/en/s277?rid=51978': 'In '
#                                                                                            'a '
#                                                                                            'nutshell',
#                            'https://www.asml.com/company/management/en/s233': 'Management',
#                            'https://www.asml.com/company/organization/en/s277?rid=51984': 'Organization',
#                            'https://www.asml.com/company/our-history/en/s277?rid=51985': 'Our '
#                                                                                          'history',
#                            'https://www.asml.com/company/what-we-do/en/s277?rid=51981': 'What '
#                                                                                         'we '
#                                                                                         'do',
#                            'https://www.asml.com/company/who-we-are/en/s277?rid=51980': 'Who '
#                                                                                         'we '
#                                                                                         'are',
#                            'https://www.asml.com/company/why-we-exist/en/s277?rid=51983': 'Why '
#                                                                                           'we '
#                                                                                           'exist',
#                            'https://www.asml.com/governance/board-of-management/appointment/en/s9571?rid=9559': 'Appointment',
#                            'https://www.asml.com/governance/board-of-management/composition/en/s10093?rid=9558': 'Composition',
#                            'https://www.asml.com/governance/board-of-management/disclosure-committee/en/s9571?rid=9562': 'Disclosure '
#                                                                                                                          'Committee',
#                            'https://www.asml.com/governance/board-of-management/en/s9571?rid=7335': 'Board '
#                                                                                                     'of '
#                                                                                                     'Management',
#                            'https://www.asml.com/governance/board-of-management/remuneration/en/s9571?rid=9560': 'Remuneration',
#                            'https://www.asml.com/governance/board-of-management/securities-holdings/en/s9571?rid=9561': 'Securities '
#                                                                                                                         'Holdings',
#                            'https://www.asml.com/governance/corporate-responsibilty/en/s9644?rid=54970': 'Corporate '
#                                                                                                          'Responsibilty',
#                            'https://www.asml.com/governance/corporate-structure/en/s7264?rid=9518': 'Corporate '
#                                                                                                     'Structure'},
#  'ASTUTE MEDICAL': {'http://www.astutemedical.com/about/intellectual-property': 'AstuteMedical.com/about/intellectualproperty'},
#  'AT&T Corporation': {'https://www.att.com/': 'Partner solutions',
#                       'https://www.att.com/bundles/': 'About Bundles',
#                       'https://www.att.com/home-phone/': 'About home phone',
#                       'https://www.att.com/internet/': 'About Internet',
#                       'https://www.att.com/offers/smart-technology.html': 'About '
#                                                                           'smart '
#                                                                           'technology',
#                       'https://www.att.com/tv/': 'About TV',
#                       'https://www.att.com/wireless/': 'About wireless'},
#  'ATC Technologies': {'http://atctechnologiesinc.com/AboutUs.html': 'None',
#                       'http://atctechnologiesinc.com/AboutUs_LatestNews.html': 'None'},
#  'ATOMERA INCORPORATED': {'http://atomera.com/management/': 'Management',
#                           'http://atomera.com/overview/': 'Company'},
#  'ATTOSTAT': {'http://www.attostat.com/': 'Company',
#               'http://www.attostat.com/about-us': 'Company Information',
#               'http://www.attostat.com/about-us/': 'About Us',
#               'http://www.attostat.com/partnership/': 'Attostat Partnership',
#               'http://www.attostat.com/the-team/': 'The Team'},
#  'AVI BioPharma': {'https://www.sarepta.com/': 'Our Team',
#                    'https://www.sarepta.com/company/board-directors': 'Board '
#                                                                       'of '
#                                                                       'Directors',
#                    'https://www.sarepta.com/company/locations': 'Global '
#                                                                 'Locations',
#                    'https://www.sarepta.com/company/senior-leadership': 'Senior '
#                                                                         'Leadership',
#                    'https://www.sarepta.com/company/strategic-partnerships': 'None',
#                    'https://www.sarepta.com/company/strategic-scientific-advisory-board': 'Strategic '
#                                                                                           '& '
#                                                                                           'Scientific '
#                                                                                           'Advisory '
#                                                                                           'Board',
#                    'https://www.sarepta.com/join-our-team': 'Our Team',
#                    'https://www.sarepta.com/our-company': 'Company',
#                    'https://www.sarepta.com/our-team/career-opportunities': 'None',
#                    'https://www.sarepta.com/our-team/working-sarepta': 'Working '
#                                                                        'at '
#                                                                        'Sarepta'},
#  'AVOGY': {'https://nexgenpowersystems.com/about/': 'About',
#            'https://nexgenpowersystems.com/about/contact/': 'Contact',
#            'https://nexgenpowersystems.com/management/': 'Management'},
#  'AbbVie Inc.': {'https://www.abbvie.com/careers/roles/corporate.html': 'Corporate',
#                  'https://www.abbvie.com/landing/careers/oncology-job-search.html': 'Join '
#                                                                                     'our '
#                                                                                     'team',
#                  'https://www.abbvie.com/our-company.html': 'Our Company',
#                  'https://www.abbvie.com/our-company/about-abbvie.html': 'About '
#                                                                          'AbbVie',
#                  'https://www.abbvie.com/our-company/at-a-glance.html': 'At A '
#                                                                         'Glance',
#                  'https://www.abbvie.com/our-company/ethics-compliance.html': 'Explore '
#                                                                               'Ethics '
#                                                                               '& '
#                                                                               'Compliance',
#                  'https://www.abbvie.com/our-company/ethics-compliance/abbvie-code-of-business-conduct.html': 'AbbVie '
#                                                                                                               'Code '
#                                                                                                               'of '
#                                                                                                               'Business '
#                                                                                                               'Conduct',
#                  'https://www.abbvie.com/our-company/ethics-compliance/ethics-compliance-program.html': 'Ethics '
#                                                                                                         '& '
#                                                                                                         'Compliance '
#                                                                                                         'Program',
#                  'https://www.abbvie.com/our-company/ethics-compliance/physician-payments.html': 'Physician '
#                                                                                                  '& '
#                                                                                                  'Other '
#                                                                                                  'Payments',
#                  'https://www.abbvie.com/our-company/leadership.html': 'Leadership',
#                  'https://www.abbvie.com/our-company/policies-disclosures.html': 'Explore '
#                                                                                  'Policies '
#                                                                                  '& '
#                                                                                  'Disclosures',
#                  'https://www.abbvie.com/our-company/policies-disclosures/protecting-data.html': 'Protecting '
#                                                                                                  'Data',
#                  'https://www.abbvie.com/our-company/positions-views.html': 'Positions '
# ...
#  'SEaB Energy Holdings Ltd.': 'http://seabenergy.com/',
#  'SICPA Holding SA': 'https://www.sicpa.com/',
#  'SII Semiconductor Corporation': 'https://www.ablic.com/en/semicon/',
#  'SOL-ELECTRICA': 'http://sol-electrica.com/',
#  'SOLAZYME': 'http://solazyme.com/',
#  'SOLENA FUELS CORPORATION': 'http://www.solenafuels.com/',
#  'SPC International': 'https://spc-intl.com/(X(1)S(zopdv2d2knciwj2xbkkpfqfz))/?AspxAutoDetectCookieSupport=1',
#  'SPICE SOLAR': 'http://www.spicesolar.com/',
#  'SRG Global': 'http://www.srgglobal.com/',
#  'STANDARD ALCOHOL COMPANY OF AMERICA': 'https://www.standardalcohol.com/?_escaped_fragment_=',
#  'STATS ChipPAC': 'http://www.statschippac.com/',
#  'SUMITOMO WIRING SYSTEMS': 'https://www.sws.co.jp/en/',
#  'SUNSALUTER': 'https://www.sunsaluter.org/',
#  'SYNTHOMER USA LLC': 'https://synthomer.com/?region=AMER&',
#  'Sagacious Investment Group L.L.C.': 'http://www.sagaciousinvestmentservices.com/',
#  'Saint-Gobain Adfors Canada': 'http://www.adfors.com/us/',
#  'Saint-Gobain Ceramics & Plastics': 'https://www.ceramicmaterials.saint-gobain.com/',
#  'Saint-Gobain Performance Plastics Corporation': 'https://www.plastics.saint-gobain.com/',
#  'Samsung Electronics': 'https://www.samsung.com/us/',
#  'Samsung SDI Co.': 'http://samsungsdi.com/',
#  'SanDisk Technologies LLC': 'https://www.sandisk.com/home/ssd/ultra-3d-ssd',
#  'Sandia Corporation': 'https://www.sandia.gov/',
#  'Sangamo BioSciences': 'https://www.sangamo.com/',
#  'Sanken Electric Co.': 'https://www.sanken-ele.co.jp/en/index.php',
#  'Sanofi': 'https://www.sanofi.com/en/',
#  'Sanuvox Technologies': 'https://sanuvox.com/',
#  'Sanyo Electric Co.': 'https://www.panasonic.com/global/corporate/profile/group-companies/sanyo.html',
#  'Schlumberger Technology Corporation': 'https://www.slb.com/',
#  'Schneider Electric Solar Inverters USA': 'https://solar.schneider-electric.com/',
#  'Schneider Electric USA': 'https://www.schneider-electric.us/en/',
#  'Scientific Design Company': 'http://scidesign.com/',
#  'Seagate Technology LLC': 'https://www.seagate.com/',
#  'Seetron Inc.': 'https://www.seetron.com/index.html',
#  'Seiko Epson Corporation': 'https://global.epson.com/',
#  'Seiko Instruments Inc.': 'http://seikoinstruments.com/',
#  'Selas Heat Technology Company LLC': 'https://www.selas.com/',
#  'Selecta Biosciences': 'https://selectabio.com/',
#  'Selkermetrics': 'http://selkermetrics.com/',
#  'Semiconductor Energy Laboratory Co.': 'http://www.sel.co.jp/en/',
#  'Semics Inc.': 'http://www.prober.com/semics-opus3-prober/',
#  'Semprius': 'https://www.semprius.com/',
#  'Senaya': 'http://www.senaya.com/',
#  'Senga Advisors': 'https://www.coengadvisors.com/',
#  'Sensor Electronic Technology': 'http://s-et.com/en/',
#  'Sensor-Kinesis Corporation': 'http://sensor-kinesis.com/',
#  'Sequenom': 'https://www.sequenom.com/',
#  'ServiceNow': 'https://www.servicenow.com/',
#  'Sharp Laboratories of America': 'http://www.sharplabs.com/',
#  'Shell Oil Company': 'https://www.shell.us/',
#  'Shin-Etsu Chemical Co.': 'http://www.shinetsu.co.jp/en/',
#  'Shoals Technologies Group': 'https://www.shoals.com/',
#  'Sick AG': 'https://www.sick.com/de/en/',
#  'Siemens Aktiengesellschaft ': 'https://www.siemens.com/us/en/home/products/automation.html',
#  'Siemens Medical Solutions USA': 'https://usa.healthcare.siemens.com/',
#  'Sienna Biopharmaceuticals': 'https://siennabio.com/',
#  'Sigma-Aldrich Co. LLC': 'https://www.sigmaaldrich.com/',
#  'Silicon Genesis Corporation': 'http://sigen.net/',
#  'Silicon Space Technology Corp.': 'https://www.voragotech.com/',
#  'Silicon Storage Technology': 'http://sst.com/',
#  'Siliconware Precision Industries Co.': 'http://www.spil.com.tw/',
#  'Silicor Materials Inc.': 'https://www.silicormaterials.com/',
#  'Siluria Technologies': 'http://siluria.com/',
#  'Sima Therapeutics': 'http://www.semma-tx.com/',
#  'Simbol Inc.': 'https://www.symbols.com/',
#  'Sinewatts': 'https://www.sinewatts.com/',
#  'Singular Bio': 'https://www.singularbio.com/',
#  'Singulex': 'http://www.singulexclarity.eu/',
#  'Sinton Consulting': 'https://www.sintoninstruments.com/',
#  'Sion Power Corporation': 'https://sionpower.com/',
#  'Sirnaomics': 'http://new.sirnaomics.com/',
#  'SixPoint Materials': 'http://spmaterials.com/',
#  'Skidmore': 'https://www.skidmore.edu/',
#  'Smart Planet Technologies': 'https://www.smartplanettech.com/',
#  'Smith & Nephew': 'http://www.smith-nephew.com/',
#  'SolAero Technologies Corp.': 'https://solaerotech.com/',
#  'Sola U.S.A. Inc.': 'https://www.sola.at/en',
#  'SolaBlock LLC': 'https://www.solablock.com/',
#  'Solaire Generation LLC': 'http://sunpowercarports.com/',
#  'Solan': 'https://www.salon.com/',
#  'Solar Junction Corporation': 'http://sj-solar.com/',
#  'Solar-Tectic LLC': 'http://www.solartecticllc.com/',
#  'SolarCity Corporation': 'https://www.tesla.com/solarpanels?energy_redirect=true',
#  'SolarLego Inc.': 'https://education.lego.com/en-us/products/lego-solar-panel/9667',
#  'SolarReserve Technology': 'https://solarreserve.com/en/technology',
#  'SolarWorld Americas Inc.': 'http://www.solarworld-usa.com/',
#  'Solarmer Energy': 'http://solarmer.com/',
#  'Solight Solar': 'http://www.solight.com/',
#  'Soliton Lasers': 'https://www.soliton.com/',
#  'Solvay Specialty Polymers USA': 'https://www.solvay.com/en/search/products',
#  'Sony Corporation': 'https://www.sony.com/',
#  'Sony Interactive Entertainment America LLC': 'https://www.sie.com/en/index.html',
#  'Soraa': 'https://www.soraa.com/',
#  'Soraa Laser Diode': 'https://www.sldlaser.com/',
#  'Southwest Research Institute': 'https://www.swri.org/',
#  'St. Jude Medical': 'https://www.sjm.com/?alert=RegionSwitchSoftAlert&clset=af584191-45c9-4201-8740-5409f4cf8bdd%3ab20716c1-c2a6-4e4c-844b-d0dd6899eb3a',
#  'St. Microelectronics Inc.': 'https://www.st.com/content/st_com/en.html',
#  'Stablcor Technology': 'http://stablcor.com/',
#  'Stanley Electric Co.': 'http://www.stanley.co.jp/e/',
#  'Star Technology and Research': 'http://star-tech-inc.com/',
#  'Starlight Energy Holdings LLC': 'http://www.starlightenergy.us/',
#  'Starsource Scientific LLC': 'http://starsource.com/about/?41.html',
#  'Stora Enso Oyj': 'https://www.storaenso.com/',
#  'Stratasys': 'https://www.stratasys.com/',
#  'Suganit Systems': 'http://suganit.com/',
#  'Sumco Corporation': 'http://sumco.com/',
#  'Sumitomo Electric Device Innovations': 'http://www.sedi.co.jp/?version=en',
#  'Sumitomo Electric Industries': 'https://global-sei.com/',
#  'Sumitomo Rubber Industries': 'https://sumitomorubber-usa.com/',
#  'Sun Chemical Corporation': 'https://www.sunchemical.com/',
#  'Sun Drilling Products Corporation': 'https://www.sunspecialtyproducts.com/',
#  'Sun Synchrony': 'http://sunsynchrony.com/',
#  'SunCulture Solar Inc.': 'http://solpad.com/',
#  'SunEdison': 'http://sunedison.com/',
#  'SunEdison Semiconductor Limited': 'https://www.gw-semi.com/',
#  'SunLink Corporation': 'https://sunlink.com/',
#  'SunPower Corporation': 'https://us.sunpower.com/',
#  'SunRun': 'https://www.sunrun.com/',
#  'Suncore Photovoltaics': 'http://suncoreus.com/',
#  'Sundrop Fuels': 'http://sundropfuels.com/',
#  'Sungevity Inc.': 'https://sungevity.com/',
#  'Sunlight Photonics Inc.': 'https://www.sunlightphotonics.com/',
#  'Supremex Inc.': 'https://www.supremex.com/',
#  'Surebeam Corporation': 'http://smebeam.com/',
#  'Sustainable Technologies': 'https://sustech.cc/wordpress/',
#  'Swagelok Company': 'https://www.swagelok.com:443/en',
#  'Sweetwater Energy': 'http://sweetwater.us/',
#  'Swift Engineering': 'https://swiftengineering.com/',
#  'Symantec Corporation': 'https://www.symantec.com/',
#  'Synaptic Research': 'https://research.synaptic.co.uk/SynapticResearch/login.asp?t=98266&page=/Default.asp?',
#  'Syngenta Participations AG': 'https://www.syngenta.com/',
#  'Synopsys': 'https://www.synopsys.com/',
#  'Synthetic Genomics': 'https://www.syntheticgenomics.com/',
#  'Sysmex Corporation': 'https://www.sysmex.com/Pages/default.aspx',
#  'System Biosciences': 'https://www.systembio.com/',
#  'T.H.E.M.': 'http://www.them.net/',
#  'TDK Corporation': 'https://www.global.tdk.com/corp/en/index.htm',
#  'TECNIUM': 'http://tecnium.es/',
#  'TEKNOR APEX COMPANY': 'https://www.teknorapex.com/',
#  'THE BOARD INSTITUTE': 'https://theboardinstitute.com/',
#  'THYSSENKRUPP INDUSTRIAL SOLUTIONS GMBH': 'https://www.thyssenkrupp.com/en/',
#  'TMC Corporation': 'http://www.tcm.com/',
#  'TOMOWAVE LABORATORIES': 'http://www.tomowave.com/',
#  'TP Solar': 'https://tpsolar.nl/?lang=en',
#  'TRANE INTERNATIONAL INC.': 'http://www.trane.com/index.aspx',
#  'TRI ALPHA ENERGY': 'https://tae.com/',
#  'TRIDONIC GMBH & CO KG': 'https://www.tridonic.com/com/en/',
#  'TT Technologies': 'http://www.tttechnologies.com/',
#  'Taiwan Semiconductor Manufacturing Company': 'http://tsmc.com/english/default.htm',
#  'Taiyo Ink Mfg. Co.': 'http://taiyo-hd.co.jp/en/group/ink/',
#  'Takara Bio Inc.': 'https://www.takarabio.com/',
#  'Takeda Pharmaceutical Company Limited': 'https://www.takeda.com/',
#  'Tamura Corporation': 'http://tamuracorp.com/',
#  'Tapwave': 'https://tapwave.net/',
#  'Tarveda Therapeutics': 'http://www.tarvedatx.com/',
#  'Tata Consultancy Services Limited': 'https://www.tcs.com/',
#  'Tau Therapeutics LLC': 'http://taurx.com/',
#  'Tela Innovations': 'http://www.tela-inc.com/',
#  'Teledyne Scientific & Imaging': 'http://www.teledyne-si.com/',
#  'Teradata US': 'https://www.teradata.com.au/About-Us',
#  'Terra Caloric': 'https://wellconnectgeo.com/',
#  'Tersus Environmental': 'https://www.tersusenv.com/',
#  'Tessera': 'https://www.tessera.com/',
#  'Texas Research International': 'https://tri-intl.com/',
#  'The Babcock & Wilcox Company': 'https://www.babcock.com',
#  'The Boeing Company': 'http://www.boeing.com/',
#  'The Carbon Cable Company': 'https://www.thecableco.com/',
#  'The Charles Stark Draper Laboratory': 'https://www.draper.com/',
#  'The Eastern Co.': 'http://easterncompany.com/',
#  'The Goodyear Tire & Rubber Company': 'https://www.goodyear.com/',
#  'The Henry M. Jackson Foundation for the Advancement of Military Medicine': 'http://www.hjf.org/',
#  'The Jackson Laboratory': 'https://www.jax.org/',
#  'The Paymaster Corporation': 'https://paymaster.com/',
#  'The Procter & Gamble Company': 'http://www.pg.com/indexRedirect.jsp',
#  'The Samuel Roberts Noble Foundation': 'https://www.noble.org/',
#  'TheGreenCell': 'http://thegreencell.com/',
#  'Theraclone Sciences': 'http://theraclone-sciences.com/home.php',
#  'Thorlabs': 'http://www.thorlabs.com/',
#  'Thorn Bioscience LLC': 'http://thornbioscience.com/',
#  'Tigo Energy': 'https://www.tigoenergy.com/',
#  'Toda Kogyo Corporation': 'http://www.todakogyo.co.jp/english/',
#  'Tokyo Electron Limited': 'https://www.tel.com/',
#  'Tokyo Ohka Kogyo Co.': 'https://www.tok.co.jp/speng',
#  'Toray Industries Inc. ': 'https://www.toray.com/',
#  'Toray Plastics (America)': 'http://toraytpa.com/',
#  'Toshiba America Electronic Components': 'http://toshiba.semicon-storage.com/us/top.html',
#  'Tosoh Corporation': 'https://www.tosoh.com/',
#  'Total Marketing Services': 'https://www.total.com/en',
#  'Toyota Motor Engineering & Manufacturing North America': 'https://www.toyota.com/usa/careers/index.html',
#  'Transilwrap Company': 'https://www.transcendia.com/',
#  'Transitions Optical': 'https://www.transitions.com/en-us/',
#  'Transposagen Biopharmaceuticals': 'http://www.transposagenbio.com/',
#  'Transtron Solutions LLC': 'http://www.transtron.com/en/',
#  'Travis Industries': 'http://travisindustries.com/',
#  'Triple Ring Technologies': 'http://www.tripleringtech.com/',
#  'True-Safe Technologies': 'https://fiatest.com/',
#  'Tufts Medical Center': 'https://www.tuftsmedicalcenter.org/',
#  'Turf Group LLC': 'https://turfgroup.net/',
#  'Turtle Beach Corporation': 'https://www.turtlebeach.com/',
#  'Two Blades Foundation': 'http://2blades.org/',
#  'Tyco Electronics Corporation': 'https://www.te.com/usa-en/home.html',
#  'U S MICROPOWER INC': 'https://micropower-group.com/',
#  'U.S. NUTRACEUTICALS': 'https://www.nutraceutical.com/',
#  'UCB Pharma S.A.': 'https://www.ucb.com/',
#  'UChicago Argonne': 'http://uchicagoargonnellc.org/',
#  'UNISANTIS ELECTRONICS SINGAPORE PTE. LTD.': 'http://www.unisantis.com/',
#  'UOP LLC': 'https://www.phoenix.edu/',
#  'UT-Battelle': 'https://ut-battelle.org/',
#  'UWM Research Foundation': 'https://uwmrf.org/',
#  'Ube Industries': 'https://ube-ind.co.jp/ube/en/index.html',
#  'Uni-Charm Corporation': 'http://www.unicharm.co.jp/english/index.html',
#  'Unifrax I LLC': 'http://www.unifrax.com/',
#  'Uniseal Solutions Inc.': 'https://www.unisealsolutions.com/',
#  'Unistrut International Corp.': 'http://unistrut.us/',
#  'United Microelectronics Corp.': 'http://www.umc.com/English/',
#  'United Technologies Corporation': 'http://www.utc.com/Pages/Home.aspx',
#  'Unity Semiconductor Corporation': 'http://www.unity-sc.com/',
#  'Universal Display Corporation': 'https://oled.com/',
#  'Universal Leaf Tobacco Co.': 'http://www.universalcorp.com/',
#  'VEECO PRECISION SURFACE PROCESSING LLC': 'http://www.veeco.com/technologies-and-products/precision-surface-processing-systems',
#  'VERLASE TECHNOLOGIES LLC': 'http://www.verlase.com/',
#  'VIASAT INC.': 'https://www.viasat.com/',
#  'VINDICO NANOBIO TECHNOLOGY INC.': 'http://vindicoat.com/joomla1/',
#  'VINYLAST': 'http://palisaderail.com/',
#  'VIOLIN MEMORY': 'https://www.violinsystems.com/',
#  'VMware': 'https://www.vmware.com/',
#  'Vadient Optics': 'http://vadient.com/',
#  'Valicor': 'http://trucent.com/',
#  'Vascular BioSciences': 'http://vascularbiosciences.com/',
#  'Vaxiion Therapeutics': 'http://www.vaxiion.com/',
#  'Veracode': 'https://www.veracode.com/',
#  'Veracyte': 'https://www.veracyte.com',
#  'Verliant Energy': 'http://www.verliantenergy.com/',
#  'Virent': 'http://www.virent.com/',
#  'Vizio Inc.': 'https://www.vizio.com/',
#  'Vorbeck Materials Corporation': 'https://vorbeck.com/',
#  'Voxtel': 'http://voxtel-inc.com/',
#  'W&Wsens Devices': 'https://www.wwsensdevices.com/',
#  'WAFERTECH': 'http://www.wafertech.com/en/careers/',
#  'WCA Group LLC': 'https://www.wca-group.com/',
#  'WHATSAPP INC.': 'https://www.whatsapp.com/',
#  'WOVN': 'https://www.wovns.com/',
#  'Warsaw Orthopedic': 'https://mywarsaw.net/',
#  'Waters Technologies Corporation': 'http://waters.com/waters/home.htm?locale=en_US',
#  'Watlow Electric Manufacturing Company': 'https://www.watlow.com/',
#  'Wave Energy Conversion Corporation of America': 'https://weccamerica.com/',
#  'Weatherford Canada Partnership': 'https://www.weatherford.com/en/',
#  'Wenger Corporation': 'https://www.wengercorp.com/',
#  'WestPoint Home': 'https://www.westpointhome.com/',
#  'WiSys Technology Foundation': 'http://wisys.org/',
#  'Wikipad': 'http://www.wikipad.com/',
#  'Winbond Electronics Corp.': 'http://www.winbond.com/hq/',
#  'Wine.com': 'https://www.wine.com/',
#  'Wireless Environment': 'http://wirelessenv.com/',
#  'Wizard Labs': 'https://wizardlabs.us/',
#  'Wostec': 'https://www.westec.org/',
#  'Wyatt Technology Corporation': 'https://www.wyatt.com/',
#  'X DEVELOPMENT LLC': 'https://www.x.org/wiki/Development/',
#  'Xerox Corporation': 'https://www.xerox.com/',
#  'Xintec Inc.': 'http://www.xintec.com.tw/eng/index.aspx',
#  'Xyleco': 'https://www.xyleco.com/',
#  'Yageo Corporation': 'http://www.yageo.com/portal/product/product.jsp',
#  'Yamaha Corporation': 'http://yamaha-motor.com/',
#  'Yeda Research and Development Co.': 'http://yedarnd.com/Overview',
#  'Yissum': 'http://yissum.co.il/',
#  'ZENA TECHNOLOGIES': 'http://xena-technologies.com/',
#  'ZIH Corp.': 'https://www.zebra.com/us/en.html/',
#  'ZON': 'https://www.zon.si/',
#  'Zeno Semiconductor Inc': 'https://www.zenosemi.com/',
#  'Zephyr Energy Systems LLC': 'http://zephyrenergy.com/',
#  'Zoetis Services LLC': 'https://www.zoetis.com/products-services/',
#  'Zygo Corporation': 'https://www.zygo.com/',
#  'aTyr Pharma': 'https://investors.atyrpharma.com/',
#  'bioTheranostics': 'http://www.biotheranostics.com/',
#  'eNow': 'https://enowenergy.com/',
#  'fybr': 'https://fybr.com/',
#  'iBio': 'https://ibioinc.com/',
#  'iNanoBio LLC': 'http://inanobio.com/',
#  'k-Space Associates': 'https://www.k-space.com/',
#  'mVerify Corporation': 'https://numverify.com/',
#  'nLIGHT': 'http://nlight.net/',
#  'nanoComposix': 'https://nanocomposix.com/'}

# %%
# print output to file 
if os.path.isfile(OUTF):
    os.remove(OUTF)

f_out = open(OUTF, 'a')
csv_out = csv.writer(f_out)

# type is either 'about' or 'home' because each will likely need to be processed differently eventually
csv_out.writerow(["firm_name","url","is_about", "descriptor","total_about_pages"]) 

for firm_key, abouts in firm_about_dict.items():
    sorted_links_by_len = sorted(abouts, key=len)
    total_about_pages = len(sorted_links_by_len)
    # pp.pprint(sorted_links_by_len)
    for link in sorted_links_by_len: 
        values = abouts[link]
        descriptor = '|'.join(values.replace('|','').split())
        csv_out.writerow([firm_key, link,1,descriptor,total_about_pages]) 

f_out.flush()
        
for firm_key, home in firm_home_dict.items():
    total_about_pages = 0
    if firm_key in firm_about_dict:
        total_about_pages = len(firm_about_dict[firm_key])
    csv_out.writerow([firm_key, home,0,'',total_about_pages]) 

f_out.flush()
f_out.close()

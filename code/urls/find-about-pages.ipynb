# %% [markdown]
# # find-about-pages
# SanjayKAroraPhD@gmail.com <br>
# December 2018
#
# ## Description
# Most of the interesting company information is not on home pages but on about us pages.  This script finds those links from the home pages for further crawling.
#
# ## Change log
# v3 adds the python boilerplate  api for web page cleaning.
#
# ## TODO:
# * Need to make better use of all pages in the site, e.g., to improve data quality and use additional paragraph data found on non-homepages
# * Standardize firm name cleaning code utility into a universally accessible module
# * Train a more effective boilerplate model to capture meaningful text from firm web pages

# %%
# import data processing and other libraries
import csv
import sys
import requests
import os
import re
import pprint
import pymongo
import traceback
from time import sleep
import requests
import pandas as pd
import io
from IPython.display import display
import time
import numpy as np
from bs4 import BeautifulSoup
import string
from urlparse import urlparse
import requests

# %%
from boilerpipe.extract import Extractor

# %%
MONGODB_DB = "FirmDB_20181203"
MONGODB_COLLECTION = "pages_depth0"
CONNECTION_STRING = "mongodb://localhost"
username = "scrapy"
password = "eager"
authSource = "FirmDB"
authMechanism='SCRAM-SHA-1'

client = pymongo.MongoClient(CONNECTION_STRING, username=username, password=password, authSource=authSource, authMechanism=authMechanism)
db = client[MONGODB_DB]
col = db[MONGODB_COLLECTION]

DATA_DIR = '/Users/sarora/dev/EAGER/data/orgs/depth0_boilerpipe/'

# %%
# gather unique firm_names from mongodb

def get_firm_aggregates ():
    query = [ { "$group": {"_id":"$firm_name" , "number":{"$sum":1}} } ]
    # test for a specific firm
    # query = [ {"$match":{"firm_name": 'Dymax Corporation'}}, { "$group": {"_id":"$firm_name" , "number":{"$sum":1}} } ]
    results = col.aggregate(query)

    mongo_dict = {}
    for result in results:
        key = (result['_id'])
        if key:
            mongo_dict[key[0]] = result['number']
    
    return mongo_dict

results_dict = get_firm_aggregates()
firm_names = results_dict.keys()
print (len(firm_names))
pp = pprint.PrettyPrinter()
pp.pprint(firm_names)
# Out:
# 1152
# [u'Little Kids',
#  u'Daylight Solutions',
#  u'Biocon Limited',
#  u'Sony Corporation',
#  u'Magna International Inc.',
#  u'Supremex Inc.',
#  u'Honeywell International Inc.',
#  u'Aurrion',
#  u'The Jackson Laboratory',
#  u'Hewlett Packard Enterprise Development LP',
#  u'CUMMINS FILTRATION IP',
#  u'Renewable Power Conversion',
#  u'Fuji Electric Co.',
#  u'Canon Kabushiki Kaisha',
#  u'Sola U.S.A. Inc.',
#  u'Chromalox',
#  u'Empire Technology Development LLC',
#  u'Cabot Corporation',
#  u'aTyr Pharma',
#  u'Alcon Research',
#  u'Wyatt Technology Corporation',
#  u'Southwest Research Institute',
#  u'Skidmore',
#  u'Fairchild Semiconductor Corporation',
#  u'Saint-Gobain Performance Plastics Corporation',
#  u'Ideal Power Inc.',
#  u'NuOrtho Surgical',
#  u'Suncore Photovoltaics',
#  u'L-3 Communications Cincinnati Electronics Corporation',
#  u'Medical Diagnostic Laboratories',
#  u'Solarmer Energy',
#  u'Braun Intertec Geothermal',
#  u'ProNAi Therapeutics',
#  u'Amicus Therapeutics',
#  u'Raytheon Company',
#  u'Weatherford Canada Partnership',
#  u'Agilent Technologies',
#  u'Toray Industries Inc. ',
#  u'Christie Digital Systems',
#  u'MICROMIDAS',
#  u'Nissan North America',
#  u'Shin-Etsu Chemical Co.',
#  u'Diamond Innovations',
#  u'Buckman Laboratories International',
#  u'KR Design House',
#  u'Ecovative Design',
#  u'Crystal Solar Inc.',
#  u'Revivicor',
#  u'Caribou Biosciences',
#  u'Uniseal Solutions Inc.',
#  u'OLYMPUS CORPORATION',
#  u'Abbott Molecular Inc.',
#  u'PLEX LLC',
#  u'E. Tech Incorporation',
#  u'Canon',
#  u'Thorn Bioscience LLC',
#  u'Renmatix',
#  u'Toray Plastics (America)',
#  u'Algenol Biotech LLC',
#  u'Cadence Design Systems',
#  u'ACACIA RESEARCH GROUP LLC',
#  u'Riverbed Technology',
#  u'Genesco Inc.',
#  u'CARBO Ceramics Inc.',
#  u'Metabolix',
#  u'TEKNOR APEX COMPANY',
#  u'FLIR Systems',
#  u'Commonwealth Scientific & Industrial Research Organization',
#  u'Alencon Acquisition Co.',
#  u'Beryllium Discovery Corp.',
#  u'Applied Nanostructures',
#  u'Community Power Corporation',
#  u'Soraa Laser Diode',
#  u'GlassPoint Solar',
#  u'Hynix Semiconductor Inc.',
#  u'Northwest Biotherapeutics',
#  u'AFMODEL',
#  u'STATS ChipPAC',
#  u'Crossbar',
#  u'Bruin Biometrics',
#  u'Photon Dynamics',
#  u'PACCAR Inc',
#  u'BAXALTA INCORPORATED',
#  u'Kodak Alaris Inc.',
#  u'J. E. WHITE',
#  u'Calysta',
#  u'TRIDONIC GMBH & CO KG',
#  u'Adlens Beacon',
#  u'GEN-PROBE INCORPORATED',
#  u'LUCERA LABS',
#  u'Tau Therapeutics LLC',
#  u'Toshiba America Electronic Components',
#  u'PPG Industries Ohio',
#  u'BAE Systems Information and Electronic Systems Integration Inc.',
#  u'Alliance for Sustainable Energy',
#  u'Adobe Systems Incorporated',
#  u'GOAL ZERO LLC',
#  u'Handstand Innovations',
#  u'FRONT EDGE TECHNOLOGY INC.',
#  u'FUJIFILM Corporation',
#  u'Dialight Corporation',
#  u'MonoSol',
#  u'Conexant Systems',
#  u'Samsung Electronics',
#  u'ADMA Products',
#  u'Energysolutions',
#  u'Authenex',
#  u'SOLAZYME',
#  u'HGST NETHERLANDS B.V.',
#  u'BioNano Genomics',
#  u'Revera',
#  u'IDEA TREE',
#  u'Moxtek',
#  u'DNA Twopointo',
#  u'VMware',
#  u'Analog Devices',
#  u'NGK Spark Plug Co.',
#  u'SOL-ELECTRICA',
#  u'Toyota Motor Engineering & Manufacturing North America',
#  u'NeoVision LLC',
#  u'Calient Technologies',
#  u'Macronix International Co.',
#  u'DIC Corporation',
#  u'Locus Energy',
#  u'Express Imaging Systems',
#  u'Proterra Inc.',
#  u'HNO Greenfuels',
#  u'Ortho-Clinical Diagnostics',
#  u'Crystalplex Corporation',
#  u'ALSTOM Technology Ltd',
#  u'Envisionit LLC',
#  u'Warsaw Orthopedic',
#  u'American Science and Technology Corporation',
#  u'Tokyo Ohka Kogyo Co.',
#  u'Semiconductor Energy Laboratory Co.',
#  u'Pharmion Corporation',
#  u'Hollywood Trucks',
#  u'Sanuvox Technologies',
#  u'POSiFA MICROSYSTEMS',
#  u'LG Display Co.',
#  u'MAXLINEAR',
#  u'Transilwrap Company',
#  u'MBC Ventures',
#  u'Headway Technologies',
#  u'SixPoint Materials',
#  u'Markel Corporation',
#  u'The Eastern Co.',
#  u'Yeda Research and Development Co.',
#  u'United Microelectronics Corp.',
#  u'Seagate Technology LLC',
#  u'Pixar',
#  u'Bisco',
#  u'Synopsys',
#  u'Karsten Manufacturing Corporation',
#  u'Amkor Technology',
#  u'Lumenco',
#  u'Sustainable Technologies',
#  u'WCA Group LLC',
#  u'Angiotech Pharmaceuticals (US)',
#  u'R.J. Reynolds Tobacco Company',
#  u'Previvo Genetics',
#  u'Biotta LLC',
#  u'SunEdison Semiconductor Limited',
#  u'Bausch & Lomb Incorporated',
#  u'Gilead Sciences',
#  u'Heidelberger Druckmaschinen AG',
#  u'SD Technologies',
#  u'Abbott Point of Care Inc.',
#  u'Antaya Technologies Corporation',
#  u'Aurora Alage',
#  u'Anelva Corporation',
#  u'Claret Medical',
#  u'Angstron Materials',
#  u'Veracyte',
#  u'Magnachip Semiconductor',
#  u'Banpil Photonics',
#  u'Medgenics Medical Israel Ltd.',
#  u'Danisco US Inc.',
#  u'Bristol-Myers Squibb Company',
#  u'Polaris Products LLC',
#  u'GE-Hitachi Nuclear Energy Americas LLC',
#  u'Butamax(TM) Advanced Biofuels LLC',
#  u'Semics Inc.',
#  u'ECOSYNTHETIX LTD.',
#  u'Waters Technologies Corporation',
#  u'Takara Bio Inc.',
#  u'ACell',
#  u'Immunolight',
#  u'The Babcock & Wilcox Company',
#  u'Hollingsworth & Vose Company',
#  u'COOK MEDICAL TECHNOLOGIES LLC',
#  u'Tamura Corporation',
#  u'AG ENERGY SOLUTIONS',
#  u'KOLO TECHNOLOGIES',
#  u'Rima Enterprises',
#  u'Casio Computer Co.',
#  u'Leap Frogg',
#  u'LGS Innovations LLC',
#  u'Ambature',
#  u'Celanese Corporation',
#  u'Zeno Semiconductor Inc',
#  u'Lehigh Technologies',
#  u'Applied Membrane Technologies',
#  u'Transposagen Biopharmaceuticals',
#  u'NEWFIELD THERAPEUTICS CORPORATION',
#  u'Northrop Grumman Systems Corporation',
#  u'NetApp',
#  u'Kronos International Inc',
#  u'Ion Power Group',
#  u'SEaB Energy Holdings Ltd.',
#  u'Chipmos Technologies Inc.',
#  u'Gas Technology Institute',
#  u'St. Microelectronics Inc.',
#  u'Globus Medical',
#  u'SABIC GLOBAL TECHNOLOGIES B.V.',
#  u'The Paymaster Corporation',
#  u'Guardian Industries',
#  u'Tela Innovations',
#  u'VEECO PRECISION SURFACE PROCESSING LLC',
#  u'K.S. INTERNATIONAL CO.',
#  u'Kala Pharmaceuticals',
#  u'Musco Corporation',
#  u'Nanotek Instruments',
#  u'Lintec Corporation',
#  u'NeuMoDx Molecular',
#  u'NanoLab',
#  u'SYNTHOMER USA LLC',
#  u'Fujitsu Limited',
#  u'Nanoholdings',
#  u'Green Extraction Technologies',
#  u'Advanced Analogic Technologies',
#  u'Integrated Device Technology',
#  u'Chevron U.S.A. Inc.',
#  u'Kashiv Pharma',
#  u'Kansai Paint Co.',
#  u'Baker Hughes Incorporated',
#  u'Solar Junction Corporation',
#  u'DHPC TECHNOLOGIES',
#  u'Two Blades Foundation',
#  u'Yamaha Corporation',
#  u'Clearside Biomedical',
#  u'Met Tech Inc.',
#  u'Intellectual Keystone Technology LLC',
#  u'22nd Century Limited',
#  u'Denso Corporation',
#  u'Avon Products',
#  u'PDF Solutions',
#  u'ATTOSTAT',
#  u'TOMOWAVE LABORATORIES',
#  u'Sungevity Inc.',
#  u'Zephyr Energy Systems LLC',
#  u'Sumco Corporation',
#  u'Angaza Design',
#  u'GE Healthcare Dharmacon',
#  u'SPC International',
#  u'Aushon Biosystems',
#  u'TheGreenCell',
#  u'CERION LLC',
#  u'Coloplast A/S',
#  u'Delavau LLC',
#  u'Kabushikikaisha Toshiba',
#  u'Veracode',
#  u'Cura Vac',
#  u'Omron Corporation',
#  u'Princeton Optronics',
#  u'Microchips Biotech',
#  u'Evoqua Water Technologies LLC',
#  u'HRL Laboratories',
#  u'Ansun Biopharma',
#  u'MicroContinuum',
#  u'ExxonMobil Upstream Research Company',
#  u'Sony Interactive Entertainment America LLC',
#  u'SII Semiconductor Corporation',
#  u'PNM',
#  u'AMPT',
#  u'FLOW CONTROL LLC.',
#  u'Great American Duck Races',
#  u'Biocare Medical',
#  u'Swift Engineering',
#  u'Renesas Electronics Corporation',
#  u'Star Technology and Research',
#  u'Praxair S.T. Technology',
#  u'TDK Corporation',
#  u'CAMBRIDGE ENTERPRISE LIMITED',
#  u'Bell Helicopter Textron Inc.',
#  u'Everspin Technologies',
#  u'Alcotek',
#  u'ARBOR THERAPEUTICS',
#  u'WOVN',
#  u'Bitrode Corporation',
#  u'Hyundai Motor Company',
#  u'BASF Plant Science GmbH',
#  u'Hitachi Metals',
#  u'BROADCOM CORPORATION',
#  u'Yageo Corporation',
#  u'Em-Tech LLC',
#  u'McAlister Technologies',
#  u'Dow AgroSciences LLC',
#  u'Biotechnology Foundation',
#  u'Quantum Devices',
#  u'Vascular BioSciences',
#  u'Agrivida',
#  u'RenovaCare Sciences Corp.',
#  u'Nordic Technologies',
#  u'Easel Biotechnologies',
#  u'Optodot Corporation',
#  u'Morpho',
#  u'MERCK SHARP & DOHME CORP.',
#  u'Ajinomoto Althea',
#  u'Combined Energies',
#  u'Flextronics AP',
#  u'Cbrite Inc.',
#  u'PetraSolar',
#  u'Halliburton Energy Services',
#  u'Virent',
#  u'International Technology Center',
#  u'TRI ALPHA ENERGY',
#  u'McElroy Manufacturing',
#  u'Astech',
#  u'DEKA Products Limited Partnership',
#  u'Fianium Ltd.',
#  u'Taiwan Semiconductor Manufacturing Company',
#  u'Sequenom',
#  u'Hunt Energy Enterprises LLC',
#  u'UChicago Argonne',
#  u'Hunter Douglas Inc.',
#  u'SRG Global',
#  u'St. Jude Medical',
#  u'SEIKO NPC Corporation',
#  u'Yissum',
#  u'ADASA INC.',
#  u'Ostendo Technologies',
#  u'Senaya',
#  u'RES USA',
#  u'EXOS LLC',
#  u'BRIGHTLEAF TECHNOLOGIES INC.',
#  u'Archer Daniels Midland Company',
#  u'Avertech',
#  u'Oculus VR',
#  u'Silicon Space Technology Corp.',
#  u'Cleanvantage LLC',
#  u'Novus Technology',
#  u'NCC Nano',
#  u'Enginuity Worldwide',
#  u'Simbol Inc.',
#  u'Agena Bioscience',
#  u'Stratasys',
#  u'U.S. NUTRACEUTICALS',
#  u'Mission Product Holdings',
#  u'GED Intergrated Solution',
#  u'Linne Industries LLC',
#  u'ElectraTherm',
#  u'Intermolecular',
#  u'Kerr Corporation',
#  u'Turf Group LLC',
#  u'Materia',
#  u'Pfizer Inc.',
#  u'Nanoco Technologies',
#  u'Ube Industries',
#  u'Alcatel Lucent',
#  u'EPCOS AG',
#  u'Sick AG',
#  u'Pixelligent Technologies',
#  u'Adynxx',
#  u'Dialogic Corporation',
#  u'NANOBIO CORPORATION',
#  u'Seiko Epson Corporation',
#  u'Babcock Power Services',
#  u'NANO CELL SYSTEMS',
#  u'Illinois Tool Works',
#  u'SunRun',
#  u'Nippon Chemi-Con Corporation',
#  u'SAINT-GOBAIN ABRASIFS',
#  u'W&Wsens Devices',
#  u'King Electric Vehicles Inc.',
#  u'Sunlight Photonics Inc.',
#  u'Global OLED Technology LLC',
#  u'CoolEarth Solar',
#  u'LG NANOH2O',
#  u'Korea Kumho Petrochemical Co.',
#  u'American Piledriving Equipment',
#  u'Gestion Ultra International Inc.',
#  u'Wizard Labs',
#  u'Genentech',
#  u'Sysmex Corporation',
#  u'GCP Applied Technologies Inc.',
#  u'KINO LLC',
#  u'TECNIUM',
#  u'Silicon Storage Technology',
#  u'Allertein Therapeutics',
#  u'MicroLink Devices',
#  u'Bioneer Corporation',
#  u'Nantero',
#  u'Selecta Biosciences',
#  u'Global Filtration Systems',
#  u'Heat Seal LLC',
#  u'Arpin Renewable Energy',
#  u'Xerox Corporation',
#  u'SB ENERGY',
#  u'Lux Bio Group',
#  u"Nationwide Children's Hospital",
#  u'Perkinelmer Holdings',
#  u'American Air Liquide',
#  u'Brewer Science Inc.',
#  u'Solvay Specialty Polymers USA',
#  u'UWM Research Foundation',
#  u'ADVANCED CERAMIC FIBERS',
#  u'BASF Coatings GmbH',
#  u'Pacific Biosciences of California',
#  u'Genisphere',
#  u'Coleman Cable',
#  u'Midrex Technologies',
#  u'TT Technologies',
#  u'Eastman Kodak Company',
#  u'Carbon3D',
#  u'Novon',
#  u'Terra Caloric',
#  u'Mainstream Engineering Corp.',
#  u'Siemens Medical Solutions USA',
#  u'Access Business Group International LLC',
#  u'IMEC',
#  u'Egenera',
#  u'Deployable Space Systems',
#  u'MATERIALS ANALYSIS TECHNOLOGY (US) CORP.',
#  u'SunCulture Solar Inc.',
#  u'KYOCERA DOCUMENT SOLUTIONS INC.',
#  u'Olympus NDT',
#  u'Shell Oil Company',
#  u'One Earth Designs Inc.',
#  u'Red Hat',
#  u'MirTech',
#  u'Momentive Performance Materials GmbH',
#  u'Pinnacle Technology',
#  u'Elwha LLC',
#  u'Inaeris Technologies',
#  u'Genomatica',
#  u'Rolls-Royce PLC',
#  u'Dentsply International',
#  u'Owens-Brockway Glass Container Inc.',
#  u'SolarWorld Americas Inc.',
#  u'GENERAL ELECTRIC COMPANY',
#  u'k-Space Associates',
#  u'QuantumScape Corporation',
#  u'Cisco Technology',
#  u'Avantor Performance Materials',
#  u'Kaneka Corporation',
#  u'Dexerials Corporation',
#  u'Dolby Laboratories Licensing Corporation',
#  u'AgroFresh Inc.',
#  u'Canon U.S. Life Sciences',
#  u'Garland Industries',
#  u'Grandis Inc.',
#  u'AGC Flat Glass North America',
#  u'Solaire Generation LLC',
#  u'Wostec',
#  u'Oracle International Corporation',
#  u'Arkival Technology Corp.',
#  u'Newport Corporation',
#  u'Dow Global Technologies Inc.',
#  u'iNanoBio LLC',
#  u'AltaRock Energy',
#  u'Unifrax I LLC',
#  u'Armageddon Energy Inc.',
#  u'Siemens Aktiengesellschaft ',
#  u'Applied Genetic Technologies Corporation',
#  u'Research Triangle Institute',
#  u'KLA-Tencor Corporation',
#  u'HARMAN INTERNATIONAL INDUSTRIES',
#  u'Brookhaven Science Associates LLC ',
#  u'nanoComposix',
#  u'Nordson Corporation',
#  u'Federal Signal Corporation',
#  u'Imperial Innovations Limited',
#  u'Crestovo LLC',
#  u'OrbusNeich Medical',
#  u'Minebea Co.',
#  u'Delphi Technologies',
#  u'Soraa',
#  u'Adhesives Research',
#  u'Singular Bio',
#  u'CP KELCO APS',
#  u'Roche Molecular Systems',
#  u'Proton Power',
#  u'Sanyo Electric Co.',
#  u'Hitachi High-Technologies Corporation',
#  u'ITN Energy Systems',
#  u'Deep Science',
#  u'Invensas Corporation',
#  u'Verliant Energy',
#  u'Johnson & Johnson Vision Care',
#  u'KJ BIOSCIENCES LLC',
#  u'Johnson & Johnson Consumer Companies',
#  u'Thorlabs',
#  u'Tessera',
#  u'Osram Sylvania Inc.',
#  u'BlackBerry Limited',
#  u'Sun Chemical Corporation',
#  u'Kajima Corporation',
#  u'Mitsubishi Metal Corporation',
#  u'TP Solar',
#  u'Aerogen',
#  u'OPTERRA ENERGY SERVICES',
#  u'Wikipad',
#  u'Global Solar Water Power Systems',
#  u'Furukawa Electric Co.',
#  u'Stablcor Technology',
#  u'Sensor Electronic Technology',
#  u'Sweetwater Energy',
#  u'NanoTech Lubricants',
#  u'The Samuel Roberts Noble Foundation',
#  u'WiSys Technology Foundation',
#  u'Seiko Instruments Inc.',
#  u'Reliance Controls Corporation',
#  u'Auterra',
#  u'Sumitomo Electric Device Innovations',
#  u'NovaSolix',
#  u'Pharmatrophix',
#  u'Microchip Technology Incorporated',
#  u'Sima Therapeutics',
#  u'Genomic Health',
#  u'Carestream Health',
#  u'Valicor',
#  u'Avtaec Limited',
#  u'GTherm',
#  u'Saint-Gobain Adfors Canada',
#  u'Evernote Corporation',
#  u'Cree',
#  u'IDEX Health & Science LLC',
#  u'Qiagen GmbH',
#  u'Echogen Power Systems',
#  u'Lion Copolymer Geismar',
#  u'Nanoridge Materials',
#  u'Rebellion Photonics',
#  u'Big Belly Solar',
#  u'Nokomis',
#  u'G.D.O. Inc',
#  u'BTU International',
#  u'VINDICO NANOBIO TECHNOLOGY INC.',
#  u'Swagelok Company',
#  u'Magnolia Optical Technologies',
#  u'PolyPlus Battery Company',
#  u'Ford Global Technologies',
#  u'Bayer Cropscience AG',
#  u'EMD Technologies Inc.',
#  u'Nederlandse Organisatie voor toegepast-natuurwetenschappelijk onderzoek TNO',
#  u'Nexcom Technology',
#  u'AT&T Corporation',
#  u'Floadia Corporation',
#  u'Entech Solar',
#  u'Amgen Fremont Inc.',
#  u'PortaFire',
#  u'Ormat Technologies Inc.',
#  u'JAC Products Inc.',
#  u'AstenJohnson',
#  u'MCI',
#  u'Boston Scientific Scimed',
#  u'Xyleco',
#  u'Bigelow Aerospace',
#  u'Sienna Biopharmaceuticals',
#  u'Integrated Solar Technology',
#  u'FULL CIRCLE BIOCHAR',
#  u'bioTheranostics',
#  u'JFE STEEL CORPORATION',
#  u'Zygo Corporation',
#  u'Cetac Technologies Inc.',
#  u'Novozymes A/S',
#  u'fybr',
#  u'Da Yu Enterprises',
#  u'Adtran',
#  u'HOWARD INDUSTRIES',
#  u'NanoGram Corporation',
#  u'GENERAL MOTORS LLC',
#  u'Quallion LLC',
#  u'Ignis Innovation',
#  u'Mumetel',
#  u'Stora Enso Oyj',
#  u'Livetv',
#  u'Dermazone Solutions',
#  u'Industrial Technology Research Institute',
#  u'First Solar',
#  u'Inphenix',
#  u'Lockheed Martin Corporation',
#  u'Eaton Corporation',
#  u'Meso Scale Technologies',
#  u'DSP Group LTD.',
#  u'Evri',
#  u'Abbott Cardiovascular Systems Inc.',
#  u'Solan',
#  u'ZENA TECHNOLOGIES',
#  u'Soliton Lasers',
#  u'Achushnet Company',
#  u'LIQUID X PRINTED METALS',
#  u'Andritz Inc.',
#  u'GOLBA LLC',
#  u'Innovation Hammer',
#  u'Conversant Intellectual Property Management Inc.',
#  u'Pacific Industrial Development Corporation',
#  u'Infinera Corporation',
#  u'Roche Diagnostics GmbH',
#  u'UT-Battelle',
#  u'BP Corporation North America Inc.',
#  u'Envision Solar International',
#  u'Avalanche Technology',
#  u'Bestway',
#  u'Nikon Corporation',
#  u'Nippon Shokubai Co.',
#  u'Apple Inc.',
#  u'Janssen Biotech',
#  u'Mitsubishi Electric Corporation',
#  u'JSR Corporation',
#  u'Cross Match Technologies',
#  u'Tokyo Electron Limited',
#  u'CELLTRION',
#  u'Kamtec',
#  u'Faurecia Interior Systems',
#  u'FUJIFILM Dimatix',
#  u'Pansonic Corporation',
#  u'Codexis',
#  u'Applied Optoelectronics',
#  u'POET Research',
#  u'Sumitomo Rubber Industries',
#  u'MANUFACTURING RESOURCES INTERNATIONAL',
#  u'Greatbatch Ltd.',
#  u'IDEALAB',
#  u'Nthdegree Technologies Worldwide Inc.',
#  u'Fina Technology',
#  u'Corporation for National Research Initiatives',
#  u'Ablexis',
#  u'AbbVie Inc.',
#  u'FastCAP Systems Corporation',
#  u'Professional Compounding Centers of America',
#  u'Sensor-Kinesis Corporation',
#  u'Molecular Rebar Design',
#  u'GLIKNIK INC.',
#  u'Luna Innovations Incorporated',
#  u'Opel Solar',
#  u'VINYLAST',
#  u'Bostik',
#  u'OSI Optoelectronics',
#  u'The Procter & Gamble Company',
#  u'Cornell Research Foundation',
#  u'CNH Industrial America LLC',
#  u'Microsemi SoC Corporation',
#  u'NOK Corporation',
#  u'Bi-Modal Corporation',
#  u'E Ink Corporation',
#  u'Wenger Corporation',
#  u'Tufts Medical Center',
#  u'Cedar Ridge Research',
#  u'Global Eagle Entertainment Inc.',
#  u'JNC Corporation',
#  u'Synaptic Research',
#  u'KT Corporation',
#  u'Intuitive Surgical Operations',
#  u'FutureWei Technologies',
#  u'GLYCON LLC',
#  u'S. C. Johnson & Son',
#  u'Solar-Tectic LLC',
#  u'Marine Polymer Technologies',
#  u'Arcturus Therapeutics',
#  u'T.H.E.M.',
#  u'SolAero Technologies Corp.',
#  u'Transtron Solutions LLC',
#  u'Atleisure LLC',
#  u'Nokia Corporation',
#  u'STANDARD ALCOHOL COMPANY OF AMERICA',
#  u'Adaptive Biotechnologies Corp.',
#  u'Brother International Corporation',
#  u'Amprius',
#  u'Vadient Optics',
#  u'Shoals Technologies Group',
#  u'Colgate-Palmolive Company',
#  u'Centre de Recherche Industrielle du Quebec',
#  u'Boehringer Ingelheim Vetmedica GmbH',
#  u'Boehringer Ingelheim International GmbH',
#  u'Inventus Holdings',
#  u'Rio Grande Valley Sugar Growers',
#  u'Hoya Corporation',
#  u'Life Technologies Corporation',
#  u'Dynamic Solutions Worldwide',
#  u'Starlight Energy Holdings LLC',
#  u'Grain Processing Corporation',
#  u'nLIGHT',
#  u'Fenwal',
#  u'CLEARSIGN COMBUSTION CORPORATION',
#  u'Incept LLC',
#  u'ZON',
#  u'Acorn Technologies',
#  u'True-Safe Technologies',
#  u'Polysar Corporation',
#  u'SunLink Corporation',
#  u'Sangamo BioSciences',
#  u'Cima NanoTech Israel Ltd.',
#  u'Tata Consultancy Services Limited',
#  u'KOLON INDUSTRIES',
#  u'Heraeus Precious Metals North America Conshohocken LLC',
#  u'Instron Corporation ',
#  u'Robert Bosch GmbH',
#  u'Biological Dynamics',
#  u'Complete Genomics',
#  u'MICROSOFT TECHNOLOGY LICENSING',
#  u'H R D CORPORATION',
#  u'Kureha Corporation',
#  u'Carver Scientific',
#  u'ATC Technologies',
#  u'WHATSAPP INC.',
#  u'Universal Display Corporation',
#  u"CSEM Centre Suisse d'Electronique et de Microtechnique SA-Recherche et Developpement",
#  u'SolaBlock LLC',
#  u'Redwood Systems',
#  u'HIQ SOLAR',
#  u'Novus Energy LLC',
#  u'DECA Technologies Inc.',
#  u'Pioneer Energy',
#  u'Kemira OY',
#  u'Sinewatts',
#  u'ESCAPE THERAPEUTICS',
#  u'OmniVision Technologies',
#  u'Monsanto Technology LLC',
#  u'Pardev',
#  u'Formula Plastics',
#  u'Green Solar Transportation',
#  u'eNow',
#  u'Phillips 66 Company',
#  u'Cool Planet Energy Systems',
#  u'Atom Nanoelectronics',
#  u'The Boeing Company',
#  u'Chemtreat',
#  u'Electrovaya Inc.',
#  u'ACUCELA INC.',
#  u'Hon Hai Precision Industry Co.',
#  u'Smith & Nephew',
#  u'Eastman Chemical Company',
#  u'UNISANTIS ELECTRONICS SINGAPORE PTE. LTD.',
#  u'Neural Signals',
#  u'Vorbeck Materials Corporation',
#  u'Mattson Technology',
#  u'Nvidia Corporation',
#  u'Nanoquantum Sciences',
#  u'PAX Scientific',
#  u'UCB Pharma S.A.',
#  u'INFINEUM INTERNATIONAL LIMITED',
#  u'ExxonMobil Chemical Patents Inc.',
#  u'Koch Biological Solutions',
#  u'INTEVAC',
#  u'Texas Research International',
#  u'Blue Sea Systems',
#  u'Electronic Warfare Associates',
#  u'Ricoh Company Limited',
#  u'SunPower Corporation',
#  u'SolarLego Inc.',
#  u'SUNSALUTER',
#  u'Nanocopocia',
#  u'GENCO SCIENCES LLC',
#  u'Amtech Systems',
#  u'mVerify Corporation',
#  u'Dana Corporation',
#  u'Sanofi',
#  u'SanDisk Technologies LLC',
#  u'Autonomic Materials',
#  u'CI4 Technologies',
#  u'Adeka Corporation',
#  u'THYSSENKRUPP INDUSTRIAL SOLUTIONS GMBH',
#  u'Universal Leaf Tobacco Co.',
#  u'Poly-Med',
#  u'Harris Corporation',
#  u'Taiyo Ink Mfg. Co.',
#  u'RF Micro Devices',
#  u'Disney Enterprises',
#  u'INVISTA North America S.a.r.l.',
#  u'Symantec Corporation',
#  u'Transitions Optical',
#  u'Teledyne Scientific & Imaging',
#  u'Sundrop Fuels',
#  u'NEC Corporation',
#  u'Production Resource Group',
#  u'Incyte Holdings Corporation',
#  u'SICPA Holding SA',
#  u'Innolux Corporation',
#  u'DuPont Teijin Films U.S. Limited Partnership',
#  u'ServiceNow',
#  u'Travis Industries',
#  u'All Power Labs',
#  u'HM3 Energy',
#  u'Lextar Electronics Corp.',
#  u'Battelle Memorial Institute',
#  u'LG Electronics Inc.',
#  u'Roll-N-Lock Corporation',
#  u'SunEdison',
#  u'Synthetic Genomics',
#  u'TRANE INTERNATIONAL INC.',
#  u'Propagation Research Associates',
#  u'Industrial Science & Technology Network',
#  u'SOLENA FUELS CORPORATION',
#  u'II-VI Incorporated',
#  u'SELMAN AND ASSOCIATES',
#  u'Pegatron Corporation',
#  u'Allison Transmission',
#  u'ASM America',
#  u'Sinton Consulting',
#  u'Hysitron Incorporated',
#  u'PeterBrod Corp.',
#  u'Daikin Industries',
#  u'NeoPhotonics Corporation',
#  u'Litron Laboratories Limited',
#  u'ConocoPhillips Company',
#  u'AC International Inc.',
#  u'PolyOne Corporation',
#  u'Forest Concepts',
#  u'Nanospectra Biosciences',
#  u'Glucan Biorenewables LLC',
#  u'GOJO Industries',
#  u'New England Biolabs',
#  u'Genzyme Corporation',
#  u'ASTUTE MEDICAL',
#  u'UOP LLC',
#  u'Quantapore',
#  u'Marathon Equipment Company',
#  u'Johnson Controls Technology Company',
#  u'EMC Corporation',
#  u'PELLION TECHNOLOGIES',
#  u'Interface Performance Materials',
#  u'Paratek Pharmaceuticals',
#  u'NLT TECHNOLOGIES',
#  u'DiscoveRx Corporation',
#  u'Tyco Electronics Corporation',
#  u'MILLENIUM SYNTHFUELS CORPORATION',
#  u'Nutech Ventures',
#  u'Plasma-Therm',
#  u'Longhorn Vaccines and Diagnostics',
#  u'Elenion Technologies',
#  u'Michigan Biotechnology Institute',
#  u'Galectin Therapeutics',
#  u'Alnylam Pharmaceuticals',
#  u'APPLIED STEMCELL',
#  u'MIETAMARK GENETICS',
#  u'AIR PRODUCTS AND CHEMICALS',
#  u'Interez',
#  u'Uni-Charm Corporation',
#  u'Atonometrics',
#  u'Performance Plants',
#  u'Syngenta Participations AG',
#  u'Cook Biotech Incorporated',
#  u'Selkermetrics',
#  u'Helios Focus LLC',
#  u'Acer Incorporated',
#  u'B.G. Negev Technologies and Applications Ltd.',
#  u'The Goodyear Tire & Rubber Company',
#  u'Basell Polyolefine GmbH',
#  u'VIASAT INC.',
#  u'Coactive Drive Corporation',
#  u'Starsource Scientific LLC',
#  u'AVOGY',
#  u'Schneider Electric USA',
#  u'WAFERTECH',
#  u'BASF',
#  u'Dymax Corporation',
#  u'InView Technology Corporation',
#  u'Conoco Inc.',
#  u'Atrium Medical Corporation',
#  u'Akron Polymer Systems',
#  u'Cardiva Medical',
#  u'Columbia Insurance Company',
#  u'Altivera',
#  u'AROG PHARMACEUTICALS',
#  u'Liquidia Technologies',
#  u'GE Healthcare Limited',
#  u'Abengoa Bioenergy New Technologies',
#  u'Kobe Steel',
#  u'Bio-Rad Laboratories',
#  u'Smart Planet Technologies',
#  u'Arrowhead Center',
#  u'Piksel',
#  u'Kinetech Power Company LLC',
#  u'Delta Electronics',
#  u'Humanetics Corporation',
#  u'Newlans',
#  u'Ivoclar Vivadent AG',
#  u'Parion Sciences',
#  u'Biosphere Medical',
#  u'GOSOLARLIFE',
#  u'Biosense Webster (Israel) Ltd.',
#  u'Stanley Electric Co.',
#  u'Sandia Corporation',
#  u'PQ CORPORATION',
#  u'Applied Materials',
#  u'Hadasit Medical Research Services & Development Company Ltd.',
#  u'Rohm and Haas Electronic Materials LLC',
#  u'Amberwave Inc.',
#  u'Entegris',
#  u'Kulite Semiconductor Products',
#  u'SolarCity Corporation',
#  u'Surebeam Corporation',
#  u'SAMSUNG DISPLAY CO.',
#  u'Masimo Semiconductor',
#  u'Oceanit Laboratories',
#  u'Medicis Pharmaceutical Corporation',
#  u'Triple Ring Technologies',
#  u'Accuri Cytometers',
#  u'Tapwave',
#  u'Saint-Gobain Ceramics & Plastics',
#  u'VIOLIN MEMORY',
#  u'Heliae Development',
#  u'Canon Nanotechnologies',
#  u'Samsung SDI Co.',
#  u'ALGETERNAL TECHNOLOGIES',
#  u'Ampio Pharmaceuticals',
#  u'Freescale Semiconductor',
#  u"Dr. Reddy's Laboratories Ltd.",
#  u'Gilead Connecticut',
#  u'FPInnovations',
#  u'Tersus Environmental',
#  u'Biogenic Reagents Ventures',
#  u'Tarveda Therapeutics',
#  u'Integrated DNA Technologies',
#  u'Palo Alto Research Center Incorporated',
#  u'Regeneron Pharmaceuticals',
#  u'Pentair Thermal Management LLC',
#  u'Bend Research',
#  u'Hamilton Sundstrand Corporation',
#  u'Neutronic Perpetual Innovations',
#  u'Gardner-Gibson',
#  u'Kinestral Technologies',
#  u'Bridgelux',
#  u'Power Integrations',
#  u'Selas Heat Technology Company LLC',
#  u'CellPrint IP Holding',
#  u'Chevron Phillips Chemical Company LP',
#  u'Kimberly-Clark Worldwide',
#  u'Ecolab Inc.',
#  u'Esolar',
#  u'Silicor Materials Inc.',
#  u'Englewood Lab',
#  u'Total Marketing Services',
#  u'SUMITOMO WIRING SYSTEMS',
#  u'Carl Zeiss Meditec AG',
#  u'MEDport',
#  u'Agienic',
#  u'Hitachi',
#  u'Pendar Technologies',
#  u'Phoseon Technology',
#  u'Winbond Electronics Corp.',
#  u'Ensyn Renewables',
#  u'Element One',
#  u'Cyberonics',
#  u'CMC ICOS BIOLOGICS',
#  u'Bird-B-Gone',
#  u'Oki Data Corporation',
#  u'Solight Solar',
#  u'Brightfield Transportation Solutions',
#  u'Dana-Farber Cancer Institute',
#  u'Graphene Technologies',
#  u'QUALCOMM Incorporated',
#  u'Google Inc.',
#  u'The Carbon Cable Company',
#  u'GROW ENERGY',
#  u'Micron Technology',
#  u'R.A. Miller Industries',
#  u'LATITUDE PHARMACEUTICALS INC.',
#  u'Turtle Beach Corporation',
#  u'Green Box Batteries',
#  u'Vaxiion Therapeutics',
#  u'Peytant Solutions',
#  u'Integrated Nano-Technologies',
#  u'Fluidigm Corporation',
#  u'GangaGen',
#  u'Mitsubishi Polyester Film',
#  u'Epizyme',
#  u'Novartis AG',
#  u'Areesys Technologies',
#  u'RADIANCE SOLAR',
#  u'Custom Electronics Inc.',
#  u'S&S X-Ray Products',
#  u'Lattice Semiconductor Corporation',
#  u'PluroGen Therapeutics',
#  u'Iogen Corporation',
#  u'Theraclone Sciences',
#  u'Lovelace Respiratory Research Institute',
#  u'Plant Sensory Systems',
#  u'DRS Network & Imaging Systems',
#  u'THE BOARD INSTITUTE',
#  u'Nanosys',
#  u'Wave Energy Conversion Corporation of America',
#  u'JX Nippon Mining & Metals Corporation',
#  u'The Henry M. Jackson Foundation for the Advancement of Military Medicine',
#  u'National Education Corporation',
#  u'VERLASE TECHNOLOGIES LLC',
#  u'Nanotech Biomachines',
#  u'SEEK THERMAL',
#  u'Nestec S. A.',
#  u'AGFA-GEVAERT N.V.',
#  u'Infineon Technologies AG',
#  u'Meyer Tool',
#  u'Magnolia Solar',
#  u'Micro Cooling Concepts',
#  u'Toda Kogyo Corporation',
#  u'Dell Software Inc.',
#  u'Kraton Polymers U.S. LLC',
#  u'Landauer',
#  u'International Business Machines Corporation',
#  u'Advanced Silicon Group',
#  u'Lake Lite',
#  u'CyboEnergy',
#  u'ADVANCED INNOVATION CENTER LLC',
#  u'Midori USA',
#  u'Eisai Co.',
#  u'NICHIA CORPORATION',
#  u'Takeda Pharmaceutical Company Limited',
#  u'Siliconware Precision Industries Co.',
#  u'U S MICROPOWER INC',
#  u'HTS',
#  u'Clean Energy Labs',
#  u'X DEVELOPMENT LLC',
#  u'SPICE SOLAR',
#  u'Mediatek Inc.',
#  u'Continental Manufacturing',
#  u'TMC Corporation',
#  u'Quantum Materials Corporation',
#  u'Narsys',
#  u'IMRA America',
#  u'Sun Drilling Products Corporation',
#  u'Ethicon Endo-Surgery',
#  u'HTC Corporation',
#  u'Sumitomo Electric Industries',
#  u'Arkema Inc.',
#  u'DISCOVERYBIOMED INC.',
#  u'PLYCEM USA',
#  u'Matrix Genetics',
#  u'Siluria Technologies',
#  u'Cellular Research',
#  u'EchoStar Technologies LLC',
#  u'Milliken & Company',
#  u'Honda Motor Co.',
#  u'Maxout Renewables',
#  u'Singulex',
#  u'Gemex Systems',
#  u'Semprius',
#  u'Copernicus Therapeutics',
#  u'Unistrut International Corp.',
#  u'Wireless Environment',
#  u'ASML Netherlands B.V.',
#  u'Bemis Company',
#  u'Sun Synchrony',
#  u'IMDS Corporation',
#  u'Sion Power Corporation',
#  u'Vizio Inc.',
#  u'Cristal USA Inc.',
#  u'Rapamycin Holdings',
#  u'ASCENT SOLAR TECHNOLOGIES',
#  u'Advanced Aqua Group',
#  u'Pulse Therapeutics',
#  u'Hosiden Corporation',
#  u'Schlumberger Technology Corporation',
#  u'Tosoh Corporation',
#  u'Johnson Matthey PLC',
#  u'Unity Semiconductor Corporation',
#  u'Ferro Corporation',
#  u'Zoetis Services LLC',
#  u'LifeNet Health',
#  u'IntriEnergy Inc.',
#  u'New Technology Ventures',
#  u'Altex Technologies Corporation',
#  u'Greyrock Energy',
#  u'Courtagen Life Sciences',
#  u'ATOMERA INCORPORATED',
#  u'FEI Company',
#  u'Alpha and Omega Semiconductor Incorporated',
#  u'Quest Diagnostics Investments Incorporated',
#  u'Ethox Chemicals',
#  u'Murata Manufacturing Co.',
#  u'O.B.I. Inc.',
#  u'Foret Plasma Labs',
#  u'Tigo Energy',
#  u'United Technologies Corporation',
#  u'Neumedicines',
#  u'OAS Design Group',
#  u'Sagacious Investment Group L.L.C.',
#  u'Sirnaomics',
#  u'Electrix',
#  u'Seetron Inc.',
#  u'Baxter Healthcare SA',
#  u'Senga Advisors',
#  u'Schneider Electric Solar Inverters USA',
#  u'Ceramatec',
#  u'NOVA Chemicals (International) S.A.',
#  u'The Charles Stark Draper Laboratory',
#  u'Pacific Light Technologies',
#  u'DePuy Synthes Products',
#  u'Fuji Xerox Co.',
#  u'Confluence Energy',
#  u'COVERIS FLEXIBLES US LLC',
#  u'Pentron Clinical Technologies',
#  u'Domtar Paper Company',
#  u'GlaxoSmithKline Biologicals',
#  u'iBio',
#  u'Voxtel',
#  u'ENI S.p.A.',
#  u'Sigma-Aldrich Co. LLC',
#  u'Bridgestone Corporation',
#  u'Lof Solar Corporation',
#  u'Scientific Design Company',
#  u'SAE Magnetics (HK) Ltd.',
#  u'AVI BioPharma',
#  u'Silicon Genesis Corporation',
#  u'Newdoll Enterprises LLC',
#  u'Johns Manville',
#  u'System Biosciences',
#  u'AccuRay Corporation',
#  u'Rockwell Collins',
#  u'Reynolds Technologies',
#  u'Chevron Oronitz Company LLC',
#  u'NanoMech',
#  u'INENTEC INC.',
#  u'Coriant Advanced Technology',
#  u'Dresser-Rand Company',
#  u'Bluestar Silicones France',
#  u'Finisar Corporation',
#  u'Bayer Materialscience LLC',
#  u'SolarReserve Technology',
#  u'BERKEN ENERGY LLC',
#  u'Kia Motors Corporation ',
#  u'Nanomix',
#  u'Lawrence Livermore National Security',
#  u'Becton',
#  u'HAMAMATSU PHOTONICS K.K.',
#  u'Relypsa',
#  u'ZIH Corp.',
#  u'Kao Corporation',
#  u'Gracenote',
#  u'Xintec Inc.',
#  u'MAHLE International GmbH',
#  u'Nova Technologies',
#  u'Sanken Electric Co.',
#  u'Alexion Pharmaceuticals',
#  u'Suganit Systems',
#  u'ABB AB',
#  u'Georgia-Pacific Gypsum LLC',
#  u'Sharp Laboratories of America',
#  u'Richtek Technology Corporation',
#  u'Avery Dennison Corporation',
#  u'3M Innovative Properties Company',
#  u'Gtech Corporation',
#  u'Watlow Electric Manufacturing Company',
#  u'Gram Power',
#  u'Teradata US',
#  u'Rockwell Automation Technologies',
#  u'NanoOncology',
#  u'OFS Fitel',
#  u'Wine.com',
#  u'WestPoint Home',
#  u'Advanced Water Technology',
#  u'Lumentum Operations LLC']

# %%
# find all links that have about, company, and corporate mentions 
# 1. pull down home page
# 2. get a list of all links in Beautiful Soup
# 3. keep only those that match a regex

firm_about_dict = {}

def fix_url(url, domain):
    if not(re.search(domain, url)): 
        url = re.sub ('///?', '/', url)
        fixed = domain + '/' + url
        return fixed
    else:
        return url

def get_domain (url):
    o = urlparse(url)
    domain = o.scheme + '://' + o.netloc
    return domain

def get_link_path (url):
    o = urlparse(url)
    path = o.path + o.params + o.query + o.fragment
    return path

def get_about_links_from_home_pages (): 
    for firm_name in firm_names: 
        regex = '^' + re.escape(firm_name) + '$'
        results = col.find( {"firm_name": re.compile(regex, re.IGNORECASE)}).sort("depth",pymongo.ASCENDING) 

        result = results[0]
        html = result['html'][0]
        home_url = result['url'][0]
        domain = get_domain(home_url)
        
        # print ("Working on " + firm_name + ' at ' + home_url)
        soup = BeautifulSoup(html, 'lxml')
        links_to_text_dict = {a.get('href'): a.string for a in soup.find_all('a', href=True)}
        link_paths_to_text_dict = {get_link_path(link): text for link, text in links_to_text_dict.items() }
        pp.pprint(link_paths_to_text_dict)
        regex = re.compile('(about|company|corporate|who.we.are|(^|/)vision|overview|profile|corporate)', flags=re.IGNORECASE)
        about_links = {link: text for link, text in link_paths_to_text_dict.items() if regex.search(link)}
        about_texts = {link: text for link, text in link_paths_to_text_dict.items() if regex.search(text)}
        abouts = {**about_texts, **about_links}
        
        abouts_clnd = {link: text for link, text in abouts.items() if not(re.search('linkedin', link))}
        abouts_clnd = {fix_url(link, domain): text for link, text in abouts_clnd.items()} 
        about_keys_srtd = sorted(abouts_clnd.keys(), key=len )
        # pp.pprint (links)
        
        if abouts_srtd:
            firm_about_dict[firm_name] = abouts_srtd
        else: 
            firm_no_about_dict[firm_name] = home_url

get_about_links_from_home_pages()
# Out:
# {'': None,
#  '/': u'Home',
#  '/about-us': u'About Us',
#  '/contact-us': u'Contact Us',
#  '/features/downloads': u'How To',
#  '/features/faqs': u'FAQs',
#  '/features/gallery': u'PICS',
#  '/features/stores': u'Stores',
#  '/little_kids_inc': None,
#  '/little_kids_inc/': None,
#  '/littlekidsinc/': None,
#  '/privacy': u'Privacy',
#  '/products': u'Products',
#  '/products/candylicious-bubbles': u'CANDYLICIOUS\xae',
#  '/products/fubbles': u'Learn More',
#  '/products/fubbles-no-spill': u'Fubbles\xae No-Spill\xae',
#  '/products/jelly-belly': u'Jelly Belly\xae',
#  '/products/junk-ball': u'Learn More',
#  '/products/magic-kidchen': u'Magic Kidchen \u2122',
#  '/products/nickelodeon': u'Nickelodeon \u2122',
#  '/products/paw-patrol': u'Learn More',
#  '/products/peeps': u'Learn More >>',
#  '/products/pj-masks': u'PJ Masks \u2122',
#  '/products/sesame-street': u'Sesame Street\xae',
#  '/products/shimmer-shine': u'Shimmer & Shine \u2122',
#  '/products/slick-tricks-bubbles': None,
#  '/returns': u'Return Policy',
#  '/terms': u'Terms',
#  '/user/LittleKidsInc': None,
#  '/user/my-account.htm': u'Portal',
#  '/user/my-accountpanel1': None,
#  'info@littlekidsinc.com': u'info@littlekidsinc.com',
#  'tel:8005455437': u'800-545-5437'}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-162-354d9a909cfd> in <module>()
#      53             firm_no_about_dict[firm_name] = home_url
#      54
# ---> 55 get_about_links_from_home_pages()
#
# <ipython-input-162-354d9a909cfd> in get_about_links_from_home_pages()
#      41         pp.pprint(link_paths_to_text_dict)
#      42         regex = re.compile('(about|company|corporate|who.we.are|(^|/)vision|overview|profile|corporate)', flags=re.IGNORECASE)
# ---> 43         abouts = list(set(list(filter (regex.search, link_paths))))
#      44
#      45         abouts_clnd = list (filter (lambda x: not(re.search('linkedin', x)), abouts))
#
# NameError: global name 'link_paths' is not defined

# %%
# look to see which firms didn't get identified with having about pages
# may want to predict which page(s) in firm website have about us like information given the training sample of positive pages
print (len(firm_no_about_dict.keys()))
for firm_key, home_page in firm_no_about_dict.items():
    print (firm_key + ': ' + home_page)
# Out:
# 141
# Star Technology and Research: http://star-tech-inc.com/
# NanoGram Corporation: http://www.nanogram.com/home/
# Quallion LLC: https://www.enersys.com/GlobalLanding.aspx
# Ivoclar Vivadent AG: http://www.ivoclarvivadent.com/
# Forest Concepts: http://forestconcepts.com/
# Mitsubishi Polyester Film: https://www.m-petfilm.com/
# INENTEC INC.: http://inentec.com/
# Industrial Technology Research Institute: https://www.itri.org.tw/eng/
# PAX Scientific: http://paxscientific.com/
# Biogenic Reagents Ventures: http://biogenicreagents.com/
# Courtagen Life Sciences: http://courtagen.com/
# KR Design House: http://krdesignhouse.com/
# Ostendo Technologies: https://www.ostendo.com/
# Masimo Semiconductor: http://masimosemiconductor.com/masimo-semiconductor/
# Avertech: http://avertech.com.sg/
# Graphene Technologies: http://graphenetechnologies.com/
# Carver Scientific: http://carversci.com/
# MEDport: https://medport.com/
# Fina Technology: http://www.finatg.com/
# Cleanvantage LLC: http://biovantage.dk/
# Molecular Rebar Design: http://www.molecularrebar.com/
# Genesco Inc.: http://genescopartners.com/
# Opel Solar: http://opelinc.com/
# Turf Group LLC: https://turfgroup.net/
# Beryllium Discovery Corp.: http://be4.com/
# Solight Solar: http://www.solight.com/
# Matrix Genetics: https://www.lumenbioscience.com/
# Community Power Corporation: https://www.cpwrfcu.org/
# Google Inc.: https://abc.xyz/
# Synaptic Research: https://research.synaptic.co.uk/SynapticResearch/login.asp?t=98266&page=/Default.asp?
# LATITUDE PHARMACEUTICALS INC.: http://latitudepharma.com/
# Green Box Batteries: https://biggreenbox.com/
# W&Wsens Devices: https://www.wwsensdevices.com/
# Global OLED Technology LLC: http://globaloledtech.com/
# Global Filtration Systems: http://globalfiltrationsystems.com/
# Redwood Systems: http://redwoodsystemsgroup.com/
# STANDARD ALCOHOL COMPANY OF AMERICA: https://www.standardalcohol.com/?_escaped_fragment_=
# Wikipad: http://www.wikipad.com/
# Travis Industries: http://travisindustries.com/
# Enginuity Worldwide: http://enginuityww.webstarts.com/
# VERLASE TECHNOLOGIES LLC: http://www.verlase.com/
# Brother International Corporation: https://www.brother-usa.com/
# Amprius: http://amprius.com/
# Shoals Technologies Group: https://www.shoals.com/
# LUCERA LABS: https://www.luceralabs.com/
# Zeno Semiconductor Inc: https://www.zenosemi.com/
# Dynamic Solutions Worldwide: https://dynatrap.com/
# Starlight Energy Holdings LLC: http://www.starlightenergy.us/
# Deep Science: http://deepscience.ai/
# Renmatix: http://renmatix.com/
# ADMA Products: https://www.admaproducts.com/?_escaped_fragment_=
# Kamtec: http://www.kamtec.co.uk
# SOLAZYME: http://solazyme.com/
# Warsaw Orthopedic: https://mywarsaw.net/
# ZON: https://www.zon.si/
# Cima NanoTech Israel Ltd.: http://cimananotech.com/en/closure/
# ADVANCED CERAMIC FIBERS: http://acfibers.com/index.html
# IDEA TREE: https://www.ideatreepromos.com/
# Copernicus Therapeutics: http://cgsys.com/
# Advanced Silicon Group: http://www.advancedsilicongroup.com/
# R.J. Reynolds Tobacco Company: https://rjrt.com/
# Applied Membrane Technologies: http://appliedmembranetech.com/
# Express Imaging Systems: https://www.eiscallcenter.com/eis/
# Nestec S. A.: http://www.nestle.com/
# Crystalplex Corporation: https://crystalplex.com/
# Clean Energy Labs: http://cleanenergylabs.com/
# Sinewatts: https://www.sinewatts.com/
# Kinetech Power Company LLC: https://kinetechpower.com/
# Green Solar Transportation: http://greensolartransport.com/
# Elwha LLC: https://www.elwha.org/
# International Technology Center: http://itc-inc.org/
# Areesys Technologies: http://areesys.com/
# Coactive Drive Corporation: https://www.coactivehs.com/team/
# SixPoint Materials: http://spmaterials.com/
# Brightfield Transportation Solutions: http://brightfieldts.com/
# Neural Signals: http://www.neuralsignals.com/
# S&S X-Ray Products: http://www.ssxray.com/
# Grandis Inc.: https://www.grandis.com/
# Achushnet Company: https://www.acushnetgolf.com/
# Solaire Generation LLC: http://sunpowercarports.com/
# Koch Biological Solutions: https://kochbiologicalsolutions.com/
# X DEVELOPMENT LLC: https://www.x.org/wiki/Development/
# Arkival Technology Corp.: http://arkival.com/
# Blue Sea Systems: https://www.bluesea.com/
# Electronic Warfare Associates: http://ewa.com/
# Aurora Alage: http://www.aurorabiofuels.com/
# Medgenics Medical Israel Ltd.: http://medgenics.com/
# IntriEnergy Inc.: http://www.intrienergy.com/?_escaped_fragment_=
# Singular Bio: https://www.singularbio.com/
# Livetv: http://livetv.sx/enx/
# Quest Diagnostics Investments Incorporated: http://ir.questdiagnostics.com/mobile.view?c=82068&p=irol-irhome
# Verliant Energy: http://www.verliantenergy.com/
# Akron Polymer Systems: http://akronpolysys.com/
# KJ BIOSCIENCES LLC: http://kjbiosciences.com/index.html
# Neumedicines: http://neumedicines.com/
# Thorlabs: http://www.thorlabs.com/
# Sirnaomics: http://new.sirnaomics.com/
# LG Electronics Inc.: https://www.lg.com/us
# Suganit Systems: http://suganit.com/
# SunEdison: http://sunedison.com/
# Inventus Holdings: http://inventusholdings.com/
# TP Solar: https://tpsolar.nl/?lang=en
# SOLENA FUELS CORPORATION: http://www.solenafuels.com/
# NEWFIELD THERAPEUTICS CORPORATION: https://newfieldthera.com/
# Toyota Motor Engineering & Manufacturing North America: https://www.toyota.com/usa/careers/index.html
# Mumetel: http://mumetel.com/index.html
# SELMAN AND ASSOCIATES: https://selmanlog.com/Default.aspx
# AROG PHARMACEUTICALS: https://www.arogpharmaceuticals.com/
# ADVANCED INNOVATION CENTER LLC: http://aicchile.com/en/
# NanoTech Lubricants: http://nanotechlubricantsinc.com/Home.html
# Novus Energy LLC: http://www.novusenergy.ca/index.php?page=investor_documents_news_release
# K.S. INTERNATIONAL CO.: http://ksandco.com/
# Sigma-Aldrich Co. LLC: https://www.sigmaaldrich.com/
# National Education Corporation: http://nationaleducation.com/
# Pharmatrophix: http://pharmatrophix.com/
# Becton: http://www.bd.com/
# Quantapore: https://quantapore.com/
# PELLION TECHNOLOGIES: http://www.pelliontech.com/
# Mission Product Holdings: https://www.mission.com/
# Hadasit Medical Research Services & Development Company Ltd.: http://www.hadasit.co.il/
# SUMITOMO WIRING SYSTEMS: https://www.sws.co.jp/en/
# VINDICO NANOBIO TECHNOLOGY INC.: http://vindicoat.com/joomla1/
# Interez: https://www.interez.sk/
# Zephyr Energy Systems LLC: http://zephyrenergy.com/
# Nanomix: http://nano.com/
# Helios Focus LLC: http://www.heliosfocus.com/
# TheGreenCell: http://thegreencell.com/
# QuantumScape Corporation: http://www.quantumscape.com/
# Entech Solar: http://entechsolutions.us/
# Plant Sensory Systems: https://www.plantsensorysystems.com/
# Kao Corporation: https://www.ako2.us.army.mil/local/pre-acceptance.html
# PortaFire: http://port-a-fire.ca/
# Dymax Corporation: https://dymax.com/
# Conoco Inc.: https://www.conoco.com/
# Xyleco: https://www.xyleco.com/
# Georgia-Pacific Gypsum LLC: https://www.buildgp.com/georgia-pacific-gypsum
# NovaSolix: http://www.novasolix.com/
# GTherm: http://gtherm.net/
# Great American Duck Races: https://www.demingduckrace.com/
# Arrowhead Center: http://arrowheadcenter.nmsu.edu/
# Advanced Water Technology: https://www.advancedwatertechnology.com/

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10.10; rv:62.0) Gecko/20100101 Firefox/62.0'}
timeout = 5

def is_valid_url (url):
    try:
        resp = requests.get(url, headers=headers, timeout=timeout, verify=False)
        # print ("\tStatus code: " + str(resp.status_code))
        if resp.status_code >= 200 and resp.status_code < 400:
            return True
        else:
            return False
    except Exception as e: 
        print(e)
        return False
        # traceback.print_exc()

# %%
final_about_dict = {}
for firm_key, abouts in firm_about_dict.items():
    for url in abouts:
        if is_valid_url (url):
            final_about_dict[firm_key] = url
            break
    home = get_domain(abouts[0])
    firm_no_about_dict[firm_key] = home
    final_about_dict[firm_key] = home
# Out:
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# HTTPSConnectionPool(host='www.magna.com', port=443): Read timed out. (read timeout=5)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# HTTPSConnectionPool(host='braunintertec.com', port=443): Max retries exceeded with url: //about-us (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x136fa6d10>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# HTTPSConnectionPool(host='braunintertec.com', port=443): Max retries exceeded with url: //about-us/ (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x136fa6510>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# HTTPSConnectionPool(host='braunintertec.com', port=443): Max retries exceeded with url: //company/62021/ (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x136fa6990>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# HTTPSConnectionPool(host='braunintertec.com', port=443): Max retries exceeded with url: //about-us/awards/ (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x136fa67d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# HTTPSConnectionPool(host='braunintertec.com', port=443): Max retries exceeded with url: //about-us/history/ (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x136fa63d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# HTTPSConnectionPool(host='braunintertec.com', port=443): Max retries exceeded with url: //about-us/leadership/ (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x136fa65d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# HTTPSConnectionPool(host='braunintertec.com', port=443): Max retries exceeded with url: //about-us/fleet-equipment/ (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x136fa6990>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# HTTPSConnectionPool(host='braunintertec.com', port=443): Max retries exceeded with url: //about-us/community-engagement/ (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x136fa6b50>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# HTTPSConnectionPool(host='braunintertec.com', port=443): Max retries exceeded with url: //about-us/safety-quality-certifications/ (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x136fa6050>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# ...
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# /Users/sarora/anaconda2/lib/python2.7/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
# check again since some firms may have been added 
print (len(firm_no_about_dict.keys()))

# %%
# write about pages to file
pp.pprint(final_about_dict)
# Out:
# {u'Little Kids': u'http://www.littlekidsinc.com'}

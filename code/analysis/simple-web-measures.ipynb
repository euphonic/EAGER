# %%
# Create simple web measures, including number of pages and mean words per page
# Sanjay K Arora
# November 2018

# Input: A single collection
# Output: (Eventually) a file with firm name, (pipe delimited unique domains), total pages, total words, (and average words per page)

import pprint
import sys
import pprint
import pymongo
import csv
import pandas as pd
import re

# %%
# Setting up database connection information
CONNECTION_STRING = 'mongodb://localhost'
MONGODB_DB = "FirmDB_20181116"
TARGET_COLLECTION = "pages_COMBINED"
OUTF = "../../data/analysis/measures/simple_web_measures_v1.csv"

client = pymongo.MongoClient(CONNECTION_STRING)
db = client[MONGODB_DB]

pp = pprint.PrettyPrinter()

# %%
def get_pages ():
    target_col = db[TARGET_COLLECTION]
    pipeline = [ { "$match": { "firm_name" : { "$exists": "true", "$ne": "null" }} },
                { "$group": {"_id":"$firm_name" , "number":{"$sum":1}} } ]
    pages_by_firm_name = list(target_col.aggregate(pipeline))
    print ('Found ' + str(len(pages_by_firm_name)) + ' firm names with pages')
    return pages_by_firm_name

def get_num_words(name):
    target_col = db[TARGET_COLLECTION]
    results = target_col.find ({ "firm_name" : name })
    num_words = 0
    for result in results:
        print ('\tWorking on', result['url'][0])
        pp.pprint (result)
        if 'full_text' in result:
            num_words += [len(t) for t in text for text in result['full_text']]
        # else continue
    return num_words

def print_measures():
    f_out = open(OUTF, 'w')
    csv_out = csv.writer(f_out)
    csv_out.writerow(['firm_name', 'num_pages'])
    for firm_name, m in measures.items():
        pages = m['pages']
        csv_out.writerow([firm_name, pages])
        
# standard firm cleaning regex
def clean_firm_name (firm):
    firm_clnd = re.sub('(\.|,| corporation| incorporated| llc| inc| international| gmbh| ltd)', '', firm, flags=re.IGNORECASE).rstrip()
    return firm_clnd

# %%
pages_by_firm_name = get_pages ()
# Out:
# Found 1186 firm names with pages

# %%
words_by_firm_name = {}
get_pages = ()
for rec in pages_by_firm_name:
    name = rec['_id'][0]
    print ('Working on', name)
    words_by_firm_name[name] = get_num_words(name) # not cleaned text, but probably a good proxy
# Out:
# Working on Shimadzu Corporation
# 	Working on https://www.shimadzu.com/an/index.html
# {'_id': ObjectId('5bec8bc84ecd311c495d2d50'),
#  'body': ['<body style="top: 0px;">\n'
#           '    <div id="wrapper">\n'
#           '  <header>\n'
#           '    <!-- 2_0_0 Page Header Region START -->\n'
#           '      <section id="head">\n'
#           '        <div class="container">\n'
#           '          <p id="logo"><a '
#           'href="https://www.shimadzu.com/">SHIMADZU</a></p>\n'
#           '          <p id="copy"><img '
#           'src="/an/profiles/shimadzu/themes/shimadzu/images/text_analytical_en.png"></p>\n'
#           '          <p id="headHamb"></p>\n'
#           '          <div class="util">\n'
#           '            <ul class="utilNav utilNav_en">\n'
#           '  <li><a href="https://www.shimadzu.com/about/"><i '
#           'class="custom-icon icon-shimadzu-logo"></i>ABOUT SHIMADZU</a></li>\n'
#           '  <li class="utilNav-top-adjust-item utilNav-top-adjust-item-02"><a '
#           'href="https://solutions.shimadzu.co.jp/cgi-bin/MailDeliver.cgi?CFGFILE=g-lab_product_Information"><i '
#           'class="custom-icon icon-inquiry"></i>CONTACT US</a></li>\n'
#           '  <li class="utilNav-top-adjust-item utilNav-top-adjust-item-01"><a '
#           'href="https://www.shimadzu.com/links/index.html"><i '
#           'class="custom-icon icon-earth"></i>GLOBAL LINKS</a></li>\n'
#           '</ul>\n'
#           '<ul class="fixNav">\n'
#           '  <li><a href="/an/contact/index.html"><i class="custom-icon '
#           'icon-contact"></i><span>Contact Search</span></a></li>\n'
#           '  <li><a '
#           'href="https://solutions.shimadzu.co.jp/cgi-bin/MailDeliver.cgi?CFGFILE=g-lab_quotation"><i '
#           'class="custom-icon '
#           'icon-quotation"></i><span>Quotation</span></a></li>\n'
#           '  <li><a '
#           'href="https://solutions.shimadzu.co.jp/cgi-bin/MailDeliver.cgi?CFGFILE=g-lab_product_Information"><i '
#           'class="custom-icon icon-inquiry"></i><span>Inquiry</span></a></li>\n'
#           '</ul>            <form '
#           'action="https://search1.shimadzu.co.jp/search" method="get" '
#           'id="shimadzu-iwgp-search-site-search-form" accept-charset="UTF-8">\n'
#           '              <dl class="form-set form-set-no-flex">\n'
#           '                <dt class="form-set-head"><input '
#           'class="search-area-input form-text-input" type="text" '
#           'id="edit-query" name="query" placeholder="Search"></dt>\n'
#           '                <dd class="form-set-content"><button type="submit" '
#           'name="submit" id="input2_name" class="btn btn-search '
#           'form-submit"><i class="custom-icon '
#           'icon-contact"></i></button></dd>\n'
#           '              </dl>\n'
#           '              <input type="hidden" name="site" value="EM0AJRZ6">\n'
#           '\n'
#           '              <input type="hidden" name="charset" value="UTF-8">\n'
#           '              <input type="hidden" name="design" value="17">\n'
#           '            </form>\n'
#           '          <ul class="global">\n'
#           '<li><a class="current home_en" '
#           'href="/an/index.html"><span>HOME</span></a></li><li><a '
#           'class="js-gnav-fatmenu-trigger products_en" '
#           'href="/an/products/index.html" data-element-index="0" '
#           'id="fatmenu_trigger_num_0"><span>PRODUCTS</span></a></li><li><a '
#           'class="js-gnav-fatmenu-trigger industry_en" '
#           'href="/an/industry/index.html" data-element-index="1" '
#           'id="fatmenu_trigger_num_1"><span>INDUSTRIES</span></a></li><li><a '
#           'class="literature_en" '
#           'href="/an/literature/index.html"><span>LITERATURE</span></a></li><li><a '
#           'class="support_en" href="/an/support/index.html"><span>SERVICE '
#           '&amp; SUPPORT</span></a></li><li><a class="news_en" '
#           'href="/an/news-events/index.html"><span>NEWS / '
#           'EVENT</span></a></li><li><a class="relation_en" '
#           'href="/an/relation/index.html"><span>CORPORATE '
#           'RELATIONSHIPS</span></a></li></ul></div>\n'
#           '        </div>\n'
#           '      </section>\n'
#           '    <!-- Page Header Region END -->\n'
#           '\n'
#           '    <!-- Global Nav Region START -->\n'
#           '    <nav id="gnav"><div class="container"><ul class="global">\n'
#           '<li><a class="current home_en" '
#           'href="/an/index.html"><span>HOME</span></a></li><li><a '
#           'class="js-gnav-fatmenu-trigger products_en" '
#           'href="/an/products/index.html" data-element-index="0" '
#           'id="fatmenu_trigger_num_0"><span>PRODUCTS</span></a></li><li><a '
#           'class="js-gnav-fatmenu-trigger industry_en" '
#           'href="/an/industry/index.html" data-element-index="1" '
#           'id="fatmenu_trigger_num_1"><span>INDUSTRIES</span></a></li><li><a '
#           'class="literature_en" '
#           'href="/an/literature/index.html"><span>LITERATURE</span></a></li><li><a '
#           'class="support_en" href="/an/support/index.html"><span>SERVICE '
#           '&amp; SUPPORT</span></a></li><li><a class="news_en" '
#           'href="/an/news-events/index.html"><span>NEWS / '
#           'EVENT</span></a></li><li><a class="relation_en" '
#           'href="/an/relation/index.html"><span>CORPORATE '
#           'RELATIONSHIPS</span></a></li></ul></div></nav>\n'
#           '<div id="global-nav-secondary-menu-container">\n'
#           '<div class="fat-menu fat-menu-for-global-nav '
#           'js-gnav-fatmenu-target" data-element-index="0" id="fatmenu_num_0" '
#           'style="display: none;"><div class="fat-menu-inner"><ul '
#           'class="unit"><li><a href="/an/gc/index.html">Gas '
#           'Chromatography</a></li><li><a href="/an/hplc/index.html">Liquid '
#           'Chromatography</a></li><li><a href="/an/gcms/index.html">Gas '
#           'Chromatograph-Mass Spectrometry</a></li><li><a '
#           'href="/an/lcms/index.html">Liquid Chromatograph-Mass '
#           'Spectrometry</a></li><li><a href="/an/system-gc/index.html">System '
#           'GC</a></li><li><a href="/an/data-net/index.html">Data Management '
#           '&amp; Software</a></li><li><a href="/an/ms/index.html">Mass '
#           'Spectrometry</a></li></ul><ul class="unit"><li><a '
#           'href="/an/molecular_spectro/index.html">Molecular '
#           'Spectroscopy</a></li><li><a '
#           'href="/an/elemental/index.html">Elemental Analysis</a></li><li><a '
#           'href="/an/consum/index.html">Columns and Consumables</a></li><li><a '
#           'href="/an/surface/index.html">Surface Analysis</a></li><li><a '
#           'href="/an/lifescience/index.html">Life Science Lab '
#           'Instruments</a></li><li><a href="/an/toc/index.html">Total Organic '
#           'Carbon Analysis</a></li><li><a '
#           'href="/an/thermal/index.html">Thermal Analysis</a></li></ul><ul '
#           'class="unit"><li><a href="/an/monitoring/index.html">Continuous '
#           'Monitoring Analysis</a></li><li><a '
#           'href="/an/powder/index.html">Particle Size Analysis</a></li><li><a '
#           'href="/an/test/index.html">Materials Testing &amp; '
#           'Inspection</a></li><li><a href="/an/ndi/index.html">Non-Destructive '
#           'Testing</a></li><li><a '
#           'href="/an/balance/index.html">Balances</a></li><li><a '
#           'href="/an/2d-chrom/index.html">Comprehensive '
#           'Chromatography</a></li></ul></div></div><div class="fat-menu '
#           'fat-menu-for-global-nav js-gnav-fatmenu-target" '
#           'data-element-index="1" id="fatmenu_num_1" style="display: '
#           'none;"><div class="fat-menu-inner"><ul class="unit"><li><a '
#           'href="/an/industry/ceramicsmetalsmining/index.html">Ceramics, '
#           'Metals, Mining</a></li><li><a '
#           'href="/an/industry/clinicalforensics/index.html">Clinical research, '
#           'Forensics</a></li><li><a '
#           'href="/an/industry/electronicselectronic/index.html">Electronics, '
#           'Electronic</a></li></ul><ul class="unit"><li><a '
#           'href="/an/industry/environment/index.html">Environment</a></li><li><a '
#           'href="/an/industry/foodbeverages/index.html">Food, '
#           'Beverages</a></li><li><a '
#           'href="/an/industry/machineryautomotive/index.html">Machinery, '
#           'Automotive</a></li></ul><ul class="unit"><li><a '
#           'href="/an/industry/new_energy/index.html">New Energy</a></li><li><a '
#           'href="/an/industry/petrochemicalchemical/index.html">Hydrocarbon '
#           'Processing Industry (Petrochemical, Chemical)</a></li><li><a '
#           'href="/an/industry/pharmaceuticallifescience/index.html">Pharmaceutical, '
#           'Life Science</a></li></ul></div></div></div>\n'
#           '    <!-- Global Nav Region END -->\n'
#           '  </header>\n'
#           '\n'
#           '    <section class="topVi">\n'
#           '<ul class="slider slick-initialized slick-slider" style="">\n'
#           '<div aria-live="polite" class="slick-list draggable"><div '
#           'class="slick-track" style="opacity: 1; width: 0px;" '
#           'role="listbox"><li data-slick-dot-label="Pharmaceutical, Life '
#           'Science" class="slick-slide slick-current slick-active" '
#           'data-slick-index="0" aria-hidden="false" style="width: 0px; '
#           'position: relative; left: 0px; top: 0px; z-index: 999; opacity: 1;" '
#           'tabindex="-1" role="option" aria-describedby="slick-slide00"><a '
#           'href="/an/industry/pharmaceuticallifescience/index.html" '
#           'tabindex="0">\n'
#           '<img '
#           'src="/an/sites/shimadzu.com.an/files/top/category-baner_640_pharmaceutical.jpg" '
#           'alt="Pharmaceutical, Life Science"></a>\n'
#           '</li><li data-slick-dot-label="Food, Beverages" class="slick-slide" '
#           'data-slick-index="1" aria-hidden="true" style="width: 0px; '
#           'position: relative; left: 0px; top: 0px; z-index: 998; opacity: 0;" '
#           'tabindex="-1" role="option" aria-describedby="slick-slide01"><a '
#           'href="/an/industry/foodbeverages/index.html" tabindex="-1">\n'
#           '<img '
#           'src="/an/sites/shimadzu.com.an/files/top/category-baner_640_food.jpg" '
#           'alt="Food, Beverages"></a>\n'
#           '</li><li data-slick-dot-label="Environment" class="slick-slide" '
#           'data-slick-index="2" aria-hidden="true" style="width: 0px; '
#           'position: relative; left: 0px; top: 0px; z-index: 998; opacity: 0;" '
#           'tabindex="-1" role="option" aria-describedby="slick-slide02"><a '
#           'href="/an/industry/environment/index.html" tabindex="-1">\n'
#           '<img '
#           'src="/an/sites/shimadzu.com.an/files/top/category-baner_640_environment.jpg" '
#           'alt="Environment"></a>\n'
#           '</li><li data-slick-dot-label="Hydrocarbon Processing Industry" '
#           'class="slick-slide" data-slick-index="3" aria-hidden="true" '
#           'style="width: 0px; position: relative; left: 0px; top: 0px; '
#           'z-index: 998; opacity: 0;" tabindex="-1" role="option" '
#           'aria-describedby="slick-slide03"><a '
#           'href="/an/industry/petrochemicalchemical/index.html" '
#           'tabindex="-1">\n'
#           '<img '
#           'src="/an/sites/shimadzu.com.an/files/category-baner_640_petrochemical_2.jpg" '
#           'alt="Hydrocarbon Processing Industry"></a>\n'
#           '</li><li class="pr slick-slide" data-slick-dot-label="Machinery, '
#           'Automotive" data-slick-index="4" aria-hidden="true" style="width: '
#           '0px; position: relative; left: 0px; top: 0px; z-index: 998; '
#           'opacity: 0;" tabindex="-1" role="option" '
#           'aria-describedby="slick-slide04"><a '
#           'href="/an/industry/machineryautomotive/index.html" tabindex="-1">\n'
#           '<img '
#           'src="/an/sites/shimadzu.com.an/files/category-baner_640_machinery_5.jpg" '
#           'alt="Machinery, Automotive"></a>\n'
#           '</li></div></div>\n'
#           '\n'
#           '\n'
#           '\n'
#           '\n'
#           '</ul>\n'
#           '<ul class="sliderPC slick-initialized slick-slider">\n'
#           '<div aria-live="polite" class="slick-list draggable"><div '
#           'class="slick-track" style="opacity: 1; width: 6780px;" '
#           'role="listbox"><li class="pr slick-slide slick-current '
#           'slick-active" style=\'background-image: '
#           'url("/an/sites/shimadzu.com.an/files/top/category-baner_Pharmaceutical.jpg"); '
#           'width: 1356px; position: relative; left: 0px; top: 0px; z-index: '
#           '999; opacity: 1;\' data-slick-dot-label="Pharmaceutical, Life '
#           'Science" data-slick-index="0" aria-hidden="false" tabindex="-1" '
#           'role="option" aria-describedby="slick-slide10"><a '
#           'href="/an/industry/pharmaceuticallifescience/index.html" '
#           'tabindex="0">\n'
#           '</a>\n'
#           '</li><li class="pr slick-slide" style=\'background-image: '
#           'url("/an/sites/shimadzu.com.an/files/top/category-baner_Food.jpg"); '
#           'width: 1356px; position: relative; left: -1356px; top: 0px; '
#           'z-index: 998; opacity: 0;\' data-slick-dot-label="Food, Beverages" '
#           'data-slick-index="1" aria-hidden="true" tabindex="-1" role="option" '
#           'aria-describedby="slick-slide11"><a '
#           'href="/an/industry/foodbeverages/index.html" tabindex="-1">\n'
#           '</a>\n'
#           '</li><li class="pr slick-slide" style=\'background-image: '
#           'url("/an/sites/shimadzu.com.an/files/top/category-baner_Environment.jpg"); '
#           'width: 1356px; position: relative; left: -2712px; top: 0px; '
#           'z-index: 998; opacity: 0;\' data-slick-dot-label="Environment" '
#           'data-slick-index="2" aria-hidden="true" tabindex="-1" role="option" '
#           'aria-describedby="slick-slide12"><a '
#           'href="/an/industry/environment/index.html" tabindex="-1">\n'
#           '</a>\n'
#           '</li><li class="pr slick-slide" style=\'background-image: '
#           'url("/an/sites/shimadzu.com.an/files/category-baner_petrochemical_2.jpg"); '
#           'width: 1356px; position: relative; left: -4068px; top: 0px; '
#           'z-index: 998; opacity: 0;\' data-slick-dot-label="Hydrocarbon '
#           'Processing Industry" data-slick-index="3" aria-hidden="true" '
#           'tabindex="-1" role="option" aria-describedby="slick-slide13"><a '
#           'href="/an/industry/petrochemicalchemical/index.html" '
#           'tabindex="-1">\n'
#           '</a>\n'
#           '</li><li class="pr slick-slide" style=\'background-image: '
#           'url("/an/sites/shimadzu.com.an/files/category-baner_machinery_5.jpg"); '
#           'width: 1356px; position: relative; left: -5424px; top: 0px; '
#           'z-index: 998; opacity: 0;\' data-slick-dot-label="Machinery, '
#           'Automotive" data-slick-index="4" aria-hidden="true" tabindex="-1" '
#           'role="option" aria-describedby="slick-slide14"><a '
#           'href="/an/industry/machineryautomotive/index.html" tabindex="-1">\n'
#           '</a>\n'
#           '</li></div></div>\n'
#           '\n'
#           '\n'
#           '\n'
#           '\n'
#           '</ul>\n'
#           '<div class="thumbWrapWrapper" role="toolbar">\n'
#           '<ul class="thumbWrap hidden-pc display-flex" style="display: '
#           'block;" role="tablist"><li class="slick-active" aria-hidden="false" '
#           'role="presentation" aria-selected="true" '
#           'aria-controls="navigation00" id="slick-slide00">Pharmaceutical, '
#           'Life Science</li><li aria-hidden="true" role="presentation" '
#           'aria-selected="false" aria-controls="navigation01" '
#           'id="slick-slide01">Food, Beverages</li><li aria-hidden="true" '
#           'role="presentation" aria-selected="false" '
#           'aria-controls="navigation02" id="slick-slide02">Environment</li><li '
#           'aria-hidden="true" role="presentation" aria-selected="false" '
#           'aria-controls="navigation03" id="slick-slide03">Hydrocarbon '
#           'Processing Industry</li><li aria-hidden="true" class="pr" '
#           'role="presentation" aria-selected="false" '
#           'aria-controls="navigation04" id="slick-slide04">Machinery, '
#           'Automotive</li></ul><ul class="thumbWrap hidden-sp" style="display: '
#           'flex;" role="tablist"><li class="slick-active" aria-hidden="false" '
#           'role="presentation" aria-selected="true" '
#           'aria-controls="navigation10" id="slick-slide10">Pharmaceutical, '
#           'Life Science</li><li aria-hidden="true" role="presentation" '
#           'aria-selected="false" aria-controls="navigation11" '
#           'id="slick-slide11">Food, Beverages</li><li aria-hidden="true" '
#           'role="presentation" aria-selected="false" '
#           'aria-controls="navigation12" id="slick-slide12">Environment</li><li '
#           'aria-hidden="true" role="presentation" aria-selected="false" '
#           'aria-controls="navigation13" id="slick-slide13">Hydrocarbon '
#           'Processing Industry</li><li aria-hidden="true" class="pr" '
#           'role="presentation" aria-selected="false" '
#           'aria-controls="navigation14" id="slick-slide14">Machinery, '
#           'Automotive</li></ul></div>\n'
#           '</section>\n'
#           '<div id="topMain">\n'
#           '  <div class="container">\n'
#           '    <ul class="gateways">\n'
#           '<li>\n'
#           '<a href="https://www.shimadzu.com/about/" target="_blank">\n'
#           '<i class="custom-icon icon-building"></i>About Shimadzu</a>\n'
#           '</li>\n'
#           '<li>\n'
#           '<a href="/an/contact/index.html">\n'
#           '<i class="custom-icon icon-contact"></i>Contact Search</a>\n'
#           '</li>\n'
#           '<li>\n'
#           '<a href="https://www.shimadzu.com/links/index.html" '
#           'target="_blank">\n'
#           '<i class="custom-icon icon-earth"></i>Global Links</a>\n'
#           '</li>\n'
#           '</ul>\n'
#           '        <section id="topWhatsnew" class="parent-block news">\n'
#           '</section>\n'
#           '          <h2 class="heading-02 heading-featured">    Featured '
#           'Article</h2>\n'
#           '      <section class="featured-article">\n'
#           '<div class="featured-article-main">\n'
#           '\n'
#           '<a href="/an/lcms/9030/webinar.html">\n'
#           '<i class="featured-article-label">\n'
#           'Products</i>\n'
#           '<figure class="featured-article-image">\n'
#           '<img '
#           'src="/an/sites/shimadzu.com.an/files/470-246_web_a.jpg"></figure>\n'
#           '<figcaption class="featured-article-text">\n'
#           '<h3 class="featured-article-caption">\n'
#           'Featured Presentations</h3>\n'
#           '</figcaption>\n'
#           '</a>\n'
#           '\n'
#           '</div>\n'
#           '<ul class="featured-article-sub">\n'
#           '\n'
#           '<li style="height: 236px;">\n'
#           '<a href="/an/gc/2030/index.html">\n'
#           '<i class="featured-article-label">\n'
#           'Products</i>\n'
#           '<figure class="featured-article-image video-set">\n'
#           '<div><iframe allowfullscreen="" scrolling="no" '
#           'src="https://www.youtube.com/embed/xcAmFdplLuE" width="248" '
#           'height="165" frameborder="0"></iframe></div>\n'
#           '</figure>\n'
#           '<figcaption class="featured-article-text">\n'
#           '<h3 class="featured-article-caption">\n'
#           'Nexis GC-2030</h3>\n'
#           '<p class="featured-article-describe">\n'
#           'Gas Chromatography</p>\n'
#           '</figcaption>\n'
#           '</a>\n'
#           '</li>\n'
#           '\n'
#           '\n'
#           '<li style="height: 236px;">\n'
#           '<a href="/an/hplc/i-series/index.html">\n'
#           '<i class="featured-article-label">\n'
#           'Products</i>\n'
#           '<figure class="featured-article-image">\n'
#           '<img '
#           'src="/an/sites/shimadzu.com.an/files/top/top_feature_i-series.jpg"></figure>\n'
#           '<figcaption class="featured-article-text">\n'
#           '<h3 class="featured-article-caption">\n'
#           'i-Series Plus</h3>\n'
#           '<p class="featured-article-describe">\n'
#           'New Industry Standard HPLCs</p>\n'
#           '</figcaption>\n'
#           '</a>\n'
#           '</li>\n'
#           '\n'
#           '\n'
#           '<li style="height: 236px;">\n'
#           '<a href="/an/bridge/index.html">\n'
#           '<i class="featured-article-label">\n'
#           "User's Voice</i>\n"
#           '<figure class="featured-article-image">\n'
#           '<img src="/an/sites/shimadzu.com.an/files/bridge_a.jpg"></figure>\n'
#           '<figcaption class="featured-article-text">\n'
#           '<h3 class="featured-article-caption">\n'
#           'Bridge</h3>\n'
#           '</figcaption>\n'
#           '</a>\n'
#           '</li>\n'
#           '\n'
#           '</ul>\n'
#           '</section>\n'
#           '      </div>\n'
#           '</div>\n'
#           '  \n'
#           '  <footer>\n'
#           '    <!-- Page Footer Region START -->\n'
#           '    <div class="container">\n'
#           '      <ul class="links">\n'
#           '          <li><a href="https://www.shimadzu.com/privacy/">Privacy '
#           'Policy</a></li>\n'
#           '          <li><a '
#           'href="https://www.shimadzu.com/terms/index.html">Terms of '
#           'Use</a></li>\n'
#           '          <li><a href="/an/sitemap.html">Site Map</a></li>\n'
#           '        </ul>                        <ul class="sns">\n'
#           '<li>\n'
#           '<h2><i class="custom-icon icon-share-connection"></i>Follow '
#           'Us:</h2></li>\n'
#           '<li>\n'
#           '<a href="https://www.facebook.com/ShimadzuCorp" target="_blank" '
#           'class="fb">\n'
#           '<img '
#           'src="/an/profiles/shimadzu/themes/shimadzu/images/icon-facebook.svg" '
#           'alt="facebook"></a>\n'
#           '</li>\n'
#           '<li>\n'
#           '<a href="https://www.linkedin.com/company/shimadzu-corporation" '
#           'target="_blank" class="linkedin">\n'
#           '<img '
#           'src="/an/profiles/shimadzu/themes/shimadzu/images/icon-linkedin.svg" '
#           'alt="linkedin"></a>\n'
#           '</li>\n'
#           '<li>\n'
#           '<a href="https://www.youtube.com/user/shimadzuan" target="_blank" '
#           'class="youtube">\n'
#           '<img '
#           'src="/an/profiles/shimadzu/themes/shimadzu/images/icon-youtube.svg" '
#           'alt="youtube"></a>\n'
#           '</li>\n'
#           '</ul>\n'
#           '                    <p class="copyright"><img '
#           'src="/an/sites/shimadzu.com.an/files/copyright.png"></p>    </div>\n'
#           '    <!-- Page Footer Region END -->\n'
#           '    </footer>\n'
#           '\n'
#           '  <div class="page-top-area"><a href="javascript:void(0);" '
#           'class="btn-page-top js-btn-page-top"><i class="icon '
#           'icon-arrow-page-top">Top of This Page</i></a></div>\n'
#           '</div>\n'
#           '  \n'
#           '  \n'
#           '<script type="text/javascript" '
#           'src="/an/misc/jquery.once.js?v=1.2"></script>\n'
#           '<script type="text/javascript" '
#           'src="/an/misc/drupal.js?phehjp"></script>\n'
#           '<script type="text/javascript" '
#           'src="/cgi-bin/now_time.cgi?phehjp"></script>\n'
#           '<script type="text/javascript" '
#           'src="/an/profiles/shimadzu/themes/shimadzu/js/newsevent.js?phehjp"></script>\n'
#           '<script type="text/javascript" '
#           'src="/an/sites/all/modules/google_analytics/googleanalytics.js?phehjp"></script>\n'
#           '<script type="text/javascript">\n'
#           '<!--//--><![CDATA[//><!--\n'
#           '(function(i,s,o,g,r,a,m){i["GoogleAnalyticsObject"]=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new '
#           'Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,"script","//www.google-analytics.com/analytics.js","ga");ga("create", '
#           '"UA-2119644-2", {"cookieDomain":"auto"});ga("set", "anonymizeIp", '
#           'true);ga("send", "pageview");\n'
#           '//--><!]]>\n'
#           '</script>\n'
#           '<script type="text/javascript" '
#           'src="/an/profiles/shimadzu/themes/shimadzu/js/lib/baguetteBox.min.js?phehjp"></script>\n'
#           '<script type="text/javascript" '
#           'src="/an/profiles/shimadzu/themes/shimadzu/js/globalnav_secondary.js?phehjp"></script>\n'
#           '<script type="text/javascript" '
#           'src="/an/profiles/shimadzu/themes/shimadzu/js/jquery.min.js?phehjp"></script>\n'
#           '<script type="text/javascript" '
#           'src="/an/profiles/shimadzu/themes/shimadzu/js/plugins.js?phehjp"></script>\n'
#           '<script type="text/javascript" '
#           'src="/an/profiles/shimadzu/themes/shimadzu/js/slick.js?phehjp"></script>\n'
#           '<script type="text/javascript" '
#           'src="/an/profiles/shimadzu/themes/shimadzu/js/lib/waslidemenu.js?phehjp"></script>\n'
#           '<script type="text/javascript" '
#           'src="/an/profiles/shimadzu/themes/shimadzu/js/modules.js?phehjp"></script><div '
#           'role="dialog" id="baguetteBox-overlay"><div '
#           'id="baguetteBox-slider"></div><button type="button" '
#           'id="previous-button" aria-label="Previous" '
#           'class="baguetteBox-button"><svg width="44" height="60"><polyline '
#           'points="30 10 10 30 30 50" stroke="rgba(255,255,255,0.5)" '
#           'stroke-width="4" stroke-linecap="butt" fill="none" '
#           'stroke-linejoin="round"></polyline></svg></button><button '
#           'type="button" id="next-button" aria-label="Next" '
#           'class="baguetteBox-button"><svg width="44" height="60"><polyline '
#           'points="14 10 34 30 14 50" stroke="rgba(255,255,255,0.5)" '
#           'stroke-width="4" stroke-linecap="butt" fill="none" '
#           'stroke-linejoin="round"></polyline></svg></button><button '
#           'type="button" id="close-button" aria-label="Close" '
#           'class="baguetteBox-button"><svg width="30" height="30"><g '
#           'stroke="rgb(160,160,160)" stroke-width="4"><line x1="5" y1="5" '
#           'x2="25" y2="25"></line><line x1="5" y1="25" x2="25" '
#           'y2="5"></line></g></svg></button></div>\n'
#           '<script type="text/javascript">\n'
#           '<!--//--><![CDATA[//><!--\n'
#           'jQuery(document).ready(function(){ '
#           'showNewsListTopPage("topWhatsnew", 10);});\n'
#           '//--><!]]>\n'
#           '</script>\n'
#           '<script type="text/javascript">\n'
#           '<!--//--><![CDATA[//><!--\n'
#           '(function($) {\n'
#           '  $(document).ready(function() {\n'
#           '    var $topViSlider = $(".topVi .slider");\n'
#           '    $topViSlider.on("init", function() {\n'
#           '      addPrClass("pr", $(".thumbWrap").find("li"));\n'
#           '    });\n'
#           '    $topViSlider.slick({\n'
#           '      appendDots: $(".thumbWrapWrapper"),\n'
#           '      arrows: false,\n'
#           '      dots: true,\n'
#           '      fade: true,\n'
#           '      dotsClass: "thumbWrap hidden-pc display-flex",\n'
#           '      customPaging: slickCustomDots,\n'
#           '      speed: 1500,\n'
#           '      initialSlide: 0,\n'
#           '      autoplaySpeed: 5000,\n'
#           '      autoplay: true\n'
#           '    });\n'
#           '\n'
#           '    var $topViSliderPC = $(".topVi .sliderPC");\n'
#           '    $topViSliderPC.on("init", function() {\n'
#           '      addPrClass("pr", $(".thumbWrap").find("li"));\n'
#           '    });\n'
#           '    $topViSliderPC.slick({\n'
#           '      appendDots: $(".thumbWrapWrapper"),\n'
#           '      arrows: false,\n'
#           '      dots: true,\n'
#           '      fade: true,\n'
#           '      dotsClass: "thumbWrap hidden-sp",\n'
#           '      customPaging: slickCustomDots,\n'
#           '      speed: 1500,\n'
#           '      initialSlide: 0,\n'
#           '      autoplaySpeed: 5000,\n'
#           '      autoplay: true\n'
#           '    });\n'
#           '\n'
#           '    // force to stop autoplay when nav is clicked\n'
#           '    $(".thumbWrap").find("li").click(function() {\n'
#           '      $(".topVi .slider").slick("slickPause");\n'
#           '      $(".topVi .sliderPC").slick("slickPause");\n'
#           '    });\n'
#           '\n'
#           '    function slickCustomDots(slick, index) {\n'
#           '      var thisPair = slick.$slides.eq(index);\n'
#           '      var thisPairClassName = thisPair.attr("class");\n'
#           '\n'
#           '      var slickDotLabel = thisPair.data("slick-dot-label");\n'
#           '      return slickDotLabel;\n'
#           '    }\n'
#           '\n'
#           '    function addPrClass(targetClassName, targetElements) {\n'
#           '      var lastIndex = targetElements.length - 1;\n'
#           '      for (var i = 0; i < 1; i++) {\n'
#           '        targetElements.eq(lastIndex - i).addClass("pr");\n'
#           '      }\n'
#           '    }\n'
#           '  });\n'
#           '})(jQuery);\n'
#           '//--><!]]>\n'
#           '</script>\n'
#           '<script type="text/javascript">\n'
#           '<!--//--><![CDATA[//><!--\n'
#           'jQuery.extend(Drupal.settings, '
#           '{"basePath":"\\/an\\/","pathPrefix":"","ajaxPageState":{"theme":"shimadzu","theme_token":"blNwYHSzzavu4hAAaNB8cU-MPNMCT1LA9_hvHwXWLdA","js":{"misc\\/jquery.js":1,"misc\\/jquery.once.js":1,"misc\\/drupal.js":1,"\\/cgi-bin\\/now_time.cgi":1,"profiles\\/shimadzu\\/themes\\/shimadzu\\/js\\/newsevent.js":1,"sites\\/all\\/modules\\/google_analytics\\/googleanalytics.js":1,"0":1,"profiles\\/shimadzu\\/themes\\/shimadzu\\/js\\/lib\\/baguetteBox.min.js":1,"profiles\\/shimadzu\\/themes\\/shimadzu\\/js\\/globalnav_secondary.js":1,"profiles\\/shimadzu\\/themes\\/shimadzu\\/js\\/jquery.min.js":1,"profiles\\/shimadzu\\/themes\\/shimadzu\\/js\\/plugins.js":1,"profiles\\/shimadzu\\/themes\\/shimadzu\\/js\\/slick.js":1,"profiles\\/shimadzu\\/themes\\/shimadzu\\/js\\/lib\\/waslidemenu.js":1,"profiles\\/shimadzu\\/themes\\/shimadzu\\/js\\/modules.js":1,"1":1,"2":1},"css":{"modules\\/system\\/system.base.css":1,"modules\\/system\\/system.menus.css":1,"modules\\/system\\/system.messages.css":1,"modules\\/system\\/system.theme.css":1,"sites\\/all\\/modules\\/date\\/date_api\\/date.css":1,"sites\\/all\\/modules\\/date\\/date_popup\\/themes\\/datepicker.1.7.css":1,"modules\\/field\\/theme\\/field.css":1,"modules\\/node\\/node.css":1,"modules\\/user\\/user.css":1,"sites\\/all\\/modules\\/views\\/css\\/views.css":1,"sites\\/all\\/modules\\/ckeditor\\/css\\/ckeditor.css":1,"sites\\/all\\/modules\\/ctools\\/css\\/ctools.css":1,"profiles\\/shimadzu\\/themes\\/shimadzu\\/css\\/style.css":1}},"googleanalytics":{"trackOutbound":1,"trackMailto":1,"trackDownload":1,"trackDownloadExtensions":"7z|aac|arc|arj|asf|asx|avi|bin|csv|doc(x|m)?|dot(x|m)?|exe|flv|gif|gz|gzip|hqx|jar|jpe?g|js|mp(2|3|4|e?g)|mov(ie)?|msi|msp|pdf|phps|png|ppt(x|m)?|pot(x|m)?|pps(x|m)?|ppam|sld(x|m)?|thmx|qtm?|ra(m|r)?|sea|sit|tar|tgz|torrent|txt|wav|wma|wmv|wpd|xls(x|m|b)?|xlt(x|m)|xlam|xml|z|zip"}});\n'
#           '//--><!]]>\n'
#           '</script>\n'
#           '\n'
#           '\n'
#           '</body>'],
#  'depth': [1],
#  'domain': ['www.shimadzu.com'],
#  'firm_name': ['Shimadzu Corporation'],
#  'footer': ['<footer>\n'
#             '    <!-- Page Footer Region START -->\n'
#             '    <div class="container">\n'
#             '      <ul class="links">\n'
#             '          <li><a href="https://www.shimadzu.com/privacy/">Privacy '
#             'Policy</a></li>\n'
#             '          <li><a '
#             'href="https://www.shimadzu.com/terms/index.html">Terms of '
#             'Use</a></li>\n'
#             '          <li><a href="/an/sitemap.html">Site Map</a></li>\n'
#             '        </ul>                        <ul class="sns">\n'
#             '<li>\n'
#             '<h2><i class="custom-icon icon-share-connection"></i>Follow '
#             'Us:</h2></li>\n'
#             '<li>\n'
#             '<a href="https://www.facebook.com/ShimadzuCorp" target="_blank" '
#             'class="fb">\n'
#             '<img '
#             'src="/an/profiles/shimadzu/themes/shimadzu/images/icon-facebook.svg" '
#             'alt="facebook"></a>\n'
#             '</li>\n'
#             '<li>\n'
#             '<a href="https://www.linkedin.com/company/shimadzu-corporation" '
#             'target="_blank" class="linkedin">\n'
#             '<img '
#             'src="/an/profiles/shimadzu/themes/shimadzu/images/icon-linkedin.svg" '
#             'alt="linkedin"></a>\n'
#             '</li>\n'
#             '<li>\n'
#             '<a href="https://www.youtube.com/user/shimadzuan" target="_blank" '
#             'class="youtube">\n'
#             '<img '
#             'src="/an/profiles/shimadzu/themes/shimadzu/images/icon-youtube.svg" '
#             'alt="youtube"></a>\n'
#             '</li>\n'
#             '</ul>\n'
#             '                    <p class="copyright"><img '
#             'src="/an/sites/shimadzu.com.an/files/copyright.png"></p>    '
#             '</div>\n'
#             '    <!-- Page Footer Region END -->\n'
#             '    </footer>'],
#  'full_text': ['SHIMADZU',
#                'ABOUT SHIMADZU',
#                'CONTACT US',
#                'GLOBAL LINKS',
#                'Contact Search',
#                'Quotation',
#                'Inquiry',
#                'HOME',
#                'PRODUCTS',
#                'INDUSTRIES',
#                'LITERATURE',
#                'SERVICE & SUPPORT',
#                'NEWS / EVENT',
#                'CORPORATE RELATIONSHIPS',
#                'About Shimadzu',
#                'Contact Search',
#                'Global Links',
#                '    Featured Article',
#                '\nProducts',
#                '\nFeatured Presentations',
#                '\nProducts',
#                '\nNexis GC-2030',
#                '\nGas Chromatography',
#                '\nProducts',
#                '\ni-Series Plus',
#                '\nNew Industry Standard HPLCs',
#                "\nUser's Voice",
#                '\nBridge',
#                'Privacy Policy',
#                'Terms of Use',
#                'Site Map',
#                'Follow Us:',
#                'Top of This Page',
#                '\n'
#                '<!--//--><![CDATA[//><!--\n'
#                '(function(i,s,o,g,r,a,m){i["GoogleAnalyticsObject"]=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new '
#                'Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,"script","//www.google-analytics.com/analytics.js","ga");ga("create", '
#                '"UA-2119644-2", {"cookieDomain":"auto"});ga("set", '
#                '"anonymizeIp", true);ga("send", "pageview");\n'
#                '//--><!]]>\n',
#                '\n'
#                '<!--//--><![CDATA[//><!--\n'
#                'jQuery(document).ready(function(){ '
#                'showNewsListTopPage("topWhatsnew", 10);});\n'
#                '//--><!]]>\n',
#                '\n'
#                '<!--//--><![CDATA[//><!--\n'
#                '(function($) {\n'
#                '  $(document).ready(function() {\n'
#                '    var $topViSlider = $(".topVi .slider");\n'
#                '    $topViSlider.on("init", function() {\n'
#                '      addPrClass("pr", $(".thumbWrap").find("li"));\n'
#                '    });\n'
#                '    $topViSlider.slick({\n'
#                '      appendDots: $(".thumbWrapWrapper"),\n'
#                '      arrows: false,\n'
#                '      dots: true,\n'
#                '      fade: true,\n'
#                '      dotsClass: "thumbWrap hidden-pc display-flex",\n'
#                '      customPaging: slickCustomDots,\n'
#                '      speed: 1500,\n'
#                '      initialSlide: 0,\n'
#                '      autoplaySpeed: 5000,\n'
#                '      autoplay: true\n'
#                '    });\n'
#                '\n'
#                '    var $topViSliderPC = $(".topVi .sliderPC");\n'
#                '    $topViSliderPC.on("init", function() {\n'
#                '      addPrClass("pr", $(".thumbWrap").find("li"));\n'
#                '    });\n'
#                '    $topViSliderPC.slick({\n'
#                '      appendDots: $(".thumbWrapWrapper"),\n'
#                '      arrows: false,\n'
#                '      dots: true,\n'
#                '      fade: true,\n'
#                '      dotsClass: "thumbWrap hidden-sp",\n'
#                '      customPaging: slickCustomDots,\n'
#                '      speed: 1500,\n'
#                '      initialSlide: 0,\n'
#                '      autoplaySpeed: 5000,\n'
#                '      autoplay: true\n'
#                '    });\n'
#                '\n'
#                '    // force to stop autoplay when nav is clicked\n'
#                '    $(".thumbWrap").find("li").click(function() {\n'
#                '      $(".topVi .slider").slick("slickPause");\n'
#                '      $(".topVi .sliderPC").slick("slickPause");\n'
#                '    });\n'
#                '\n'
#                '    function slickCustomDots(slick, index) {\n'
#                '      var thisPair = slick.$slides.eq(index);\n'
#                '      var thisPairClassName = thisPair.attr("class");\n'
#                '\n'
#                '      var slickDotLabel = thisPair.data("slick-dot-label");\n'
#                '      return slickDotLabel;\n'
#                '    }\n'
#                '\n'
#                '    function addPrClass(targetClassName, targetElements) {\n'
#                '      var lastIndex = targetElements.length - 1;\n'
#                '      for (var i = 0; i < 1; i++) {\n'
#                '        targetElements.eq(lastIndex - i).addClass("pr");\n'
#                '      }\n'
#                '    }\n'
#                '  });\n'
#                '})(jQuery);\n'
#                '//--><!]]>\n',
#                '\n'
#                '<!--//--><![CDATA[//><!--\n'
#                'jQuery.extend(Drupal.settings, '
#                '{"basePath":"\\/an\\/","pathPrefix":"","ajaxPageState":{"theme":"shimadzu","theme_token":"blNwYHSzzavu4hAAaNB8cU-MPNMCT1LA9_hvHwXWLdA","js":{"misc\\/jquery.js":1,"misc\\/jquery.once.js":1,"misc\\/drupal.js":1,"\\/cgi-bin\\/now_time.cgi":1,"profiles\\/shimadzu\\/themes\\/shimadzu\\/js\\/newsevent.js":1,"sites\\/all\\/modules\\/google_analytics\\/googleanalytics.js":1,"0":1,"profiles\\/shimadzu\\/themes\\/shimadzu\\/js\\/lib\\/baguetteBox.min.js":1,"profiles\\/shimadzu\\/themes\\/shimadzu\\/js\\/globalnav_secondary.js":1,"profiles\\/shimadzu\\/themes\\/shimadzu\\/js\\/jquery.min.js":1,"profiles\\/shimadzu\\/themes\\/shimadzu\\/js\\/plugins.js":1,"profiles\\/shimadzu\\/themes\\/shimadzu\\/js\\/slick.js":1,"profiles\\/shimadzu\\/themes\\/shimadzu\\/js\\/lib\\/waslidemenu.js":1,"profiles\\/shimadzu\\/themes\\/shimadzu\\/js\\/modules.js":1,"1":1,"2":1},"css":{"modules\\/system\\/system.base.css":1,"modules\\/system\\/system.menus.css":1,"modules\\/system\\/system.messages.css":1,"modules\\/system\\/system.theme.css":1,"sites\\/all\\/modules\\/date\\/date_api\\/date.css":1,"sites\\/all\\/modules\\/date\\/date_popup\\/themes\\/datepicker.1.7.css":1,"modules\\/field\\/theme\\/field.css":1,"modules\\/node\\/node.css":1,"modules\\/user\\/user.css":1,"sites\\/all\\/modules\\/views\\/css\\/views.css":1,"sites\\/all\\/modules\\/ckeditor\\/css\\/ckeditor.css":1,"sites\\/all\\/modules\\/ctools\\/css\\/ctools.css":1,"profiles\\/shimadzu\\/themes\\/shimadzu\\/css\\/style.css":1}},"googleanalytics":{"trackOutbound":1,"trackMailto":1,"trackDownload":1,"trackDownloadExtensions":"7z|aac|arc|arj|asf|asx|avi|bin|csv|doc(x|m)?|dot(x|m)?|exe|flv|gif|gz|gzip|hqx|jar|jpe?g|js|mp(2|3|4|e?g)|mov(ie)?|msi|msp|pdf|phps|png|ppt(x|m)?|pot(x|m)?|pps(x|m)?|ppam|sld(x|m)?|thmx|qtm?|ra(m|r)?|sea|sit|tar|tgz|torrent|txt|wav|wma|wmv|wpd|xls(x|m|b)?|xlt(x|m)|xlam|xml|z|zip"}});\n'
#                '//--><!]]>\n'],
#  'head': ['<head>\n'
#           '    <meta charset="utf-8">\n'
#           '  <meta http-equiv="X-UA-Compatible" content="IE=edge">\n'
#           '  <script async="" '
#           'src="//www.google-analytics.com/analytics.js"></script><script>\n'
#           '  var ua = navigator.userAgent;\n'
#           "  if (ua.indexOf('iPad') > 0 || (ua.indexOf('Android') > 0 && "
#           "ua.indexOf('Mobile') < 0)) {\n"
#           '    document.write(\'<meta name="viewport" '
#           'content="width=1040">\');\n'
#           '  } else {\n'
#           '    document.write(\'<meta name="viewport" '
#           'content="width=device-width,initial-scale=1">\');\n'
#           '  }\n'
#           '  </script><meta name="viewport" '
#           'content="width=device-width,initial-scale=1">\n'
#           '  <meta name="mobile-web-app-capable" content="yes">\n'
#           '  <meta name="theme-color" content="#ffffff">\n'
#           '  <meta name="application-name">\n'
#           '  <link rel="apple-touch-icon" sizes="57x57" '
#           'href="/an/profiles/shimadzu/themes/shimadzu/favicons/apple-touch-icon-57x57.png">\n'
#           '  <link rel="apple-touch-icon" sizes="60x60" '
#           'href="/an/profiles/shimadzu/themes/shimadzu/favicons/apple-touch-icon-60x60.png">\n'
#           '  <link rel="apple-touch-icon" sizes="72x72" '
#           'href="/an/profiles/shimadzu/themes/shimadzu/favicons/apple-touch-icon-72x72.png">\n'
#           '  <link rel="apple-touch-icon" sizes="76x76" '
#           'href="/an/profiles/shimadzu/themes/shimadzu/favicons/apple-touch-icon-76x76.png">\n'
#           '  <link rel="apple-touch-icon" sizes="114x114" '
#           'href="/an/profiles/shimadzu/themes/shimadzu/favicons/apple-touch-icon-114x114.png">\n'
#           '  <link rel="apple-touch-icon" sizes="120x120" '
#           'href="/an/profiles/shimadzu/themes/shimadzu/favicons/apple-touch-icon-120x120.png">\n'
#           '  <link rel="apple-touch-icon" sizes="144x144" '
#           'href="/an/profiles/shimadzu/themes/shimadzu/favicons/apple-touch-icon-144x144.png">\n'
#           '  <link rel="apple-touch-icon" sizes="152x152" '
#           'href="/an/profiles/shimadzu/themes/shimadzu/favicons/apple-touch-icon-152x152.png">\n'
#           '  <link rel="apple-touch-icon" sizes="180x180" '
#           'href="/an/profiles/shimadzu/themes/shimadzu/favicons/apple-touch-icon-180x180.png">\n'
#           '  <meta name="apple-mobile-web-app-capable" content="yes">\n'
#           '  <meta name="apple-mobile-web-app-status-bar-style" '
#           'content="black-translucent">\n'
#           '  <meta name="apple-mobile-web-app-title">\n'
#           '  <link rel="icon" type="image/png" sizes="228x228" '
#           'href="/an/profiles/shimadzu/themes/shimadzu/favicons/coast-228x228.png">\n'
#           '  <link rel="yandex-tableau-widget" '
#           'href="/an/profiles/shimadzu/themes/shimadzu/favicons/yandex-browser-manifest.json">\n'
#           '  <meta name="msapplication-TileColor" content="#ffffff">\n'
#           '  <meta name="msapplication-TileImage" '
#           'content="/an/profiles/shimadzu/themes/shimadzu/favicons/mstile-144x144.png">\n'
#           '  <meta name="msapplication-config" '
#           'content="/an/profiles/shimadzu/themes/shimadzu/favicons/browserconfig.xml">\n'
#           '  <link rel="icon" type="image/png" sizes="32x32" '
#           'href="/an/profiles/shimadzu/themes/shimadzu/favicons/favicon-32x32.png">\n'
#           '  <link rel="icon" type="image/png" sizes="192x192" '
#           'href="/an/profiles/shimadzu/themes/shimadzu/favicons/android-chrome-192x192.png">\n'
#           '  <link rel="icon" type="image/png" sizes="16x16" '
#           'href="/an/profiles/shimadzu/themes/shimadzu/favicons/favicon-16x16.png">\n'
#           '  <link rel="shortcut icon" '
#           'href="/an/profiles/shimadzu/themes/shimadzu/favicons/favicon.ico">\n'
#           '  <link rel="apple-touch-startup-image" media="(device-width: '
#           '320px) and (device-height: 480px) and (-webkit-device-pixel-ratio: '
#           '1)" '
#           'href="/an/profiles/shimadzu/themes/shimadzu/favicons/apple-touch-startup-image-320x460.png">\n'
#           '  <link rel="apple-touch-startup-image" media="(device-width: '
#           '320px) and (device-height: 480px) and (-webkit-device-pixel-ratio: '
#           '2)" '
#           'href="/an/profiles/shimadzu/themes/shimadzu/favicons/apple-touch-startup-image-640x920.png">\n'
#           '  <link rel="apple-touch-startup-image" media="(device-width: '
#           '320px) and (device-height: 568px) and (-webkit-device-pixel-ratio: '
#           '2)" '
#           'href="/an/profiles/shimadzu/themes/shimadzu/favicons/apple-touch-startup-image-640x1096.png">\n'
#           '  <link rel="apple-touch-startup-image" media="(device-width: '
#           '375px) and (device-height: 667px) and (-webkit-device-pixel-ratio: '
#           '2)" '
#           'href="/an/profiles/shimadzu/themes/shimadzu/favicons/apple-touch-startup-image-750x1294.png">\n'
#           '  <link rel="apple-touch-startup-image" media="(device-width: '
#           '414px) and (device-height: 736px) and (orientation: landscape) and '
#           '(-webkit-device-pixel-ratio: 3)" '
#           'href="/an/profiles/shimadzu/themes/shimadzu/favicons/apple-touch-startup-image-1182x2208.png">\n'
#           '  <link rel="apple-touch-startup-image" media="(device-width: '
#           '414px) and (device-height: 736px) and (orientation: portrait) and '
#           '(-webkit-device-pixel-ratio: 3)" '
#           'href="/an/profiles/shimadzu/themes/shimadzu/favicons/apple-touch-startup-image-1242x2148.png">\n'
#           '  <link rel="apple-touch-startup-image" media="(device-width: '
#           '768px) and (device-height: 1024px) and (orientation: landscape) and '
#           '(-webkit-device-pixel-ratio: 1)" '
#           'href="/an/profiles/shimadzu/themes/shimadzu/favicons/apple-touch-startup-image-748x1024.png">\n'
#           '  <link rel="apple-touch-startup-image" media="(device-width: '
#           '768px) and (device-height: 1024px) and (orientation: portrait) and '
#           '(-webkit-device-pixel-ratio: 1)" '
#           'href="/an/profiles/shimadzu/themes/shimadzu/favicons/apple-touch-startup-image-768x1004.png">\n'
#           '  <link rel="apple-touch-startup-image" media="(device-width: '
#           '768px) and (device-height: 1024px) and (orientation: landscape) and '
#           '(-webkit-device-pixel-ratio: 2)" '
#           'href="/an/profiles/shimadzu/themes/shimadzu/favicons/apple-touch-startup-image-1496x2048.png">\n'
#           '  <link rel="apple-touch-startup-image" media="(device-width: '
#           '768px) and (device-height: 1024px) and (orientation: portrait) and '
#           '(-webkit-device-pixel-ratio: 2)" '
#           'href="/an/profiles/shimadzu/themes/shimadzu/favicons/apple-touch-startup-image-1536x2008.png">\n'
#           '  <link rel="manifest" href="/an/manifest/manifest.json">\n'
#           '<script src="/an/geotargeting.js?alias=index.html"></script><meta '
#           'name="description" content="Shimadzu Corporation">\n'
#           '<meta name="keywords" content="Shimadzu Corporation">\n'
#           '  <title>TOP : SHIMADZU (Shimadzu Corporation)</title>\n'
#           '  <style type="text/css" media="all">\n'
#           '@import url("/an/modules/system/system.base.css?phehjp");\n'
#           '@import url("/an/modules/system/system.menus.css?phehjp");\n'
#           '@import url("/an/modules/system/system.messages.css?phehjp");\n'
#           '@import url("/an/modules/system/system.theme.css?phehjp");\n'
#           '</style>\n'
#           '<style type="text/css" media="all">\n'
#           '@import '
#           'url("/an/sites/all/modules/date/date_api/date.css?phehjp");\n'
#           '@import '
#           'url("/an/sites/all/modules/date/date_popup/themes/datepicker.1.7.css?phehjp");\n'
#           '@import url("/an/modules/field/theme/field.css?phehjp");\n'
#           '@import url("/an/modules/node/node.css?phehjp");\n'
#           '@import url("/an/modules/user/user.css?phehjp");\n'
#           '@import url("/an/sites/all/modules/views/css/views.css?phehjp");\n'
#           '@import '
#           'url("/an/sites/all/modules/ckeditor/css/ckeditor.css?phehjp");\n'
#           '</style>\n'
# ...
#           'role="presentation" aria-selected="false" '
#           'aria-controls="navigation04" id="slick-slide04">Machinery, '
#           'Automotive</li></ul><ul class="thumbWrap hidden-sp" style="display: '
#           'flex;" role="tablist"><li class="slick-active" aria-hidden="false" '
#           'role="presentation" aria-selected="true" '
#           'aria-controls="navigation10" id="slick-slide10">Pharmaceutical, '
#           'Life Science</li><li aria-hidden="true" role="presentation" '
#           'aria-selected="false" aria-controls="navigation11" '
#           'id="slick-slide11">Food, Beverages</li><li aria-hidden="true" '
#           'role="presentation" aria-selected="false" '
#           'aria-controls="navigation12" id="slick-slide12">Environment</li><li '
#           'aria-hidden="true" role="presentation" aria-selected="false" '
#           'aria-controls="navigation13" id="slick-slide13">Hydrocarbon '
#           'Processing Industry</li><li aria-hidden="true" class="pr" '
#           'role="presentation" aria-selected="false" '
#           'aria-controls="navigation14" id="slick-slide14">Machinery, '
#           'Automotive</li></ul></div>\n'
#           '</section>\n'
#           '<div id="topMain">\n'
#           '  <div class="container">\n'
#           '    <ul class="gateways">\n'
#           '<li>\n'
#           '<a href="https://www.shimadzu.com/about/" target="_blank">\n'
#           '<i class="custom-icon icon-building"></i>About Shimadzu</a>\n'
#           '</li>\n'
#           '<li>\n'
#           '<a href="/an/contact/index.html">\n'
#           '<i class="custom-icon icon-contact"></i>Contact Search</a>\n'
#           '</li>\n'
#           '<li>\n'
#           '<a href="https://www.shimadzu.com/links/index.html" '
#           'target="_blank">\n'
#           '<i class="custom-icon icon-earth"></i>Global Links</a>\n'
#           '</li>\n'
#           '</ul>\n'
#           '        <section id="topWhatsnew" class="parent-block news">\n'
#           '</section>\n'
#           '          <h2 class="heading-02 heading-featured">    Featured '
#           'Article</h2>\n'
#           '      <section class="featured-article">\n'
#           '<div class="featured-article-main">\n'
#           '\n'
#           '<a href="/an/lcms/9030/webinar.html">\n'
#           '<i class="featured-article-label">\n'
#           'Products</i>\n'
#           '<figure class="featured-article-image">\n'
#           '<img '
#           'src="/an/sites/shimadzu.com.an/files/470-246_web_a.jpg"></figure>\n'
#           '<figcaption class="featured-article-text">\n'
#           '<h3 class="featured-article-caption">\n'
#           'Featured Presentations</h3>\n'
#           '</figcaption>\n'
#           '</a>\n'
#           '\n'
#           '</div>\n'
#           '<ul class="featured-article-sub">\n'
#           '\n'
#           '<li style="height: 236px;">\n'
#           '<a href="/an/gc/2030/index.html">\n'
#           '<i class="featured-article-label">\n'
#           'Products</i>\n'
#           '<figure class="featured-article-image video-set">\n'
#           '<div><iframe allowfullscreen="" scrolling="no" '
#           'src="https://www.youtube.com/embed/xcAmFdplLuE" width="248" '
#           'height="165" frameborder="0"></iframe></div>\n'
#           '</figure>\n'
#           '<figcaption class="featured-article-text">\n'
#           '<h3 class="featured-article-caption">\n'
#           'Nexis GC-2030</h3>\n'
#           '<p class="featured-article-describe">\n'
#           'Gas Chromatography</p>\n'
#           '</figcaption>\n'
#           '</a>\n'
#           '</li>\n'
#           '\n'
#           '\n'
#           '<li style="height: 236px;">\n'
#           '<a href="/an/hplc/i-series/index.html">\n'
#           '<i class="featured-article-label">\n'
#           'Products</i>\n'
#           '<figure class="featured-article-image">\n'
#           '<img '
#           'src="/an/sites/shimadzu.com.an/files/top/top_feature_i-series.jpg"></figure>\n'
#           '<figcaption class="featured-article-text">\n'
#           '<h3 class="featured-article-caption">\n'
#           'i-Series Plus</h3>\n'
#           '<p class="featured-article-describe">\n'
#           'New Industry Standard HPLCs</p>\n'
#           '</figcaption>\n'
#           '</a>\n'
#           '</li>\n'
#           '\n'
#           '\n'
#           '<li style="height: 236px;">\n'
#           '<a href="/an/bridge/index.html">\n'
#           '<i class="featured-article-label">\n'
#           "User's Voice</i>\n"
#           '<figure class="featured-article-image">\n'
#           '<img src="/an/sites/shimadzu.com.an/files/bridge_a.jpg"></figure>\n'
#           '<figcaption class="featured-article-text">\n'
#           '<h3 class="featured-article-caption">\n'
#           'Bridge</h3>\n'
#           '</figcaption>\n'
#           '</a>\n'
#           '</li>\n'
#           '\n'
#           '</ul>\n'
#           '</section>\n'
#           '      </div>\n'
#           '</div>\n'
#           '  \n'
#           '  <footer>\n'
#           '    <!-- Page Footer Region START -->\n'
#           '    <div class="container">\n'
#           '      <ul class="links">\n'
#           '          <li><a href="https://www.shimadzu.com/privacy/">Privacy '
#           'Policy</a></li>\n'
#           '          <li><a '
#           'href="https://www.shimadzu.com/terms/index.html">Terms of '
#           'Use</a></li>\n'
#           '          <li><a href="/an/sitemap.html">Site Map</a></li>\n'
#           '        </ul>                        <ul class="sns">\n'
#           '<li>\n'
#           '<h2><i class="custom-icon icon-share-connection"></i>Follow '
#           'Us:</h2></li>\n'
#           '<li>\n'
#           '<a href="https://www.facebook.com/ShimadzuCorp" target="_blank" '
#           'class="fb">\n'
#           '<img '
#           'src="/an/profiles/shimadzu/themes/shimadzu/images/icon-facebook.svg" '
#           'alt="facebook"></a>\n'
#           '</li>\n'
#           '<li>\n'
#           '<a href="https://www.linkedin.com/company/shimadzu-corporation" '
#           'target="_blank" class="linkedin">\n'
#           '<img '
#           'src="/an/profiles/shimadzu/themes/shimadzu/images/icon-linkedin.svg" '
#           'alt="linkedin"></a>\n'
#           '</li>\n'
#           '<li>\n'
#           '<a href="https://www.youtube.com/user/shimadzuan" target="_blank" '
#           'class="youtube">\n'
#           '<img '
#           'src="/an/profiles/shimadzu/themes/shimadzu/images/icon-youtube.svg" '
#           'alt="youtube"></a>\n'
#           '</li>\n'
#           '</ul>\n'
#           '                    <p class="copyright"><img '
#           'src="/an/sites/shimadzu.com.an/files/copyright.png"></p>    </div>\n'
#           '    <!-- Page Footer Region END -->\n'
#           '    </footer>\n'
#           '\n'
#           '  <div class="page-top-area"><a href="javascript:void(0);" '
#           'class="btn-page-top js-btn-page-top"><i class="icon '
#           'icon-arrow-page-top">Top of This Page</i></a></div>\n'
#           '</div>\n'
#           '  \n'
#           '  \n'
#           '<script type="text/javascript" '
#           'src="/an/misc/jquery.once.js?v=1.2"></script>\n'
#           '<script type="text/javascript" '
#           'src="/an/misc/drupal.js?phehjp"></script>\n'
#           '<script type="text/javascript" '
#           'src="/cgi-bin/now_time.cgi?phehjp"></script>\n'
#           '<script type="text/javascript" '
#           'src="/an/profiles/shimadzu/themes/shimadzu/js/newsevent.js?phehjp"></script>\n'
#           '<script type="text/javascript" '
#           'src="/an/sites/all/modules/google_analytics/googleanalytics.js?phehjp"></script>\n'
#           '<script type="text/javascript">\n'
#           '<!--//--><![CDATA[//><!--\n'
#           '(function(i,s,o,g,r,a,m){i["GoogleAnalyticsObject"]=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new '
#           'Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,"script","//www.google-analytics.com/analytics.js","ga");ga("create", '
#           '"UA-2119644-2", {"cookieDomain":"auto"});ga("set", "anonymizeIp", '
#           'true);ga("send", "pageview");\n'
#           '//--><!]]>\n'
#           '</script>\n'
#           '<script type="text/javascript" '
#           'src="/an/profiles/shimadzu/themes/shimadzu/js/lib/baguetteBox.min.js?phehjp"></script>\n'
#           '<script type="text/javascript" '
#           'src="/an/profiles/shimadzu/themes/shimadzu/js/globalnav_secondary.js?phehjp"></script>\n'
#           '<script type="text/javascript" '
#           'src="/an/profiles/shimadzu/themes/shimadzu/js/jquery.min.js?phehjp"></script>\n'
#           '<script type="text/javascript" '
#           'src="/an/profiles/shimadzu/themes/shimadzu/js/plugins.js?phehjp"></script>\n'
#           '<script type="text/javascript" '
#           'src="/an/profiles/shimadzu/themes/shimadzu/js/slick.js?phehjp"></script>\n'
#           '<script type="text/javascript" '
#           'src="/an/profiles/shimadzu/themes/shimadzu/js/lib/waslidemenu.js?phehjp"></script>\n'
#           '<script type="text/javascript" '
#           'src="/an/profiles/shimadzu/themes/shimadzu/js/modules.js?phehjp"></script><div '
#           'role="dialog" id="baguetteBox-overlay"><div '
#           'id="baguetteBox-slider"></div><button type="button" '
#           'id="previous-button" aria-label="Previous" '
#           'class="baguetteBox-button"><svg width="44" height="60"><polyline '
#           'points="30 10 10 30 30 50" stroke="rgba(255,255,255,0.5)" '
#           'stroke-width="4" stroke-linecap="butt" fill="none" '
#           'stroke-linejoin="round"></polyline></svg></button><button '
#           'type="button" id="next-button" aria-label="Next" '
#           'class="baguetteBox-button"><svg width="44" height="60"><polyline '
#           'points="14 10 34 30 14 50" stroke="rgba(255,255,255,0.5)" '
#           'stroke-width="4" stroke-linecap="butt" fill="none" '
#           'stroke-linejoin="round"></polyline></svg></button><button '
#           'type="button" id="close-button" aria-label="Close" '
#           'class="baguetteBox-button"><svg width="30" height="30"><g '
#           'stroke="rgb(160,160,160)" stroke-width="4"><line x1="5" y1="5" '
#           'x2="25" y2="25"></line><line x1="5" y1="25" x2="25" '
#           'y2="5"></line></g></svg></button></div>\n'
#           '<script type="text/javascript">\n'
#           '<!--//--><![CDATA[//><!--\n'
#           'jQuery(document).ready(function(){ '
#           'showNewsListTopPage("topWhatsnew", 10);});\n'
#           '//--><!]]>\n'
#           '</script>\n'
#           '<script type="text/javascript">\n'
#           '<!--//--><![CDATA[//><!--\n'
#           '(function($) {\n'
#           '  $(document).ready(function() {\n'
#           '    var $topViSlider = $(".topVi .slider");\n'
#           '    $topViSlider.on("init", function() {\n'
#           '      addPrClass("pr", $(".thumbWrap").find("li"));\n'
#           '    });\n'
#           '    $topViSlider.slick({\n'
#           '      appendDots: $(".thumbWrapWrapper"),\n'
#           '      arrows: false,\n'
#           '      dots: true,\n'
#           '      fade: true,\n'
#           '      dotsClass: "thumbWrap hidden-pc display-flex",\n'
#           '      customPaging: slickCustomDots,\n'
#           '      speed: 1500,\n'
#           '      initialSlide: 0,\n'
#           '      autoplaySpeed: 5000,\n'
#           '      autoplay: true\n'
#           '    });\n'
#           '\n'
#           '    var $topViSliderPC = $(".topVi .sliderPC");\n'
#           '    $topViSliderPC.on("init", function() {\n'
#           '      addPrClass("pr", $(".thumbWrap").find("li"));\n'
#           '    });\n'
#           '    $topViSliderPC.slick({\n'
#           '      appendDots: $(".thumbWrapWrapper"),\n'
#           '      arrows: false,\n'
#           '      dots: true,\n'
#           '      fade: true,\n'
#           '      dotsClass: "thumbWrap hidden-sp",\n'
#           '      customPaging: slickCustomDots,\n'
#           '      speed: 1500,\n'
#           '      initialSlide: 0,\n'
#           '      autoplaySpeed: 5000,\n'
#           '      autoplay: true\n'
#           '    });\n'
#           '\n'
#           '    // force to stop autoplay when nav is clicked\n'
#           '    $(".thumbWrap").find("li").click(function() {\n'
#           '      $(".topVi .slider").slick("slickPause");\n'
#           '      $(".topVi .sliderPC").slick("slickPause");\n'
#           '    });\n'
#           '\n'
#           '    function slickCustomDots(slick, index) {\n'
#           '      var thisPair = slick.$slides.eq(index);\n'
#           '      var thisPairClassName = thisPair.attr("class");\n'
#           '\n'
#           '      var slickDotLabel = thisPair.data("slick-dot-label");\n'
#           '      return slickDotLabel;\n'
#           '    }\n'
#           '\n'
#           '    function addPrClass(targetClassName, targetElements) {\n'
#           '      var lastIndex = targetElements.length - 1;\n'
#           '      for (var i = 0; i < 1; i++) {\n'
#           '        targetElements.eq(lastIndex - i).addClass("pr");\n'
#           '      }\n'
#           '    }\n'
#           '  });\n'
#           '})(jQuery);\n'
#           '//--><!]]>\n'
#           '</script>\n'
#           '<script type="text/javascript">\n'
#           '<!--//--><![CDATA[//><!--\n'
#           'jQuery.extend(Drupal.settings, '
#           '{"basePath":"\\/an\\/","pathPrefix":"","ajaxPageState":{"theme":"shimadzu","theme_token":"blNwYHSzzavu4hAAaNB8cU-MPNMCT1LA9_hvHwXWLdA","js":{"misc\\/jquery.js":1,"misc\\/jquery.once.js":1,"misc\\/drupal.js":1,"\\/cgi-bin\\/now_time.cgi":1,"profiles\\/shimadzu\\/themes\\/shimadzu\\/js\\/newsevent.js":1,"sites\\/all\\/modules\\/google_analytics\\/googleanalytics.js":1,"0":1,"profiles\\/shimadzu\\/themes\\/shimadzu\\/js\\/lib\\/baguetteBox.min.js":1,"profiles\\/shimadzu\\/themes\\/shimadzu\\/js\\/globalnav_secondary.js":1,"profiles\\/shimadzu\\/themes\\/shimadzu\\/js\\/jquery.min.js":1,"profiles\\/shimadzu\\/themes\\/shimadzu\\/js\\/plugins.js":1,"profiles\\/shimadzu\\/themes\\/shimadzu\\/js\\/slick.js":1,"profiles\\/shimadzu\\/themes\\/shimadzu\\/js\\/lib\\/waslidemenu.js":1,"profiles\\/shimadzu\\/themes\\/shimadzu\\/js\\/modules.js":1,"1":1,"2":1},"css":{"modules\\/system\\/system.base.css":1,"modules\\/system\\/system.menus.css":1,"modules\\/system\\/system.messages.css":1,"modules\\/system\\/system.theme.css":1,"sites\\/all\\/modules\\/date\\/date_api\\/date.css":1,"sites\\/all\\/modules\\/date\\/date_popup\\/themes\\/datepicker.1.7.css":1,"modules\\/field\\/theme\\/field.css":1,"modules\\/node\\/node.css":1,"modules\\/user\\/user.css":1,"sites\\/all\\/modules\\/views\\/css\\/views.css":1,"sites\\/all\\/modules\\/ckeditor\\/css\\/ckeditor.css":1,"sites\\/all\\/modules\\/ctools\\/css\\/ctools.css":1,"profiles\\/shimadzu\\/themes\\/shimadzu\\/css\\/style.css":1}},"googleanalytics":{"trackOutbound":1,"trackMailto":1,"trackDownload":1,"trackDownloadExtensions":"7z|aac|arc|arj|asf|asx|avi|bin|csv|doc(x|m)?|dot(x|m)?|exe|flv|gif|gz|gzip|hqx|jar|jpe?g|js|mp(2|3|4|e?g)|mov(ie)?|msi|msp|pdf|phps|png|ppt(x|m)?|pot(x|m)?|pps(x|m)?|ppam|sld(x|m)?|thmx|qtm?|ra(m|r)?|sea|sit|tar|tgz|torrent|txt|wav|wma|wmv|wpd|xls(x|m|b)?|xlt(x|m)|xlam|xml|z|zip"}});\n'
#           '//--><!]]>\n'
#           '</script>\n'
#           '\n'
#           '\n'
#           '</body></html>'],
#  'referring_url': ['https://www.shimadzu.com/'],
#  'title': ['TOP : SHIMADZU (Shimadzu Corporation)'],
#  'url': ['https://www.shimadzu.com/an/index.html']}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-ab87bf1a7b7c> in <module>
#       4     name = rec['_id'][0]
#       5     print ('Working on', name)
# ----> 6     words_by_firm_name[name] = get_num_words(name) # not cleaned text, but probably a good proxy
#
# <ipython-input-33-7bf165f88637> in get_num_words(name)
#      15         pp.pprint (result)
#      16         if 'full_text' in result:
# ---> 17             num_words += [len(t) for t in text for text in result['full_text']]
#      18         # else continue
#      19     return num_words
#
# NameError: name 'text' is not defined

# %%
measures = {} # key is firm

# pp.pprint(pages_by_firm_name)
for rec in pages_by_firm_name:
    firm_name = clean_firm_name(rec['_id'][0])
    measures[firm_name] = {}
    measures[firm_name]['pages'] = int(rec['number'])
    measures[firm_name]['num_words'] = words_by_firm_name[rec]
# pp.pprint(measures)

# %%
print_measures()

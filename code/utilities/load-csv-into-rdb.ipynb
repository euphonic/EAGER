# %% [markdown]
# # load-csv-into-rdb
# SanjayKAroraPhD@gmail.com <br>
# February 2019
#
# ## Description
# Load a csv into a pandas dataframe and persist to a mysql db

# %%
import pandas as pd
import csv 
from pandas.io import sql
from sqlalchemy import create_engine
from sqlalchemy import types

# %%
PATENT_DATA = '/Users/sanjay/data/patentsview/20181127/'
ENGINE = create_engine('mysql://root:innovate@localhost/patents_20181127?charset=utf8', encoding='utf-8')
CON = ENGINE.connect()

# %%
table_name = 'eager_assignee'
file = PATENT_DATA + table_name + '.csv'
print (file)
table_df = pd.read_csv(file, sep=',', encoding='utf-8', warn_bad_lines=True, error_bad_lines=False)
table_df.head()
# Out:
# /Users/sanjay/data/patentsview/20181127/eager_assignee.csv
#                                firm                       lookup_firm  \
# 0              22nd Century Limited              22nd Century Limited
# 1  3M Innovative Properties Company  3M Innovative Properties Company
# 2                540 Grid Solutions                540 Grid Solutions
# 3               646840 Alberta Ltd.                    646840 Alberta
# 4        AAC Technologies Pte. Ltd.              AAC Technologies Pte
#
#   vlookup_fixed_firm            final_lookup_firm_clnd  firm_length  \
# 0                NaN              22nd Century Limited         20.0
# 1                NaN  3M Innovative Properties Company         32.0
# 2                NaN                540 Grid Solutions         18.0
# 3                NaN                    646840 Alberta         14.0
# 4                NaN              AAC Technologies Pte         20.0
#
#                                            name_clnd  name_length  manual_fix  \
# 0           22nd Century Group, Inc. - Official Site           40         NaN
# 1                                 3M - Official Site           18         NaN
# 2  540 Grid Solutions LLC Company Profile | Key C...           57         1.0
# 3  16440 S Alberta Ct, Homer Glen, IL 60491 - rea...           54         1.0
# 4  AAC Technologies Pte. Ltd.: Private Company In...           59         1.0
#
#             hit_url  hit_url_length  ...  public  acquired_merged  Votes  \
# 0  xxiicentury.com/              27  ...       0                0      5
# 1           3m.com/              19  ...       0                0      3
# 2               NaN             106  ...       0                0      0
# 3               NaN              99  ...       0                0      0
# 4               NaN              82  ...       0                0      0
#
#    Group  nano  green  synbio  count_all_ind  max_emps           size_state
# 0      0     0      0       1              1       734  FirmSize.LARGE_FIRM
# 1      1     1      1       1              3     60593  FirmSize.LARGE_FIRM
# 2      2     0      1       0              1        18  FirmSize.SMALL_FIRM
# 3      3     0      1       0              1         0   FirmSize.UNDEFINED
# 4      4     1      0       0              1      2174  FirmSize.LARGE_FIRM
#
# [5 rows x 22 columns]

# %%
max(table_df['firm'].apply(len))
# Out:
# 84

# %%
table_df.to_sql(name=table_name,con=CON,if_exists='replace', index=False, 
                dtype={'id': types.NVARCHAR(length=36)}
               )

# %%
CON.close()
